# %% [markdown]
# # Gyroscope DDPG reward function testing (spinup library)

# %%
import gym
from gym import spaces
from gym.utils import seeding
from gym.envs.registration import register

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control

import spinup

from os import path
from scipy.integrate import solve_ivp
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline
#from vpython import *
from functools import partial


register(id='gyroscopeenv-v0',entry_point='gym_GyroscopeEnv.envs:GyroscopeEnv')

# %% [markdown]
# ## Training

# %% [markdown]
# #### Quadratic reward

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='ddpg_q', exp_name='ddpg_q')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0025
qlr_b = 0.0025

# Env function
reward_args = {'qx1':9,'qx2':0.05,'qx3':9,'qx4':0.05,'pu1':0.1,'pu2':0.1}
env_fn = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Quadratic', reward_args = reward_args,ep_len=maxeplen_b)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Warning: Log dir ddpg_q already exists! Storing info there anyway.
# Logging data to ddpg_q/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7f76de14bea0>, env_name='gyroscopeenv-v0', reward_type='Quadratic', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1}, ep_len=110)",
#     "epochs":	100,
#     "exp_name":	"ddpg_q",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f76adf1bc18>":	{
#             "epoch_dict":	{},
#             "exp_name":	"ddpg_q",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_q",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_q/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"ddpg_q",
#         "output_dir":	"ddpg_q"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0025,
#     "polyak":	0.995,
#     "q_lr":	0.0025,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 4802, 	 q: 5201
# /home/matthieulc/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |       -6.77e+03 |
# |          StdEpRet |         1.6e+03 |
# |          MaxEpRet |       -4.39e+03 |
# |          MinEpRet |       -1.04e+04 |
# |  AverageTestEpRet |       -7.26e+03 |
# |      StdTestEpRet |        2.44e+03 |
# |      MaxTestEpRet |       -3.51e+03 |
# |      MinTestEpRet |       -1.11e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |      AverageQVals |            -107 |
# |          StdQVals |            60.6 |
# |          MaxQVals |           0.149 |
# |          MinQVals |            -382 |
# |            LossPi |             104 |
# |             LossQ |        1.28e+03 |
# |              Time |            4.97 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |       -7.42e+03 |
# |          StdEpRet |        2.05e+03 |
# |          MaxEpRet |       -4.28e+03 |
# |          MinEpRet |       -1.07e+04 |
# |  AverageTestEpRet |       -7.91e+03 |
# |      StdTestEpRet |        3.15e+03 |
# |      MaxTestEpRet |       -2.41e+03 |
# |      MinTestEpRet |       -1.31e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |      AverageQVals |            -387 |
# |          StdQVals |             161 |
# |          MaxQVals |           -63.7 |
# |          MinQVals |       -1.08e+03 |
# |            LossPi |             376 |
# |             LossQ |        1.39e+03 |
# |              Time |            13.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |       -7.04e+03 |
# |          StdEpRet |        1.62e+03 |
# |          MaxEpRet |       -4.64e+03 |
# |          MinEpRet |       -1.09e+04 |
# |  AverageTestEpRet |       -5.72e+03 |
# |      StdTestEpRet |        3.26e+03 |
# |      MaxTestEpRet |       -1.54e+03 |
# |      MinTestEpRet |       -1.16e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |      AverageQVals |            -752 |
# |          StdQVals |             205 |
# |          MaxQVals |            -233 |
# |          MinQVals |       -1.59e+03 |
# |            LossPi |             732 |
# |             LossQ |        2.72e+03 |
# |              Time |            21.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |       -6.72e+03 |
# |          StdEpRet |        2.01e+03 |
# |          MaxEpRet |       -2.76e+03 |
# |          MinEpRet |       -1.15e+04 |
# |  AverageTestEpRet |          -4e+03 |
# |      StdTestEpRet |         3.9e+03 |
# |      MaxTestEpRet |            -699 |
# |      MinTestEpRet |       -1.36e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |      AverageQVals |       -1.05e+03 |
# |          StdQVals |             219 |
# |          MaxQVals |            -472 |
# |          MinQVals |       -1.91e+03 |
# |            LossPi |        1.03e+03 |
# |             LossQ |        3.12e+03 |
# |              Time |              32 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |       -7.06e+03 |
# |          StdEpRet |        2.35e+03 |
# |          MaxEpRet |       -4.33e+03 |
# |          MinEpRet |       -1.26e+04 |
# |  AverageTestEpRet |       -1.95e+03 |
# |      StdTestEpRet |        2.14e+03 |
# |      MaxTestEpRet |           -53.8 |
# |      MinTestEpRet |       -6.14e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |      AverageQVals |       -1.31e+03 |
# |          StdQVals |             241 |
# |          MaxQVals |            -673 |
# |          MinQVals |       -2.28e+03 |
# |            LossPi |        1.29e+03 |
# |             LossQ |        3.49e+03 |
# |              Time |            41.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |       -6.75e+03 |
# |          StdEpRet |         2.2e+03 |
# |          MaxEpRet |       -2.39e+03 |
# |          MinEpRet |       -1.12e+04 |
# |  AverageTestEpRet |       -2.03e+03 |
# |      StdTestEpRet |        1.79e+03 |
# |      MaxTestEpRet |            -481 |
# |      MinTestEpRet |       -6.86e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |      AverageQVals |       -1.53e+03 |
# |          StdQVals |             267 |
# |          MaxQVals |            -792 |
# |          MinQVals |       -2.52e+03 |
# |            LossPi |        1.49e+03 |
# |             LossQ |        3.99e+03 |
# |              Time |            49.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |       -1.55e+03 |
# |          StdEpRet |             955 |
# |          MaxEpRet |            -126 |
# |          MinEpRet |       -3.91e+03 |
# |  AverageTestEpRet |       -2.95e+03 |
# |      StdTestEpRet |        1.86e+03 |
# |      MaxTestEpRet |            -530 |
# |      MinTestEpRet |          -7e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |      AverageQVals |       -1.64e+03 |
# |          StdQVals |             306 |
# |          MaxQVals |            -873 |
# |          MinQVals |       -2.65e+03 |
# |            LossPi |        1.61e+03 |
# |             LossQ |           4e+03 |
# |              Time |            59.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |       -2.56e+03 |
# |          StdEpRet |        2.04e+03 |
# |          MaxEpRet |            -240 |
# |          MinEpRet |       -7.11e+03 |
# |  AverageTestEpRet |       -1.86e+03 |
# |      StdTestEpRet |        1.06e+03 |
# |      MaxTestEpRet |            -227 |
# |      MinTestEpRet |       -3.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |      AverageQVals |       -1.69e+03 |
# |          StdQVals |             352 |
# |          MaxQVals |            -946 |
# |          MinQVals |       -2.81e+03 |
# |            LossPi |        1.65e+03 |
# |             LossQ |        3.75e+03 |
# |              Time |            68.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |       -2.07e+03 |
# |          StdEpRet |        1.67e+03 |
# |          MaxEpRet |            -478 |
# |          MinEpRet |       -7.55e+03 |
# |  AverageTestEpRet |       -1.69e+03 |
# |      StdTestEpRet |        1.09e+03 |
# |      MaxTestEpRet |            -420 |
# |      MinTestEpRet |       -3.13e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |      AverageQVals |       -1.71e+03 |
# |          StdQVals |             387 |
# |          MaxQVals |            -879 |
# |          MinQVals |       -2.93e+03 |
# |            LossPi |        1.67e+03 |
# |             LossQ |        3.48e+03 |
# |              Time |            78.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |       -2.21e+03 |
# |          StdEpRet |        1.32e+03 |
# |          MaxEpRet |            -484 |
# |          MinEpRet |       -4.51e+03 |
# |  AverageTestEpRet |       -2.27e+03 |
# |      StdTestEpRet |             911 |
# |      MaxTestEpRet |       -1.13e+03 |
# |      MinTestEpRet |       -4.26e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |       -1.72e+03 |
# |          StdQVals |             413 |
# |          MaxQVals |            -852 |
# |          MinQVals |       -3.07e+03 |
# |            LossPi |        1.68e+03 |
# |             LossQ |        3.24e+03 |
# |              Time |            87.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |       -2.36e+03 |
# |          StdEpRet |        2.05e+03 |
# |          MaxEpRet |            -264 |
# |          MinEpRet |       -9.21e+03 |
# |  AverageTestEpRet |       -1.38e+03 |
# |      StdTestEpRet |             930 |
# |      MaxTestEpRet |            -207 |
# |      MinTestEpRet |       -3.46e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |      AverageQVals |       -1.73e+03 |
# |          StdQVals |             426 |
# |          MaxQVals |            -829 |
# |          MinQVals |       -3.15e+03 |
# |            LossPi |         1.7e+03 |
# |             LossQ |        3.04e+03 |
# |              Time |            96.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |       -2.18e+03 |
# |          StdEpRet |        2.27e+03 |
# |          MaxEpRet |            -357 |
# |          MinEpRet |       -8.09e+03 |
# |  AverageTestEpRet |       -1.88e+03 |
# |      StdTestEpRet |        1.04e+03 |
# |      MaxTestEpRet |            -806 |
# |      MinTestEpRet |       -4.27e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |      AverageQVals |       -1.72e+03 |
# |          StdQVals |             448 |
# |          MaxQVals |            -790 |
# |          MinQVals |       -3.23e+03 |
# |            LossPi |        1.69e+03 |
# |             LossQ |        2.79e+03 |
# |              Time |             106 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |       -2.26e+03 |
# |          StdEpRet |        1.68e+03 |
# |          MaxEpRet |            -165 |
# |          MinEpRet |       -7.35e+03 |
# |  AverageTestEpRet |       -1.22e+03 |
# |      StdTestEpRet |             749 |
# |      MaxTestEpRet |            -255 |
# |      MinTestEpRet |       -2.57e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |      AverageQVals |       -1.72e+03 |
# |          StdQVals |             463 |
# |          MaxQVals |            -748 |
# |          MinQVals |       -3.28e+03 |
# |            LossPi |         1.7e+03 |
# |             LossQ |        2.63e+03 |
# |              Time |             115 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |       -2.05e+03 |
# |          StdEpRet |        1.59e+03 |
# |          MaxEpRet |            -407 |
# |          MinEpRet |       -5.51e+03 |
# |  AverageTestEpRet |       -1.96e+03 |
# |      StdTestEpRet |         1.4e+03 |
# |      MaxTestEpRet |            -278 |
# |      MinTestEpRet |       -4.75e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |      AverageQVals |       -1.73e+03 |
# |          StdQVals |             472 |
# |          MaxQVals |            -713 |
# |          MinQVals |       -3.35e+03 |
# |            LossPi |         1.7e+03 |
# |             LossQ |        2.52e+03 |
# |              Time |             125 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |       -2.42e+03 |
# |          StdEpRet |        1.43e+03 |
# |          MaxEpRet |            -858 |
# |          MinEpRet |       -6.44e+03 |
# |  AverageTestEpRet |       -1.77e+03 |
# |      StdTestEpRet |        1.43e+03 |
# |      MaxTestEpRet |            -202 |
# |      MinTestEpRet |       -5.57e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |      AverageQVals |       -1.73e+03 |
# |          StdQVals |             487 |
# |          MaxQVals |            -675 |
# |          MinQVals |       -3.39e+03 |
# |            LossPi |         1.7e+03 |
# |             LossQ |        2.48e+03 |
# |              Time |             134 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |       -2.11e+03 |
# |          StdEpRet |        1.22e+03 |
# |          MaxEpRet |            -554 |
# |          MinEpRet |       -5.49e+03 |
# |  AverageTestEpRet |       -2.36e+03 |
# |      StdTestEpRet |        1.54e+03 |
# |      MaxTestEpRet |            -328 |
# |      MinTestEpRet |       -5.46e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |      AverageQVals |       -1.72e+03 |
# |          StdQVals |             500 |
# |          MaxQVals |            -642 |
# |          MinQVals |       -3.43e+03 |
# |            LossPi |        1.69e+03 |
# |             LossQ |        2.39e+03 |
# |              Time |             143 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |       -1.37e+03 |
# |          StdEpRet |             832 |
# |          MaxEpRet |            -353 |
# |          MinEpRet |       -3.69e+03 |
# |  AverageTestEpRet |       -2.01e+03 |
# |      StdTestEpRet |             858 |
# |      MaxTestEpRet |            -262 |
# |      MinTestEpRet |       -3.71e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |      AverageQVals |        -1.7e+03 |
# |          StdQVals |             513 |
# |          MaxQVals |            -584 |
# |          MinQVals |       -3.47e+03 |
# |            LossPi |        1.68e+03 |
# |             LossQ |        2.29e+03 |
# |              Time |             153 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |        -2.2e+03 |
# |          StdEpRet |        1.57e+03 |
# |          MaxEpRet |            -198 |
# |          MinEpRet |       -5.07e+03 |
# |  AverageTestEpRet |       -2.48e+03 |
# |      StdTestEpRet |        2.59e+03 |
# |      MaxTestEpRet |           -36.3 |
# |      MinTestEpRet |       -9.86e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |      AverageQVals |       -1.68e+03 |
# |          StdQVals |             526 |
# |          MaxQVals |            -531 |
# |          MinQVals |       -3.46e+03 |
# |            LossPi |        1.66e+03 |
# |             LossQ |         2.2e+03 |
# |              Time |             163 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |       -1.97e+03 |
# |          StdEpRet |        1.09e+03 |
# |          MaxEpRet |            -848 |
# |          MinEpRet |       -4.11e+03 |
# |  AverageTestEpRet |       -2.27e+03 |
# |      StdTestEpRet |        2.69e+03 |
# |      MaxTestEpRet |            -191 |
# |      MinTestEpRet |       -9.68e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |      AverageQVals |       -1.67e+03 |
# |          StdQVals |             549 |
# |          MaxQVals |            -490 |
# |          MinQVals |       -3.51e+03 |
# |            LossPi |        1.65e+03 |
# |             LossQ |        2.14e+03 |
# |              Time |             173 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |        -1.4e+03 |
# |          StdEpRet |             895 |
# |          MaxEpRet |            -152 |
# |          MinEpRet |       -3.09e+03 |
# |  AverageTestEpRet |       -2.41e+03 |
# |      StdTestEpRet |        1.72e+03 |
# |      MaxTestEpRet |            -329 |
# |      MinTestEpRet |       -5.01e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |       -1.65e+03 |
# |          StdQVals |             562 |
# |          MaxQVals |            -442 |
# |          MinQVals |       -3.51e+03 |
# |            LossPi |        1.63e+03 |
# |             LossQ |        2.07e+03 |
# |              Time |             183 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |       -2.16e+03 |
# |          StdEpRet |        1.41e+03 |
# |          MaxEpRet |            -299 |
# |          MinEpRet |       -4.39e+03 |
# |  AverageTestEpRet |       -1.82e+03 |
# |      StdTestEpRet |        1.25e+03 |
# |      MaxTestEpRet |            -111 |
# |      MinTestEpRet |       -3.47e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |      AverageQVals |       -1.63e+03 |
# |          StdQVals |             576 |
# |          MaxQVals |            -394 |
# |          MinQVals |       -3.53e+03 |
# |            LossPi |        1.61e+03 |
# |             LossQ |        2.04e+03 |
# |              Time |             192 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |       -2.27e+03 |
# |          StdEpRet |        1.39e+03 |
# |          MaxEpRet |            -607 |
# |          MinEpRet |       -4.75e+03 |
# |  AverageTestEpRet |          -2e+03 |
# |      StdTestEpRet |        1.06e+03 |
# |      MaxTestEpRet |            -440 |
# |      MinTestEpRet |        -3.7e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |      AverageQVals |       -1.61e+03 |
# |          StdQVals |             590 |
# |          MaxQVals |            -349 |
# |          MinQVals |       -3.55e+03 |
# |            LossPi |        1.59e+03 |
# |             LossQ |        1.95e+03 |
# |              Time |             202 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |       -2.03e+03 |
# |          StdEpRet |        1.22e+03 |
# |          MaxEpRet |            -457 |
# |          MinEpRet |       -4.76e+03 |
# |  AverageTestEpRet |       -1.78e+03 |
# |      StdTestEpRet |        1.38e+03 |
# |      MaxTestEpRet |            -382 |
# |      MinTestEpRet |       -4.93e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |      AverageQVals |       -1.58e+03 |
# |          StdQVals |             597 |
# |          MaxQVals |            -307 |
# |          MinQVals |       -3.58e+03 |
# |            LossPi |        1.56e+03 |
# |             LossQ |        1.93e+03 |
# |              Time |             210 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |       -1.63e+03 |
# |          StdEpRet |             868 |
# |          MaxEpRet |            -572 |
# |          MinEpRet |       -3.51e+03 |
# |  AverageTestEpRet |       -2.02e+03 |
# |      StdTestEpRet |             877 |
# |      MaxTestEpRet |            -584 |
# |      MinTestEpRet |        -3.7e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |      AverageQVals |       -1.55e+03 |
# |          StdQVals |             607 |
# |          MaxQVals |            -272 |
# |          MinQVals |        -3.6e+03 |
# |            LossPi |        1.53e+03 |
# |             LossQ |        1.87e+03 |
# |              Time |             219 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |       -1.86e+03 |
# |          StdEpRet |        2.18e+03 |
# |          MaxEpRet |            -199 |
# |          MinEpRet |       -9.42e+03 |
# |  AverageTestEpRet |       -1.85e+03 |
# |      StdTestEpRet |        1.35e+03 |
# |      MaxTestEpRet |            -448 |
# |      MinTestEpRet |       -3.96e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |      AverageQVals |       -1.51e+03 |
# |          StdQVals |             611 |
# |          MaxQVals |            -234 |
# |          MinQVals |       -3.61e+03 |
# |            LossPi |        1.49e+03 |
# |             LossQ |        1.87e+03 |
# |              Time |             229 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |       -1.87e+03 |
# |          StdEpRet |        1.33e+03 |
# |          MaxEpRet |            -250 |
# |          MinEpRet |        -5.4e+03 |
# |  AverageTestEpRet |       -1.94e+03 |
# |      StdTestEpRet |        1.28e+03 |
# |      MaxTestEpRet |            -154 |
# |      MinTestEpRet |       -3.94e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |      AverageQVals |       -1.48e+03 |
# |          StdQVals |             621 |
# |          MaxQVals |            -201 |
# |          MinQVals |       -3.62e+03 |
# |            LossPi |        1.46e+03 |
# |             LossQ |        1.82e+03 |
# |              Time |             238 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |       -1.89e+03 |
# |          StdEpRet |        1.03e+03 |
# |          MaxEpRet |            -506 |
# |          MinEpRet |       -3.72e+03 |
# |  AverageTestEpRet |       -1.95e+03 |
# |      StdTestEpRet |        1.35e+03 |
# |      MaxTestEpRet |            -568 |
# |      MinTestEpRet |       -5.43e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |      AverageQVals |       -1.45e+03 |
# |          StdQVals |             623 |
# |          MaxQVals |            -175 |
# |          MinQVals |       -3.67e+03 |
# |            LossPi |        1.43e+03 |
# |             LossQ |        1.82e+03 |
# |              Time |             248 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |       -2.07e+03 |
# |          StdEpRet |        1.35e+03 |
# |          MaxEpRet |            -251 |
# |          MinEpRet |       -4.49e+03 |
# |  AverageTestEpRet |       -1.76e+03 |
# |      StdTestEpRet |             984 |
# |      MaxTestEpRet |            -737 |
# |      MinTestEpRet |        -4.1e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |      AverageQVals |       -1.42e+03 |
# |          StdQVals |             630 |
# |          MaxQVals |            -153 |
# |          MinQVals |       -3.68e+03 |
# |            LossPi |         1.4e+03 |
# |             LossQ |        1.85e+03 |
# |              Time |             257 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |       -2.27e+03 |
# |          StdEpRet |        1.52e+03 |
# |          MaxEpRet |            -530 |
# |          MinEpRet |       -5.87e+03 |
# |  AverageTestEpRet |       -1.51e+03 |
# |      StdTestEpRet |             878 |
# |      MaxTestEpRet |            -588 |
# |      MinTestEpRet |        -3.6e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |      AverageQVals |       -1.39e+03 |
# |          StdQVals |             635 |
# |          MaxQVals |            -131 |
# |          MinQVals |       -3.68e+03 |
# |            LossPi |        1.37e+03 |
# |             LossQ |        1.82e+03 |
# |              Time |             266 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |       -1.65e+03 |
# |          StdEpRet |        1.68e+03 |
# |          MaxEpRet |           -82.3 |
# |          MinEpRet |       -6.33e+03 |
# |  AverageTestEpRet |       -2.03e+03 |
# |      StdTestEpRet |        2.01e+03 |
# |      MaxTestEpRet |            -226 |
# |      MinTestEpRet |       -7.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |       -1.35e+03 |
# |          StdQVals |             645 |
# |          MaxQVals |            -108 |
# |          MinQVals |       -3.67e+03 |
# |            LossPi |        1.33e+03 |
# |             LossQ |        1.85e+03 |
# |              Time |             274 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |       -1.93e+03 |
# |          StdEpRet |        1.32e+03 |
# |          MaxEpRet |            -577 |
# |          MinEpRet |       -4.77e+03 |
# |  AverageTestEpRet |       -1.85e+03 |
# |      StdTestEpRet |        1.34e+03 |
# |      MaxTestEpRet |            -415 |
# |      MinTestEpRet |       -4.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |      AverageQVals |       -1.31e+03 |
# |          StdQVals |             659 |
# |          MaxQVals |           -80.3 |
# |          MinQVals |       -3.69e+03 |
# |            LossPi |        1.29e+03 |
# |             LossQ |        1.83e+03 |
# |              Time |             282 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |       -1.81e+03 |
# |          StdEpRet |        1.64e+03 |
# |          MaxEpRet |            -112 |
# |          MinEpRet |        -5.8e+03 |
# |  AverageTestEpRet |       -1.69e+03 |
# |      StdTestEpRet |        1.17e+03 |
# |      MaxTestEpRet |            -151 |
# |      MinTestEpRet |       -3.95e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |      AverageQVals |       -1.27e+03 |
# |          StdQVals |             666 |
# |          MaxQVals |           -28.4 |
# |          MinQVals |       -3.75e+03 |
# |            LossPi |        1.25e+03 |
# |             LossQ |        1.85e+03 |
# |              Time |             290 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |       -1.82e+03 |
# |          StdEpRet |        1.53e+03 |
# |          MaxEpRet |            -141 |
# |          MinEpRet |       -4.97e+03 |
# |  AverageTestEpRet |            -998 |
# |      StdTestEpRet |             796 |
# |      MaxTestEpRet |            -341 |
# |      MinTestEpRet |       -2.47e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |      AverageQVals |       -1.21e+03 |
# |          StdQVals |             671 |
# |          MaxQVals |            31.5 |
# |          MinQVals |       -3.75e+03 |
# |            LossPi |        1.19e+03 |
# |             LossQ |        1.82e+03 |
# |              Time |             298 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |       -1.11e+03 |
# |          StdEpRet |         1.1e+03 |
# |          MaxEpRet |             -66 |
# |          MinEpRet |       -4.86e+03 |
# |  AverageTestEpRet |       -1.73e+03 |
# |      StdTestEpRet |             984 |
# |      MaxTestEpRet |            -243 |
# |      MinTestEpRet |       -3.57e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |      AverageQVals |       -1.15e+03 |
# |          StdQVals |             678 |
# |          MaxQVals |            86.1 |
# |          MinQVals |       -3.75e+03 |
# |            LossPi |        1.13e+03 |
# |             LossQ |         1.8e+03 |
# |              Time |             305 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |       -1.68e+03 |
# |          StdEpRet |        1.19e+03 |
# |          MaxEpRet |            -168 |
# |          MinEpRet |       -4.18e+03 |
# |  AverageTestEpRet |       -1.83e+03 |
# |      StdTestEpRet |        1.46e+03 |
# |      MaxTestEpRet |            -324 |
# |      MinTestEpRet |       -5.03e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |      AverageQVals |        -1.1e+03 |
# |          StdQVals |             688 |
# |          MaxQVals |             145 |
# |          MinQVals |       -3.75e+03 |
# |            LossPi |        1.08e+03 |
# |             LossQ |        1.76e+03 |
# |              Time |             313 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |       -1.59e+03 |
# |          StdEpRet |             934 |
# |          MaxEpRet |            -345 |
# |          MinEpRet |       -3.33e+03 |
# |  AverageTestEpRet |       -1.94e+03 |
# |      StdTestEpRet |        1.23e+03 |
# |      MaxTestEpRet |            -344 |
# |      MinTestEpRet |       -4.14e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |      AverageQVals |       -1.05e+03 |
# |          StdQVals |             694 |
# |          MaxQVals |             176 |
# |          MinQVals |       -3.71e+03 |
# |            LossPi |        1.03e+03 |
# |             LossQ |        1.75e+03 |
# |              Time |             320 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |       -1.62e+03 |
# |          StdEpRet |        1.26e+03 |
# |          MaxEpRet |            -446 |
# |          MinEpRet |       -4.14e+03 |
# |  AverageTestEpRet |       -1.13e+03 |
# |      StdTestEpRet |             698 |
# |      MaxTestEpRet |           -97.7 |
# |      MinTestEpRet |        -2.3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |      AverageQVals |            -998 |
# |          StdQVals |             700 |
# |          MaxQVals |             212 |
# |          MinQVals |       -3.73e+03 |
# |            LossPi |             975 |
# |             LossQ |        1.67e+03 |
# |              Time |             329 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |        -1.4e+03 |
# |          StdEpRet |        1.32e+03 |
# |          MaxEpRet |            -205 |
# |          MinEpRet |       -3.65e+03 |
# |  AverageTestEpRet |            -830 |
# |      StdTestEpRet |             484 |
# |      MaxTestEpRet |            -110 |
# |      MinTestEpRet |       -1.92e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |      AverageQVals |            -944 |
# |          StdQVals |             714 |
# |          MaxQVals |             255 |
# |          MinQVals |       -3.72e+03 |
# |            LossPi |             921 |
# |             LossQ |        1.68e+03 |
# |              Time |             337 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -991 |
# |          StdEpRet |             565 |
# |          MaxEpRet |            -170 |
# |          MinEpRet |       -2.01e+03 |
# |  AverageTestEpRet |            -851 |
# |      StdTestEpRet |             790 |
# |      MaxTestEpRet |           -98.3 |
# |      MinTestEpRet |       -2.98e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |      AverageQVals |            -869 |
# |          StdQVals |             719 |
# |          MaxQVals |             296 |
# |          MinQVals |       -3.68e+03 |
# |            LossPi |             845 |
# |             LossQ |        1.62e+03 |
# |              Time |             346 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |       -1.24e+03 |
# |          StdEpRet |             743 |
# |          MaxEpRet |            -248 |
# |          MinEpRet |       -2.91e+03 |
# |  AverageTestEpRet |       -1.45e+03 |
# |      StdTestEpRet |        1.02e+03 |
# |      MaxTestEpRet |            -288 |
# |      MinTestEpRet |       -3.42e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |            -792 |
# |          StdQVals |             720 |
# |          MaxQVals |             351 |
# |          MinQVals |       -3.63e+03 |
# |            LossPi |             767 |
# |             LossQ |        1.58e+03 |
# |              Time |             356 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |       -1.13e+03 |
# |          StdEpRet |             747 |
# |          MaxEpRet |             -57 |
# |          MinEpRet |       -3.19e+03 |
# |  AverageTestEpRet |        -1.3e+03 |
# |      StdTestEpRet |             567 |
# |      MaxTestEpRet |            -354 |
# |      MinTestEpRet |       -2.36e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |      AverageQVals |            -720 |
# |          StdQVals |             719 |
# |          MaxQVals |             449 |
# |          MinQVals |        -3.6e+03 |
# |            LossPi |             696 |
# |             LossQ |        1.54e+03 |
# |              Time |             366 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |       -1.11e+03 |
# |          StdEpRet |        1.14e+03 |
# |          MaxEpRet |           -96.9 |
# |          MinEpRet |       -4.74e+03 |
# |  AverageTestEpRet |            -850 |
# |      StdTestEpRet |             431 |
# |      MaxTestEpRet |            -199 |
# |      MinTestEpRet |       -1.63e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |      AverageQVals |            -647 |
# |          StdQVals |             718 |
# |          MaxQVals |             540 |
# |          MinQVals |       -3.51e+03 |
# |            LossPi |             623 |
# |             LossQ |        1.51e+03 |
# |              Time |             376 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -806 |
# |          StdEpRet |             594 |
# |          MaxEpRet |           -97.7 |
# |          MinEpRet |       -2.22e+03 |
# |  AverageTestEpRet |       -2.04e+03 |
# |      StdTestEpRet |        1.32e+03 |
# |      MaxTestEpRet |            -327 |
# |      MinTestEpRet |        -4.3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |      AverageQVals |            -579 |
# |          StdQVals |             722 |
# |          MaxQVals |             655 |
# |          MinQVals |       -3.39e+03 |
# |            LossPi |             555 |
# |             LossQ |        1.48e+03 |
# |              Time |             387 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |       -1.36e+03 |
# |          StdEpRet |             993 |
# |          MaxEpRet |           -84.3 |
# |          MinEpRet |       -3.88e+03 |
# |  AverageTestEpRet |       -1.38e+03 |
# |      StdTestEpRet |             935 |
# |      MaxTestEpRet |            -158 |
# |      MinTestEpRet |       -3.43e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |      AverageQVals |            -509 |
# |          StdQVals |             724 |
# |          MaxQVals |             698 |
# |          MinQVals |       -3.38e+03 |
# |            LossPi |             486 |
# |             LossQ |        1.41e+03 |
# |              Time |             397 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |       -1.12e+03 |
# |          StdEpRet |             632 |
# |          MaxEpRet |            -214 |
# |          MinEpRet |       -2.17e+03 |
# |  AverageTestEpRet |       -1.59e+03 |
# |      StdTestEpRet |        1.24e+03 |
# |      MaxTestEpRet |            -382 |
# |      MinTestEpRet |       -4.97e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |      AverageQVals |            -450 |
# |          StdQVals |             725 |
# |          MaxQVals |             783 |
# |          MinQVals |       -3.35e+03 |
# |            LossPi |             427 |
# |             LossQ |        1.42e+03 |
# |              Time |             407 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |       -1.08e+03 |
# |          StdEpRet |        1.35e+03 |
# |          MaxEpRet |           -63.9 |
# |          MinEpRet |       -4.72e+03 |
# |  AverageTestEpRet |       -1.74e+03 |
# |      StdTestEpRet |        1.12e+03 |
# |      MaxTestEpRet |            -439 |
# |      MinTestEpRet |       -3.85e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |      AverageQVals |            -385 |
# |          StdQVals |             730 |
# |          MaxQVals |             844 |
# |          MinQVals |       -3.36e+03 |
# |            LossPi |             361 |
# |             LossQ |        1.38e+03 |
# |              Time |             416 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |       -1.31e+03 |
# |          StdEpRet |        1.07e+03 |
# |          MaxEpRet |            -187 |
# |          MinEpRet |       -4.24e+03 |
# |  AverageTestEpRet |        -2.1e+03 |
# |      StdTestEpRet |        1.59e+03 |
# |      MaxTestEpRet |            -253 |
# |      MinTestEpRet |       -5.91e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.75e+04 |
# |      AverageQVals |            -320 |
# |          StdQVals |             728 |
# |          MaxQVals |             924 |
# |          MinQVals |        -3.3e+03 |
# |            LossPi |             297 |
# |             LossQ |        1.37e+03 |
# |              Time |             427 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |       -1.41e+03 |
# |          StdEpRet |        1.13e+03 |
# |          MaxEpRet |            -324 |
# |          MinEpRet |       -4.25e+03 |
# |  AverageTestEpRet |            -686 |
# |      StdTestEpRet |             528 |
# |      MaxTestEpRet |            -164 |
# |      MinTestEpRet |       -2.02e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.92e+04 |
# |      AverageQVals |            -263 |
# |          StdQVals |             731 |
# |          MaxQVals |             984 |
# |          MinQVals |       -3.32e+03 |
# |            LossPi |             240 |
# |             LossQ |        1.39e+03 |
# |              Time |             436 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |       -1.75e+03 |
# |          StdEpRet |        1.61e+03 |
# |          MaxEpRet |            -281 |
# |          MinEpRet |       -5.87e+03 |
# |  AverageTestEpRet |       -1.46e+03 |
# |      StdTestEpRet |        1.29e+03 |
# |      MaxTestEpRet |            -108 |
# |      MinTestEpRet |       -3.95e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+04 |
# |      AverageQVals |            -208 |
# |          StdQVals |             733 |
# |          MaxQVals |        1.05e+03 |
# |          MinQVals |       -3.27e+03 |
# |            LossPi |             186 |
# |             LossQ |        1.34e+03 |
# |              Time |             446 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |       -1.25e+03 |
# |          StdEpRet |             775 |
# |          MaxEpRet |            -168 |
# |          MinEpRet |          -3e+03 |
# |  AverageTestEpRet |       -1.67e+03 |
# |      StdTestEpRet |             745 |
# |      MaxTestEpRet |            -337 |
# |      MinTestEpRet |       -3.07e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |            -152 |
# |          StdQVals |             734 |
# |          MaxQVals |        1.07e+03 |
# |          MinQVals |       -3.25e+03 |
# |            LossPi |             129 |
# |             LossQ |        1.33e+03 |
# |              Time |             455 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |       -1.31e+03 |
# |          StdEpRet |        1.05e+03 |
# |          MaxEpRet |            -393 |
# |          MinEpRet |       -4.18e+03 |
# |  AverageTestEpRet |        -1.3e+03 |
# |      StdTestEpRet |        1.07e+03 |
# |      MaxTestEpRet |            -274 |
# |      MinTestEpRet |       -3.25e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.41e+04 |
# |      AverageQVals |            -108 |
# |          StdQVals |             741 |
# |          MaxQVals |        1.14e+03 |
# |          MinQVals |       -3.25e+03 |
# |            LossPi |            84.4 |
# |             LossQ |        1.34e+03 |
# |              Time |             465 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |       -1.31e+03 |
# |          StdEpRet |             797 |
# |          MaxEpRet |            -438 |
# |          MinEpRet |       -2.72e+03 |
# |  AverageTestEpRet |       -1.46e+03 |
# |      StdTestEpRet |        1.24e+03 |
# |      MaxTestEpRet |            -245 |
# |      MinTestEpRet |       -4.52e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.58e+04 |
# |      AverageQVals |             -55 |
# |          StdQVals |             746 |
# |          MaxQVals |        1.21e+03 |
# |          MinQVals |       -3.29e+03 |
# |            LossPi |            30.8 |
# |             LossQ |        1.35e+03 |
# |              Time |             475 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |       -1.48e+03 |
# |          StdEpRet |        1.11e+03 |
# |          MaxEpRet |            -317 |
# |          MinEpRet |       -4.02e+03 |
# |  AverageTestEpRet |       -1.44e+03 |
# |      StdTestEpRet |        1.19e+03 |
# |      MaxTestEpRet |            -146 |
# |      MinTestEpRet |       -4.46e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.74e+04 |
# |      AverageQVals |             3.1 |
# |          StdQVals |             749 |
# |          MaxQVals |        1.28e+03 |
# |          MinQVals |        -3.3e+03 |
# |            LossPi |           -26.8 |
# |             LossQ |        1.34e+03 |
# |              Time |             484 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |       -1.73e+03 |
# |          StdEpRet |        1.64e+03 |
# |          MaxEpRet |            -109 |
# |          MinEpRet |       -6.18e+03 |
# |  AverageTestEpRet |            -880 |
# |      StdTestEpRet |             730 |
# |      MaxTestEpRet |            -108 |
# |      MinTestEpRet |       -2.21e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.91e+04 |
# |      AverageQVals |            60.7 |
# |          StdQVals |             749 |
# |          MaxQVals |        1.33e+03 |
# |          MinQVals |       -3.27e+03 |
# |            LossPi |           -84.8 |
# |             LossQ |        1.36e+03 |
# |              Time |             493 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |            -952 |
# |          StdEpRet |             705 |
# |          MaxEpRet |           -79.9 |
# |          MinEpRet |       -2.37e+03 |
# |  AverageTestEpRet |       -1.12e+03 |
# |      StdTestEpRet |             648 |
# |      MaxTestEpRet |            -398 |
# |      MinTestEpRet |       -2.65e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        9.07e+04 |
# |      AverageQVals |             119 |
# |          StdQVals |             756 |
# |          MaxQVals |        1.41e+03 |
# |          MinQVals |       -3.22e+03 |
# |            LossPi |            -144 |
# |             LossQ |        1.36e+03 |
# |              Time |             503 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              56 |
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              82 |
# |      AverageEpRet |            -896 |
# |          StdEpRet |             625 |
# |          MaxEpRet |            -174 |
# |          MinEpRet |       -2.26e+03 |
# |  AverageTestEpRet |            -945 |
# |      StdTestEpRet |        1.03e+03 |
# |      MaxTestEpRet |            -116 |
# |      MinTestEpRet |       -3.66e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.35e+05 |
# |      AverageQVals |        1.17e+03 |
# |          StdQVals |             782 |
# |          MaxQVals |        2.52e+03 |
# |          MinQVals |       -2.74e+03 |
# |            LossPi |        -1.2e+03 |
# |             LossQ |         1.1e+03 |
# |              Time |             747 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              83 |
# |      AverageEpRet |            -789 |
# |          StdEpRet |             425 |
# |          MaxEpRet |            -244 |
# |          MinEpRet |        -2.1e+03 |
# |  AverageTestEpRet |          -1e+03 |
# |      StdTestEpRet |             577 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |       -1.83e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.37e+05 |
# |      AverageQVals |        1.19e+03 |
# |          StdQVals |             779 |
# |          MaxQVals |        2.53e+03 |
# |          MinQVals |       -2.73e+03 |
# |            LossPi |       -1.21e+03 |
# |             LossQ |        1.11e+03 |
# |              Time |             757 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |            -930 |
# |          StdEpRet |             625 |
# |          MaxEpRet |            -129 |
# |          MinEpRet |       -2.11e+03 |
# |  AverageTestEpRet |            -652 |
# |      StdTestEpRet |             376 |
# |      MaxTestEpRet |            -191 |
# |      MinTestEpRet |        -1.5e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.39e+05 |
# |      AverageQVals |        1.21e+03 |
# |          StdQVals |             781 |
# |          MaxQVals |        2.51e+03 |
# |          MinQVals |       -2.75e+03 |
# |            LossPi |       -1.23e+03 |
# |             LossQ |        1.08e+03 |
# |              Time |             767 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |            -807 |
# |          StdEpRet |             567 |
# |          MaxEpRet |           -83.2 |
# |          MinEpRet |       -1.95e+03 |
# |  AverageTestEpRet |            -840 |
# |      StdTestEpRet |             607 |
# |      MaxTestEpRet |            -319 |
# |      MinTestEpRet |       -2.42e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.4e+05 |
# |      AverageQVals |        1.23e+03 |
# |          StdQVals |             775 |
# |          MaxQVals |        2.51e+03 |
# |          MinQVals |       -2.74e+03 |
# |            LossPi |       -1.25e+03 |
# |             LossQ |        1.08e+03 |
# |              Time |             776 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |        -1.1e+03 |
# |          StdEpRet |             661 |
# |          MaxEpRet |            -265 |
# |          MinEpRet |       -2.66e+03 |
# |  AverageTestEpRet |            -763 |
# |      StdTestEpRet |             300 |
# |      MaxTestEpRet |            -131 |
# |      MinTestEpRet |       -1.35e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.42e+05 |
# |      AverageQVals |        1.24e+03 |
# |          StdQVals |             778 |
# |          MaxQVals |        2.51e+03 |
# |          MinQVals |       -2.74e+03 |
# |            LossPi |       -1.26e+03 |
# |             LossQ |        1.08e+03 |
# |              Time |             786 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |       -1.05e+03 |
# |          StdEpRet |             683 |
# |          MaxEpRet |            -244 |
# |          MinEpRet |        -2.6e+03 |
# |  AverageTestEpRet |            -867 |
# |      StdTestEpRet |             648 |
# |      MaxTestEpRet |            -178 |
# |      MinTestEpRet |       -2.32e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.44e+05 |
# |      AverageQVals |        1.26e+03 |
# |          StdQVals |             773 |
# |          MaxQVals |        2.53e+03 |
# |          MinQVals |       -2.69e+03 |
# |            LossPi |       -1.28e+03 |
# |             LossQ |        1.08e+03 |
# |              Time |             796 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |        -1.1e+03 |
# |          StdEpRet |             564 |
# |          MaxEpRet |            -253 |
# |          MinEpRet |       -2.15e+03 |
# |  AverageTestEpRet |            -533 |
# |      StdTestEpRet |             342 |
# |      MaxTestEpRet |            -252 |
# |      MinTestEpRet |        -1.4e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.45e+05 |
# |      AverageQVals |        1.28e+03 |
# |          StdQVals |             764 |
# |          MaxQVals |        2.55e+03 |
# |          MinQVals |       -2.61e+03 |
# |            LossPi |        -1.3e+03 |
# |             LossQ |        1.06e+03 |
# |              Time |             805 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |            -641 |
# |          StdEpRet |             459 |
# |          MaxEpRet |           -75.5 |
# |          MinEpRet |       -2.01e+03 |
# |  AverageTestEpRet |            -673 |
# |      StdTestEpRet |             282 |
# |      MaxTestEpRet |            -125 |
# |      MinTestEpRet |        -1.2e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.47e+05 |
# |      AverageQVals |         1.3e+03 |
# |          StdQVals |             757 |
# |          MaxQVals |        2.58e+03 |
# |          MinQVals |       -2.59e+03 |
# |            LossPi |       -1.32e+03 |
# |             LossQ |        1.07e+03 |
# |              Time |             814 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |       -1.07e+03 |
# |          StdEpRet |        1.06e+03 |
# |          MaxEpRet |            -144 |
# |          MinEpRet |       -4.14e+03 |
# |  AverageTestEpRet |       -1.24e+03 |
# |      StdTestEpRet |             865 |
# |      MaxTestEpRet |            -332 |
# |      MinTestEpRet |       -3.46e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+05 |
# |      AverageQVals |        1.32e+03 |
# |          StdQVals |             750 |
# |          MaxQVals |         2.6e+03 |
# |          MinQVals |       -2.46e+03 |
# |            LossPi |       -1.34e+03 |
# |             LossQ |        1.07e+03 |
# |              Time |             823 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |            -925 |
# |          StdEpRet |             456 |
# |          MaxEpRet |            -242 |
# |          MinEpRet |       -1.89e+03 |
# |  AverageTestEpRet |       -1.23e+03 |
# |      StdTestEpRet |         1.2e+03 |
# |      MaxTestEpRet |            -185 |
# |      MinTestEpRet |       -4.51e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.5e+05 |
# |      AverageQVals |        1.34e+03 |
# |          StdQVals |             742 |
# |          MaxQVals |        2.63e+03 |
# |          MinQVals |        -2.4e+03 |
# |            LossPi |       -1.37e+03 |
# |             LossQ |        1.07e+03 |
# |              Time |             831 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |            -747 |
# |          StdEpRet |             704 |
# |          MaxEpRet |            -154 |
# |          MinEpRet |       -3.22e+03 |
# |  AverageTestEpRet |            -717 |
# |      StdTestEpRet |             534 |
# |      MaxTestEpRet |            -219 |
# |      MinTestEpRet |       -1.71e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.52e+05 |
# |      AverageQVals |        1.37e+03 |
# |          StdQVals |             733 |
# |          MaxQVals |        2.62e+03 |
# |          MinQVals |       -2.31e+03 |
# |            LossPi |       -1.39e+03 |
# |             LossQ |        1.05e+03 |
# |              Time |             839 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |            -750 |
# |          StdEpRet |             374 |
# |          MaxEpRet |            -261 |
# |          MinEpRet |       -1.66e+03 |
# |  AverageTestEpRet |            -739 |
# |      StdTestEpRet |             376 |
# |      MaxTestEpRet |           -97.2 |
# |      MinTestEpRet |       -1.34e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.53e+05 |
# |      AverageQVals |        1.38e+03 |
# |          StdQVals |             719 |
# |          MaxQVals |        2.59e+03 |
# |          MinQVals |       -2.24e+03 |
# |            LossPi |       -1.41e+03 |
# |             LossQ |        1.05e+03 |
# |              Time |             847 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |            -891 |
# |          StdEpRet |             314 |
# |          MaxEpRet |            -295 |
# |          MinEpRet |       -1.32e+03 |
# |  AverageTestEpRet |            -743 |
# |      StdTestEpRet |             381 |
# |      MaxTestEpRet |            -179 |
# |      MinTestEpRet |        -1.3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.55e+05 |
# |      AverageQVals |         1.4e+03 |
# |          StdQVals |             703 |
# |          MaxQVals |         2.6e+03 |
# |          MinQVals |       -2.17e+03 |
# |            LossPi |       -1.42e+03 |
# |             LossQ |        1.05e+03 |
# |              Time |             854 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |            -809 |
# |          StdEpRet |             565 |
# |          MaxEpRet |            -214 |
# |          MinEpRet |       -2.49e+03 |
# |  AverageTestEpRet |       -1.05e+03 |
# |      StdTestEpRet |             687 |
# |      MaxTestEpRet |            -185 |
# |      MinTestEpRet |       -2.21e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.57e+05 |
# |      AverageQVals |        1.41e+03 |
# |          StdQVals |             688 |
# |          MaxQVals |        2.58e+03 |
# |          MinQVals |       -2.05e+03 |
# |            LossPi |       -1.43e+03 |
# |             LossQ |        1.06e+03 |
# |              Time |             863 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |       -1.14e+03 |
# |          StdEpRet |             818 |
# |          MaxEpRet |            -242 |
# |          MinEpRet |       -3.22e+03 |
# |  AverageTestEpRet |       -1.01e+03 |
# |      StdTestEpRet |             822 |
# |      MaxTestEpRet |            -350 |
# |      MinTestEpRet |       -3.29e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.58e+05 |
# |      AverageQVals |        1.42e+03 |
# |          StdQVals |             677 |
# |          MaxQVals |        2.58e+03 |
# |          MinQVals |       -1.99e+03 |
# |            LossPi |       -1.44e+03 |
# |             LossQ |        1.05e+03 |
# |              Time |             873 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |            -788 |
# |          StdEpRet |             593 |
# |          MaxEpRet |            -209 |
# |          MinEpRet |       -2.18e+03 |
# |  AverageTestEpRet |            -836 |
# |      StdTestEpRet |             359 |
# |      MaxTestEpRet |            -457 |
# |      MinTestEpRet |       -1.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.6e+05 |
# |      AverageQVals |        1.43e+03 |
# |          StdQVals |             670 |
# |          MaxQVals |        2.58e+03 |
# |          MinQVals |       -1.95e+03 |
# |            LossPi |       -1.45e+03 |
# |             LossQ |        1.07e+03 |
# |              Time |             883 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |            -448 |
# |          StdEpRet |             268 |
# |          MaxEpRet |           -70.3 |
# |          MinEpRet |        -1.1e+03 |
# |  AverageTestEpRet |            -892 |
# |      StdTestEpRet |             766 |
# |      MaxTestEpRet |            -267 |
# |      MinTestEpRet |       -2.55e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.62e+05 |
# |      AverageQVals |        1.45e+03 |
# |          StdQVals |             661 |
# |          MaxQVals |        2.61e+03 |
# |          MinQVals |       -1.88e+03 |
# |            LossPi |       -1.47e+03 |
# |             LossQ |        1.06e+03 |
# |              Time |             892 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |            -506 |
# |          StdEpRet |             365 |
# |          MaxEpRet |           -91.9 |
# |          MinEpRet |       -1.18e+03 |
# |  AverageTestEpRet |            -673 |
# |      StdTestEpRet |             641 |
# |      MaxTestEpRet |           -26.2 |
# |      MinTestEpRet |       -2.32e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.63e+05 |
# |      AverageQVals |        1.47e+03 |
# |          StdQVals |             654 |
# |          MaxQVals |        2.64e+03 |
# |          MinQVals |       -1.83e+03 |
# |            LossPi |       -1.49e+03 |
# |             LossQ |        1.04e+03 |
# |              Time |             902 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             100 |
# |      AverageEpRet |            -571 |
# |          StdEpRet |             313 |
# |          MaxEpRet |           -99.8 |
# |          MinEpRet |       -1.18e+03 |
# |  AverageTestEpRet |            -951 |
# |      StdTestEpRet |             851 |
# |      MaxTestEpRet |            -226 |
# |      MinTestEpRet |       -2.87e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+05 |
# |      AverageQVals |        1.49e+03 |
# |          StdQVals |             651 |
# |          MaxQVals |        2.66e+03 |
# |          MinQVals |        -1.8e+03 |
# |            LossPi |       -1.51e+03 |
# |             LossQ |        1.04e+03 |
# |              Time |             911 |
# ---------------------------------------

# %% [markdown]
# #### Absolute reward

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='ddpg_a', exp_name='ddpg_a')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0025
qlr_b = 0.0025

# Env function
reward_args = {'qx1':9,'qx2':0.05,'qx3':9,'qx4':0.05,'pu1':0.5,'pu2':0.5} # weights of P higher to match that of quad
env_fn = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Absolute', reward_args = reward_args,ep_len=maxeplen_b)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Warning: Log dir ddpg_a already exists! Storing info there anyway.
# Logging data to ddpg_a/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(functools.partial(<function env_fn at 0x7f76de14bea0>, env_name='gyroscopeenv-v0', reward_type='Quadratic', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Absolute', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.5, 'pu2': 0.5}, ep_len=110)",
#     "epochs":	100,
#     "exp_name":	"ddpg_a",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f7758af28d0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"ddpg_a",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_a",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_a/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"ddpg_a",
#         "output_dir":	"ddpg_a"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0025,
#     "polyak":	0.995,
#     "q_lr":	0.0025,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 4802, 	 q: 5201
# /home/matthieulc/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |       -3.29e+03 |
# |          StdEpRet |             858 |
# |          MaxEpRet |       -1.95e+03 |
# |          MinEpRet |          -5e+03 |
# |  AverageTestEpRet |       -2.85e+03 |
# |      StdTestEpRet |             711 |
# |      MaxTestEpRet |       -1.65e+03 |
# |      MinTestEpRet |       -4.07e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |      AverageQVals |           -54.4 |
# |          StdQVals |            27.5 |
# |          MaxQVals |           0.267 |
# |          MinQVals |            -150 |
# |            LossPi |            52.9 |
# |             LossQ |             124 |
# |              Time |            4.58 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |       -3.28e+03 |
# |          StdEpRet |             612 |
# |          MaxEpRet |       -1.82e+03 |
# |          MinEpRet |       -4.15e+03 |
# |  AverageTestEpRet |       -2.86e+03 |
# |      StdTestEpRet |        1.03e+03 |
# |      MaxTestEpRet |            -909 |
# |      MinTestEpRet |       -4.57e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |      AverageQVals |            -186 |
# |          StdQVals |            73.5 |
# |          MaxQVals |           -32.6 |
# |          MinQVals |            -486 |
# |            LossPi |             182 |
# |             LossQ |             105 |
# |              Time |            12.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |       -3.01e+03 |
# |          StdEpRet |             603 |
# |          MaxEpRet |       -1.83e+03 |
# |          MinEpRet |       -3.75e+03 |
# |  AverageTestEpRet |       -3.04e+03 |
# |      StdTestEpRet |             986 |
# |      MaxTestEpRet |        -1.2e+03 |
# |      MinTestEpRet |       -4.39e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |      AverageQVals |            -367 |
# |          StdQVals |            93.7 |
# |          MaxQVals |             -99 |
# |          MinQVals |            -723 |
# |            LossPi |             360 |
# |             LossQ |             209 |
# |              Time |            19.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |       -3.17e+03 |
# |          StdEpRet |             538 |
# |          MaxEpRet |       -2.11e+03 |
# |          MinEpRet |       -3.92e+03 |
# |  AverageTestEpRet |       -2.53e+03 |
# |      StdTestEpRet |        1.09e+03 |
# |      MaxTestEpRet |       -1.13e+03 |
# |      MinTestEpRet |       -4.48e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |      AverageQVals |            -512 |
# |          StdQVals |             117 |
# |          MaxQVals |            -172 |
# |          MinQVals |            -951 |
# |            LossPi |             503 |
# |             LossQ |             290 |
# |              Time |            27.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |       -3.45e+03 |
# |          StdEpRet |             643 |
# |          MaxEpRet |       -2.42e+03 |
# |          MinEpRet |       -4.73e+03 |
# |  AverageTestEpRet |        -1.8e+03 |
# |      StdTestEpRet |             476 |
# |      MaxTestEpRet |            -772 |
# |      MinTestEpRet |       -2.44e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |      AverageQVals |            -649 |
# |          StdQVals |             141 |
# |          MaxQVals |            -239 |
# |          MinQVals |       -1.18e+03 |
# |            LossPi |             637 |
# |             LossQ |             350 |
# |              Time |            34.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |       -3.16e+03 |
# |          StdEpRet |             545 |
# |          MaxEpRet |       -1.99e+03 |
# |          MinEpRet |       -4.39e+03 |
# |  AverageTestEpRet |       -2.17e+03 |
# |      StdTestEpRet |             475 |
# |      MaxTestEpRet |        -1.2e+03 |
# |      MinTestEpRet |        -3.1e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |      AverageQVals |            -755 |
# |          StdQVals |             166 |
# |          MaxQVals |            -302 |
# |          MinQVals |       -1.39e+03 |
# |            LossPi |             742 |
# |             LossQ |             397 |
# |              Time |            42.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |       -2.21e+03 |
# |          StdEpRet |             777 |
# |          MaxEpRet |            -861 |
# |          MinEpRet |       -3.28e+03 |
# |  AverageTestEpRet |        -1.6e+03 |
# |      StdTestEpRet |             723 |
# |      MaxTestEpRet |            -230 |
# |      MinTestEpRet |       -2.71e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |      AverageQVals |            -836 |
# |          StdQVals |             188 |
# |          MaxQVals |            -365 |
# |          MinQVals |       -1.55e+03 |
# |            LossPi |             822 |
# |             LossQ |             380 |
# |              Time |            50.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |       -2.01e+03 |
# |          StdEpRet |             785 |
# |          MaxEpRet |            -850 |
# |          MinEpRet |        -3.8e+03 |
# |  AverageTestEpRet |       -1.64e+03 |
# |      StdTestEpRet |             714 |
# |      MaxTestEpRet |            -650 |
# |      MinTestEpRet |       -2.85e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |      AverageQVals |            -908 |
# |          StdQVals |             208 |
# |          MaxQVals |            -430 |
# |          MinQVals |        -1.7e+03 |
# |            LossPi |             895 |
# |             LossQ |             329 |
# |              Time |            58.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |       -1.78e+03 |
# |          StdEpRet |             894 |
# |          MaxEpRet |            -633 |
# |          MinEpRet |       -3.29e+03 |
# |  AverageTestEpRet |       -1.77e+03 |
# |      StdTestEpRet |             816 |
# |      MaxTestEpRet |            -369 |
# |      MinTestEpRet |       -2.82e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |      AverageQVals |            -970 |
# |          StdQVals |             229 |
# |          MaxQVals |            -463 |
# |          MinQVals |       -1.83e+03 |
# |            LossPi |             958 |
# |             LossQ |             305 |
# |              Time |            66.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |       -1.68e+03 |
# |          StdEpRet |             676 |
# |          MaxEpRet |            -658 |
# |          MinEpRet |       -3.02e+03 |
# |  AverageTestEpRet |       -1.81e+03 |
# |      StdTestEpRet |             327 |
# |      MaxTestEpRet |       -1.22e+03 |
# |      MinTestEpRet |       -2.41e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |       -1.03e+03 |
# |          StdQVals |             244 |
# |          MaxQVals |            -521 |
# |          MinQVals |       -1.96e+03 |
# |            LossPi |        1.02e+03 |
# |             LossQ |             287 |
# |              Time |              76 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |       -1.59e+03 |
# |          StdEpRet |             957 |
# |          MaxEpRet |            -375 |
# |          MinEpRet |       -3.28e+03 |
# |  AverageTestEpRet |       -1.98e+03 |
# |      StdTestEpRet |             579 |
# |      MaxTestEpRet |       -1.29e+03 |
# |      MinTestEpRet |       -2.97e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |      AverageQVals |       -1.09e+03 |
# |          StdQVals |             257 |
# |          MaxQVals |            -564 |
# |          MinQVals |       -2.06e+03 |
# |            LossPi |        1.08e+03 |
# |             LossQ |             267 |
# |              Time |            85.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |       -1.53e+03 |
# |          StdEpRet |             762 |
# |          MaxEpRet |            -420 |
# |          MinEpRet |       -2.97e+03 |
# |  AverageTestEpRet |       -1.51e+03 |
# |      StdTestEpRet |             582 |
# |      MaxTestEpRet |            -336 |
# |      MinTestEpRet |       -2.54e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |      AverageQVals |       -1.15e+03 |
# |          StdQVals |             274 |
# |          MaxQVals |            -601 |
# |          MinQVals |       -2.25e+03 |
# |            LossPi |        1.14e+03 |
# |             LossQ |             262 |
# |              Time |              95 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |       -1.91e+03 |
# |          StdEpRet |             900 |
# |          MaxEpRet |            -516 |
# |          MinEpRet |       -3.79e+03 |
# |  AverageTestEpRet |       -1.45e+03 |
# |      StdTestEpRet |             594 |
# |      MaxTestEpRet |            -355 |
# |      MinTestEpRet |       -2.27e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |      AverageQVals |       -1.21e+03 |
# |          StdQVals |             294 |
# |          MaxQVals |            -624 |
# |          MinQVals |        -2.3e+03 |
# |            LossPi |         1.2e+03 |
# |             LossQ |             263 |
# |              Time |             105 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |       -1.36e+03 |
# |          StdEpRet |             396 |
# |          MaxEpRet |            -861 |
# |          MinEpRet |       -2.18e+03 |
# |  AverageTestEpRet |        -1.6e+03 |
# |      StdTestEpRet |             559 |
# |      MaxTestEpRet |            -934 |
# |      MinTestEpRet |       -2.78e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |      AverageQVals |       -1.26e+03 |
# |          StdQVals |             307 |
# |          MaxQVals |            -634 |
# |          MinQVals |       -2.42e+03 |
# |            LossPi |        1.25e+03 |
# |             LossQ |             269 |
# |              Time |             114 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |       -1.36e+03 |
# |          StdEpRet |             557 |
# |          MaxEpRet |            -513 |
# |          MinEpRet |       -2.64e+03 |
# |  AverageTestEpRet |        -1.6e+03 |
# |      StdTestEpRet |             566 |
# |      MaxTestEpRet |          -1e+03 |
# |      MinTestEpRet |       -2.58e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |      AverageQVals |       -1.29e+03 |
# |          StdQVals |             319 |
# |          MaxQVals |            -635 |
# |          MinQVals |       -2.49e+03 |
# |            LossPi |        1.29e+03 |
# |             LossQ |             268 |
# |              Time |             123 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |       -1.42e+03 |
# |          StdEpRet |             515 |
# |          MaxEpRet |            -512 |
# |          MinEpRet |       -2.27e+03 |
# |  AverageTestEpRet |       -1.32e+03 |
# |      StdTestEpRet |             425 |
# |      MaxTestEpRet |            -853 |
# |      MinTestEpRet |       -2.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |      AverageQVals |       -1.32e+03 |
# |          StdQVals |             327 |
# |          MaxQVals |            -647 |
# |          MinQVals |       -2.56e+03 |
# |            LossPi |        1.31e+03 |
# |             LossQ |             271 |
# |              Time |             133 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |        -1.5e+03 |
# |          StdEpRet |             534 |
# |          MaxEpRet |            -679 |
# |          MinEpRet |       -2.47e+03 |
# |  AverageTestEpRet |        -1.5e+03 |
# |      StdTestEpRet |             867 |
# |      MaxTestEpRet |            -215 |
# |      MinTestEpRet |       -2.89e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |      AverageQVals |       -1.35e+03 |
# |          StdQVals |             334 |
# |          MaxQVals |            -655 |
# |          MinQVals |        -2.6e+03 |
# |            LossPi |        1.35e+03 |
# |             LossQ |             276 |
# |              Time |             142 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |       -1.42e+03 |
# |          StdEpRet |             699 |
# |          MaxEpRet |            -232 |
# |          MinEpRet |       -2.86e+03 |
# |  AverageTestEpRet |       -1.27e+03 |
# |      StdTestEpRet |             581 |
# |      MaxTestEpRet |            -394 |
# |      MinTestEpRet |       -2.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |      AverageQVals |       -1.38e+03 |
# |          StdQVals |             339 |
# |          MaxQVals |            -662 |
# |          MinQVals |       -2.63e+03 |
# |            LossPi |        1.37e+03 |
# |             LossQ |             284 |
# |              Time |             152 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |       -1.21e+03 |
# |          StdEpRet |             536 |
# |          MaxEpRet |            -414 |
# |          MinEpRet |       -2.51e+03 |
# |  AverageTestEpRet |       -1.43e+03 |
# |      StdTestEpRet |             553 |
# |      MaxTestEpRet |            -841 |
# |      MinTestEpRet |        -2.3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |      AverageQVals |       -1.39e+03 |
# |          StdQVals |             349 |
# |          MaxQVals |            -671 |
# |          MinQVals |       -2.66e+03 |
# |            LossPi |        1.38e+03 |
# |             LossQ |             285 |
# |              Time |             161 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |       -1.22e+03 |
# |          StdEpRet |             508 |
# |          MaxEpRet |            -555 |
# |          MinEpRet |       -2.21e+03 |
# |  AverageTestEpRet |       -1.64e+03 |
# |      StdTestEpRet |             701 |
# |      MaxTestEpRet |            -752 |
# |      MinTestEpRet |       -2.69e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |       -1.39e+03 |
# |          StdQVals |             359 |
# |          MaxQVals |            -640 |
# |          MinQVals |       -2.67e+03 |
# |            LossPi |        1.38e+03 |
# |             LossQ |             273 |
# |              Time |             171 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |        -1.3e+03 |
# |          StdEpRet |             653 |
# |          MaxEpRet |            -210 |
# |          MinEpRet |       -2.41e+03 |
# |  AverageTestEpRet |       -1.26e+03 |
# |      StdTestEpRet |             478 |
# |      MaxTestEpRet |            -480 |
# |      MinTestEpRet |        -1.9e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |      AverageQVals |        -1.4e+03 |
# |          StdQVals |             367 |
# |          MaxQVals |            -642 |
# |          MinQVals |       -2.69e+03 |
# |            LossPi |        1.39e+03 |
# |             LossQ |             270 |
# |              Time |             180 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |       -1.34e+03 |
# |          StdEpRet |             610 |
# |          MaxEpRet |            -408 |
# |          MinEpRet |       -2.62e+03 |
# |  AverageTestEpRet |       -1.05e+03 |
# |      StdTestEpRet |             459 |
# |      MaxTestEpRet |            -370 |
# |      MinTestEpRet |       -1.95e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |      AverageQVals |        -1.4e+03 |
# |          StdQVals |             376 |
# |          MaxQVals |            -651 |
# |          MinQVals |       -2.73e+03 |
# |            LossPi |        1.39e+03 |
# |             LossQ |             274 |
# |              Time |             188 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |       -1.36e+03 |
# |          StdEpRet |             517 |
# |          MaxEpRet |            -394 |
# |          MinEpRet |       -2.17e+03 |
# |  AverageTestEpRet |       -1.28e+03 |
# |      StdTestEpRet |             565 |
# |      MaxTestEpRet |            -212 |
# |      MinTestEpRet |       -2.07e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |      AverageQVals |       -1.41e+03 |
# |          StdQVals |             386 |
# |          MaxQVals |            -636 |
# |          MinQVals |       -2.73e+03 |
# |            LossPi |         1.4e+03 |
# |             LossQ |             283 |
# |              Time |             195 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |       -1.24e+03 |
# |          StdEpRet |             769 |
# |          MaxEpRet |            -324 |
# |          MinEpRet |        -2.8e+03 |
# |  AverageTestEpRet |       -1.71e+03 |
# |      StdTestEpRet |             628 |
# |      MaxTestEpRet |            -584 |
# |      MinTestEpRet |       -2.73e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |      AverageQVals |       -1.41e+03 |
# |          StdQVals |             397 |
# |          MaxQVals |            -628 |
# |          MinQVals |       -3.12e+03 |
# |            LossPi |         1.4e+03 |
# |             LossQ |             285 |
# |              Time |             203 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |       -1.54e+03 |
# |          StdEpRet |             770 |
# |          MaxEpRet |            -443 |
# |          MinEpRet |       -2.91e+03 |
# |  AverageTestEpRet |       -1.29e+03 |
# |      StdTestEpRet |             724 |
# |      MaxTestEpRet |            -584 |
# |      MinTestEpRet |       -2.72e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |      AverageQVals |       -1.41e+03 |
# |          StdQVals |             410 |
# |          MaxQVals |            -630 |
# |          MinQVals |       -3.17e+03 |
# |            LossPi |         1.4e+03 |
# |             LossQ |             286 |
# |              Time |             213 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |       -1.41e+03 |
# |          StdEpRet |             652 |
# |          MaxEpRet |            -467 |
# |          MinEpRet |       -2.89e+03 |
# |  AverageTestEpRet |       -1.43e+03 |
# |      StdTestEpRet |             528 |
# |      MaxTestEpRet |            -429 |
# |      MinTestEpRet |       -2.57e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |      AverageQVals |       -1.41e+03 |
# |          StdQVals |             421 |
# |          MaxQVals |            -628 |
# |          MinQVals |        -3.2e+03 |
# |            LossPi |         1.4e+03 |
# |             LossQ |             281 |
# |              Time |             223 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |       -1.25e+03 |
# |          StdEpRet |             744 |
# |          MaxEpRet |            -271 |
# |          MinEpRet |       -2.93e+03 |
# |  AverageTestEpRet |       -1.08e+03 |
# |      StdTestEpRet |             475 |
# |      MaxTestEpRet |            -598 |
# |      MinTestEpRet |       -2.14e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |      AverageQVals |       -1.41e+03 |
# |          StdQVals |             433 |
# |          MaxQVals |            -627 |
# |          MinQVals |       -3.24e+03 |
# |            LossPi |         1.4e+03 |
# |             LossQ |             283 |
# |              Time |             233 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -945 |
# |          StdEpRet |             356 |
# |          MaxEpRet |            -457 |
# |          MinEpRet |       -1.66e+03 |
# |  AverageTestEpRet |       -1.35e+03 |
# |      StdTestEpRet |             579 |
# |      MaxTestEpRet |            -443 |
# |      MinTestEpRet |       -2.16e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |      AverageQVals |       -1.41e+03 |
# |          StdQVals |             445 |
# |          MaxQVals |            -628 |
# |          MinQVals |       -3.29e+03 |
# |            LossPi |         1.4e+03 |
# |             LossQ |             278 |
# |              Time |             242 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |       -1.18e+03 |
# |          StdEpRet |             537 |
# |          MaxEpRet |            -176 |
# |          MinEpRet |       -1.98e+03 |
# |  AverageTestEpRet |            -970 |
# |      StdTestEpRet |             387 |
# |      MaxTestEpRet |            -165 |
# |      MinTestEpRet |       -1.55e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |      AverageQVals |       -1.41e+03 |
# |          StdQVals |             455 |
# |          MaxQVals |            -621 |
# |          MinQVals |       -3.31e+03 |
# |            LossPi |         1.4e+03 |
# |             LossQ |             274 |
# |              Time |             251 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |       -1.08e+03 |
# |          StdEpRet |             443 |
# |          MaxEpRet |            -239 |
# |          MinEpRet |       -1.72e+03 |
# |  AverageTestEpRet |       -1.34e+03 |
# |      StdTestEpRet |             986 |
# |      MaxTestEpRet |            -209 |
# |      MinTestEpRet |       -3.24e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |        -1.4e+03 |
# |          StdQVals |             466 |
# |          MaxQVals |            -608 |
# |          MinQVals |       -3.34e+03 |
# |            LossPi |         1.4e+03 |
# |             LossQ |             271 |
# |              Time |             260 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |       -1.82e+03 |
# |          StdEpRet |             798 |
# |          MaxEpRet |            -444 |
# |          MinEpRet |       -3.29e+03 |
# |  AverageTestEpRet |       -1.71e+03 |
# |      StdTestEpRet |             682 |
# |      MaxTestEpRet |            -517 |
# |      MinTestEpRet |       -2.68e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |      AverageQVals |       -1.41e+03 |
# |          StdQVals |             475 |
# |          MaxQVals |            -603 |
# |          MinQVals |       -3.41e+03 |
# |            LossPi |         1.4e+03 |
# |             LossQ |             274 |
# |              Time |             269 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |        -1.3e+03 |
# |          StdEpRet |             641 |
# |          MaxEpRet |            -260 |
# |          MinEpRet |       -2.51e+03 |
# |  AverageTestEpRet |       -1.91e+03 |
# |      StdTestEpRet |             748 |
# |      MaxTestEpRet |            -417 |
# |      MinTestEpRet |       -3.19e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |      AverageQVals |       -1.42e+03 |
# |          StdQVals |             489 |
# |          MaxQVals |            -596 |
# |          MinQVals |       -3.41e+03 |
# |            LossPi |        1.41e+03 |
# |             LossQ |             277 |
# |              Time |             279 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |       -1.43e+03 |
# |          StdEpRet |             572 |
# |          MaxEpRet |            -535 |
# |          MinEpRet |       -2.36e+03 |
# |  AverageTestEpRet |       -1.51e+03 |
# |      StdTestEpRet |             841 |
# |      MaxTestEpRet |            -178 |
# |      MinTestEpRet |       -2.76e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |      AverageQVals |       -1.42e+03 |
# |          StdQVals |             502 |
# |          MaxQVals |            -585 |
# |          MinQVals |       -3.45e+03 |
# |            LossPi |        1.41e+03 |
# |             LossQ |             274 |
# |              Time |             288 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |       -1.46e+03 |
# |          StdEpRet |             604 |
# |          MaxEpRet |            -754 |
# |          MinEpRet |       -2.66e+03 |
# |  AverageTestEpRet |       -1.13e+03 |
# |      StdTestEpRet |             630 |
# |      MaxTestEpRet |            -478 |
# |      MinTestEpRet |       -2.65e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |      AverageQVals |       -1.42e+03 |
# |          StdQVals |             508 |
# |          MaxQVals |            -563 |
# |          MinQVals |       -3.48e+03 |
# |            LossPi |        1.41e+03 |
# |             LossQ |             283 |
# |              Time |             297 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |       -1.22e+03 |
# |          StdEpRet |             576 |
# |          MaxEpRet |            -362 |
# |          MinEpRet |       -2.76e+03 |
# |  AverageTestEpRet |       -1.45e+03 |
# |      StdTestEpRet |             371 |
# |      MaxTestEpRet |            -732 |
# |      MinTestEpRet |       -2.05e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |      AverageQVals |       -1.41e+03 |
# |          StdQVals |             515 |
# |          MaxQVals |            -544 |
# |          MinQVals |       -3.49e+03 |
# |            LossPi |        1.41e+03 |
# |             LossQ |             285 |
# |              Time |             306 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |       -1.59e+03 |
# |          StdEpRet |             652 |
# |          MaxEpRet |            -535 |
# |          MinEpRet |       -2.66e+03 |
# |  AverageTestEpRet |       -1.25e+03 |
# |      StdTestEpRet |             553 |
# |      MaxTestEpRet |            -507 |
# |      MinTestEpRet |       -2.28e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |      AverageQVals |       -1.42e+03 |
# |          StdQVals |             525 |
# |          MaxQVals |            -528 |
# |          MinQVals |       -3.51e+03 |
# |            LossPi |        1.41e+03 |
# |             LossQ |             287 |
# |              Time |             316 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |       -1.45e+03 |
# |          StdEpRet |             776 |
# |          MaxEpRet |            -473 |
# |          MinEpRet |       -3.32e+03 |
# |  AverageTestEpRet |       -1.23e+03 |
# |      StdTestEpRet |             672 |
# |      MaxTestEpRet |            -240 |
# |      MinTestEpRet |       -2.71e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |      AverageQVals |       -1.42e+03 |
# |          StdQVals |             536 |
# |          MaxQVals |            -504 |
# |          MinQVals |       -3.53e+03 |
# |            LossPi |        1.41e+03 |
# |             LossQ |             288 |
# |              Time |             325 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |       -1.06e+03 |
# |          StdEpRet |             397 |
# |          MaxEpRet |            -427 |
# |          MinEpRet |       -1.95e+03 |
# |  AverageTestEpRet |       -1.64e+03 |
# |      StdTestEpRet |             508 |
# |      MaxTestEpRet |            -833 |
# |      MinTestEpRet |       -2.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |      AverageQVals |       -1.41e+03 |
# |          StdQVals |             546 |
# |          MaxQVals |            -481 |
# |          MinQVals |       -3.57e+03 |
# |            LossPi |        1.41e+03 |
# |             LossQ |             283 |
# |              Time |             334 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |        -1.2e+03 |
# |          StdEpRet |             483 |
# |          MaxEpRet |            -555 |
# |          MinEpRet |       -2.21e+03 |
# |  AverageTestEpRet |            -981 |
# |      StdTestEpRet |             447 |
# |      MaxTestEpRet |            -323 |
# |      MinTestEpRet |        -1.8e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |      AverageQVals |       -1.41e+03 |
# |          StdQVals |             554 |
# |          MaxQVals |            -453 |
# |          MinQVals |       -3.61e+03 |
# |            LossPi |         1.4e+03 |
# |             LossQ |             280 |
# |              Time |             343 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -965 |
# |          StdEpRet |             316 |
# |          MaxEpRet |            -550 |
# |          MinEpRet |       -1.81e+03 |
# |  AverageTestEpRet |       -1.32e+03 |
# |      StdTestEpRet |             508 |
# |      MaxTestEpRet |            -525 |
# |      MinTestEpRet |       -2.25e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |       -1.39e+03 |
# |          StdQVals |             560 |
# |          MaxQVals |            -442 |
# |          MinQVals |       -3.62e+03 |
# |            LossPi |        1.38e+03 |
# |             LossQ |             281 |
# |              Time |             353 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |       -1.01e+03 |
# |          StdEpRet |             461 |
# |          MaxEpRet |            -582 |
# |          MinEpRet |        -2.1e+03 |
# |  AverageTestEpRet |       -1.01e+03 |
# |      StdTestEpRet |             417 |
# |      MaxTestEpRet |            -197 |
# |      MinTestEpRet |       -1.52e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |      AverageQVals |       -1.37e+03 |
# |          StdQVals |             566 |
# |          MaxQVals |            -428 |
# |          MinQVals |       -3.66e+03 |
# |            LossPi |        1.36e+03 |
# |             LossQ |             284 |
# |              Time |             363 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |       -1.05e+03 |
# |          StdEpRet |             557 |
# |          MaxEpRet |            -193 |
# |          MinEpRet |       -2.57e+03 |
# |  AverageTestEpRet |       -1.32e+03 |
# |      StdTestEpRet |             790 |
# |      MaxTestEpRet |            -302 |
# |      MinTestEpRet |       -2.71e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |      AverageQVals |       -1.35e+03 |
# |          StdQVals |             568 |
# |          MaxQVals |            -410 |
# |          MinQVals |       -3.66e+03 |
# |            LossPi |        1.34e+03 |
# |             LossQ |             288 |
# |              Time |             372 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |       -1.04e+03 |
# |          StdEpRet |             529 |
# |          MaxEpRet |            -321 |
# |          MinEpRet |       -2.14e+03 |
# |  AverageTestEpRet |       -1.19e+03 |
# |      StdTestEpRet |             799 |
# |      MaxTestEpRet |            -317 |
# |      MinTestEpRet |        -3.2e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |      AverageQVals |       -1.33e+03 |
# |          StdQVals |             570 |
# |          MaxQVals |            -391 |
# |          MinQVals |       -3.67e+03 |
# |            LossPi |        1.32e+03 |
# |             LossQ |             284 |
# |              Time |             381 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |       -1.07e+03 |
# |          StdEpRet |             542 |
# |          MaxEpRet |            -543 |
# |          MinEpRet |       -2.46e+03 |
# |  AverageTestEpRet |       -1.23e+03 |
# |      StdTestEpRet |             600 |
# |      MaxTestEpRet |            -440 |
# |      MinTestEpRet |       -2.15e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |      AverageQVals |       -1.31e+03 |
# |          StdQVals |             571 |
# |          MaxQVals |            -372 |
# |          MinQVals |       -3.67e+03 |
# |            LossPi |         1.3e+03 |
# |             LossQ |             285 |
# |              Time |             390 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -883 |
# |          StdEpRet |             460 |
# |          MaxEpRet |            -341 |
# |          MinEpRet |       -2.11e+03 |
# |  AverageTestEpRet |       -1.37e+03 |
# |      StdTestEpRet |             882 |
# |      MaxTestEpRet |            -261 |
# |      MinTestEpRet |       -2.91e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |      AverageQVals |       -1.28e+03 |
# |          StdQVals |             573 |
# |          MaxQVals |            -355 |
# |          MinQVals |       -3.64e+03 |
# |            LossPi |        1.27e+03 |
# |             LossQ |             279 |
# |              Time |             398 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |       -1.17e+03 |
# |          StdEpRet |             663 |
# |          MaxEpRet |            -302 |
# |          MinEpRet |       -2.49e+03 |
# |  AverageTestEpRet |       -1.07e+03 |
# |      StdTestEpRet |             532 |
# |      MaxTestEpRet |            -459 |
# |      MinTestEpRet |       -2.52e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |      AverageQVals |       -1.26e+03 |
# |          StdQVals |             576 |
# |          MaxQVals |            -330 |
# |          MinQVals |       -3.61e+03 |
# |            LossPi |        1.25e+03 |
# |             LossQ |             277 |
# |              Time |             405 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |       -1.01e+03 |
# |          StdEpRet |             496 |
# |          MaxEpRet |            -421 |
# |          MinEpRet |       -2.18e+03 |
# |  AverageTestEpRet |            -848 |
# |      StdTestEpRet |             705 |
# |      MaxTestEpRet |            -333 |
# |      MinTestEpRet |       -2.71e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.75e+04 |
# |      AverageQVals |       -1.23e+03 |
# |          StdQVals |             579 |
# |          MaxQVals |            -310 |
# |          MinQVals |       -3.58e+03 |
# |            LossPi |        1.22e+03 |
# |             LossQ |             278 |
# |              Time |             413 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            -906 |
# |          StdEpRet |             564 |
# |          MaxEpRet |            -390 |
# |          MinEpRet |       -2.35e+03 |
# |  AverageTestEpRet |            -875 |
# |      StdTestEpRet |             290 |
# |      MaxTestEpRet |            -499 |
# |      MinTestEpRet |       -1.61e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.92e+04 |
# |      AverageQVals |        -1.2e+03 |
# |          StdQVals |             578 |
# |          MaxQVals |            -269 |
# |          MinQVals |       -3.54e+03 |
# |            LossPi |        1.19e+03 |
# |             LossQ |             264 |
# |              Time |             421 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |       -1.04e+03 |
# |          StdEpRet |             470 |
# |          MaxEpRet |            -357 |
# |          MinEpRet |       -1.86e+03 |
# |  AverageTestEpRet |            -967 |
# |      StdTestEpRet |             479 |
# |      MaxTestEpRet |            -414 |
# |      MinTestEpRet |       -2.21e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+04 |
# |      AverageQVals |       -1.17e+03 |
# |          StdQVals |             578 |
# |          MaxQVals |            -253 |
# |          MinQVals |       -3.52e+03 |
# |            LossPi |        1.16e+03 |
# |             LossQ |             264 |
# |              Time |             429 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |       -1.12e+03 |
# |          StdEpRet |             458 |
# |          MaxEpRet |            -546 |
# |          MinEpRet |       -2.28e+03 |
# |  AverageTestEpRet |          -1e+03 |
# |      StdTestEpRet |             374 |
# |      MaxTestEpRet |            -588 |
# |      MinTestEpRet |       -1.73e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |       -1.15e+03 |
# |          StdQVals |             575 |
# |          MaxQVals |            -226 |
# |          MinQVals |        -3.5e+03 |
# |            LossPi |        1.14e+03 |
# |             LossQ |             265 |
# |              Time |             437 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |       -1.04e+03 |
# |          StdEpRet |             385 |
# |          MaxEpRet |            -329 |
# |          MinEpRet |       -1.65e+03 |
# |  AverageTestEpRet |            -921 |
# |      StdTestEpRet |             474 |
# |      MaxTestEpRet |            -259 |
# |      MinTestEpRet |       -1.94e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.41e+04 |
# |      AverageQVals |       -1.12e+03 |
# |          StdQVals |             571 |
# |          MaxQVals |            -205 |
# |          MinQVals |       -3.47e+03 |
# |            LossPi |        1.11e+03 |
# |             LossQ |             260 |
# |              Time |             447 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |            -995 |
# |          StdEpRet |             541 |
# |          MaxEpRet |            -308 |
# |          MinEpRet |       -2.22e+03 |
# |  AverageTestEpRet |       -1.14e+03 |
# |      StdTestEpRet |             687 |
# |      MaxTestEpRet |            -437 |
# |      MinTestEpRet |       -2.77e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.58e+04 |
# |      AverageQVals |       -1.09e+03 |
# |          StdQVals |             565 |
# |          MaxQVals |            -189 |
# |          MinQVals |       -3.43e+03 |
# |            LossPi |        1.08e+03 |
# |             LossQ |             257 |
# |              Time |             456 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |            -793 |
# |          StdEpRet |             432 |
# |          MaxEpRet |            -346 |
# |          MinEpRet |       -2.21e+03 |
# |  AverageTestEpRet |       -1.15e+03 |
# |      StdTestEpRet |             507 |
# |      MaxTestEpRet |            -648 |
# |      MinTestEpRet |       -2.15e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.74e+04 |
# |      AverageQVals |       -1.06e+03 |
# |          StdQVals |             561 |
# |          MaxQVals |            -173 |
# |          MinQVals |       -3.39e+03 |
# |            LossPi |        1.05e+03 |
# |             LossQ |             251 |
# |              Time |             466 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |       -1.07e+03 |
# |          StdEpRet |             556 |
# |          MaxEpRet |            -394 |
# |          MinEpRet |       -2.74e+03 |
# |  AverageTestEpRet |            -907 |
# |      StdTestEpRet |             514 |
# |      MaxTestEpRet |            -324 |
# |      MinTestEpRet |       -2.03e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.91e+04 |
# |      AverageQVals |       -1.03e+03 |
# |          StdQVals |             556 |
# |          MaxQVals |            -163 |
# |          MinQVals |        -3.3e+03 |
# |            LossPi |        1.02e+03 |
# |             LossQ |             247 |
# |              Time |             475 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |       -1.04e+03 |
# |          StdEpRet |             356 |
# |          MaxEpRet |            -409 |
# |          MinEpRet |       -1.68e+03 |
# |  AverageTestEpRet |            -970 |
# |      StdTestEpRet |             477 |
# |      MaxTestEpRet |            -116 |
# |      MinTestEpRet |       -1.75e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        9.07e+04 |
# |      AverageQVals |       -1.01e+03 |
# |          StdQVals |             550 |
# |          MaxQVals |            -152 |
# |          MinQVals |       -3.26e+03 |
# |            LossPi |             996 |
# |             LossQ |             239 |
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              82 |
# |      AverageEpRet |            -898 |
# |          StdEpRet |             362 |
# |          MaxEpRet |            -467 |
# |          MinEpRet |       -1.66e+03 |
# |  AverageTestEpRet |            -742 |
# |      StdTestEpRet |             280 |
# |      MaxTestEpRet |            -211 |
# |      MinTestEpRet |       -1.25e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.35e+05 |
# |      AverageQVals |            -571 |
# |          StdQVals |             388 |
# |          MaxQVals |            75.4 |
# |          MinQVals |       -2.13e+03 |
# |            LossPi |             562 |
# |             LossQ |             175 |
# |              Time |             723 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              83 |
# |      AverageEpRet |            -796 |
# |          StdEpRet |             369 |
# |          MaxEpRet |            -297 |
# |          MinEpRet |       -1.76e+03 |
# |  AverageTestEpRet |            -748 |
# |      StdTestEpRet |             228 |
# |      MaxTestEpRet |            -326 |
# |      MinTestEpRet |       -1.06e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.37e+05 |
# |      AverageQVals |            -560 |
# |          StdQVals |             379 |
# |          MaxQVals |            69.8 |
# |          MinQVals |       -2.08e+03 |
# |            LossPi |             551 |
# |             LossQ |             177 |
# |              Time |             731 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |            -767 |
# |          StdEpRet |             274 |
# |          MaxEpRet |            -410 |
# |          MinEpRet |       -1.44e+03 |
# |  AverageTestEpRet |            -843 |
# |      StdTestEpRet |             347 |
# |      MaxTestEpRet |            -278 |
# |      MinTestEpRet |       -1.54e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.39e+05 |
# |      AverageQVals |            -544 |
# |          StdQVals |             372 |
# |          MaxQVals |            53.6 |
# |          MinQVals |       -2.08e+03 |
# |            LossPi |             535 |
# |             LossQ |             172 |
# |              Time |             739 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |            -744 |
# |          StdEpRet |             310 |
# |          MaxEpRet |            -308 |
# |          MinEpRet |       -1.39e+03 |
# |  AverageTestEpRet |            -921 |
# |      StdTestEpRet |             481 |
# |      MaxTestEpRet |            -419 |
# |      MinTestEpRet |       -2.18e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.4e+05 |
# |      AverageQVals |            -529 |
# |          StdQVals |             365 |
# |          MaxQVals |            43.6 |
# |          MinQVals |       -2.05e+03 |
# |            LossPi |             520 |
# |             LossQ |             177 |
# |              Time |             747 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |            -755 |
# |          StdEpRet |             311 |
# |          MaxEpRet |            -312 |
# |          MinEpRet |       -1.46e+03 |
# |  AverageTestEpRet |            -990 |
# |      StdTestEpRet |             340 |
# |      MaxTestEpRet |            -529 |
# |      MinTestEpRet |       -1.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.42e+05 |
# |      AverageQVals |            -519 |
# |          StdQVals |             362 |
# |          MaxQVals |            45.9 |
# |          MinQVals |          -2e+03 |
# |            LossPi |             511 |
# |             LossQ |             175 |
# |              Time |             755 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |            -838 |
# |          StdEpRet |             278 |
# |          MaxEpRet |            -374 |
# |          MinEpRet |       -1.52e+03 |
# |  AverageTestEpRet |            -998 |
# |      StdTestEpRet |             453 |
# |      MaxTestEpRet |            -521 |
# |      MinTestEpRet |       -2.08e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.44e+05 |
# |      AverageQVals |            -508 |
# |          StdQVals |             358 |
# |          MaxQVals |            38.5 |
# |          MinQVals |       -1.99e+03 |
# |            LossPi |             499 |
# |             LossQ |             175 |
# |              Time |             763 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |            -782 |
# |          StdEpRet |             418 |
# |          MaxEpRet |            -148 |
# |          MinEpRet |       -1.79e+03 |
# |  AverageTestEpRet |            -594 |
# |      StdTestEpRet |             204 |
# |      MaxTestEpRet |            -332 |
# |      MinTestEpRet |       -1.02e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.45e+05 |
# |      AverageQVals |            -497 |
# |          StdQVals |             356 |
# |          MaxQVals |              38 |
# |          MinQVals |       -1.96e+03 |
# |            LossPi |             488 |
# |             LossQ |             177 |
# |              Time |             770 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |            -806 |
# |          StdEpRet |             344 |
# |          MaxEpRet |            -376 |
# |          MinEpRet |       -1.72e+03 |
# |  AverageTestEpRet |            -733 |
# |      StdTestEpRet |             431 |
# |      MaxTestEpRet |            -328 |
# |      MinTestEpRet |       -1.87e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.47e+05 |
# |      AverageQVals |            -488 |
# |          StdQVals |             356 |
# |          MaxQVals |            42.4 |
# |          MinQVals |       -1.96e+03 |
# |            LossPi |             479 |
# |             LossQ |             176 |
# |              Time |             778 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |            -806 |
# |          StdEpRet |             248 |
# |          MaxEpRet |            -499 |
# |          MinEpRet |       -1.34e+03 |
# |  AverageTestEpRet |            -752 |
# |      StdTestEpRet |             389 |
# |      MaxTestEpRet |            -318 |
# |      MinTestEpRet |        -1.6e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+05 |
# |      AverageQVals |            -477 |
# |          StdQVals |             354 |
# |          MaxQVals |            50.7 |
# |          MinQVals |       -1.91e+03 |
# |            LossPi |             469 |
# |             LossQ |             179 |
# |              Time |             786 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |            -819 |
# |          StdEpRet |             467 |
# |          MaxEpRet |            -257 |
# |          MinEpRet |       -1.85e+03 |
# |  AverageTestEpRet |       -1.01e+03 |
# |      StdTestEpRet |             510 |
# |      MaxTestEpRet |            -181 |
# |      MinTestEpRet |       -2.22e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.5e+05 |
# |      AverageQVals |            -465 |
# |          StdQVals |             353 |
# |          MaxQVals |            90.2 |
# |          MinQVals |       -1.93e+03 |
# |            LossPi |             457 |
# |             LossQ |             181 |
# |              Time |             795 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |            -856 |
# |          StdEpRet |             290 |
# |          MaxEpRet |            -423 |
# |          MinEpRet |       -1.34e+03 |
# |  AverageTestEpRet |            -678 |
# |      StdTestEpRet |             303 |
# |      MaxTestEpRet |            -320 |
# |      MinTestEpRet |        -1.4e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.52e+05 |
# |      AverageQVals |            -454 |
# |          StdQVals |             352 |
# |          MaxQVals |             102 |
# |          MinQVals |       -1.94e+03 |
# |            LossPi |             445 |
# |             LossQ |             179 |
# |              Time |             804 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |            -742 |
# |          StdEpRet |             336 |
# |          MaxEpRet |            -287 |
# |          MinEpRet |       -1.51e+03 |
# |  AverageTestEpRet |            -825 |
# |      StdTestEpRet |             494 |
# |      MaxTestEpRet |            -395 |
# |      MinTestEpRet |       -1.83e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.53e+05 |
# |      AverageQVals |            -439 |
# |          StdQVals |             348 |
# |          MaxQVals |             116 |
# |          MinQVals |       -1.93e+03 |
# |            LossPi |             430 |
# |             LossQ |             180 |
# |              Time |             813 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |            -826 |
# |          StdEpRet |             310 |
# |          MaxEpRet |            -333 |
# |          MinEpRet |       -1.44e+03 |
# |  AverageTestEpRet |            -974 |
# |      StdTestEpRet |             484 |
# |      MaxTestEpRet |            -482 |
# |      MinTestEpRet |       -2.07e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.55e+05 |
# |      AverageQVals |            -428 |
# |          StdQVals |             348 |
# |          MaxQVals |             134 |
# |          MinQVals |       -1.94e+03 |
# |            LossPi |             419 |
# |             LossQ |             184 |
# |              Time |             823 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |            -852 |
# |          StdEpRet |             560 |
# |          MaxEpRet |            -304 |
# |          MinEpRet |        -2.3e+03 |
# |  AverageTestEpRet |            -767 |
# |      StdTestEpRet |             379 |
# |      MaxTestEpRet |            -318 |
# |      MinTestEpRet |       -1.65e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.57e+05 |
# |      AverageQVals |            -416 |
# |          StdQVals |             344 |
# |          MaxQVals |             144 |
# |          MinQVals |        -1.9e+03 |
# |            LossPi |             408 |
# |             LossQ |             181 |
# |              Time |             833 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |            -777 |
# |          StdEpRet |             273 |
# |          MaxEpRet |            -201 |
# |          MinEpRet |       -1.16e+03 |
# |  AverageTestEpRet |            -798 |
# |      StdTestEpRet |             355 |
# |      MaxTestEpRet |            -318 |
# |      MinTestEpRet |        -1.4e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.58e+05 |
# |      AverageQVals |            -406 |
# |          StdQVals |             343 |
# |          MaxQVals |             153 |
# |          MinQVals |       -1.87e+03 |
# |            LossPi |             398 |
# |             LossQ |             179 |
# |              Time |             842 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |            -685 |
# |          StdEpRet |             306 |
# |          MaxEpRet |            -296 |
# |          MinEpRet |       -1.37e+03 |
# |  AverageTestEpRet |            -741 |
# |      StdTestEpRet |             250 |
# |      MaxTestEpRet |            -298 |
# |      MinTestEpRet |       -1.13e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.6e+05 |
# |      AverageQVals |            -395 |
# |          StdQVals |             342 |
# |          MaxQVals |             168 |
# |          MinQVals |       -1.88e+03 |
# |            LossPi |             386 |
# |             LossQ |             178 |
# |              Time |             852 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |            -811 |
# |          StdEpRet |             258 |
# |          MaxEpRet |            -356 |
# |          MinEpRet |       -1.35e+03 |
# |  AverageTestEpRet |            -720 |
# |      StdTestEpRet |             185 |
# |      MaxTestEpRet |            -505 |
# |      MinTestEpRet |       -1.07e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.62e+05 |
# |      AverageQVals |            -385 |
# |          StdQVals |             343 |
# |          MaxQVals |             185 |
# |          MinQVals |       -1.87e+03 |
# |            LossPi |             376 |
# |             LossQ |             186 |
# |              Time |             860 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |            -700 |
# |          StdEpRet |             260 |
# |          MaxEpRet |            -277 |
# |          MinEpRet |        -1.3e+03 |
# |  AverageTestEpRet |            -597 |
# |      StdTestEpRet |             211 |
# |      MaxTestEpRet |            -341 |
# |      MinTestEpRet |            -956 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.63e+05 |
# |      AverageQVals |            -375 |
# |          StdQVals |             341 |
# |          MaxQVals |             197 |
# |          MinQVals |       -1.87e+03 |
# |            LossPi |             367 |
# |             LossQ |             183 |
# |              Time |             868 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             100 |
# |      AverageEpRet |            -990 |
# |          StdEpRet |             500 |
# |          MaxEpRet |            -210 |
# |          MinEpRet |       -2.34e+03 |
# |  AverageTestEpRet |            -861 |
# |      StdTestEpRet |             772 |
# |      MaxTestEpRet |            -275 |
# |      MinTestEpRet |        -2.9e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+05 |
# |      AverageQVals |            -369 |
# |          StdQVals |             338 |
# |          MaxQVals |             197 |
# |          MinQVals |       -1.84e+03 |
# |            LossPi |             361 |
# |             LossQ |             185 |
# |              Time |             876 |
# ---------------------------------------

# %% [markdown]
# #### Normalized reward

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='ddpg_n', exp_name='ddpg_n')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 20000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.001
qlr_b = 0.001

# Env function
reward_args = {'k': 0.25, 'qx2' : 0.05, 'qx4' : 0.05, 'pu1':0.05,'pu2':0.05}
env_fn = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=maxeplen_b)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Warning: Log dir ddpg_n already exists! Storing info there anyway.
# Logging data to ddpg_n/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(functools.partial(<function env_fn at 0x7f36fb4d9ea0>, env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.25, 'qx2': 0.05, 'qx4': 0.05, 'pu1': 0.05, 'pu2': 0.05}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.25, 'qx2': 0.05, 'qx4': 0.05, 'pu1': 0.05, 'pu2': 0.05}, ep_len=110)",
#     "epochs":	100,
#     "exp_name":	"ddpg_n",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f36c5e3eb38>":	{
#             "epoch_dict":	{},
#             "exp_name":	"ddpg_n",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_n",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_n/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"ddpg_n",
#         "output_dir":	"ddpg_n"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	20000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 4802, 	 q: 5201
# /home/matthieulc/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -486 |
# |          StdEpRet |             107 |
# |          MaxEpRet |            -345 |
# |          MinEpRet |            -762 |
# |  AverageTestEpRet |            -201 |
# |      StdTestEpRet |            17.6 |
# |      MaxTestEpRet |            -157 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |      AverageQVals |           -9.06 |
# |          StdQVals |            4.05 |
# |          MaxQVals |           0.226 |
# |          MinQVals |           -24.9 |
# |            LossPi |            8.13 |
# |             LossQ |            3.34 |
# |              Time |            4.78 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -574 |
# |          StdEpRet |             133 |
# |          MaxEpRet |            -417 |
# |          MinEpRet |            -858 |
# |  AverageTestEpRet |            -176 |
# |      StdTestEpRet |            24.1 |
# |      MaxTestEpRet |            -120 |
# |      MinTestEpRet |            -210 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |      AverageQVals |           -22.2 |
# |          StdQVals |            7.93 |
# |          MaxQVals |            -7.1 |
# |          MinQVals |           -56.8 |
# |            LossPi |            19.4 |
# |             LossQ |            1.24 |
# |              Time |            12.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -511 |
# |          StdEpRet |             105 |
# |          MaxEpRet |            -350 |
# |          MinEpRet |            -748 |
# |  AverageTestEpRet |            -168 |
# |      StdTestEpRet |            27.2 |
# |      MaxTestEpRet |            -105 |
# |      MinTestEpRet |            -200 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |      AverageQVals |           -31.1 |
# |          StdQVals |               9 |
# |          MaxQVals |           -13.2 |
# |          MinQVals |           -65.8 |
# |            LossPi |            27.2 |
# |             LossQ |            1.49 |
# |              Time |            20.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -548 |
# |          StdEpRet |             111 |
# |          MaxEpRet |            -432 |
# |          MinEpRet |            -827 |
# |  AverageTestEpRet |            -178 |
# |      StdTestEpRet |            16.8 |
# |      MaxTestEpRet |            -143 |
# |      MinTestEpRet |            -196 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |      AverageQVals |           -36.1 |
# |          StdQVals |             8.6 |
# |          MaxQVals |           -16.3 |
# |          MinQVals |           -71.9 |
# |            LossPi |            32.2 |
# |             LossQ |            1.46 |
# |              Time |            28.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -547 |
# |          StdEpRet |             121 |
# |          MaxEpRet |            -411 |
# |          MinEpRet |            -838 |
# |  AverageTestEpRet |            -171 |
# |      StdTestEpRet |            39.6 |
# |      MaxTestEpRet |           -68.6 |
# |      MinTestEpRet |            -208 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |      AverageQVals |           -41.6 |
# |          StdQVals |            8.39 |
# |          MaxQVals |           -19.5 |
# |          MinQVals |           -79.9 |
# |            LossPi |            37.7 |
# |             LossQ |            1.38 |
# |              Time |            35.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -558 |
# |          StdEpRet |             143 |
# |          MaxEpRet |            -367 |
# |          MinEpRet |            -883 |
# |  AverageTestEpRet |            -173 |
# |      StdTestEpRet |            19.4 |
# |      MaxTestEpRet |            -138 |
# |      MinTestEpRet |            -210 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |      AverageQVals |           -48.1 |
# |          StdQVals |            8.66 |
# |          MaxQVals |           -23.2 |
# |          MinQVals |           -84.9 |
# |            LossPi |            44.3 |
# |             LossQ |            1.33 |
# |              Time |            43.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -554 |
# |          StdEpRet |             113 |
# |          MaxEpRet |            -385 |
# |          MinEpRet |            -759 |
# |  AverageTestEpRet |            -186 |
# |      StdTestEpRet |            10.2 |
# |      MaxTestEpRet |            -172 |
# |      MinTestEpRet |            -204 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |      AverageQVals |           -55.3 |
# |          StdQVals |            9.09 |
# |          MaxQVals |           -28.2 |
# |          MinQVals |           -92.4 |
# |            LossPi |            51.6 |
# |             LossQ |            1.33 |
# |              Time |            51.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -565 |
# |          StdEpRet |             148 |
# |          MaxEpRet |            -376 |
# |          MinEpRet |            -872 |
# |  AverageTestEpRet |            -176 |
# |      StdTestEpRet |            18.3 |
# |      MaxTestEpRet |            -134 |
# |      MinTestEpRet |            -197 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |      AverageQVals |           -62.1 |
# |          StdQVals |            9.91 |
# |          MaxQVals |             -34 |
# |          MinQVals |           -99.1 |
# |            LossPi |            58.4 |
# |             LossQ |            1.41 |
# |              Time |              59 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -528 |
# |          StdEpRet |             116 |
# |          MaxEpRet |            -349 |
# |          MinEpRet |            -792 |
# |  AverageTestEpRet |            -175 |
# |      StdTestEpRet |            25.4 |
# |      MaxTestEpRet |            -134 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |      AverageQVals |           -69.4 |
# |          StdQVals |            10.6 |
# |          MaxQVals |           -37.5 |
# |          MinQVals |            -108 |
# |            LossPi |            65.6 |
# |             LossQ |            1.44 |
# |              Time |            66.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -576 |
# |          StdEpRet |             114 |
# |          MaxEpRet |            -408 |
# |          MinEpRet |            -844 |
# |  AverageTestEpRet |            -168 |
# |      StdTestEpRet |            22.3 |
# |      MaxTestEpRet |            -133 |
# |      MinTestEpRet |            -203 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |           -76.2 |
# |          StdQVals |            11.4 |
# |          MaxQVals |           -42.2 |
# |          MinQVals |            -128 |
# |            LossPi |            72.5 |
# |             LossQ |            1.46 |
# |              Time |              74 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -580 |
# |          StdEpRet |             156 |
# |          MaxEpRet |            -334 |
# |          MinEpRet |            -842 |
# |  AverageTestEpRet |            -175 |
# |      StdTestEpRet |            16.1 |
# |      MaxTestEpRet |            -134 |
# |      MinTestEpRet |            -191 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |      AverageQVals |           -82.7 |
# |          StdQVals |            12.1 |
# |          MaxQVals |           -48.4 |
# |          MinQVals |            -134 |
# |            LossPi |              79 |
# |             LossQ |            1.47 |
# |              Time |            81.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -573 |
# |          StdEpRet |             142 |
# |          MaxEpRet |            -381 |
# |          MinEpRet |            -840 |
# |  AverageTestEpRet |            -165 |
# |      StdTestEpRet |            26.2 |
# |      MaxTestEpRet |            -106 |
# |      MinTestEpRet |            -196 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |      AverageQVals |           -88.8 |
# |          StdQVals |            12.7 |
# |          MaxQVals |           -51.4 |
# |          MinQVals |            -141 |
# |            LossPi |              85 |
# |             LossQ |             1.5 |
# |              Time |            89.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            97.7 |
# |          MaxEpRet |             -68 |
# |          MinEpRet |            -443 |
# |  AverageTestEpRet |            -168 |
# |      StdTestEpRet |              28 |
# |      MaxTestEpRet |            -128 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |      AverageQVals |           -93.6 |
# |          StdQVals |            13.3 |
# |          MaxQVals |           -54.6 |
# |          MinQVals |            -148 |
# |            LossPi |            89.9 |
# |             LossQ |            1.44 |
# |              Time |              99 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -178 |
# |          StdEpRet |            28.3 |
# |          MaxEpRet |            -104 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -177 |
# |      StdTestEpRet |            17.8 |
# |      MaxTestEpRet |            -136 |
# |      MinTestEpRet |            -198 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |      AverageQVals |           -98.4 |
# |          StdQVals |            14.3 |
# |          MaxQVals |           -58.2 |
# |          MinQVals |            -153 |
# |            LossPi |            94.9 |
# |             LossQ |            1.34 |
# |              Time |             108 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -165 |
# |          StdEpRet |            29.2 |
# |          MaxEpRet |            -112 |
# |          MinEpRet |            -209 |
# |  AverageTestEpRet |            -183 |
# |      StdTestEpRet |            10.8 |
# |      MaxTestEpRet |            -167 |
# |      MinTestEpRet |            -203 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |      AverageQVals |            -103 |
# |          StdQVals |            14.9 |
# |          MaxQVals |             -63 |
# |          MinQVals |            -159 |
# |            LossPi |            99.9 |
# |             LossQ |             1.2 |
# |              Time |             118 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -171 |
# |          StdEpRet |            26.4 |
# |          MaxEpRet |            -110 |
# |          MinEpRet |            -210 |
# |  AverageTestEpRet |            -166 |
# |      StdTestEpRet |            21.6 |
# |      MaxTestEpRet |            -130 |
# |      MinTestEpRet |            -209 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |      AverageQVals |            -108 |
# |          StdQVals |            15.6 |
# |          MaxQVals |             -67 |
# |          MinQVals |            -162 |
# |            LossPi |             105 |
# |             LossQ |            1.11 |
# |              Time |             126 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -173 |
# |          StdEpRet |            21.5 |
# |          MaxEpRet |            -134 |
# |          MinEpRet |            -214 |
# |  AverageTestEpRet |            -177 |
# |      StdTestEpRet |            8.42 |
# |      MaxTestEpRet |            -161 |
# |      MinTestEpRet |            -191 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |      AverageQVals |            -112 |
# |          StdQVals |              16 |
# |          MaxQVals |           -71.5 |
# |          MinQVals |            -166 |
# |            LossPi |             109 |
# |             LossQ |            1.05 |
# |              Time |             134 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -187 |
# |          StdEpRet |            9.21 |
# |          MaxEpRet |            -172 |
# |          MinEpRet |            -203 |
# |  AverageTestEpRet |            -169 |
# |      StdTestEpRet |            33.1 |
# |      MaxTestEpRet |           -91.3 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |      AverageQVals |            -117 |
# |          StdQVals |            16.3 |
# |          MaxQVals |           -76.9 |
# |          MinQVals |            -171 |
# |            LossPi |             114 |
# |             LossQ |            1.02 |
# |              Time |             142 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -174 |
# |          StdEpRet |            23.2 |
# |          MaxEpRet |            -132 |
# |          MinEpRet |            -214 |
# |  AverageTestEpRet |            -154 |
# |      StdTestEpRet |            18.8 |
# |      MaxTestEpRet |            -124 |
# |      MinTestEpRet |            -186 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |      AverageQVals |            -122 |
# |          StdQVals |            16.7 |
# |          MaxQVals |           -81.1 |
# |          MinQVals |            -179 |
# |            LossPi |             119 |
# |             LossQ |           0.969 |
# |              Time |             150 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -175 |
# |          StdEpRet |            19.2 |
# |          MaxEpRet |            -140 |
# |          MinEpRet |            -215 |
# |  AverageTestEpRet |            -175 |
# |      StdTestEpRet |            25.1 |
# |      MaxTestEpRet |            -125 |
# |      MinTestEpRet |            -208 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |            -126 |
# |          StdQVals |            16.9 |
# |          MaxQVals |           -85.8 |
# |          MinQVals |            -186 |
# |            LossPi |             124 |
# |             LossQ |           0.946 |
# |              Time |             158 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -173 |
# |          StdEpRet |            31.4 |
# |          MaxEpRet |           -93.5 |
# |          MinEpRet |            -210 |
# |  AverageTestEpRet |            -179 |
# |      StdTestEpRet |            16.8 |
# |      MaxTestEpRet |            -152 |
# |      MinTestEpRet |            -203 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |      AverageQVals |            -131 |
# |          StdQVals |            17.1 |
# |          MaxQVals |           -92.9 |
# |          MinQVals |            -193 |
# |            LossPi |             129 |
# |             LossQ |           0.918 |
# |              Time |             166 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -173 |
# |          StdEpRet |              32 |
# |          MaxEpRet |           -78.7 |
# |          MinEpRet |            -215 |
# |  AverageTestEpRet |            -145 |
# |      StdTestEpRet |            25.7 |
# |      MaxTestEpRet |            -105 |
# |      MinTestEpRet |            -177 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |      AverageQVals |            -136 |
# |          StdQVals |            17.2 |
# |          MaxQVals |           -97.8 |
# |          MinQVals |            -200 |
# |            LossPi |             133 |
# |             LossQ |           0.906 |
# |              Time |             173 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -172 |
# |          StdEpRet |            28.4 |
# |          MaxEpRet |            -121 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -161 |
# |      StdTestEpRet |            30.9 |
# |      MaxTestEpRet |            -103 |
# |      MinTestEpRet |            -197 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |      AverageQVals |            -140 |
# |          StdQVals |            17.6 |
# |          MaxQVals |            -103 |
# |          MinQVals |            -207 |
# |            LossPi |             138 |
# |             LossQ |             0.9 |
# |              Time |             181 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -169 |
# |          StdEpRet |            28.4 |
# |          MaxEpRet |            -106 |
# |          MinEpRet |            -210 |
# |  AverageTestEpRet |            -152 |
# |      StdTestEpRet |            31.4 |
# |      MaxTestEpRet |            -108 |
# |      MinTestEpRet |            -203 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |      AverageQVals |            -144 |
# |          StdQVals |            18.2 |
# |          MaxQVals |            -107 |
# |          MinQVals |            -213 |
# |            LossPi |             142 |
# |             LossQ |           0.924 |
# |              Time |             189 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -175 |
# |          StdEpRet |            22.2 |
# |          MaxEpRet |            -122 |
# |          MinEpRet |            -203 |
# |  AverageTestEpRet |            -165 |
# |      StdTestEpRet |            37.6 |
# |      MaxTestEpRet |            -101 |
# |      MinTestEpRet |            -208 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |      AverageQVals |            -148 |
# |          StdQVals |            18.3 |
# |          MaxQVals |            -110 |
# |          MinQVals |            -218 |
# |            LossPi |             146 |
# |             LossQ |           0.928 |
# |              Time |             197 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -172 |
# |          StdEpRet |            24.3 |
# |          MaxEpRet |            -134 |
# |          MinEpRet |            -212 |
# |  AverageTestEpRet |            -167 |
# |      StdTestEpRet |              29 |
# |      MaxTestEpRet |            -108 |
# |      MinTestEpRet |            -196 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |      AverageQVals |            -151 |
# |          StdQVals |            18.6 |
# |          MaxQVals |            -113 |
# |          MinQVals |            -228 |
# |            LossPi |             149 |
# |             LossQ |           0.921 |
# |              Time |             204 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -156 |
# |          StdEpRet |              23 |
# |          MaxEpRet |            -118 |
# |          MinEpRet |            -193 |
# |  AverageTestEpRet |            -133 |
# |      StdTestEpRet |            21.5 |
# |      MaxTestEpRet |           -90.2 |
# |      MinTestEpRet |            -165 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |      AverageQVals |            -155 |
# |          StdQVals |            18.9 |
# |          MaxQVals |            -117 |
# |          MinQVals |            -231 |
# |            LossPi |             153 |
# |             LossQ |           0.908 |
# |              Time |             212 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -158 |
# |          StdEpRet |            29.9 |
# |          MaxEpRet |           -80.9 |
# |          MinEpRet |            -196 |
# |  AverageTestEpRet |            -164 |
# |      StdTestEpRet |            25.8 |
# |      MaxTestEpRet |           -93.8 |
# |      MinTestEpRet |            -191 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |      AverageQVals |            -158 |
# |          StdQVals |            19.1 |
# |          MaxQVals |            -119 |
# |          MinQVals |            -235 |
# |            LossPi |             156 |
# |             LossQ |            0.92 |
# |              Time |             220 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -150 |
# |          StdEpRet |            24.2 |
# |          MaxEpRet |            -116 |
# |          MinEpRet |            -199 |
# |  AverageTestEpRet |            -170 |
# |      StdTestEpRet |            19.7 |
# |      MaxTestEpRet |            -121 |
# |      MinTestEpRet |            -194 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |      AverageQVals |            -161 |
# |          StdQVals |            19.3 |
# |          MaxQVals |            -122 |
# |          MinQVals |            -240 |
# |            LossPi |             159 |
# |             LossQ |             0.9 |
# |              Time |             227 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -161 |
# |          StdEpRet |            17.5 |
# |          MaxEpRet |            -136 |
# |          MinEpRet |            -198 |
# |  AverageTestEpRet |            -165 |
# |      StdTestEpRet |            21.9 |
# |      MaxTestEpRet |            -128 |
# |      MinTestEpRet |            -199 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |            -164 |
# |          StdQVals |            19.4 |
# |          MaxQVals |            -126 |
# |          MinQVals |            -242 |
# |            LossPi |             162 |
# |             LossQ |           0.896 |
# |              Time |             235 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -158 |
# |          StdEpRet |            20.6 |
# |          MaxEpRet |            -134 |
# |          MinEpRet |            -199 |
# |  AverageTestEpRet |            -156 |
# |      StdTestEpRet |            16.8 |
# |      MaxTestEpRet |            -122 |
# |      MinTestEpRet |            -189 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |      AverageQVals |            -166 |
# |          StdQVals |            19.5 |
# |          MaxQVals |            -127 |
# |          MinQVals |            -246 |
# |            LossPi |             164 |
# |             LossQ |           0.906 |
# |              Time |             243 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -163 |
# |          StdEpRet |            28.4 |
# |          MaxEpRet |           -96.1 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -140 |
# |      StdTestEpRet |            23.1 |
# |      MaxTestEpRet |            -105 |
# |      MinTestEpRet |            -177 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |      AverageQVals |            -168 |
# |          StdQVals |            19.6 |
# |          MaxQVals |            -129 |
# |          MinQVals |            -249 |
# |            LossPi |             167 |
# |             LossQ |           0.923 |
# |              Time |             251 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -159 |
# |          StdEpRet |            17.5 |
# |          MaxEpRet |            -113 |
# |          MinEpRet |            -188 |
# |  AverageTestEpRet |            -159 |
# |      StdTestEpRet |            22.2 |
# |      MaxTestEpRet |            -122 |
# |      MinTestEpRet |            -200 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |      AverageQVals |            -171 |
# |          StdQVals |            19.8 |
# |          MaxQVals |            -130 |
# |          MinQVals |            -253 |
# |            LossPi |             169 |
# |             LossQ |           0.917 |
# |              Time |             259 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -160 |
# |          StdEpRet |            26.6 |
# |          MaxEpRet |            -117 |
# |          MinEpRet |            -196 |
# |  AverageTestEpRet |            -146 |
# |      StdTestEpRet |            31.3 |
# |      MaxTestEpRet |           -91.2 |
# |      MinTestEpRet |            -187 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |      AverageQVals |            -172 |
# |          StdQVals |            19.9 |
# |          MaxQVals |            -132 |
# |          MinQVals |            -252 |
# |            LossPi |             171 |
# |             LossQ |           0.896 |
# |              Time |             267 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -153 |
# |          StdEpRet |            19.4 |
# |          MaxEpRet |            -106 |
# |          MinEpRet |            -177 |
# |  AverageTestEpRet |            -156 |
# |      StdTestEpRet |            21.8 |
# |      MaxTestEpRet |            -127 |
# |      MinTestEpRet |            -194 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |      AverageQVals |            -174 |
# |          StdQVals |            19.9 |
# |          MaxQVals |            -133 |
# |          MinQVals |            -254 |
# |            LossPi |             173 |
# |             LossQ |           0.882 |
# |              Time |             275 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -150 |
# |          StdEpRet |            23.4 |
# |          MaxEpRet |            -112 |
# |          MinEpRet |            -182 |
# |  AverageTestEpRet |            -143 |
# |      StdTestEpRet |            33.9 |
# |      MaxTestEpRet |           -52.7 |
# |      MinTestEpRet |            -172 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |      AverageQVals |            -176 |
# |          StdQVals |            19.9 |
# |          MaxQVals |            -134 |
# |          MinQVals |            -264 |
# |            LossPi |             175 |
# |             LossQ |           0.894 |
# |              Time |             283 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -153 |
# |          StdEpRet |            21.4 |
# |          MaxEpRet |            -118 |
# |          MinEpRet |            -195 |
# |  AverageTestEpRet |            -135 |
# |      StdTestEpRet |            24.5 |
# |      MaxTestEpRet |           -89.6 |
# |      MinTestEpRet |            -182 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |      AverageQVals |            -178 |
# |          StdQVals |            20.1 |
# |          MaxQVals |            -136 |
# |          MinQVals |            -267 |
# |            LossPi |             176 |
# |             LossQ |             0.9 |
# |              Time |             290 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -153 |
# |          StdEpRet |            18.1 |
# |          MaxEpRet |            -122 |
# |          MinEpRet |            -180 |
# |  AverageTestEpRet |            -165 |
# |      StdTestEpRet |            19.1 |
# |      MaxTestEpRet |            -128 |
# |      MinTestEpRet |            -193 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |      AverageQVals |            -179 |
# |          StdQVals |            19.9 |
# |          MaxQVals |            -137 |
# |          MinQVals |            -269 |
# |            LossPi |             178 |
# |             LossQ |           0.892 |
# |              Time |             298 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -154 |
# |          StdEpRet |            19.6 |
# |          MaxEpRet |            -124 |
# |          MinEpRet |            -188 |
# |  AverageTestEpRet |            -160 |
# |      StdTestEpRet |            20.6 |
# |      MaxTestEpRet |            -124 |
# |      MinTestEpRet |            -191 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |      AverageQVals |            -181 |
# |          StdQVals |              20 |
# |          MaxQVals |            -138 |
# |          MinQVals |            -269 |
# |            LossPi |             179 |
# |             LossQ |           0.883 |
# |              Time |             306 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -144 |
# |          StdEpRet |            27.9 |
# |          MaxEpRet |           -94.9 |
# |          MinEpRet |            -184 |
# |  AverageTestEpRet |            -143 |
# |      StdTestEpRet |            29.6 |
# |      MaxTestEpRet |           -99.7 |
# |      MinTestEpRet |            -205 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |            -182 |
# |          StdQVals |            20.1 |
# |          MaxQVals |            -139 |
# |          MinQVals |            -270 |
# |            LossPi |             180 |
# |             LossQ |           0.905 |
# |              Time |             314 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -159 |
# |          StdEpRet |            22.1 |
# |          MaxEpRet |            -109 |
# |          MinEpRet |            -199 |
# |  AverageTestEpRet |            -161 |
# |      StdTestEpRet |            23.9 |
# |      MaxTestEpRet |            -129 |
# |      MinTestEpRet |            -194 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |      AverageQVals |            -183 |
# |          StdQVals |              20 |
# |          MaxQVals |            -140 |
# |          MinQVals |            -270 |
# |            LossPi |             182 |
# |             LossQ |           0.889 |
# |              Time |             322 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -144 |
# |          StdEpRet |            25.4 |
# |          MaxEpRet |           -90.4 |
# |          MinEpRet |            -185 |
# |  AverageTestEpRet |            -151 |
# |      StdTestEpRet |            29.8 |
# |      MaxTestEpRet |           -95.3 |
# |      MinTestEpRet |            -200 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |      AverageQVals |            -184 |
# |          StdQVals |              20 |
# |          MaxQVals |            -141 |
# |          MinQVals |            -270 |
# |            LossPi |             183 |
# |             LossQ |           0.891 |
# |              Time |             330 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -145 |
# |          StdEpRet |            26.9 |
# |          MaxEpRet |           -95.6 |
# |          MinEpRet |            -206 |
# |  AverageTestEpRet |            -139 |
# |      StdTestEpRet |            22.1 |
# |      MaxTestEpRet |           -97.7 |
# |      MinTestEpRet |            -169 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |      AverageQVals |            -185 |
# |          StdQVals |            19.8 |
# |          MaxQVals |            -142 |
# |          MinQVals |            -270 |
# |            LossPi |             184 |
# |             LossQ |            0.89 |
# |              Time |             338 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -152 |
# |          StdEpRet |            24.3 |
# |          MaxEpRet |           -96.8 |
# |          MinEpRet |            -186 |
# |  AverageTestEpRet |            -139 |
# |      StdTestEpRet |              18 |
# |      MaxTestEpRet |            -108 |
# |      MinTestEpRet |            -162 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |      AverageQVals |            -186 |
# |          StdQVals |            19.8 |
# |          MaxQVals |            -143 |
# |          MinQVals |            -270 |
# |            LossPi |             184 |
# |             LossQ |           0.902 |
# |              Time |             345 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -149 |
# |          StdEpRet |              32 |
# |          MaxEpRet |           -58.1 |
# |          MinEpRet |            -186 |
# |  AverageTestEpRet |            -150 |
# |      StdTestEpRet |              19 |
# |      MaxTestEpRet |            -117 |
# |      MinTestEpRet |            -177 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |      AverageQVals |            -186 |
# |          StdQVals |            19.9 |
# |          MaxQVals |            -144 |
# |          MinQVals |            -271 |
# |            LossPi |             185 |
# |             LossQ |           0.903 |
# |              Time |             353 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -140 |
# |          StdEpRet |            26.5 |
# |          MaxEpRet |           -95.6 |
# |          MinEpRet |            -175 |
# |  AverageTestEpRet |            -155 |
# |      StdTestEpRet |            23.3 |
# |      MaxTestEpRet |            -111 |
# |      MinTestEpRet |            -189 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |      AverageQVals |            -187 |
# |          StdQVals |            19.9 |
# |          MaxQVals |            -144 |
# |          MinQVals |            -269 |
# |            LossPi |             186 |
# |             LossQ |            0.91 |
# |              Time |             361 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -129 |
# |          StdEpRet |            34.6 |
# |          MaxEpRet |             -58 |
# |          MinEpRet |            -190 |
# |  AverageTestEpRet |            -142 |
# |      StdTestEpRet |            18.7 |
# |      MaxTestEpRet |            -105 |
# |      MinTestEpRet |            -168 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.75e+04 |
# |      AverageQVals |            -187 |
# |          StdQVals |            19.9 |
# |          MaxQVals |            -144 |
# |          MinQVals |            -270 |
# |            LossPi |             186 |
# |             LossQ |           0.903 |
# |              Time |             369 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            -141 |
# |          StdEpRet |            34.9 |
# |          MaxEpRet |           -83.4 |
# |          MinEpRet |            -191 |
# |  AverageTestEpRet |            -131 |
# |      StdTestEpRet |            32.6 |
# |      MaxTestEpRet |           -70.3 |
# |      MinTestEpRet |            -173 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.92e+04 |
# |      AverageQVals |            -187 |
# |          StdQVals |            19.8 |
# |          MaxQVals |            -145 |
# |          MinQVals |            -271 |
# |            LossPi |             186 |
# |             LossQ |           0.908 |
# |              Time |             377 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |            -136 |
# |          StdEpRet |            24.3 |
# |          MaxEpRet |             -97 |
# |          MinEpRet |            -179 |
# |  AverageTestEpRet |            -134 |
# |      StdTestEpRet |            21.5 |
# |      MaxTestEpRet |            -104 |
# |      MinTestEpRet |            -184 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+04 |
# |      AverageQVals |            -188 |
# |          StdQVals |            19.8 |
# |          MaxQVals |            -145 |
# |          MinQVals |            -272 |
# |            LossPi |             186 |
# |             LossQ |           0.914 |
# |              Time |             385 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            -132 |
# |          StdEpRet |            25.3 |
# |          MaxEpRet |           -85.6 |
# |          MinEpRet |            -179 |
# |  AverageTestEpRet |            -139 |
# |      StdTestEpRet |            35.7 |
# |      MaxTestEpRet |           -70.4 |
# |      MinTestEpRet |            -187 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |            -188 |
# |          StdQVals |            19.9 |
# |          MaxQVals |            -145 |
# |          MinQVals |            -273 |
# |            LossPi |             187 |
# |             LossQ |           0.922 |
# |              Time |             393 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |            -139 |
# |          StdEpRet |            30.7 |
# |          MaxEpRet |           -81.9 |
# |          MinEpRet |            -191 |
# |  AverageTestEpRet |            -138 |
# |      StdTestEpRet |            40.5 |
# |      MaxTestEpRet |           -69.8 |
# |      MinTestEpRet |            -202 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.41e+04 |
# |      AverageQVals |            -188 |
# |          StdQVals |            20.1 |
# |          MaxQVals |            -145 |
# |          MinQVals |            -273 |
# |            LossPi |             187 |
# |             LossQ |           0.933 |
# |              Time |             401 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |            -140 |
# |          StdEpRet |            26.9 |
# |          MaxEpRet |           -86.4 |
# |          MinEpRet |            -182 |
# |  AverageTestEpRet |            -131 |
# |      StdTestEpRet |              37 |
# |      MaxTestEpRet |           -78.7 |
# |      MinTestEpRet |            -191 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.58e+04 |
# |      AverageQVals |            -188 |
# |          StdQVals |              20 |
# |          MaxQVals |            -145 |
# |          MinQVals |            -276 |
# |            LossPi |             187 |
# |             LossQ |           0.937 |
# |              Time |             409 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |            -145 |
# |          StdEpRet |              27 |
# |          MaxEpRet |           -86.3 |
# |          MinEpRet |            -186 |
# |  AverageTestEpRet |            -140 |
# |      StdTestEpRet |            20.9 |
# |      MaxTestEpRet |           -99.2 |
# |      MinTestEpRet |            -167 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.74e+04 |
# |      AverageQVals |            -188 |
# |          StdQVals |            20.1 |
# |          MaxQVals |            -145 |
# |          MinQVals |            -275 |
# |            LossPi |             186 |
# |             LossQ |           0.948 |
# |              Time |             417 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |            -136 |
# |          StdEpRet |            26.2 |
# |          MaxEpRet |             -78 |
# |          MinEpRet |            -183 |
# |  AverageTestEpRet |            -137 |
# |      StdTestEpRet |            39.6 |
# |      MaxTestEpRet |           -71.1 |
# |      MinTestEpRet |            -185 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.91e+04 |
# |      AverageQVals |            -188 |
# |          StdQVals |            20.1 |
# |          MaxQVals |            -145 |
# |          MinQVals |            -276 |
# |            LossPi |             186 |
# |             LossQ |           0.944 |
# |              Time |             425 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |            -149 |
# |          StdEpRet |            28.6 |
# |          MaxEpRet |           -99.8 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -155 |
# |      StdTestEpRet |            27.6 |
# |      MaxTestEpRet |            -120 |
# |      MinTestEpRet |            -205 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        9.07e+04 |
# |      AverageQVals |            -187 |
# |          StdQVals |            20.3 |
# |          MaxQVals |            -144 |
# |          MinQVals |            -278 |
# |            LossPi |             186 |
# |             LossQ |           0.964 |
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              82 |
# |      AverageEpRet |            -122 |
# |          StdEpRet |              34 |
# |          MaxEpRet |           -66.7 |
# |          MinEpRet |            -179 |
# |  AverageTestEpRet |           -94.5 |
# |      StdTestEpRet |            33.2 |
# |      MaxTestEpRet |           -27.7 |
# |      MinTestEpRet |            -151 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.35e+05 |
# |      AverageQVals |            -170 |
# |          StdQVals |            26.1 |
# |          MaxQVals |            -119 |
# |          MinQVals |            -260 |
# |            LossPi |             169 |
# |             LossQ |            1.03 |
# |              Time |             686 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              83 |
# |      AverageEpRet |            -111 |
# |          StdEpRet |            20.4 |
# |          MaxEpRet |           -75.6 |
# |          MinEpRet |            -153 |
# |  AverageTestEpRet |            -109 |
# |      StdTestEpRet |              33 |
# |      MaxTestEpRet |           -57.7 |
# |      MinTestEpRet |            -182 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.37e+05 |
# |      AverageQVals |            -169 |
# |          StdQVals |            26.4 |
# |          MaxQVals |            -118 |
# |          MinQVals |            -262 |
# |            LossPi |             168 |
# |             LossQ |            1.05 |
# |              Time |             696 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |            -127 |
# |          StdEpRet |              31 |
# |          MaxEpRet |           -75.6 |
# |          MinEpRet |            -168 |
# |  AverageTestEpRet |            -109 |
# |      StdTestEpRet |            41.7 |
# |      MaxTestEpRet |           -51.4 |
# |      MinTestEpRet |            -202 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.39e+05 |
# |      AverageQVals |            -168 |
# |          StdQVals |            26.6 |
# |          MaxQVals |            -116 |
# |          MinQVals |            -262 |
# |            LossPi |             167 |
# |             LossQ |            1.04 |
# |              Time |             706 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |            -123 |
# |          StdEpRet |            27.7 |
# |          MaxEpRet |           -76.1 |
# |          MinEpRet |            -163 |
# |  AverageTestEpRet |            -124 |
# |      StdTestEpRet |            31.3 |
# |      MaxTestEpRet |           -68.7 |
# |      MinTestEpRet |            -167 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.4e+05 |
# |      AverageQVals |            -167 |
# |          StdQVals |            26.8 |
# |          MaxQVals |            -115 |
# |          MinQVals |            -260 |
# |            LossPi |             166 |
# |             LossQ |            1.06 |
# |              Time |             720 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |           -96.5 |
# |          StdEpRet |            27.2 |
# |          MaxEpRet |           -57.5 |
# |          MinEpRet |            -159 |
# |  AverageTestEpRet |            -113 |
# |      StdTestEpRet |            27.4 |
# |      MaxTestEpRet |           -74.2 |
# |      MinTestEpRet |            -155 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.42e+05 |
# |      AverageQVals |            -166 |
# |          StdQVals |            27.1 |
# |          MaxQVals |            -113 |
# |          MinQVals |            -263 |
# |            LossPi |             165 |
# |             LossQ |            1.05 |
# |              Time |             732 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |            -120 |
# |          StdEpRet |            24.9 |
# |          MaxEpRet |             -70 |
# |          MinEpRet |            -161 |
# |  AverageTestEpRet |            -116 |
# |      StdTestEpRet |            15.6 |
# |      MaxTestEpRet |           -90.3 |
# |      MinTestEpRet |            -148 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.44e+05 |
# |      AverageQVals |            -165 |
# |          StdQVals |            27.4 |
# |          MaxQVals |            -112 |
# |          MinQVals |            -263 |
# |            LossPi |             164 |
# |             LossQ |            1.03 |
# |              Time |             744 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |            -125 |
# |          StdEpRet |            23.9 |
# |          MaxEpRet |           -85.1 |
# |          MinEpRet |            -172 |
# |  AverageTestEpRet |            -117 |
# |      StdTestEpRet |            24.5 |
# |      MaxTestEpRet |           -79.8 |
# |      MinTestEpRet |            -160 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.45e+05 |
# |      AverageQVals |            -165 |
# |          StdQVals |            27.5 |
# |          MaxQVals |            -111 |
# |          MinQVals |            -263 |
# |            LossPi |             164 |
# |             LossQ |            1.07 |
# |              Time |             754 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |            -125 |
# |          StdEpRet |            38.6 |
# |          MaxEpRet |           -63.4 |
# |          MinEpRet |            -205 |
# |  AverageTestEpRet |            -117 |
# |      StdTestEpRet |            28.9 |
# |      MaxTestEpRet |           -54.6 |
# |      MinTestEpRet |            -150 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.47e+05 |
# |      AverageQVals |            -164 |
# |          StdQVals |            27.8 |
# |          MaxQVals |            -109 |
# |          MinQVals |            -264 |
# |            LossPi |             163 |
# |             LossQ |            1.07 |
# |              Time |             765 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |            -141 |
# |          StdEpRet |            21.2 |
# |          MaxEpRet |            -106 |
# |          MinEpRet |            -172 |
# |  AverageTestEpRet |            -101 |
# |      StdTestEpRet |            19.8 |
# |      MaxTestEpRet |           -74.7 |
# |      MinTestEpRet |            -136 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+05 |
# |      AverageQVals |            -163 |
# |          StdQVals |            27.9 |
# |          MaxQVals |            -108 |
# |          MinQVals |            -262 |
# |            LossPi |             162 |
# |             LossQ |            1.06 |
# |              Time |             775 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |            -123 |
# |          StdEpRet |            26.8 |
# |          MaxEpRet |           -74.9 |
# |          MinEpRet |            -160 |
# |  AverageTestEpRet |            -115 |
# |      StdTestEpRet |            32.1 |
# |      MaxTestEpRet |           -66.9 |
# |      MinTestEpRet |            -172 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.5e+05 |
# |      AverageQVals |            -162 |
# |          StdQVals |            27.9 |
# |          MaxQVals |            -106 |
# |          MinQVals |            -262 |
# |            LossPi |             161 |
# |             LossQ |            1.07 |
# |              Time |             785 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |            -115 |
# |          StdEpRet |            30.9 |
# |          MaxEpRet |           -66.8 |
# |          MinEpRet |            -173 |
# |  AverageTestEpRet |            -101 |
# |      StdTestEpRet |            28.8 |
# |      MaxTestEpRet |           -65.7 |
# |      MinTestEpRet |            -153 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.52e+05 |
# |      AverageQVals |            -161 |
# |          StdQVals |              28 |
# |          MaxQVals |            -104 |
# |          MinQVals |            -267 |
# |            LossPi |             160 |
# |             LossQ |            1.08 |
# |              Time |             794 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |            -113 |
# |          StdEpRet |              33 |
# |          MaxEpRet |           -37.5 |
# |          MinEpRet |            -166 |
# |  AverageTestEpRet |             -88 |
# |      StdTestEpRet |            38.5 |
# |      MaxTestEpRet |           -22.6 |
# |      MinTestEpRet |            -155 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.53e+05 |
# |      AverageQVals |            -160 |
# |          StdQVals |            28.3 |
# |          MaxQVals |            -102 |
# |          MinQVals |            -259 |
# |            LossPi |             159 |
# |             LossQ |            1.08 |
# |              Time |             804 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |            -116 |
# |          StdEpRet |            26.7 |
# |          MaxEpRet |           -57.4 |
# |          MinEpRet |            -166 |
# |  AverageTestEpRet |            -115 |
# |      StdTestEpRet |            42.5 |
# |      MaxTestEpRet |           -45.5 |
# |      MinTestEpRet |            -177 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.55e+05 |
# |      AverageQVals |            -159 |
# |          StdQVals |            28.3 |
# |          MaxQVals |           -99.8 |
# |          MinQVals |            -267 |
# |            LossPi |             158 |
# |             LossQ |            1.13 |
# |              Time |             815 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |            -113 |
# |          StdEpRet |            23.3 |
# |          MaxEpRet |             -79 |
# |          MinEpRet |            -166 |
# |  AverageTestEpRet |            -122 |
# |      StdTestEpRet |            27.8 |
# |      MaxTestEpRet |           -61.7 |
# |      MinTestEpRet |            -155 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.57e+05 |
# |      AverageQVals |            -158 |
# |          StdQVals |            28.3 |
# |          MaxQVals |           -97.8 |
# |          MinQVals |            -268 |
# |            LossPi |             157 |
# |             LossQ |            1.12 |
# |              Time |             826 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |            -119 |
# |          StdEpRet |            32.8 |
# |          MaxEpRet |             -80 |
# |          MinEpRet |            -187 |
# |  AverageTestEpRet |            -117 |
# |      StdTestEpRet |            22.7 |
# |      MaxTestEpRet |           -82.3 |
# |      MinTestEpRet |            -156 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.58e+05 |
# |      AverageQVals |            -157 |
# |          StdQVals |            28.6 |
# |          MaxQVals |           -95.7 |
# |          MinQVals |            -260 |
# |            LossPi |             156 |
# |             LossQ |            1.12 |
# |              Time |             835 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |            -106 |
# |          StdEpRet |            28.6 |
# |          MaxEpRet |             -72 |
# |          MinEpRet |            -172 |
# |  AverageTestEpRet |            -117 |
# |      StdTestEpRet |            18.5 |
# |      MaxTestEpRet |           -92.1 |
# |      MinTestEpRet |            -143 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.6e+05 |
# |      AverageQVals |            -156 |
# |          StdQVals |            28.6 |
# |          MaxQVals |           -93.3 |
# |          MinQVals |            -266 |
# |            LossPi |             155 |
# |             LossQ |            1.13 |
# |              Time |             846 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |            -113 |
# |          StdEpRet |            21.7 |
# |          MaxEpRet |           -61.5 |
# |          MinEpRet |            -154 |
# |  AverageTestEpRet |            -126 |
# |      StdTestEpRet |            26.8 |
# |      MaxTestEpRet |           -79.8 |
# |      MinTestEpRet |            -165 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.62e+05 |
# |      AverageQVals |            -155 |
# |          StdQVals |            28.7 |
# |          MaxQVals |           -91.9 |
# |          MinQVals |            -260 |
# |            LossPi |             154 |
# |             LossQ |            1.11 |
# |              Time |             856 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |            -103 |
# |          StdEpRet |            28.2 |
# |          MaxEpRet |             -46 |
# |          MinEpRet |            -162 |
# |  AverageTestEpRet |            -113 |
# |      StdTestEpRet |            28.2 |
# |      MaxTestEpRet |           -60.9 |
# |      MinTestEpRet |            -146 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.63e+05 |
# |      AverageQVals |            -153 |
# |          StdQVals |            28.7 |
# |          MaxQVals |           -90.6 |
# |          MinQVals |            -264 |
# |            LossPi |             153 |
# |             LossQ |             1.1 |
# |              Time |             867 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             100 |
# |      AverageEpRet |            -117 |
# |          StdEpRet |            21.1 |
# |          MaxEpRet |             -72 |
# |          MinEpRet |            -158 |
# |  AverageTestEpRet |            -114 |
# |      StdTestEpRet |            25.7 |
# |      MaxTestEpRet |           -76.6 |
# |      MinTestEpRet |            -149 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+05 |
# |      AverageQVals |            -152 |
# |          StdQVals |            28.7 |
# |          MaxQVals |             -89 |
# |          MinQVals |            -258 |
# |            LossPi |             151 |
# |             LossQ |            1.13 |
# |              Time |             877 |
# ---------------------------------------

# %% [markdown]
# #### Quadratic reward with ending penalty

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='ddpg_q_ep', exp_name='ddpg_q_ep')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0025
qlr_b = 0.0025

# Env function
reward_args = {'qx1':9,'qx2':0.05,'qx3':9,'qx4':0.05,'pu1':0.1,'pu2':0.1, 'sx1': 100, 'sx3':100, 'end_horizon':0}
env_fn = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Quadratic with ending penalty', reward_args = reward_args,ep_len=maxeplen_b)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Warning: Log dir ddpg_q_ep already exists! Storing info there anyway.
# Logging data to ddpg_q_ep/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(functools.partial(functools.partial(functools.partial(<function env_fn at 0x7f76de14bea0>, env_name='gyroscopeenv-v0', reward_type='Quadratic', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Absolute', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.5, 'pu2': 0.5}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.1, 'pu1': 0.25, 'pu2': 0.25}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with ending penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1, 'sx1': 100, 'sx3': 100, 'end_horizon': 0}, ep_len=110)",
#     "epochs":	100,
#     "exp_name":	"ddpg_q_ep",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f76adf01b00>":	{
#             "epoch_dict":	{},
#             "exp_name":	"ddpg_q_ep",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_q_ep",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_q_ep/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"ddpg_q_ep",
#         "output_dir":	"ddpg_q_ep"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0025,
#     "polyak":	0.995,
#     "q_lr":	0.0025,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 4802, 	 q: 5201
# /home/matthieulc/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |       -7.59e+04 |
# |          StdEpRet |         3.1e+04 |
# |          MaxEpRet |       -7.13e+03 |
# |          MinEpRet |       -1.42e+05 |
# |  AverageTestEpRet |       -8.41e+04 |
# |      StdTestEpRet |        1.71e+04 |
# |      MaxTestEpRet |       -5.42e+04 |
# |      MinTestEpRet |       -1.26e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |      AverageQVals |            -596 |
# |          StdQVals |             519 |
# |          MaxQVals |           0.289 |
# |          MinQVals |       -2.86e+03 |
# |            LossPi |             567 |
# |             LossQ |        3.28e+05 |
# |              Time |             5.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |       -8.43e+04 |
# |          StdEpRet |        3.03e+04 |
# |          MaxEpRet |       -4.24e+04 |
# |          MinEpRet |       -1.41e+05 |
# |  AverageTestEpRet |       -8.46e+04 |
# |      StdTestEpRet |        2.77e+04 |
# |      MaxTestEpRet |       -5.67e+04 |
# |      MinTestEpRet |       -1.37e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |      AverageQVals |       -3.61e+03 |
# |          StdQVals |        1.71e+03 |
# |          MaxQVals |            -425 |
# |          MinQVals |       -1.09e+04 |
# |            LossPi |        3.54e+03 |
# |             LossQ |           2e+05 |
# |              Time |            14.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |       -7.75e+04 |
# |          StdEpRet |        2.07e+04 |
# |          MaxEpRet |       -4.35e+04 |
# |          MinEpRet |       -1.14e+05 |
# |  AverageTestEpRet |       -9.27e+04 |
# |      StdTestEpRet |         3.6e+04 |
# |      MaxTestEpRet |       -4.21e+04 |
# |      MinTestEpRet |       -1.56e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |      AverageQVals |       -8.32e+03 |
# |          StdQVals |        2.29e+03 |
# |          MaxQVals |       -2.81e+03 |
# |          MinQVals |       -1.78e+04 |
# |            LossPi |         8.2e+03 |
# |             LossQ |        2.72e+05 |
# |              Time |            23.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |       -7.77e+04 |
# |          StdEpRet |        2.11e+04 |
# |          MaxEpRet |       -3.88e+04 |
# |          MinEpRet |       -1.18e+05 |
# |  AverageTestEpRet |       -5.26e+04 |
# |      StdTestEpRet |        2.71e+04 |
# |      MaxTestEpRet |        -2.3e+04 |
# |      MinTestEpRet |       -9.92e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |      AverageQVals |       -1.26e+04 |
# |          StdQVals |        2.88e+03 |
# |          MaxQVals |          -5e+03 |
# |          MinQVals |       -2.43e+04 |
# |            LossPi |        1.24e+04 |
# |             LossQ |        3.74e+05 |
# |              Time |            32.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |       -7.81e+04 |
# |          StdEpRet |        2.66e+04 |
# |          MaxEpRet |       -3.28e+04 |
# |          MinEpRet |       -1.25e+05 |
# |  AverageTestEpRet |       -4.76e+04 |
# |      StdTestEpRet |        3.36e+04 |
# |      MaxTestEpRet |       -1.85e+03 |
# |      MinTestEpRet |       -1.07e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |      AverageQVals |       -1.67e+04 |
# |          StdQVals |        3.57e+03 |
# |          MaxQVals |        -7.4e+03 |
# |          MinQVals |       -3.16e+04 |
# |            LossPi |        1.65e+04 |
# |             LossQ |        4.65e+05 |
# |              Time |            41.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |       -7.18e+04 |
# |          StdEpRet |        2.34e+04 |
# |          MaxEpRet |       -4.13e+04 |
# |          MinEpRet |       -1.29e+05 |
# |  AverageTestEpRet |        -5.8e+04 |
# |      StdTestEpRet |        3.68e+04 |
# |      MaxTestEpRet |        -2.1e+03 |
# |      MinTestEpRet |       -1.29e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |      AverageQVals |       -2.02e+04 |
# |          StdQVals |        4.17e+03 |
# |          MaxQVals |       -9.73e+03 |
# |          MinQVals |       -3.86e+04 |
# |            LossPi |           2e+04 |
# |             LossQ |        5.44e+05 |
# |              Time |            50.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |       -4.95e+04 |
# |          StdEpRet |        2.43e+04 |
# |          MaxEpRet |       -1.46e+04 |
# |          MinEpRet |       -9.07e+04 |
# |  AverageTestEpRet |       -5.02e+04 |
# |      StdTestEpRet |        3.14e+04 |
# |      MaxTestEpRet |       -3.97e+03 |
# |      MinTestEpRet |       -1.09e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |      AverageQVals |        -2.3e+04 |
# |          StdQVals |        4.64e+03 |
# |          MaxQVals |       -1.17e+04 |
# |          MinQVals |       -4.39e+04 |
# |            LossPi |        2.27e+04 |
# |             LossQ |        5.57e+05 |
# |              Time |            57.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |       -3.31e+04 |
# |          StdEpRet |        2.31e+04 |
# |          MaxEpRet |       -3.23e+03 |
# |          MinEpRet |        -7.9e+04 |
# |  AverageTestEpRet |        -3.7e+04 |
# |      StdTestEpRet |        3.09e+04 |
# |      MaxTestEpRet |       -7.61e+03 |
# |      MinTestEpRet |       -1.09e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |      AverageQVals |       -2.48e+04 |
# |          StdQVals |           5e+03 |
# |          MaxQVals |       -1.33e+04 |
# |          MinQVals |        -4.8e+04 |
# |            LossPi |        2.46e+04 |
# |             LossQ |        5.31e+05 |
# |              Time |            65.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |       -5.56e+04 |
# |          StdEpRet |        3.86e+04 |
# |          MaxEpRet |       -8.28e+03 |
# |          MinEpRet |       -1.34e+05 |
# |  AverageTestEpRet |       -3.94e+04 |
# |      StdTestEpRet |         3.6e+04 |
# |      MaxTestEpRet |       -1.08e+04 |
# |      MinTestEpRet |       -1.36e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |      AverageQVals |       -2.63e+04 |
# |          StdQVals |        5.23e+03 |
# |          MaxQVals |       -1.52e+04 |
# |          MinQVals |       -5.13e+04 |
# |            LossPi |         2.6e+04 |
# |             LossQ |        5.14e+05 |
# |              Time |            73.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |       -6.01e+04 |
# |          StdEpRet |        3.78e+04 |
# |          MaxEpRet |        -4.1e+03 |
# |          MinEpRet |       -1.19e+05 |
# |  AverageTestEpRet |       -3.56e+04 |
# |      StdTestEpRet |        2.46e+04 |
# |      MaxTestEpRet |        -1.6e+03 |
# |      MinTestEpRet |       -7.61e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |       -2.77e+04 |
# |          StdQVals |        5.37e+03 |
# |          MaxQVals |       -1.67e+04 |
# |          MinQVals |        -5.4e+04 |
# |            LossPi |        2.74e+04 |
# |             LossQ |        5.09e+05 |
# |              Time |            80.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |       -4.48e+04 |
# |          StdEpRet |        3.09e+04 |
# |          MaxEpRet |       -7.75e+03 |
# |          MinEpRet |       -1.25e+05 |
# |  AverageTestEpRet |       -2.82e+04 |
# |      StdTestEpRet |        2.06e+04 |
# |      MaxTestEpRet |        -5.3e+03 |
# |      MinTestEpRet |       -7.34e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |      AverageQVals |       -2.89e+04 |
# |          StdQVals |        5.45e+03 |
# |          MaxQVals |       -1.82e+04 |
# |          MinQVals |       -5.68e+04 |
# |            LossPi |        2.87e+04 |
# |             LossQ |        4.88e+05 |
# |              Time |            88.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |        -5.7e+04 |
# |          StdEpRet |        3.65e+04 |
# |          MaxEpRet |       -2.99e+03 |
# |          MinEpRet |        -1.2e+05 |
# |  AverageTestEpRet |        -3.7e+04 |
# |      StdTestEpRet |        2.04e+04 |
# |      MaxTestEpRet |       -9.58e+03 |
# |      MinTestEpRet |       -6.84e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |      AverageQVals |       -3.02e+04 |
# |          StdQVals |        5.48e+03 |
# |          MaxQVals |       -1.99e+04 |
# |          MinQVals |       -5.92e+04 |
# |            LossPi |           3e+04 |
# |             LossQ |        4.72e+05 |
# |              Time |            96.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |       -4.87e+04 |
# |          StdEpRet |        2.66e+04 |
# |          MaxEpRet |       -7.12e+03 |
# |          MinEpRet |       -9.22e+04 |
# |  AverageTestEpRet |       -4.06e+04 |
# |      StdTestEpRet |        3.27e+04 |
# |      MaxTestEpRet |       -8.41e+03 |
# |      MinTestEpRet |       -1.08e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |      AverageQVals |       -3.16e+04 |
# |          StdQVals |        5.54e+03 |
# |          MaxQVals |       -2.09e+04 |
# |          MinQVals |       -6.18e+04 |
# |            LossPi |        3.14e+04 |
# |             LossQ |        4.55e+05 |
# |              Time |             104 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |       -5.12e+04 |
# |          StdEpRet |        3.04e+04 |
# |          MaxEpRet |       -3.23e+03 |
# |          MinEpRet |       -1.09e+05 |
# |  AverageTestEpRet |       -4.71e+04 |
# |      StdTestEpRet |        3.24e+04 |
# |      MaxTestEpRet |       -1.44e+04 |
# |      MinTestEpRet |       -1.18e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |      AverageQVals |        -3.3e+04 |
# |          StdQVals |        5.67e+03 |
# |          MaxQVals |        -2.2e+04 |
# |          MinQVals |       -6.44e+04 |
# |            LossPi |        3.28e+04 |
# |             LossQ |         4.4e+05 |
# |              Time |             111 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |       -5.03e+04 |
# |          StdEpRet |           3e+04 |
# |          MaxEpRet |       -2.46e+03 |
# |          MinEpRet |       -1.08e+05 |
# |  AverageTestEpRet |       -3.56e+04 |
# |      StdTestEpRet |        2.95e+04 |
# |      MaxTestEpRet |       -5.42e+03 |
# |      MinTestEpRet |       -1.13e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |      AverageQVals |       -3.43e+04 |
# |          StdQVals |        5.88e+03 |
# |          MaxQVals |       -2.33e+04 |
# |          MinQVals |       -6.79e+04 |
# |            LossPi |        3.41e+04 |
# |             LossQ |        4.47e+05 |
# |              Time |             119 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |       -5.04e+04 |
# |          StdEpRet |        3.47e+04 |
# |          MaxEpRet |       -3.75e+03 |
# |          MinEpRet |       -1.03e+05 |
# |  AverageTestEpRet |       -5.35e+04 |
# |      StdTestEpRet |        2.09e+04 |
# |      MaxTestEpRet |       -9.87e+03 |
# |      MinTestEpRet |       -7.75e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |      AverageQVals |       -3.56e+04 |
# |          StdQVals |        6.08e+03 |
# |          MaxQVals |       -2.39e+04 |
# |          MinQVals |       -7.09e+04 |
# |            LossPi |        3.54e+04 |
# |             LossQ |         4.5e+05 |
# |              Time |             127 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |       -4.56e+04 |
# |          StdEpRet |        3.45e+04 |
# |          MaxEpRet |       -5.47e+03 |
# |          MinEpRet |       -1.16e+05 |
# |  AverageTestEpRet |       -5.55e+04 |
# |      StdTestEpRet |        4.43e+04 |
# |      MaxTestEpRet |       -3.89e+03 |
# |      MinTestEpRet |       -1.23e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |      AverageQVals |       -3.68e+04 |
# |          StdQVals |        6.31e+03 |
# |          MaxQVals |       -2.45e+04 |
# |          MinQVals |       -7.33e+04 |
# |            LossPi |        3.66e+04 |
# |             LossQ |        4.48e+05 |
# |              Time |             135 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |       -3.41e+04 |
# |          StdEpRet |        2.79e+04 |
# |          MaxEpRet |       -2.93e+03 |
# |          MinEpRet |       -1.11e+05 |
# |  AverageTestEpRet |       -4.54e+04 |
# |      StdTestEpRet |        3.39e+04 |
# |      MaxTestEpRet |        -2.2e+03 |
# |      MinTestEpRet |       -9.76e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |      AverageQVals |        -3.8e+04 |
# |          StdQVals |        6.53e+03 |
# |          MaxQVals |       -2.46e+04 |
# |          MinQVals |       -7.52e+04 |
# |            LossPi |        3.78e+04 |
# |             LossQ |        4.49e+05 |
# |              Time |             142 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |       -4.07e+04 |
# |          StdEpRet |        3.17e+04 |
# |          MaxEpRet |       -3.83e+03 |
# |          MinEpRet |       -1.09e+05 |
# |  AverageTestEpRet |       -4.01e+04 |
# |      StdTestEpRet |        3.46e+04 |
# |      MaxTestEpRet |       -2.43e+03 |
# |      MinTestEpRet |       -1.25e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |      AverageQVals |       -3.91e+04 |
# |          StdQVals |        6.84e+03 |
# |          MaxQVals |       -2.46e+04 |
# |          MinQVals |       -7.78e+04 |
# |            LossPi |        3.89e+04 |
# |             LossQ |        4.64e+05 |
# |              Time |             150 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |       -3.86e+04 |
# |          StdEpRet |        2.68e+04 |
# |          MaxEpRet |       -1.24e+03 |
# |          MinEpRet |       -8.41e+04 |
# |  AverageTestEpRet |       -3.51e+04 |
# |      StdTestEpRet |        2.36e+04 |
# |      MaxTestEpRet |       -1.47e+03 |
# |      MinTestEpRet |       -8.31e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |       -4.01e+04 |
# |          StdQVals |        7.09e+03 |
# |          MaxQVals |       -2.44e+04 |
# |          MinQVals |       -7.99e+04 |
# |            LossPi |        3.99e+04 |
# |             LossQ |        4.77e+05 |
# |              Time |             158 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |       -4.99e+04 |
# |          StdEpRet |        2.79e+04 |
# |          MaxEpRet |       -5.38e+03 |
# |          MinEpRet |       -1.11e+05 |
# |  AverageTestEpRet |       -4.19e+04 |
# |      StdTestEpRet |        2.15e+04 |
# |      MaxTestEpRet |       -3.24e+03 |
# |      MinTestEpRet |       -8.73e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |      AverageQVals |       -4.09e+04 |
# |          StdQVals |        7.42e+03 |
# |          MaxQVals |       -2.44e+04 |
# |          MinQVals |        -8.1e+04 |
# |            LossPi |        4.07e+04 |
# |             LossQ |        4.77e+05 |
# |              Time |             167 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |        -3.9e+04 |
# |          StdEpRet |        2.79e+04 |
# |          MaxEpRet |       -2.47e+03 |
# |          MinEpRet |       -8.84e+04 |
# |  AverageTestEpRet |       -2.84e+04 |
# |      StdTestEpRet |        2.19e+04 |
# |      MaxTestEpRet |       -1.94e+03 |
# |      MinTestEpRet |       -6.15e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |      AverageQVals |       -4.16e+04 |
# |          StdQVals |        7.72e+03 |
# |          MaxQVals |       -2.43e+04 |
# |          MinQVals |       -8.27e+04 |
# |            LossPi |        4.14e+04 |
# |             LossQ |        4.84e+05 |
# |              Time |             176 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |       -3.49e+04 |
# |          StdEpRet |        3.18e+04 |
# |          MaxEpRet |       -2.33e+03 |
# |          MinEpRet |       -1.02e+05 |
# |  AverageTestEpRet |        -3.7e+04 |
# |      StdTestEpRet |        2.01e+04 |
# |      MaxTestEpRet |       -1.27e+04 |
# |      MinTestEpRet |       -7.95e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |      AverageQVals |       -4.22e+04 |
# |          StdQVals |        8.08e+03 |
# |          MaxQVals |       -2.43e+04 |
# |          MinQVals |       -8.41e+04 |
# |            LossPi |         4.2e+04 |
# |             LossQ |        4.87e+05 |
# |              Time |             186 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |       -4.25e+04 |
# |          StdEpRet |        2.49e+04 |
# |          MaxEpRet |       -8.13e+03 |
# |          MinEpRet |       -9.91e+04 |
# |  AverageTestEpRet |       -3.31e+04 |
# |      StdTestEpRet |        2.84e+04 |
# |      MaxTestEpRet |        -8.6e+03 |
# |      MinTestEpRet |       -1.08e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |      AverageQVals |       -4.26e+04 |
# |          StdQVals |        8.34e+03 |
# |          MaxQVals |       -2.42e+04 |
# |          MinQVals |       -8.52e+04 |
# |            LossPi |        4.24e+04 |
# |             LossQ |        4.95e+05 |
# |              Time |             195 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |       -5.04e+04 |
# |          StdEpRet |        3.16e+04 |
# |          MaxEpRet |       -1.11e+04 |
# |          MinEpRet |       -1.14e+05 |
# |  AverageTestEpRet |       -3.05e+04 |
# |      StdTestEpRet |        1.97e+04 |
# |      MaxTestEpRet |       -1.02e+04 |
# |      MinTestEpRet |       -6.86e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |      AverageQVals |       -4.32e+04 |
# |          StdQVals |        8.71e+03 |
# |          MaxQVals |        -2.4e+04 |
# |          MinQVals |       -8.65e+04 |
# |            LossPi |         4.3e+04 |
# |             LossQ |        5.05e+05 |
# |              Time |             204 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |       -3.96e+04 |
# |          StdEpRet |         2.5e+04 |
# |          MaxEpRet |       -7.67e+03 |
# |          MinEpRet |        -9.3e+04 |
# |  AverageTestEpRet |       -4.11e+04 |
# |      StdTestEpRet |        2.97e+04 |
# |      MaxTestEpRet |       -4.65e+03 |
# |      MinTestEpRet |        -8.7e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |      AverageQVals |       -4.37e+04 |
# |          StdQVals |        8.98e+03 |
# |          MaxQVals |       -2.39e+04 |
# |          MinQVals |       -8.71e+04 |
# |            LossPi |        4.35e+04 |
# |             LossQ |        4.95e+05 |
# |              Time |             214 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |       -3.52e+04 |
# |          StdEpRet |        2.46e+04 |
# |          MaxEpRet |       -2.12e+03 |
# |          MinEpRet |       -8.42e+04 |
# |  AverageTestEpRet |       -4.55e+04 |
# |      StdTestEpRet |        2.08e+04 |
# |      MaxTestEpRet |       -1.55e+04 |
# |      MinTestEpRet |       -7.98e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |      AverageQVals |       -4.39e+04 |
# |          StdQVals |        9.24e+03 |
# |          MaxQVals |       -2.39e+04 |
# |          MinQVals |       -8.83e+04 |
# |            LossPi |        4.37e+04 |
# |             LossQ |        4.87e+05 |
# |              Time |             223 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |        -3.6e+04 |
# |          StdEpRet |         2.2e+04 |
# |          MaxEpRet |       -6.99e+03 |
# |          MinEpRet |       -7.75e+04 |
# |  AverageTestEpRet |       -2.61e+04 |
# |      StdTestEpRet |        1.54e+04 |
# |      MaxTestEpRet |        -7.6e+03 |
# |      MinTestEpRet |       -5.99e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |      AverageQVals |       -4.43e+04 |
# |          StdQVals |        9.64e+03 |
# |          MaxQVals |       -2.33e+04 |
# |          MinQVals |       -8.93e+04 |
# |            LossPi |        4.41e+04 |
# |             LossQ |        4.84e+05 |
# |              Time |             232 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |       -3.07e+04 |
# |          StdEpRet |         1.9e+04 |
# |          MaxEpRet |       -7.02e+03 |
# |          MinEpRet |       -7.67e+04 |
# |  AverageTestEpRet |       -2.97e+04 |
# |      StdTestEpRet |        1.27e+04 |
# |      MaxTestEpRet |       -1.18e+04 |
# |      MinTestEpRet |       -5.23e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |      AverageQVals |       -4.46e+04 |
# |          StdQVals |        9.95e+03 |
# |          MaxQVals |        -2.3e+04 |
# |          MinQVals |       -9.08e+04 |
# |            LossPi |        4.45e+04 |
# |             LossQ |        4.83e+05 |
# |              Time |             240 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |       -4.83e+04 |
# |          StdEpRet |        3.47e+04 |
# |          MaxEpRet |       -3.48e+03 |
# |          MinEpRet |        -1.1e+05 |
# |  AverageTestEpRet |       -3.38e+04 |
# |      StdTestEpRet |        2.85e+04 |
# |      MaxTestEpRet |       -1.05e+04 |
# |      MinTestEpRet |       -9.83e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |       -4.48e+04 |
# |          StdQVals |        1.02e+04 |
# |          MaxQVals |       -2.27e+04 |
# |          MinQVals |       -9.18e+04 |
# |            LossPi |        4.46e+04 |
# |             LossQ |        4.72e+05 |
# |              Time |             248 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |       -3.45e+04 |
# |          StdEpRet |        1.47e+04 |
# |          MaxEpRet |       -1.59e+04 |
# |          MinEpRet |       -7.19e+04 |
# |  AverageTestEpRet |       -4.58e+04 |
# |      StdTestEpRet |         2.8e+04 |
# |      MaxTestEpRet |       -7.21e+03 |
# |      MinTestEpRet |       -1.09e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |      AverageQVals |       -4.51e+04 |
# |          StdQVals |        1.06e+04 |
# |          MaxQVals |       -2.25e+04 |
# |          MinQVals |        -9.3e+04 |
# |            LossPi |         4.5e+04 |
# |             LossQ |        4.73e+05 |
# |              Time |             256 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |       -4.92e+04 |
# |          StdEpRet |        2.67e+04 |
# |          MaxEpRet |       -6.52e+03 |
# |          MinEpRet |       -9.53e+04 |
# |  AverageTestEpRet |          -6e+04 |
# |      StdTestEpRet |        4.24e+04 |
# |      MaxTestEpRet |       -6.81e+03 |
# |      MinTestEpRet |        -1.2e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |      AverageQVals |       -4.54e+04 |
# |          StdQVals |        1.08e+04 |
# |          MaxQVals |       -2.22e+04 |
# |          MinQVals |       -9.43e+04 |
# |            LossPi |        4.52e+04 |
# |             LossQ |         4.7e+05 |
# |              Time |             263 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |       -3.48e+04 |
# |          StdEpRet |        2.19e+04 |
# |          MaxEpRet |       -8.79e+03 |
# |          MinEpRet |       -9.76e+04 |
# |  AverageTestEpRet |          -3e+04 |
# |      StdTestEpRet |        1.75e+04 |
# |      MaxTestEpRet |       -8.53e+03 |
# |      MinTestEpRet |       -5.62e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |      AverageQVals |       -4.57e+04 |
# |          StdQVals |        1.11e+04 |
# |          MaxQVals |        -2.2e+04 |
# |          MinQVals |       -9.52e+04 |
# |            LossPi |        4.55e+04 |
# |             LossQ |        4.72e+05 |
# |              Time |             271 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |        -3.8e+04 |
# |          StdEpRet |        3.39e+04 |
# |          MaxEpRet |        -2.3e+03 |
# |          MinEpRet |       -1.05e+05 |
# |  AverageTestEpRet |       -3.13e+04 |
# |      StdTestEpRet |        2.28e+04 |
# |      MaxTestEpRet |            -564 |
# |      MinTestEpRet |       -6.36e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |      AverageQVals |       -4.57e+04 |
# |          StdQVals |        1.15e+04 |
# |          MaxQVals |       -2.16e+04 |
# |          MinQVals |       -9.62e+04 |
# |            LossPi |        4.55e+04 |
# |             LossQ |        4.72e+05 |
# |              Time |             279 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |       -3.04e+04 |
# |          StdEpRet |         2.9e+04 |
# |          MaxEpRet |       -2.84e+03 |
# |          MinEpRet |       -1.03e+05 |
# |  AverageTestEpRet |       -3.79e+04 |
# |      StdTestEpRet |        2.66e+04 |
# |      MaxTestEpRet |       -8.75e+03 |
# |      MinTestEpRet |       -1.03e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |      AverageQVals |       -4.58e+04 |
# |          StdQVals |        1.17e+04 |
# |          MaxQVals |       -2.13e+04 |
# |          MinQVals |       -9.76e+04 |
# |            LossPi |        4.56e+04 |
# |             LossQ |        4.64e+05 |
# |              Time |             287 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |       -2.97e+04 |
# |          StdEpRet |        1.89e+04 |
# |          MaxEpRet |       -5.26e+03 |
# |          MinEpRet |       -6.16e+04 |
# |  AverageTestEpRet |        -3.5e+04 |
# |      StdTestEpRet |         2.6e+04 |
# |      MaxTestEpRet |            -439 |
# |      MinTestEpRet |       -9.32e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |      AverageQVals |       -4.59e+04 |
# |          StdQVals |         1.2e+04 |
# |          MaxQVals |       -2.08e+04 |
# |          MinQVals |        -9.8e+04 |
# |            LossPi |        4.57e+04 |
# |             LossQ |         4.6e+05 |
# |              Time |             294 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |       -4.36e+04 |
# |          StdEpRet |        2.46e+04 |
# |          MaxEpRet |       -3.25e+03 |
# |          MinEpRet |       -8.22e+04 |
# |  AverageTestEpRet |       -2.81e+04 |
# |      StdTestEpRet |        1.46e+04 |
# |      MaxTestEpRet |       -6.53e+03 |
# |      MinTestEpRet |       -5.29e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |      AverageQVals |       -4.58e+04 |
# |          StdQVals |        1.23e+04 |
# |          MaxQVals |       -2.03e+04 |
# |          MinQVals |       -9.91e+04 |
# |            LossPi |        4.57e+04 |
# |             LossQ |        4.56e+05 |
# |              Time |             302 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |       -3.55e+04 |
# |          StdEpRet |        2.79e+04 |
# |          MaxEpRet |            -622 |
# |          MinEpRet |       -1.14e+05 |
# |  AverageTestEpRet |       -6.22e+04 |
# |      StdTestEpRet |        5.64e+04 |
# |      MaxTestEpRet |       -1.06e+04 |
# |      MinTestEpRet |       -2.18e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |      AverageQVals |       -4.57e+04 |
# |          StdQVals |        1.25e+04 |
# |          MaxQVals |       -1.99e+04 |
# |          MinQVals |       -9.94e+04 |
# |            LossPi |        4.55e+04 |
# |             LossQ |        4.61e+05 |
# |              Time |             311 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |       -3.26e+04 |
# |          StdEpRet |        1.63e+04 |
# |          MaxEpRet |       -2.67e+03 |
# |          MinEpRet |       -5.79e+04 |
# |  AverageTestEpRet |       -4.73e+04 |
# |      StdTestEpRet |           2e+04 |
# |      MaxTestEpRet |       -2.08e+04 |
# |      MinTestEpRet |       -8.17e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |      AverageQVals |       -4.57e+04 |
# |          StdQVals |        1.28e+04 |
# |          MaxQVals |       -1.94e+04 |
# |          MinQVals |       -9.95e+04 |
# |            LossPi |        4.55e+04 |
# |             LossQ |        4.55e+05 |
# |              Time |             320 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |       -3.79e+04 |
# |          StdEpRet |        2.12e+04 |
# |          MaxEpRet |       -1.48e+03 |
# |          MinEpRet |       -7.63e+04 |
# |  AverageTestEpRet |       -3.06e+04 |
# |      StdTestEpRet |        1.81e+04 |
# |      MaxTestEpRet |       -1.15e+04 |
# |      MinTestEpRet |       -6.62e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |       -4.55e+04 |
# |          StdQVals |         1.3e+04 |
# |          MaxQVals |       -1.89e+04 |
# |          MinQVals |       -9.96e+04 |
# |            LossPi |        4.53e+04 |
# |             LossQ |        4.54e+05 |
# |              Time |             330 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |       -4.14e+04 |
# |          StdEpRet |        1.92e+04 |
# |          MaxEpRet |       -9.33e+03 |
# |          MinEpRet |       -7.86e+04 |
# |  AverageTestEpRet |       -4.51e+04 |
# |      StdTestEpRet |        3.65e+04 |
# |      MaxTestEpRet |       -9.36e+03 |
# |      MinTestEpRet |       -1.15e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |      AverageQVals |       -4.55e+04 |
# |          StdQVals |        1.31e+04 |
# |          MaxQVals |       -1.85e+04 |
# |          MinQVals |       -9.94e+04 |
# |            LossPi |        4.53e+04 |
# |             LossQ |        4.62e+05 |
# |              Time |             340 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |       -3.42e+04 |
# |          StdEpRet |        2.48e+04 |
# |          MaxEpRet |       -4.44e+03 |
# |          MinEpRet |       -9.26e+04 |
# |  AverageTestEpRet |       -3.36e+04 |
# |      StdTestEpRet |        2.02e+04 |
# |      MaxTestEpRet |        -3.8e+03 |
# |      MinTestEpRet |       -7.67e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |      AverageQVals |       -4.53e+04 |
# |          StdQVals |        1.31e+04 |
# |          MaxQVals |       -1.82e+04 |
# |          MinQVals |       -9.91e+04 |
# |            LossPi |        4.51e+04 |
# |             LossQ |        4.68e+05 |
# |              Time |             352 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |       -2.65e+04 |
# |          StdEpRet |        1.75e+04 |
# |          MaxEpRet |       -3.18e+03 |
# |          MinEpRet |        -6.3e+04 |
# |  AverageTestEpRet |       -2.95e+04 |
# |      StdTestEpRet |        1.79e+04 |
# |      MaxTestEpRet |       -2.81e+03 |
# |      MinTestEpRet |       -6.34e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |      AverageQVals |       -4.51e+04 |
# |          StdQVals |        1.32e+04 |
# |          MaxQVals |       -1.79e+04 |
# |          MinQVals |       -9.87e+04 |
# |            LossPi |        4.49e+04 |
# |             LossQ |        4.74e+05 |
# |              Time |             363 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |       -4.07e+04 |
# |          StdEpRet |        2.52e+04 |
# |          MaxEpRet |       -5.91e+03 |
# |          MinEpRet |       -9.15e+04 |
# |  AverageTestEpRet |       -1.82e+04 |
# |      StdTestEpRet |        6.63e+03 |
# |      MaxTestEpRet |       -7.97e+03 |
# |      MinTestEpRet |       -3.01e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |      AverageQVals |       -4.47e+04 |
# |          StdQVals |        1.33e+04 |
# |          MaxQVals |       -1.77e+04 |
# |          MinQVals |       -9.81e+04 |
# |            LossPi |        4.45e+04 |
# |             LossQ |        4.63e+05 |
# |              Time |             373 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |       -2.31e+04 |
# |          StdEpRet |        1.72e+04 |
# |          MaxEpRet |       -2.98e+03 |
# |          MinEpRet |       -6.59e+04 |
# |  AverageTestEpRet |       -2.29e+04 |
# |      StdTestEpRet |         1.4e+04 |
# |      MaxTestEpRet |       -1.73e+03 |
# |      MinTestEpRet |       -4.77e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |      AverageQVals |       -4.44e+04 |
# |          StdQVals |        1.32e+04 |
# |          MaxQVals |       -1.74e+04 |
# |          MinQVals |       -9.81e+04 |
# |            LossPi |        4.42e+04 |
# |             LossQ |        4.72e+05 |
# |              Time |             383 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |       -3.42e+04 |
# |          StdEpRet |        2.39e+04 |
# |          MaxEpRet |       -1.13e+03 |
# |          MinEpRet |       -8.51e+04 |
# |  AverageTestEpRet |       -3.57e+04 |
# |      StdTestEpRet |         1.5e+04 |
# |      MaxTestEpRet |       -1.31e+04 |
# |      MinTestEpRet |       -6.28e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |      AverageQVals |       -4.41e+04 |
# |          StdQVals |        1.32e+04 |
# |          MaxQVals |       -1.71e+04 |
# |          MinQVals |       -9.79e+04 |
# |            LossPi |        4.39e+04 |
# |             LossQ |        4.61e+05 |
# |              Time |             392 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |       -2.79e+04 |
# |          StdEpRet |        2.38e+04 |
# |          MaxEpRet |       -1.11e+03 |
# |          MinEpRet |        -8.4e+04 |
# |  AverageTestEpRet |       -2.21e+04 |
# |      StdTestEpRet |        2.18e+04 |
# |      MaxTestEpRet |       -3.01e+03 |
# |      MinTestEpRet |       -8.22e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.75e+04 |
# |      AverageQVals |       -4.38e+04 |
# |          StdQVals |        1.32e+04 |
# |          MaxQVals |       -1.67e+04 |
# |          MinQVals |       -9.69e+04 |
# |            LossPi |        4.37e+04 |
# |             LossQ |        4.67e+05 |
# |              Time |             402 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |       -3.26e+04 |
# |          StdEpRet |        2.49e+04 |
# |          MaxEpRet |        -3.5e+03 |
# |          MinEpRet |       -9.47e+04 |
# |  AverageTestEpRet |       -2.83e+04 |
# |      StdTestEpRet |        1.36e+04 |
# |      MaxTestEpRet |       -7.81e+03 |
# |      MinTestEpRet |       -5.16e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.92e+04 |
# |      AverageQVals |       -4.34e+04 |
# |          StdQVals |        1.31e+04 |
# |          MaxQVals |       -1.63e+04 |
# |          MinQVals |       -9.66e+04 |
# |            LossPi |        4.32e+04 |
# |             LossQ |        4.65e+05 |
# |              Time |             411 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |       -3.07e+04 |
# |          StdEpRet |        2.36e+04 |
# |          MaxEpRet |       -1.19e+04 |
# |          MinEpRet |       -1.09e+05 |
# |  AverageTestEpRet |        -3.5e+04 |
# |      StdTestEpRet |        3.75e+04 |
# |      MaxTestEpRet |       -5.24e+03 |
# |      MinTestEpRet |       -1.19e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+04 |
# |      AverageQVals |       -4.31e+04 |
# |          StdQVals |         1.3e+04 |
# |          MaxQVals |        -1.6e+04 |
# |          MinQVals |        -9.5e+04 |
# |            LossPi |        4.29e+04 |
# |             LossQ |        4.63e+05 |
# |              Time |             420 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |       -2.59e+04 |
# |          StdEpRet |        1.82e+04 |
# |          MaxEpRet |       -3.97e+03 |
# |          MinEpRet |        -5.8e+04 |
# |  AverageTestEpRet |       -2.49e+04 |
# |      StdTestEpRet |        1.66e+04 |
# |      MaxTestEpRet |       -2.21e+03 |
# |      MinTestEpRet |       -5.68e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |       -4.26e+04 |
# |          StdQVals |         1.3e+04 |
# |          MaxQVals |       -1.59e+04 |
# |          MinQVals |        -9.4e+04 |
# |            LossPi |        4.24e+04 |
# |             LossQ |        4.67e+05 |
# |              Time |             430 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |        -1.9e+04 |
# |          StdEpRet |         1.1e+04 |
# |          MaxEpRet |       -2.51e+03 |
# |          MinEpRet |       -4.05e+04 |
# |  AverageTestEpRet |       -2.96e+04 |
# |      StdTestEpRet |        1.84e+04 |
# |      MaxTestEpRet |       -2.07e+03 |
# |      MinTestEpRet |       -5.44e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.41e+04 |
# |      AverageQVals |       -4.21e+04 |
# |          StdQVals |         1.3e+04 |
# |          MaxQVals |       -1.55e+04 |
# |          MinQVals |       -9.33e+04 |
# |            LossPi |        4.19e+04 |
# |             LossQ |        4.67e+05 |
# |              Time |             439 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |       -1.05e+04 |
# |          StdEpRet |        8.33e+03 |
# |          MaxEpRet |        -1.4e+03 |
# |          MinEpRet |       -3.35e+04 |
# |  AverageTestEpRet |       -2.56e+04 |
# |      StdTestEpRet |        1.58e+04 |
# |      MaxTestEpRet |       -9.97e+03 |
# |      MinTestEpRet |        -6.4e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.58e+04 |
# |      AverageQVals |       -4.17e+04 |
# |          StdQVals |        1.29e+04 |
# |          MaxQVals |       -1.52e+04 |
# |          MinQVals |       -9.24e+04 |
# |            LossPi |        4.15e+04 |
# |             LossQ |         4.7e+05 |
# |              Time |             448 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |       -3.49e+04 |
# |          StdEpRet |        2.86e+04 |
# |          MaxEpRet |       -3.79e+03 |
# |          MinEpRet |       -1.01e+05 |
# |  AverageTestEpRet |        -2.9e+04 |
# |      StdTestEpRet |        1.43e+04 |
# |      MaxTestEpRet |       -3.61e+03 |
# |      MinTestEpRet |       -4.67e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.74e+04 |
# |      AverageQVals |       -4.11e+04 |
# |          StdQVals |        1.28e+04 |
# |          MaxQVals |       -1.49e+04 |
# |          MinQVals |        -9.1e+04 |
# |            LossPi |        4.09e+04 |
# |             LossQ |        4.69e+05 |
# |              Time |             458 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |       -2.76e+04 |
# |          StdEpRet |        2.21e+04 |
# |          MaxEpRet |       -2.64e+03 |
# |          MinEpRet |        -8.2e+04 |
# |  AverageTestEpRet |       -2.39e+04 |
# |      StdTestEpRet |        1.81e+04 |
# |      MaxTestEpRet |       -4.86e+03 |
# |      MinTestEpRet |       -7.01e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.91e+04 |
# |      AverageQVals |       -4.07e+04 |
# |          StdQVals |        1.27e+04 |
# |          MaxQVals |       -1.47e+04 |
# |          MinQVals |       -8.86e+04 |
# |            LossPi |        4.05e+04 |
# |             LossQ |        4.76e+05 |
# |              Time |             467 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |       -2.96e+04 |
# |          StdEpRet |        2.19e+04 |
# |          MaxEpRet |            -942 |
# |          MinEpRet |        -8.9e+04 |
# |  AverageTestEpRet |        -3.5e+04 |
# |      StdTestEpRet |        2.53e+04 |
# |      MaxTestEpRet |       -5.93e+03 |
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              82 |
# |      AverageEpRet |       -2.29e+04 |
# |          StdEpRet |         1.4e+04 |
# |          MaxEpRet |       -2.43e+03 |
# |          MinEpRet |       -5.12e+04 |
# |  AverageTestEpRet |       -2.87e+04 |
# |      StdTestEpRet |        1.94e+04 |
# |      MaxTestEpRet |       -2.76e+03 |
# |      MinTestEpRet |       -6.78e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.35e+05 |
# |      AverageQVals |       -2.43e+04 |
# |          StdQVals |        8.59e+03 |
# |          MaxQVals |       -7.87e+03 |
# |          MinQVals |       -6.68e+04 |
# |            LossPi |        2.41e+04 |
# |             LossQ |        3.72e+05 |
# |              Time |             712 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              83 |
# |      AverageEpRet |       -2.04e+04 |
# |          StdEpRet |        1.36e+04 |
# |          MaxEpRet |            -262 |
# |          MinEpRet |       -4.74e+04 |
# |  AverageTestEpRet |       -1.78e+04 |
# |      StdTestEpRet |        9.73e+03 |
# |      MaxTestEpRet |       -1.69e+03 |
# |      MinTestEpRet |       -3.43e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.37e+05 |
# |      AverageQVals |       -2.38e+04 |
# |          StdQVals |        8.51e+03 |
# |          MaxQVals |       -7.59e+03 |
# |          MinQVals |       -6.46e+04 |
# |            LossPi |        2.36e+04 |
# |             LossQ |         3.6e+05 |
# |              Time |             721 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |       -1.98e+04 |
# |          StdEpRet |        9.93e+03 |
# |          MaxEpRet |       -1.89e+03 |
# |          MinEpRet |       -3.49e+04 |
# |  AverageTestEpRet |       -2.22e+04 |
# |      StdTestEpRet |        1.76e+04 |
# |      MaxTestEpRet |       -3.68e+03 |
# |      MinTestEpRet |        -5.6e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.39e+05 |
# |      AverageQVals |       -2.33e+04 |
# |          StdQVals |        8.37e+03 |
# |          MaxQVals |        -7.1e+03 |
# |          MinQVals |       -6.37e+04 |
# |            LossPi |        2.31e+04 |
# |             LossQ |        3.58e+05 |
# |              Time |             731 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |       -1.94e+04 |
# |          StdEpRet |        9.45e+03 |
# |          MaxEpRet |       -4.23e+03 |
# |          MinEpRet |       -4.05e+04 |
# |  AverageTestEpRet |       -2.88e+04 |
# |      StdTestEpRet |        1.61e+04 |
# |      MaxTestEpRet |       -1.13e+04 |
# |      MinTestEpRet |       -6.02e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.4e+05 |
# |      AverageQVals |       -2.28e+04 |
# |          StdQVals |        8.33e+03 |
# |          MaxQVals |       -7.08e+03 |
# |          MinQVals |       -6.24e+04 |
# |            LossPi |        2.26e+04 |
# |             LossQ |        3.58e+05 |
# |              Time |             741 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |          -2e+04 |
# |          StdEpRet |        1.34e+04 |
# |          MaxEpRet |            -599 |
# |          MinEpRet |       -4.31e+04 |
# |  AverageTestEpRet |       -3.56e+04 |
# |      StdTestEpRet |        2.78e+04 |
# |      MaxTestEpRet |       -6.93e+03 |
# |      MinTestEpRet |       -1.04e+05 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.42e+05 |
# |      AverageQVals |       -2.24e+04 |
# |          StdQVals |        8.23e+03 |
# |          MaxQVals |       -6.72e+03 |
# |          MinQVals |        -6.2e+04 |
# |            LossPi |        2.22e+04 |
# |             LossQ |        3.56e+05 |
# |              Time |             750 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |       -2.43e+04 |
# |          StdEpRet |        1.39e+04 |
# |          MaxEpRet |       -7.99e+03 |
# |          MinEpRet |       -5.57e+04 |
# |  AverageTestEpRet |       -1.71e+04 |
# |      StdTestEpRet |        1.01e+04 |
# |      MaxTestEpRet |       -1.87e+03 |
# |      MinTestEpRet |          -4e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.44e+05 |
# |      AverageQVals |       -2.19e+04 |
# |          StdQVals |        8.14e+03 |
# |          MaxQVals |       -6.16e+03 |
# |          MinQVals |       -6.11e+04 |
# |            LossPi |        2.17e+04 |
# |             LossQ |        3.45e+05 |
# |              Time |             760 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |       -1.81e+04 |
# |          StdEpRet |        9.39e+03 |
# |          MaxEpRet |       -4.95e+03 |
# |          MinEpRet |       -3.43e+04 |
# |  AverageTestEpRet |        -1.5e+04 |
# |      StdTestEpRet |        1.38e+04 |
# |      MaxTestEpRet |       -1.03e+03 |
# |      MinTestEpRet |       -4.33e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.45e+05 |
# |      AverageQVals |       -2.16e+04 |
# |          StdQVals |         8.1e+03 |
# |          MaxQVals |       -5.79e+03 |
# |          MinQVals |       -5.99e+04 |
# |            LossPi |        2.14e+04 |
# |             LossQ |        3.52e+05 |
# |              Time |             768 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |       -2.73e+04 |
# |          StdEpRet |        1.99e+04 |
# |          MaxEpRet |       -6.73e+03 |
# |          MinEpRet |       -8.11e+04 |
# |  AverageTestEpRet |       -2.31e+04 |
# |      StdTestEpRet |        1.45e+04 |
# |      MaxTestEpRet |            -795 |
# |      MinTestEpRet |       -5.15e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.47e+05 |
# |      AverageQVals |       -2.11e+04 |
# |          StdQVals |        8.05e+03 |
# |          MaxQVals |       -5.49e+03 |
# |          MinQVals |       -6.09e+04 |
# |            LossPi |        2.09e+04 |
# |             LossQ |        3.48e+05 |
# |              Time |             777 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |        -1.7e+04 |
# |          StdEpRet |        8.84e+03 |
# |          MaxEpRet |       -2.21e+03 |
# |          MinEpRet |       -3.84e+04 |
# |  AverageTestEpRet |       -1.68e+04 |
# |      StdTestEpRet |        5.92e+03 |
# |      MaxTestEpRet |       -8.94e+03 |
# |      MinTestEpRet |       -3.02e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+05 |
# |      AverageQVals |       -2.07e+04 |
# |          StdQVals |        7.98e+03 |
# |          MaxQVals |       -5.09e+03 |
# |          MinQVals |       -5.99e+04 |
# |            LossPi |        2.05e+04 |
# |             LossQ |        3.46e+05 |
# |              Time |             786 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |       -1.54e+04 |
# |          StdEpRet |        8.47e+03 |
# |          MaxEpRet |        -4.3e+03 |
# |          MinEpRet |       -3.63e+04 |
# |  AverageTestEpRet |       -1.79e+04 |
# |      StdTestEpRet |        1.28e+04 |
# |      MaxTestEpRet |        -4.3e+03 |
# |      MinTestEpRet |       -4.37e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.5e+05 |
# |      AverageQVals |       -2.04e+04 |
# |          StdQVals |        7.97e+03 |
# |          MaxQVals |       -4.86e+03 |
# |          MinQVals |       -5.98e+04 |
# |            LossPi |        2.02e+04 |
# |             LossQ |        3.41e+05 |
# |              Time |             796 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |       -2.11e+04 |
# |          StdEpRet |        1.46e+04 |
# |          MaxEpRet |       -1.89e+03 |
# |          MinEpRet |       -5.56e+04 |
# |  AverageTestEpRet |       -1.39e+04 |
# |      StdTestEpRet |         1.1e+04 |
# |      MaxTestEpRet |       -3.13e+03 |
# |      MinTestEpRet |       -4.22e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.52e+05 |
# |      AverageQVals |          -2e+04 |
# |          StdQVals |        7.94e+03 |
# |          MaxQVals |       -4.56e+03 |
# |          MinQVals |       -5.98e+04 |
# |            LossPi |        1.98e+04 |
# |             LossQ |        3.32e+05 |
# |              Time |             805 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |       -2.99e+04 |
# |          StdEpRet |        9.55e+03 |
# |          MaxEpRet |       -1.26e+04 |
# |          MinEpRet |       -4.65e+04 |
# |  AverageTestEpRet |       -2.68e+04 |
# |      StdTestEpRet |        1.29e+04 |
# |      MaxTestEpRet |       -1.18e+04 |
# |      MinTestEpRet |       -5.25e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.53e+05 |
# |      AverageQVals |       -1.98e+04 |
# |          StdQVals |        7.89e+03 |
# |          MaxQVals |       -4.44e+03 |
# |          MinQVals |       -5.94e+04 |
# |            LossPi |        1.96e+04 |
# |             LossQ |        3.36e+05 |
# |              Time |             814 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |       -1.83e+04 |
# |          StdEpRet |        9.07e+03 |
# |          MaxEpRet |       -5.98e+03 |
# |          MinEpRet |       -3.38e+04 |
# |  AverageTestEpRet |       -2.16e+04 |
# |      StdTestEpRet |        9.11e+03 |
# |      MaxTestEpRet |       -7.24e+03 |
# |      MinTestEpRet |       -3.87e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.55e+05 |
# |      AverageQVals |       -1.95e+04 |
# |          StdQVals |        7.89e+03 |
# |          MaxQVals |       -4.27e+03 |
# |          MinQVals |        -5.9e+04 |
# |            LossPi |        1.93e+04 |
# |             LossQ |        3.27e+05 |
# |              Time |             824 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |       -2.31e+04 |
# |          StdEpRet |        1.29e+04 |
# |          MaxEpRet |       -1.87e+03 |
# |          MinEpRet |       -4.58e+04 |
# |  AverageTestEpRet |       -2.21e+04 |
# |      StdTestEpRet |        1.73e+04 |
# |      MaxTestEpRet |       -7.92e+03 |
# |      MinTestEpRet |       -6.89e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.57e+05 |
# |      AverageQVals |       -1.92e+04 |
# |          StdQVals |        7.82e+03 |
# |          MaxQVals |       -4.13e+03 |
# |          MinQVals |        -5.9e+04 |
# |            LossPi |         1.9e+04 |
# |             LossQ |         3.3e+05 |
# |              Time |             832 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |       -2.02e+04 |
# |          StdEpRet |        1.07e+04 |
# |          MaxEpRet |       -3.14e+03 |
# |          MinEpRet |       -4.34e+04 |
# |  AverageTestEpRet |       -1.72e+04 |
# |      StdTestEpRet |        1.16e+04 |
# |      MaxTestEpRet |       -2.51e+03 |
# |      MinTestEpRet |       -3.37e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.58e+05 |
# |      AverageQVals |       -1.89e+04 |
# |          StdQVals |        7.82e+03 |
# |          MaxQVals |       -3.94e+03 |
# |          MinQVals |       -5.86e+04 |
# |            LossPi |        1.87e+04 |
# |             LossQ |        3.25e+05 |
# |              Time |             840 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |       -1.68e+04 |
# |          StdEpRet |        1.04e+04 |
# |          MaxEpRet |       -1.35e+03 |
# |          MinEpRet |       -4.25e+04 |
# |  AverageTestEpRet |       -1.24e+04 |
# |      StdTestEpRet |        8.46e+03 |
# |      MaxTestEpRet |       -2.48e+03 |
# |      MinTestEpRet |       -2.94e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.6e+05 |
# |      AverageQVals |       -1.86e+04 |
# |          StdQVals |        7.83e+03 |
# |          MaxQVals |       -3.65e+03 |
# |          MinQVals |       -5.81e+04 |
# |            LossPi |        1.84e+04 |
# |             LossQ |        3.15e+05 |
# |              Time |             849 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |       -2.37e+04 |
# |          StdEpRet |        1.11e+04 |
# |          MaxEpRet |       -8.26e+03 |
# |          MinEpRet |       -4.88e+04 |
# |  AverageTestEpRet |        -1.8e+04 |
# |      StdTestEpRet |        1.29e+04 |
# |      MaxTestEpRet |       -4.15e+03 |
# |      MinTestEpRet |       -4.52e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.62e+05 |
# |      AverageQVals |       -1.82e+04 |
# |          StdQVals |        7.85e+03 |
# |          MaxQVals |       -3.46e+03 |
# |          MinQVals |       -5.81e+04 |
# |            LossPi |         1.8e+04 |
# |             LossQ |        3.13e+05 |
# |              Time |             857 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |       -2.01e+04 |
# |          StdEpRet |        1.05e+04 |
# |          MaxEpRet |       -6.37e+03 |
# |          MinEpRet |       -3.93e+04 |
# |  AverageTestEpRet |       -2.32e+04 |
# |      StdTestEpRet |        8.22e+03 |
# |      MaxTestEpRet |       -6.61e+03 |
# |      MinTestEpRet |       -3.42e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.63e+05 |
# |      AverageQVals |       -1.79e+04 |
# |          StdQVals |        7.85e+03 |
# |          MaxQVals |       -3.44e+03 |
# |          MinQVals |       -5.77e+04 |
# |            LossPi |        1.77e+04 |
# |             LossQ |        3.09e+05 |
# |              Time |             867 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             100 |
# |      AverageEpRet |       -1.73e+04 |
# |          StdEpRet |        1.46e+04 |
# |          MaxEpRet |            -447 |
# |          MinEpRet |        -5.2e+04 |
# |  AverageTestEpRet |       -1.61e+04 |
# |      StdTestEpRet |        6.47e+03 |
# |      MaxTestEpRet |        -6.1e+03 |
# |      MinTestEpRet |       -2.64e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+05 |
# |      AverageQVals |       -1.76e+04 |
# |          StdQVals |        7.88e+03 |
# |          MaxQVals |       -3.16e+03 |
# |          MinQVals |        -5.8e+04 |
# |            LossPi |        1.74e+04 |
# |             LossQ |        3.06e+05 |
# |              Time |             877 |
# ---------------------------------------

# %% [markdown]
# #### Quadratic reward with penalty

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='ddpg_q_p', exp_name='ddpg_q_p')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0025
qlr_b = 0.0025

# Env function
reward_args = {'qx1':9,'qx2':0.05,'qx3':9,'qx4':0.05,'pu1':0.25,'pu2':0.25, 'bound': 0.2,'penalty':40}
env_fn = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Quadratic with penalty', reward_args = reward_args,ep_len=maxeplen_b)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Warning: Log dir ddpg_q_p already exists! Storing info there anyway.
# Logging data to ddpg_q_p/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(<function env_fn at 0x7f76de14bea0>, env_name='gyroscopeenv-v0', reward_type='Quadratic', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Absolute', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.5, 'pu2': 0.5}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.1, 'pu1': 0.25, 'pu2': 0.25}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with ending penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1, 'sx1': 100, 'sx3': 100, 'end_horizon': 1}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.25, 'pu2': 0.25, 'bound': 0.2, 'penalty': 40}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.25, 'pu2': 0.25, 'bound': 0.2, 'penalty': 40}, ep_len=110)",
#     "epochs":	100,
#     "exp_name":	"ddpg_q_p",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f76a96e1ac8>":	{
#             "epoch_dict":	{},
#             "exp_name":	"ddpg_q_p",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_q_p",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_q_p/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"ddpg_q_p",
#         "output_dir":	"ddpg_q_p"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0025,
#     "polyak":	0.995,
#     "q_lr":	0.0025,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 4802, 	 q: 5201
# /home/matthieulc/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |       -1.05e+04 |
# |          StdEpRet |        1.99e+03 |
# |          MaxEpRet |       -7.27e+03 |
# |          MinEpRet |       -1.41e+04 |
# |  AverageTestEpRet |       -1.24e+04 |
# |      StdTestEpRet |        2.68e+03 |
# |      MaxTestEpRet |       -8.31e+03 |
# |      MinTestEpRet |       -1.66e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |      AverageQVals |            -154 |
# |          StdQVals |            85.5 |
# |          MaxQVals |            0.21 |
# |          MinQVals |            -443 |
# |            LossPi |             149 |
# |             LossQ |        2.03e+03 |
# |              Time |            5.04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |       -1.16e+04 |
# |          StdEpRet |        2.69e+03 |
# |          MaxEpRet |       -6.87e+03 |
# |          MinEpRet |       -1.56e+04 |
# |  AverageTestEpRet |       -9.93e+03 |
# |      StdTestEpRet |        2.54e+03 |
# |      MaxTestEpRet |       -6.55e+03 |
# |      MinTestEpRet |       -1.45e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |      AverageQVals |            -601 |
# |          StdQVals |             224 |
# |          MaxQVals |            -133 |
# |          MinQVals |       -1.44e+03 |
# |            LossPi |             587 |
# |             LossQ |        1.13e+03 |
# |              Time |              15 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |       -1.15e+04 |
# |          StdEpRet |        1.68e+03 |
# |          MaxEpRet |       -8.55e+03 |
# |          MinEpRet |       -1.39e+04 |
# |  AverageTestEpRet |       -8.08e+03 |
# |      StdTestEpRet |         3.1e+03 |
# |      MaxTestEpRet |       -5.35e+03 |
# |      MinTestEpRet |       -1.58e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |      AverageQVals |       -1.22e+03 |
# |          StdQVals |             286 |
# |          MaxQVals |            -476 |
# |          MinQVals |       -2.38e+03 |
# |            LossPi |         1.2e+03 |
# |             LossQ |        2.13e+03 |
# |              Time |            25.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |       -1.08e+04 |
# |          StdEpRet |        1.69e+03 |
# |          MaxEpRet |       -8.31e+03 |
# |          MinEpRet |        -1.4e+04 |
# |  AverageTestEpRet |       -8.92e+03 |
# |      StdTestEpRet |        4.41e+03 |
# |      MaxTestEpRet |       -1.21e+03 |
# |      MinTestEpRet |       -1.69e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |      AverageQVals |        -1.8e+03 |
# |          StdQVals |             336 |
# |          MaxQVals |            -932 |
# |          MinQVals |       -3.17e+03 |
# |            LossPi |        1.78e+03 |
# |             LossQ |        2.84e+03 |
# |              Time |            34.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |       -9.82e+03 |
# |          StdEpRet |        1.78e+03 |
# |          MaxEpRet |       -7.65e+03 |
# |          MinEpRet |       -1.38e+04 |
# |  AverageTestEpRet |       -6.41e+03 |
# |      StdTestEpRet |        1.36e+03 |
# |      MaxTestEpRet |       -4.57e+03 |
# |      MinTestEpRet |       -8.79e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |      AverageQVals |       -2.29e+03 |
# |          StdQVals |             384 |
# |          MaxQVals |       -1.38e+03 |
# |          MinQVals |       -3.91e+03 |
# |            LossPi |        2.26e+03 |
# |             LossQ |        3.46e+03 |
# |              Time |            44.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |       -1.19e+04 |
# |          StdEpRet |        1.97e+03 |
# |          MaxEpRet |       -8.24e+03 |
# |          MinEpRet |       -1.49e+04 |
# |  AverageTestEpRet |       -6.61e+03 |
# |      StdTestEpRet |        2.01e+03 |
# |      MaxTestEpRet |       -4.61e+03 |
# |      MinTestEpRet |       -1.15e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |      AverageQVals |       -2.73e+03 |
# |          StdQVals |             421 |
# |          MaxQVals |       -1.74e+03 |
# |          MinQVals |       -4.67e+03 |
# |            LossPi |        2.69e+03 |
# |             LossQ |        3.72e+03 |
# |              Time |            53.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |       -6.58e+03 |
# |          StdEpRet |        1.52e+03 |
# |          MaxEpRet |       -4.81e+03 |
# |          MinEpRet |          -1e+04 |
# |  AverageTestEpRet |       -5.88e+03 |
# |      StdTestEpRet |             653 |
# |      MaxTestEpRet |       -4.68e+03 |
# |      MinTestEpRet |       -6.81e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |      AverageQVals |       -3.09e+03 |
# |          StdQVals |             459 |
# |          MaxQVals |          -2e+03 |
# |          MinQVals |       -5.21e+03 |
# |            LossPi |        3.05e+03 |
# |             LossQ |        3.44e+03 |
# |              Time |            63.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |       -6.34e+03 |
# |          StdEpRet |        1.85e+03 |
# |          MaxEpRet |       -3.46e+03 |
# |          MinEpRet |       -1.15e+04 |
# |  AverageTestEpRet |       -5.97e+03 |
# |      StdTestEpRet |             755 |
# |      MaxTestEpRet |       -4.88e+03 |
# |      MinTestEpRet |       -7.77e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |      AverageQVals |       -3.38e+03 |
# |          StdQVals |             502 |
# |          MaxQVals |       -2.24e+03 |
# |          MinQVals |       -5.72e+03 |
# |            LossPi |        3.35e+03 |
# |             LossQ |        3.11e+03 |
# |              Time |            73.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |       -5.94e+03 |
# |          StdEpRet |        1.23e+03 |
# |          MaxEpRet |        -2.8e+03 |
# |          MinEpRet |       -7.82e+03 |
# |  AverageTestEpRet |       -6.43e+03 |
# |      StdTestEpRet |        1.05e+03 |
# |      MaxTestEpRet |       -5.24e+03 |
# |      MinTestEpRet |        -7.9e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |      AverageQVals |       -3.66e+03 |
# |          StdQVals |             531 |
# |          MaxQVals |       -2.47e+03 |
# |          MinQVals |       -6.17e+03 |
# |            LossPi |        3.63e+03 |
# |             LossQ |        2.98e+03 |
# |              Time |            85.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |       -5.81e+03 |
# |          StdEpRet |        1.08e+03 |
# |          MaxEpRet |       -4.72e+03 |
# |          MinEpRet |        -8.1e+03 |
# |  AverageTestEpRet |       -5.47e+03 |
# |      StdTestEpRet |        1.66e+03 |
# |      MaxTestEpRet |       -1.57e+03 |
# |      MinTestEpRet |       -8.52e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |        -3.9e+03 |
# |          StdQVals |             560 |
# |          MaxQVals |       -2.64e+03 |
# |          MinQVals |       -6.54e+03 |
# |            LossPi |        3.87e+03 |
# |             LossQ |        2.84e+03 |
# |              Time |            95.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |       -6.31e+03 |
# |          StdEpRet |         2.3e+03 |
# |          MaxEpRet |       -2.35e+03 |
# |          MinEpRet |       -1.03e+04 |
# |  AverageTestEpRet |       -6.57e+03 |
# |      StdTestEpRet |        2.21e+03 |
# |      MaxTestEpRet |       -4.66e+03 |
# |      MinTestEpRet |        -1.2e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |      AverageQVals |       -4.11e+03 |
# |          StdQVals |             586 |
# |          MaxQVals |       -2.89e+03 |
# |          MinQVals |       -6.85e+03 |
# |            LossPi |        4.08e+03 |
# |             LossQ |        2.74e+03 |
# |              Time |             105 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |       -6.22e+03 |
# |          StdEpRet |        1.03e+03 |
# |          MaxEpRet |       -4.73e+03 |
# |          MinEpRet |       -8.53e+03 |
# |  AverageTestEpRet |       -6.52e+03 |
# |      StdTestEpRet |        1.08e+03 |
# |      MaxTestEpRet |       -4.47e+03 |
# |      MinTestEpRet |       -8.02e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |      AverageQVals |       -4.33e+03 |
# |          StdQVals |             605 |
# |          MaxQVals |       -3.12e+03 |
# |          MinQVals |       -7.15e+03 |
# |            LossPi |         4.3e+03 |
# |             LossQ |        2.65e+03 |
# |              Time |             116 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |       -5.19e+03 |
# |          StdEpRet |         1.6e+03 |
# |          MaxEpRet |            -817 |
# |          MinEpRet |       -7.78e+03 |
# |  AverageTestEpRet |       -5.12e+03 |
# |      StdTestEpRet |             663 |
# |      MaxTestEpRet |       -4.13e+03 |
# |      MinTestEpRet |       -6.37e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |      AverageQVals |       -4.53e+03 |
# |          StdQVals |             617 |
# |          MaxQVals |       -3.34e+03 |
# |          MinQVals |       -7.52e+03 |
# |            LossPi |         4.5e+03 |
# |             LossQ |        2.62e+03 |
# |              Time |             126 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |       -6.15e+03 |
# |          StdEpRet |        1.24e+03 |
# |          MaxEpRet |       -4.47e+03 |
# |          MinEpRet |       -8.47e+03 |
# |  AverageTestEpRet |       -6.45e+03 |
# |      StdTestEpRet |        1.51e+03 |
# |      MaxTestEpRet |       -4.46e+03 |
# |      MinTestEpRet |       -8.88e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |      AverageQVals |       -4.72e+03 |
# |          StdQVals |             626 |
# |          MaxQVals |       -3.48e+03 |
# |          MinQVals |       -7.82e+03 |
# |            LossPi |        4.69e+03 |
# |             LossQ |        2.61e+03 |
# |              Time |             138 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |        -5.5e+03 |
# |          StdEpRet |        2.26e+03 |
# |          MaxEpRet |       -1.51e+03 |
# |          MinEpRet |       -1.08e+04 |
# |  AverageTestEpRet |       -6.45e+03 |
# |      StdTestEpRet |         1.5e+03 |
# |      MaxTestEpRet |       -4.92e+03 |
# |      MinTestEpRet |       -9.19e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |      AverageQVals |       -4.89e+03 |
# |          StdQVals |             637 |
# |          MaxQVals |       -3.62e+03 |
# |          MinQVals |       -8.11e+03 |
# |            LossPi |        4.87e+03 |
# |             LossQ |        2.54e+03 |
# |              Time |             150 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |       -5.92e+03 |
# |          StdEpRet |             988 |
# |          MaxEpRet |       -4.62e+03 |
# |          MinEpRet |       -8.15e+03 |
# |  AverageTestEpRet |        -5.8e+03 |
# |      StdTestEpRet |        1.49e+03 |
# |      MaxTestEpRet |       -2.31e+03 |
# |      MinTestEpRet |        -7.9e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |      AverageQVals |       -5.04e+03 |
# |          StdQVals |             639 |
# |          MaxQVals |       -3.74e+03 |
# |          MinQVals |       -8.33e+03 |
# |            LossPi |        5.01e+03 |
# |             LossQ |        2.47e+03 |
# |              Time |             163 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |       -6.06e+03 |
# |          StdEpRet |        1.32e+03 |
# |          MaxEpRet |       -4.16e+03 |
# |          MinEpRet |        -9.1e+03 |
# |  AverageTestEpRet |        -5.6e+03 |
# |      StdTestEpRet |        1.77e+03 |
# |      MaxTestEpRet |            -910 |
# |      MinTestEpRet |       -7.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |      AverageQVals |       -5.17e+03 |
# |          StdQVals |             653 |
# |          MaxQVals |       -3.86e+03 |
# |          MinQVals |       -8.53e+03 |
# |            LossPi |        5.15e+03 |
# |             LossQ |         2.4e+03 |
# |              Time |             174 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |       -5.79e+03 |
# |          StdEpRet |        2.13e+03 |
# |          MaxEpRet |       -1.35e+03 |
# |          MinEpRet |       -9.33e+03 |
# |  AverageTestEpRet |       -6.27e+03 |
# |      StdTestEpRet |         2.1e+03 |
# |      MaxTestEpRet |       -1.33e+03 |
# |      MinTestEpRet |       -8.66e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |      AverageQVals |       -5.31e+03 |
# |          StdQVals |             674 |
# |          MaxQVals |       -3.98e+03 |
# |          MinQVals |       -8.74e+03 |
# |            LossPi |        5.28e+03 |
# |             LossQ |        2.37e+03 |
# |              Time |             186 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |       -5.68e+03 |
# |          StdEpRet |        1.55e+03 |
# |          MaxEpRet |       -2.53e+03 |
# |          MinEpRet |       -8.09e+03 |
# |  AverageTestEpRet |       -5.09e+03 |
# |      StdTestEpRet |        1.09e+03 |
# |      MaxTestEpRet |       -2.03e+03 |
# |      MinTestEpRet |       -5.99e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |      AverageQVals |       -5.44e+03 |
# |          StdQVals |             684 |
# |          MaxQVals |       -4.08e+03 |
# |          MinQVals |       -8.85e+03 |
# |            LossPi |        5.41e+03 |
# |             LossQ |        2.33e+03 |
# |              Time |             198 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |       -6.09e+03 |
# |          StdEpRet |        2.26e+03 |
# |          MaxEpRet |            -832 |
# |          MinEpRet |       -1.08e+04 |
# |  AverageTestEpRet |       -5.47e+03 |
# |      StdTestEpRet |             713 |
# |      MaxTestEpRet |       -4.28e+03 |
# |      MinTestEpRet |       -6.53e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |       -5.56e+03 |
# |          StdQVals |             703 |
# |          MaxQVals |       -4.18e+03 |
# |          MinQVals |       -9.17e+03 |
# |            LossPi |        5.54e+03 |
# |             LossQ |        2.34e+03 |
# |              Time |             209 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |       -5.32e+03 |
# |          StdEpRet |        1.75e+03 |
# |          MaxEpRet |       -1.46e+03 |
# |          MinEpRet |       -9.76e+03 |
# |  AverageTestEpRet |       -5.55e+03 |
# |      StdTestEpRet |        1.52e+03 |
# |      MaxTestEpRet |       -2.03e+03 |
# |      MinTestEpRet |       -7.65e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |      AverageQVals |       -5.67e+03 |
# |          StdQVals |             704 |
# |          MaxQVals |       -4.29e+03 |
# |          MinQVals |       -9.36e+03 |
# |            LossPi |        5.65e+03 |
# |             LossQ |        2.28e+03 |
# |              Time |             223 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |       -6.46e+03 |
# |          StdEpRet |        1.44e+03 |
# |          MaxEpRet |       -3.19e+03 |
# |          MinEpRet |       -9.77e+03 |
# |  AverageTestEpRet |       -5.64e+03 |
# |      StdTestEpRet |             788 |
# |      MaxTestEpRet |       -4.82e+03 |
# |      MinTestEpRet |       -7.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |      AverageQVals |       -5.77e+03 |
# |          StdQVals |             706 |
# |          MaxQVals |       -4.41e+03 |
# |          MinQVals |        -9.5e+03 |
# |            LossPi |        5.75e+03 |
# |             LossQ |        2.29e+03 |
# |              Time |             238 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |       -5.17e+03 |
# |          StdEpRet |             938 |
# |          MaxEpRet |       -3.32e+03 |
# |          MinEpRet |       -7.68e+03 |
# |  AverageTestEpRet |       -5.47e+03 |
# |      StdTestEpRet |             837 |
# |      MaxTestEpRet |       -3.18e+03 |
# |      MinTestEpRet |       -6.37e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |      AverageQVals |       -5.86e+03 |
# |          StdQVals |             711 |
# |          MaxQVals |        -4.5e+03 |
# |          MinQVals |       -9.61e+03 |
# |            LossPi |        5.84e+03 |
# |             LossQ |        2.26e+03 |
# |              Time |             249 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |       -5.11e+03 |
# |          StdEpRet |        1.15e+03 |
# |          MaxEpRet |       -2.54e+03 |
# |          MinEpRet |       -7.58e+03 |
# |  AverageTestEpRet |       -5.74e+03 |
# |      StdTestEpRet |             907 |
# |      MaxTestEpRet |       -4.61e+03 |
# |      MinTestEpRet |       -7.72e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |      AverageQVals |       -5.95e+03 |
# |          StdQVals |             717 |
# |          MaxQVals |       -4.62e+03 |
# |          MinQVals |       -9.75e+03 |
# |            LossPi |        5.93e+03 |
# |             LossQ |        2.24e+03 |
# |              Time |             260 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |       -5.45e+03 |
# |          StdEpRet |        1.02e+03 |
# |          MaxEpRet |       -3.18e+03 |
# |          MinEpRet |       -7.56e+03 |
# |  AverageTestEpRet |       -5.78e+03 |
# |      StdTestEpRet |        1.66e+03 |
# |      MaxTestEpRet |       -1.06e+03 |
# |      MinTestEpRet |       -7.07e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |      AverageQVals |       -6.03e+03 |
# |          StdQVals |             725 |
# |          MaxQVals |        -4.7e+03 |
# |          MinQVals |       -9.85e+03 |
# |            LossPi |        6.01e+03 |
# |             LossQ |        2.23e+03 |
# |              Time |             270 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |       -6.11e+03 |
# |          StdEpRet |        1.44e+03 |
# |          MaxEpRet |       -4.65e+03 |
# |          MinEpRet |       -1.08e+04 |
# |  AverageTestEpRet |       -5.59e+03 |
# |      StdTestEpRet |        1.61e+03 |
# |      MaxTestEpRet |       -1.78e+03 |
# |      MinTestEpRet |       -7.59e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |      AverageQVals |        -6.1e+03 |
# |          StdQVals |             739 |
# |          MaxQVals |        -4.8e+03 |
# |          MinQVals |          -1e+04 |
# |            LossPi |        6.07e+03 |
# |             LossQ |        2.22e+03 |
# |              Time |             280 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |       -6.38e+03 |
# |          StdEpRet |        1.27e+03 |
# |          MaxEpRet |       -4.48e+03 |
# |          MinEpRet |       -9.72e+03 |
# |  AverageTestEpRet |       -5.83e+03 |
# |      StdTestEpRet |        1.64e+03 |
# |      MaxTestEpRet |       -1.68e+03 |
# |      MinTestEpRet |       -8.27e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |      AverageQVals |       -6.17e+03 |
# |          StdQVals |             749 |
# |          MaxQVals |       -4.87e+03 |
# |          MinQVals |       -1.01e+04 |
# |            LossPi |        6.15e+03 |
# |             LossQ |        2.27e+03 |
# |              Time |             291 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |       -5.76e+03 |
# |          StdEpRet |        2.19e+03 |
# |          MaxEpRet |       -1.91e+03 |
# |          MinEpRet |       -1.21e+04 |
# |  AverageTestEpRet |       -5.97e+03 |
# |      StdTestEpRet |             696 |
# |      MaxTestEpRet |       -5.07e+03 |
# |      MinTestEpRet |       -7.65e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |      AverageQVals |       -6.24e+03 |
# |          StdQVals |             756 |
# |          MaxQVals |       -4.93e+03 |
# |          MinQVals |       -1.02e+04 |
# |            LossPi |        6.22e+03 |
# |             LossQ |        2.26e+03 |
# |              Time |             303 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |       -6.07e+03 |
# |          StdEpRet |        1.69e+03 |
# |          MaxEpRet |       -1.66e+03 |
# |          MinEpRet |       -9.59e+03 |
# |  AverageTestEpRet |       -6.65e+03 |
# |      StdTestEpRet |        1.37e+03 |
# |      MaxTestEpRet |       -5.07e+03 |
# |      MinTestEpRet |       -9.57e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |      AverageQVals |        -6.3e+03 |
# |          StdQVals |             755 |
# |          MaxQVals |       -4.97e+03 |
# |          MinQVals |       -1.03e+04 |
# |            LossPi |        6.28e+03 |
# |             LossQ |        2.21e+03 |
# |              Time |             316 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |       -6.15e+03 |
# |          StdEpRet |        1.07e+03 |
# |          MaxEpRet |       -4.93e+03 |
# |          MinEpRet |       -8.27e+03 |
# |  AverageTestEpRet |       -5.83e+03 |
# |      StdTestEpRet |             893 |
# |      MaxTestEpRet |       -4.89e+03 |
# |      MinTestEpRet |       -7.86e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |       -6.36e+03 |
# |          StdQVals |             759 |
# |          MaxQVals |       -5.05e+03 |
# |          MinQVals |       -1.03e+04 |
# |            LossPi |        6.34e+03 |
# |             LossQ |        2.15e+03 |
# |              Time |             327 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |       -5.41e+03 |
# |          StdEpRet |         1.5e+03 |
# |          MaxEpRet |       -1.43e+03 |
# |          MinEpRet |          -8e+03 |
# |  AverageTestEpRet |        -5.7e+03 |
# |      StdTestEpRet |        1.21e+03 |
# |      MaxTestEpRet |       -4.69e+03 |
# |      MinTestEpRet |       -8.87e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |      AverageQVals |       -6.43e+03 |
# |          StdQVals |             774 |
# |          MaxQVals |       -5.05e+03 |
# |          MinQVals |       -1.04e+04 |
# |            LossPi |        6.41e+03 |
# |             LossQ |        2.15e+03 |
# |              Time |             337 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |       -6.02e+03 |
# |          StdEpRet |        1.02e+03 |
# |          MaxEpRet |        -4.9e+03 |
# |          MinEpRet |       -8.24e+03 |
# |  AverageTestEpRet |       -5.07e+03 |
# |      StdTestEpRet |        1.55e+03 |
# |      MaxTestEpRet |            -907 |
# |      MinTestEpRet |       -6.83e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |      AverageQVals |       -6.49e+03 |
# |          StdQVals |             788 |
# |          MaxQVals |        -5.1e+03 |
# |          MinQVals |       -1.05e+04 |
# |            LossPi |        6.47e+03 |
# |             LossQ |         2.1e+03 |
# |              Time |             347 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |       -5.83e+03 |
# |          StdEpRet |        1.35e+03 |
# |          MaxEpRet |       -4.28e+03 |
# |          MinEpRet |       -9.27e+03 |
# |  AverageTestEpRet |       -5.35e+03 |
# |      StdTestEpRet |        2.45e+03 |
# |      MaxTestEpRet |       -2.17e+03 |
# |      MinTestEpRet |       -1.18e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |      AverageQVals |       -6.54e+03 |
# |          StdQVals |             800 |
# |          MaxQVals |       -5.14e+03 |
# |          MinQVals |       -1.06e+04 |
# |            LossPi |        6.52e+03 |
# |             LossQ |        2.04e+03 |
# |              Time |             358 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |       -5.16e+03 |
# |          StdEpRet |        2.06e+03 |
# |          MaxEpRet |            -412 |
# |          MinEpRet |       -9.56e+03 |
# |  AverageTestEpRet |       -5.98e+03 |
# |      StdTestEpRet |        1.03e+03 |
# |      MaxTestEpRet |       -4.69e+03 |
# |      MinTestEpRet |       -8.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |      AverageQVals |        -6.6e+03 |
# |          StdQVals |             808 |
# |          MaxQVals |       -5.16e+03 |
# |          MinQVals |       -1.07e+04 |
# |            LossPi |        6.58e+03 |
# |             LossQ |        1.99e+03 |
# |              Time |             368 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |       -5.39e+03 |
# |          StdEpRet |        1.76e+03 |
# |          MaxEpRet |       -1.43e+03 |
# |          MinEpRet |       -9.09e+03 |
# |  AverageTestEpRet |       -5.98e+03 |
# |      StdTestEpRet |        1.28e+03 |
# |      MaxTestEpRet |       -4.21e+03 |
# |      MinTestEpRet |       -8.56e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |      AverageQVals |       -6.64e+03 |
# |          StdQVals |             816 |
# |          MaxQVals |       -5.21e+03 |
# |          MinQVals |       -1.07e+04 |
# |            LossPi |        6.63e+03 |
# |             LossQ |        1.98e+03 |
# |              Time |             380 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |       -5.99e+03 |
# |          StdEpRet |        1.58e+03 |
# |          MaxEpRet |        -2.3e+03 |
# |          MinEpRet |       -8.38e+03 |
# |  AverageTestEpRet |       -4.98e+03 |
# |      StdTestEpRet |        1.53e+03 |
# |      MaxTestEpRet |            -738 |
# |      MinTestEpRet |       -6.44e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |      AverageQVals |        -6.7e+03 |
# |          StdQVals |             831 |
# |          MaxQVals |       -5.25e+03 |
# |          MinQVals |       -1.08e+04 |
# |            LossPi |        6.68e+03 |
# |             LossQ |        1.97e+03 |
# |              Time |             391 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |       -5.88e+03 |
# |          StdEpRet |             851 |
# |          MaxEpRet |       -3.45e+03 |
# |          MinEpRet |       -7.23e+03 |
# |  AverageTestEpRet |       -6.18e+03 |
# |      StdTestEpRet |             713 |
# |      MaxTestEpRet |       -5.21e+03 |
# |      MinTestEpRet |       -7.15e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |      AverageQVals |       -6.74e+03 |
# |          StdQVals |             841 |
# |          MaxQVals |       -5.28e+03 |
# |          MinQVals |       -1.09e+04 |
# |            LossPi |        6.72e+03 |
# |             LossQ |        1.99e+03 |
# |              Time |             403 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |       -5.03e+03 |
# |          StdEpRet |        1.65e+03 |
# |          MaxEpRet |       -1.75e+03 |
# |          MinEpRet |       -7.62e+03 |
# |  AverageTestEpRet |       -4.44e+03 |
# |      StdTestEpRet |        1.87e+03 |
# |      MaxTestEpRet |            -699 |
# |      MinTestEpRet |       -6.04e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |      AverageQVals |       -6.78e+03 |
# |          StdQVals |             852 |
# |          MaxQVals |       -5.35e+03 |
# |          MinQVals |       -1.09e+04 |
# |            LossPi |        6.76e+03 |
# |             LossQ |        1.97e+03 |
# |              Time |             413 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |       -5.39e+03 |
# |          StdEpRet |        1.64e+03 |
# |          MaxEpRet |            -748 |
# |          MinEpRet |        -8.8e+03 |
# |  AverageTestEpRet |       -5.25e+03 |
# |      StdTestEpRet |        2.36e+03 |
# |      MaxTestEpRet |            -587 |
# |      MinTestEpRet |       -8.13e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |      AverageQVals |        -6.8e+03 |
# |          StdQVals |             867 |
# |          MaxQVals |       -5.27e+03 |
# |          MinQVals |        -1.1e+04 |
# |            LossPi |        6.78e+03 |
# |             LossQ |        1.98e+03 |
# |              Time |             424 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |       -6.19e+03 |
# |          StdEpRet |        1.46e+03 |
# |          MaxEpRet |       -3.21e+03 |
# |          MinEpRet |       -8.73e+03 |
# |  AverageTestEpRet |       -6.06e+03 |
# |      StdTestEpRet |        1.08e+03 |
# |      MaxTestEpRet |       -4.85e+03 |
# |      MinTestEpRet |       -8.78e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |       -6.83e+03 |
# |          StdQVals |             878 |
# |          MaxQVals |       -5.27e+03 |
# |          MinQVals |        -1.1e+04 |
# |            LossPi |        6.82e+03 |
# |             LossQ |        1.99e+03 |
# |              Time |             434 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |        -6.1e+03 |
# |          StdEpRet |        1.08e+03 |
# |          MaxEpRet |       -4.54e+03 |
# |          MinEpRet |       -8.53e+03 |
# |  AverageTestEpRet |       -5.56e+03 |
# |      StdTestEpRet |             568 |
# |      MaxTestEpRet |       -4.78e+03 |
# |      MinTestEpRet |       -6.51e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |      AverageQVals |       -6.87e+03 |
# |          StdQVals |             891 |
# |          MaxQVals |       -5.25e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |        6.85e+03 |
# |             LossQ |           2e+03 |
# |              Time |             445 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |       -5.71e+03 |
# |          StdEpRet |             899 |
# |          MaxEpRet |       -4.11e+03 |
# |          MinEpRet |       -7.19e+03 |
# |  AverageTestEpRet |       -5.95e+03 |
# |      StdTestEpRet |             619 |
# |      MaxTestEpRet |       -5.16e+03 |
# |      MinTestEpRet |        -7.1e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |      AverageQVals |       -6.89e+03 |
# |          StdQVals |             901 |
# |          MaxQVals |       -5.25e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |        6.88e+03 |
# |             LossQ |        1.97e+03 |
# |              Time |             456 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |       -5.48e+03 |
# |          StdEpRet |        1.51e+03 |
# |          MaxEpRet |       -2.01e+03 |
# |          MinEpRet |       -8.36e+03 |
# |  AverageTestEpRet |       -4.51e+03 |
# |      StdTestEpRet |        1.94e+03 |
# |      MaxTestEpRet |            -256 |
# |      MinTestEpRet |       -6.41e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |      AverageQVals |       -6.91e+03 |
# |          StdQVals |             907 |
# |          MaxQVals |       -5.24e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |        6.89e+03 |
# |             LossQ |        2.01e+03 |
# |              Time |             467 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |       -5.23e+03 |
# |          StdEpRet |        1.31e+03 |
# |          MaxEpRet |       -2.06e+03 |
# |          MinEpRet |       -7.69e+03 |
# |  AverageTestEpRet |       -5.51e+03 |
# |      StdTestEpRet |        1.62e+03 |
# |      MaxTestEpRet |       -1.29e+03 |
# |      MinTestEpRet |        -7.3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |      AverageQVals |       -6.92e+03 |
# |          StdQVals |             917 |
# |          MaxQVals |       -5.23e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |         6.9e+03 |
# |             LossQ |        1.94e+03 |
# |              Time |             478 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |       -6.02e+03 |
# |          StdEpRet |        2.03e+03 |
# |          MaxEpRet |       -4.54e+03 |
# |          MinEpRet |        -1.3e+04 |
# |  AverageTestEpRet |       -6.57e+03 |
# |      StdTestEpRet |        1.54e+03 |
# |      MaxTestEpRet |       -4.71e+03 |
# |      MinTestEpRet |       -9.88e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |      AverageQVals |       -6.94e+03 |
# |          StdQVals |             925 |
# |          MaxQVals |       -5.26e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |        6.92e+03 |
# |             LossQ |        1.95e+03 |
# |              Time |             489 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |       -5.88e+03 |
# |          StdEpRet |        1.43e+03 |
# |          MaxEpRet |       -3.93e+03 |
# |          MinEpRet |       -9.43e+03 |
# |  AverageTestEpRet |       -4.94e+03 |
# |      StdTestEpRet |        1.42e+03 |
# |      MaxTestEpRet |            -991 |
# |      MinTestEpRet |       -6.38e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |      AverageQVals |       -6.95e+03 |
# |          StdQVals |             939 |
# |          MaxQVals |       -5.25e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |        6.93e+03 |
# |             LossQ |         1.9e+03 |
# |              Time |             499 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |       -5.05e+03 |
# |          StdEpRet |        1.03e+03 |
# |          MaxEpRet |       -1.82e+03 |
# |          MinEpRet |       -6.16e+03 |
# |  AverageTestEpRet |       -4.87e+03 |
# |      StdTestEpRet |        1.93e+03 |
# |      MaxTestEpRet |            -971 |
# |      MinTestEpRet |       -7.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.75e+04 |
# |      AverageQVals |       -6.97e+03 |
# |          StdQVals |             948 |
# |          MaxQVals |       -5.25e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |        6.95e+03 |
# |             LossQ |        1.89e+03 |
# |              Time |             510 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |       -5.66e+03 |
# |          StdEpRet |        1.56e+03 |
# |          MaxEpRet |       -2.08e+03 |
# |          MinEpRet |       -8.39e+03 |
# |  AverageTestEpRet |       -6.33e+03 |
# |      StdTestEpRet |        1.33e+03 |
# |      MaxTestEpRet |       -4.27e+03 |
# |      MinTestEpRet |       -8.43e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.92e+04 |
# |      AverageQVals |       -6.98e+03 |
# |          StdQVals |             956 |
# |          MaxQVals |       -5.25e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |        6.96e+03 |
# |             LossQ |        1.85e+03 |
# |              Time |             520 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |       -5.65e+03 |
# |          StdEpRet |        2.03e+03 |
# |          MaxEpRet |       -1.99e+03 |
# |          MinEpRet |       -9.74e+03 |
# |  AverageTestEpRet |       -6.47e+03 |
# |      StdTestEpRet |        1.64e+03 |
# |      MaxTestEpRet |       -4.78e+03 |
# |      MinTestEpRet |       -1.09e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+04 |
# |      AverageQVals |       -6.98e+03 |
# |          StdQVals |             964 |
# |          MaxQVals |       -5.24e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |        6.96e+03 |
# |             LossQ |        1.82e+03 |
# |              Time |             530 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |       -5.18e+03 |
# |          StdEpRet |             585 |
# |          MaxEpRet |       -4.58e+03 |
# |          MinEpRet |       -6.32e+03 |
# |  AverageTestEpRet |       -5.45e+03 |
# |      StdTestEpRet |             451 |
# |      MaxTestEpRet |       -4.58e+03 |
# |      MinTestEpRet |       -5.95e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |       -6.98e+03 |
# |          StdQVals |             971 |
# |          MaxQVals |       -5.25e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |        6.97e+03 |
# |             LossQ |        1.78e+03 |
# |              Time |             541 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |       -5.03e+03 |
# |          StdEpRet |        2.02e+03 |
# |          MaxEpRet |            -869 |
# |          MinEpRet |       -8.09e+03 |
# |  AverageTestEpRet |       -5.11e+03 |
# |      StdTestEpRet |        1.09e+03 |
# |      MaxTestEpRet |       -2.21e+03 |
# |      MinTestEpRet |       -6.28e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.41e+04 |
# |      AverageQVals |       -6.99e+03 |
# |          StdQVals |             979 |
# |          MaxQVals |       -5.23e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |        6.97e+03 |
# |             LossQ |        1.76e+03 |
# |              Time |             553 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |       -5.22e+03 |
# |          StdEpRet |        1.76e+03 |
# |          MaxEpRet |            -530 |
# |          MinEpRet |       -8.28e+03 |
# |  AverageTestEpRet |       -6.01e+03 |
# |      StdTestEpRet |             830 |
# |      MaxTestEpRet |       -4.91e+03 |
# |      MinTestEpRet |       -7.53e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.58e+04 |
# |      AverageQVals |          -7e+03 |
# |          StdQVals |             992 |
# |          MaxQVals |       -5.22e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |        6.99e+03 |
# |             LossQ |        1.82e+03 |
# |              Time |             564 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |       -5.11e+03 |
# |          StdEpRet |        1.65e+03 |
# |          MaxEpRet |            -702 |
# |          MinEpRet |       -8.32e+03 |
# |  AverageTestEpRet |       -4.56e+03 |
# |      StdTestEpRet |        2.01e+03 |
# |      MaxTestEpRet |            -570 |
# |      MinTestEpRet |       -6.73e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.74e+04 |
# |      AverageQVals |       -7.01e+03 |
# |          StdQVals |             999 |
# |          MaxQVals |       -5.22e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |        6.99e+03 |
# |             LossQ |        1.78e+03 |
# |              Time |             575 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |       -5.61e+03 |
# |          StdEpRet |        1.56e+03 |
# |          MaxEpRet |       -2.99e+03 |
# |          MinEpRet |       -1.02e+04 |
# |  AverageTestEpRet |       -6.04e+03 |
# |      StdTestEpRet |        2.18e+03 |
# |      MaxTestEpRet |          -2e+03 |
# |      MinTestEpRet |        -1.1e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.91e+04 |
# |      AverageQVals |       -7.01e+03 |
# |          StdQVals |        1.01e+03 |
# |          MaxQVals |        -5.2e+03 |
# |          MinQVals |       -1.11e+04 |
# |            LossPi |           7e+03 |
# |             LossQ |        1.76e+03 |
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              82 |
# |      AverageEpRet |       -5.53e+03 |
# |          StdEpRet |        1.06e+03 |
# |          MaxEpRet |        -4.6e+03 |
# |          MinEpRet |       -8.69e+03 |
# |  AverageTestEpRet |       -5.81e+03 |
# |      StdTestEpRet |             812 |
# |      MaxTestEpRet |       -4.78e+03 |
# |      MinTestEpRet |       -7.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.35e+05 |
# |      AverageQVals |       -6.98e+03 |
# |          StdQVals |        1.09e+03 |
# |          MaxQVals |       -5.08e+03 |
# |          MinQVals |       -1.21e+04 |
# |            LossPi |        6.96e+03 |
# |             LossQ |        1.62e+03 |
# |              Time |             898 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              83 |
# |      AverageEpRet |       -5.43e+03 |
# |          StdEpRet |        1.43e+03 |
# |          MaxEpRet |        -2.6e+03 |
# |          MinEpRet |       -8.82e+03 |
# |  AverageTestEpRet |       -5.54e+03 |
# |      StdTestEpRet |        1.84e+03 |
# |      MaxTestEpRet |            -440 |
# |      MinTestEpRet |       -7.25e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.37e+05 |
# |      AverageQVals |       -6.98e+03 |
# |          StdQVals |        1.09e+03 |
# |          MaxQVals |       -5.09e+03 |
# |          MinQVals |       -1.21e+04 |
# |            LossPi |        6.96e+03 |
# |             LossQ |        1.61e+03 |
# |              Time |             911 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |       -5.67e+03 |
# |          StdEpRet |        1.75e+03 |
# |          MaxEpRet |       -1.22e+03 |
# |          MinEpRet |       -9.82e+03 |
# |  AverageTestEpRet |       -5.71e+03 |
# |      StdTestEpRet |        1.72e+03 |
# |      MaxTestEpRet |       -1.03e+03 |
# |      MinTestEpRet |       -7.28e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.39e+05 |
# |      AverageQVals |       -6.97e+03 |
# |          StdQVals |        1.09e+03 |
# |          MaxQVals |       -5.08e+03 |
# |          MinQVals |       -1.22e+04 |
# |            LossPi |        6.96e+03 |
# |             LossQ |        1.65e+03 |
# |              Time |             926 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |       -4.55e+03 |
# |          StdEpRet |        1.47e+03 |
# |          MaxEpRet |       -1.32e+03 |
# |          MinEpRet |       -6.89e+03 |
# |  AverageTestEpRet |       -5.79e+03 |
# |      StdTestEpRet |        2.65e+03 |
# |      MaxTestEpRet |       -2.24e+03 |
# |      MinTestEpRet |       -1.27e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.4e+05 |
# |      AverageQVals |       -6.97e+03 |
# |          StdQVals |        1.09e+03 |
# |          MaxQVals |       -5.08e+03 |
# |          MinQVals |       -1.22e+04 |
# |            LossPi |        6.96e+03 |
# |             LossQ |        1.68e+03 |
# |              Time |             939 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |       -4.92e+03 |
# |          StdEpRet |        2.07e+03 |
# |          MaxEpRet |            -425 |
# |          MinEpRet |       -8.69e+03 |
# |  AverageTestEpRet |       -5.82e+03 |
# |      StdTestEpRet |        1.94e+03 |
# |      MaxTestEpRet |       -1.06e+03 |
# |      MinTestEpRet |       -9.14e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.42e+05 |
# |      AverageQVals |       -6.97e+03 |
# |          StdQVals |         1.1e+03 |
# |          MaxQVals |       -5.07e+03 |
# |          MinQVals |       -1.22e+04 |
# |            LossPi |        6.95e+03 |
# |             LossQ |        1.64e+03 |
# |              Time |             950 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |       -5.21e+03 |
# |          StdEpRet |             706 |
# |          MaxEpRet |       -3.79e+03 |
# |          MinEpRet |        -6.3e+03 |
# |  AverageTestEpRet |       -5.33e+03 |
# |      StdTestEpRet |             507 |
# |      MaxTestEpRet |       -4.48e+03 |
# |      MinTestEpRet |       -6.05e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.44e+05 |
# |      AverageQVals |       -6.97e+03 |
# |          StdQVals |        1.11e+03 |
# |          MaxQVals |       -5.06e+03 |
# |          MinQVals |       -1.22e+04 |
# |            LossPi |        6.96e+03 |
# |             LossQ |        1.63e+03 |
# |              Time |             960 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |       -5.26e+03 |
# |          StdEpRet |        1.22e+03 |
# |          MaxEpRet |       -2.96e+03 |
# |          MinEpRet |       -8.12e+03 |
# |  AverageTestEpRet |       -4.78e+03 |
# |      StdTestEpRet |        2.39e+03 |
# |      MaxTestEpRet |            -548 |
# |      MinTestEpRet |       -8.44e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.45e+05 |
# |      AverageQVals |       -6.97e+03 |
# |          StdQVals |        1.11e+03 |
# |          MaxQVals |       -5.04e+03 |
# |          MinQVals |       -1.22e+04 |
# |            LossPi |        6.96e+03 |
# |             LossQ |        1.67e+03 |
# |              Time |             971 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |       -5.29e+03 |
# |          StdEpRet |             968 |
# |          MaxEpRet |       -2.47e+03 |
# |          MinEpRet |       -6.93e+03 |
# |  AverageTestEpRet |       -4.74e+03 |
# |      StdTestEpRet |        1.36e+03 |
# |      MaxTestEpRet |            -964 |
# |      MinTestEpRet |       -6.36e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.47e+05 |
# |      AverageQVals |       -6.96e+03 |
# |          StdQVals |        1.11e+03 |
# |          MaxQVals |       -5.02e+03 |
# |          MinQVals |       -1.22e+04 |
# |            LossPi |        6.94e+03 |
# |             LossQ |        1.65e+03 |
# |              Time |             982 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |       -5.19e+03 |
# |          StdEpRet |        1.42e+03 |
# |          MaxEpRet |            -384 |
# |          MinEpRet |       -6.82e+03 |
# |  AverageTestEpRet |       -5.09e+03 |
# |      StdTestEpRet |        1.76e+03 |
# |      MaxTestEpRet |            -370 |
# |      MinTestEpRet |       -7.17e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+05 |
# |      AverageQVals |       -6.94e+03 |
# |          StdQVals |         1.1e+03 |
# |          MaxQVals |          -5e+03 |
# |          MinQVals |       -1.22e+04 |
# |            LossPi |        6.92e+03 |
# |             LossQ |        1.62e+03 |
# |              Time |             993 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |       -4.93e+03 |
# |          StdEpRet |        1.38e+03 |
# |          MaxEpRet |       -2.27e+03 |
# |          MinEpRet |       -7.02e+03 |
# |  AverageTestEpRet |       -6.08e+03 |
# |      StdTestEpRet |        3.11e+03 |
# |      MaxTestEpRet |            -687 |
# |      MinTestEpRet |        -1.4e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.5e+05 |
# |      AverageQVals |       -6.93e+03 |
# |          StdQVals |        1.11e+03 |
# |          MaxQVals |       -4.99e+03 |
# |          MinQVals |       -1.22e+04 |
# |            LossPi |        6.92e+03 |
# |             LossQ |        1.62e+03 |
# |              Time |           1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |       -4.89e+03 |
# |          StdEpRet |        1.24e+03 |
# |          MaxEpRet |            -887 |
# |          MinEpRet |       -5.86e+03 |
# |  AverageTestEpRet |       -6.04e+03 |
# |      StdTestEpRet |        1.55e+03 |
# |      MaxTestEpRet |       -4.96e+03 |
# |      MinTestEpRet |       -1.01e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.52e+05 |
# |      AverageQVals |       -6.92e+03 |
# |          StdQVals |         1.1e+03 |
# |          MaxQVals |       -4.98e+03 |
# |          MinQVals |       -1.23e+04 |
# |            LossPi |        6.91e+03 |
# |             LossQ |        1.61e+03 |
# |              Time |        1.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |       -5.72e+03 |
# |          StdEpRet |        1.68e+03 |
# |          MaxEpRet |       -2.87e+03 |
# |          MinEpRet |       -9.75e+03 |
# |  AverageTestEpRet |       -5.62e+03 |
# |      StdTestEpRet |             907 |
# |      MaxTestEpRet |       -4.61e+03 |
# |      MinTestEpRet |       -7.71e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.53e+05 |
# |      AverageQVals |        -6.9e+03 |
# |          StdQVals |        1.11e+03 |
# |          MaxQVals |       -4.98e+03 |
# |          MinQVals |       -1.23e+04 |
# |            LossPi |        6.89e+03 |
# |             LossQ |         1.6e+03 |
# |              Time |        1.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |       -4.66e+03 |
# |          StdEpRet |        2.01e+03 |
# |          MaxEpRet |       -1.19e+03 |
# |          MinEpRet |       -8.66e+03 |
# |  AverageTestEpRet |       -4.12e+03 |
# |      StdTestEpRet |        2.19e+03 |
# |      MaxTestEpRet |            -309 |
# |      MinTestEpRet |       -6.74e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.55e+05 |
# |      AverageQVals |       -6.89e+03 |
# |          StdQVals |        1.11e+03 |
# |          MaxQVals |       -4.96e+03 |
# |          MinQVals |       -1.23e+04 |
# |            LossPi |        6.87e+03 |
# |             LossQ |        1.59e+03 |
# |              Time |        1.04e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |       -5.27e+03 |
# |          StdEpRet |        1.98e+03 |
# |          MaxEpRet |       -1.63e+03 |
# |          MinEpRet |       -8.81e+03 |
# |  AverageTestEpRet |       -5.26e+03 |
# |      StdTestEpRet |        2.36e+03 |
# |      MaxTestEpRet |       -1.14e+03 |
# |      MinTestEpRet |       -1.14e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.57e+05 |
# |      AverageQVals |       -6.88e+03 |
# |          StdQVals |        1.11e+03 |
# |          MaxQVals |       -4.95e+03 |
# |          MinQVals |       -1.23e+04 |
# |            LossPi |        6.86e+03 |
# |             LossQ |        1.59e+03 |
# |              Time |        1.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |       -5.33e+03 |
# |          StdEpRet |        1.82e+03 |
# |          MaxEpRet |       -2.17e+03 |
# |          MinEpRet |       -8.79e+03 |
# |  AverageTestEpRet |       -4.98e+03 |
# |      StdTestEpRet |        1.64e+03 |
# |      MaxTestEpRet |            -439 |
# |      MinTestEpRet |       -6.74e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.58e+05 |
# |      AverageQVals |       -6.86e+03 |
# |          StdQVals |        1.11e+03 |
# |          MaxQVals |       -4.92e+03 |
# |          MinQVals |       -1.23e+04 |
# |            LossPi |        6.84e+03 |
# |             LossQ |        1.57e+03 |
# |              Time |        1.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |       -5.45e+03 |
# |          StdEpRet |         1.4e+03 |
# |          MaxEpRet |       -2.14e+03 |
# |          MinEpRet |       -7.99e+03 |
# |  AverageTestEpRet |       -5.13e+03 |
# |      StdTestEpRet |        1.99e+03 |
# |      MaxTestEpRet |       -1.05e+03 |
# |      MinTestEpRet |       -7.06e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.6e+05 |
# |      AverageQVals |       -6.85e+03 |
# |          StdQVals |        1.11e+03 |
# |          MaxQVals |        -4.9e+03 |
# |          MinQVals |       -1.23e+04 |
# |            LossPi |        6.83e+03 |
# |             LossQ |        1.58e+03 |
# |              Time |        1.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |       -4.42e+03 |
# |          StdEpRet |        1.55e+03 |
# |          MaxEpRet |       -1.06e+03 |
# |          MinEpRet |       -6.01e+03 |
# |  AverageTestEpRet |          -6e+03 |
# |      StdTestEpRet |        1.24e+03 |
# |      MaxTestEpRet |        -4.5e+03 |
# |      MinTestEpRet |       -9.01e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.62e+05 |
# |      AverageQVals |       -6.83e+03 |
# |          StdQVals |        1.11e+03 |
# |          MaxQVals |       -4.85e+03 |
# |          MinQVals |       -1.22e+04 |
# |            LossPi |        6.81e+03 |
# |             LossQ |         1.6e+03 |
# |              Time |        1.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |       -4.88e+03 |
# |          StdEpRet |        1.71e+03 |
# |          MaxEpRet |            -658 |
# |          MinEpRet |       -7.38e+03 |
# |  AverageTestEpRet |       -4.32e+03 |
# |      StdTestEpRet |        1.64e+03 |
# |      MaxTestEpRet |            -961 |
# |      MinTestEpRet |       -6.21e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.63e+05 |
# |      AverageQVals |       -6.81e+03 |
# |          StdQVals |        1.11e+03 |
# |          MaxQVals |       -4.82e+03 |
# |          MinQVals |       -1.22e+04 |
# |            LossPi |        6.79e+03 |
# |             LossQ |        1.55e+03 |
# |              Time |        1.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             100 |
# |      AverageEpRet |       -5.59e+03 |
# |          StdEpRet |         1.8e+03 |
# |          MaxEpRet |            -163 |
# |          MinEpRet |       -8.17e+03 |
# |  AverageTestEpRet |       -5.23e+03 |
# |      StdTestEpRet |        1.11e+03 |
# |      MaxTestEpRet |       -2.45e+03 |
# |      MinTestEpRet |       -6.97e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+05 |
# |      AverageQVals |        -6.8e+03 |
# |          StdQVals |        1.11e+03 |
# |          MaxQVals |       -4.79e+03 |
# |          MinQVals |       -1.22e+04 |
# |            LossPi |        6.78e+03 |
# |             LossQ |        1.58e+03 |
# |              Time |         1.1e+03 |
# ---------------------------------------

# %% [markdown]
# #### Quadratic reward with exponential term

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='ddpg_q_e', exp_name='ddpg_q_e')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0025
qlr_b = 0.0025

# Env function
reward_args = {'qx1':1,'qx2':0,'qx3':1,'qx4':0,'pu1':0,'pu2':0,'eax1' : 10,'ebx1':10,'eax3': 10,'ebx3':10}
env_fn = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Quadratic with exponential', reward_args = reward_args,ep_len=maxeplen_b)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Warning: Log dir ddpg_q_e already exists! Storing info there anyway.
# Logging data to ddpg_q_e/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(<function env_fn at 0x7f76de14bea0>, env_name='gyroscopeenv-v0', reward_type='Quadratic', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Absolute', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.5, 'pu2': 0.5}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.1, 'pu1': 0.25, 'pu2': 0.25}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with ending penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1, 'sx1': 100, 'sx3': 100, 'end_horizon': 1}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.25, 'pu2': 0.25, 'bound': 0.2, 'penalty': 40}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.25, 'pu2': 0.25, 'bound': 0.2, 'penalty': 40}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with exponential', reward_args={'qx1': 1, 'qx2': 0, 'qx3': 1, 'qx4': 0, 'pu1': 0, 'pu2': 0, 'eax1': 10, 'ebx1': 10, 'eax3': 10, 'ebx3': 10}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.25, 'pu2': 0.25, 'bound': 0.2, 'penalty': 40}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with bonus', reward_args={'qx1': 1, 'qx2': 0, 'qx3': 1, 'qx4': 0, 'pu1': 0, 'pu2': 0, 'bound': 0.05, 'bonus': 2}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with exponential', reward_args={'qx1': 1, 'qx2': 0, 'qx3': 1, 'qx4': 0, 'pu1': 0, 'pu2': 0, 'eax1': 10, 'ebx1': 5, 'eax3': 10, 'ebx3': 5}, ep_len=110)",
#     "epochs":	300,
#     "exp_name":	"ddpg_q_e",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f76acb87668>":	{
#             "epoch_dict":	{},
#             "exp_name":	"ddpg_q_e",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_q_e",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_q_e/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"ddpg_q_e",
#         "output_dir":	"ddpg_q_e"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0025,
#     "polyak":	0.995,
#     "q_lr":	0.0025,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 4802, 	 q: 5201
# /home/matthieulc/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |       -2.77e+03 |
# |          StdEpRet |             288 |
# |          MaxEpRet |       -2.39e+03 |
# |          MinEpRet |       -3.34e+03 |
# |  AverageTestEpRet |       -2.57e+03 |
# |      StdTestEpRet |             425 |
# |      MaxTestEpRet |       -1.68e+03 |
# |      MinTestEpRet |       -3.17e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |      AverageQVals |           -47.2 |
# |          StdQVals |            21.3 |
# |          MaxQVals |            0.25 |
# |          MinQVals |            -113 |
# |            LossPi |              46 |
# |             LossQ |            56.6 |
# |              Time |            4.91 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |       -2.73e+03 |
# |          StdEpRet |             332 |
# |          MaxEpRet |       -2.16e+03 |
# |          MinEpRet |       -3.48e+03 |
# |  AverageTestEpRet |       -2.79e+03 |
# |      StdTestEpRet |             702 |
# |      MaxTestEpRet |       -1.41e+03 |
# |      MinTestEpRet |       -3.38e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |      AverageQVals |            -165 |
# |          StdQVals |            57.4 |
# |          MaxQVals |           -46.8 |
# |          MinQVals |            -362 |
# |            LossPi |             162 |
# |             LossQ |            44.4 |
# |              Time |            12.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |        -2.5e+03 |
# |          StdEpRet |             294 |
# |          MaxEpRet |       -1.97e+03 |
# |          MinEpRet |       -3.18e+03 |
# |  AverageTestEpRet |       -2.14e+03 |
# |      StdTestEpRet |             579 |
# |      MaxTestEpRet |       -1.16e+03 |
# |      MinTestEpRet |       -2.91e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |      AverageQVals |            -323 |
# |          StdQVals |            58.6 |
# |          MaxQVals |            -144 |
# |          MinQVals |            -529 |
# |            LossPi |             317 |
# |             LossQ |            97.2 |
# |              Time |            19.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |       -2.71e+03 |
# |          StdEpRet |             352 |
# |          MaxEpRet |       -2.03e+03 |
# |          MinEpRet |        -3.2e+03 |
# |  AverageTestEpRet |       -2.01e+03 |
# |      StdTestEpRet |             410 |
# |      MaxTestEpRet |       -1.36e+03 |
# |      MinTestEpRet |       -2.57e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |      AverageQVals |            -448 |
# |          StdQVals |            61.8 |
# |          MaxQVals |            -260 |
# |          MinQVals |            -685 |
# |            LossPi |             440 |
# |             LossQ |             116 |
# |              Time |            28.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |        -2.5e+03 |
# |          StdEpRet |             540 |
# |          MaxEpRet |       -1.61e+03 |
# |          MinEpRet |       -3.14e+03 |
# |  AverageTestEpRet |        -1.7e+03 |
# |      StdTestEpRet |             693 |
# |      MaxTestEpRet |            -265 |
# |      MinTestEpRet |       -2.94e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |      AverageQVals |            -562 |
# |          StdQVals |            66.4 |
# |          MaxQVals |            -363 |
# |          MinQVals |            -814 |
# |            LossPi |             554 |
# |             LossQ |             123 |
# |              Time |            37.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |        -2.6e+03 |
# |          StdEpRet |             272 |
# |          MaxEpRet |       -2.04e+03 |
# |          MinEpRet |       -2.94e+03 |
# |  AverageTestEpRet |       -1.28e+03 |
# |      StdTestEpRet |             586 |
# |      MaxTestEpRet |            -328 |
# |      MinTestEpRet |       -2.08e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |      AverageQVals |            -665 |
# |          StdQVals |            69.6 |
# |          MaxQVals |            -473 |
# |          MinQVals |            -936 |
# |            LossPi |             656 |
# |             LossQ |             132 |
# |              Time |              47 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |       -1.82e+03 |
# |          StdEpRet |             626 |
# |          MaxEpRet |            -542 |
# |          MinEpRet |       -2.68e+03 |
# |  AverageTestEpRet |       -1.87e+03 |
# |      StdTestEpRet |             656 |
# |      MaxTestEpRet |            -771 |
# |      MinTestEpRet |       -2.66e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |      AverageQVals |            -754 |
# |          StdQVals |              74 |
# |          MaxQVals |            -565 |
# |          MinQVals |       -1.06e+03 |
# |            LossPi |             746 |
# |             LossQ |             133 |
# |              Time |            55.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |       -1.55e+03 |
# |          StdEpRet |             509 |
# |          MaxEpRet |            -475 |
# |          MinEpRet |       -2.27e+03 |
# |  AverageTestEpRet |       -1.33e+03 |
# |      StdTestEpRet |             460 |
# |      MaxTestEpRet |            -274 |
# |      MinTestEpRet |          -2e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |      AverageQVals |            -836 |
# |          StdQVals |            79.7 |
# |          MaxQVals |            -648 |
# |          MinQVals |       -1.17e+03 |
# |            LossPi |             828 |
# |             LossQ |             118 |
# |              Time |            63.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |       -1.43e+03 |
# |          StdEpRet |             585 |
# |          MaxEpRet |            -689 |
# |          MinEpRet |       -2.68e+03 |
# |  AverageTestEpRet |       -1.64e+03 |
# |      StdTestEpRet |             789 |
# |      MaxTestEpRet |            -199 |
# |      MinTestEpRet |          -3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |      AverageQVals |            -911 |
# |          StdQVals |            87.4 |
# |          MaxQVals |            -709 |
# |          MinQVals |       -1.26e+03 |
# |            LossPi |             904 |
# |             LossQ |             112 |
# |              Time |            71.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |       -1.44e+03 |
# |          StdEpRet |             469 |
# |          MaxEpRet |            -740 |
# |          MinEpRet |       -2.28e+03 |
# |  AverageTestEpRet |        -1.9e+03 |
# |      StdTestEpRet |             573 |
# |      MaxTestEpRet |            -924 |
# |      MinTestEpRet |       -2.77e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |            -980 |
# |          StdQVals |            97.9 |
# |          MaxQVals |            -761 |
# |          MinQVals |       -1.36e+03 |
# |            LossPi |             973 |
# |             LossQ |             116 |
# |              Time |            79.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |       -1.65e+03 |
# |          StdEpRet |             552 |
# |          MaxEpRet |            -713 |
# |          MinEpRet |       -2.82e+03 |
# |  AverageTestEpRet |       -1.26e+03 |
# |      StdTestEpRet |             614 |
# |      MaxTestEpRet |            -355 |
# |      MinTestEpRet |       -2.17e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |      AverageQVals |       -1.04e+03 |
# |          StdQVals |             108 |
# |          MaxQVals |            -802 |
# |          MinQVals |       -1.48e+03 |
# |            LossPi |        1.03e+03 |
# |             LossQ |             125 |
# |              Time |            87.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |       -1.52e+03 |
# |          StdEpRet |             433 |
# |          MaxEpRet |            -946 |
# |          MinEpRet |       -2.45e+03 |
# |  AverageTestEpRet |       -1.68e+03 |
# |      StdTestEpRet |             564 |
# |      MaxTestEpRet |            -732 |
# |      MinTestEpRet |       -2.28e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |      AverageQVals |        -1.1e+03 |
# |          StdQVals |             117 |
# |          MaxQVals |            -838 |
# |          MinQVals |       -1.57e+03 |
# |            LossPi |        1.09e+03 |
# |             LossQ |             130 |
# |              Time |            95.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |       -1.42e+03 |
# |          StdEpRet |             552 |
# |          MaxEpRet |            -347 |
# |          MinEpRet |       -2.38e+03 |
# |  AverageTestEpRet |       -1.23e+03 |
# |      StdTestEpRet |             407 |
# |      MaxTestEpRet |            -393 |
# |      MinTestEpRet |       -2.01e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |      AverageQVals |       -1.15e+03 |
# |          StdQVals |             125 |
# |          MaxQVals |            -870 |
# |          MinQVals |       -1.64e+03 |
# |            LossPi |        1.14e+03 |
# |             LossQ |             136 |
# |              Time |             103 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |       -1.65e+03 |
# |          StdEpRet |             423 |
# |          MaxEpRet |          -1e+03 |
# |          MinEpRet |       -2.23e+03 |
# |  AverageTestEpRet |       -1.34e+03 |
# |      StdTestEpRet |             579 |
# |      MaxTestEpRet |            -480 |
# |      MinTestEpRet |       -2.13e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |      AverageQVals |        -1.2e+03 |
# |          StdQVals |             135 |
# |          MaxQVals |            -912 |
# |          MinQVals |       -1.73e+03 |
# |            LossPi |        1.19e+03 |
# |             LossQ |             140 |
# |              Time |             111 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |       -1.76e+03 |
# |          StdEpRet |             356 |
# |          MaxEpRet |       -1.38e+03 |
# |          MinEpRet |       -2.48e+03 |
# |  AverageTestEpRet |       -1.55e+03 |
# |      StdTestEpRet |             722 |
# |      MaxTestEpRet |            -177 |
# |      MinTestEpRet |        -2.3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |      AverageQVals |       -1.24e+03 |
# |          StdQVals |             143 |
# |          MaxQVals |            -938 |
# |          MinQVals |       -1.78e+03 |
# |            LossPi |        1.24e+03 |
# |             LossQ |             144 |
# |              Time |             120 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |       -1.76e+03 |
# |          StdEpRet |             533 |
# |          MaxEpRet |            -692 |
# |          MinEpRet |       -2.77e+03 |
# |  AverageTestEpRet |       -1.37e+03 |
# |      StdTestEpRet |             607 |
# |      MaxTestEpRet |            -366 |
# |      MinTestEpRet |       -2.31e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |      AverageQVals |       -1.29e+03 |
# |          StdQVals |             150 |
# |          MaxQVals |            -962 |
# |          MinQVals |       -1.94e+03 |
# |            LossPi |        1.29e+03 |
# |             LossQ |             151 |
# |              Time |             130 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |       -1.78e+03 |
# |          StdEpRet |             434 |
# |          MaxEpRet |            -648 |
# |          MinEpRet |       -2.38e+03 |
# |  AverageTestEpRet |        -1.6e+03 |
# |      StdTestEpRet |             512 |
# |      MaxTestEpRet |            -461 |
# |      MinTestEpRet |       -2.31e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |      AverageQVals |       -1.33e+03 |
# |          StdQVals |             156 |
# |          MaxQVals |            -990 |
# |          MinQVals |       -2.01e+03 |
# |            LossPi |        1.33e+03 |
# |             LossQ |             154 |
# |              Time |             139 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |       -1.77e+03 |
# |          StdEpRet |             534 |
# |          MaxEpRet |            -487 |
# |          MinEpRet |       -2.48e+03 |
# |  AverageTestEpRet |       -1.93e+03 |
# |      StdTestEpRet |             605 |
# |      MaxTestEpRet |            -911 |
# |      MinTestEpRet |       -2.65e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |      AverageQVals |       -1.37e+03 |
# |          StdQVals |             160 |
# |          MaxQVals |       -1.01e+03 |
# |          MinQVals |       -2.04e+03 |
# |            LossPi |        1.37e+03 |
# |             LossQ |             153 |
# |              Time |             148 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |       -1.56e+03 |
# |          StdEpRet |             583 |
# |          MaxEpRet |            -446 |
# |          MinEpRet |       -2.41e+03 |
# |  AverageTestEpRet |       -1.69e+03 |
# |      StdTestEpRet |             559 |
# |      MaxTestEpRet |            -760 |
# |      MinTestEpRet |       -2.64e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |      AverageQVals |       -1.41e+03 |
# |          StdQVals |             166 |
# |          MaxQVals |       -1.03e+03 |
# |          MinQVals |       -2.09e+03 |
# |            LossPi |         1.4e+03 |
# |             LossQ |             153 |
# |              Time |             155 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |       -1.86e+03 |
# |          StdEpRet |             402 |
# |          MaxEpRet |            -978 |
# |          MinEpRet |       -2.41e+03 |
# |  AverageTestEpRet |       -1.45e+03 |
# |      StdTestEpRet |             558 |
# |      MaxTestEpRet |            -289 |
# |      MinTestEpRet |       -2.12e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |       -1.44e+03 |
# |          StdQVals |             170 |
# |          MaxQVals |       -1.06e+03 |
# |          MinQVals |       -2.18e+03 |
# |            LossPi |        1.44e+03 |
# |             LossQ |             151 |
# |              Time |             163 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |       -1.59e+03 |
# |          StdEpRet |             489 |
# |          MaxEpRet |            -553 |
# |          MinEpRet |       -2.81e+03 |
# |  AverageTestEpRet |       -1.63e+03 |
# |      StdTestEpRet |             739 |
# |      MaxTestEpRet |            -869 |
# |      MinTestEpRet |       -3.02e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |      AverageQVals |       -1.48e+03 |
# |          StdQVals |             173 |
# |          MaxQVals |       -1.08e+03 |
# |          MinQVals |       -2.22e+03 |
# |            LossPi |        1.47e+03 |
# |             LossQ |             148 |
# |              Time |             171 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |       -1.51e+03 |
# |          StdEpRet |             664 |
# |          MaxEpRet |            -483 |
# |          MinEpRet |       -3.11e+03 |
# |  AverageTestEpRet |        -1.7e+03 |
# |      StdTestEpRet |             451 |
# |      MaxTestEpRet |            -975 |
# |      MinTestEpRet |       -2.39e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |      AverageQVals |       -1.51e+03 |
# |          StdQVals |             179 |
# |          MaxQVals |       -1.09e+03 |
# |          MinQVals |       -2.26e+03 |
# |            LossPi |        1.51e+03 |
# |             LossQ |             148 |
# |              Time |             179 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |       -1.62e+03 |
# |          StdEpRet |             578 |
# |          MaxEpRet |            -772 |
# |          MinEpRet |       -2.64e+03 |
# |  AverageTestEpRet |       -1.62e+03 |
# |      StdTestEpRet |             491 |
# |      MaxTestEpRet |            -530 |
# |      MinTestEpRet |       -2.37e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |      AverageQVals |       -1.54e+03 |
# |          StdQVals |             183 |
# |          MaxQVals |       -1.11e+03 |
# |          MinQVals |       -2.27e+03 |
# |            LossPi |        1.54e+03 |
# |             LossQ |             147 |
# |              Time |             188 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |       -1.53e+03 |
# |          StdEpRet |             623 |
# |          MaxEpRet |            -630 |
# |          MinEpRet |       -2.76e+03 |
# |  AverageTestEpRet |       -1.35e+03 |
# |      StdTestEpRet |             633 |
# |      MaxTestEpRet |            -425 |
# |      MinTestEpRet |       -2.62e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |      AverageQVals |       -1.57e+03 |
# |          StdQVals |             188 |
# |          MaxQVals |       -1.13e+03 |
# |          MinQVals |        -2.3e+03 |
# |            LossPi |        1.57e+03 |
# |             LossQ |             148 |
# |              Time |             197 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |       -1.56e+03 |
# |          StdEpRet |             541 |
# |          MaxEpRet |            -645 |
# |          MinEpRet |       -2.48e+03 |
# |  AverageTestEpRet |       -1.82e+03 |
# |      StdTestEpRet |             477 |
# |      MaxTestEpRet |       -1.11e+03 |
# |      MinTestEpRet |       -2.59e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |      AverageQVals |        -1.6e+03 |
# |          StdQVals |             192 |
# |          MaxQVals |       -1.15e+03 |
# |          MinQVals |       -2.34e+03 |
# |            LossPi |        1.59e+03 |
# |             LossQ |             147 |
# |              Time |             207 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |       -1.44e+03 |
# |          StdEpRet |             465 |
# |          MaxEpRet |            -614 |
# |          MinEpRet |       -2.52e+03 |
# |  AverageTestEpRet |       -1.32e+03 |
# |      StdTestEpRet |             551 |
# |      MaxTestEpRet |            -573 |
# |      MinTestEpRet |       -2.52e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |      AverageQVals |       -1.62e+03 |
# |          StdQVals |             199 |
# |          MaxQVals |       -1.16e+03 |
# |          MinQVals |       -2.38e+03 |
# |            LossPi |        1.62e+03 |
# |             LossQ |             149 |
# |              Time |             217 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |       -1.66e+03 |
# |          StdEpRet |             568 |
# |          MaxEpRet |            -668 |
# |          MinEpRet |       -2.36e+03 |
# |  AverageTestEpRet |       -1.57e+03 |
# |      StdTestEpRet |             769 |
# |      MaxTestEpRet |            -373 |
# |      MinTestEpRet |       -2.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |      AverageQVals |       -1.64e+03 |
# |          StdQVals |             204 |
# |          MaxQVals |       -1.18e+03 |
# |          MinQVals |       -2.42e+03 |
# |            LossPi |        1.64e+03 |
# |             LossQ |             147 |
# |              Time |             226 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |       -1.57e+03 |
# |          StdEpRet |             480 |
# |          MaxEpRet |            -786 |
# |          MinEpRet |       -2.36e+03 |
# |  AverageTestEpRet |       -1.89e+03 |
# |      StdTestEpRet |             773 |
# |      MaxTestEpRet |            -607 |
# |      MinTestEpRet |       -3.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |      AverageQVals |       -1.66e+03 |
# |          StdQVals |             210 |
# |          MaxQVals |       -1.18e+03 |
# |          MinQVals |       -2.47e+03 |
# |            LossPi |        1.66e+03 |
# |             LossQ |             152 |
# |              Time |             236 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |       -1.54e+03 |
# |          StdEpRet |             606 |
# |          MaxEpRet |            -552 |
# |          MinEpRet |       -2.81e+03 |
# |  AverageTestEpRet |       -1.42e+03 |
# |      StdTestEpRet |             572 |
# |      MaxTestEpRet |            -514 |
# |      MinTestEpRet |       -2.19e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |      AverageQVals |       -1.69e+03 |
# |          StdQVals |             216 |
# |          MaxQVals |       -1.19e+03 |
# |          MinQVals |       -2.51e+03 |
# |            LossPi |        1.68e+03 |
# |             LossQ |             152 |
# |              Time |             245 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |       -1.51e+03 |
# |          StdEpRet |             457 |
# |          MaxEpRet |            -695 |
# |          MinEpRet |       -2.54e+03 |
# |  AverageTestEpRet |       -1.24e+03 |
# |      StdTestEpRet |             704 |
# |      MaxTestEpRet |            -204 |
# |      MinTestEpRet |       -2.54e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |        -1.7e+03 |
# |          StdQVals |             220 |
# |          MaxQVals |        -1.2e+03 |
# |          MinQVals |       -2.54e+03 |
# |            LossPi |         1.7e+03 |
# |             LossQ |             154 |
# |              Time |             254 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |       -1.37e+03 |
# |          StdEpRet |             328 |
# |          MaxEpRet |            -839 |
# |          MinEpRet |       -1.98e+03 |
# |  AverageTestEpRet |       -1.27e+03 |
# |      StdTestEpRet |             666 |
# |      MaxTestEpRet |            -407 |
# |      MinTestEpRet |       -2.55e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |      AverageQVals |       -1.72e+03 |
# |          StdQVals |             223 |
# |          MaxQVals |       -1.21e+03 |
# |          MinQVals |       -2.59e+03 |
# |            LossPi |        1.71e+03 |
# |             LossQ |             153 |
# |              Time |             264 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |        -1.4e+03 |
# |          StdEpRet |             558 |
# |          MaxEpRet |            -578 |
# |          MinEpRet |       -2.31e+03 |
# |  AverageTestEpRet |       -1.32e+03 |
# |      StdTestEpRet |             516 |
# |      MaxTestEpRet |            -747 |
# |      MinTestEpRet |       -2.64e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |      AverageQVals |       -1.73e+03 |
# |          StdQVals |             226 |
# |          MaxQVals |       -1.21e+03 |
# |          MinQVals |       -2.61e+03 |
# |            LossPi |        1.73e+03 |
# |             LossQ |             156 |
# |              Time |             273 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |       -1.31e+03 |
# |          StdEpRet |             439 |
# |          MaxEpRet |            -622 |
# |          MinEpRet |       -2.11e+03 |
# |  AverageTestEpRet |       -1.04e+03 |
# |      StdTestEpRet |             635 |
# |      MaxTestEpRet |            -456 |
# |      MinTestEpRet |       -2.33e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |      AverageQVals |       -1.74e+03 |
# |          StdQVals |             230 |
# |          MaxQVals |       -1.22e+03 |
# |          MinQVals |       -2.63e+03 |
# |            LossPi |        1.74e+03 |
# |             LossQ |             154 |
# |              Time |             283 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |       -1.42e+03 |
# |          StdEpRet |             388 |
# |          MaxEpRet |            -543 |
# |          MinEpRet |       -1.95e+03 |
# |  AverageTestEpRet |       -1.02e+03 |
# |      StdTestEpRet |             362 |
# |      MaxTestEpRet |            -576 |
# |      MinTestEpRet |       -1.81e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |      AverageQVals |       -1.76e+03 |
# |          StdQVals |             233 |
# |          MaxQVals |       -1.22e+03 |
# |          MinQVals |       -2.65e+03 |
# |            LossPi |        1.75e+03 |
# |             LossQ |             159 |
# |              Time |             291 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |       -1.15e+03 |
# |          StdEpRet |             557 |
# |          MaxEpRet |            -291 |
# |          MinEpRet |       -2.07e+03 |
# |  AverageTestEpRet |       -1.37e+03 |
# |      StdTestEpRet |             392 |
# |      MaxTestEpRet |            -699 |
# |      MinTestEpRet |       -1.87e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |      AverageQVals |       -1.77e+03 |
# |          StdQVals |             236 |
# |          MaxQVals |       -1.22e+03 |
# |          MinQVals |       -2.69e+03 |
# |            LossPi |        1.76e+03 |
# |             LossQ |             158 |
# |              Time |             299 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |       -1.33e+03 |
# |          StdEpRet |             429 |
# |          MaxEpRet |            -621 |
# |          MinEpRet |       -2.03e+03 |
# |  AverageTestEpRet |       -1.27e+03 |
# |      StdTestEpRet |             837 |
# |      MaxTestEpRet |            -574 |
# |      MinTestEpRet |       -3.05e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |      AverageQVals |       -1.77e+03 |
# |          StdQVals |             240 |
# |          MaxQVals |       -1.22e+03 |
# |          MinQVals |        -2.7e+03 |
# |            LossPi |        1.77e+03 |
# |             LossQ |             162 |
# |              Time |             307 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |       -1.14e+03 |
# |          StdEpRet |             478 |
# |          MaxEpRet |            -526 |
# |          MinEpRet |       -2.21e+03 |
# |  AverageTestEpRet |       -1.53e+03 |
# |      StdTestEpRet |             559 |
# |      MaxTestEpRet |            -465 |
# |      MinTestEpRet |       -2.63e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |      AverageQVals |       -1.78e+03 |
# |          StdQVals |             244 |
# |          MaxQVals |       -1.22e+03 |
# |          MinQVals |       -2.73e+03 |
# |            LossPi |        1.77e+03 |
# |             LossQ |             162 |
# |              Time |             315 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |        -1.3e+03 |
# |          StdEpRet |             424 |
# |          MaxEpRet |            -543 |
# |          MinEpRet |       -2.17e+03 |
# |  AverageTestEpRet |       -1.33e+03 |
# |      StdTestEpRet |             537 |
# |      MaxTestEpRet |            -639 |
# |      MinTestEpRet |       -2.29e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |      AverageQVals |       -1.78e+03 |
# |          StdQVals |             250 |
# |          MaxQVals |       -1.21e+03 |
# |          MinQVals |       -2.77e+03 |
# |            LossPi |        1.78e+03 |
# |             LossQ |             169 |
# |              Time |             324 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |       -1.13e+03 |
# |          StdEpRet |             534 |
# |          MaxEpRet |            -340 |
# |          MinEpRet |       -1.89e+03 |
# |  AverageTestEpRet |       -1.25e+03 |
# |      StdTestEpRet |             541 |
# |      MaxTestEpRet |            -140 |
# |      MinTestEpRet |        -2.1e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |      AverageQVals |       -1.78e+03 |
# |          StdQVals |             253 |
# |          MaxQVals |       -1.21e+03 |
# |          MinQVals |       -2.79e+03 |
# |            LossPi |        1.78e+03 |
# |             LossQ |             166 |
# |              Time |             332 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |        -1.2e+03 |
# |          StdEpRet |             329 |
# |          MaxEpRet |            -763 |
# |          MinEpRet |          -2e+03 |
# |  AverageTestEpRet |       -1.28e+03 |
# |      StdTestEpRet |             575 |
# |      MaxTestEpRet |            -380 |
# |      MinTestEpRet |       -2.12e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |       -1.78e+03 |
# |          StdQVals |             256 |
# |          MaxQVals |        -1.2e+03 |
# |          MinQVals |       -2.81e+03 |
# |            LossPi |        1.78e+03 |
# |             LossQ |             170 |
# |              Time |             341 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |       -1.24e+03 |
# |          StdEpRet |             472 |
# |          MaxEpRet |            -202 |
# |          MinEpRet |       -1.96e+03 |
# |  AverageTestEpRet |        -1.2e+03 |
# |      StdTestEpRet |             379 |
# |      MaxTestEpRet |            -515 |
# |      MinTestEpRet |       -1.69e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |      AverageQVals |       -1.79e+03 |
# |          StdQVals |             259 |
# |          MaxQVals |        -1.2e+03 |
# |          MinQVals |       -2.83e+03 |
# |            LossPi |        1.78e+03 |
# |             LossQ |             168 |
# |              Time |             349 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |       -1.35e+03 |
# |          StdEpRet |             434 |
# |          MaxEpRet |            -507 |
# |          MinEpRet |       -2.14e+03 |
# |  AverageTestEpRet |       -1.45e+03 |
# |      StdTestEpRet |             601 |
# |      MaxTestEpRet |            -633 |
# |      MinTestEpRet |        -2.8e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |      AverageQVals |       -1.78e+03 |
# |          StdQVals |             261 |
# |          MaxQVals |        -1.2e+03 |
# |          MinQVals |       -2.83e+03 |
# |            LossPi |        1.78e+03 |
# |             LossQ |             169 |
# |              Time |             357 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |       -1.39e+03 |
# |          StdEpRet |             480 |
# |          MaxEpRet |            -513 |
# |          MinEpRet |       -2.23e+03 |
# |  AverageTestEpRet |       -1.79e+03 |
# |      StdTestEpRet |             676 |
# |      MaxTestEpRet |            -595 |
# |      MinTestEpRet |       -2.83e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |      AverageQVals |       -1.78e+03 |
# |          StdQVals |             263 |
# |          MaxQVals |        -1.2e+03 |
# |          MinQVals |       -2.89e+03 |
# |            LossPi |        1.78e+03 |
# |             LossQ |             173 |
# |              Time |             365 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |       -1.43e+03 |
# |          StdEpRet |             616 |
# |          MaxEpRet |            -505 |
# |          MinEpRet |       -2.96e+03 |
# |  AverageTestEpRet |       -1.46e+03 |
# |      StdTestEpRet |             387 |
# |      MaxTestEpRet |       -1.06e+03 |
# |      MinTestEpRet |        -2.3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |      AverageQVals |       -1.78e+03 |
# |          StdQVals |             265 |
# |          MaxQVals |        -1.2e+03 |
# |          MinQVals |       -2.89e+03 |
# |            LossPi |        1.78e+03 |
# |             LossQ |             171 |
# |              Time |             372 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |       -1.23e+03 |
# |          StdEpRet |             596 |
# |          MaxEpRet |            -220 |
# |          MinEpRet |       -2.49e+03 |
# |  AverageTestEpRet |       -1.36e+03 |
# |      StdTestEpRet |             460 |
# |      MaxTestEpRet |            -501 |
# |      MinTestEpRet |       -2.13e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |      AverageQVals |       -1.78e+03 |
# |          StdQVals |             269 |
# |          MaxQVals |       -1.21e+03 |
# |          MinQVals |       -2.91e+03 |
# |            LossPi |        1.78e+03 |
# |             LossQ |             173 |
# |              Time |             380 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |       -1.21e+03 |
# |          StdEpRet |             604 |
# |          MaxEpRet |            -221 |
# |          MinEpRet |       -2.14e+03 |
# |  AverageTestEpRet |       -1.29e+03 |
# |      StdTestEpRet |             358 |
# |      MaxTestEpRet |            -693 |
# |      MinTestEpRet |       -1.82e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |      AverageQVals |       -1.78e+03 |
# |          StdQVals |             274 |
# |          MaxQVals |        -1.2e+03 |
# |          MinQVals |       -2.91e+03 |
# |            LossPi |        1.77e+03 |
# |             LossQ |             171 |
# |              Time |             388 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |       -1.26e+03 |
# |          StdEpRet |             514 |
# |          MaxEpRet |            -513 |
# |          MinEpRet |       -2.55e+03 |
# |  AverageTestEpRet |       -1.27e+03 |
# |      StdTestEpRet |             464 |
# |      MaxTestEpRet |            -261 |
# |      MinTestEpRet |       -1.97e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.75e+04 |
# |      AverageQVals |       -1.77e+03 |
# |          StdQVals |             276 |
# |          MaxQVals |       -1.21e+03 |
# |          MinQVals |       -2.93e+03 |
# |            LossPi |        1.77e+03 |
# |             LossQ |             175 |
# |              Time |             396 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |       -1.06e+03 |
# |          StdEpRet |             371 |
# |          MaxEpRet |            -412 |
# |          MinEpRet |       -1.77e+03 |
# |  AverageTestEpRet |       -1.15e+03 |
# |      StdTestEpRet |             333 |
# |      MaxTestEpRet |            -442 |
# |      MinTestEpRet |       -1.67e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.92e+04 |
# |      AverageQVals |       -1.77e+03 |
# |          StdQVals |             278 |
# |          MaxQVals |       -1.21e+03 |
# |          MinQVals |       -2.86e+03 |
# |            LossPi |        1.76e+03 |
# |             LossQ |             177 |
# |              Time |             404 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |            -899 |
# |          StdEpRet |             483 |
# |          MaxEpRet |            -142 |
# |          MinEpRet |       -1.93e+03 |
# |  AverageTestEpRet |        -1.2e+03 |
# |      StdTestEpRet |             801 |
# |      MaxTestEpRet |            -270 |
# |      MinTestEpRet |       -2.45e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+04 |
# |      AverageQVals |       -1.76e+03 |
# |          StdQVals |             281 |
# |          MaxQVals |        -1.2e+03 |
# |          MinQVals |       -2.94e+03 |
# |            LossPi |        1.75e+03 |
# |             LossQ |             179 |
# |              Time |             414 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        -1.2e+03 |
# |          StdEpRet |             474 |
# |          MaxEpRet |            -251 |
# |          MinEpRet |       -1.98e+03 |
# |  AverageTestEpRet |       -1.26e+03 |
# |      StdTestEpRet |             413 |
# |      MaxTestEpRet |            -445 |
# |      MinTestEpRet |       -2.09e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |       -1.75e+03 |
# |          StdQVals |             284 |
# |          MaxQVals |       -1.19e+03 |
# |          MinQVals |       -2.91e+03 |
# |            LossPi |        1.74e+03 |
# |             LossQ |             177 |
# |              Time |             425 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |       -1.03e+03 |
# |          StdEpRet |             529 |
# |          MaxEpRet |            -215 |
# |          MinEpRet |       -2.06e+03 |
# |  AverageTestEpRet |            -995 |
# |      StdTestEpRet |             386 |
# |      MaxTestEpRet |            -476 |
# |      MinTestEpRet |       -1.83e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.41e+04 |
# |      AverageQVals |       -1.74e+03 |
# |          StdQVals |             287 |
# |          MaxQVals |       -1.17e+03 |
# |          MinQVals |       -2.96e+03 |
# |            LossPi |        1.74e+03 |
# |             LossQ |             178 |
# |              Time |             436 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |          -1e+03 |
# |          StdEpRet |             490 |
# |          MaxEpRet |            -282 |
# |          MinEpRet |       -2.08e+03 |
# |  AverageTestEpRet |       -1.08e+03 |
# |      StdTestEpRet |             633 |
# |      MaxTestEpRet |            -213 |
# |      MinTestEpRet |       -2.13e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.58e+04 |
# |      AverageQVals |       -1.73e+03 |
# |          StdQVals |             288 |
# |          MaxQVals |       -1.15e+03 |
# |          MinQVals |       -2.97e+03 |
# |            LossPi |        1.73e+03 |
# |             LossQ |             176 |
# |              Time |             447 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |        -1.3e+03 |
# |          StdEpRet |             436 |
# |          MaxEpRet |            -233 |
# |          MinEpRet |       -2.06e+03 |
# |  AverageTestEpRet |        -1.3e+03 |
# |      StdTestEpRet |             781 |
# |      MaxTestEpRet |            -301 |
# |      MinTestEpRet |       -2.65e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.74e+04 |
# |      AverageQVals |       -1.72e+03 |
# |          StdQVals |             291 |
# |          MaxQVals |       -1.13e+03 |
# |          MinQVals |        -2.9e+03 |
# |            LossPi |        1.72e+03 |
# |             LossQ |             176 |
# ...
# |            LossPi |             315 |
# |             LossQ |             152 |
# |              Time |        1.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             155 |
# |      AverageEpRet |            -742 |
# |          StdEpRet |             375 |
# |          MaxEpRet |            -168 |
# |          MinEpRet |       -1.33e+03 |
# |  AverageTestEpRet |            -782 |
# |      StdTestEpRet |             397 |
# |      MaxTestEpRet |            -191 |
# |      MinTestEpRet |       -1.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.56e+05 |
# |      AverageQVals |            -313 |
# |          StdQVals |             340 |
# |          MaxQVals |             328 |
# |          MinQVals |       -2.03e+03 |
# |            LossPi |             306 |
# |             LossQ |             153 |
# |              Time |        1.45e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             156 |
# |      AverageEpRet |            -870 |
# |          StdEpRet |             485 |
# |          MaxEpRet |            -115 |
# |          MinEpRet |       -1.82e+03 |
# |  AverageTestEpRet |            -746 |
# |      StdTestEpRet |             437 |
# |      MaxTestEpRet |            -290 |
# |      MinTestEpRet |       -1.89e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.57e+05 |
# |      AverageQVals |            -304 |
# |          StdQVals |             338 |
# |          MaxQVals |             340 |
# |          MinQVals |       -2.02e+03 |
# |            LossPi |             297 |
# |             LossQ |             153 |
# |              Time |        1.46e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             157 |
# |      AverageEpRet |            -767 |
# |          StdEpRet |             432 |
# |          MaxEpRet |            -190 |
# |          MinEpRet |       -1.66e+03 |
# |  AverageTestEpRet |            -691 |
# |      StdTestEpRet |             281 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |       -1.24e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.59e+05 |
# |      AverageQVals |            -294 |
# |          StdQVals |             336 |
# |          MaxQVals |             354 |
# |          MinQVals |       -2.02e+03 |
# |            LossPi |             287 |
# |             LossQ |             151 |
# |              Time |        1.47e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             158 |
# |      AverageEpRet |            -764 |
# |          StdEpRet |             394 |
# |          MaxEpRet |            -121 |
# |          MinEpRet |       -1.35e+03 |
# |  AverageTestEpRet |            -885 |
# |      StdTestEpRet |             507 |
# |      MaxTestEpRet |            -298 |
# |      MinTestEpRet |       -2.06e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.61e+05 |
# |      AverageQVals |            -289 |
# |          StdQVals |             334 |
# |          MaxQVals |             350 |
# |          MinQVals |       -1.99e+03 |
# |            LossPi |             281 |
# |             LossQ |             150 |
# |              Time |        1.48e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             159 |
# |      AverageEpRet |            -885 |
# |          StdEpRet |             321 |
# |          MaxEpRet |            -503 |
# |          MinEpRet |       -1.74e+03 |
# |  AverageTestEpRet |            -677 |
# |      StdTestEpRet |             385 |
# |      MaxTestEpRet |             -83 |
# |      MinTestEpRet |       -1.39e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.62e+05 |
# |      AverageQVals |            -284 |
# |          StdQVals |             333 |
# |          MaxQVals |             359 |
# |          MinQVals |       -1.96e+03 |
# |            LossPi |             276 |
# |             LossQ |             147 |
# |              Time |        1.49e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             160 |
# |      AverageEpRet |            -501 |
# |          StdEpRet |             327 |
# |          MaxEpRet |            -138 |
# |          MinEpRet |       -1.16e+03 |
# |  AverageTestEpRet |            -643 |
# |      StdTestEpRet |             235 |
# |      MaxTestEpRet |            -340 |
# |      MinTestEpRet |       -1.07e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+05 |
# |      AverageQVals |            -277 |
# |          StdQVals |             331 |
# |          MaxQVals |             360 |
# |          MinQVals |       -1.94e+03 |
# |            LossPi |             270 |
# |             LossQ |             145 |
# |              Time |         1.5e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             161 |
# |      AverageEpRet |            -809 |
# |          StdEpRet |             657 |
# |          MaxEpRet |            -244 |
# |          MinEpRet |        -2.9e+03 |
# |  AverageTestEpRet |            -723 |
# |      StdTestEpRet |             151 |
# |      MaxTestEpRet |            -508 |
# |      MinTestEpRet |            -977 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.66e+05 |
# |      AverageQVals |            -273 |
# |          StdQVals |             329 |
# |          MaxQVals |             360 |
# |          MinQVals |       -1.88e+03 |
# |            LossPi |             265 |
# |             LossQ |             148 |
# |              Time |        1.51e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             162 |
# |      AverageEpRet |            -656 |
# |          StdEpRet |             306 |
# |          MaxEpRet |            -232 |
# |          MinEpRet |       -1.23e+03 |
# |  AverageTestEpRet |            -780 |
# |      StdTestEpRet |             475 |
# |      MaxTestEpRet |            -311 |
# |      MinTestEpRet |       -1.98e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.67e+05 |
# |      AverageQVals |            -267 |
# |          StdQVals |             329 |
# |          MaxQVals |             362 |
# |          MinQVals |       -1.88e+03 |
# |            LossPi |             259 |
# |             LossQ |             146 |
# |              Time |        1.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             163 |
# |      AverageEpRet |            -676 |
# |          StdEpRet |             259 |
# |          MaxEpRet |            -217 |
# |          MinEpRet |       -1.18e+03 |
# |  AverageTestEpRet |            -798 |
# |      StdTestEpRet |             438 |
# |      MaxTestEpRet |            -329 |
# |      MinTestEpRet |       -1.75e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.69e+05 |
# |      AverageQVals |            -261 |
# |          StdQVals |             327 |
# |          MaxQVals |             361 |
# |          MinQVals |       -1.87e+03 |
# |            LossPi |             254 |
# |             LossQ |             142 |
# |              Time |        1.53e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             164 |
# |      AverageEpRet |          -1e+03 |
# |          StdEpRet |             512 |
# |          MaxEpRet |            -199 |
# |          MinEpRet |       -2.27e+03 |
# |  AverageTestEpRet |            -621 |
# |      StdTestEpRet |             245 |
# |      MaxTestEpRet |            -336 |
# |      MinTestEpRet |       -1.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.71e+05 |
# |      AverageQVals |            -260 |
# |          StdQVals |             327 |
# |          MaxQVals |             370 |
# |          MinQVals |       -1.86e+03 |
# |            LossPi |             252 |
# |             LossQ |             146 |
# |              Time |        1.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             165 |
# |      AverageEpRet |            -662 |
# |          StdEpRet |             347 |
# |          MaxEpRet |            -169 |
# |          MinEpRet |       -1.44e+03 |
# |  AverageTestEpRet |            -932 |
# |      StdTestEpRet |             409 |
# |      MaxTestEpRet |            -358 |
# |      MinTestEpRet |        -1.5e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.72e+05 |
# |      AverageQVals |            -255 |
# |          StdQVals |             326 |
# |          MaxQVals |             368 |
# |          MinQVals |       -1.85e+03 |
# |            LossPi |             248 |
# |             LossQ |             147 |
# |              Time |        1.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             166 |
# |      AverageEpRet |            -985 |
# |          StdEpRet |             609 |
# |          MaxEpRet |            -276 |
# |          MinEpRet |       -2.22e+03 |
# |  AverageTestEpRet |            -783 |
# |      StdTestEpRet |             349 |
# |      MaxTestEpRet |            -200 |
# |      MinTestEpRet |       -1.54e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.74e+05 |
# |      AverageQVals |            -251 |
# |          StdQVals |             326 |
# |          MaxQVals |             364 |
# |          MinQVals |       -1.81e+03 |
# |            LossPi |             244 |
# |             LossQ |             147 |
# |              Time |        1.56e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             167 |
# |      AverageEpRet |            -834 |
# |          StdEpRet |             336 |
# |          MaxEpRet |            -459 |
# |          MinEpRet |       -1.67e+03 |
# |  AverageTestEpRet |       -1.09e+03 |
# |      StdTestEpRet |             707 |
# |      MaxTestEpRet |            -225 |
# |      MinTestEpRet |       -2.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.76e+05 |
# |      AverageQVals |            -247 |
# |          StdQVals |             325 |
# |          MaxQVals |             373 |
# |          MinQVals |       -1.78e+03 |
# |            LossPi |             240 |
# |             LossQ |             144 |
# |              Time |        1.57e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             168 |
# |      AverageEpRet |            -741 |
# |          StdEpRet |             489 |
# |          MaxEpRet |            -138 |
# |          MinEpRet |       -1.88e+03 |
# |  AverageTestEpRet |            -647 |
# |      StdTestEpRet |             252 |
# |      MaxTestEpRet |            -228 |
# |      MinTestEpRet |       -1.19e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.77e+05 |
# |      AverageQVals |            -242 |
# |          StdQVals |             324 |
# |          MaxQVals |             372 |
# |          MinQVals |       -1.74e+03 |
# |            LossPi |             234 |
# |             LossQ |             142 |
# |              Time |        1.58e+03 |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-f7c5d0cdcd6c> in <module>
#      22 # Baseline 0 training
#      23 spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
# ---> 24 polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
#
# ~/Documents/MA2/ps-drl-for-gyroscope-control/resources/spinningup/spinup/algos/pytorch/ddpg/ddpg.py in ddpg(env_fn, actor_critic, ac_kwargs, seed, steps_per_epoch, epochs, replay_size, gamma, polyak, pi_lr, q_lr, batch_size, start_steps, update_after, update_every, act_noise, num_test_episodes, max_ep_len, logger_kwargs, save_freq)
#     281             for _ in range(update_every):
#     282                 batch = replay_buffer.sample_batch(batch_size)
# --> 283                 update(data=batch)
#     284
#     285         # End of epoch handling
#
# ~/Documents/MA2/ps-drl-for-gyroscope-control/resources/spinningup/spinup/algos/pytorch/ddpg/ddpg.py in update(data)
#     194         # First run one gradient descent step for Q.
#     195         q_optimizer.zero_grad()
# --> 196         loss_q, loss_info = compute_loss_q(data)
#     197         loss_q.backward()
#     198         q_optimizer.step()
#
# ~/Documents/MA2/ps-drl-for-gyroscope-control/resources/spinningup/spinup/algos/pytorch/ddpg/ddpg.py in compute_loss_q(data)
#     163         o, a, r, o2, d = data['obs'], data['act'], data['rew'], data['obs2'], data['done']
#     164
# --> 165         q = ac.q(o,a)
#     166
#     167         # Bellman backup for Q function
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/Documents/MA2/ps-drl-for-gyroscope-control/resources/spinningup/spinup/algos/pytorch/ddpg/core.py in forward(self, obs, act)
#      40
#      41     def forward(self, obs, act):
# ---> 42         q = self.q(torch.cat([obs, act], dim=-1))
#      43         return torch.squeeze(q, -1) # Critical to ensure q has right shape.
#      44
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/.local/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1368     if input.dim() == 2 and bias is not None:
#    1369         # fused op is marginally faster
# -> 1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
#    1372         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %% [markdown]
# #### Quadratic reward with penalty

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='ddpg_q_p', exp_name='ddpg_q_p')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0025
qlr_b = 0.0025

# Env function
reward_args = {'qx1':9,'qx2':0.05,'qx3':9,'qx4':0.05,'pu1':0.25,'pu2':0.25, 'bound': 0.2,'penalty':40}
env_fn = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Quadratic with penalty', reward_args = reward_args,ep_len=maxeplen_b)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Warning: Log dir ddpg_q_p already exists! Storing info there anyway.
# Logging data to ddpg_q_p/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(<function env_fn at 0x7f76de14bea0>, env_name='gyroscopeenv-v0', reward_type='Quadratic', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Absolute', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.5, 'pu2': 0.5}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.1, 'pu1': 0.25, 'pu2': 0.25}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with ending penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1, 'sx1': 100, 'sx3': 100, 'end_horizon': 1}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.25, 'pu2': 0.25, 'bound': 0.2, 'penalty': 40}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.25, 'pu2': 0.25, 'bound': 0.2, 'penalty': 40}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with exponential', reward_args={'qx1': 1, 'qx2': 0, 'qx3': 1, 'qx4': 0, 'pu1': 0, 'pu2': 0, 'eax1': 10, 'ebx1': 10, 'eax3': 10, 'ebx3': 10}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.25, 'pu2': 0.25, 'bound': 0.2, 'penalty': 40}, ep_len=110)",
#     "epochs":	100,
#     "exp_name":	"ddpg_q_p",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f76acc4a908>":	{
#             "epoch_dict":	{},
#             "exp_name":	"ddpg_q_p",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_q_p",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_q_p/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"ddpg_q_p",
#         "output_dir":	"ddpg_q_p"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0025,
#     "polyak":	0.995,
#     "q_lr":	0.0025,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 4802, 	 q: 5201
# /home/matthieulc/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |       -1.19e+04 |
# |          StdEpRet |        2.28e+03 |
# |          MaxEpRet |       -8.61e+03 |
# |          MinEpRet |       -1.57e+04 |
# |  AverageTestEpRet |       -1.24e+04 |
# |      StdTestEpRet |        3.84e+03 |
# |      MaxTestEpRet |       -7.62e+03 |
# |      MinTestEpRet |       -1.86e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |      AverageQVals |            -168 |
# |          StdQVals |            97.6 |
# |          MaxQVals |           0.254 |
# |          MinQVals |            -465 |
# |            LossPi |             163 |
# |             LossQ |        2.35e+03 |
# |              Time |            5.85 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |       -1.13e+04 |
# |          StdEpRet |        1.86e+03 |
# |          MaxEpRet |       -7.37e+03 |
# |          MinEpRet |       -1.37e+04 |
# |  AverageTestEpRet |       -8.23e+03 |
# |      StdTestEpRet |        2.45e+03 |
# |      MaxTestEpRet |       -4.66e+03 |
# |      MinTestEpRet |       -1.16e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |      AverageQVals |            -663 |
# |          StdQVals |             241 |
# |          MaxQVals |            -158 |
# |          MinQVals |       -1.47e+03 |
# |            LossPi |             651 |
# |             LossQ |        1.52e+03 |
# |              Time |            16.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |       -1.15e+04 |
# |          StdEpRet |        2.27e+03 |
# |          MaxEpRet |       -7.27e+03 |
# |          MinEpRet |       -1.57e+04 |
# |  AverageTestEpRet |       -7.31e+03 |
# |      StdTestEpRet |        1.81e+03 |
# |      MaxTestEpRet |       -4.57e+03 |
# |      MinTestEpRet |       -1.09e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |      AverageQVals |       -1.33e+03 |
# |          StdQVals |             309 |
# |          MaxQVals |            -587 |
# |          MinQVals |       -2.33e+03 |
# |            LossPi |        1.31e+03 |
# |             LossQ |         2.7e+03 |
# |              Time |              26 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |        -1.2e+04 |
# |          StdEpRet |        2.51e+03 |
# |          MaxEpRet |       -8.32e+03 |
# |          MinEpRet |       -1.61e+04 |
# |  AverageTestEpRet |       -6.45e+03 |
# |      StdTestEpRet |        1.18e+03 |
# |      MaxTestEpRet |       -3.94e+03 |
# |      MinTestEpRet |       -7.94e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |      AverageQVals |       -1.89e+03 |
# |          StdQVals |             337 |
# |          MaxQVals |            -983 |
# |          MinQVals |       -2.99e+03 |
# |            LossPi |        1.86e+03 |
# |             LossQ |        3.52e+03 |
# |              Time |            36.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |       -1.17e+04 |
# |          StdEpRet |             991 |
# |          MaxEpRet |       -8.96e+03 |
# |          MinEpRet |        -1.3e+04 |
# |  AverageTestEpRet |       -7.96e+03 |
# |      StdTestEpRet |        3.86e+03 |
# |      MaxTestEpRet |       -4.36e+03 |
# |      MinTestEpRet |       -1.87e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |      AverageQVals |       -2.36e+03 |
# |          StdQVals |             360 |
# |          MaxQVals |       -1.39e+03 |
# |          MinQVals |       -3.51e+03 |
# |            LossPi |        2.32e+03 |
# |             LossQ |        3.95e+03 |
# |              Time |            46.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |       -1.07e+04 |
# |          StdEpRet |         1.7e+03 |
# |          MaxEpRet |       -7.27e+03 |
# |          MinEpRet |       -1.36e+04 |
# |  AverageTestEpRet |       -7.07e+03 |
# |      StdTestEpRet |        1.66e+03 |
# |      MaxTestEpRet |       -4.91e+03 |
# |      MinTestEpRet |       -1.12e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |      AverageQVals |        -2.8e+03 |
# |          StdQVals |             388 |
# |          MaxQVals |       -1.71e+03 |
# |          MinQVals |       -4.13e+03 |
# |            LossPi |        2.75e+03 |
# |             LossQ |        4.08e+03 |
# |              Time |            57.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |       -7.35e+03 |
# |          StdEpRet |        2.15e+03 |
# |          MaxEpRet |       -4.65e+03 |
# |          MinEpRet |       -1.11e+04 |
# |  AverageTestEpRet |       -5.67e+03 |
# |      StdTestEpRet |        1.83e+03 |
# |      MaxTestEpRet |            -944 |
# |      MinTestEpRet |       -8.44e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |      AverageQVals |       -3.14e+03 |
# |          StdQVals |             419 |
# |          MaxQVals |       -2.04e+03 |
# |          MinQVals |        -4.6e+03 |
# |            LossPi |         3.1e+03 |
# |             LossQ |        3.74e+03 |
# |              Time |            68.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |       -5.88e+03 |
# |          StdEpRet |        1.66e+03 |
# |          MaxEpRet |       -2.02e+03 |
# |          MinEpRet |       -8.79e+03 |
# |  AverageTestEpRet |       -6.06e+03 |
# |      StdTestEpRet |         1.3e+03 |
# |      MaxTestEpRet |       -4.55e+03 |
# |      MinTestEpRet |       -8.44e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |      AverageQVals |        -3.4e+03 |
# |          StdQVals |             464 |
# |          MaxQVals |       -2.32e+03 |
# |          MinQVals |       -4.94e+03 |
# |            LossPi |        3.36e+03 |
# |             LossQ |        3.27e+03 |
# |              Time |            78.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |       -6.14e+03 |
# |          StdEpRet |        1.91e+03 |
# |          MaxEpRet |       -3.09e+03 |
# |          MinEpRet |       -1.01e+04 |
# |  AverageTestEpRet |       -6.79e+03 |
# |      StdTestEpRet |        1.04e+03 |
# |      MaxTestEpRet |       -4.98e+03 |
# |      MinTestEpRet |       -8.97e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |      AverageQVals |       -3.65e+03 |
# |          StdQVals |             498 |
# |          MaxQVals |        -2.6e+03 |
# |          MinQVals |       -5.31e+03 |
# |            LossPi |        3.61e+03 |
# |             LossQ |        2.93e+03 |
# |              Time |            89.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |       -7.11e+03 |
# |          StdEpRet |        1.73e+03 |
# |          MaxEpRet |       -4.88e+03 |
# |          MinEpRet |       -1.16e+04 |
# |  AverageTestEpRet |       -5.16e+03 |
# |      StdTestEpRet |        1.53e+03 |
# |      MaxTestEpRet |            -989 |
# |      MinTestEpRet |       -6.47e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |       -3.89e+03 |
# |          StdQVals |             526 |
# |          MaxQVals |       -2.85e+03 |
# |          MinQVals |       -5.68e+03 |
# |            LossPi |        3.85e+03 |
# |             LossQ |        2.74e+03 |
# |              Time |             101 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |       -6.17e+03 |
# |          StdEpRet |        1.89e+03 |
# |          MaxEpRet |       -2.18e+03 |
# |          MinEpRet |       -1.03e+04 |
# |  AverageTestEpRet |        -7.2e+03 |
# |      StdTestEpRet |         2.2e+03 |
# |      MaxTestEpRet |       -4.89e+03 |
# |      MinTestEpRet |       -1.32e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |      AverageQVals |       -4.11e+03 |
# |          StdQVals |             554 |
# |          MaxQVals |       -3.06e+03 |
# |          MinQVals |       -6.04e+03 |
# |            LossPi |        4.07e+03 |
# |             LossQ |        2.64e+03 |
# |              Time |             111 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |       -7.74e+03 |
# |          StdEpRet |        1.96e+03 |
# |          MaxEpRet |       -5.31e+03 |
# |          MinEpRet |       -1.21e+04 |
# |  AverageTestEpRet |          -6e+03 |
# |      StdTestEpRet |             759 |
# |      MaxTestEpRet |       -4.77e+03 |
# |      MinTestEpRet |       -6.87e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |      AverageQVals |       -4.32e+03 |
# |          StdQVals |             582 |
# |          MaxQVals |       -3.18e+03 |
# |          MinQVals |       -6.31e+03 |
# |            LossPi |        4.29e+03 |
# |             LossQ |        2.58e+03 |
# |              Time |             122 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |       -6.21e+03 |
# |          StdEpRet |        1.67e+03 |
# |          MaxEpRet |       -3.09e+03 |
# |          MinEpRet |       -1.08e+04 |
# |  AverageTestEpRet |       -6.62e+03 |
# |      StdTestEpRet |        2.09e+03 |
# |      MaxTestEpRet |       -4.63e+03 |
# |      MinTestEpRet |       -1.12e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |      AverageQVals |       -4.55e+03 |
# |          StdQVals |             609 |
# |          MaxQVals |       -3.31e+03 |
# |          MinQVals |       -6.73e+03 |
# |            LossPi |        4.53e+03 |
# |             LossQ |        2.61e+03 |
# |              Time |             133 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |        -5.9e+03 |
# |          StdEpRet |             838 |
# |          MaxEpRet |       -4.69e+03 |
# |          MinEpRet |       -7.88e+03 |
# |  AverageTestEpRet |       -5.37e+03 |
# |      StdTestEpRet |        1.67e+03 |
# |      MaxTestEpRet |       -2.51e+03 |
# |      MinTestEpRet |       -8.34e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |      AverageQVals |       -4.76e+03 |
# |          StdQVals |             628 |
# |          MaxQVals |       -3.47e+03 |
# |          MinQVals |       -7.04e+03 |
# |            LossPi |        4.73e+03 |
# |             LossQ |        2.57e+03 |
# |              Time |             142 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |       -6.28e+03 |
# |          StdEpRet |        1.74e+03 |
# |          MaxEpRet |       -1.82e+03 |
# |          MinEpRet |       -1.05e+04 |
# |  AverageTestEpRet |       -5.13e+03 |
# |      StdTestEpRet |        1.97e+03 |
# |      MaxTestEpRet |       -1.09e+03 |
# |      MinTestEpRet |       -6.95e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |      AverageQVals |       -4.95e+03 |
# |          StdQVals |             645 |
# |          MaxQVals |       -3.61e+03 |
# |          MinQVals |       -7.25e+03 |
# |            LossPi |        4.93e+03 |
# |             LossQ |        2.56e+03 |
# |              Time |             152 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |        -5.9e+03 |
# |          StdEpRet |        1.84e+03 |
# |          MaxEpRet |       -1.02e+03 |
# |          MinEpRet |       -7.58e+03 |
# |  AverageTestEpRet |       -8.33e+03 |
# |      StdTestEpRet |        3.86e+03 |
# |      MaxTestEpRet |       -4.81e+03 |
# |      MinTestEpRet |       -1.44e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |      AverageQVals |       -5.15e+03 |
# |          StdQVals |             663 |
# |          MaxQVals |       -3.76e+03 |
# |          MinQVals |       -7.52e+03 |
# |            LossPi |        5.13e+03 |
# |             LossQ |        2.55e+03 |
# |              Time |             163 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |       -5.55e+03 |
# |          StdEpRet |        2.02e+03 |
# |          MaxEpRet |       -1.18e+03 |
# |          MinEpRet |       -9.02e+03 |
# |  AverageTestEpRet |       -6.87e+03 |
# |      StdTestEpRet |        2.21e+03 |
# |      MaxTestEpRet |       -4.79e+03 |
# |      MinTestEpRet |       -1.23e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |      AverageQVals |       -5.32e+03 |
# |          StdQVals |             679 |
# |          MaxQVals |        -3.9e+03 |
# |          MinQVals |       -7.77e+03 |
# |            LossPi |        5.29e+03 |
# |             LossQ |        2.53e+03 |
# |              Time |             173 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |       -5.29e+03 |
# |          StdEpRet |        1.56e+03 |
# |          MaxEpRet |       -2.52e+03 |
# |          MinEpRet |       -8.53e+03 |
# |  AverageTestEpRet |       -5.83e+03 |
# |      StdTestEpRet |             954 |
# |      MaxTestEpRet |       -4.09e+03 |
# |      MinTestEpRet |       -7.37e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |      AverageQVals |       -5.46e+03 |
# |          StdQVals |             698 |
# |          MaxQVals |       -4.01e+03 |
# |          MinQVals |       -7.95e+03 |
# |            LossPi |        5.44e+03 |
# |             LossQ |        2.53e+03 |
# |              Time |             183 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |       -6.34e+03 |
# |          StdEpRet |        1.21e+03 |
# |          MaxEpRet |       -4.54e+03 |
# |          MinEpRet |       -8.72e+03 |
# |  AverageTestEpRet |       -5.17e+03 |
# |      StdTestEpRet |        1.64e+03 |
# |      MaxTestEpRet |       -1.42e+03 |
# |      MinTestEpRet |        -8.3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |      AverageQVals |        -5.6e+03 |
# |          StdQVals |             706 |
# |          MaxQVals |       -4.12e+03 |
# |          MinQVals |       -8.08e+03 |
# |            LossPi |        5.57e+03 |
# |             LossQ |        2.53e+03 |
# |              Time |             192 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |       -5.85e+03 |
# |          StdEpRet |        1.41e+03 |
# |          MaxEpRet |       -2.67e+03 |
# |          MinEpRet |       -8.38e+03 |
# |  AverageTestEpRet |       -5.66e+03 |
# |      StdTestEpRet |        1.06e+03 |
# |      MaxTestEpRet |       -4.45e+03 |
# |      MinTestEpRet |       -7.36e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |       -5.72e+03 |
# |          StdQVals |             723 |
# |          MaxQVals |       -4.21e+03 |
# |          MinQVals |       -8.24e+03 |
# |            LossPi |         5.7e+03 |
# |             LossQ |        2.52e+03 |
# |              Time |             202 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |       -6.02e+03 |
# |          StdEpRet |        2.07e+03 |
# |          MaxEpRet |          -2e+03 |
# |          MinEpRet |       -9.82e+03 |
# |  AverageTestEpRet |       -6.84e+03 |
# |      StdTestEpRet |        2.35e+03 |
# |      MaxTestEpRet |       -2.77e+03 |
# |      MinTestEpRet |        -1.2e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |      AverageQVals |       -5.83e+03 |
# |          StdQVals |             747 |
# |          MaxQVals |        -4.3e+03 |
# |          MinQVals |       -8.43e+03 |
# |            LossPi |        5.81e+03 |
# |             LossQ |        2.57e+03 |
# |              Time |             212 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |       -6.43e+03 |
# |          StdEpRet |        1.54e+03 |
# |          MaxEpRet |       -2.79e+03 |
# |          MinEpRet |       -9.04e+03 |
# |  AverageTestEpRet |       -4.88e+03 |
# |      StdTestEpRet |        1.69e+03 |
# |      MaxTestEpRet |            -215 |
# |      MinTestEpRet |       -6.33e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |      AverageQVals |       -5.95e+03 |
# |          StdQVals |             768 |
# |          MaxQVals |       -4.39e+03 |
# |          MinQVals |       -8.56e+03 |
# |            LossPi |        5.93e+03 |
# |             LossQ |         2.6e+03 |
# |              Time |             223 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |       -5.39e+03 |
# |          StdEpRet |        1.59e+03 |
# |          MaxEpRet |       -1.14e+03 |
# |          MinEpRet |          -8e+03 |
# |  AverageTestEpRet |        -6.5e+03 |
# |      StdTestEpRet |        1.12e+03 |
# |      MaxTestEpRet |       -4.67e+03 |
# |      MinTestEpRet |       -8.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |      AverageQVals |       -6.05e+03 |
# |          StdQVals |             783 |
# |          MaxQVals |       -4.46e+03 |
# |          MinQVals |        -8.7e+03 |
# |            LossPi |        6.03e+03 |
# |             LossQ |        2.63e+03 |
# |              Time |             234 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |       -6.02e+03 |
# |          StdEpRet |             973 |
# |          MaxEpRet |       -4.41e+03 |
# |          MinEpRet |       -7.85e+03 |
# |  AverageTestEpRet |       -5.32e+03 |
# |      StdTestEpRet |        1.77e+03 |
# |      MaxTestEpRet |            -641 |
# |      MinTestEpRet |       -7.17e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |      AverageQVals |       -6.14e+03 |
# |          StdQVals |             804 |
# |          MaxQVals |       -4.52e+03 |
# |          MinQVals |       -8.91e+03 |
# |            LossPi |        6.12e+03 |
# |             LossQ |        2.73e+03 |
# |              Time |             244 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |       -5.96e+03 |
# |          StdEpRet |             953 |
# |          MaxEpRet |       -4.64e+03 |
# |          MinEpRet |       -8.47e+03 |
# |  AverageTestEpRet |       -6.56e+03 |
# |      StdTestEpRet |         1.4e+03 |
# |      MaxTestEpRet |       -4.03e+03 |
# |      MinTestEpRet |       -9.01e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |      AverageQVals |       -6.23e+03 |
# |          StdQVals |             816 |
# |          MaxQVals |       -4.59e+03 |
# |          MinQVals |          -9e+03 |
# |            LossPi |        6.21e+03 |
# |             LossQ |        2.71e+03 |
# |              Time |             254 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |       -5.76e+03 |
# |          StdEpRet |        1.74e+03 |
# |          MaxEpRet |            -868 |
# |          MinEpRet |       -8.37e+03 |
# |  AverageTestEpRet |       -6.13e+03 |
# |      StdTestEpRet |        1.58e+03 |
# |      MaxTestEpRet |       -3.97e+03 |
# |      MinTestEpRet |       -9.42e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |      AverageQVals |        -6.3e+03 |
# |          StdQVals |             825 |
# |          MaxQVals |       -4.66e+03 |
# |          MinQVals |        -9.1e+03 |
# |            LossPi |        6.28e+03 |
# |             LossQ |        2.67e+03 |
# |              Time |             264 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |       -5.83e+03 |
# |          StdEpRet |        1.02e+03 |
# |          MaxEpRet |       -4.37e+03 |
# |          MinEpRet |       -8.09e+03 |
# |  AverageTestEpRet |       -6.38e+03 |
# |      StdTestEpRet |             898 |
# |      MaxTestEpRet |       -5.18e+03 |
# |      MinTestEpRet |       -7.52e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |      AverageQVals |       -6.38e+03 |
# |          StdQVals |             840 |
# |          MaxQVals |       -4.72e+03 |
# |          MinQVals |       -9.23e+03 |
# |            LossPi |        6.36e+03 |
# |             LossQ |        2.67e+03 |
# |              Time |             274 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |       -6.44e+03 |
# |          StdEpRet |        1.43e+03 |
# |          MaxEpRet |       -4.03e+03 |
# |          MinEpRet |       -9.21e+03 |
# |  AverageTestEpRet |       -5.54e+03 |
# |      StdTestEpRet |        1.04e+03 |
# |      MaxTestEpRet |       -4.25e+03 |
# |      MinTestEpRet |       -7.83e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |      AverageQVals |       -6.45e+03 |
# |          StdQVals |             854 |
# |          MaxQVals |       -4.76e+03 |
# |          MinQVals |       -9.32e+03 |
# |            LossPi |        6.43e+03 |
# |             LossQ |        2.64e+03 |
# |              Time |             284 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |       -6.61e+03 |
# |          StdEpRet |        1.35e+03 |
# |          MaxEpRet |       -3.59e+03 |
# |          MinEpRet |       -9.97e+03 |
# |  AverageTestEpRet |       -7.16e+03 |
# |      StdTestEpRet |        2.73e+03 |
# |      MaxTestEpRet |       -4.86e+03 |
# |      MinTestEpRet |       -1.48e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |      AverageQVals |       -6.52e+03 |
# |          StdQVals |             863 |
# |          MaxQVals |       -4.78e+03 |
# |          MinQVals |       -9.42e+03 |
# |            LossPi |         6.5e+03 |
# |             LossQ |        2.68e+03 |
# |              Time |             294 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |       -6.53e+03 |
# |          StdEpRet |        1.35e+03 |
# |          MaxEpRet |       -4.26e+03 |
# |          MinEpRet |       -9.83e+03 |
# |  AverageTestEpRet |       -6.52e+03 |
# |      StdTestEpRet |        1.76e+03 |
# |      MaxTestEpRet |       -2.98e+03 |
# |      MinTestEpRet |       -9.91e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |       -6.58e+03 |
# |          StdQVals |             878 |
# |          MaxQVals |       -4.79e+03 |
# |          MinQVals |       -9.59e+03 |
# |            LossPi |        6.56e+03 |
# |             LossQ |         2.7e+03 |
# |              Time |             305 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |       -5.59e+03 |
# |          StdEpRet |         2.4e+03 |
# |          MaxEpRet |            -225 |
# |          MinEpRet |       -8.87e+03 |
# |  AverageTestEpRet |       -5.49e+03 |
# |      StdTestEpRet |             826 |
# |      MaxTestEpRet |       -4.65e+03 |
# |      MinTestEpRet |       -7.67e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |      AverageQVals |       -6.63e+03 |
# |          StdQVals |             891 |
# |          MaxQVals |       -4.81e+03 |
# |          MinQVals |       -9.73e+03 |
# |            LossPi |        6.61e+03 |
# |             LossQ |        2.68e+03 |
# |              Time |             315 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |       -5.45e+03 |
# |          StdEpRet |        1.54e+03 |
# |          MaxEpRet |       -1.89e+03 |
# |          MinEpRet |       -8.84e+03 |
# |  AverageTestEpRet |       -5.98e+03 |
# |      StdTestEpRet |        1.07e+03 |
# |      MaxTestEpRet |       -4.55e+03 |
# |      MinTestEpRet |       -7.92e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |      AverageQVals |       -6.68e+03 |
# |          StdQVals |             911 |
# |          MaxQVals |       -4.83e+03 |
# |          MinQVals |       -9.92e+03 |
# |            LossPi |        6.66e+03 |
# |             LossQ |        2.66e+03 |
# |              Time |             325 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |       -5.76e+03 |
# |          StdEpRet |         1.6e+03 |
# |          MaxEpRet |       -1.91e+03 |
# |          MinEpRet |       -7.88e+03 |
# |  AverageTestEpRet |       -5.38e+03 |
# |      StdTestEpRet |        1.94e+03 |
# |      MaxTestEpRet |            -597 |
# |      MinTestEpRet |       -7.34e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |      AverageQVals |       -6.72e+03 |
# |          StdQVals |             923 |
# |          MaxQVals |       -4.84e+03 |
# |          MinQVals |          -1e+04 |
# |            LossPi |         6.7e+03 |
# |             LossQ |        2.66e+03 |
# |              Time |             335 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |       -5.97e+03 |
# |          StdEpRet |        1.32e+03 |
# |          MaxEpRet |       -4.09e+03 |
# |          MinEpRet |       -8.65e+03 |
# |  AverageTestEpRet |       -6.23e+03 |
# |      StdTestEpRet |             875 |
# |      MaxTestEpRet |       -4.74e+03 |
# |      MinTestEpRet |       -7.29e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |      AverageQVals |       -6.75e+03 |
# |          StdQVals |             940 |
# |          MaxQVals |       -4.83e+03 |
# |          MinQVals |       -1.02e+04 |
# |            LossPi |        6.72e+03 |
# |             LossQ |        2.69e+03 |
# |              Time |             344 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |       -6.11e+03 |
# |          StdEpRet |        1.14e+03 |
# |          MaxEpRet |       -4.75e+03 |
# |          MinEpRet |       -8.82e+03 |
# |  AverageTestEpRet |       -6.37e+03 |
# |      StdTestEpRet |        1.24e+03 |
# |      MaxTestEpRet |       -5.04e+03 |
# |      MinTestEpRet |        -8.8e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |      AverageQVals |       -6.78e+03 |
# |          StdQVals |             951 |
# |          MaxQVals |       -4.84e+03 |
# |          MinQVals |       -1.03e+04 |
# |            LossPi |        6.76e+03 |
# |             LossQ |         2.7e+03 |
# |              Time |             355 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |       -5.21e+03 |
# |          StdEpRet |        1.31e+03 |
# |          MaxEpRet |       -2.86e+03 |
# |          MinEpRet |       -8.43e+03 |
# |  AverageTestEpRet |       -5.36e+03 |
# |      StdTestEpRet |        2.16e+03 |
# |      MaxTestEpRet |       -1.39e+03 |
# |      MinTestEpRet |       -1.05e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |      AverageQVals |       -6.81e+03 |
# |          StdQVals |             956 |
# |          MaxQVals |       -4.85e+03 |
# |          MinQVals |       -1.03e+04 |
# |            LossPi |        6.79e+03 |
# |             LossQ |        2.67e+03 |
# |              Time |             366 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |       -5.59e+03 |
# |          StdEpRet |        1.27e+03 |
# |          MaxEpRet |       -4.02e+03 |
# |          MinEpRet |       -8.45e+03 |
# |  AverageTestEpRet |       -5.67e+03 |
# |      StdTestEpRet |             611 |
# |      MaxTestEpRet |       -5.08e+03 |
# |      MinTestEpRet |       -7.22e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |      AverageQVals |       -6.82e+03 |
# |          StdQVals |             963 |
# |          MaxQVals |       -4.85e+03 |
# |          MinQVals |       -1.04e+04 |
# |            LossPi |         6.8e+03 |
# |             LossQ |        2.64e+03 |
# |              Time |             376 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |       -5.05e+03 |
# |          StdEpRet |        1.43e+03 |
# |          MaxEpRet |       -1.72e+03 |
# |          MinEpRet |       -7.06e+03 |
# |  AverageTestEpRet |       -5.75e+03 |
# |      StdTestEpRet |             858 |
# |      MaxTestEpRet |       -4.83e+03 |
# |      MinTestEpRet |       -7.15e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |      AverageQVals |       -6.85e+03 |
# |          StdQVals |             973 |
# |          MaxQVals |       -4.78e+03 |
# |          MinQVals |       -1.05e+04 |
# |            LossPi |        6.83e+03 |
# |             LossQ |         2.6e+03 |
# |              Time |             387 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |       -6.25e+03 |
# |          StdEpRet |        1.85e+03 |
# |          MaxEpRet |       -1.88e+03 |
# |          MinEpRet |       -1.06e+04 |
# |  AverageTestEpRet |       -6.02e+03 |
# |      StdTestEpRet |        1.34e+03 |
# |      MaxTestEpRet |       -4.26e+03 |
# |      MinTestEpRet |       -8.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |      AverageQVals |       -6.87e+03 |
# |          StdQVals |             978 |
# |          MaxQVals |       -4.78e+03 |
# |          MinQVals |       -1.05e+04 |
# |            LossPi |        6.85e+03 |
# |             LossQ |        2.62e+03 |
# |              Time |             396 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |       -6.26e+03 |
# |          StdEpRet |        1.11e+03 |
# |          MaxEpRet |       -4.63e+03 |
# |          MinEpRet |       -8.32e+03 |
# |  AverageTestEpRet |        -5.3e+03 |
# |      StdTestEpRet |             935 |
# |      MaxTestEpRet |       -4.61e+03 |
# |      MinTestEpRet |       -7.95e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |       -6.89e+03 |
# |          StdQVals |             987 |
# |          MaxQVals |       -4.78e+03 |
# |          MinQVals |       -1.06e+04 |
# |            LossPi |        6.87e+03 |
# |             LossQ |        2.57e+03 |
# |              Time |             406 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |       -5.98e+03 |
# |          StdEpRet |        1.28e+03 |
# |          MaxEpRet |       -3.33e+03 |
# |          MinEpRet |       -8.96e+03 |
# |  AverageTestEpRet |        -5.1e+03 |
# |      StdTestEpRet |        1.98e+03 |
# |      MaxTestEpRet |            -796 |
# |      MinTestEpRet |       -7.27e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |      AverageQVals |       -6.92e+03 |
# |          StdQVals |             986 |
# |          MaxQVals |       -4.78e+03 |
# |          MinQVals |       -1.06e+04 |
# |            LossPi |         6.9e+03 |
# |             LossQ |        2.54e+03 |
# |              Time |             416 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |       -5.38e+03 |
# |          StdEpRet |        1.56e+03 |
# |          MaxEpRet |       -1.53e+03 |
# |          MinEpRet |       -7.66e+03 |
# |  AverageTestEpRet |       -4.62e+03 |
# |      StdTestEpRet |        2.18e+03 |
# |      MaxTestEpRet |            -762 |
# |      MinTestEpRet |       -7.02e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |      AverageQVals |       -6.93e+03 |
# |          StdQVals |             990 |
# |          MaxQVals |       -4.77e+03 |
# |          MinQVals |       -1.07e+04 |
# |            LossPi |        6.91e+03 |
# |             LossQ |        2.55e+03 |
# |              Time |             426 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |       -5.41e+03 |
# |          StdEpRet |        1.21e+03 |
# |          MaxEpRet |       -2.01e+03 |
# |          MinEpRet |       -7.39e+03 |
# |  AverageTestEpRet |       -5.73e+03 |
# |      StdTestEpRet |        1.32e+03 |
# |      MaxTestEpRet |       -3.47e+03 |
# |      MinTestEpRet |        -7.8e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |      AverageQVals |       -6.94e+03 |
# |          StdQVals |             992 |
# |          MaxQVals |       -4.77e+03 |
# |          MinQVals |       -1.07e+04 |
# |            LossPi |        6.92e+03 |
# |             LossQ |        2.49e+03 |
# |              Time |             436 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |       -5.27e+03 |
# |          StdEpRet |        1.31e+03 |
# |          MaxEpRet |       -2.14e+03 |
# |          MinEpRet |       -7.14e+03 |
# |  AverageTestEpRet |       -4.93e+03 |
# |      StdTestEpRet |        1.76e+03 |
# |      MaxTestEpRet |            -614 |
# |      MinTestEpRet |       -7.42e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |      AverageQVals |       -6.94e+03 |
# |          StdQVals |           1e+03 |
# |          MaxQVals |       -4.78e+03 |
# |          MinQVals |       -1.07e+04 |
# |            LossPi |        6.92e+03 |
# |             LossQ |        2.38e+03 |
# |              Time |             446 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |       -5.16e+03 |
# |          StdEpRet |        1.67e+03 |
# |          MaxEpRet |        -1.1e+03 |
# |          MinEpRet |       -7.44e+03 |
# |  AverageTestEpRet |        -5.6e+03 |
# |      StdTestEpRet |             646 |
# |      MaxTestEpRet |       -4.71e+03 |
# |      MinTestEpRet |       -6.65e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |      AverageQVals |       -6.94e+03 |
# |          StdQVals |        1.01e+03 |
# |          MaxQVals |       -4.79e+03 |
# |          MinQVals |       -1.07e+04 |
# |            LossPi |        6.92e+03 |
# |             LossQ |        2.39e+03 |
# |              Time |             456 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |       -5.37e+03 |
# |          StdEpRet |             853 |
# |          MaxEpRet |       -3.07e+03 |
# |          MinEpRet |       -6.66e+03 |
# |  AverageTestEpRet |       -4.96e+03 |
# |      StdTestEpRet |        1.43e+03 |
# |      MaxTestEpRet |            -939 |
# |      MinTestEpRet |       -6.08e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |      AverageQVals |       -6.94e+03 |
# |          StdQVals |        1.01e+03 |
# |          MaxQVals |       -4.78e+03 |
# |          MinQVals |       -1.14e+04 |
# |            LossPi |        6.92e+03 |
# |             LossQ |        2.31e+03 |
# |              Time |             465 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |       -5.92e+03 |
# |          StdEpRet |             944 |
# |          MaxEpRet |       -4.71e+03 |
# |          MinEpRet |       -7.99e+03 |
# |  AverageTestEpRet |       -5.19e+03 |
# |      StdTestEpRet |        1.61e+03 |
# |      MaxTestEpRet |            -764 |
# |      MinTestEpRet |       -7.06e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.75e+04 |
# |      AverageQVals |       -6.93e+03 |
# |          StdQVals |        1.02e+03 |
# |          MaxQVals |       -4.76e+03 |
# |          MinQVals |       -1.14e+04 |
# |            LossPi |        6.91e+03 |
# |             LossQ |        2.29e+03 |
# |              Time |             476 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |       -6.17e+03 |
# |          StdEpRet |        1.99e+03 |
# |          MaxEpRet |       -4.65e+03 |
# |          MinEpRet |        -1.3e+04 |
# |  AverageTestEpRet |       -5.27e+03 |
# |      StdTestEpRet |        1.31e+03 |
# |      MaxTestEpRet |       -2.12e+03 |
# |      MinTestEpRet |       -7.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.92e+04 |
# |      AverageQVals |       -6.93e+03 |
# |          StdQVals |        1.02e+03 |
# |          MaxQVals |       -4.74e+03 |
# |          MinQVals |       -1.13e+04 |
# |            LossPi |        6.91e+03 |
# |             LossQ |        2.24e+03 |
# |              Time |             486 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |       -5.09e+03 |
# |          StdEpRet |        1.27e+03 |
# |          MaxEpRet |       -2.41e+03 |
# |          MinEpRet |       -6.85e+03 |
# |  AverageTestEpRet |       -5.89e+03 |
# |      StdTestEpRet |        1.18e+03 |
# |      MaxTestEpRet |       -4.79e+03 |
# |      MinTestEpRet |        -8.8e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+04 |
# |      AverageQVals |       -6.92e+03 |
# |          StdQVals |        1.02e+03 |
# |          MaxQVals |       -4.75e+03 |
# |          MinQVals |       -1.12e+04 |
# |            LossPi |         6.9e+03 |
# |             LossQ |        2.16e+03 |
# |              Time |             496 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |        -4.8e+03 |
# |          StdEpRet |        1.56e+03 |
# |          MaxEpRet |       -1.55e+03 |
# |          MinEpRet |       -6.94e+03 |
# |  AverageTestEpRet |       -5.97e+03 |
# |      StdTestEpRet |           2e+03 |
# |      MaxTestEpRet |       -3.02e+03 |
# |      MinTestEpRet |       -9.75e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |        -6.9e+03 |
# |          StdQVals |        1.03e+03 |
# |          MaxQVals |       -4.76e+03 |
# |          MinQVals |       -1.12e+04 |
# |            LossPi |        6.88e+03 |
# |             LossQ |         2.1e+03 |
# |              Time |             506 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |       -5.49e+03 |
# |          StdEpRet |        1.56e+03 |
# |          MaxEpRet |       -2.75e+03 |
# |          MinEpRet |       -7.97e+03 |
# |  AverageTestEpRet |       -5.91e+03 |
# |      StdTestEpRet |        1.36e+03 |
# |      MaxTestEpRet |       -4.81e+03 |
# |      MinTestEpRet |       -9.58e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.41e+04 |
# |      AverageQVals |       -6.89e+03 |
# |          StdQVals |        1.03e+03 |
# |          MaxQVals |       -4.76e+03 |
# |          MinQVals |       -1.12e+04 |
# |            LossPi |        6.87e+03 |
# |             LossQ |        2.07e+03 |
# |              Time |             516 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |       -5.11e+03 |
# |          StdEpRet |        1.31e+03 |
# |          MaxEpRet |          -3e+03 |
# |          MinEpRet |       -9.17e+03 |
# |  AverageTestEpRet |       -5.71e+03 |
# |      StdTestEpRet |        1.45e+03 |
# |      MaxTestEpRet |        -2.7e+03 |
# |      MinTestEpRet |       -8.18e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.58e+04 |
# |      AverageQVals |       -6.89e+03 |
# |          StdQVals |        1.03e+03 |
# |          MaxQVals |       -4.77e+03 |
# |          MinQVals |       -1.12e+04 |
# |            LossPi |        6.87e+03 |
# |             LossQ |        2.02e+03 |
# |              Time |             526 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |       -5.91e+03 |
# |          StdEpRet |        1.53e+03 |
# |          MaxEpRet |       -1.22e+03 |
# |          MinEpRet |       -7.92e+03 |
# |  AverageTestEpRet |       -4.88e+03 |
# |      StdTestEpRet |        2.25e+03 |
# |      MaxTestEpRet |            -419 |
# |      MinTestEpRet |       -7.32e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.74e+04 |
# |      AverageQVals |       -6.89e+03 |
# |          StdQVals |        1.04e+03 |
# |          MaxQVals |       -4.77e+03 |
# |          MinQVals |       -1.12e+04 |
# |            LossPi |        6.87e+03 |
# |             LossQ |        2.04e+03 |
# |              Time |             536 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |       -5.11e+03 |
# |          StdEpRet |        1.15e+03 |
# |          MaxEpRet |       -2.07e+03 |
# |          MinEpRet |        -6.8e+03 |
# |  AverageTestEpRet |       -5.92e+03 |
# |      StdTestEpRet |             966 |
# |      MaxTestEpRet |       -4.52e+03 |
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              82 |
# |      AverageEpRet |       -6.56e+03 |
# |          StdEpRet |        1.98e+03 |
# |          MaxEpRet |       -4.89e+03 |
# |          MinEpRet |       -1.21e+04 |
# |  AverageTestEpRet |       -5.83e+03 |
# |      StdTestEpRet |        1.96e+03 |
# |      MaxTestEpRet |       -1.36e+03 |
# |      MinTestEpRet |       -9.22e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.35e+05 |
# |      AverageQVals |        -6.7e+03 |
# |          StdQVals |        1.08e+03 |
# |          MaxQVals |       -4.37e+03 |
# |          MinQVals |        -1.1e+04 |
# |            LossPi |        6.68e+03 |
# |             LossQ |         1.7e+03 |
# |              Time |             839 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              83 |
# |      AverageEpRet |       -5.97e+03 |
# |          StdEpRet |        1.47e+03 |
# |          MaxEpRet |       -4.17e+03 |
# |          MinEpRet |       -8.83e+03 |
# |  AverageTestEpRet |       -4.46e+03 |
# |      StdTestEpRet |         1.7e+03 |
# |      MaxTestEpRet |       -1.11e+03 |
# |      MinTestEpRet |       -6.72e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.37e+05 |
# |      AverageQVals |       -6.69e+03 |
# |          StdQVals |        1.09e+03 |
# |          MaxQVals |       -4.37e+03 |
# |          MinQVals |       -1.12e+04 |
# |            LossPi |        6.67e+03 |
# |             LossQ |        1.71e+03 |
# |              Time |             849 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |        -5.9e+03 |
# |          StdEpRet |             953 |
# |          MaxEpRet |       -3.31e+03 |
# |          MinEpRet |       -7.44e+03 |
# |  AverageTestEpRet |       -5.65e+03 |
# |      StdTestEpRet |        1.74e+03 |
# |      MaxTestEpRet |       -2.19e+03 |
# |      MinTestEpRet |       -8.16e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.39e+05 |
# |      AverageQVals |       -6.68e+03 |
# |          StdQVals |        1.09e+03 |
# |          MaxQVals |       -4.34e+03 |
# |          MinQVals |       -1.12e+04 |
# |            LossPi |        6.66e+03 |
# |             LossQ |        1.72e+03 |
# |              Time |             859 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |       -5.97e+03 |
# |          StdEpRet |        1.36e+03 |
# |          MaxEpRet |       -3.14e+03 |
# |          MinEpRet |       -8.59e+03 |
# |  AverageTestEpRet |       -6.17e+03 |
# |      StdTestEpRet |             959 |
# |      MaxTestEpRet |       -5.15e+03 |
# |      MinTestEpRet |       -8.18e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.4e+05 |
# |      AverageQVals |       -6.67e+03 |
# |          StdQVals |         1.1e+03 |
# |          MaxQVals |       -4.32e+03 |
# |          MinQVals |       -1.12e+04 |
# |            LossPi |        6.65e+03 |
# |             LossQ |        1.67e+03 |
# |              Time |             870 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |       -5.19e+03 |
# |          StdEpRet |         1.4e+03 |
# |          MaxEpRet |       -1.15e+03 |
# |          MinEpRet |       -7.03e+03 |
# |  AverageTestEpRet |       -5.55e+03 |
# |      StdTestEpRet |             739 |
# |      MaxTestEpRet |       -4.52e+03 |
# |      MinTestEpRet |       -6.66e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.42e+05 |
# |      AverageQVals |       -6.66e+03 |
# |          StdQVals |         1.1e+03 |
# |          MaxQVals |       -4.28e+03 |
# |          MinQVals |       -1.14e+04 |
# |            LossPi |        6.64e+03 |
# |             LossQ |         1.7e+03 |
# |              Time |             879 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |       -5.36e+03 |
# |          StdEpRet |        1.66e+03 |
# |          MaxEpRet |        -1.9e+03 |
# |          MinEpRet |       -9.41e+03 |
# |  AverageTestEpRet |       -5.43e+03 |
# |      StdTestEpRet |             437 |
# |      MaxTestEpRet |        -4.5e+03 |
# |      MinTestEpRet |       -6.03e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.44e+05 |
# |      AverageQVals |       -6.66e+03 |
# |          StdQVals |         1.1e+03 |
# |          MaxQVals |       -4.27e+03 |
# |          MinQVals |       -1.15e+04 |
# |            LossPi |        6.64e+03 |
# |             LossQ |        1.66e+03 |
# |              Time |             889 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |       -5.27e+03 |
# |          StdEpRet |        1.68e+03 |
# |          MaxEpRet |       -1.27e+03 |
# |          MinEpRet |        -7.5e+03 |
# |  AverageTestEpRet |       -5.63e+03 |
# |      StdTestEpRet |        1.61e+03 |
# |      MaxTestEpRet |       -2.29e+03 |
# |      MinTestEpRet |       -9.07e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.45e+05 |
# |      AverageQVals |       -6.66e+03 |
# |          StdQVals |         1.1e+03 |
# |          MaxQVals |       -4.26e+03 |
# |          MinQVals |        -1.2e+04 |
# |            LossPi |        6.65e+03 |
# |             LossQ |        1.66e+03 |
# |              Time |             899 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |       -5.38e+03 |
# |          StdEpRet |         2.1e+03 |
# |          MaxEpRet |            -507 |
# |          MinEpRet |       -8.76e+03 |
# |  AverageTestEpRet |       -5.77e+03 |
# |      StdTestEpRet |        1.25e+03 |
# |      MaxTestEpRet |       -4.31e+03 |
# |      MinTestEpRet |       -8.89e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.47e+05 |
# |      AverageQVals |       -6.66e+03 |
# |          StdQVals |         1.1e+03 |
# |          MaxQVals |       -4.31e+03 |
# |          MinQVals |       -1.18e+04 |
# |            LossPi |        6.64e+03 |
# |             LossQ |        1.65e+03 |
# |              Time |             909 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |       -5.61e+03 |
# |          StdEpRet |             755 |
# |          MaxEpRet |       -4.76e+03 |
# |          MinEpRet |       -7.12e+03 |
# |  AverageTestEpRet |       -4.43e+03 |
# |      StdTestEpRet |        1.93e+03 |
# |      MaxTestEpRet |            -435 |
# |      MinTestEpRet |       -6.28e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+05 |
# |      AverageQVals |       -6.66e+03 |
# |          StdQVals |         1.1e+03 |
# |          MaxQVals |       -4.26e+03 |
# |          MinQVals |       -1.19e+04 |
# |            LossPi |        6.64e+03 |
# |             LossQ |        1.63e+03 |
# |              Time |             919 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |       -5.25e+03 |
# |          StdEpRet |        1.75e+03 |
# |          MaxEpRet |       -1.31e+03 |
# |          MinEpRet |       -7.96e+03 |
# |  AverageTestEpRet |       -4.89e+03 |
# |      StdTestEpRet |        1.64e+03 |
# |      MaxTestEpRet |       -1.01e+03 |
# |      MinTestEpRet |       -8.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.5e+05 |
# |      AverageQVals |       -6.66e+03 |
# |          StdQVals |         1.1e+03 |
# |          MaxQVals |       -4.26e+03 |
# |          MinQVals |       -1.17e+04 |
# |            LossPi |        6.64e+03 |
# |             LossQ |         1.6e+03 |
# |              Time |             929 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |        -5.3e+03 |
# |          StdEpRet |        1.66e+03 |
# |          MaxEpRet |       -1.59e+03 |
# |          MinEpRet |       -7.95e+03 |
# |  AverageTestEpRet |       -5.36e+03 |
# |      StdTestEpRet |             552 |
# |      MaxTestEpRet |       -4.53e+03 |
# |      MinTestEpRet |       -6.35e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.52e+05 |
# |      AverageQVals |       -6.65e+03 |
# |          StdQVals |         1.1e+03 |
# |          MaxQVals |        -4.3e+03 |
# |          MinQVals |       -1.17e+04 |
# |            LossPi |        6.64e+03 |
# |             LossQ |        1.57e+03 |
# |              Time |             939 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |       -5.36e+03 |
# |          StdEpRet |        1.47e+03 |
# |          MaxEpRet |       -2.12e+03 |
# |          MinEpRet |        -8.9e+03 |
# |  AverageTestEpRet |       -5.08e+03 |
# |      StdTestEpRet |        1.79e+03 |
# |      MaxTestEpRet |            -819 |
# |      MinTestEpRet |       -8.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.53e+05 |
# |      AverageQVals |       -6.65e+03 |
# |          StdQVals |         1.1e+03 |
# |          MaxQVals |       -4.37e+03 |
# |          MinQVals |       -1.18e+04 |
# |            LossPi |        6.63e+03 |
# |             LossQ |        1.58e+03 |
# |              Time |             949 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |       -5.62e+03 |
# |          StdEpRet |             762 |
# |          MaxEpRet |       -4.05e+03 |
# |          MinEpRet |       -6.74e+03 |
# |  AverageTestEpRet |        -5.9e+03 |
# |      StdTestEpRet |         3.5e+03 |
# |      MaxTestEpRet |            -753 |
# |      MinTestEpRet |       -1.28e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.55e+05 |
# |      AverageQVals |       -6.65e+03 |
# |          StdQVals |         1.1e+03 |
# |          MaxQVals |       -4.28e+03 |
# |          MinQVals |       -1.16e+04 |
# |            LossPi |        6.63e+03 |
# |             LossQ |        1.57e+03 |
# |              Time |             958 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |       -5.41e+03 |
# |          StdEpRet |        1.85e+03 |
# |          MaxEpRet |       -2.44e+03 |
# |          MinEpRet |       -1.06e+04 |
# |  AverageTestEpRet |       -5.62e+03 |
# |      StdTestEpRet |        2.72e+03 |
# |      MaxTestEpRet |            -631 |
# |      MinTestEpRet |       -1.24e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.57e+05 |
# |      AverageQVals |       -6.64e+03 |
# |          StdQVals |        1.09e+03 |
# |          MaxQVals |       -4.28e+03 |
# |          MinQVals |       -1.17e+04 |
# |            LossPi |        6.62e+03 |
# |             LossQ |        1.56e+03 |
# |              Time |             969 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |       -4.45e+03 |
# |          StdEpRet |        1.48e+03 |
# |          MaxEpRet |            -225 |
# |          MinEpRet |       -6.35e+03 |
# |  AverageTestEpRet |       -5.08e+03 |
# |      StdTestEpRet |        1.25e+03 |
# |      MaxTestEpRet |       -2.05e+03 |
# |      MinTestEpRet |       -6.66e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.58e+05 |
# |      AverageQVals |       -6.62e+03 |
# |          StdQVals |        1.09e+03 |
# |          MaxQVals |       -4.29e+03 |
# |          MinQVals |       -1.17e+04 |
# |            LossPi |        6.61e+03 |
# |             LossQ |        1.54e+03 |
# |              Time |             980 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |       -5.51e+03 |
# |          StdEpRet |         2.3e+03 |
# |          MaxEpRet |       -1.18e+03 |
# |          MinEpRet |       -1.26e+04 |
# |  AverageTestEpRet |       -4.67e+03 |
# |      StdTestEpRet |        1.32e+03 |
# |      MaxTestEpRet |        -1.1e+03 |
# |      MinTestEpRet |       -6.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.6e+05 |
# |      AverageQVals |       -6.61e+03 |
# |          StdQVals |        1.09e+03 |
# |          MaxQVals |        -4.3e+03 |
# |          MinQVals |       -1.16e+04 |
# |            LossPi |        6.59e+03 |
# |             LossQ |         1.6e+03 |
# |              Time |             990 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |       -5.31e+03 |
# |          StdEpRet |        1.28e+03 |
# |          MaxEpRet |       -2.96e+03 |
# |          MinEpRet |       -9.14e+03 |
# |  AverageTestEpRet |       -5.19e+03 |
# |      StdTestEpRet |             525 |
# |      MaxTestEpRet |       -4.61e+03 |
# |      MinTestEpRet |       -6.54e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.62e+05 |
# |      AverageQVals |        -6.6e+03 |
# |          StdQVals |        1.09e+03 |
# |          MaxQVals |       -4.29e+03 |
# |          MinQVals |       -1.15e+04 |
# |            LossPi |        6.58e+03 |
# |             LossQ |        1.58e+03 |
# |              Time |           1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |        -5.7e+03 |
# |          StdEpRet |        2.43e+03 |
# |          MaxEpRet |       -1.75e+03 |
# |          MinEpRet |       -1.14e+04 |
# |  AverageTestEpRet |       -4.57e+03 |
# |      StdTestEpRet |        1.81e+03 |
# |      MaxTestEpRet |       -1.06e+03 |
# |      MinTestEpRet |       -6.95e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.63e+05 |
# |      AverageQVals |        -6.6e+03 |
# |          StdQVals |        1.08e+03 |
# |          MaxQVals |       -4.32e+03 |
# |          MinQVals |       -1.13e+04 |
# |            LossPi |        6.58e+03 |
# |             LossQ |        1.58e+03 |
# |              Time |        1.01e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             100 |
# |      AverageEpRet |       -6.03e+03 |
# |          StdEpRet |        2.98e+03 |
# |          MaxEpRet |       -2.54e+03 |
# |          MinEpRet |       -1.51e+04 |
# |  AverageTestEpRet |       -4.96e+03 |
# |      StdTestEpRet |        1.64e+03 |
# |      MaxTestEpRet |            -188 |
# |      MinTestEpRet |       -6.32e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+05 |
# |      AverageQVals |       -6.59e+03 |
# |          StdQVals |        1.08e+03 |
# |          MaxQVals |       -4.29e+03 |
# |          MinQVals |       -1.14e+04 |
# |            LossPi |        6.57e+03 |
# |             LossQ |         1.6e+03 |
# |              Time |        1.02e+03 |
# ---------------------------------------

# %% [markdown]
# #### Quadratic reward with bonus

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='ddpg_q_b', exp_name='ddpg_q_b')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0025
qlr_b = 0.0025

# Env function
reward_args = {'qx1':1,'qx2':0,'qx3':1,'qx4':0,'pu1':0,'pu2':0, 'bound': 0.05,'bonus':2}
env_fn = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Quadratic with bonus', reward_args = reward_args,ep_len=maxeplen_b)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Warning: Log dir ddpg_q_b already exists! Storing info there anyway.
# Logging data to ddpg_q_b/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(functools.partial(<function env_fn at 0x7f76de14bea0>, env_name='gyroscopeenv-v0', reward_type='Quadratic', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Absolute', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.5, 'pu2': 0.5}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.1, 'pu1': 0.25, 'pu2': 0.25}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with ending penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1, 'sx1': 100, 'sx3': 100, 'end_horizon': 1}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.25, 'pu2': 0.25, 'bound': 0.2, 'penalty': 40}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.25, 'pu2': 0.25, 'bound': 0.2, 'penalty': 40}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with exponential', reward_args={'qx1': 1, 'qx2': 0, 'qx3': 1, 'qx4': 0, 'pu1': 0, 'pu2': 0, 'eax1': 10, 'ebx1': 10, 'eax3': 10, 'ebx3': 10}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with penalty', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.25, 'pu2': 0.25, 'bound': 0.2, 'penalty': 40}, ep_len=110), env_name='gyroscopeenv-v0', reward_type='Quadratic with bonus', reward_args={'qx1': 1, 'qx2': 0, 'qx3': 1, 'qx4': 0, 'pu1': 0, 'pu2': 0, 'bound': 0.05, 'bonus': 2}, ep_len=110)",
#     "epochs":	100,
#     "exp_name":	"ddpg_q_b",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f76aca8bcc0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"ddpg_q_b",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_q_b",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_q_b/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"ddpg_q_b",
#         "output_dir":	"ddpg_q_b"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0025,
#     "polyak":	0.995,
#     "q_lr":	0.0025,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 4802, 	 q: 5201
# /home/matthieulc/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -771 |
# |          StdEpRet |             288 |
# |          MaxEpRet |            -293 |
# |          MinEpRet |       -1.36e+03 |
# |  AverageTestEpRet |            -789 |
# |      StdTestEpRet |             377 |
# |      MaxTestEpRet |           -2.75 |
# |      MinTestEpRet |       -1.42e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |      AverageQVals |           -14.6 |
# |          StdQVals |             8.5 |
# |          MaxQVals |           0.273 |
# |          MinQVals |           -55.5 |
# |            LossPi |            14.1 |
# |             LossQ |             9.5 |
# |              Time |            6.19 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -615 |
# |          StdEpRet |             128 |
# |          MaxEpRet |            -382 |
# |          MinEpRet |            -918 |
# |  AverageTestEpRet |            -520 |
# |      StdTestEpRet |             248 |
# |      MaxTestEpRet |            -213 |
# |      MinTestEpRet |            -915 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |      AverageQVals |           -39.4 |
# |          StdQVals |            20.1 |
# |          MaxQVals |         -0.0566 |
# |          MinQVals |            -128 |
# |            LossPi |            37.2 |
# |             LossQ |            10.7 |
# |              Time |            16.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -726 |
# |          StdEpRet |             212 |
# |          MaxEpRet |            -499 |
# |          MinEpRet |       -1.12e+03 |
# |  AverageTestEpRet |            -364 |
# |      StdTestEpRet |             319 |
# |      MaxTestEpRet |           -35.5 |
# |      MinTestEpRet |       -1.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |      AverageQVals |           -61.4 |
# |          StdQVals |            28.4 |
# |          MaxQVals |            15.1 |
# |          MinQVals |            -173 |
# |            LossPi |            57.3 |
# |             LossQ |            18.8 |
# |              Time |            26.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -698 |
# |          StdEpRet |             259 |
# |          MaxEpRet |            -273 |
# |          MinEpRet |       -1.24e+03 |
# |  AverageTestEpRet |            -232 |
# |      StdTestEpRet |             169 |
# |      MaxTestEpRet |           -56.5 |
# |      MinTestEpRet |            -648 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |      AverageQVals |           -73.2 |
# |          StdQVals |            40.3 |
# |          MaxQVals |            32.8 |
# |          MinQVals |            -225 |
# |            LossPi |            68.3 |
# |             LossQ |            27.4 |
# |              Time |            36.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -671 |
# |          StdEpRet |             250 |
# |          MaxEpRet |            -345 |
# |          MinEpRet |       -1.13e+03 |
# |  AverageTestEpRet |            -185 |
# |      StdTestEpRet |             114 |
# |      MaxTestEpRet |           -11.3 |
# |      MinTestEpRet |            -441 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |      AverageQVals |           -77.5 |
# |          StdQVals |            47.3 |
# |          MaxQVals |            35.1 |
# |          MinQVals |            -265 |
# |            LossPi |            71.9 |
# |             LossQ |            31.9 |
# |              Time |            45.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -723 |
# |          StdEpRet |             227 |
# |          MaxEpRet |            -398 |
# |          MinEpRet |       -1.16e+03 |
# |  AverageTestEpRet |            -154 |
# |      StdTestEpRet |             138 |
# |      MaxTestEpRet |           -10.9 |
# |      MinTestEpRet |            -410 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |      AverageQVals |           -78.2 |
# |          StdQVals |            53.4 |
# |          MaxQVals |            38.2 |
# |          MinQVals |            -291 |
# |            LossPi |              72 |
# |             LossQ |            35.5 |
# |              Time |            55.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -135 |
# |          StdEpRet |             122 |
# |          MaxEpRet |            78.2 |
# |          MinEpRet |            -398 |
# |  AverageTestEpRet |            -190 |
# |      StdTestEpRet |             150 |
# |      MaxTestEpRet |         -0.0381 |
# |      MinTestEpRet |            -453 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |      AverageQVals |           -75.9 |
# |          StdQVals |            57.1 |
# |          MaxQVals |            37.2 |
# |          MinQVals |            -303 |
# |            LossPi |            69.8 |
# |             LossQ |              38 |
# |              Time |            65.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -168 |
# |          StdEpRet |             178 |
# |          MaxEpRet |             142 |
# |          MinEpRet |            -589 |
# |  AverageTestEpRet |            -184 |
# |      StdTestEpRet |             159 |
# |      MaxTestEpRet |           -2.07 |
# |      MinTestEpRet |            -502 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |      AverageQVals |           -66.3 |
# |          StdQVals |              58 |
# |          MaxQVals |            44.1 |
# |          MinQVals |            -311 |
# |            LossPi |            60.7 |
# |             LossQ |            35.7 |
# |              Time |            75.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -158 |
# |          StdEpRet |             139 |
# |          MaxEpRet |            6.52 |
# |          MinEpRet |            -518 |
# |  AverageTestEpRet |            -185 |
# |      StdTestEpRet |             214 |
# |      MaxTestEpRet |             121 |
# |      MinTestEpRet |            -534 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |      AverageQVals |             -54 |
# |          StdQVals |            58.5 |
# |          MaxQVals |            58.5 |
# |          MinQVals |            -305 |
# |            LossPi |            48.8 |
# |             LossQ |            34.3 |
# |              Time |            85.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -132 |
# |          StdEpRet |             129 |
# |          MaxEpRet |            24.7 |
# |          MinEpRet |            -465 |
# |  AverageTestEpRet |            -173 |
# |      StdTestEpRet |             187 |
# |      MaxTestEpRet |            13.9 |
# |      MinTestEpRet |            -636 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |           -43.3 |
# |          StdQVals |            57.7 |
# |          MaxQVals |            64.4 |
# |          MinQVals |            -305 |
# |            LossPi |            38.4 |
# |             LossQ |            30.6 |
# |              Time |            95.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -107 |
# |          StdEpRet |             113 |
# |          MaxEpRet |             116 |
# |          MinEpRet |            -383 |
# |  AverageTestEpRet |           -87.3 |
# |      StdTestEpRet |            97.5 |
# |      MaxTestEpRet |            88.7 |
# |      MinTestEpRet |            -238 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |      AverageQVals |           -32.9 |
# |          StdQVals |            56.6 |
# |          MaxQVals |            77.5 |
# |          MinQVals |            -295 |
# |            LossPi |            28.2 |
# |             LossQ |            27.3 |
# |              Time |             106 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |           -49.4 |
# |          StdEpRet |            89.4 |
# |          MaxEpRet |            95.6 |
# |          MinEpRet |            -215 |
# |  AverageTestEpRet |           -84.9 |
# |      StdTestEpRet |             165 |
# |      MaxTestEpRet |             185 |
# |      MinTestEpRet |            -413 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |      AverageQVals |             -21 |
# |          StdQVals |            56.3 |
# |          MaxQVals |            92.9 |
# |          MinQVals |            -271 |
# |            LossPi |            16.5 |
# |             LossQ |            24.9 |
# |              Time |             116 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |           -81.4 |
# |          StdEpRet |            92.4 |
# |          MaxEpRet |            79.5 |
# |          MinEpRet |            -258 |
# |  AverageTestEpRet |            -102 |
# |      StdTestEpRet |            54.9 |
# |      MaxTestEpRet |           -23.3 |
# |      MinTestEpRet |            -191 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |      AverageQVals |           -10.7 |
# |          StdQVals |            55.9 |
# |          MaxQVals |             103 |
# |          MinQVals |            -267 |
# |            LossPi |            6.47 |
# |             LossQ |            23.7 |
# |              Time |             126 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -137 |
# |          StdEpRet |             102 |
# |          MaxEpRet |           -5.93 |
# |          MinEpRet |            -311 |
# |  AverageTestEpRet |           -75.6 |
# |      StdTestEpRet |            87.1 |
# |      MaxTestEpRet |            80.4 |
# |      MinTestEpRet |            -202 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |      AverageQVals |           -1.15 |
# |          StdQVals |            56.7 |
# |          MaxQVals |             117 |
# |          MinQVals |            -262 |
# |            LossPi |           -2.98 |
# |             LossQ |            22.8 |
# |              Time |             136 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           -81.7 |
# |          StdEpRet |              88 |
# |          MaxEpRet |            60.9 |
# |          MinEpRet |            -320 |
# |  AverageTestEpRet |            -153 |
# |      StdTestEpRet |             191 |
# |      MaxTestEpRet |            99.6 |
# |      MinTestEpRet |            -633 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |      AverageQVals |            9.14 |
# |          StdQVals |            57.1 |
# |          MaxQVals |             132 |
# |          MinQVals |            -258 |
# |            LossPi |           -13.2 |
# |             LossQ |            22.1 |
# |              Time |             146 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |           -81.9 |
# |          StdEpRet |            98.6 |
# |          MaxEpRet |            64.5 |
# |          MinEpRet |            -307 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |             188 |
# |      MaxTestEpRet |             149 |
# |      MinTestEpRet |            -565 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |      AverageQVals |            18.9 |
# |          StdQVals |            58.4 |
# |          MaxQVals |             154 |
# |          MinQVals |            -255 |
# |            LossPi |           -22.8 |
# |             LossQ |            21.7 |
# |              Time |             156 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |           -84.1 |
# |          StdEpRet |            92.4 |
# |          MaxEpRet |            91.2 |
# |          MinEpRet |            -295 |
# |  AverageTestEpRet |            -154 |
# |      StdTestEpRet |             166 |
# |      MaxTestEpRet |             177 |
# |      MinTestEpRet |            -436 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |      AverageQVals |            28.9 |
# |          StdQVals |            59.6 |
# |          MaxQVals |             168 |
# |          MinQVals |            -243 |
# |            LossPi |           -32.6 |
# |             LossQ |            21.3 |
# |              Time |             166 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -107 |
# |          StdEpRet |             107 |
# |          MaxEpRet |            45.6 |
# |          MinEpRet |            -325 |
# |  AverageTestEpRet |           -72.5 |
# |      StdTestEpRet |             108 |
# |      MaxTestEpRet |             147 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |      AverageQVals |            38.5 |
# |          StdQVals |            60.1 |
# |          MaxQVals |             179 |
# |          MinQVals |            -235 |
# |            LossPi |           -42.1 |
# |             LossQ |            21.1 |
# |              Time |             176 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -105 |
# |          StdEpRet |            90.6 |
# |          MaxEpRet |            97.1 |
# |          MinEpRet |            -286 |
# |  AverageTestEpRet |            -113 |
# |      StdTestEpRet |             129 |
# |      MaxTestEpRet |            76.2 |
# |      MinTestEpRet |            -451 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |      AverageQVals |              47 |
# |          StdQVals |            61.1 |
# |          MaxQVals |             187 |
# |          MinQVals |            -233 |
# |            LossPi |           -50.5 |
# |             LossQ |            20.7 |
# |              Time |             185 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -105 |
# |          StdEpRet |            94.8 |
# |          MaxEpRet |             128 |
# |          MinEpRet |            -321 |
# |  AverageTestEpRet |           -95.5 |
# |      StdTestEpRet |             121 |
# |      MaxTestEpRet |            68.6 |
# |      MinTestEpRet |            -389 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |              55 |
# |          StdQVals |            61.6 |
# |          MaxQVals |             196 |
# |          MinQVals |            -229 |
# |            LossPi |           -58.5 |
# |             LossQ |            20.5 |
# |              Time |             197 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |           -86.4 |
# |          StdEpRet |            96.1 |
# |          MaxEpRet |            58.9 |
# |          MinEpRet |            -310 |
# |  AverageTestEpRet |           -12.5 |
# |      StdTestEpRet |             116 |
# |      MaxTestEpRet |             149 |
# |      MinTestEpRet |            -193 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |      AverageQVals |            63.8 |
# |          StdQVals |            62.7 |
# |          MaxQVals |             206 |
# |          MinQVals |            -224 |
# |            LossPi |           -67.3 |
# |             LossQ |            20.3 |
# |              Time |             208 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -105 |
# |          StdEpRet |            97.4 |
# |          MaxEpRet |              22 |
# |          MinEpRet |            -291 |
# |  AverageTestEpRet |            -144 |
# |      StdTestEpRet |             104 |
# |      MaxTestEpRet |           -9.27 |
# |      MinTestEpRet |            -345 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |      AverageQVals |            72.9 |
# |          StdQVals |            63.8 |
# |          MaxQVals |             209 |
# |          MinQVals |            -214 |
# |            LossPi |           -76.4 |
# |             LossQ |            20.5 |
# |              Time |             218 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -120 |
# |          StdEpRet |             112 |
# |          MaxEpRet |            45.6 |
# |          MinEpRet |            -374 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            90.5 |
# |      MaxTestEpRet |           -49.7 |
# |      MinTestEpRet |            -334 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |      AverageQVals |            82.3 |
# |          StdQVals |            64.8 |
# |          MaxQVals |             215 |
# |          MinQVals |            -201 |
# |            LossPi |           -85.8 |
# |             LossQ |            19.9 |
# |              Time |             229 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |           -85.2 |
# |          StdEpRet |            81.1 |
# |          MaxEpRet |            99.9 |
# |          MinEpRet |            -263 |
# |  AverageTestEpRet |            -103 |
# |      StdTestEpRet |             120 |
# |      MaxTestEpRet |            55.5 |
# |      MinTestEpRet |            -389 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |      AverageQVals |            91.6 |
# |          StdQVals |            65.6 |
# |          MaxQVals |             227 |
# |          MinQVals |            -199 |
# |            LossPi |           -94.9 |
# |             LossQ |              20 |
# |              Time |             239 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -154 |
# |          StdEpRet |             118 |
# |          MaxEpRet |            66.6 |
# |          MinEpRet |            -431 |
# |  AverageTestEpRet |            -116 |
# |      StdTestEpRet |             112 |
# |      MaxTestEpRet |            57.5 |
# |      MinTestEpRet |            -311 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |      AverageQVals |            99.3 |
# |          StdQVals |            66.4 |
# |          MaxQVals |             238 |
# |          MinQVals |            -208 |
# |            LossPi |            -103 |
# |             LossQ |            19.5 |
# |              Time |             249 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -113 |
# |          StdEpRet |             160 |
# |          MaxEpRet |            67.9 |
# |          MinEpRet |            -509 |
# |  AverageTestEpRet |           -56.2 |
# |      StdTestEpRet |            85.6 |
# |      MaxTestEpRet |             106 |
# |      MinTestEpRet |            -230 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |      AverageQVals |             107 |
# |          StdQVals |            67.1 |
# |          MaxQVals |             248 |
# |          MinQVals |            -200 |
# |            LossPi |            -110 |
# |             LossQ |            19.4 |
# |              Time |             260 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -104 |
# |          StdEpRet |             175 |
# |          MaxEpRet |             163 |
# |          MinEpRet |            -599 |
# |  AverageTestEpRet |           -98.9 |
# |      StdTestEpRet |            66.4 |
# |      MaxTestEpRet |           -5.25 |
# |      MinTestEpRet |            -205 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |      AverageQVals |             114 |
# |          StdQVals |            68.8 |
# |          MaxQVals |             258 |
# |          MinQVals |            -211 |
# |            LossPi |            -117 |
# |             LossQ |            19.6 |
# |              Time |             272 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |           -77.2 |
# |          StdEpRet |             130 |
# |          MaxEpRet |             166 |
# |          MinEpRet |            -419 |
# |  AverageTestEpRet |           -10.9 |
# |      StdTestEpRet |              83 |
# |      MaxTestEpRet |             170 |
# |      MinTestEpRet |            -115 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |      AverageQVals |             120 |
# |          StdQVals |            70.2 |
# |          MaxQVals |             274 |
# |          MinQVals |            -218 |
# |            LossPi |            -123 |
# |             LossQ |            19.7 |
# |              Time |             282 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |           -63.3 |
# |          StdEpRet |             147 |
# |          MaxEpRet |             155 |
# |          MinEpRet |            -419 |
# |  AverageTestEpRet |           -68.9 |
# |      StdTestEpRet |            93.7 |
# |      MaxTestEpRet |             153 |
# |      MinTestEpRet |            -173 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |      AverageQVals |             127 |
# |          StdQVals |            71.7 |
# |          MaxQVals |             277 |
# |          MinQVals |            -224 |
# |            LossPi |            -130 |
# |             LossQ |            19.9 |
# |              Time |             292 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -139 |
# |          StdEpRet |             109 |
# |          MaxEpRet |           -31.9 |
# |          MinEpRet |            -395 |
# |  AverageTestEpRet |           -97.5 |
# |      StdTestEpRet |            51.3 |
# |      MaxTestEpRet |             -30 |
# |      MinTestEpRet |            -171 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |             134 |
# |          StdQVals |            73.1 |
# |          MaxQVals |             292 |
# |          MinQVals |            -239 |
# |            LossPi |            -138 |
# |             LossQ |            20.2 |
# |              Time |             302 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -103 |
# |          StdEpRet |            93.8 |
# |          MaxEpRet |           -19.4 |
# |          MinEpRet |            -323 |
# |  AverageTestEpRet |            -121 |
# |      StdTestEpRet |             133 |
# |      MaxTestEpRet |             134 |
# |      MinTestEpRet |            -381 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |      AverageQVals |             141 |
# |          StdQVals |            74.6 |
# |          MaxQVals |             296 |
# |          MinQVals |            -244 |
# |            LossPi |            -144 |
# |             LossQ |            19.9 |
# |              Time |             312 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |             -64 |
# |          StdEpRet |             114 |
# |          MaxEpRet |             151 |
# |          MinEpRet |            -364 |
# |  AverageTestEpRet |            -165 |
# |      StdTestEpRet |             138 |
# |      MaxTestEpRet |          -0.986 |
# |      MinTestEpRet |            -396 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |      AverageQVals |             148 |
# |          StdQVals |            75.9 |
# |          MaxQVals |             301 |
# |          MinQVals |            -246 |
# |            LossPi |            -151 |
# |             LossQ |            19.4 |
# |              Time |             323 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |           -64.8 |
# |          StdEpRet |            70.1 |
# |          MaxEpRet |            63.7 |
# |          MinEpRet |            -169 |
# |  AverageTestEpRet |            -149 |
# |      StdTestEpRet |             130 |
# |      MaxTestEpRet |            20.9 |
# |      MinTestEpRet |            -455 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |      AverageQVals |             155 |
# |          StdQVals |            76.5 |
# |          MaxQVals |             307 |
# |          MinQVals |            -246 |
# |            LossPi |            -158 |
# |             LossQ |            19.5 |
# |              Time |             334 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -108 |
# |          StdEpRet |             100 |
# |          MaxEpRet |            43.1 |
# |          MinEpRet |            -325 |
# |  AverageTestEpRet |           -78.3 |
# |      StdTestEpRet |            95.6 |
# |      MaxTestEpRet |             144 |
# |      MinTestEpRet |            -248 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |      AverageQVals |             161 |
# |          StdQVals |            76.9 |
# |          MaxQVals |             314 |
# |          MinQVals |            -255 |
# |            LossPi |            -164 |
# |             LossQ |            19.5 |
# |              Time |             344 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -110 |
# |          StdEpRet |             126 |
# |          MaxEpRet |            54.6 |
# |          MinEpRet |            -364 |
# |  AverageTestEpRet |             -63 |
# |      StdTestEpRet |             212 |
# |      MaxTestEpRet |             172 |
# |      MinTestEpRet |            -647 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |      AverageQVals |             167 |
# |          StdQVals |            77.9 |
# |          MaxQVals |             329 |
# |          MinQVals |            -259 |
# |            LossPi |            -170 |
# |             LossQ |            19.6 |
# |              Time |             354 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |           -48.3 |
# |          StdEpRet |            96.4 |
# |          MaxEpRet |             114 |
# |          MinEpRet |            -191 |
# |  AverageTestEpRet |           -75.4 |
# |      StdTestEpRet |             136 |
# |      MaxTestEpRet |             144 |
# |      MinTestEpRet |            -354 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |      AverageQVals |             174 |
# |          StdQVals |            78.7 |
# |          MaxQVals |             339 |
# |          MinQVals |            -254 |
# |            LossPi |            -177 |
# |             LossQ |            19.5 |
# |              Time |             365 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |             -69 |
# |          StdEpRet |            92.4 |
# |          MaxEpRet |            99.7 |
# |          MinEpRet |            -261 |
# |  AverageTestEpRet |            -125 |
# |      StdTestEpRet |             154 |
# |      MaxTestEpRet |           -1.56 |
# |      MinTestEpRet |            -415 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |      AverageQVals |             179 |
# |          StdQVals |            79.7 |
# |          MaxQVals |             344 |
# |          MinQVals |            -265 |
# |            LossPi |            -182 |
# |             LossQ |            19.5 |
# |              Time |             376 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -105 |
# |          StdEpRet |             164 |
# |          MaxEpRet |              50 |
# |          MinEpRet |            -629 |
# |  AverageTestEpRet |            -129 |
# |      StdTestEpRet |             128 |
# |      MaxTestEpRet |            77.3 |
# |      MinTestEpRet |            -319 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |      AverageQVals |             185 |
# |          StdQVals |              81 |
# |          MaxQVals |             345 |
# |          MinQVals |            -272 |
# |            LossPi |            -187 |
# |             LossQ |            19.2 |
# |              Time |             387 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |           -78.7 |
# |          StdEpRet |            96.3 |
# |          MaxEpRet |            65.5 |
# |          MinEpRet |            -332 |
# |  AverageTestEpRet |           -90.4 |
# |      StdTestEpRet |             179 |
# |      MaxTestEpRet |             133 |
# |      MinTestEpRet |            -567 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |      AverageQVals |             189 |
# |          StdQVals |            81.7 |
# |          MaxQVals |             356 |
# |          MinQVals |            -273 |
# |            LossPi |            -191 |
# |             LossQ |            19.6 |
# |              Time |             398 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |           -62.5 |
# |          StdEpRet |            96.1 |
# |          MaxEpRet |             134 |
# |          MinEpRet |            -255 |
# |  AverageTestEpRet |            -226 |
# |      StdTestEpRet |             248 |
# |      MaxTestEpRet |            55.4 |
# |      MinTestEpRet |            -700 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |             194 |
# |          StdQVals |            81.8 |
# |          MaxQVals |             362 |
# |          MinQVals |            -287 |
# |            LossPi |            -197 |
# |             LossQ |              20 |
# |              Time |             410 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |           -59.4 |
# |          StdEpRet |             107 |
# |          MaxEpRet |             113 |
# |          MinEpRet |            -346 |
# |  AverageTestEpRet |            -137 |
# |      StdTestEpRet |              94 |
# |      MaxTestEpRet |           -12.2 |
# |      MinTestEpRet |            -330 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |      AverageQVals |             199 |
# |          StdQVals |            82.1 |
# |          MaxQVals |             366 |
# |          MinQVals |            -278 |
# |            LossPi |            -202 |
# |             LossQ |            19.8 |
# |              Time |             421 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |           -99.2 |
# |          StdEpRet |             108 |
# |          MaxEpRet |            80.7 |
# |          MinEpRet |            -289 |
# |  AverageTestEpRet |           -76.6 |
# |      StdTestEpRet |            49.9 |
# |      MaxTestEpRet |            -4.2 |
# |      MinTestEpRet |            -155 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |      AverageQVals |             205 |
# |          StdQVals |            81.8 |
# |          MaxQVals |             371 |
# |          MinQVals |            -272 |
# |            LossPi |            -208 |
# |             LossQ |              20 |
# |              Time |             432 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |           -23.6 |
# |          StdEpRet |            65.4 |
# |          MaxEpRet |            85.3 |
# |          MinEpRet |            -132 |
# |  AverageTestEpRet |           -94.4 |
# |      StdTestEpRet |            84.3 |
# |      MaxTestEpRet |            7.24 |
# |      MinTestEpRet |            -253 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |      AverageQVals |             211 |
# |          StdQVals |            81.8 |
# |          MaxQVals |             378 |
# |          MinQVals |            -274 |
# |            LossPi |            -214 |
# |             LossQ |            20.2 |
# |              Time |             441 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |           -86.9 |
# |          StdEpRet |            77.6 |
# |          MaxEpRet |            26.7 |
# |          MinEpRet |            -262 |
# |  AverageTestEpRet |             -81 |
# |      StdTestEpRet |            69.2 |
# |      MaxTestEpRet |           -8.92 |
# |      MinTestEpRet |            -248 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |      AverageQVals |             217 |
# |          StdQVals |            82.2 |
# |          MaxQVals |             380 |
# |          MinQVals |            -277 |
# |            LossPi |            -220 |
# |             LossQ |              20 |
# |              Time |             451 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |           -78.7 |
# |          StdEpRet |             106 |
# |          MaxEpRet |            98.9 |
# |          MinEpRet |            -319 |
# |  AverageTestEpRet |           -63.9 |
# |      StdTestEpRet |            96.1 |
# |      MaxTestEpRet |             139 |
# |      MinTestEpRet |            -205 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |      AverageQVals |             222 |
# |          StdQVals |            82.8 |
# |          MaxQVals |             384 |
# |          MinQVals |            -273 |
# |            LossPi |            -225 |
# |             LossQ |            20.5 |
# |              Time |             461 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |           -82.7 |
# |          StdEpRet |             107 |
# |          MaxEpRet |            32.8 |
# |          MinEpRet |            -369 |
# |  AverageTestEpRet |            -109 |
# |      StdTestEpRet |            68.4 |
# |      MaxTestEpRet |             -18 |
# |      MinTestEpRet |            -255 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |      AverageQVals |             228 |
# |          StdQVals |            82.6 |
# |          MaxQVals |             384 |
# |          MinQVals |            -271 |
# |            LossPi |            -231 |
# |             LossQ |              20 |
# |              Time |             472 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |           -99.8 |
# |          StdEpRet |             101 |
# |          MaxEpRet |            8.76 |
# |          MinEpRet |            -428 |
# |  AverageTestEpRet |           -79.9 |
# |      StdTestEpRet |             136 |
# |      MaxTestEpRet |             151 |
# |      MinTestEpRet |            -280 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.75e+04 |
# |      AverageQVals |             233 |
# |          StdQVals |            82.3 |
# |          MaxQVals |             387 |
# |          MinQVals |            -256 |
# |            LossPi |            -236 |
# |             LossQ |            19.4 |
# |              Time |             482 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |           -83.2 |
# |          StdEpRet |            88.2 |
# |          MaxEpRet |            14.9 |
# |          MinEpRet |            -334 |
# |  AverageTestEpRet |           -90.2 |
# |      StdTestEpRet |            60.8 |
# |      MaxTestEpRet |            16.3 |
# |      MinTestEpRet |            -200 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.92e+04 |
# |      AverageQVals |             238 |
# |          StdQVals |            82.5 |
# |          MaxQVals |             391 |
# |          MinQVals |            -257 |
# |            LossPi |            -240 |
# |             LossQ |            19.4 |
# |              Time |             492 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |           -43.7 |
# |          StdEpRet |            53.3 |
# |          MaxEpRet |              65 |
# |          MinEpRet |            -160 |
# |  AverageTestEpRet |           -67.8 |
# |      StdTestEpRet |            96.6 |
# |      MaxTestEpRet |              67 |
# |      MinTestEpRet |            -315 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+04 |
# |      AverageQVals |             242 |
# |          StdQVals |            82.3 |
# |          MaxQVals |             394 |
# |          MinQVals |            -255 |
# |            LossPi |            -245 |
# |             LossQ |            19.5 |
# |              Time |             503 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |           -84.6 |
# |          StdEpRet |            68.3 |
# |          MaxEpRet |            13.6 |
# |          MinEpRet |            -258 |
# |  AverageTestEpRet |             -95 |
# |      StdTestEpRet |             114 |
# |      MaxTestEpRet |            72.3 |
# |      MinTestEpRet |            -323 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |             246 |
# |          StdQVals |              82 |
# |          MaxQVals |             406 |
# |          MinQVals |            -246 |
# |            LossPi |            -249 |
# |             LossQ |            19.5 |
# |              Time |             513 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |             -93 |
# |          StdEpRet |            78.8 |
# |          MaxEpRet |            46.3 |
# |          MinEpRet |            -253 |
# |  AverageTestEpRet |          -0.664 |
# |      StdTestEpRet |              99 |
# |      MaxTestEpRet |             158 |
# |      MinTestEpRet |            -166 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.41e+04 |
# |      AverageQVals |             252 |
# |          StdQVals |            81.3 |
# |          MaxQVals |             415 |
# |          MinQVals |            -235 |
# |            LossPi |            -254 |
# |             LossQ |            19.1 |
# |              Time |             523 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |           -67.8 |
# |          StdEpRet |            82.4 |
# |          MaxEpRet |            79.4 |
# |          MinEpRet |            -185 |
# |  AverageTestEpRet |           -74.7 |
# |      StdTestEpRet |            61.8 |
# |      MaxTestEpRet |            52.1 |
# |      MinTestEpRet |            -181 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.58e+04 |
# |      AverageQVals |             255 |
# |          StdQVals |            81.3 |
# |          MaxQVals |             421 |
# |          MinQVals |            -236 |
# |            LossPi |            -258 |
# |             LossQ |            18.9 |
# |              Time |             533 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |            -114 |
# |          StdEpRet |             111 |
# |          MaxEpRet |            12.8 |
# |          MinEpRet |            -419 |
# |  AverageTestEpRet |           -91.8 |
# |      StdTestEpRet |             108 |
# |      MaxTestEpRet |             165 |
# |      MinTestEpRet |            -226 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.74e+04 |
# |      AverageQVals |             258 |
# |          StdQVals |            80.8 |
# |          MaxQVals |             429 |
# |          MinQVals |            -221 |
# |            LossPi |            -261 |
# |             LossQ |            19.3 |
# |              Time |             545 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |           -36.7 |
# |          StdEpRet |            88.6 |
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              82 |
# |      AverageEpRet |           -36.4 |
# |          StdEpRet |            96.1 |
# |          MaxEpRet |             104 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |           -40.8 |
# |      StdTestEpRet |            84.5 |
# |      MaxTestEpRet |             136 |
# |      MinTestEpRet |            -157 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.35e+05 |
# |      AverageQVals |             329 |
# |          StdQVals |            75.2 |
# |          MaxQVals |             493 |
# |          MinQVals |           -72.9 |
# |            LossPi |            -331 |
# |             LossQ |            20.1 |
# |              Time |             851 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              83 |
# |      AverageEpRet |           -63.9 |
# |          StdEpRet |            74.8 |
# |          MaxEpRet |            95.2 |
# |          MinEpRet |            -169 |
# |  AverageTestEpRet |           -43.2 |
# |      StdTestEpRet |            86.7 |
# |      MaxTestEpRet |             148 |
# |      MinTestEpRet |            -210 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.37e+05 |
# |      AverageQVals |             331 |
# |          StdQVals |            75.1 |
# |          MaxQVals |             487 |
# |          MinQVals |           -68.2 |
# |            LossPi |            -333 |
# |             LossQ |              20 |
# |              Time |             863 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |            -129 |
# |          StdEpRet |             152 |
# |          MaxEpRet |            44.1 |
# |          MinEpRet |            -539 |
# |  AverageTestEpRet |           -65.4 |
# |      StdTestEpRet |            67.5 |
# |      MaxTestEpRet |            64.9 |
# |      MinTestEpRet |            -187 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.39e+05 |
# |      AverageQVals |             333 |
# |          StdQVals |            74.5 |
# |          MaxQVals |             488 |
# |          MinQVals |           -59.3 |
# |            LossPi |            -335 |
# |             LossQ |            19.5 |
# |              Time |             874 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |           -50.3 |
# |          StdEpRet |            59.5 |
# |          MaxEpRet |            49.7 |
# |          MinEpRet |            -163 |
# |  AverageTestEpRet |            -117 |
# |      StdTestEpRet |             156 |
# |      MaxTestEpRet |              20 |
# |      MinTestEpRet |            -537 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.4e+05 |
# |      AverageQVals |             335 |
# |          StdQVals |            74.4 |
# |          MaxQVals |             487 |
# |          MinQVals |           -58.2 |
# |            LossPi |            -337 |
# |             LossQ |            19.7 |
# |              Time |             884 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |           -59.6 |
# |          StdEpRet |            68.4 |
# |          MaxEpRet |            76.9 |
# |          MinEpRet |            -206 |
# |  AverageTestEpRet |           -66.1 |
# |      StdTestEpRet |            78.1 |
# |      MaxTestEpRet |            35.9 |
# |      MinTestEpRet |            -196 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.42e+05 |
# |      AverageQVals |             337 |
# |          StdQVals |            74.2 |
# |          MaxQVals |             487 |
# |          MinQVals |           -45.2 |
# |            LossPi |            -339 |
# |             LossQ |            19.4 |
# |              Time |             895 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |           -72.5 |
# |          StdEpRet |            98.7 |
# |          MaxEpRet |            95.1 |
# |          MinEpRet |            -295 |
# |  AverageTestEpRet |           -64.9 |
# |      StdTestEpRet |             132 |
# |      MaxTestEpRet |             177 |
# |      MinTestEpRet |            -253 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.44e+05 |
# |      AverageQVals |             339 |
# |          StdQVals |            73.7 |
# |          MaxQVals |             486 |
# |          MinQVals |           -50.7 |
# |            LossPi |            -341 |
# |             LossQ |            19.2 |
# |              Time |             906 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |           -36.6 |
# |          StdEpRet |            66.2 |
# |          MaxEpRet |            47.5 |
# |          MinEpRet |            -208 |
# |  AverageTestEpRet |           -82.3 |
# |      StdTestEpRet |             110 |
# |      MaxTestEpRet |             193 |
# |      MinTestEpRet |            -193 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.45e+05 |
# |      AverageQVals |             339 |
# |          StdQVals |            74.4 |
# |          MaxQVals |             494 |
# |          MinQVals |           -61.3 |
# |            LossPi |            -341 |
# |             LossQ |            18.9 |
# |              Time |             916 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |           -73.7 |
# |          StdEpRet |            71.6 |
# |          MaxEpRet |            25.5 |
# |          MinEpRet |            -231 |
# |  AverageTestEpRet |           -57.7 |
# |      StdTestEpRet |            64.7 |
# |      MaxTestEpRet |              97 |
# |      MinTestEpRet |            -146 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.47e+05 |
# |      AverageQVals |             340 |
# |          StdQVals |            74.9 |
# |          MaxQVals |             494 |
# |          MinQVals |           -68.8 |
# |            LossPi |            -342 |
# |             LossQ |            18.8 |
# |              Time |             926 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |           -72.4 |
# |          StdEpRet |            81.4 |
# |          MaxEpRet |            77.6 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |           -31.7 |
# |      StdTestEpRet |            75.6 |
# |      MaxTestEpRet |            80.5 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+05 |
# |      AverageQVals |             340 |
# |          StdQVals |            75.5 |
# |          MaxQVals |             494 |
# |          MinQVals |           -88.8 |
# |            LossPi |            -343 |
# |             LossQ |            18.9 |
# |              Time |             936 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |           -53.1 |
# |          StdEpRet |            76.9 |
# |          MaxEpRet |            80.6 |
# |          MinEpRet |            -193 |
# |  AverageTestEpRet |           -49.1 |
# |      StdTestEpRet |             142 |
# |      MaxTestEpRet |             173 |
# |      MinTestEpRet |            -290 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.5e+05 |
# |      AverageQVals |             341 |
# |          StdQVals |            75.8 |
# |          MaxQVals |             497 |
# |          MinQVals |           -88.7 |
# |            LossPi |            -343 |
# |             LossQ |            18.9 |
# |              Time |             947 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |             -99 |
# |          StdEpRet |            90.3 |
# |          MaxEpRet |            46.6 |
# |          MinEpRet |            -372 |
# |  AverageTestEpRet |           -74.1 |
# |      StdTestEpRet |            98.4 |
# |      MaxTestEpRet |            94.6 |
# |      MinTestEpRet |            -194 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.52e+05 |
# |      AverageQVals |             341 |
# |          StdQVals |            76.1 |
# |          MaxQVals |             495 |
# |          MinQVals |             -70 |
# |            LossPi |            -343 |
# |             LossQ |            18.5 |
# |              Time |             957 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |           -68.1 |
# |          StdEpRet |            58.1 |
# |          MaxEpRet |            40.3 |
# |          MinEpRet |            -213 |
# |  AverageTestEpRet |           -84.7 |
# |      StdTestEpRet |            73.4 |
# |      MaxTestEpRet |           -3.57 |
# |      MinTestEpRet |            -285 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.53e+05 |
# |      AverageQVals |             341 |
# |          StdQVals |            76.3 |
# |          MaxQVals |             494 |
# |          MinQVals |           -71.3 |
# |            LossPi |            -343 |
# |             LossQ |            19.1 |
# |              Time |             970 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |           -69.4 |
# |          StdEpRet |             108 |
# |          MaxEpRet |            92.1 |
# |          MinEpRet |            -328 |
# |  AverageTestEpRet |           -8.38 |
# |      StdTestEpRet |             107 |
# |      MaxTestEpRet |             162 |
# |      MinTestEpRet |            -148 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.55e+05 |
# |      AverageQVals |             341 |
# |          StdQVals |            76.8 |
# |          MaxQVals |             494 |
# |          MinQVals |           -89.8 |
# |            LossPi |            -343 |
# |             LossQ |            18.7 |
# |              Time |             981 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |            -102 |
# |          StdEpRet |             129 |
# |          MaxEpRet |            70.3 |
# |          MinEpRet |            -386 |
# |  AverageTestEpRet |           -72.3 |
# |      StdTestEpRet |            63.5 |
# |      MaxTestEpRet |              64 |
# |      MinTestEpRet |            -172 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.57e+05 |
# |      AverageQVals |             341 |
# |          StdQVals |            76.4 |
# |          MaxQVals |             495 |
# |          MinQVals |           -78.8 |
# |            LossPi |            -343 |
# |             LossQ |            18.8 |
# |              Time |             992 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |            -110 |
# |          StdEpRet |             121 |
# |          MaxEpRet |            65.5 |
# |          MinEpRet |            -311 |
# |  AverageTestEpRet |            -140 |
# |      StdTestEpRet |             113 |
# |      MaxTestEpRet |             -17 |
# |      MinTestEpRet |            -398 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.58e+05 |
# |      AverageQVals |             341 |
# |          StdQVals |            76.4 |
# |          MaxQVals |             498 |
# |          MinQVals |           -75.5 |
# |            LossPi |            -344 |
# |             LossQ |            18.5 |
# |              Time |           1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |           -48.2 |
# |          StdEpRet |            84.7 |
# |          MaxEpRet |             117 |
# |          MinEpRet |            -263 |
# |  AverageTestEpRet |           -44.6 |
# |      StdTestEpRet |             105 |
# |      MaxTestEpRet |             154 |
# |      MinTestEpRet |            -197 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.6e+05 |
# |      AverageQVals |             342 |
# |          StdQVals |            75.8 |
# |          MaxQVals |             500 |
# |          MinQVals |           -83.1 |
# |            LossPi |            -344 |
# |             LossQ |            19.1 |
# |              Time |        1.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |           -42.8 |
# |          StdEpRet |            80.2 |
# |          MaxEpRet |            94.5 |
# |          MinEpRet |            -235 |
# |  AverageTestEpRet |            -121 |
# |      StdTestEpRet |             133 |
# |      MaxTestEpRet |            92.1 |
# |      MinTestEpRet |            -380 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.62e+05 |
# |      AverageQVals |             342 |
# |          StdQVals |              75 |
# |          MaxQVals |             499 |
# |          MinQVals |           -78.5 |
# |            LossPi |            -344 |
# |             LossQ |            18.8 |
# |              Time |        1.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |           -57.5 |
# |          StdEpRet |              90 |
# |          MaxEpRet |            85.4 |
# |          MinEpRet |            -300 |
# |  AverageTestEpRet |           -20.1 |
# |      StdTestEpRet |             100 |
# |      MaxTestEpRet |             116 |
# |      MinTestEpRet |            -202 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.63e+05 |
# |      AverageQVals |             343 |
# |          StdQVals |            74.5 |
# |          MaxQVals |             496 |
# |          MinQVals |           -75.6 |
# |            LossPi |            -345 |
# |             LossQ |            18.7 |
# |              Time |        1.04e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             100 |
# |      AverageEpRet |             -37 |
# |          StdEpRet |             104 |
# |          MaxEpRet |             135 |
# |          MinEpRet |            -257 |
# |  AverageTestEpRet |           -65.8 |
# |      StdTestEpRet |            79.6 |
# |      MaxTestEpRet |             151 |
# |      MinTestEpRet |            -134 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+05 |
# |      AverageQVals |             343 |
# |          StdQVals |            74.9 |
# |          MaxQVals |             495 |
# |          MinQVals |           -77.8 |
# |            LossPi |            -345 |
# |             LossQ |            18.8 |
# |              Time |        1.05e+03 |
# ---------------------------------------

# %% [markdown]
# #### Sparse reward

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='ddpg_s', exp_name='ddpg_s')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0025
qlr_b = 0.0025

# Env function
reward_args = {'bound': 0.05,'reward':1}
env_fn = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Sparse', reward_args = reward_args,ep_len=maxeplen_b)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Warning: Log dir ddpg_s already exists! Storing info there anyway.
# Logging data to ddpg_s/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7f538e951488>, env_name='gyroscopeenv-v0', reward_type='Sparse', reward_args={'bound': 0.05, 'reward': 1}, ep_len=110)",
#     "epochs":	100,
#     "exp_name":	"ddpg_s",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f5409a39390>":	{
#             "epoch_dict":	{},
#             "exp_name":	"ddpg_s",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_s",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_s/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"ddpg_s",
#         "output_dir":	"ddpg_s"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0025,
#     "polyak":	0.995,
#     "q_lr":	0.0025,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 4802, 	 q: 5201
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |      AverageQVals |        -0.00869 |
# |          StdQVals |           0.116 |
# |          MaxQVals |           0.356 |
# |          MinQVals |          -0.507 |
# |            LossPi |           -0.01 |
# |             LossQ |        0.000391 |
# |              Time |            5.17 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |      AverageQVals |          0.0804 |
# |          StdQVals |          0.0961 |
# |          MaxQVals |            0.37 |
# |          MinQVals |          -0.234 |
# |            LossPi |         -0.0903 |
# |             LossQ |        0.000164 |
# |              Time |            13.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |           0.133 |
# |          StdEpRet |            0.34 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |      AverageQVals |           0.145 |
# |          StdQVals |          0.0965 |
# |          MaxQVals |           0.761 |
# |          MinQVals |           -0.16 |
# |            LossPi |          -0.153 |
# |             LossQ |        0.000589 |
# |              Time |            21.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |      AverageQVals |           0.228 |
# |          StdQVals |           0.116 |
# |          MaxQVals |            1.67 |
# |          MinQVals |          -0.113 |
# |            LossPi |          -0.239 |
# |             LossQ |        0.000697 |
# |              Time |            28.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |      AverageQVals |             0.3 |
# |          StdQVals |           0.162 |
# |          MaxQVals |            2.15 |
# |          MinQVals |         -0.0395 |
# |            LossPi |           -0.31 |
# |             LossQ |        0.000619 |
# |              Time |            36.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |      AverageQVals |           0.371 |
# |          StdQVals |           0.207 |
# |          MaxQVals |            2.69 |
# |          MinQVals |        -0.00711 |
# |            LossPi |          -0.382 |
# |             LossQ |        0.000597 |
# |              Time |              44 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             0.2 |
# |          StdEpRet |           0.748 |
# |          MaxEpRet |               3 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |      AverageQVals |           0.441 |
# |          StdQVals |            0.25 |
# |          MaxQVals |            3.73 |
# |          MinQVals |          0.0845 |
# |            LossPi |          -0.451 |
# |             LossQ |         0.00076 |
# |              Time |            52.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |      AverageQVals |           0.538 |
# |          StdQVals |           0.392 |
# |          MaxQVals |             4.1 |
# |          MinQVals |           0.155 |
# |            LossPi |          -0.548 |
# |             LossQ |           0.001 |
# |              Time |            60.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |      AverageQVals |            0.62 |
# |          StdQVals |           0.475 |
# |          MaxQVals |            4.27 |
# |          MinQVals |           0.182 |
# |            LossPi |           -0.63 |
# |             LossQ |         0.00108 |
# |              Time |            68.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |           0.133 |
# |          StdEpRet |            0.34 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |            0.68 |
# |          StdQVals |           0.516 |
# |          MaxQVals |            4.48 |
# |          MinQVals |            0.22 |
# |            LossPi |          -0.689 |
# |             LossQ |         0.00095 |
# |              Time |            76.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |      AverageQVals |           0.748 |
# |          StdQVals |           0.562 |
# |          MaxQVals |            4.58 |
# |          MinQVals |           0.254 |
# |            LossPi |          -0.757 |
# |             LossQ |        0.000922 |
# |              Time |            84.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |      AverageQVals |             0.8 |
# |          StdQVals |           0.581 |
# |          MaxQVals |            4.65 |
# |          MinQVals |           0.241 |
# |            LossPi |          -0.809 |
# |             LossQ |        0.000946 |
# |              Time |            93.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |      AverageQVals |           0.837 |
# |          StdQVals |           0.594 |
# |          MaxQVals |            4.89 |
# |          MinQVals |           0.291 |
# |            LossPi |          -0.844 |
# |             LossQ |        0.000972 |
# |              Time |             102 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |      AverageQVals |           0.867 |
# |          StdQVals |           0.611 |
# |          MaxQVals |            4.82 |
# |          MinQVals |           0.303 |
# |            LossPi |          -0.874 |
# |             LossQ |        0.000888 |
# |              Time |             110 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |      AverageQVals |           0.903 |
# |          StdQVals |           0.628 |
# |          MaxQVals |            4.97 |
# |          MinQVals |           0.321 |
# |            LossPi |           -0.91 |
# |             LossQ |        0.000839 |
# |              Time |             119 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |      AverageQVals |           0.939 |
# |          StdQVals |           0.645 |
# |          MaxQVals |            5.09 |
# |          MinQVals |           0.338 |
# |            LossPi |          -0.946 |
# |             LossQ |        0.000942 |
# |              Time |             128 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.3 |
# |      StdTestEpRet |            0.64 |
# |      MaxTestEpRet |               2 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |      AverageQVals |           0.969 |
# |          StdQVals |            0.66 |
# |          MaxQVals |            4.97 |
# |          MinQVals |           0.335 |
# |            LossPi |          -0.975 |
# |             LossQ |        0.000797 |
# |              Time |             136 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |      AverageQVals |           0.978 |
# |          StdQVals |           0.654 |
# |          MaxQVals |               5 |
# |          MinQVals |           0.342 |
# |            LossPi |          -0.984 |
# |             LossQ |        0.000702 |
# |              Time |             147 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.1 |
# |      StdTestEpRet |             0.3 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |      AverageQVals |            0.99 |
# |          StdQVals |           0.647 |
# |          MaxQVals |            5.02 |
# |          MinQVals |           0.358 |
# |            LossPi |          -0.995 |
# |             LossQ |        0.000603 |
# |              Time |             155 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |           0.991 |
# |          StdQVals |           0.629 |
# |          MaxQVals |            4.88 |
# |          MinQVals |            0.36 |
# |            LossPi |          -0.995 |
# |             LossQ |        0.000549 |
# |              Time |             164 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |      AverageQVals |            0.98 |
# |          StdQVals |           0.614 |
# |          MaxQVals |            4.77 |
# |          MinQVals |           0.346 |
# |            LossPi |          -0.983 |
# |             LossQ |        0.000648 |
# |              Time |             173 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |           0.133 |
# |          StdEpRet |           0.499 |
# |          MaxEpRet |               2 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |      AverageQVals |           0.966 |
# |          StdQVals |           0.596 |
# |          MaxQVals |            4.51 |
# |          MinQVals |           0.349 |
# |            LossPi |          -0.968 |
# |             LossQ |        0.000527 |
# |              Time |             181 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.1 |
# |      StdTestEpRet |             0.3 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |      AverageQVals |           0.964 |
# |          StdQVals |           0.594 |
# |          MaxQVals |            4.51 |
# |          MinQVals |           0.357 |
# |            LossPi |          -0.966 |
# |             LossQ |        0.000635 |
# |              Time |             190 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.1 |
# |      StdTestEpRet |             0.3 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |      AverageQVals |           0.956 |
# |          StdQVals |           0.583 |
# |          MaxQVals |            4.39 |
# |          MinQVals |           0.358 |
# |            LossPi |          -0.958 |
# |             LossQ |         0.00068 |
# |              Time |             198 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |      AverageQVals |           0.947 |
# |          StdQVals |           0.566 |
# |          MaxQVals |            4.21 |
# |          MinQVals |           0.347 |
# |            LossPi |           -0.95 |
# |             LossQ |        0.000567 |
# |              Time |             206 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.2 |
# |      StdTestEpRet |             0.6 |
# |      MaxTestEpRet |               2 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |      AverageQVals |           0.926 |
# |          StdQVals |           0.545 |
# |          MaxQVals |            4.09 |
# |          MinQVals |           0.339 |
# |            LossPi |          -0.928 |
# |             LossQ |        0.000502 |
# |              Time |             214 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |      AverageQVals |           0.898 |
# |          StdQVals |           0.521 |
# |          MaxQVals |            3.97 |
# |          MinQVals |           0.344 |
# |            LossPi |            -0.9 |
# |             LossQ |        0.000525 |
# |              Time |             222 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |      AverageQVals |            0.88 |
# |          StdQVals |           0.507 |
# |          MaxQVals |               4 |
# |          MinQVals |           0.339 |
# |            LossPi |          -0.881 |
# |             LossQ |        0.000534 |
# |              Time |             231 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |      AverageQVals |           0.853 |
# |          StdQVals |           0.488 |
# |          MaxQVals |            3.86 |
# |          MinQVals |           0.333 |
# |            LossPi |          -0.854 |
# |             LossQ |        0.000483 |
# |              Time |             240 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |           0.133 |
# |          StdEpRet |           0.499 |
# |          MaxEpRet |               2 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.2 |
# |      StdTestEpRet |             0.4 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |           0.835 |
# |          StdQVals |           0.479 |
# |          MaxQVals |            3.73 |
# |          MinQVals |           0.324 |
# |            LossPi |          -0.837 |
# |             LossQ |        0.000515 |
# |              Time |             249 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |      AverageQVals |           0.816 |
# |          StdQVals |           0.462 |
# |          MaxQVals |             3.6 |
# |          MinQVals |           0.312 |
# |            LossPi |          -0.817 |
# |             LossQ |        0.000521 |
# |              Time |             258 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |      AverageQVals |           0.794 |
# |          StdQVals |           0.445 |
# |          MaxQVals |            3.51 |
# |          MinQVals |           0.302 |
# |            LossPi |          -0.794 |
# |             LossQ |        0.000442 |
# |              Time |             268 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |      AverageQVals |           0.772 |
# |          StdQVals |            0.43 |
# |          MaxQVals |            3.32 |
# |          MinQVals |           0.291 |
# |            LossPi |          -0.773 |
# |             LossQ |        0.000568 |
# |              Time |             276 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |      AverageQVals |           0.759 |
# |          StdQVals |           0.424 |
# |          MaxQVals |            3.21 |
# |          MinQVals |           0.275 |
# |            LossPi |           -0.76 |
# |             LossQ |        0.000473 |
# |              Time |             285 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |      AverageQVals |            0.74 |
# |          StdQVals |           0.419 |
# |          MaxQVals |            3.21 |
# |          MinQVals |           0.269 |
# |            LossPi |          -0.742 |
# |             LossQ |        0.000441 |
# |              Time |             293 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |      AverageQVals |           0.727 |
# |          StdQVals |           0.419 |
# |          MaxQVals |            3.06 |
# |          MinQVals |            0.26 |
# |            LossPi |          -0.728 |
# |             LossQ |         0.00039 |
# |              Time |             303 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |      AverageQVals |           0.711 |
# |          StdQVals |           0.411 |
# |          MaxQVals |               3 |
# |          MinQVals |           0.249 |
# |            LossPi |          -0.712 |
# |             LossQ |        0.000394 |
# |              Time |             313 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.1 |
# |      StdTestEpRet |             0.3 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |      AverageQVals |           0.698 |
# |          StdQVals |           0.404 |
# |          MaxQVals |            2.85 |
# |          MinQVals |           0.237 |
# |            LossPi |          -0.699 |
# |             LossQ |        0.000415 |
# |              Time |             322 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |      AverageQVals |           0.683 |
# |          StdQVals |           0.394 |
# |          MaxQVals |            2.61 |
# |          MinQVals |           0.221 |
# |            LossPi |          -0.684 |
# |             LossQ |        0.000329 |
# |              Time |             333 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.2 |
# |      StdTestEpRet |             0.4 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |           0.666 |
# |          StdQVals |            0.38 |
# |          MaxQVals |            2.57 |
# |          MinQVals |           0.208 |
# |            LossPi |          -0.667 |
# |             LossQ |          0.0004 |
# |              Time |             344 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |      AverageQVals |           0.648 |
# |          StdQVals |           0.371 |
# |          MaxQVals |            2.51 |
# |          MinQVals |           0.187 |
# |            LossPi |          -0.649 |
# |             LossQ |        0.000404 |
# |              Time |             354 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.2 |
# |      StdTestEpRet |             0.4 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |      AverageQVals |           0.635 |
# |          StdQVals |           0.369 |
# |          MaxQVals |             2.4 |
# |          MinQVals |           0.193 |
# |            LossPi |          -0.636 |
# |             LossQ |         0.00039 |
# |              Time |             366 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.1 |
# |      StdTestEpRet |             0.3 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |      AverageQVals |           0.621 |
# |          StdQVals |           0.364 |
# |          MaxQVals |            2.37 |
# |          MinQVals |           0.185 |
# |            LossPi |          -0.622 |
# |             LossQ |        0.000299 |
# |              Time |             378 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |           0.133 |
# |          StdEpRet |            0.34 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |      AverageQVals |           0.605 |
# |          StdQVals |           0.354 |
# |          MaxQVals |            2.34 |
# |          MinQVals |            0.17 |
# |            LossPi |          -0.606 |
# |             LossQ |         0.00043 |
# |              Time |             391 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |           0.133 |
# |          StdEpRet |            0.34 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |      AverageQVals |           0.593 |
# |          StdQVals |           0.347 |
# |          MaxQVals |            2.29 |
# |          MinQVals |           0.144 |
# |            LossPi |          -0.594 |
# |             LossQ |        0.000313 |
# |              Time |             403 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |      AverageQVals |           0.578 |
# |          StdQVals |           0.339 |
# |          MaxQVals |            2.31 |
# |          MinQVals |           0.155 |
# |            LossPi |          -0.579 |
# |             LossQ |        0.000404 |
# |              Time |             414 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.75e+04 |
# |      AverageQVals |           0.567 |
# |          StdQVals |           0.332 |
# |          MaxQVals |            2.22 |
# |          MinQVals |           0.162 |
# |            LossPi |          -0.567 |
# |             LossQ |        0.000233 |
# |              Time |             424 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.92e+04 |
# |      AverageQVals |           0.546 |
# |          StdQVals |           0.319 |
# |          MaxQVals |               2 |
# |          MinQVals |           0.153 |
# |            LossPi |          -0.547 |
# |             LossQ |        0.000329 |
# |              Time |             435 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+04 |
# |      AverageQVals |           0.531 |
# |          StdQVals |            0.31 |
# |          MaxQVals |            1.98 |
# |          MinQVals |           0.146 |
# |            LossPi |          -0.532 |
# |             LossQ |         0.00042 |
# |              Time |             446 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |           0.133 |
# |          StdEpRet |           0.499 |
# |          MaxEpRet |               2 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |           0.517 |
# |          StdQVals |           0.303 |
# |          MaxQVals |            1.99 |
# |          MinQVals |           0.139 |
# |            LossPi |          -0.518 |
# |             LossQ |        0.000366 |
# |              Time |             457 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.41e+04 |
# |      AverageQVals |           0.503 |
# |          StdQVals |           0.296 |
# |          MaxQVals |            1.83 |
# |          MinQVals |           0.128 |
# |            LossPi |          -0.504 |
# |             LossQ |        0.000324 |
# |              Time |             472 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.1 |
# |      StdTestEpRet |             0.3 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.58e+04 |
# |      AverageQVals |           0.491 |
# |          StdQVals |           0.289 |
# |          MaxQVals |            1.79 |
# |          MinQVals |           0.114 |
# |            LossPi |          -0.491 |
# |             LossQ |        0.000436 |
# |              Time |             486 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |           0.133 |
# |          StdEpRet |            0.34 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.74e+04 |
# |      AverageQVals |           0.479 |
# |          StdQVals |           0.281 |
# |          MaxQVals |            1.72 |
# |          MinQVals |           0.109 |
# |            LossPi |           -0.48 |
# |             LossQ |        0.000374 |
# |              Time |             498 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.91e+04 |
# |      AverageQVals |           0.465 |
# |          StdQVals |           0.272 |
# |          MaxQVals |            1.73 |
# |          MinQVals |           0.103 |
# |            LossPi |          -0.466 |
# |             LossQ |        0.000382 |
# |              Time |             512 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.1 |
# |      StdTestEpRet |             0.3 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        9.07e+04 |
# |      AverageQVals |           0.451 |
# |          StdQVals |           0.264 |
# |          MaxQVals |            1.61 |
# |          MinQVals |             0.1 |
# |            LossPi |          -0.452 |
# |             LossQ |        0.000339 |
# |              Time |             523 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              56 |
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              77 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.1 |
# |      StdTestEpRet |             0.3 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.27e+05 |
# |      AverageQVals |            0.27 |
# |          StdQVals |           0.167 |
# |          MaxQVals |            1.28 |
# |          MinQVals |          0.0353 |
# |            LossPi |           -0.27 |
# |             LossQ |        0.000377 |
# |              Time |             751 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              78 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.29e+05 |
# |      AverageQVals |           0.264 |
# |          StdQVals |           0.164 |
# |          MaxQVals |            1.27 |
# |          MinQVals |          0.0241 |
# |            LossPi |          -0.264 |
# |             LossQ |        0.000367 |
# |              Time |             761 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              79 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+05 |
# |      AverageQVals |           0.257 |
# |          StdQVals |           0.162 |
# |          MaxQVals |            1.22 |
# |          MinQVals |          0.0219 |
# |            LossPi |          -0.257 |
# |             LossQ |        0.000331 |
# |              Time |             772 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              80 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+05 |
# |      AverageQVals |            0.25 |
# |          StdQVals |           0.158 |
# |          MaxQVals |            1.19 |
# |          MinQVals |          0.0257 |
# |            LossPi |          -0.251 |
# |             LossQ |        0.000331 |
# |              Time |             782 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              81 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.34e+05 |
# |      AverageQVals |           0.243 |
# |          StdQVals |           0.155 |
# |          MaxQVals |            1.22 |
# |          MinQVals |          0.0129 |
# |            LossPi |          -0.244 |
# |             LossQ |        0.000339 |
# |              Time |             792 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              82 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.35e+05 |
# |      AverageQVals |           0.238 |
# |          StdQVals |           0.152 |
# |          MaxQVals |            1.16 |
# |          MinQVals |          0.0123 |
# |            LossPi |          -0.238 |
# |             LossQ |        0.000336 |
# |              Time |             802 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              83 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.37e+05 |
# |      AverageQVals |           0.232 |
# |          StdQVals |           0.148 |
# |          MaxQVals |            1.15 |
# |          MinQVals |          0.0149 |
# |            LossPi |          -0.232 |
# |             LossQ |        0.000314 |
# |              Time |             811 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.1 |
# |      StdTestEpRet |             0.3 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.39e+05 |
# |      AverageQVals |           0.228 |
# |          StdQVals |           0.146 |
# |          MaxQVals |            1.15 |
# |          MinQVals |         0.00943 |
# |            LossPi |          -0.229 |
# |             LossQ |        0.000421 |
# |              Time |             820 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.4e+05 |
# |      AverageQVals |           0.225 |
# |          StdQVals |           0.146 |
# |          MaxQVals |            1.23 |
# |          MinQVals |         0.00511 |
# |            LossPi |          -0.225 |
# |             LossQ |        0.000443 |
# |              Time |             832 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.1 |
# |      StdTestEpRet |             0.3 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.42e+05 |
# |      AverageQVals |            0.22 |
# |          StdQVals |           0.145 |
# |          MaxQVals |            1.26 |
# |          MinQVals |         0.00781 |
# |            LossPi |           -0.22 |
# |             LossQ |        0.000279 |
# |              Time |             843 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.44e+05 |
# |      AverageQVals |           0.216 |
# |          StdQVals |           0.144 |
# |          MaxQVals |            1.17 |
# |          MinQVals |       -8.71e-05 |
# |            LossPi |          -0.216 |
# |             LossQ |        0.000303 |
# |              Time |             854 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.45e+05 |
# |      AverageQVals |           0.214 |
# |          StdQVals |           0.143 |
# |          MaxQVals |            1.15 |
# |          MinQVals |         0.00197 |
# |            LossPi |          -0.214 |
# |             LossQ |        0.000414 |
# |              Time |             866 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.47e+05 |
# |      AverageQVals |            0.21 |
# |          StdQVals |           0.141 |
# |          MaxQVals |            1.15 |
# |          MinQVals |         -0.0136 |
# |            LossPi |           -0.21 |
# |             LossQ |          0.0003 |
# |              Time |             877 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+05 |
# |      AverageQVals |           0.206 |
# |          StdQVals |           0.139 |
# |          MaxQVals |            1.13 |
# |          MinQVals |        -0.00892 |
# |            LossPi |          -0.206 |
# |             LossQ |        0.000371 |
# |              Time |             889 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.5e+05 |
# |      AverageQVals |           0.203 |
# |          StdQVals |           0.135 |
# |          MaxQVals |            1.04 |
# |          MinQVals |         -0.0097 |
# |            LossPi |          -0.203 |
# |             LossQ |        0.000351 |
# |              Time |             899 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.1 |
# |      StdTestEpRet |             0.3 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.52e+05 |
# |      AverageQVals |           0.198 |
# |          StdQVals |           0.131 |
# |          MaxQVals |           0.991 |
# |          MinQVals |        -0.00661 |
# |            LossPi |          -0.198 |
# |             LossQ |        0.000295 |
# |              Time |             909 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             0.1 |
# |      StdTestEpRet |             0.3 |
# |      MaxTestEpRet |               1 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.53e+05 |
# |      AverageQVals |           0.194 |
# |          StdQVals |           0.128 |
# |          MaxQVals |            1.03 |
# |          MinQVals |         -0.0148 |
# |            LossPi |          -0.194 |
# |             LossQ |         0.00034 |
# |              Time |             918 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |          0.0667 |
# |          StdEpRet |           0.249 |
# |          MaxEpRet |               1 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.55e+05 |
# |      AverageQVals |           0.189 |
# |          StdQVals |           0.125 |
# |          MaxQVals |           0.944 |
# |          MinQVals |         -0.0305 |
# |            LossPi |          -0.189 |
# |             LossQ |        0.000329 |
# |              Time |             928 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |               0 |
# |          StdEpRet |               0 |
# |          MaxEpRet |               0 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |               0 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |               0 |
# |      MinTestEpRet |               0 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.57e+05 |
# |      AverageQVals |           0.185 |
# |          StdQVals |           0.121 |
# |          MaxQVals |           0.912 |
# |          MinQVals |         -0.0195 |
# |            LossPi |          -0.185 |
# |             LossQ |        0.000362 |
# |              Time |             937 |
# ---------------------------------------

# %% [markdown]
# ## Test

# %%
# Test paramaters
env_name = 'gyroscopeenv-v0'
reward_type = 'Quadratic'
reward_args = {'qx1':9,'qx2':0.05,'qx3':9,'qx4':0.05,'pu1':0.1,'pu2':0.1}
seed = 0
agent_path = 'td3_nh_b2/'
init_state = [1.3,0,0,0,-0.8,0.9,20]
ep_len = 220
t_end = ep_len*0.05

# Perform testing
r,score,x1_eval,x2_eval,x3_eval,x4_eval,x1_ref_eval,x3_ref_eval,act = test_agent(env_name,reward_type,reward_args,seed,agent_path,init_state,t_end,ep_len)
# Out:
# Total cumulative reward: -254.76078676844725

# %% [markdown]
# ## Plot

# %%
plot_test(x1_eval,x2_eval,x3_eval,x4_eval,x1_ref_eval,x3_ref_eval,act,t_end)

# %% [markdown]
# ## Evaluate control performance

# %%
# Single evaluation
env_name = 'gyroscopeenv-v0'
agent_path = 'ddpg_q'
ss_bound = 0.25
metrics = evaluate_control(env_name,agent_path,ss_bound)
metrics
# Out:
# /home/matthieulc/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
#          MAE on θ (rad)  MAE on φ (rad)  Mean SS error on θ (rad)  \
# Config.
# ddpg_q         0.502788        0.391088                  0.533114
#
#          Mean SS error on φ (rad)  θ in bounds %  φ in bounds %  θ unsteady %  \
# Config.
# ddpg_q                   0.377736           21.5           24.0          28.5
#
#          φ unsteady %  Mean rise time on θ (s)  Mean rise time on φ (s)  \
# Config.
# ddpg_q           32.0                 0.296221                 0.332552
#
#          Mean settling time on θ (s)  Mean settling time on φ (s)  \
# Config.
# ddpg_q                       0.89564                     0.722135
#
#          Mean u1 (V)  Mean u2 (V)  Mean u1 difference (V)  \
# Config.
# ddpg_q      1.748288     1.616401                0.241502
#
#          Mean u2 difference (V)  Convergence time (min)
# Config.
# ddpg_q                 0.285933               15.184833

# %%
# Init dataframe
env_name = 'gyroscopeenv-v0'
agent_paths = ['ddpg_q','ddpg_q_ep','ddpg_q_p','ddpg_q_e','ddpg_q_b','ddpg_a','ddpg_n']
ss_bound = 0.25

# Loop dataframe
for idx, agent_path in zip(range(len(agent_paths)),agent_paths):
    if idx == 0:
        metrics = evaluate_control(env_name,agent_path,ss_bound)
    else:
        new_metrics = evaluate_control(env_name,agent_path,ss_bound)
        metrics = metrics.append(new_metrics)
# Out:
# /home/matthieulc/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
# Manipulate
metrics_man = metrics[['$\theta$ MAE (rad)','$\phi$ MAE (rad)','$\theta$ MSSE (rad)','$\phi$ MSSE (rad)','$\theta$ in bounds (%)','$\phi$ in bounds (%)','$\theta$ unsteady (%)','$\phi$ unsteady (%)','u1 (V)','u2 (V)','u1 variation (V)','u2 variation (V)']]
metrics_man = metrics_man.loc[['ddpg_q','ddpg_q_ep','ddpg_q_p','ddpg_q_e','ddpg_q_b'],:]
metrics_man = metrics_man.transpose()
metrics_man = metrics_man.round(2)
metrics_man
# Out:
# Config.                 ddpg_q  ddpg_q_ep  ddpg_q_p  ddpg_q_e  ddpg_q_b
# $\theta$ MAE (rad)        0.51       0.77      0.52      0.40      0.63
# $\phi$ MAE (rad)          0.36       0.54      0.37      0.29      0.46
# $\theta$ MSSE (rad)       0.46       0.60      0.42      0.29      0.54
# $\phi$ MSSE (rad)         0.32       0.48      0.31      0.21      0.40
# $\theta$ in bounds (%)   39.50      40.00     38.00     65.50     28.00
# $\phi$ in bounds (%)     45.50      34.50     46.50     74.00     27.50
# $\theta$ unsteady (%)     0.00       0.00      0.00      0.00      5.00
# $\phi$ unsteady (%)      11.00       0.00      0.00      3.00      8.00
# u1 (V)                    1.83       1.38      1.10      0.97      1.66
# u2 (V)                    1.54       0.91      0.95      1.07      1.94
# u1 variation (V)          0.25       0.11      0.09      0.11      0.28
# u2 variation (V)          0.27       0.16      0.26      0.21      0.55

# %%
# To LaTex
print(metrics_man.to_latex(escape=False))
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# Config. &  ddpg_q &  ddpg_q_ep &  ddpg_q_p &  ddpg_q_e &  ddpg_q_b \\
# \midrule
# $\theta$ MAE (rad)     &    0.51 &       0.77 &      0.52 &      0.40 &      0.63 \\
# $\phi$ MAE (rad)       &    0.36 &       0.54 &      0.37 &      0.29 &      0.46 \\
# $\theta$ MSSE (rad)    &    0.46 &       0.60 &      0.42 &      0.29 &      0.54 \\
# $\phi$ MSSE (rad)      &    0.32 &       0.48 &      0.31 &      0.21 &      0.40 \\
# $\theta$ in bounds (%) &   39.50 &      40.00 &     38.00 &     65.50 &     28.00 \\
# $\phi$ in bounds (%)   &   45.50 &      34.50 &     46.50 &     74.00 &     27.50 \\
# $\theta$ unsteady (%)  &    0.00 &       0.00 &      0.00 &      0.00 &      5.00 \\
# $\phi$ unsteady (%)    &   11.00 &       0.00 &      0.00 &      3.00 &      8.00 \\
# u1 (V)                 &    1.83 &       1.38 &      1.10 &      0.97 &      1.66 \\
# u2 (V)                 &    1.54 &       0.91 &      0.95 &      1.07 &      1.94 \\
# u1 variation (V)       &    0.25 &       0.11 &      0.09 &      0.11 &      0.28 \\
# u2 variation (V)       &    0.27 &       0.16 &      0.26 &      0.21 &      0.55 \\
# \bottomrule
# \end{tabular}

# %%
# Manipulate
metrics_man = metrics[['$\theta$ MAE (rad)','$\phi$ MAE (rad)','$\theta$ MSSE (rad)','$\phi$ MSSE (rad)','$\theta$ in bounds (%)','$\phi$ in bounds (%)','$\theta$ unsteady (%)','$\phi$ unsteady (%)','u1 (V)','u2 (V)','u1 variation (V)','u2 variation (V)']]
metrics_man = metrics_man.loc[['ddpg_a','ddpg_n'],:]
metrics_man = metrics_man.transpose()
metrics_man = metrics_man.round(2)
metrics_man
# Out:
# Config.                 ddpg_a  ddpg_n
# $\theta$ MAE (rad)        0.41    0.49
# $\phi$ MAE (rad)          0.34    0.32
# $\theta$ MSSE (rad)       0.33    0.17
# $\phi$ MSSE (rad)         0.25    0.16
# $\theta$ in bounds (%)   51.50   82.50
# $\phi$ in bounds (%)     54.50   89.00
# $\theta$ unsteady (%)     0.00    0.00
# $\phi$ unsteady (%)       0.00    0.00
# u1 (V)                    0.98    0.82
# u2 (V)                    0.77    0.59
# u1 variation (V)          0.10    0.08
# u2 variation (V)          0.13    0.05

# %%
# To LaTex
print(metrics_man.to_latex(escape=False))
# Out:
# \begin{tabular}{lrr}
# \toprule
# Config. &  ddpg_a &  ddpg_n \\
# \midrule
# $\theta$ MAE (rad)     &    0.41 &    0.49 \\
# $\phi$ MAE (rad)       &    0.34 &    0.32 \\
# $\theta$ MSSE (rad)    &    0.33 &    0.17 \\
# $\phi$ MSSE (rad)      &    0.25 &    0.16 \\
# $\theta$ in bounds (%) &   51.50 &   82.50 \\
# $\phi$ in bounds (%)   &   54.50 &   89.00 \\
# $\theta$ unsteady (%)  &    0.00 &    0.00 \\
# $\phi$ unsteady (%)    &    0.00 &    0.00 \\
# u1 (V)                 &    0.98 &    0.82 \\
# u2 (V)                 &    0.77 &    0.59 \\
# u1 variation (V)       &    0.10 &    0.08 \\
# u2 variation (V)       &    0.13 &    0.05 \\
# \bottomrule
# \end{tabular}
