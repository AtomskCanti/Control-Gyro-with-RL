# %% [markdown]
# # TD3 hyperparameter search with normalized reward (spinup library)

# %%
import gym
from gym import spaces
from gym.utils import seeding
from gym.envs.registration import register

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control

import spinup

from os import path
from scipy.integrate import solve_ivp
import random
import torch
import numpy as np
import pandas as pd
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline
#from vpython import *
from functools import partial

register(id='gyroscopeenv-v0',entry_point='gym_GyroscopeEnv.envs:GyroscopeEnv')

# %% [markdown]
# ## Baseline iteration

# %% [markdown]
# #### Extra layer

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_b_it2_extralay', exp_name='td3_n_b_it2_extralay')
seed_b = 10
epochs_b = 1000
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.985
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[700,70], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0015
qlr_b = 0.0015

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.04

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)
# Out:
# Logging data to td3_n_it1_hid_var0/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             700
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	150,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fc9b0b23710>, env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.05, 'qx2': 0.01, 'qx4': 0.01, 'pu1': 0.5, 'pu2': 0.5}, ep_len=110)",
#     "epochs":	800,
#     "exp_name":	"td3_n_it1_hid_var0",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fc97c338410>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_n_it1_hid_var0",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_n_it1_hid_var0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_n_it1_hid_var0/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_n_it1_hid_var0",
#         "output_dir":	"td3_n_it1_hid_var0"
#     },
#     "max_ep_len":	110,
#     "noise_clip":	0.05,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.999,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	20000,
#     "steps_per_epoch":	1650,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 8402, 	 q1: 9101, 	 q2: 9101
# /home/lecauchoismatthieu/drlenv/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -303 |
# |          StdEpRet |            11.4 |
# |          MaxEpRet |            -289 |
# |          MinEpRet |            -325 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            12.5 |
# |      MaxTestEpRet |            -179 |
# |      MinTestEpRet |            -226 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |     AverageQ1Vals |           -3.18 |
# |         StdQ1Vals |           0.569 |
# |         MaxQ1Vals |           0.245 |
# |         MinQ1Vals |            -5.2 |
# |     AverageQ2Vals |           -3.18 |
# |         StdQ2Vals |           0.575 |
# |         MaxQ2Vals |           0.309 |
# |         MinQ2Vals |           -5.29 |
# |            LossPi |            2.85 |
# |             LossQ |           0.379 |
# |              Time |            8.31 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -323 |
# |          StdEpRet |            19.4 |
# |          MaxEpRet |            -286 |
# |          MinEpRet |            -351 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            15.7 |
# |      MaxTestEpRet |            -165 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |     AverageQ1Vals |           -4.48 |
# |         StdQ1Vals |           0.772 |
# |         MaxQ1Vals |           -2.37 |
# |         MinQ1Vals |           -8.31 |
# |     AverageQ2Vals |           -4.48 |
# |         StdQ2Vals |           0.772 |
# |         MaxQ2Vals |           -2.39 |
# |         MinQ2Vals |           -8.34 |
# |            LossPi |            4.02 |
# |             LossQ |          0.0875 |
# |              Time |            22.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -313 |
# |          StdEpRet |              23 |
# |          MaxEpRet |            -287 |
# |          MinEpRet |            -367 |
# |  AverageTestEpRet |            -212 |
# |      StdTestEpRet |             8.8 |
# |      MaxTestEpRet |            -193 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |     AverageQ1Vals |           -6.08 |
# |         StdQ1Vals |           0.916 |
# |         MaxQ1Vals |           -3.24 |
# |         MinQ1Vals |           -10.5 |
# |     AverageQ2Vals |           -6.08 |
# |         StdQ2Vals |           0.916 |
# |         MaxQ2Vals |           -3.32 |
# |         MinQ2Vals |           -10.6 |
# |            LossPi |            5.56 |
# |             LossQ |          0.0754 |
# |              Time |            36.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -317 |
# |          StdEpRet |            31.4 |
# |          MaxEpRet |            -285 |
# |          MinEpRet |            -385 |
# |  AverageTestEpRet |            -212 |
# |      StdTestEpRet |            10.5 |
# |      MaxTestEpRet |            -191 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |     AverageQ1Vals |           -7.76 |
# |         StdQ1Vals |            1.13 |
# |         MaxQ1Vals |           -4.48 |
# |         MinQ1Vals |             -13 |
# |     AverageQ2Vals |           -7.76 |
# |         StdQ2Vals |            1.13 |
# |         MaxQ2Vals |           -4.46 |
# |         MinQ2Vals |           -12.9 |
# |            LossPi |            7.18 |
# |             LossQ |          0.0785 |
# |              Time |            50.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -318 |
# |          StdEpRet |            25.8 |
# |          MaxEpRet |            -268 |
# |          MinEpRet |            -358 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            10.1 |
# |      MaxTestEpRet |            -195 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |     AverageQ1Vals |           -9.41 |
# |         StdQ1Vals |            1.32 |
# |         MaxQ1Vals |           -5.77 |
# |         MinQ1Vals |           -15.3 |
# |     AverageQ2Vals |           -9.41 |
# |         StdQ2Vals |            1.32 |
# |         MaxQ2Vals |           -5.76 |
# |         MinQ2Vals |           -15.4 |
# |            LossPi |            8.77 |
# |             LossQ |          0.0793 |
# |              Time |            64.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -329 |
# |          StdEpRet |            27.9 |
# |          MaxEpRet |            -286 |
# |          MinEpRet |            -378 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            9.42 |
# |      MaxTestEpRet |            -191 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |     AverageQ1Vals |           -11.1 |
# |         StdQ1Vals |            1.51 |
# |         MaxQ1Vals |           -6.92 |
# |         MinQ1Vals |           -17.4 |
# |     AverageQ2Vals |           -11.1 |
# |         StdQ2Vals |            1.51 |
# |         MaxQ2Vals |           -6.95 |
# |         MinQ2Vals |           -17.6 |
# |            LossPi |            10.4 |
# |             LossQ |          0.0869 |
# |              Time |            79.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -314 |
# |          StdEpRet |            24.9 |
# |          MaxEpRet |            -281 |
# |          MinEpRet |            -363 |
# |  AverageTestEpRet |            -210 |
# |      StdTestEpRet |            10.2 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |     AverageQ1Vals |           -12.8 |
# |         StdQ1Vals |            1.69 |
# |         MaxQ1Vals |            -8.2 |
# |         MinQ1Vals |           -19.3 |
# |     AverageQ2Vals |           -12.8 |
# |         StdQ2Vals |            1.69 |
# |         MaxQ2Vals |           -8.32 |
# |         MinQ2Vals |           -19.6 |
# |            LossPi |              12 |
# |             LossQ |          0.0924 |
# |              Time |            93.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -315 |
# |          StdEpRet |            27.2 |
# |          MaxEpRet |            -288 |
# |          MinEpRet |            -386 |
# |  AverageTestEpRet |            -216 |
# |      StdTestEpRet |            3.04 |
# |      MaxTestEpRet |            -211 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |     AverageQ1Vals |           -14.3 |
# |         StdQ1Vals |            1.84 |
# |         MaxQ1Vals |           -9.52 |
# |         MinQ1Vals |           -22.1 |
# |     AverageQ2Vals |           -14.3 |
# |         StdQ2Vals |            1.84 |
# |         MaxQ2Vals |           -9.59 |
# |         MinQ2Vals |           -21.8 |
# |            LossPi |            13.5 |
# |             LossQ |             0.1 |
# |              Time |             107 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -316 |
# |          StdEpRet |            19.9 |
# |          MaxEpRet |            -286 |
# |          MinEpRet |            -356 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |            12.1 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |            -224 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |     AverageQ1Vals |           -15.8 |
# |         StdQ1Vals |            1.96 |
# |         MaxQ1Vals |           -10.6 |
# |         MinQ1Vals |           -24.1 |
# |     AverageQ2Vals |           -15.8 |
# |         StdQ2Vals |            1.96 |
# |         MaxQ2Vals |           -10.7 |
# |         MinQ2Vals |           -23.9 |
# |            LossPi |            14.9 |
# |             LossQ |            0.11 |
# |              Time |             121 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -331 |
# |          StdEpRet |            29.5 |
# |          MaxEpRet |            -286 |
# |          MinEpRet |            -396 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |            11.3 |
# |      MaxTestEpRet |            -188 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -17.3 |
# |         StdQ1Vals |            2.07 |
# |         MaxQ1Vals |           -11.8 |
# |         MinQ1Vals |           -25.9 |
# |     AverageQ2Vals |           -17.3 |
# |         StdQ2Vals |            2.07 |
# |         MaxQ2Vals |           -11.8 |
# |         MinQ2Vals |             -26 |
# |            LossPi |            16.3 |
# |             LossQ |           0.121 |
# |              Time |             135 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -335 |
# |          StdEpRet |            33.4 |
# |          MaxEpRet |            -286 |
# |          MinEpRet |            -398 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |            10.8 |
# |      MaxTestEpRet |            -191 |
# |      MinTestEpRet |            -224 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |     AverageQ1Vals |           -18.8 |
# |         StdQ1Vals |            2.22 |
# |         MaxQ1Vals |           -13.1 |
# |         MinQ1Vals |           -27.8 |
# |     AverageQ2Vals |           -18.8 |
# |         StdQ2Vals |            2.22 |
# |         MaxQ2Vals |             -13 |
# |         MinQ2Vals |           -27.9 |
# |            LossPi |            17.8 |
# |             LossQ |           0.134 |
# |              Time |             148 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -313 |
# |          StdEpRet |            26.7 |
# |          MaxEpRet |            -279 |
# |          MinEpRet |            -370 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            9.83 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |     AverageQ1Vals |           -20.2 |
# |         StdQ1Vals |            2.28 |
# |         MaxQ1Vals |           -14.2 |
# |         MinQ1Vals |           -29.6 |
# |     AverageQ2Vals |           -20.2 |
# |         StdQ2Vals |            2.28 |
# |         MaxQ2Vals |           -14.1 |
# |         MinQ2Vals |           -29.6 |
# |            LossPi |            19.2 |
# |             LossQ |           0.141 |
# |              Time |             163 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -224 |
# |          StdEpRet |              37 |
# |          MaxEpRet |            -195 |
# |          MinEpRet |            -321 |
# |  AverageTestEpRet |            -199 |
# |      StdTestEpRet |            19.2 |
# |      MaxTestEpRet |            -160 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |     AverageQ1Vals |           -21.5 |
# |         StdQ1Vals |            2.37 |
# |         MaxQ1Vals |           -15.3 |
# |         MinQ1Vals |           -30.9 |
# |     AverageQ2Vals |           -21.5 |
# |         StdQ2Vals |            2.37 |
# |         MaxQ2Vals |           -15.3 |
# |         MinQ2Vals |           -31.1 |
# |            LossPi |            20.5 |
# |             LossQ |            0.14 |
# |              Time |             177 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |              16 |
# |          MaxEpRet |            -171 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            10.2 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |     AverageQ1Vals |           -22.6 |
# |         StdQ1Vals |            2.53 |
# |         MaxQ1Vals |           -16.2 |
# |         MinQ1Vals |           -32.3 |
# |     AverageQ2Vals |           -22.6 |
# |         StdQ2Vals |            2.53 |
# |         MaxQ2Vals |           -16.1 |
# |         MinQ2Vals |           -32.8 |
# |            LossPi |            21.6 |
# |             LossQ |           0.133 |
# |              Time |             192 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -206 |
# |          StdEpRet |            13.1 |
# |          MaxEpRet |            -178 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |            10.8 |
# |      MaxTestEpRet |            -187 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |     AverageQ1Vals |           -23.7 |
# |         StdQ1Vals |            2.64 |
# |         MaxQ1Vals |           -17.2 |
# |         MinQ1Vals |             -34 |
# |     AverageQ2Vals |           -23.7 |
# |         StdQ2Vals |            2.64 |
# |         MaxQ2Vals |           -17.1 |
# |         MinQ2Vals |           -34.2 |
# |            LossPi |            22.8 |
# |             LossQ |           0.129 |
# |              Time |             206 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -209 |
# |          StdEpRet |            11.9 |
# |          MaxEpRet |            -176 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            4.97 |
# |      MaxTestEpRet |            -201 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |     AverageQ1Vals |           -24.8 |
# |         StdQ1Vals |            2.71 |
# |         MaxQ1Vals |           -18.3 |
# |         MinQ1Vals |           -35.2 |
# |     AverageQ2Vals |           -24.8 |
# |         StdQ2Vals |            2.71 |
# |         MaxQ2Vals |           -18.2 |
# |         MinQ2Vals |           -35.4 |
# |            LossPi |              24 |
# |             LossQ |           0.126 |
# |              Time |             220 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |              13 |
# |          MaxEpRet |            -170 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -202 |
# |      StdTestEpRet |              11 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |             -26 |
# |         StdQ1Vals |            2.77 |
# |         MaxQ1Vals |           -19.1 |
# |         MinQ1Vals |           -36.7 |
# |     AverageQ2Vals |             -26 |
# |         StdQ2Vals |            2.77 |
# |         MaxQ2Vals |           -19.1 |
# |         MinQ2Vals |           -36.9 |
# |            LossPi |            25.2 |
# |             LossQ |           0.125 |
# |              Time |             235 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -201 |
# |          StdEpRet |            15.3 |
# |          MaxEpRet |            -169 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            9.15 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |     AverageQ1Vals |           -27.1 |
# |         StdQ1Vals |            2.83 |
# |         MaxQ1Vals |           -20.1 |
# |         MinQ1Vals |           -38.5 |
# |     AverageQ2Vals |           -27.1 |
# |         StdQ2Vals |            2.83 |
# |         MaxQ2Vals |           -20.2 |
# |         MinQ2Vals |           -38.7 |
# |            LossPi |            26.4 |
# |             LossQ |           0.123 |
# |              Time |             249 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -206 |
# |          StdEpRet |            15.7 |
# |          MaxEpRet |            -158 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |              16 |
# |      MaxTestEpRet |            -169 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |     AverageQ1Vals |           -28.3 |
# |         StdQ1Vals |            2.89 |
# |         MaxQ1Vals |           -21.2 |
# |         MinQ1Vals |           -39.5 |
# |     AverageQ2Vals |           -28.3 |
# |         StdQ2Vals |            2.89 |
# |         MaxQ2Vals |           -21.2 |
# |         MinQ2Vals |           -39.4 |
# |            LossPi |            27.6 |
# |             LossQ |           0.124 |
# |              Time |             264 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -211 |
# |          StdEpRet |            6.26 |
# |          MaxEpRet |            -198 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -202 |
# |      StdTestEpRet |            22.6 |
# |      MaxTestEpRet |            -150 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -29.4 |
# |         StdQ1Vals |            2.93 |
# |         MaxQ1Vals |           -22.2 |
# |         MinQ1Vals |           -41.1 |
# |     AverageQ2Vals |           -29.4 |
# |         StdQ2Vals |            2.93 |
# |         MaxQ2Vals |           -22.2 |
# |         MinQ2Vals |             -41 |
# |            LossPi |            28.8 |
# |             LossQ |           0.122 |
# |              Time |             278 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            10.1 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            8.45 |
# |      MaxTestEpRet |            -194 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |     AverageQ1Vals |           -30.6 |
# |         StdQ1Vals |            2.97 |
# |         MaxQ1Vals |           -23.2 |
# |         MinQ1Vals |           -42.7 |
# |     AverageQ2Vals |           -30.6 |
# |         StdQ2Vals |            2.97 |
# |         MaxQ2Vals |           -23.3 |
# |         MinQ2Vals |           -42.9 |
# |            LossPi |            29.9 |
# |             LossQ |           0.122 |
# |              Time |             292 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -209 |
# |          StdEpRet |            9.22 |
# |          MaxEpRet |            -189 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -199 |
# |      StdTestEpRet |            16.1 |
# |      MaxTestEpRet |            -171 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |     AverageQ1Vals |           -31.7 |
# |         StdQ1Vals |            3.02 |
# |         MaxQ1Vals |           -24.3 |
# |         MinQ1Vals |           -43.9 |
# |     AverageQ2Vals |           -31.7 |
# |         StdQ2Vals |            3.02 |
# |         MaxQ2Vals |           -24.2 |
# |         MinQ2Vals |           -43.9 |
# |            LossPi |            31.1 |
# |             LossQ |           0.124 |
# |              Time |             306 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -202 |
# |          StdEpRet |            15.6 |
# |          MaxEpRet |            -166 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            6.45 |
# |      MaxTestEpRet |            -197 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |     AverageQ1Vals |           -32.9 |
# |         StdQ1Vals |            3.05 |
# |         MaxQ1Vals |           -25.3 |
# |         MinQ1Vals |           -45.3 |
# |     AverageQ2Vals |           -32.9 |
# |         StdQ2Vals |            3.05 |
# |         MaxQ2Vals |           -25.4 |
# |         MinQ2Vals |           -45.7 |
# |            LossPi |            32.3 |
# |             LossQ |           0.125 |
# |              Time |             321 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            14.6 |
# |          MaxEpRet |            -178 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            5.33 |
# |      MaxTestEpRet |            -195 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |     AverageQ1Vals |           -34.1 |
# |         StdQ1Vals |            3.08 |
# |         MaxQ1Vals |           -26.3 |
# |         MinQ1Vals |           -46.1 |
# |     AverageQ2Vals |           -34.1 |
# |         StdQ2Vals |            3.08 |
# |         MaxQ2Vals |           -26.3 |
# |         MinQ2Vals |           -46.8 |
# |            LossPi |            33.5 |
# |             LossQ |           0.126 |
# |              Time |             335 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -197 |
# |          StdEpRet |            20.3 |
# |          MaxEpRet |            -157 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -204 |
# |      StdTestEpRet |            12.7 |
# |      MaxTestEpRet |            -177 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |     AverageQ1Vals |           -35.2 |
# |         StdQ1Vals |            3.13 |
# |         MaxQ1Vals |           -27.2 |
# |         MinQ1Vals |           -48.3 |
# |     AverageQ2Vals |           -35.2 |
# |         StdQ2Vals |            3.13 |
# |         MaxQ2Vals |           -27.2 |
# |         MinQ2Vals |             -48 |
# |            LossPi |            34.6 |
# |             LossQ |           0.129 |
# |              Time |             350 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -197 |
# |          StdEpRet |            13.6 |
# |          MaxEpRet |            -161 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -213 |
# |      StdTestEpRet |            6.36 |
# |      MaxTestEpRet |            -201 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |     AverageQ1Vals |           -36.4 |
# |         StdQ1Vals |            3.15 |
# |         MaxQ1Vals |           -28.2 |
# |         MinQ1Vals |           -49.4 |
# |     AverageQ2Vals |           -36.4 |
# |         StdQ2Vals |            3.15 |
# |         MaxQ2Vals |           -28.2 |
# |         MinQ2Vals |           -49.6 |
# |            LossPi |            35.8 |
# |             LossQ |           0.132 |
# |              Time |             365 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -199 |
# |          StdEpRet |            23.3 |
# |          MaxEpRet |            -135 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -200 |
# |      StdTestEpRet |            11.2 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |     AverageQ1Vals |           -37.5 |
# |         StdQ1Vals |            3.21 |
# |         MaxQ1Vals |           -29.2 |
# |         MinQ1Vals |           -50.6 |
# |     AverageQ2Vals |           -37.5 |
# |         StdQ2Vals |            3.21 |
# |         MaxQ2Vals |           -29.3 |
# |         MinQ2Vals |           -50.8 |
# |            LossPi |            36.9 |
# |             LossQ |           0.136 |
# |              Time |             379 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -208 |
# |          StdEpRet |            10.2 |
# |          MaxEpRet |            -185 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -194 |
# |      StdTestEpRet |            16.4 |
# |      MaxTestEpRet |            -175 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |     AverageQ1Vals |           -38.6 |
# |         StdQ1Vals |            3.26 |
# |         MaxQ1Vals |           -30.3 |
# |         MinQ1Vals |           -52.2 |
# |     AverageQ2Vals |           -38.6 |
# |         StdQ2Vals |            3.26 |
# |         MaxQ2Vals |           -30.2 |
# |         MinQ2Vals |           -52.3 |
# |            LossPi |            38.1 |
# |             LossQ |           0.139 |
# |              Time |             394 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            19.5 |
# |          MaxEpRet |            -154 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -201 |
# |      StdTestEpRet |            17.4 |
# |      MaxTestEpRet |            -160 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |     AverageQ1Vals |           -39.7 |
# |         StdQ1Vals |            3.32 |
# |         MaxQ1Vals |           -31.2 |
# |         MinQ1Vals |           -53.8 |
# |     AverageQ2Vals |           -39.7 |
# |         StdQ2Vals |            3.32 |
# |         MaxQ2Vals |           -31.1 |
# |         MinQ2Vals |           -53.7 |
# |            LossPi |            39.2 |
# |             LossQ |           0.144 |
# |              Time |             408 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -199 |
# |          StdEpRet |            17.5 |
# |          MaxEpRet |            -163 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |            22.7 |
# |      MaxTestEpRet |            -151 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -40.8 |
# |         StdQ1Vals |            3.37 |
# |         MaxQ1Vals |           -32.3 |
# |         MinQ1Vals |           -55.1 |
# |     AverageQ2Vals |           -40.8 |
# |         StdQ2Vals |            3.37 |
# |         MaxQ2Vals |           -32.1 |
# |         MinQ2Vals |           -55.2 |
# |            LossPi |            40.3 |
# |             LossQ |           0.148 |
# |              Time |             423 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -207 |
# |          StdEpRet |            11.5 |
# |          MaxEpRet |            -177 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -193 |
# |      StdTestEpRet |            18.2 |
# |      MaxTestEpRet |            -159 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |     AverageQ1Vals |           -41.9 |
# |         StdQ1Vals |            3.43 |
# |         MaxQ1Vals |           -33.2 |
# |         MinQ1Vals |           -56.8 |
# |     AverageQ2Vals |           -41.9 |
# |         StdQ2Vals |            3.43 |
# |         MaxQ2Vals |           -33.1 |
# |         MinQ2Vals |           -56.6 |
# |            LossPi |            41.4 |
# |             LossQ |           0.151 |
# |              Time |             437 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            14.5 |
# |          MaxEpRet |            -174 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |              22 |
# |      MaxTestEpRet |            -135 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |     AverageQ1Vals |             -43 |
# |         StdQ1Vals |            3.46 |
# |         MaxQ1Vals |           -34.3 |
# |         MinQ1Vals |           -57.9 |
# |     AverageQ2Vals |             -43 |
# |         StdQ2Vals |            3.46 |
# |         MaxQ2Vals |           -34.1 |
# |         MinQ2Vals |           -58.1 |
# |            LossPi |            42.6 |
# |             LossQ |           0.154 |
# |              Time |             452 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -200 |
# |          StdEpRet |              24 |
# |          MaxEpRet |            -124 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -192 |
# |      StdTestEpRet |            16.4 |
# |      MaxTestEpRet |            -170 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |     AverageQ1Vals |           -44.1 |
# |         StdQ1Vals |            3.52 |
# |         MaxQ1Vals |           -35.2 |
# |         MinQ1Vals |           -59.2 |
# |     AverageQ2Vals |           -44.1 |
# |         StdQ2Vals |            3.52 |
# |         MaxQ2Vals |           -35.1 |
# |         MinQ2Vals |           -59.4 |
# |            LossPi |            43.6 |
# |             LossQ |           0.156 |
# |              Time |             466 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -196 |
# |          StdEpRet |            17.9 |
# |          MaxEpRet |            -158 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -201 |
# |      StdTestEpRet |            6.99 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |     AverageQ1Vals |           -45.2 |
# |         StdQ1Vals |            3.59 |
# |         MaxQ1Vals |           -36.2 |
# |         MinQ1Vals |           -60.5 |
# |     AverageQ2Vals |           -45.2 |
# |         StdQ2Vals |            3.59 |
# |         MaxQ2Vals |             -36 |
# |         MinQ2Vals |           -60.4 |
# |            LossPi |            44.7 |
# |             LossQ |           0.161 |
# |              Time |             480 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            10.3 |
# |          MaxEpRet |            -185 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -186 |
# |      StdTestEpRet |            21.8 |
# |      MaxTestEpRet |            -150 |
# |      MinTestEpRet |            -215 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |     AverageQ1Vals |           -46.2 |
# |         StdQ1Vals |            3.66 |
# |         MaxQ1Vals |             -37 |
# |         MinQ1Vals |           -61.8 |
# |     AverageQ2Vals |           -46.2 |
# |         StdQ2Vals |            3.66 |
# |         MaxQ2Vals |             -37 |
# |         MinQ2Vals |           -62.3 |
# |            LossPi |            45.8 |
# |             LossQ |           0.164 |
# |              Time |             495 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            10.6 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |            11.5 |
# |      MaxTestEpRet |            -183 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |     AverageQ1Vals |           -47.3 |
# |         StdQ1Vals |            3.71 |
# |         MaxQ1Vals |             -38 |
# |         MinQ1Vals |           -63.3 |
# |     AverageQ2Vals |           -47.3 |
# |         StdQ2Vals |            3.71 |
# |         MaxQ2Vals |             -38 |
# |         MinQ2Vals |             -63 |
# |            LossPi |            46.9 |
# |             LossQ |           0.169 |
# |              Time |             509 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -202 |
# |          StdEpRet |            17.4 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -197 |
# |      StdTestEpRet |            15.9 |
# |      MaxTestEpRet |            -166 |
# |      MinTestEpRet |            -215 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |     AverageQ1Vals |           -48.4 |
# |         StdQ1Vals |            3.76 |
# |         MaxQ1Vals |           -38.8 |
# |         MinQ1Vals |           -64.7 |
# |     AverageQ2Vals |           -48.4 |
# |         StdQ2Vals |            3.76 |
# |         MaxQ2Vals |           -38.8 |
# |         MinQ2Vals |           -64.3 |
# |            LossPi |            47.9 |
# |             LossQ |           0.172 |
# |              Time |             524 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -206 |
# |          StdEpRet |            8.06 |
# |          MaxEpRet |            -186 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -187 |
# |      StdTestEpRet |            20.7 |
# |      MaxTestEpRet |            -157 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |     AverageQ1Vals |           -49.4 |
# |         StdQ1Vals |            3.81 |
# |         MaxQ1Vals |           -39.5 |
# |         MinQ1Vals |           -66.1 |
# |     AverageQ2Vals |           -49.4 |
# |         StdQ2Vals |            3.81 |
# |         MaxQ2Vals |           -39.4 |
# |         MinQ2Vals |           -65.6 |
# |            LossPi |              49 |
# |             LossQ |           0.174 |
# |              Time |             538 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -191 |
# |          StdEpRet |            15.5 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -194 |
# |      StdTestEpRet |            11.3 |
# |      MaxTestEpRet |            -178 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |     AverageQ1Vals |           -50.4 |
# |         StdQ1Vals |            3.87 |
# |         MaxQ1Vals |           -40.3 |
# |         MinQ1Vals |           -66.9 |
# |     AverageQ2Vals |           -50.4 |
# |         StdQ2Vals |            3.87 |
# |         MaxQ2Vals |           -40.4 |
# |         MinQ2Vals |           -66.5 |
# |            LossPi |              50 |
# |             LossQ |           0.176 |
# |              Time |             553 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -190 |
# |          StdEpRet |              20 |
# |          MaxEpRet |            -147 |
# |          MinEpRet |            -215 |
# |  AverageTestEpRet |            -200 |
# |      StdTestEpRet |            8.57 |
# |      MaxTestEpRet |            -187 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -51.5 |
# |         StdQ1Vals |            3.94 |
# |         MaxQ1Vals |           -41.1 |
# |         MinQ1Vals |           -68.2 |
# |     AverageQ2Vals |           -51.5 |
# |         StdQ2Vals |            3.94 |
# |         MaxQ2Vals |             -41 |
# |         MinQ2Vals |           -68.1 |
# |            LossPi |            51.1 |
# |             LossQ |           0.184 |
# |              Time |             567 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            17.4 |
# |          MaxEpRet |            -150 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -192 |
# |      StdTestEpRet |            26.2 |
# |      MaxTestEpRet |            -123 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |     AverageQ1Vals |           -52.5 |
# |         StdQ1Vals |               4 |
# |         MaxQ1Vals |           -41.6 |
# |         MinQ1Vals |           -69.7 |
# |     AverageQ2Vals |           -52.5 |
# |         StdQ2Vals |               4 |
# |         MaxQ2Vals |           -41.6 |
# |         MinQ2Vals |           -69.6 |
# |            LossPi |            52.1 |
# |             LossQ |           0.189 |
# |              Time |             582 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -189 |
# |          StdEpRet |            22.5 |
# |          MaxEpRet |            -139 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -190 |
# |      StdTestEpRet |            23.3 |
# |      MaxTestEpRet |            -138 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |     AverageQ1Vals |           -53.5 |
# |         StdQ1Vals |            4.05 |
# |         MaxQ1Vals |           -42.5 |
# |         MinQ1Vals |           -70.9 |
# |     AverageQ2Vals |           -53.5 |
# |         StdQ2Vals |            4.06 |
# |         MaxQ2Vals |           -42.5 |
# |         MinQ2Vals |           -70.7 |
# |            LossPi |            53.1 |
# |             LossQ |           0.194 |
# |              Time |             597 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -197 |
# |          StdEpRet |            12.2 |
# |          MaxEpRet |            -175 |
# |          MinEpRet |            -211 |
# |  AverageTestEpRet |            -194 |
# |      StdTestEpRet |            22.8 |
# |      MaxTestEpRet |            -134 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |     AverageQ1Vals |           -54.5 |
# |         StdQ1Vals |            4.11 |
# |         MaxQ1Vals |           -43.3 |
# |         MinQ1Vals |           -71.4 |
# |     AverageQ2Vals |           -54.5 |
# |         StdQ2Vals |            4.11 |
# |         MaxQ2Vals |           -43.1 |
# |         MinQ2Vals |           -71.9 |
# |            LossPi |            54.1 |
# |             LossQ |           0.199 |
# |              Time |             611 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -193 |
# |          StdEpRet |            17.2 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -188 |
# |      StdTestEpRet |            14.5 |
# |      MaxTestEpRet |            -156 |
# |      MinTestEpRet |            -211 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |     AverageQ1Vals |           -55.4 |
# |         StdQ1Vals |             4.2 |
# |         MaxQ1Vals |           -43.7 |
# |         MinQ1Vals |             -73 |
# |     AverageQ2Vals |           -55.4 |
# |         StdQ2Vals |             4.2 |
# |         MaxQ2Vals |           -43.5 |
# |         MinQ2Vals |           -73.2 |
# |            LossPi |              55 |
# |             LossQ |           0.203 |
# |              Time |             626 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -189 |
# |          StdEpRet |            16.6 |
# |          MaxEpRet |            -165 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -194 |
# |      StdTestEpRet |            17.8 |
# |      MaxTestEpRet |            -151 |
# |      MinTestEpRet |            -215 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |     AverageQ1Vals |           -56.4 |
# |         StdQ1Vals |            4.26 |
# |         MaxQ1Vals |           -44.4 |
# |         MinQ1Vals |           -74.3 |
# |     AverageQ2Vals |           -56.4 |
# |         StdQ2Vals |            4.26 |
# |         MaxQ2Vals |           -44.4 |
# |         MinQ2Vals |           -74.2 |
# |            LossPi |              56 |
# |             LossQ |           0.209 |
# |              Time |             641 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -193 |
# |          StdEpRet |              14 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -186 |
# |      StdTestEpRet |            15.4 |
# |      MaxTestEpRet |            -149 |
# |      MinTestEpRet |            -210 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |     AverageQ1Vals |           -57.3 |
# |         StdQ1Vals |            4.33 |
# |         MaxQ1Vals |           -45.1 |
# |         MinQ1Vals |           -75.2 |
# |     AverageQ2Vals |           -57.3 |
# |         StdQ2Vals |            4.33 |
# |         MaxQ2Vals |           -45.1 |
# |         MinQ2Vals |           -75.8 |
# |            LossPi |              57 |
# |             LossQ |           0.214 |
# |              Time |             656 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -190 |
# |          StdEpRet |              13 |
# ...
# ---------------------------------------
# |             Epoch |             785 |
# |      AverageEpRet |            -127 |
# |          StdEpRet |            23.2 |
# |          MaxEpRet |           -89.1 |
# |          MinEpRet |            -171 |
# |  AverageTestEpRet |           -98.4 |
# |      StdTestEpRet |            42.9 |
# |      MaxTestEpRet |           -59.5 |
# |      MinTestEpRet |            -197 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -94.6 |
# |         StdQ1Vals |              16 |
# |         MaxQ1Vals |           -65.7 |
# |         MinQ1Vals |            -180 |
# |     AverageQ2Vals |           -94.6 |
# |         StdQ2Vals |              16 |
# |         MaxQ2Vals |           -65.7 |
# |         MinQ2Vals |            -182 |
# |            LossPi |            94.4 |
# |             LossQ |           0.817 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             786 |
# |      AverageEpRet |            -105 |
# |          StdEpRet |            14.7 |
# |          MaxEpRet |           -73.9 |
# |          MinEpRet |            -134 |
# |  AverageTestEpRet |            -107 |
# |      StdTestEpRet |            22.1 |
# |      MaxTestEpRet |           -77.4 |
# |      MinTestEpRet |            -155 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -94.5 |
# |         StdQ1Vals |              16 |
# |         MaxQ1Vals |           -65.7 |
# |         MinQ1Vals |            -181 |
# |     AverageQ2Vals |           -94.5 |
# |         StdQ2Vals |              16 |
# |         MaxQ2Vals |           -65.6 |
# |         MinQ2Vals |            -184 |
# |            LossPi |            94.2 |
# |             LossQ |           0.776 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             787 |
# |      AverageEpRet |            -115 |
# |          StdEpRet |            25.7 |
# |          MaxEpRet |           -76.2 |
# |          MinEpRet |            -174 |
# |  AverageTestEpRet |           -94.1 |
# |      StdTestEpRet |            28.5 |
# |      MaxTestEpRet |           -52.2 |
# |      MinTestEpRet |            -143 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -94.4 |
# |         StdQ1Vals |              16 |
# |         MaxQ1Vals |           -65.4 |
# |         MinQ1Vals |            -184 |
# |     AverageQ2Vals |           -94.4 |
# |         StdQ2Vals |              16 |
# |         MaxQ2Vals |           -65.6 |
# |         MinQ2Vals |            -182 |
# |            LossPi |            94.1 |
# |             LossQ |            0.81 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             788 |
# |      AverageEpRet |            -110 |
# |          StdEpRet |            28.4 |
# |          MaxEpRet |           -73.4 |
# |          MinEpRet |            -185 |
# |  AverageTestEpRet |            -116 |
# |      StdTestEpRet |            41.2 |
# |      MaxTestEpRet |           -65.1 |
# |      MinTestEpRet |            -207 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -94.3 |
# |         StdQ1Vals |              16 |
# |         MaxQ1Vals |           -65.6 |
# |         MinQ1Vals |            -187 |
# |     AverageQ2Vals |           -94.3 |
# |         StdQ2Vals |              16 |
# |         MaxQ2Vals |           -65.6 |
# |         MinQ2Vals |            -187 |
# |            LossPi |            94.1 |
# |             LossQ |           0.792 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             789 |
# |      AverageEpRet |            -117 |
# |          StdEpRet |              25 |
# |          MaxEpRet |           -69.7 |
# |          MinEpRet |            -159 |
# |  AverageTestEpRet |            -110 |
# |      StdTestEpRet |            19.7 |
# |      MaxTestEpRet |           -83.3 |
# |      MinTestEpRet |            -146 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -94.3 |
# |         StdQ1Vals |              16 |
# |         MaxQ1Vals |           -65.3 |
# |         MinQ1Vals |            -183 |
# |     AverageQ2Vals |           -94.3 |
# |         StdQ2Vals |              16 |
# |         MaxQ2Vals |           -65.5 |
# |         MinQ2Vals |            -184 |
# |            LossPi |            94.1 |
# |             LossQ |           0.795 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             790 |
# |      AverageEpRet |            -123 |
# |          StdEpRet |            25.4 |
# |          MaxEpRet |           -81.4 |
# |          MinEpRet |            -173 |
# |  AverageTestEpRet |           -96.2 |
# |      StdTestEpRet |            27.9 |
# |      MaxTestEpRet |           -47.9 |
# |      MinTestEpRet |            -152 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -94.2 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.7 |
# |         MinQ1Vals |            -179 |
# |     AverageQ2Vals |           -94.2 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.6 |
# |         MinQ2Vals |            -181 |
# |            LossPi |              94 |
# |             LossQ |           0.803 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             791 |
# |      AverageEpRet |            -119 |
# |          StdEpRet |            31.6 |
# |          MaxEpRet |           -77.8 |
# |          MinEpRet |            -178 |
# |  AverageTestEpRet |            -121 |
# |      StdTestEpRet |            31.4 |
# |      MaxTestEpRet |           -65.7 |
# |      MinTestEpRet |            -170 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -94.2 |
# |         StdQ1Vals |              16 |
# |         MaxQ1Vals |           -65.7 |
# |         MinQ1Vals |            -179 |
# |     AverageQ2Vals |           -94.2 |
# |         StdQ2Vals |              16 |
# |         MaxQ2Vals |           -65.5 |
# |         MinQ2Vals |            -180 |
# |            LossPi |            93.9 |
# |             LossQ |           0.809 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             792 |
# |      AverageEpRet |            -121 |
# |          StdEpRet |            29.3 |
# |          MaxEpRet |             -85 |
# |          MinEpRet |            -191 |
# |  AverageTestEpRet |            -124 |
# |      StdTestEpRet |            37.1 |
# |      MaxTestEpRet |           -64.6 |
# |      MinTestEpRet |            -181 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -94.1 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.4 |
# |         MinQ1Vals |            -184 |
# |     AverageQ2Vals |           -94.1 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.3 |
# |         MinQ2Vals |            -183 |
# |            LossPi |            93.9 |
# |             LossQ |           0.805 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             793 |
# |      AverageEpRet |            -117 |
# |          StdEpRet |            26.8 |
# |          MaxEpRet |           -73.2 |
# |          MinEpRet |            -160 |
# |  AverageTestEpRet |            -105 |
# |      StdTestEpRet |            27.1 |
# |      MaxTestEpRet |           -71.7 |
# |      MinTestEpRet |            -165 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |             -94 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.4 |
# |         MinQ1Vals |            -182 |
# |     AverageQ2Vals |             -94 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.5 |
# |         MinQ2Vals |            -183 |
# |            LossPi |            93.8 |
# |             LossQ |           0.805 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             794 |
# |      AverageEpRet |            -131 |
# |          StdEpRet |            33.1 |
# |          MaxEpRet |           -89.1 |
# |          MinEpRet |            -187 |
# |  AverageTestEpRet |            -111 |
# |      StdTestEpRet |            31.4 |
# |      MaxTestEpRet |           -68.4 |
# |      MinTestEpRet |            -161 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |             -94 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.2 |
# |         MinQ1Vals |            -186 |
# |     AverageQ2Vals |             -94 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.3 |
# |         MinQ2Vals |            -185 |
# |            LossPi |            93.8 |
# |             LossQ |           0.809 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             795 |
# |      AverageEpRet |            -120 |
# |          StdEpRet |            23.8 |
# |          MaxEpRet |           -79.2 |
# |          MinEpRet |            -180 |
# |  AverageTestEpRet |            -102 |
# |      StdTestEpRet |            38.2 |
# |      MaxTestEpRet |           -55.7 |
# |      MinTestEpRet |            -188 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |             -94 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.4 |
# |         MinQ1Vals |            -182 |
# |     AverageQ2Vals |             -94 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.5 |
# |         MinQ2Vals |            -182 |
# |            LossPi |            93.7 |
# |             LossQ |           0.802 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             796 |
# |      AverageEpRet |            -131 |
# |          StdEpRet |              34 |
# |          MaxEpRet |           -63.2 |
# |          MinEpRet |            -188 |
# |  AverageTestEpRet |            -110 |
# |      StdTestEpRet |            26.6 |
# |      MaxTestEpRet |           -73.1 |
# |      MinTestEpRet |            -146 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |             -94 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.3 |
# |         MinQ1Vals |            -184 |
# |     AverageQ2Vals |             -94 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.4 |
# |         MinQ2Vals |            -183 |
# |            LossPi |            93.7 |
# |             LossQ |           0.797 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             797 |
# |      AverageEpRet |            -118 |
# |          StdEpRet |            21.3 |
# |          MaxEpRet |           -88.9 |
# |          MinEpRet |            -166 |
# |  AverageTestEpRet |            -134 |
# |      StdTestEpRet |            21.9 |
# |      MaxTestEpRet |            -101 |
# |      MinTestEpRet |            -184 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -93.9 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.3 |
# |         MinQ1Vals |            -186 |
# |     AverageQ2Vals |           -93.9 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.5 |
# |         MinQ2Vals |            -185 |
# |            LossPi |            93.7 |
# |             LossQ |           0.801 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             798 |
# |      AverageEpRet |            -122 |
# |          StdEpRet |            19.7 |
# |          MaxEpRet |           -80.7 |
# |          MinEpRet |            -146 |
# |  AverageTestEpRet |             -94 |
# |      StdTestEpRet |            18.7 |
# |      MaxTestEpRet |           -62.8 |
# |      MinTestEpRet |            -125 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -93.8 |
# |         StdQ1Vals |            15.8 |
# |         MaxQ1Vals |           -65.3 |
# |         MinQ1Vals |            -179 |
# |     AverageQ2Vals |           -93.8 |
# |         StdQ2Vals |            15.8 |
# |         MaxQ2Vals |           -65.2 |
# |         MinQ2Vals |            -182 |
# |            LossPi |            93.6 |
# |             LossQ |             0.8 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             799 |
# |      AverageEpRet |            -114 |
# |          StdEpRet |            25.6 |
# |          MaxEpRet |           -61.3 |
# |          MinEpRet |            -146 |
# |  AverageTestEpRet |            -115 |
# |      StdTestEpRet |            30.8 |
# |      MaxTestEpRet |           -64.6 |
# |      MinTestEpRet |            -190 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -93.9 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.4 |
# |         MinQ1Vals |            -185 |
# |     AverageQ2Vals |           -93.9 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.3 |
# |         MinQ2Vals |            -184 |
# |            LossPi |            93.7 |
# |             LossQ |           0.807 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             800 |
# |      AverageEpRet |            -119 |
# |          StdEpRet |            20.1 |
# |          MaxEpRet |             -73 |
# |          MinEpRet |            -148 |
# |  AverageTestEpRet |           -96.2 |
# |      StdTestEpRet |              25 |
# |      MaxTestEpRet |           -46.7 |
# |      MinTestEpRet |            -135 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -93.8 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.1 |
# |         MinQ1Vals |            -180 |
# |     AverageQ2Vals |           -93.8 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.3 |
# |         MinQ2Vals |            -182 |
# |            LossPi |            93.6 |
# |             LossQ |           0.802 |
# |              Time |         1.2e+04 |
# ---------------------------------------

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it2_hid_var0', exp_name='td3_n_it2_hid_var0')
seed_b = 10
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.985
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[700,200], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0015
qlr_b = 0.0015

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.04

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it2_hid_var1', exp_name='td3_n_it2_hid_var1')
seed_b = 10
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.985
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[300,70], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0015
qlr_b = 0.0015

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.04

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %% [markdown]
# #### Action noise

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it2_an_var0', exp_name='td3_n_it2_an_var0')
seed_b = 10
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.985
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[700], activation=torch.nn.ReLU)
actnoise_b = 0.05
pilr_b = 0.0015
qlr_b = 0.0015

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.04

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it2_an_var1', exp_name='td3_n_it2_an_var1')
seed_b = 10
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.985
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[700], activation=torch.nn.ReLU)
actnoise_b = 0.5
pilr_b = 0.0015
qlr_b = 0.0015

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.04

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it2_an_var2', exp_name='td3_n_it2_an_var2')
seed_b = 10
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.985
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[700], activation=torch.nn.ReLU)
actnoise_b = 0.9
pilr_b = 0.0015
qlr_b = 0.0015

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.04

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %% [markdown]
# ## New baseline

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it2_an_var1_extralay', exp_name='td3_n_it2_an_var1_extralay')
seed_b = 10
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.985
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[700,70], activation=torch.nn.ReLU)
actnoise_b = 0.5
pilr_b = 0.0015
qlr_b = 0.0015

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.04

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %% [markdown]
# ## Adding an extra layer to final

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it2_an_var1_extralay_extralay', exp_name='td3_n_it2_an_var1_extralay_extralay')
seed_b = 10
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.985
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[700,70,10], activation=torch.nn.ReLU)
actnoise_b = 0.5
pilr_b = 0.0015
qlr_b = 0.0015

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.04

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='quadratic_test', exp_name='quadratic test')
seed_b = 10
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.985
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[700,70,10], activation=torch.nn.ReLU)
actnoise_b = 0.5
pilr_b = 0.0015
qlr_b = 0.0015

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.04

# Env function
reward_args = {'qx1':9,'qx2':0.05,'qx3':9,'qx4':0.05,'pu1':0.1,'pu2':0.1}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Quadratic', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)
# Out:
# Logging data to quadratic_test/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             700,
#             70,
#             10
#         ]
#     },
#     "act_noise":	0.5,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	150,
#     "env_fn":	"functools.partial(<function env_fn at 0x7f7c860d3510>, env_name='gyroscopeenv-v0', reward_type='Quadratic', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1}, ep_len=110)",
#     "epochs":	800,
#     "exp_name":	"quadratic test",
#     "gamma":	0.985,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7f7c555141d0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"quadratic test",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"quadratic_test",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='quadratic_test/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"quadratic test",
#         "output_dir":	"quadratic_test"
#     },
#     "max_ep_len":	110,
#     "noise_clip":	0.04,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0015,
#     "policy_delay":	2,
#     "polyak":	0.999,
#     "q_lr":	0.0015,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	10,
#     "start_steps":	20000,
#     "steps_per_epoch":	1650,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 56802, 	 q1: 58191, 	 q2: 58191
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |       -7.01e+03 |
# |          StdEpRet |        2.19e+03 |
# |          MaxEpRet |       -3.46e+03 |
# |          MinEpRet |        -1.1e+04 |
# |  AverageTestEpRet |       -6.32e+03 |
# |      StdTestEpRet |        1.35e+03 |
# |      MaxTestEpRet |       -4.11e+03 |
# |      MinTestEpRet |        -8.8e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |     AverageQ1Vals |             -62 |
# |         StdQ1Vals |            28.1 |
# |         MaxQ1Vals |         -0.0692 |
# |         MinQ1Vals |            -157 |
# |     AverageQ2Vals |           -61.5 |
# |         StdQ2Vals |            27.9 |
# |         MaxQ2Vals |           -0.26 |
# |         MinQ2Vals |            -156 |
# |            LossPi |            58.6 |
# |             LossQ |        2.32e+03 |
# |              Time |            10.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |        -6.7e+03 |
# |          StdEpRet |        1.78e+03 |
# |          MaxEpRet |       -3.69e+03 |
# |          MinEpRet |       -9.55e+03 |
# |  AverageTestEpRet |       -6.37e+03 |
# |      StdTestEpRet |        1.96e+03 |
# |      MaxTestEpRet |       -4.02e+03 |
# |      MinTestEpRet |       -9.74e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |     AverageQ1Vals |           -78.8 |
# |         StdQ1Vals |            40.2 |
# |         MaxQ1Vals |          -0.399 |
# |         MinQ1Vals |            -231 |
# |     AverageQ2Vals |           -78.8 |
# |         StdQ2Vals |            39.5 |
# |         MaxQ2Vals |           -1.46 |
# |         MinQ2Vals |            -231 |
# |            LossPi |            74.1 |
# |             LossQ |             317 |
# |              Time |              30 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |       -6.54e+03 |
# |          StdEpRet |        2.19e+03 |
# |          MaxEpRet |       -2.84e+03 |
# |          MinEpRet |       -1.12e+04 |
# |  AverageTestEpRet |        -5.1e+03 |
# |      StdTestEpRet |        2.06e+03 |
# |      MaxTestEpRet |            -140 |
# |      MinTestEpRet |       -7.93e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |     AverageQ1Vals |            -109 |
# |         StdQ1Vals |            56.9 |
# |         MaxQ1Vals |           -6.96 |
# |         MinQ1Vals |            -320 |
# |     AverageQ2Vals |            -109 |
# |         StdQ2Vals |            56.9 |
# |         MaxQ2Vals |            -3.4 |
# |         MinQ2Vals |            -318 |
# |            LossPi |             102 |
# |             LossQ |              73 |
# |              Time |            50.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |        -7.3e+03 |
# |          StdEpRet |         2.3e+03 |
# |          MaxEpRet |       -4.42e+03 |
# |          MinEpRet |       -1.38e+04 |
# |  AverageTestEpRet |       -4.95e+03 |
# |      StdTestEpRet |         1.8e+03 |
# |      MaxTestEpRet |       -1.45e+03 |
# |      MinTestEpRet |       -7.73e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |     AverageQ1Vals |            -148 |
# |         StdQ1Vals |            77.1 |
# |         MaxQ1Vals |            -8.1 |
# |         MinQ1Vals |            -429 |
# |     AverageQ2Vals |            -148 |
# |         StdQ2Vals |            77.1 |
# |         MaxQ2Vals |            -6.3 |
# |         MinQ2Vals |            -425 |
# |            LossPi |             137 |
# |             LossQ |            86.5 |
# |              Time |              70 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |       -7.91e+03 |
# |          StdEpRet |        2.31e+03 |
# |          MaxEpRet |       -5.03e+03 |
# |          MinEpRet |       -1.41e+04 |
# |  AverageTestEpRet |       -4.07e+03 |
# |      StdTestEpRet |        3.41e+03 |
# |      MaxTestEpRet |       -1.14e+03 |
# |      MinTestEpRet |       -1.12e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |     AverageQ1Vals |            -187 |
# |         StdQ1Vals |            98.1 |
# |         MaxQ1Vals |            -7.6 |
# |         MinQ1Vals |            -560 |
# |     AverageQ2Vals |            -187 |
# |         StdQ2Vals |            98.1 |
# |         MaxQ2Vals |           -7.23 |
# |         MinQ2Vals |            -545 |
# |            LossPi |             172 |
# |             LossQ |             161 |
# |              Time |              93 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |       -7.12e+03 |
# |          StdEpRet |        2.18e+03 |
# |          MaxEpRet |       -3.31e+03 |
# |          MinEpRet |       -9.95e+03 |
# |  AverageTestEpRet |       -2.12e+03 |
# |      StdTestEpRet |        1.34e+03 |
# |      MaxTestEpRet |            -300 |
# |      MinTestEpRet |       -5.37e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |     AverageQ1Vals |            -224 |
# |         StdQ1Vals |             118 |
# |         MaxQ1Vals |           -7.99 |
# |         MinQ1Vals |            -664 |
# |     AverageQ2Vals |            -224 |
# |         StdQ2Vals |             118 |
# |         MaxQ2Vals |           -11.3 |
# |         MinQ2Vals |            -660 |
# |            LossPi |             203 |
# |             LossQ |             266 |
# |              Time |             114 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |       -7.52e+03 |
# |          StdEpRet |        2.21e+03 |
# |          MaxEpRet |       -4.35e+03 |
# |          MinEpRet |       -1.15e+04 |
# |  AverageTestEpRet |       -1.27e+03 |
# |      StdTestEpRet |        1.24e+03 |
# |      MaxTestEpRet |            -291 |
# |      MinTestEpRet |       -4.08e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |     AverageQ1Vals |            -254 |
# |         StdQ1Vals |             136 |
# |         MaxQ1Vals |            -8.2 |
# |         MinQ1Vals |            -763 |
# |     AverageQ2Vals |            -255 |
# |         StdQ2Vals |             136 |
# |         MaxQ2Vals |           -8.17 |
# |         MinQ2Vals |            -761 |
# |            LossPi |             228 |
# |             LossQ |             406 |
# |              Time |             133 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |       -6.16e+03 |
# |          StdEpRet |        1.57e+03 |
# |          MaxEpRet |       -3.99e+03 |
# |          MinEpRet |       -9.77e+03 |
# |  AverageTestEpRet |       -1.46e+03 |
# |      StdTestEpRet |             942 |
# |      MaxTestEpRet |            -266 |
# |      MinTestEpRet |       -3.58e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |     AverageQ1Vals |            -283 |
# |         StdQ1Vals |             152 |
# |         MaxQ1Vals |           -6.23 |
# |         MinQ1Vals |            -831 |
# |     AverageQ2Vals |            -283 |
# |         StdQ2Vals |             152 |
# |         MaxQ2Vals |           -8.39 |
# |         MinQ2Vals |            -829 |
# |            LossPi |             251 |
# |             LossQ |             623 |
# |              Time |             154 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |       -6.27e+03 |
# |          StdEpRet |        1.83e+03 |
# |          MaxEpRet |       -3.84e+03 |
# |          MinEpRet |       -9.09e+03 |
# |  AverageTestEpRet |       -1.49e+03 |
# |      StdTestEpRet |             560 |
# |      MaxTestEpRet |            -646 |
# |      MinTestEpRet |        -2.3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |     AverageQ1Vals |            -304 |
# |         StdQ1Vals |             166 |
# |         MaxQ1Vals |            3.04 |
# |         MinQ1Vals |            -910 |
# |     AverageQ2Vals |            -304 |
# |         StdQ2Vals |             167 |
# |         MaxQ2Vals |           -6.52 |
# |         MinQ2Vals |            -907 |
# |            LossPi |             267 |
# |             LossQ |             849 |
# |              Time |             178 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |       -5.81e+03 |
# |          StdEpRet |        1.63e+03 |
# |          MaxEpRet |       -3.23e+03 |
# |          MinEpRet |       -8.77e+03 |
# |  AverageTestEpRet |            -699 |
# |      StdTestEpRet |             388 |
# |      MaxTestEpRet |            -255 |
# |      MinTestEpRet |       -1.34e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |            -324 |
# |         StdQ1Vals |             179 |
# |         MaxQ1Vals |            3.62 |
# |         MinQ1Vals |            -962 |
# |     AverageQ2Vals |            -324 |
# |         StdQ2Vals |             179 |
# |         MaxQ2Vals |           -5.11 |
# |         MinQ2Vals |          -1e+03 |
# |            LossPi |             284 |
# |             LossQ |        1.08e+03 |
# |              Time |             202 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |       -6.33e+03 |
# |          StdEpRet |        2.31e+03 |
# |          MaxEpRet |       -2.16e+03 |
# |          MinEpRet |       -1.05e+04 |
# |  AverageTestEpRet |       -1.03e+03 |
# |      StdTestEpRet |             505 |
# |      MaxTestEpRet |            -336 |
# |      MinTestEpRet |       -1.89e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |     AverageQ1Vals |            -342 |
# |         StdQ1Vals |             191 |
# |         MaxQ1Vals |            5.77 |
# |         MinQ1Vals |       -1.03e+03 |
# |     AverageQ2Vals |            -342 |
# |         StdQ2Vals |             191 |
# |         MaxQ2Vals |           -3.29 |
# |         MinQ2Vals |       -1.06e+03 |
# |            LossPi |             300 |
# |             LossQ |         1.3e+03 |
# |              Time |             221 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |       -7.14e+03 |
# |          StdEpRet |        2.39e+03 |
# |          MaxEpRet |       -4.17e+03 |
# |          MinEpRet |       -1.32e+04 |
# |  AverageTestEpRet |       -1.19e+03 |
# |      StdTestEpRet |        1.34e+03 |
# |      MaxTestEpRet |            -305 |
# |      MinTestEpRet |       -5.09e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |     AverageQ1Vals |            -359 |
# |         StdQ1Vals |             201 |
# |         MaxQ1Vals |            3.68 |
# |         MinQ1Vals |       -1.09e+03 |
# |     AverageQ2Vals |            -359 |
# |         StdQ2Vals |             201 |
# |         MaxQ2Vals |           -4.22 |
# |         MinQ2Vals |       -1.12e+03 |
# |            LossPi |             315 |
# |             LossQ |        1.53e+03 |
# |              Time |             241 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |       -1.86e+03 |
# |          StdEpRet |         1.8e+03 |
# |          MaxEpRet |            -659 |
# |          MinEpRet |       -7.44e+03 |
# |  AverageTestEpRet |            -965 |
# |      StdTestEpRet |             642 |
# |      MaxTestEpRet |            -341 |
# |      MinTestEpRet |       -2.42e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |     AverageQ1Vals |            -368 |
# |         StdQ1Vals |             212 |
# |         MaxQ1Vals |            5.03 |
# |         MinQ1Vals |       -1.18e+03 |
# |     AverageQ2Vals |            -368 |
# |         StdQ2Vals |             212 |
# |         MaxQ2Vals |           -2.94 |
# |         MinQ2Vals |       -1.19e+03 |
# |            LossPi |             323 |
# |             LossQ |        1.68e+03 |
# |              Time |             260 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |       -1.35e+03 |
# |          StdEpRet |        1.05e+03 |
# |          MaxEpRet |            -387 |
# |          MinEpRet |       -3.94e+03 |
# |  AverageTestEpRet |       -1.04e+03 |
# |      StdTestEpRet |        1.06e+03 |
# |      MaxTestEpRet |            -145 |
# |      MinTestEpRet |       -4.09e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |     AverageQ1Vals |            -364 |
# |         StdQ1Vals |             226 |
# |         MaxQ1Vals |               6 |
# |         MinQ1Vals |       -1.21e+03 |
# |     AverageQ2Vals |            -364 |
# |         StdQ2Vals |             226 |
# |         MaxQ2Vals |           -2.49 |
# |         MinQ2Vals |       -1.25e+03 |
# |            LossPi |             322 |
# |             LossQ |        1.72e+03 |
# |              Time |             282 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |       -1.15e+03 |
# |          StdEpRet |             818 |
# |          MaxEpRet |            -227 |
# |          MinEpRet |       -2.87e+03 |
# |  AverageTestEpRet |            -561 |
# |      StdTestEpRet |             239 |
# |      MaxTestEpRet |            -242 |
# |      MinTestEpRet |       -1.16e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |     AverageQ1Vals |            -360 |
# |         StdQ1Vals |             239 |
# |         MaxQ1Vals |            1.48 |
# |         MinQ1Vals |       -1.29e+03 |
# |     AverageQ2Vals |            -360 |
# |         StdQ2Vals |             239 |
# |         MaxQ2Vals |           -6.14 |
# |         MinQ2Vals |       -1.32e+03 |
# |            LossPi |             317 |
# |             LossQ |        1.76e+03 |
# |              Time |             303 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |       -1.18e+03 |
# |          StdEpRet |             896 |
# |          MaxEpRet |            -237 |
# |          MinEpRet |       -4.02e+03 |
# |  AverageTestEpRet |       -1.01e+03 |
# |      StdTestEpRet |             563 |
# |      MaxTestEpRet |            -231 |
# |      MinTestEpRet |       -2.26e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |     AverageQ1Vals |            -357 |
# |         StdQ1Vals |             249 |
# |         MaxQ1Vals |            6.56 |
# |         MinQ1Vals |       -1.31e+03 |
# |     AverageQ2Vals |            -356 |
# |         StdQ2Vals |             249 |
# |         MaxQ2Vals |           -8.59 |
# |         MinQ2Vals |       -1.35e+03 |
# |            LossPi |             316 |
# |             LossQ |        1.83e+03 |
# |              Time |             324 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |        -1.2e+03 |
# |          StdEpRet |             795 |
# |          MaxEpRet |            -185 |
# |          MinEpRet |       -2.57e+03 |
# |  AverageTestEpRet |            -860 |
# |      StdTestEpRet |             248 |
# |      MaxTestEpRet |            -481 |
# |      MinTestEpRet |       -1.22e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |            -352 |
# |         StdQ1Vals |             257 |
# |         MaxQ1Vals |            7.57 |
# |         MinQ1Vals |       -1.33e+03 |
# |     AverageQ2Vals |            -352 |
# |         StdQ2Vals |             257 |
# |         MaxQ2Vals |           -10.3 |
# |         MinQ2Vals |        -1.4e+03 |
# |            LossPi |             312 |
# |             LossQ |        1.83e+03 |
# |              Time |             342 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -762 |
# |          StdEpRet |             425 |
# |          MaxEpRet |            -259 |
# |          MinEpRet |       -1.67e+03 |
# |  AverageTestEpRet |            -742 |
# |      StdTestEpRet |             370 |
# |      MaxTestEpRet |            -243 |
# |      MinTestEpRet |       -1.62e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |     AverageQ1Vals |            -347 |
# |         StdQ1Vals |             265 |
# |         MaxQ1Vals |            5.05 |
# |         MinQ1Vals |       -1.39e+03 |
# |     AverageQ2Vals |            -347 |
# |         StdQ2Vals |             265 |
# |         MaxQ2Vals |             -12 |
# |         MinQ2Vals |       -1.45e+03 |
# |            LossPi |             307 |
# |             LossQ |        1.85e+03 |
# |              Time |             361 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -706 |
# |          StdEpRet |             367 |
# |          MaxEpRet |            -164 |
# |          MinEpRet |       -1.51e+03 |
# |  AverageTestEpRet |            -603 |
# |      StdTestEpRet |             350 |
# |      MaxTestEpRet |            -207 |
# |      MinTestEpRet |       -1.28e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |     AverageQ1Vals |            -343 |
# |         StdQ1Vals |             273 |
# |         MaxQ1Vals |            4.53 |
# |         MinQ1Vals |       -1.44e+03 |
# |     AverageQ2Vals |            -343 |
# |         StdQ2Vals |             273 |
# |         MaxQ2Vals |           -14.4 |
# |         MinQ2Vals |       -1.42e+03 |
# |            LossPi |             305 |
# |             LossQ |        1.82e+03 |
# |              Time |             381 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -912 |
# |          StdEpRet |             573 |
# |          MaxEpRet |            -196 |
# |          MinEpRet |          -2e+03 |
# |  AverageTestEpRet |            -687 |
# |      StdTestEpRet |             327 |
# |      MaxTestEpRet |            -128 |
# |      MinTestEpRet |       -1.19e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |            -338 |
# |         StdQ1Vals |             279 |
# |         MaxQ1Vals |            8.57 |
# |         MinQ1Vals |       -1.48e+03 |
# |     AverageQ2Vals |            -339 |
# |         StdQ2Vals |             279 |
# |         MaxQ2Vals |           -15.1 |
# |         MinQ2Vals |       -1.46e+03 |
# |            LossPi |             301 |
# |             LossQ |        1.81e+03 |
# |              Time |             401 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -852 |
# |          StdEpRet |             814 |
# |          MaxEpRet |            -298 |
# |          MinEpRet |       -3.79e+03 |
# |  AverageTestEpRet |            -520 |
# |      StdTestEpRet |             149 |
# |      MaxTestEpRet |            -280 |
# |      MinTestEpRet |            -786 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |     AverageQ1Vals |            -335 |
# |         StdQ1Vals |             283 |
# |         MaxQ1Vals |            6.08 |
# |         MinQ1Vals |       -1.52e+03 |
# |     AverageQ2Vals |            -335 |
# |         StdQ2Vals |             283 |
# |         MaxQ2Vals |           -17.1 |
# |         MinQ2Vals |        -1.5e+03 |
# |            LossPi |             298 |
# |             LossQ |        1.83e+03 |
# |              Time |             423 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |       -1.04e+03 |
# |          StdEpRet |             627 |
# |          MaxEpRet |            -329 |
# |          MinEpRet |       -2.73e+03 |
# |  AverageTestEpRet |            -997 |
# |      StdTestEpRet |             821 |
# |      MaxTestEpRet |            -173 |
# |      MinTestEpRet |       -2.82e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |     AverageQ1Vals |            -329 |
# |         StdQ1Vals |             287 |
# |         MaxQ1Vals |            2.83 |
# |         MinQ1Vals |       -1.61e+03 |
# |     AverageQ2Vals |            -329 |
# |         StdQ2Vals |             287 |
# |         MaxQ2Vals |           -19.1 |
# |         MinQ2Vals |       -1.58e+03 |
# |            LossPi |             293 |
# |             LossQ |         1.8e+03 |
# |              Time |             444 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -763 |
# |          StdEpRet |             444 |
# |          MaxEpRet |            -283 |
# |          MinEpRet |       -1.86e+03 |
# |  AverageTestEpRet |            -852 |
# |      StdTestEpRet |             322 |
# |      MaxTestEpRet |            -279 |
# |      MinTestEpRet |       -1.27e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |     AverageQ1Vals |            -324 |
# |         StdQ1Vals |             290 |
# |         MaxQ1Vals |           0.864 |
# |         MinQ1Vals |       -1.59e+03 |
# |     AverageQ2Vals |            -324 |
# |         StdQ2Vals |             290 |
# |         MaxQ2Vals |             -22 |
# |         MinQ2Vals |        -1.6e+03 |
# |            LossPi |             289 |
# |             LossQ |        1.81e+03 |
# |              Time |             462 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -964 |
# |          StdEpRet |             439 |
# |          MaxEpRet |            -393 |
# |          MinEpRet |       -1.74e+03 |
# |  AverageTestEpRet |            -861 |
# |      StdTestEpRet |             393 |
# |      MaxTestEpRet |            -103 |
# |      MinTestEpRet |       -1.45e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |     AverageQ1Vals |            -320 |
# |         StdQ1Vals |             293 |
# |         MaxQ1Vals |            1.21 |
# |         MinQ1Vals |       -1.62e+03 |
# |     AverageQ2Vals |            -320 |
# |         StdQ2Vals |             293 |
# |         MaxQ2Vals |             -22 |
# |         MinQ2Vals |       -1.61e+03 |
# |            LossPi |             285 |
# |             LossQ |        1.84e+03 |
# |              Time |             486 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -828 |
# |          StdEpRet |             427 |
# |          MaxEpRet |            -129 |
# |          MinEpRet |       -1.49e+03 |
# |  AverageTestEpRet |            -792 |
# |      StdTestEpRet |             367 |
# |      MaxTestEpRet |            -183 |
# |      MinTestEpRet |       -1.32e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |     AverageQ1Vals |            -314 |
# |         StdQ1Vals |             295 |
# |         MaxQ1Vals |           -5.09 |
# |         MinQ1Vals |       -1.65e+03 |
# |     AverageQ2Vals |            -314 |
# |         StdQ2Vals |             295 |
# |         MaxQ2Vals |           -25.1 |
# |         MinQ2Vals |       -1.68e+03 |
# |            LossPi |             280 |
# |             LossQ |        1.77e+03 |
# |              Time |             505 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -757 |
# |          StdEpRet |             434 |
# |          MaxEpRet |            -184 |
# |          MinEpRet |       -1.61e+03 |
# |  AverageTestEpRet |            -463 |
# |      StdTestEpRet |             271 |
# |      MaxTestEpRet |            -155 |
# |      MinTestEpRet |            -954 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |     AverageQ1Vals |            -309 |
# |         StdQ1Vals |             296 |
# |         MaxQ1Vals |           -11.5 |
# |         MinQ1Vals |       -1.67e+03 |
# |     AverageQ2Vals |            -309 |
# |         StdQ2Vals |             296 |
# |         MaxQ2Vals |           -28.8 |
# |         MinQ2Vals |       -1.69e+03 |
# |            LossPi |             276 |
# |             LossQ |        1.79e+03 |
# |              Time |             524 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |          -1e+03 |
# |          StdEpRet |             497 |
# |          MaxEpRet |            -147 |
# |          MinEpRet |       -1.89e+03 |
# |  AverageTestEpRet |            -445 |
# |      StdTestEpRet |             210 |
# |      MaxTestEpRet |            -147 |
# |      MinTestEpRet |            -872 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |     AverageQ1Vals |            -305 |
# |         StdQ1Vals |             296 |
# |         MaxQ1Vals |           -14.9 |
# |         MinQ1Vals |       -1.71e+03 |
# |     AverageQ2Vals |            -305 |
# |         StdQ2Vals |             296 |
# |         MaxQ2Vals |           -28.8 |
# |         MinQ2Vals |       -1.73e+03 |
# |            LossPi |             272 |
# |             LossQ |        1.81e+03 |
# |              Time |             545 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -678 |
# |          StdEpRet |             428 |
# |          MaxEpRet |            -248 |
# |          MinEpRet |        -1.9e+03 |
# |  AverageTestEpRet |            -852 |
# |      StdTestEpRet |             525 |
# |      MaxTestEpRet |            -158 |
# |      MinTestEpRet |        -1.8e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |     AverageQ1Vals |            -299 |
# |         StdQ1Vals |             296 |
# |         MaxQ1Vals |           -15.2 |
# |         MinQ1Vals |       -1.68e+03 |
# |     AverageQ2Vals |            -299 |
# |         StdQ2Vals |             296 |
# |         MaxQ2Vals |           -31.8 |
# |         MinQ2Vals |       -1.71e+03 |
# |            LossPi |             268 |
# |             LossQ |        1.78e+03 |
# |              Time |             570 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -908 |
# |          StdEpRet |             389 |
# |          MaxEpRet |            -477 |
# |          MinEpRet |       -1.68e+03 |
# |  AverageTestEpRet |            -792 |
# |      StdTestEpRet |             676 |
# |      MaxTestEpRet |            -186 |
# |      MinTestEpRet |       -2.26e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |     AverageQ1Vals |            -295 |
# |         StdQ1Vals |             295 |
# |         MaxQ1Vals |           -16.6 |
# |         MinQ1Vals |       -1.75e+03 |
# |     AverageQ2Vals |            -295 |
# |         StdQ2Vals |             295 |
# |         MaxQ2Vals |           -29.8 |
# |         MinQ2Vals |       -1.76e+03 |
# |            LossPi |             264 |
# |             LossQ |        1.77e+03 |
# |              Time |             593 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |        -1.1e+03 |
# |          StdEpRet |             631 |
# |          MaxEpRet |            -483 |
# |          MinEpRet |       -2.91e+03 |
# |  AverageTestEpRet |            -727 |
# |      StdTestEpRet |             483 |
# |      MaxTestEpRet |            -149 |
# |      MinTestEpRet |       -1.72e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |            -292 |
# |         StdQ1Vals |             294 |
# |         MaxQ1Vals |           -18.1 |
# |         MinQ1Vals |       -1.74e+03 |
# |     AverageQ2Vals |            -292 |
# |         StdQ2Vals |             294 |
# |         MaxQ2Vals |           -30.2 |
# |         MinQ2Vals |       -1.85e+03 |
# |            LossPi |             262 |
# |             LossQ |        1.77e+03 |
# |              Time |             612 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -672 |
# |          StdEpRet |             369 |
# |          MaxEpRet |            -193 |
# |          MinEpRet |       -1.67e+03 |
# |  AverageTestEpRet |            -694 |
# |      StdTestEpRet |             480 |
# |      MaxTestEpRet |            -109 |
# |      MinTestEpRet |       -1.72e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |     AverageQ1Vals |            -288 |
# |         StdQ1Vals |             292 |
# |         MaxQ1Vals |           -13.9 |
# |         MinQ1Vals |       -1.78e+03 |
# |     AverageQ2Vals |            -288 |
# |         StdQ2Vals |             292 |
# |         MaxQ2Vals |           -31.8 |
# |         MinQ2Vals |       -1.77e+03 |
# |            LossPi |             259 |
# |             LossQ |        1.73e+03 |
# |              Time |             634 |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d4a9d147756c> in <module>
#      27 # Baseline 0 training
#      28 spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
# ---> 29 polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)
#
# ~/Documents/MA2/DRLGyro/resources/spinningup/spinup/algos/pytorch/td3/td3.py in td3(env_fn, actor_critic, ac_kwargs, seed, steps_per_epoch, epochs, replay_size, gamma, polyak, pi_lr, q_lr, batch_size, start_steps, update_after, update_every, act_noise, target_noise, noise_clip, policy_delay, num_test_episodes, max_ep_len, logger_kwargs, save_freq)
#     321             for j in range(update_every):
#     322                 batch = replay_buffer.sample_batch(batch_size)
# --> 323                 update(data=batch, timer=j)
#     324
#     325         # End of epoch handling
#
# ~/Documents/MA2/DRLGyro/resources/spinningup/spinup/algos/pytorch/td3/td3.py in update(data, timer)
#     247             loss_pi = compute_loss_pi(data)
#     248             loss_pi.backward()
# --> 249             pi_optimizer.step()
#     250
#     251             # Unfreeze Q-networks so you can optimize it at next DDPG step.
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#      94                 # Decay the first and second moment running average coefficient
#      95                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
# ---> 96                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      97                 if amsgrad:
#      98                     # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test

# %%
# Test paramaters
env_name = 'gyroscopeenv-v0'
reward_type = 'Quadratic'
reward_args = {'qx1':1,'qx2':0,'qx3':1,'qx4':0,'pu1':0,'pu2':0}
seed = 2
agent_path = 'td3_n_it2_an_var1_extralay_extralay_s0/'
init_state = [70*np.pi/180,0,0,0,20*np.pi/180,0,20]
ep_len = 110
t_end = ep_len*0.05

# Perform testing
r,score,x1_eval,x2_eval,x3_eval,x4_eval,x1_ref_eval,x3_ref_eval,act = test_agent(env_name,reward_type,reward_args,seed,agent_path,init_state,t_end,ep_len)
# Out:
# Total cumulative reward: -3.129853253868411

# %% [markdown]
# ## Plot

# %%
plot_test(x1_eval,x2_eval,x3_eval,x4_eval,x1_ref_eval,x3_ref_eval,act,t_end)

# %% [markdown]
# ## Evaluate control performance

# %%
# Single evaluation
env_name = 'gyroscopeenv-v0'
agent_path = 'td3_n_it2_an_var1_extralay_extralay_s0/'
ss_bound = 0.05
metrics = evaluate_control(env_name,agent_path,ss_bound)
metrics
# Out:
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
#                                          $\theta$ MAE (rad)  $\phi$ MAE (rad)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/            0.159896          0.107655
#
#                                          $\theta$ MSSE (rad)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/             0.006076
#
#                                          $\phi$ MSSE (rad)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/           0.013367
#
#                                          $\theta$ in bounds (%)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/                   100.0
#
#                                          $\phi$ in bounds (%)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/                 100.0
#
#                                          $\theta$ unsteady (%)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/                    0.0
#
#                                          $\phi$ unsteady (%)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/                  0.0
#
#                                          $\theta$ rise time (s)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/                 0.37975
#
#                                          $\phi$ rise time (s)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/               0.32125
#
#                                          $\theta$ settling time (s)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/                    0.711312
#
#                                          $\phi$ settling time (s)    u1 (V)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/                  0.612062  0.863728
#
#                                            u2 (V)  u1 variation (V)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/  0.487802          0.076104
#
#                                          u2 variation (V)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/          0.073388
#
#                                          Convergence time (min)
# Config.
# td3_n_it2_an_var1_extralay_extralay_s0/              425.916687

# %%
# Single evaluation
env_name = 'gyroscopeenv-v0'
agent_path = 'td3_n_it2_an_var1_extralay_extralay'
ss_bound = 0.05
metrics = evaluate_control(env_name,agent_path,ss_bound)
metrics
# Out:
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
#                                      $\theta$ MAE (rad)  $\phi$ MAE (rad)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay            0.143801          0.099878
#
#                                      $\theta$ MSSE (rad)  $\phi$ MSSE (rad)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay             0.009421           0.014316
#
#                                      $\theta$ in bounds (%)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay                   100.0
#
#                                      $\phi$ in bounds (%)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay                 100.0
#
#                                      $\theta$ unsteady (%)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay                    0.0
#
#                                      $\phi$ unsteady (%)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay                  0.0
#
#                                      $\theta$ rise time (s)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay                0.433688
#
#                                      $\phi$ rise time (s)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay              0.305437
#
#                                      $\theta$ settling time (s)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay                    0.738562
#
#                                      $\phi$ settling time (s)    u1 (V)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay                  0.511688  0.759247
#
#                                       u2 (V)  u1 variation (V)  \
# Config.
# td3_n_it2_an_var1_extralay_extralay  0.46568           0.06742
#
#                                      u2 variation (V)  Convergence time (min)
# Config.
# td3_n_it2_an_var1_extralay_extralay          0.058414              370.311922

# %%
# Single evaluation
env_name = 'gyroscopeenv-v0'
agent_path = 'td3_n_it2_an_var1_extralay'
ss_bound = 0.05
metrics = evaluate_control(env_name,agent_path,ss_bound)
metrics
# Out:
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
#                             $\theta$ MAE (rad)  $\phi$ MAE (rad)  \
# Config.
# td3_n_it2_an_var1_extralay            0.153349          0.110079
#
#                             $\theta$ MSSE (rad)  $\phi$ MSSE (rad)  \
# Config.
# td3_n_it2_an_var1_extralay             0.009723           0.018245
#
#                             $\theta$ in bounds (%)  $\phi$ in bounds (%)  \
# Config.
# td3_n_it2_an_var1_extralay                   100.0                  95.5
#
#                             $\theta$ unsteady (%)  $\phi$ unsteady (%)  \
# Config.
# td3_n_it2_an_var1_extralay                    0.0                  0.0
#
#                             $\theta$ rise time (s)  $\phi$ rise time (s)  \
# Config.
# td3_n_it2_an_var1_extralay                  0.4665              0.314071
#
#                             $\theta$ settling time (s)  \
# Config.
# td3_n_it2_an_var1_extralay                     0.70825
#
#                             $\phi$ settling time (s)    u1 (V)    u2 (V)  \
# Config.
# td3_n_it2_an_var1_extralay                  0.571466  0.827964  0.517435
#
#                             u1 variation (V)  u2 variation (V)  \
# Config.
# td3_n_it2_an_var1_extralay          0.067812          0.058029
#
#                             Convergence time (min)
# Config.
# td3_n_it2_an_var1_extralay              340.726763

# %%
# Init dataframe
env_name = 'gyroscopeenv-v0'
agent_paths = ['td3_n_b_it1/','td3_n_it1_lr_var0/','td3_n_it1_lr_var1/','td3_n_it1_hid_var0/','td3_n_it1_hid_var1/','td3_n_it1_bs_var0/','td3_n_it1_bs_var1/','td3_n_it1_g_var0/','td3_n_it1_g_var1/','td3_n_it1_pol_var0/','td3_n_it1_pol_var1/','td3_n_it1_nc_var0/','td3_n_it1_nc_var1/','td3_n_b_it2/']
ss_bound = 0.05

# Loop dataframe
for idx, agent_path in zip(range(len(agent_paths)),agent_paths):
    if idx == 0:
        metrics = evaluate_control(env_name,agent_path,ss_bound)
    else:
        new_metrics = evaluate_control(env_name,agent_path,ss_bound)
        metrics = metrics.append(new_metrics)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-61af205bd18c> in <module>
#       9         metrics = evaluate_control(env_name,agent_path,ss_bound)
#      10     else:
# ---> 11         new_metrics = evaluate_control(env_name,agent_path,ss_bound)
#      12         metrics = metrics.append(new_metrics)
#
# ~/Documents/MA2/DRLGyro/code/custom_functions/custom_functions/custom_functions.py in evaluate_control(env_name, agent_path, ss_bound)
#     255
#     256         # Run trial
# --> 257         r,score,x1_eval,x2_eval,x3_eval,x4_eval,x1_ref_eval,x3_ref_eval,act = run_trial(env,dt,eval_per_dt,agent,state,t_end,ep_len)
#     258
#     259         # Evaluate control metrics for that run
#
# ~/Documents/MA2/DRLGyro/code/custom_functions/custom_functions/custom_functions.py in run_trial(env, dt, eval_per_dt, agent, state, t_end, ep_len, x1_ref_seq, x3_ref_seq, w_seq)
#     114
#     115         # Get action from agent
# --> 116         action = agent.act(torch.as_tensor(obs, dtype=torch.float32))
#     117
#     118         # Perform step in environment
#
# ~/Documents/MA2/DRLGyro/resources/spinningup/spinup/algos/pytorch/td3/core.py in act(self, obs)
#      60     def act(self, obs):
#      61         with torch.no_grad():
# ---> 62             return self.pi(obs).numpy()
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/Documents/MA2/DRLGyro/resources/spinningup/spinup/algos/pytorch/td3/core.py in forward(self, obs)
#      31     def forward(self, obs):
#      32         # Return output from network scaled to action space limits.
# ---> 33         return self.act_limit * self.pi(obs)
#      34
#      35 class MLPQFunction(nn.Module):
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
# -> 1374             output += bias
#    1375         ret = output
#    1376     return ret
#
# KeyboardInterrupt:

# %%
# Manipulate
metrics_man = metrics[['$\theta$ MAE (rad)','$\phi$ MAE (rad)','$\theta$ MSSE (rad)','$\phi$ MSSE (rad)','$\theta$ in bounds (%)','$\phi$ in bounds (%)','$\theta$ unsteady (%)','$\phi$ unsteady (%)','u1 (V)','u2 (V)','u1 variation (V)','u2 variation (V)']]
metrics_man = metrics_man.transpose()
metrics_man = metrics_man.round(2)
metrics_man
# Out:
# Config.                 td3_n_b_it1/  td3_n_it1_lr_var0/  td3_n_it1_lr_var1/  \
# $\theta$ MAE (rad)              0.21                0.21                0.18
# $\phi$ MAE (rad)                0.13                0.13                0.12
# $\theta$ MSSE (rad)             0.04                0.04                0.04
# $\phi$ MSSE (rad)               0.02                0.02                0.02
# $\theta$ in bounds (%)         77.50               69.50               64.00
# $\phi$ in bounds (%)           89.50               89.00               90.00
# $\theta$ unsteady (%)           0.00                0.00                0.00
# $\phi$ unsteady (%)             0.00                0.00                0.00
# u1 (V)                          0.73                0.79                0.80
# u2 (V)                          0.59                0.64                0.55
# u1 variation (V)                0.06                0.07                0.07
# u2 variation (V)                0.07                0.07                0.07
#
# Config.                 td3_n_it1_hid_var0/  td3_n_it1_hid_var1/  \
# $\theta$ MAE (rad)                     0.23                 0.23
# $\phi$ MAE (rad)                       0.11                 0.14
# $\theta$ MSSE (rad)                    0.03                 0.03
# $\phi$ MSSE (rad)                      0.02                 0.03
# $\theta$ in bounds (%)                74.00                69.50
# $\phi$ in bounds (%)                  97.00                82.00
# $\theta$ unsteady (%)                  0.00                 0.00
# $\phi$ unsteady (%)                    0.00                 0.00
# u1 (V)                                 0.89                 0.87
# u2 (V)                                 0.65                 0.61
# u1 variation (V)                       0.07                 0.07
# u2 variation (V)                       0.07                 0.08
#
# Config.                 td3_n_it1_bs_var0/  td3_n_it1_bs_var1/  \
# $\theta$ MAE (rad)                    0.20                0.21
# $\phi$ MAE (rad)                      0.13                0.13
# $\theta$ MSSE (rad)                   0.04                0.05
# $\phi$ MSSE (rad)                     0.04                0.04
# $\theta$ in bounds (%)               54.00               66.00
# $\phi$ in bounds (%)                 80.00               79.00
# $\theta$ unsteady (%)                 0.00                0.00
# $\phi$ unsteady (%)                   0.00                0.00
# u1 (V)                                0.83                0.84
# u2 (V)                                0.53                0.64
# u1 variation (V)                      0.07                0.07
# u2 variation (V)                      0.07                0.07
#
# Config.                 td3_n_it1_g_var0/  td3_n_it1_g_var1/  \
# $\theta$ MAE (rad)                   0.23               0.20
# $\phi$ MAE (rad)                     0.16               0.13
# $\theta$ MSSE (rad)                  0.02               0.04
# $\phi$ MSSE (rad)                    0.02               0.03
# $\theta$ in bounds (%)              95.00              85.00
# $\phi$ in bounds (%)                89.50              84.50
# $\theta$ unsteady (%)                0.00               0.00
# $\phi$ unsteady (%)                  0.00               0.00
# u1 (V)                               0.82               0.81
# u2 (V)                               0.60               0.68
# u1 variation (V)                     0.07               0.06
# u2 variation (V)                     0.07               0.07
#
# Config.                 td3_n_it1_pol_var0/  td3_n_it1_pol_var1/  \
# $\theta$ MAE (rad)                     0.19                 0.19
# $\phi$ MAE (rad)                       0.15                 0.14
# $\theta$ MSSE (rad)                    0.03                 0.03
# $\phi$ MSSE (rad)                      0.03                 0.05
# $\theta$ in bounds (%)                77.50                80.00
# $\phi$ in bounds (%)                  78.00                79.50
# $\theta$ unsteady (%)                  0.00                 0.00
# $\phi$ unsteady (%)                    0.00                 0.00
# u1 (V)                                 0.84                 0.79
# u2 (V)                                 0.63                 0.55
# u1 variation (V)                       0.07                 0.07
# u2 variation (V)                       0.07                 0.07
#
# Config.                 td3_n_it1_nc_var0/  td3_n_it1_nc_var1/
# $\theta$ MAE (rad)                    0.32                0.21
# $\phi$ MAE (rad)                      0.14                0.11
# $\theta$ MSSE (rad)                   0.15                0.03
# $\phi$ MSSE (rad)                     0.05                0.02
# $\theta$ in bounds (%)               74.00               86.00
# $\phi$ in bounds (%)                 78.50               97.00
# $\theta$ unsteady (%)                 0.00                0.00
# $\phi$ unsteady (%)                   0.00                0.00
# u1 (V)                                0.79                0.79
# u2 (V)                                0.60                0.59
# u1 variation (V)                      0.07                0.07
# u2 variation (V)                      0.08                0.06

# %%
# Init dataframe
env_name = 'gyroscopeenv-v0'
agent_paths = ['td3_n_b_var1/','td3_n_b_it1/','td3_n_b_it2/']
ss_bound = 0.05

# Loop dataframe
for idx, agent_path in zip(range(len(agent_paths)),agent_paths):
    if idx == 0:
        metrics = evaluate_control(env_name,agent_path,ss_bound)
    else:
        new_metrics = evaluate_control(env_name,agent_path,ss_bound)
        metrics = metrics.append(new_metrics)
# Out:
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/serialization.py:493: SourceChangeWarning: source code of class 'torch.nn.modules.container.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
# Manipulate
metrics_man = metrics[['$\theta$ MAE (rad)','$\phi$ MAE (rad)','$\theta$ MSSE (rad)','$\phi$ MSSE (rad)','$\theta$ in bounds (%)','$\phi$ in bounds (%)','$\theta$ unsteady (%)','$\phi$ unsteady (%)','u1 (V)','u2 (V)','u1 variation (V)','u2 variation (V)']]
metrics_man = metrics_man.transpose()
metrics_man = metrics_man.round(2)
metrics_man
# Out:
# Config.                 td3_n_b_var1/  td3_n_b_it1/  td3_n_b_it2/
# $\theta$ MAE (rad)               0.26          0.20          0.20
# $\phi$ MAE (rad)                 0.18          0.13          0.12
# $\theta$ MSSE (rad)              0.07          0.05          0.02
# $\phi$ MSSE (rad)                0.05          0.02          0.02
# $\theta$ in bounds (%)          55.50         71.50         95.50
# $\phi$ in bounds (%)            58.00         92.00         93.50
# $\theta$ unsteady (%)            0.00          0.00          0.00
# $\phi$ unsteady (%)              0.00          0.00          0.00
# u1 (V)                           0.83          0.76          0.79
# u2 (V)                           0.65          0.58          0.62
# u1 variation (V)                 0.07          0.06          0.07
# u2 variation (V)                 0.05          0.07          0.08

# %%
# To LaTex
print(metrics_man.to_latex(escape=False))
# Out:
# \begin{tabular}{lrrr}
# \toprule
# Config. &  td3_n_b_var1/ &  td3_n_b_it1/ &  td3_n_b_it2/ \\
# \midrule
# $\theta$ MAE (rad)     &           0.26 &          0.20 &          0.20 \\
# $\phi$ MAE (rad)       &           0.18 &          0.13 &          0.12 \\
# $\theta$ MSSE (rad)    &           0.07 &          0.05 &          0.02 \\
# $\phi$ MSSE (rad)      &           0.05 &          0.02 &          0.02 \\
# $\theta$ in bounds (%) &          55.50 &         71.50 &         95.50 \\
# $\phi$ in bounds (%)   &          58.00 &         92.00 &         93.50 \\
# $\theta$ unsteady (%)  &           0.00 &          0.00 &          0.00 \\
# $\phi$ unsteady (%)    &           0.00 &          0.00 &          0.00 \\
# u1 (V)                 &           0.83 &          0.76 &          0.79 \\
# u2 (V)                 &           0.65 &          0.58 &          0.62 \\
# u1 variation (V)       &           0.07 &          0.06 &          0.07 \\
# u2 variation (V)       &           0.05 &          0.07 &          0.08 \\
# \bottomrule
# \end{tabular}
