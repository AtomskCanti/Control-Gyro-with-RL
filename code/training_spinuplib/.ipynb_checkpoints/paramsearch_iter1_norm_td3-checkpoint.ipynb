# %% [markdown]
# # TD3 hyperparameter search with normalized reward (spinup library)

# %%
import gym
from gym import spaces
from gym.utils import seeding
from gym.envs.registration import register

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control

import spinup

from os import path
from scipy.integrate import solve_ivp
import random
import torch
import numpy as np
import pandas as pd
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline
#from vpython import *
from functools import partial

register(id='gyroscopeenv-v0',entry_point='gym_GyroscopeEnv.envs:GyroscopeEnv')

# %% [markdown]
# ## Baseline iteration

# %% [markdown]
# #### Learning rate

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it1_lr_var0', exp_name='td3_n_it1_lr_var0')
seed_b = 0
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.99
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[800], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0008
qlr_b = 0.0008

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.05

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)
# Out:
# Warning: Log dir td3_n_it1_lr_var0 already exists! Storing info there anyway.
# Logging data to td3_n_it1_lr_var0/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             800
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	150,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fc9b0b23710>, env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.05, 'qx2': 0.01, 'qx4': 0.01, 'pu1': 0.5, 'pu2': 0.5}, ep_len=110)",
#     "epochs":	800,
#     "exp_name":	"td3_n_it1_lr_var0",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fc982cc20d0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_n_it1_lr_var0",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_n_it1_lr_var0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_n_it1_lr_var0/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_n_it1_lr_var0",
#         "output_dir":	"td3_n_it1_lr_var0"
#     },
#     "max_ep_len":	110,
#     "noise_clip":	0.05,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0008,
#     "policy_delay":	2,
#     "polyak":	0.999,
#     "q_lr":	0.0008,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	20000,
#     "steps_per_epoch":	1650,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 9602, 	 q1: 10401, 	 q2: 10401
# /home/lecauchoismatthieu/drlenv/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -319 |
# |          StdEpRet |              25 |
# |          MaxEpRet |            -283 |
# |          MinEpRet |            -373 |
# |  AverageTestEpRet |            -214 |
# |      StdTestEpRet |            8.72 |
# |      MaxTestEpRet |            -196 |
# |      MinTestEpRet |            -227 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |     AverageQ1Vals |           -3.32 |
# |         StdQ1Vals |           0.644 |
# |         MaxQ1Vals |           0.245 |
# |         MinQ1Vals |           -5.51 |
# |     AverageQ2Vals |           -3.32 |
# |         StdQ2Vals |           0.635 |
# |         MaxQ2Vals |           0.106 |
# |         MinQ2Vals |           -5.57 |
# |            LossPi |               3 |
# |             LossQ |           0.439 |
# |              Time |            8.42 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -328 |
# |          StdEpRet |              32 |
# |          MaxEpRet |            -288 |
# |          MinEpRet |            -384 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            12.8 |
# |      MaxTestEpRet |            -177 |
# |      MinTestEpRet |            -225 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |     AverageQ1Vals |           -4.72 |
# |         StdQ1Vals |           0.856 |
# |         MaxQ1Vals |           -2.51 |
# |         MinQ1Vals |           -8.15 |
# |     AverageQ2Vals |           -4.72 |
# |         StdQ2Vals |           0.855 |
# |         MaxQ2Vals |           -2.52 |
# |         MinQ2Vals |           -8.19 |
# |            LossPi |            4.25 |
# |             LossQ |          0.0882 |
# |              Time |            22.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -319 |
# |          StdEpRet |            30.6 |
# |          MaxEpRet |            -274 |
# |          MinEpRet |            -382 |
# |  AverageTestEpRet |            -213 |
# |      StdTestEpRet |            7.86 |
# |      MaxTestEpRet |            -202 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |     AverageQ1Vals |           -6.39 |
# |         StdQ1Vals |            1.04 |
# |         MaxQ1Vals |           -3.59 |
# |         MinQ1Vals |           -10.7 |
# |     AverageQ2Vals |           -6.39 |
# |         StdQ2Vals |            1.04 |
# |         MaxQ2Vals |           -3.58 |
# |         MinQ2Vals |           -10.7 |
# |            LossPi |            5.86 |
# |             LossQ |          0.0732 |
# |              Time |            37.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -324 |
# |          StdEpRet |            19.9 |
# |          MaxEpRet |            -296 |
# |          MinEpRet |            -368 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            3.23 |
# |      MaxTestEpRet |            -207 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |     AverageQ1Vals |           -8.09 |
# |         StdQ1Vals |            1.27 |
# |         MaxQ1Vals |           -4.58 |
# |         MinQ1Vals |             -13 |
# |     AverageQ2Vals |           -8.09 |
# |         StdQ2Vals |            1.27 |
# |         MaxQ2Vals |           -4.62 |
# |         MinQ2Vals |           -13.1 |
# |            LossPi |            7.49 |
# |             LossQ |          0.0796 |
# |              Time |            52.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -324 |
# |          StdEpRet |            36.7 |
# |          MaxEpRet |            -264 |
# |          MinEpRet |            -394 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            7.72 |
# |      MaxTestEpRet |            -192 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |     AverageQ1Vals |           -9.85 |
# |         StdQ1Vals |            1.49 |
# |         MaxQ1Vals |           -5.73 |
# |         MinQ1Vals |           -15.5 |
# |     AverageQ2Vals |           -9.85 |
# |         StdQ2Vals |            1.49 |
# |         MaxQ2Vals |           -5.67 |
# |         MinQ2Vals |           -15.5 |
# |            LossPi |            9.19 |
# |             LossQ |           0.085 |
# |              Time |              67 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -315 |
# |          StdEpRet |            24.8 |
# |          MaxEpRet |            -284 |
# |          MinEpRet |            -371 |
# |  AverageTestEpRet |            -213 |
# |      StdTestEpRet |            9.27 |
# |      MaxTestEpRet |            -191 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |     AverageQ1Vals |           -11.5 |
# |         StdQ1Vals |            1.69 |
# |         MaxQ1Vals |           -6.81 |
# |         MinQ1Vals |           -17.9 |
# |     AverageQ2Vals |           -11.5 |
# |         StdQ2Vals |            1.69 |
# |         MaxQ2Vals |           -6.81 |
# |         MinQ2Vals |             -18 |
# |            LossPi |            10.8 |
# |             LossQ |          0.0899 |
# |              Time |            80.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -321 |
# |          StdEpRet |              25 |
# |          MaxEpRet |            -288 |
# |          MinEpRet |            -381 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            8.81 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |     AverageQ1Vals |           -13.1 |
# |         StdQ1Vals |            1.85 |
# |         MaxQ1Vals |              -8 |
# |         MinQ1Vals |           -20.5 |
# |     AverageQ2Vals |           -13.1 |
# |         StdQ2Vals |            1.85 |
# |         MaxQ2Vals |           -7.96 |
# |         MinQ2Vals |           -20.6 |
# |            LossPi |            12.3 |
# |             LossQ |           0.101 |
# |              Time |            95.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -312 |
# |          StdEpRet |            27.5 |
# |          MaxEpRet |            -268 |
# |          MinEpRet |            -383 |
# |  AverageTestEpRet |            -213 |
# |      StdTestEpRet |            7.79 |
# |      MaxTestEpRet |            -193 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |     AverageQ1Vals |           -14.6 |
# |         StdQ1Vals |            1.99 |
# |         MaxQ1Vals |           -9.21 |
# |         MinQ1Vals |           -22.9 |
# |     AverageQ2Vals |           -14.6 |
# |         StdQ2Vals |            1.99 |
# |         MaxQ2Vals |           -9.26 |
# |         MinQ2Vals |           -22.8 |
# |            LossPi |            13.8 |
# |             LossQ |           0.107 |
# |              Time |             110 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -313 |
# |          StdEpRet |            19.2 |
# |          MaxEpRet |            -281 |
# |          MinEpRet |            -349 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |            7.64 |
# |      MaxTestEpRet |            -196 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |     AverageQ1Vals |           -16.1 |
# |         StdQ1Vals |            2.09 |
# |         MaxQ1Vals |           -10.5 |
# |         MinQ1Vals |           -24.7 |
# |     AverageQ2Vals |           -16.1 |
# |         StdQ2Vals |            2.09 |
# |         MaxQ2Vals |           -10.5 |
# |         MinQ2Vals |           -24.8 |
# |            LossPi |            15.2 |
# |             LossQ |           0.112 |
# |              Time |             125 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -317 |
# |          StdEpRet |            30.9 |
# |          MaxEpRet |            -261 |
# |          MinEpRet |            -394 |
# |  AverageTestEpRet |            -202 |
# |      StdTestEpRet |            12.3 |
# |      MaxTestEpRet |            -182 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -17.6 |
# |         StdQ1Vals |            2.19 |
# |         MaxQ1Vals |           -11.6 |
# |         MinQ1Vals |           -26.4 |
# |     AverageQ2Vals |           -17.6 |
# |         StdQ2Vals |            2.19 |
# |         MaxQ2Vals |           -11.7 |
# |         MinQ2Vals |           -26.4 |
# |            LossPi |            16.6 |
# |             LossQ |           0.123 |
# |              Time |             139 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -313 |
# |          StdEpRet |            24.8 |
# |          MaxEpRet |            -279 |
# |          MinEpRet |            -374 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            6.42 |
# |      MaxTestEpRet |            -194 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |     AverageQ1Vals |             -19 |
# |         StdQ1Vals |            2.25 |
# |         MaxQ1Vals |           -12.7 |
# |         MinQ1Vals |             -28 |
# |     AverageQ2Vals |             -19 |
# |         StdQ2Vals |            2.25 |
# |         MaxQ2Vals |           -12.7 |
# |         MinQ2Vals |           -27.9 |
# |            LossPi |              18 |
# |             LossQ |           0.133 |
# |              Time |             154 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -326 |
# |          StdEpRet |            18.8 |
# |          MaxEpRet |            -299 |
# |          MinEpRet |            -366 |
# |  AverageTestEpRet |            -210 |
# |      StdTestEpRet |            6.74 |
# |      MaxTestEpRet |            -194 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |     AverageQ1Vals |           -20.4 |
# |         StdQ1Vals |            2.31 |
# |         MaxQ1Vals |           -13.8 |
# |         MinQ1Vals |           -29.7 |
# |     AverageQ2Vals |           -20.4 |
# |         StdQ2Vals |            2.31 |
# |         MaxQ2Vals |           -13.9 |
# |         MinQ2Vals |           -29.5 |
# |            LossPi |            19.4 |
# |             LossQ |           0.139 |
# |              Time |             169 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -218 |
# |          StdEpRet |            31.3 |
# |          MaxEpRet |            -173 |
# |          MinEpRet |            -293 |
# |  AverageTestEpRet |            -203 |
# |      StdTestEpRet |              10 |
# |      MaxTestEpRet |            -177 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |     AverageQ1Vals |           -21.6 |
# |         StdQ1Vals |            2.42 |
# |         MaxQ1Vals |           -15.1 |
# |         MinQ1Vals |           -31.1 |
# |     AverageQ2Vals |           -21.6 |
# |         StdQ2Vals |            2.42 |
# |         MaxQ2Vals |           -15.1 |
# |         MinQ2Vals |           -30.9 |
# |            LossPi |            20.6 |
# |             LossQ |           0.141 |
# |              Time |             183 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -214 |
# |          StdEpRet |            6.57 |
# |          MaxEpRet |            -197 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |            6.54 |
# |      MaxTestEpRet |            -202 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |     AverageQ1Vals |           -22.7 |
# |         StdQ1Vals |            2.57 |
# |         MaxQ1Vals |           -16.3 |
# |         MinQ1Vals |           -32.4 |
# |     AverageQ2Vals |           -22.7 |
# |         StdQ2Vals |            2.57 |
# |         MaxQ2Vals |           -16.2 |
# |         MinQ2Vals |           -32.5 |
# |            LossPi |            21.8 |
# |             LossQ |           0.134 |
# |              Time |             199 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -209 |
# |          StdEpRet |            10.8 |
# |          MaxEpRet |            -188 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |             6.4 |
# |      MaxTestEpRet |            -200 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |     AverageQ1Vals |           -23.9 |
# |         StdQ1Vals |            2.69 |
# |         MaxQ1Vals |           -17.5 |
# |         MinQ1Vals |           -34.1 |
# |     AverageQ2Vals |           -23.9 |
# |         StdQ2Vals |            2.69 |
# |         MaxQ2Vals |           -17.5 |
# |         MinQ2Vals |             -34 |
# |            LossPi |            22.9 |
# |             LossQ |           0.128 |
# |              Time |             214 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            15.3 |
# |          MaxEpRet |            -156 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            5.78 |
# |      MaxTestEpRet |            -198 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |     AverageQ1Vals |             -25 |
# |         StdQ1Vals |            2.77 |
# |         MaxQ1Vals |           -18.5 |
# |         MinQ1Vals |           -35.7 |
# |     AverageQ2Vals |             -25 |
# |         StdQ2Vals |            2.77 |
# |         MaxQ2Vals |           -18.5 |
# |         MinQ2Vals |           -35.6 |
# |            LossPi |            24.1 |
# |             LossQ |           0.123 |
# |              Time |             229 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            10.6 |
# |          MaxEpRet |            -180 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            14.8 |
# |      MaxTestEpRet |            -176 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |           -26.1 |
# |         StdQ1Vals |            2.82 |
# |         MaxQ1Vals |           -19.5 |
# |         MinQ1Vals |           -37.1 |
# |     AverageQ2Vals |           -26.1 |
# |         StdQ2Vals |            2.82 |
# |         MaxQ2Vals |           -19.6 |
# |         MinQ2Vals |           -36.9 |
# |            LossPi |            25.3 |
# |             LossQ |           0.121 |
# |              Time |             244 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -207 |
# |          StdEpRet |            12.7 |
# |          MaxEpRet |            -179 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -213 |
# |      StdTestEpRet |            4.21 |
# |      MaxTestEpRet |            -207 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |     AverageQ1Vals |           -27.3 |
# |         StdQ1Vals |            2.87 |
# |         MaxQ1Vals |           -20.6 |
# |         MinQ1Vals |             -39 |
# |     AverageQ2Vals |           -27.3 |
# |         StdQ2Vals |            2.87 |
# |         MaxQ2Vals |           -20.6 |
# |         MinQ2Vals |           -38.8 |
# |            LossPi |            26.5 |
# |             LossQ |            0.12 |
# |              Time |             259 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -200 |
# |          StdEpRet |            16.9 |
# |          MaxEpRet |            -151 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |            11.6 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |     AverageQ1Vals |           -28.4 |
# |         StdQ1Vals |            2.92 |
# |         MaxQ1Vals |           -21.5 |
# |         MinQ1Vals |           -40.5 |
# |     AverageQ2Vals |           -28.4 |
# |         StdQ2Vals |            2.92 |
# |         MaxQ2Vals |           -21.5 |
# |         MinQ2Vals |           -40.3 |
# |            LossPi |            27.6 |
# |             LossQ |           0.117 |
# |              Time |             274 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -204 |
# |          StdEpRet |            12.5 |
# |          MaxEpRet |            -180 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            9.77 |
# |      MaxTestEpRet |            -191 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -29.5 |
# |         StdQ1Vals |            2.97 |
# |         MaxQ1Vals |           -22.5 |
# |         MinQ1Vals |           -41.6 |
# |     AverageQ2Vals |           -29.5 |
# |         StdQ2Vals |            2.97 |
# |         MaxQ2Vals |           -22.4 |
# |         MinQ2Vals |           -41.4 |
# |            LossPi |            28.8 |
# |             LossQ |           0.117 |
# |              Time |             289 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -206 |
# |          StdEpRet |            15.6 |
# |          MaxEpRet |            -168 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            11.1 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |     AverageQ1Vals |           -30.7 |
# |         StdQ1Vals |            2.99 |
# |         MaxQ1Vals |           -23.5 |
# |         MinQ1Vals |           -43.2 |
# |     AverageQ2Vals |           -30.7 |
# |         StdQ2Vals |            2.99 |
# |         MaxQ2Vals |           -23.5 |
# |         MinQ2Vals |           -43.1 |
# |            LossPi |              30 |
# |             LossQ |           0.116 |
# |              Time |             305 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -206 |
# |          StdEpRet |            12.5 |
# |          MaxEpRet |            -183 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -197 |
# |      StdTestEpRet |            23.2 |
# |      MaxTestEpRet |            -139 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |     AverageQ1Vals |           -31.8 |
# |         StdQ1Vals |            3.03 |
# |         MaxQ1Vals |           -24.4 |
# |         MinQ1Vals |           -44.5 |
# |     AverageQ2Vals |           -31.8 |
# |         StdQ2Vals |            3.03 |
# |         MaxQ2Vals |           -24.4 |
# |         MinQ2Vals |           -44.3 |
# |            LossPi |            31.2 |
# |             LossQ |           0.116 |
# |              Time |             320 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -209 |
# |          StdEpRet |            12.1 |
# |          MaxEpRet |            -185 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -202 |
# |      StdTestEpRet |            20.1 |
# |      MaxTestEpRet |            -153 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |     AverageQ1Vals |             -33 |
# |         StdQ1Vals |            3.05 |
# |         MaxQ1Vals |           -25.2 |
# |         MinQ1Vals |           -45.4 |
# |     AverageQ2Vals |             -33 |
# |         StdQ2Vals |            3.05 |
# |         MaxQ2Vals |           -25.3 |
# |         MinQ2Vals |           -45.2 |
# |            LossPi |            32.4 |
# |             LossQ |           0.117 |
# |              Time |             335 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            17.9 |
# |          MaxEpRet |            -167 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            6.52 |
# |      MaxTestEpRet |            -194 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |     AverageQ1Vals |           -34.2 |
# |         StdQ1Vals |            3.08 |
# |         MaxQ1Vals |           -26.4 |
# |         MinQ1Vals |           -47.2 |
# |     AverageQ2Vals |           -34.2 |
# |         StdQ2Vals |            3.08 |
# |         MaxQ2Vals |           -26.4 |
# |         MinQ2Vals |           -46.6 |
# |            LossPi |            33.6 |
# |             LossQ |           0.118 |
# |              Time |             350 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            19.7 |
# |          MaxEpRet |            -151 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -201 |
# |      StdTestEpRet |            18.1 |
# |      MaxTestEpRet |            -152 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |     AverageQ1Vals |           -35.3 |
# |         StdQ1Vals |            3.13 |
# |         MaxQ1Vals |           -27.3 |
# |         MinQ1Vals |           -48.5 |
# |     AverageQ2Vals |           -35.3 |
# |         StdQ2Vals |            3.13 |
# |         MaxQ2Vals |           -27.3 |
# |         MinQ2Vals |             -48 |
# |            LossPi |            34.8 |
# |             LossQ |           0.119 |
# |              Time |             365 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -210 |
# |          StdEpRet |            14.4 |
# |          MaxEpRet |            -178 |
# |          MinEpRet |            -227 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |            7.86 |
# |      MaxTestEpRet |            -194 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |     AverageQ1Vals |           -36.5 |
# |         StdQ1Vals |            3.16 |
# |         MaxQ1Vals |           -28.3 |
# |         MinQ1Vals |           -50.2 |
# |     AverageQ2Vals |           -36.5 |
# |         StdQ2Vals |            3.16 |
# |         MaxQ2Vals |           -28.4 |
# |         MinQ2Vals |           -49.8 |
# |            LossPi |            35.9 |
# |             LossQ |           0.121 |
# |              Time |             380 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -212 |
# |          StdEpRet |            11.7 |
# |          MaxEpRet |            -172 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |            11.9 |
# |      MaxTestEpRet |            -185 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |     AverageQ1Vals |           -37.6 |
# |         StdQ1Vals |            3.18 |
# |         MaxQ1Vals |           -29.1 |
# |         MinQ1Vals |           -50.9 |
# |     AverageQ2Vals |           -37.6 |
# |         StdQ2Vals |            3.18 |
# |         MaxQ2Vals |           -29.1 |
# |         MinQ2Vals |           -50.7 |
# |            LossPi |            37.1 |
# |             LossQ |           0.123 |
# |              Time |             395 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -207 |
# |          StdEpRet |            10.9 |
# |          MaxEpRet |            -181 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -204 |
# |      StdTestEpRet |             6.6 |
# |      MaxTestEpRet |            -188 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |     AverageQ1Vals |           -38.8 |
# |         StdQ1Vals |            3.22 |
# |         MaxQ1Vals |           -30.1 |
# |         MinQ1Vals |           -52.1 |
# |     AverageQ2Vals |           -38.8 |
# |         StdQ2Vals |            3.22 |
# |         MaxQ2Vals |           -30.2 |
# |         MinQ2Vals |           -51.9 |
# |            LossPi |            38.3 |
# |             LossQ |           0.124 |
# |              Time |             410 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -200 |
# |          StdEpRet |            14.7 |
# |          MaxEpRet |            -167 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -201 |
# |      StdTestEpRet |            15.5 |
# |      MaxTestEpRet |            -170 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |     AverageQ1Vals |           -39.9 |
# |         StdQ1Vals |            3.25 |
# |         MaxQ1Vals |           -31.1 |
# |         MinQ1Vals |           -53.7 |
# |     AverageQ2Vals |           -39.9 |
# |         StdQ2Vals |            3.25 |
# |         MaxQ2Vals |           -31.1 |
# |         MinQ2Vals |           -53.2 |
# |            LossPi |            39.4 |
# |             LossQ |           0.126 |
# |              Time |             424 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -207 |
# |          StdEpRet |            8.72 |
# |          MaxEpRet |            -190 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |            24.1 |
# |      MaxTestEpRet |            -127 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -41.1 |
# |         StdQ1Vals |            3.31 |
# |         MaxQ1Vals |           -32.1 |
# |         MinQ1Vals |           -55.3 |
# |     AverageQ2Vals |           -41.1 |
# |         StdQ2Vals |            3.31 |
# |         MaxQ2Vals |           -32.1 |
# |         MinQ2Vals |           -54.9 |
# |            LossPi |            40.6 |
# |             LossQ |           0.129 |
# |              Time |             440 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -196 |
# |          StdEpRet |            15.9 |
# |          MaxEpRet |            -169 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            18.4 |
# |      MaxTestEpRet |            -151 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |     AverageQ1Vals |           -42.2 |
# |         StdQ1Vals |            3.35 |
# |         MaxQ1Vals |           -33.1 |
# |         MinQ1Vals |             -56 |
# |     AverageQ2Vals |           -42.2 |
# |         StdQ2Vals |            3.35 |
# |         MaxQ2Vals |             -33 |
# |         MinQ2Vals |           -56.3 |
# |            LossPi |            41.7 |
# |             LossQ |           0.131 |
# |              Time |             454 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -209 |
# |          StdEpRet |               8 |
# |          MaxEpRet |            -194 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -203 |
# |      StdTestEpRet |            11.5 |
# |      MaxTestEpRet |            -186 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |     AverageQ1Vals |           -43.3 |
# |         StdQ1Vals |            3.39 |
# |         MaxQ1Vals |           -33.9 |
# |         MinQ1Vals |           -57.6 |
# |     AverageQ2Vals |           -43.3 |
# |         StdQ2Vals |            3.39 |
# |         MaxQ2Vals |             -34 |
# |         MinQ2Vals |           -57.7 |
# |            LossPi |            42.8 |
# |             LossQ |           0.134 |
# |              Time |             469 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -194 |
# |          StdEpRet |              21 |
# |          MaxEpRet |            -131 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -204 |
# |      StdTestEpRet |            15.1 |
# |      MaxTestEpRet |            -177 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |     AverageQ1Vals |           -44.4 |
# |         StdQ1Vals |            3.44 |
# |         MaxQ1Vals |           -34.6 |
# |         MinQ1Vals |           -58.9 |
# |     AverageQ2Vals |           -44.4 |
# |         StdQ2Vals |            3.44 |
# |         MaxQ2Vals |           -34.8 |
# |         MinQ2Vals |           -58.6 |
# |            LossPi |            43.9 |
# |             LossQ |           0.134 |
# |              Time |             484 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            14.8 |
# |          MaxEpRet |            -167 |
# |          MinEpRet |            -215 |
# |  AverageTestEpRet |            -193 |
# |      StdTestEpRet |              19 |
# |      MaxTestEpRet |            -156 |
# |      MinTestEpRet |            -215 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |     AverageQ1Vals |           -45.4 |
# |         StdQ1Vals |            3.51 |
# |         MaxQ1Vals |           -35.4 |
# |         MinQ1Vals |           -60.3 |
# |     AverageQ2Vals |           -45.4 |
# |         StdQ2Vals |            3.51 |
# |         MaxQ2Vals |           -35.4 |
# |         MinQ2Vals |           -60.2 |
# |            LossPi |              45 |
# |             LossQ |           0.138 |
# |              Time |             499 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -202 |
# |          StdEpRet |              18 |
# |          MaxEpRet |            -159 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -204 |
# |      StdTestEpRet |            12.9 |
# |      MaxTestEpRet |            -168 |
# |      MinTestEpRet |            -215 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |     AverageQ1Vals |           -46.5 |
# |         StdQ1Vals |            3.58 |
# |         MaxQ1Vals |           -36.4 |
# |         MinQ1Vals |           -61.1 |
# |     AverageQ2Vals |           -46.5 |
# |         StdQ2Vals |            3.58 |
# |         MaxQ2Vals |           -36.2 |
# |         MinQ2Vals |           -61.3 |
# |            LossPi |            46.1 |
# |             LossQ |           0.143 |
# |              Time |             514 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -204 |
# |          StdEpRet |            16.1 |
# |          MaxEpRet |            -164 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -202 |
# |      StdTestEpRet |            17.1 |
# |      MaxTestEpRet |            -155 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |     AverageQ1Vals |           -47.6 |
# |         StdQ1Vals |            3.63 |
# |         MaxQ1Vals |           -37.1 |
# |         MinQ1Vals |           -62.5 |
# |     AverageQ2Vals |           -47.6 |
# |         StdQ2Vals |            3.63 |
# |         MaxQ2Vals |           -37.1 |
# |         MinQ2Vals |           -62.5 |
# |            LossPi |            47.2 |
# |             LossQ |           0.146 |
# |              Time |             529 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -196 |
# |          StdEpRet |            19.5 |
# |          MaxEpRet |            -156 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -197 |
# |      StdTestEpRet |            13.5 |
# |      MaxTestEpRet |            -172 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |     AverageQ1Vals |           -48.7 |
# |         StdQ1Vals |            3.68 |
# |         MaxQ1Vals |           -37.8 |
# |         MinQ1Vals |             -64 |
# |     AverageQ2Vals |           -48.7 |
# |         StdQ2Vals |            3.68 |
# |         MaxQ2Vals |             -38 |
# |         MinQ2Vals |           -64.1 |
# |            LossPi |            48.3 |
# |             LossQ |           0.148 |
# |              Time |             544 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -204 |
# |          StdEpRet |            12.7 |
# |          MaxEpRet |            -176 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            13.6 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |     AverageQ1Vals |           -49.8 |
# |         StdQ1Vals |            3.74 |
# |         MaxQ1Vals |           -38.7 |
# |         MinQ1Vals |           -65.5 |
# |     AverageQ2Vals |           -49.8 |
# |         StdQ2Vals |            3.74 |
# |         MaxQ2Vals |           -38.7 |
# |         MinQ2Vals |           -65.5 |
# |            LossPi |            49.3 |
# |             LossQ |            0.15 |
# |              Time |             559 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            13.7 |
# |          MaxEpRet |            -176 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            6.99 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |     AverageQ1Vals |           -50.8 |
# |         StdQ1Vals |            3.78 |
# |         MaxQ1Vals |           -39.5 |
# |         MinQ1Vals |           -66.3 |
# |     AverageQ2Vals |           -50.8 |
# |         StdQ2Vals |            3.78 |
# |         MaxQ2Vals |           -39.5 |
# |         MinQ2Vals |           -66.6 |
# |            LossPi |            50.4 |
# |             LossQ |           0.156 |
# |              Time |             574 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -196 |
# |          StdEpRet |            16.3 |
# |          MaxEpRet |            -168 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            15.3 |
# |      MaxTestEpRet |            -171 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -51.8 |
# |         StdQ1Vals |            3.86 |
# |         MaxQ1Vals |           -40.1 |
# |         MinQ1Vals |           -67.9 |
# |     AverageQ2Vals |           -51.8 |
# |         StdQ2Vals |            3.86 |
# |         MaxQ2Vals |           -40.2 |
# |         MinQ2Vals |           -68.3 |
# |            LossPi |            51.4 |
# |             LossQ |           0.158 |
# |              Time |             589 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -202 |
# |          StdEpRet |            17.6 |
# |          MaxEpRet |            -158 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |            15.4 |
# |      MaxTestEpRet |            -171 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |     AverageQ1Vals |           -52.9 |
# |         StdQ1Vals |            3.91 |
# |         MaxQ1Vals |           -41.1 |
# |         MinQ1Vals |           -69.2 |
# |     AverageQ2Vals |           -52.9 |
# |         StdQ2Vals |            3.91 |
# |         MaxQ2Vals |           -41.1 |
# |         MinQ2Vals |           -69.3 |
# |            LossPi |            52.5 |
# |             LossQ |           0.162 |
# |              Time |             604 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -194 |
# |          StdEpRet |            22.6 |
# |          MaxEpRet |            -128 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -186 |
# |      StdTestEpRet |            24.9 |
# |      MaxTestEpRet |            -146 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |     AverageQ1Vals |           -53.9 |
# |         StdQ1Vals |            3.97 |
# |         MaxQ1Vals |           -41.9 |
# |         MinQ1Vals |           -70.7 |
# |     AverageQ2Vals |           -53.9 |
# |         StdQ2Vals |            3.97 |
# |         MaxQ2Vals |           -41.9 |
# |         MinQ2Vals |           -70.8 |
# |            LossPi |            53.5 |
# |             LossQ |           0.167 |
# |              Time |             618 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -187 |
# |          StdEpRet |            21.9 |
# |          MaxEpRet |            -144 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -197 |
# |      StdTestEpRet |              16 |
# |      MaxTestEpRet |            -160 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |     AverageQ1Vals |           -54.9 |
# |         StdQ1Vals |            4.06 |
# |         MaxQ1Vals |           -42.5 |
# |         MinQ1Vals |           -71.7 |
# |     AverageQ2Vals |           -54.9 |
# |         StdQ2Vals |            4.06 |
# |         MaxQ2Vals |           -42.4 |
# |         MinQ2Vals |           -71.6 |
# |            LossPi |            54.5 |
# |             LossQ |           0.172 |
# |              Time |             633 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            14.4 |
# |          MaxEpRet |            -175 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -201 |
# |      StdTestEpRet |            11.3 |
# |      MaxTestEpRet |            -178 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |     AverageQ1Vals |           -55.8 |
# |         StdQ1Vals |            4.14 |
# |         MaxQ1Vals |           -43.2 |
# |         MinQ1Vals |             -73 |
# |     AverageQ2Vals |           -55.8 |
# |         StdQ2Vals |            4.14 |
# |         MaxQ2Vals |           -43.2 |
# |         MinQ2Vals |           -73.1 |
# |            LossPi |            55.5 |
# |             LossQ |           0.178 |
# |              Time |             648 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -197 |
# |          StdEpRet |            20.1 |
# |          MaxEpRet |            -147 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -186 |
# |      StdTestEpRet |            17.5 |
# |      MaxTestEpRet |            -157 |
# |      MinTestEpRet |            -211 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |     AverageQ1Vals |           -56.8 |
# |         StdQ1Vals |             4.2 |
# |         MaxQ1Vals |           -43.9 |
# |         MinQ1Vals |             -74 |
# |     AverageQ2Vals |           -56.8 |
# |         StdQ2Vals |             4.2 |
# |         MaxQ2Vals |           -43.9 |
# |         MinQ2Vals |             -74 |
# |            LossPi |            56.4 |
# |             LossQ |           0.181 |
# |              Time |             663 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -194 |
# |          StdEpRet |            25.9 |
# |          MaxEpRet |            -117 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -188 |
# |      StdTestEpRet |            21.5 |
# |      MaxTestEpRet |            -143 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |     AverageQ1Vals |           -57.8 |
# |         StdQ1Vals |            4.25 |
# |         MaxQ1Vals |           -44.4 |
# |         MinQ1Vals |           -75.4 |
# |     AverageQ2Vals |           -57.8 |
# |         StdQ2Vals |            4.25 |
# |         MaxQ2Vals |           -44.4 |
# |         MinQ2Vals |           -75.1 |
# |            LossPi |            57.5 |
# |             LossQ |           0.185 |
# |              Time |             678 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# ...
# ---------------------------------------
# |             Epoch |             785 |
# |      AverageEpRet |            -117 |
# |          StdEpRet |            17.7 |
# |          MaxEpRet |           -86.8 |
# |          MinEpRet |            -156 |
# |  AverageTestEpRet |           -98.9 |
# |      StdTestEpRet |            40.9 |
# |      MaxTestEpRet |           -39.7 |
# |      MinTestEpRet |            -175 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |             -92 |
# |         StdQ1Vals |            16.5 |
# |         MaxQ1Vals |           -63.2 |
# |         MinQ1Vals |            -177 |
# |     AverageQ2Vals |             -92 |
# |         StdQ2Vals |            16.5 |
# |         MaxQ2Vals |           -63.7 |
# |         MinQ2Vals |            -174 |
# |            LossPi |            91.8 |
# |             LossQ |           0.809 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             786 |
# |      AverageEpRet |            -107 |
# |          StdEpRet |            22.5 |
# |          MaxEpRet |             -80 |
# |          MinEpRet |            -147 |
# |  AverageTestEpRet |            -121 |
# |      StdTestEpRet |            25.9 |
# |      MaxTestEpRet |           -64.8 |
# |      MinTestEpRet |            -150 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -91.9 |
# |         StdQ1Vals |            16.5 |
# |         MaxQ1Vals |           -63.5 |
# |         MinQ1Vals |            -179 |
# |     AverageQ2Vals |           -91.9 |
# |         StdQ2Vals |            16.5 |
# |         MaxQ2Vals |           -63.7 |
# |         MinQ2Vals |            -176 |
# |            LossPi |            91.6 |
# |             LossQ |           0.805 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             787 |
# |      AverageEpRet |            -115 |
# |          StdEpRet |            25.1 |
# |          MaxEpRet |           -80.6 |
# |          MinEpRet |            -166 |
# |  AverageTestEpRet |            -109 |
# |      StdTestEpRet |            30.9 |
# |      MaxTestEpRet |           -56.5 |
# |      MinTestEpRet |            -155 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -91.8 |
# |         StdQ1Vals |            16.4 |
# |         MaxQ1Vals |           -63.4 |
# |         MinQ1Vals |            -179 |
# |     AverageQ2Vals |           -91.8 |
# |         StdQ2Vals |            16.4 |
# |         MaxQ2Vals |           -63.6 |
# |         MinQ2Vals |            -177 |
# |            LossPi |            91.6 |
# |             LossQ |           0.804 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             788 |
# |      AverageEpRet |            -124 |
# |          StdEpRet |            38.3 |
# |          MaxEpRet |           -69.9 |
# |          MinEpRet |            -191 |
# |  AverageTestEpRet |            -104 |
# |      StdTestEpRet |            24.3 |
# |      MaxTestEpRet |             -63 |
# |      MinTestEpRet |            -139 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -91.9 |
# |         StdQ1Vals |            16.5 |
# |         MaxQ1Vals |             -63 |
# |         MinQ1Vals |            -176 |
# |     AverageQ2Vals |           -91.9 |
# |         StdQ2Vals |            16.5 |
# |         MaxQ2Vals |           -63.2 |
# |         MinQ2Vals |            -174 |
# |            LossPi |            91.6 |
# |             LossQ |           0.821 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             789 |
# |      AverageEpRet |            -107 |
# |          StdEpRet |            17.8 |
# |          MaxEpRet |           -58.4 |
# |          MinEpRet |            -133 |
# |  AverageTestEpRet |            -121 |
# |      StdTestEpRet |            28.8 |
# |      MaxTestEpRet |           -61.4 |
# |      MinTestEpRet |            -168 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -91.7 |
# |         StdQ1Vals |            16.5 |
# |         MaxQ1Vals |           -63.1 |
# |         MinQ1Vals |            -175 |
# |     AverageQ2Vals |           -91.7 |
# |         StdQ2Vals |            16.5 |
# |         MaxQ2Vals |           -63.6 |
# |         MinQ2Vals |            -176 |
# |            LossPi |            91.5 |
# |             LossQ |           0.811 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             790 |
# |      AverageEpRet |            -122 |
# |          StdEpRet |            16.5 |
# |          MaxEpRet |            -100 |
# |          MinEpRet |            -152 |
# |  AverageTestEpRet |            -107 |
# |      StdTestEpRet |              32 |
# |      MaxTestEpRet |           -52.7 |
# |      MinTestEpRet |            -144 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -91.7 |
# |         StdQ1Vals |            16.4 |
# |         MaxQ1Vals |           -63.2 |
# |         MinQ1Vals |            -178 |
# |     AverageQ2Vals |           -91.7 |
# |         StdQ2Vals |            16.4 |
# |         MaxQ2Vals |           -63.3 |
# |         MinQ2Vals |            -176 |
# |            LossPi |            91.5 |
# |             LossQ |           0.815 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             791 |
# |      AverageEpRet |            -120 |
# |          StdEpRet |            14.9 |
# |          MaxEpRet |            -102 |
# |          MinEpRet |            -154 |
# |  AverageTestEpRet |            -136 |
# |      StdTestEpRet |            42.7 |
# |      MaxTestEpRet |           -75.7 |
# |      MinTestEpRet |            -206 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -91.6 |
# |         StdQ1Vals |            16.4 |
# |         MaxQ1Vals |           -63.1 |
# |         MinQ1Vals |            -175 |
# |     AverageQ2Vals |           -91.6 |
# |         StdQ2Vals |            16.4 |
# |         MaxQ2Vals |           -63.6 |
# |         MinQ2Vals |            -176 |
# |            LossPi |            91.4 |
# |             LossQ |            0.81 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             792 |
# |      AverageEpRet |            -123 |
# |          StdEpRet |            54.7 |
# |          MaxEpRet |           -75.5 |
# |          MinEpRet |            -314 |
# |  AverageTestEpRet |           -98.8 |
# |      StdTestEpRet |            34.4 |
# |      MaxTestEpRet |           -59.9 |
# |      MinTestEpRet |            -174 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -91.5 |
# |         StdQ1Vals |            16.4 |
# |         MaxQ1Vals |           -63.3 |
# |         MinQ1Vals |            -174 |
# |     AverageQ2Vals |           -91.5 |
# |         StdQ2Vals |            16.4 |
# |         MaxQ2Vals |           -63.6 |
# |         MinQ2Vals |            -172 |
# |            LossPi |            91.3 |
# |             LossQ |           0.803 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             793 |
# |      AverageEpRet |            -109 |
# |          StdEpRet |              27 |
# |          MaxEpRet |           -61.4 |
# |          MinEpRet |            -155 |
# |  AverageTestEpRet |            -130 |
# |      StdTestEpRet |              42 |
# |      MaxTestEpRet |           -83.1 |
# |      MinTestEpRet |            -194 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -91.5 |
# |         StdQ1Vals |            16.4 |
# |         MaxQ1Vals |           -63.1 |
# |         MinQ1Vals |            -179 |
# |     AverageQ2Vals |           -91.5 |
# |         StdQ2Vals |            16.4 |
# |         MaxQ2Vals |           -63.4 |
# |         MinQ2Vals |            -176 |
# |            LossPi |            91.2 |
# |             LossQ |           0.808 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             794 |
# |      AverageEpRet |            -120 |
# |          StdEpRet |            20.9 |
# |          MaxEpRet |           -92.4 |
# |          MinEpRet |            -157 |
# |  AverageTestEpRet |            -111 |
# |      StdTestEpRet |            20.8 |
# |      MaxTestEpRet |           -76.2 |
# |      MinTestEpRet |            -145 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -91.5 |
# |         StdQ1Vals |            16.4 |
# |         MaxQ1Vals |           -63.3 |
# |         MinQ1Vals |            -176 |
# |     AverageQ2Vals |           -91.5 |
# |         StdQ2Vals |            16.4 |
# |         MaxQ2Vals |           -63.6 |
# |         MinQ2Vals |            -175 |
# |            LossPi |            91.3 |
# |             LossQ |           0.813 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             795 |
# |      AverageEpRet |            -100 |
# |          StdEpRet |            22.4 |
# |          MaxEpRet |           -61.3 |
# |          MinEpRet |            -142 |
# |  AverageTestEpRet |           -99.8 |
# |      StdTestEpRet |            16.8 |
# |      MaxTestEpRet |           -65.9 |
# |      MinTestEpRet |            -126 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -91.4 |
# |         StdQ1Vals |            16.4 |
# |         MaxQ1Vals |           -63.1 |
# |         MinQ1Vals |            -175 |
# |     AverageQ2Vals |           -91.4 |
# |         StdQ2Vals |            16.4 |
# |         MaxQ2Vals |           -63.4 |
# |         MinQ2Vals |            -175 |
# |            LossPi |            91.2 |
# |             LossQ |           0.815 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             796 |
# |      AverageEpRet |            -111 |
# |          StdEpRet |            26.8 |
# |          MaxEpRet |           -66.6 |
# |          MinEpRet |            -171 |
# |  AverageTestEpRet |            -106 |
# |      StdTestEpRet |            34.8 |
# |      MaxTestEpRet |           -43.4 |
# |      MinTestEpRet |            -155 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -91.4 |
# |         StdQ1Vals |            16.5 |
# |         MaxQ1Vals |           -62.9 |
# |         MinQ1Vals |            -173 |
# |     AverageQ2Vals |           -91.4 |
# |         StdQ2Vals |            16.5 |
# |         MaxQ2Vals |           -63.3 |
# |         MinQ2Vals |            -173 |
# |            LossPi |            91.2 |
# |             LossQ |           0.813 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             797 |
# |      AverageEpRet |            -117 |
# |          StdEpRet |            32.7 |
# |          MaxEpRet |             -81 |
# |          MinEpRet |            -179 |
# |  AverageTestEpRet |           -98.5 |
# |      StdTestEpRet |            26.1 |
# |      MaxTestEpRet |           -67.6 |
# |      MinTestEpRet |            -132 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -91.4 |
# |         StdQ1Vals |            16.4 |
# |         MaxQ1Vals |           -63.1 |
# |         MinQ1Vals |            -173 |
# |     AverageQ2Vals |           -91.4 |
# |         StdQ2Vals |            16.4 |
# |         MaxQ2Vals |           -63.4 |
# |         MinQ2Vals |            -173 |
# |            LossPi |            91.2 |
# |             LossQ |           0.821 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             798 |
# |      AverageEpRet |            -112 |
# |          StdEpRet |            18.3 |
# |          MaxEpRet |           -79.5 |
# |          MinEpRet |            -148 |
# |  AverageTestEpRet |           -98.3 |
# |      StdTestEpRet |            29.6 |
# |      MaxTestEpRet |           -45.1 |
# |      MinTestEpRet |            -144 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -91.3 |
# |         StdQ1Vals |            16.4 |
# |         MaxQ1Vals |           -63.2 |
# |         MinQ1Vals |            -173 |
# |     AverageQ2Vals |           -91.3 |
# |         StdQ2Vals |            16.4 |
# |         MaxQ2Vals |           -63.3 |
# |         MinQ2Vals |            -174 |
# |            LossPi |            91.1 |
# |             LossQ |           0.809 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             799 |
# |      AverageEpRet |            -120 |
# |          StdEpRet |            29.6 |
# |          MaxEpRet |           -80.1 |
# |          MinEpRet |            -175 |
# |  AverageTestEpRet |            -121 |
# |      StdTestEpRet |            21.1 |
# |      MaxTestEpRet |           -93.3 |
# |      MinTestEpRet |            -173 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -91.3 |
# |         StdQ1Vals |            16.5 |
# |         MaxQ1Vals |           -62.9 |
# |         MinQ1Vals |            -172 |
# |     AverageQ2Vals |           -91.3 |
# |         StdQ2Vals |            16.5 |
# |         MaxQ2Vals |           -63.2 |
# |         MinQ2Vals |            -171 |
# |            LossPi |              91 |
# |             LossQ |           0.821 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             800 |
# |      AverageEpRet |            -111 |
# |          StdEpRet |            19.7 |
# |          MaxEpRet |             -79 |
# |          MinEpRet |            -145 |
# |  AverageTestEpRet |            -119 |
# |      StdTestEpRet |            35.8 |
# |      MaxTestEpRet |           -67.3 |
# |      MinTestEpRet |            -167 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -91.2 |
# |         StdQ1Vals |            16.4 |
# |         MaxQ1Vals |             -63 |
# |         MinQ1Vals |            -174 |
# |     AverageQ2Vals |           -91.2 |
# |         StdQ2Vals |            16.4 |
# |         MaxQ2Vals |           -63.4 |
# |         MinQ2Vals |            -172 |
# |            LossPi |            91.1 |
# |             LossQ |           0.791 |
# |              Time |         1.2e+04 |
# ---------------------------------------

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it1_lr_var1', exp_name='td3_n_it1_lr_var1')
seed_b = 0
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.99
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[800], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0015
qlr_b = 0.0015

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.05

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)
# Out:
# Logging data to td3_n_it1_lr_var1/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             800
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	150,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fc9b0b23710>, env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.05, 'qx2': 0.01, 'qx4': 0.01, 'pu1': 0.5, 'pu2': 0.5}, ep_len=110)",
#     "epochs":	800,
#     "exp_name":	"td3_n_it1_lr_var1",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fc97d86f790>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_n_it1_lr_var1",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_n_it1_lr_var1",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_n_it1_lr_var1/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_n_it1_lr_var1",
#         "output_dir":	"td3_n_it1_lr_var1"
#     },
#     "max_ep_len":	110,
#     "noise_clip":	0.05,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0015,
#     "policy_delay":	2,
#     "polyak":	0.999,
#     "q_lr":	0.0015,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	20000,
#     "steps_per_epoch":	1650,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 9602, 	 q1: 10401, 	 q2: 10401
# /home/lecauchoismatthieu/drlenv/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -314 |
# |          StdEpRet |            20.4 |
# |          MaxEpRet |            -282 |
# |          MinEpRet |            -359 |
# |  AverageTestEpRet |            -213 |
# |      StdTestEpRet |            7.58 |
# |      MaxTestEpRet |            -199 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |     AverageQ1Vals |           -3.34 |
# |         StdQ1Vals |           0.562 |
# |         MaxQ1Vals |           0.213 |
# |         MinQ1Vals |           -5.49 |
# |     AverageQ2Vals |           -3.34 |
# |         StdQ2Vals |           0.555 |
# |         MaxQ2Vals |           0.179 |
# |         MinQ2Vals |           -5.49 |
# |            LossPi |            2.97 |
# |             LossQ |           0.281 |
# |              Time |            8.18 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -326 |
# |          StdEpRet |            28.3 |
# |          MaxEpRet |            -271 |
# |          MinEpRet |            -371 |
# |  AverageTestEpRet |            -215 |
# |      StdTestEpRet |            9.08 |
# |      MaxTestEpRet |            -198 |
# |      MinTestEpRet |            -227 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |     AverageQ1Vals |           -4.63 |
# |         StdQ1Vals |           0.815 |
# |         MaxQ1Vals |           -2.42 |
# |         MinQ1Vals |           -8.64 |
# |     AverageQ2Vals |           -4.63 |
# |         StdQ2Vals |           0.814 |
# |         MaxQ2Vals |            -2.4 |
# |         MinQ2Vals |           -8.61 |
# |            LossPi |            4.14 |
# |             LossQ |          0.0637 |
# |              Time |            22.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -317 |
# |          StdEpRet |            25.2 |
# |          MaxEpRet |            -278 |
# |          MinEpRet |            -374 |
# |  AverageTestEpRet |            -212 |
# |      StdTestEpRet |            8.66 |
# |      MaxTestEpRet |            -196 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |     AverageQ1Vals |            -6.3 |
# |         StdQ1Vals |           0.998 |
# |         MaxQ1Vals |           -3.42 |
# |         MinQ1Vals |           -10.9 |
# |     AverageQ2Vals |            -6.3 |
# |         StdQ2Vals |           0.998 |
# |         MaxQ2Vals |           -3.47 |
# |         MinQ2Vals |           -10.9 |
# |            LossPi |            5.75 |
# |             LossQ |          0.0584 |
# |              Time |            36.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -313 |
# |          StdEpRet |            19.5 |
# |          MaxEpRet |            -272 |
# |          MinEpRet |            -336 |
# |  AverageTestEpRet |            -210 |
# |      StdTestEpRet |            13.7 |
# |      MaxTestEpRet |            -173 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |     AverageQ1Vals |           -7.94 |
# |         StdQ1Vals |            1.16 |
# |         MaxQ1Vals |           -4.56 |
# |         MinQ1Vals |           -13.2 |
# |     AverageQ2Vals |           -7.94 |
# |         StdQ2Vals |            1.16 |
# |         MaxQ2Vals |           -4.54 |
# |         MinQ2Vals |           -13.3 |
# |            LossPi |            7.33 |
# |             LossQ |          0.0654 |
# |              Time |            50.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -320 |
# |          StdEpRet |            32.8 |
# |          MaxEpRet |            -284 |
# |          MinEpRet |            -386 |
# |  AverageTestEpRet |            -210 |
# |      StdTestEpRet |             7.4 |
# |      MaxTestEpRet |            -200 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |     AverageQ1Vals |           -9.58 |
# |         StdQ1Vals |            1.35 |
# |         MaxQ1Vals |           -5.61 |
# |         MinQ1Vals |           -15.6 |
# |     AverageQ2Vals |           -9.58 |
# |         StdQ2Vals |            1.35 |
# |         MaxQ2Vals |           -5.61 |
# |         MinQ2Vals |           -15.9 |
# |            LossPi |             8.9 |
# |             LossQ |          0.0751 |
# |              Time |            64.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -315 |
# |          StdEpRet |            27.2 |
# |          MaxEpRet |            -284 |
# |          MinEpRet |            -388 |
# |  AverageTestEpRet |            -212 |
# |      StdTestEpRet |             6.5 |
# |      MaxTestEpRet |            -198 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |     AverageQ1Vals |           -11.2 |
# |         StdQ1Vals |            1.53 |
# |         MaxQ1Vals |           -6.84 |
# |         MinQ1Vals |           -17.7 |
# |     AverageQ2Vals |           -11.2 |
# |         StdQ2Vals |            1.53 |
# |         MaxQ2Vals |           -6.86 |
# |         MinQ2Vals |           -17.8 |
# |            LossPi |            10.5 |
# |             LossQ |          0.0823 |
# |              Time |            79.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -318 |
# |          StdEpRet |            28.3 |
# |          MaxEpRet |            -282 |
# |          MinEpRet |            -380 |
# |  AverageTestEpRet |            -212 |
# |      StdTestEpRet |            6.91 |
# |      MaxTestEpRet |            -193 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |     AverageQ1Vals |           -12.8 |
# |         StdQ1Vals |            1.67 |
# |         MaxQ1Vals |           -8.08 |
# |         MinQ1Vals |           -19.8 |
# |     AverageQ2Vals |           -12.8 |
# |         StdQ2Vals |            1.67 |
# |         MaxQ2Vals |           -7.85 |
# |         MinQ2Vals |           -19.9 |
# |            LossPi |              12 |
# |             LossQ |          0.0921 |
# |              Time |            93.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -316 |
# |          StdEpRet |            30.7 |
# |          MaxEpRet |            -260 |
# |          MinEpRet |            -405 |
# |  AverageTestEpRet |            -212 |
# |      StdTestEpRet |            5.96 |
# |      MaxTestEpRet |            -202 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |     AverageQ1Vals |           -14.3 |
# |         StdQ1Vals |            1.83 |
# |         MaxQ1Vals |           -9.27 |
# |         MinQ1Vals |             -22 |
# |     AverageQ2Vals |           -14.3 |
# |         StdQ2Vals |            1.83 |
# |         MaxQ2Vals |           -9.17 |
# |         MinQ2Vals |           -22.1 |
# |            LossPi |            13.5 |
# |             LossQ |           0.103 |
# |              Time |             108 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -321 |
# |          StdEpRet |            25.8 |
# |          MaxEpRet |            -272 |
# |          MinEpRet |            -355 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            15.8 |
# |      MaxTestEpRet |            -165 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |     AverageQ1Vals |           -15.8 |
# |         StdQ1Vals |            1.95 |
# |         MaxQ1Vals |           -10.4 |
# |         MinQ1Vals |           -23.8 |
# |     AverageQ2Vals |           -15.8 |
# |         StdQ2Vals |            1.95 |
# |         MaxQ2Vals |           -10.2 |
# |         MinQ2Vals |             -24 |
# |            LossPi |            14.9 |
# |             LossQ |           0.112 |
# |              Time |             122 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -310 |
# |          StdEpRet |            23.4 |
# |          MaxEpRet |            -280 |
# |          MinEpRet |            -368 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            11.8 |
# |      MaxTestEpRet |            -182 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -17.3 |
# |         StdQ1Vals |            2.06 |
# |         MaxQ1Vals |           -11.5 |
# |         MinQ1Vals |           -25.9 |
# |     AverageQ2Vals |           -17.3 |
# |         StdQ2Vals |            2.06 |
# |         MaxQ2Vals |           -11.4 |
# |         MinQ2Vals |           -26.1 |
# |            LossPi |            16.4 |
# |             LossQ |           0.123 |
# |              Time |             136 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -317 |
# |          StdEpRet |            26.5 |
# |          MaxEpRet |            -280 |
# |          MinEpRet |            -397 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            10.6 |
# |      MaxTestEpRet |            -184 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |     AverageQ1Vals |           -18.7 |
# |         StdQ1Vals |            2.14 |
# |         MaxQ1Vals |           -12.6 |
# |         MinQ1Vals |           -27.6 |
# |     AverageQ2Vals |           -18.7 |
# |         StdQ2Vals |            2.14 |
# |         MaxQ2Vals |           -12.6 |
# |         MinQ2Vals |           -27.8 |
# |            LossPi |            17.8 |
# |             LossQ |           0.131 |
# |              Time |             151 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -318 |
# |          StdEpRet |            17.8 |
# |          MaxEpRet |            -288 |
# |          MinEpRet |            -351 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            11.2 |
# |      MaxTestEpRet |            -177 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |     AverageQ1Vals |           -20.1 |
# |         StdQ1Vals |            2.19 |
# |         MaxQ1Vals |             -14 |
# |         MinQ1Vals |           -29.1 |
# |     AverageQ2Vals |           -20.1 |
# |         StdQ2Vals |            2.19 |
# |         MaxQ2Vals |           -13.8 |
# |         MinQ2Vals |           -29.3 |
# |            LossPi |            19.1 |
# |             LossQ |           0.139 |
# |              Time |             165 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -223 |
# |          StdEpRet |            29.5 |
# |          MaxEpRet |            -200 |
# |          MinEpRet |            -311 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            8.69 |
# |      MaxTestEpRet |            -195 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |     AverageQ1Vals |           -21.4 |
# |         StdQ1Vals |             2.3 |
# |         MaxQ1Vals |           -15.1 |
# |         MinQ1Vals |           -30.6 |
# |     AverageQ2Vals |           -21.4 |
# |         StdQ2Vals |             2.3 |
# |         MaxQ2Vals |           -15.1 |
# |         MinQ2Vals |           -30.6 |
# |            LossPi |            20.4 |
# |             LossQ |           0.142 |
# |              Time |             180 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -207 |
# |          StdEpRet |            13.7 |
# |          MaxEpRet |            -171 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            10.3 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |     AverageQ1Vals |           -22.5 |
# |         StdQ1Vals |            2.45 |
# |         MaxQ1Vals |           -16.3 |
# |         MinQ1Vals |           -32.2 |
# |     AverageQ2Vals |           -22.5 |
# |         StdQ2Vals |            2.45 |
# |         MaxQ2Vals |           -16.2 |
# |         MinQ2Vals |           -32.5 |
# |            LossPi |            21.6 |
# |             LossQ |           0.137 |
# |              Time |             194 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -209 |
# |          StdEpRet |            10.3 |
# |          MaxEpRet |            -185 |
# |          MinEpRet |            -224 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            11.6 |
# |      MaxTestEpRet |            -179 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |     AverageQ1Vals |           -23.6 |
# |         StdQ1Vals |            2.58 |
# |         MaxQ1Vals |           -17.2 |
# |         MinQ1Vals |             -34 |
# |     AverageQ2Vals |           -23.6 |
# |         StdQ2Vals |            2.58 |
# |         MaxQ2Vals |           -17.3 |
# |         MinQ2Vals |             -34 |
# |            LossPi |            22.8 |
# |             LossQ |           0.133 |
# |              Time |             209 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -208 |
# |          StdEpRet |            9.83 |
# |          MaxEpRet |            -193 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            9.26 |
# |      MaxTestEpRet |            -188 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |     AverageQ1Vals |           -24.8 |
# |         StdQ1Vals |            2.66 |
# |         MaxQ1Vals |           -18.1 |
# |         MinQ1Vals |           -35.2 |
# |     AverageQ2Vals |           -24.8 |
# |         StdQ2Vals |            2.66 |
# |         MaxQ2Vals |           -18.2 |
# |         MinQ2Vals |           -35.2 |
# |            LossPi |            23.9 |
# |             LossQ |           0.131 |
# |              Time |             224 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            12.9 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |            -224 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |              11 |
# |      MaxTestEpRet |            -182 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |           -25.9 |
# |         StdQ1Vals |            2.75 |
# |         MaxQ1Vals |           -18.8 |
# |         MinQ1Vals |           -37.1 |
# |     AverageQ2Vals |           -25.9 |
# |         StdQ2Vals |            2.75 |
# |         MaxQ2Vals |           -18.8 |
# |         MinQ2Vals |           -36.9 |
# |            LossPi |            25.1 |
# |             LossQ |           0.128 |
# |              Time |             238 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            14.7 |
# |          MaxEpRet |            -167 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            9.99 |
# |      MaxTestEpRet |            -185 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |     AverageQ1Vals |           -27.1 |
# |         StdQ1Vals |            2.79 |
# |         MaxQ1Vals |           -19.9 |
# |         MinQ1Vals |           -38.5 |
# |     AverageQ2Vals |           -27.1 |
# |         StdQ2Vals |            2.79 |
# |         MaxQ2Vals |           -19.8 |
# |         MinQ2Vals |           -38.4 |
# |            LossPi |            26.3 |
# |             LossQ |           0.128 |
# |              Time |             253 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -207 |
# |          StdEpRet |            13.2 |
# |          MaxEpRet |            -175 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            5.94 |
# |      MaxTestEpRet |            -199 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |     AverageQ1Vals |           -28.2 |
# |         StdQ1Vals |            2.81 |
# |         MaxQ1Vals |             -21 |
# |         MinQ1Vals |           -39.8 |
# |     AverageQ2Vals |           -28.2 |
# |         StdQ2Vals |            2.81 |
# |         MaxQ2Vals |             -21 |
# |         MinQ2Vals |           -39.8 |
# |            LossPi |            27.5 |
# |             LossQ |           0.126 |
# |              Time |             268 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            11.5 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            9.63 |
# |      MaxTestEpRet |            -186 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -29.4 |
# |         StdQ1Vals |            2.85 |
# |         MaxQ1Vals |           -22.2 |
# |         MinQ1Vals |           -41.6 |
# |     AverageQ2Vals |           -29.4 |
# |         StdQ2Vals |            2.85 |
# |         MaxQ2Vals |           -22.1 |
# |         MinQ2Vals |           -41.9 |
# |            LossPi |            28.7 |
# |             LossQ |           0.127 |
# |              Time |             282 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -207 |
# |          StdEpRet |            12.9 |
# |          MaxEpRet |            -179 |
# |          MinEpRet |            -224 |
# |  AverageTestEpRet |            -204 |
# |      StdTestEpRet |            16.9 |
# |      MaxTestEpRet |            -157 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |     AverageQ1Vals |           -30.5 |
# |         StdQ1Vals |            2.89 |
# |         MaxQ1Vals |           -22.9 |
# |         MinQ1Vals |           -43.1 |
# |     AverageQ2Vals |           -30.5 |
# |         StdQ2Vals |            2.89 |
# |         MaxQ2Vals |           -23.2 |
# |         MinQ2Vals |           -43.2 |
# |            LossPi |            29.9 |
# |             LossQ |           0.127 |
# |              Time |             297 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -208 |
# |          StdEpRet |            13.8 |
# |          MaxEpRet |            -170 |
# |          MinEpRet |            -224 |
# |  AverageTestEpRet |            -197 |
# |      StdTestEpRet |            19.4 |
# |      MaxTestEpRet |            -151 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |     AverageQ1Vals |           -31.7 |
# |         StdQ1Vals |            2.91 |
# |         MaxQ1Vals |           -24.1 |
# |         MinQ1Vals |           -44.4 |
# |     AverageQ2Vals |           -31.7 |
# |         StdQ2Vals |            2.91 |
# |         MaxQ2Vals |           -24.2 |
# |         MinQ2Vals |             -45 |
# |            LossPi |            31.1 |
# |             LossQ |            0.13 |
# |              Time |             312 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -201 |
# |          StdEpRet |            14.5 |
# |          MaxEpRet |            -170 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |              13 |
# |      MaxTestEpRet |            -171 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |     AverageQ1Vals |           -32.9 |
# |         StdQ1Vals |            2.96 |
# |         MaxQ1Vals |             -25 |
# |         MinQ1Vals |             -46 |
# |     AverageQ2Vals |           -32.9 |
# |         StdQ2Vals |            2.96 |
# |         MaxQ2Vals |           -25.1 |
# |         MinQ2Vals |           -46.2 |
# |            LossPi |            32.2 |
# |             LossQ |            0.13 |
# |              Time |             326 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            9.39 |
# |          MaxEpRet |            -190 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            16.3 |
# |      MaxTestEpRet |            -161 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |     AverageQ1Vals |             -34 |
# |         StdQ1Vals |            2.98 |
# |         MaxQ1Vals |             -26 |
# |         MinQ1Vals |           -47.6 |
# |     AverageQ2Vals |             -34 |
# |         StdQ2Vals |            2.98 |
# |         MaxQ2Vals |             -26 |
# |         MinQ2Vals |           -47.6 |
# |            LossPi |            33.4 |
# |             LossQ |           0.131 |
# |              Time |             341 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -202 |
# |          StdEpRet |            12.3 |
# |          MaxEpRet |            -172 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -201 |
# |      StdTestEpRet |               9 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |     AverageQ1Vals |           -35.1 |
# |         StdQ1Vals |            3.03 |
# |         MaxQ1Vals |             -27 |
# |         MinQ1Vals |           -48.8 |
# |     AverageQ2Vals |           -35.1 |
# |         StdQ2Vals |            3.03 |
# |         MaxQ2Vals |           -26.9 |
# |         MinQ2Vals |           -48.8 |
# |            LossPi |            34.6 |
# |             LossQ |           0.134 |
# |              Time |             356 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            12.9 |
# |          MaxEpRet |            -175 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            8.28 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |     AverageQ1Vals |           -36.3 |
# |         StdQ1Vals |            3.08 |
# |         MaxQ1Vals |             -28 |
# |         MinQ1Vals |           -50.5 |
# |     AverageQ2Vals |           -36.3 |
# |         StdQ2Vals |            3.08 |
# |         MaxQ2Vals |             -28 |
# |         MinQ2Vals |           -50.5 |
# |            LossPi |            35.7 |
# |             LossQ |           0.136 |
# |              Time |             370 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            15.9 |
# |          MaxEpRet |            -163 |
# |          MinEpRet |            -214 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            14.7 |
# |      MaxTestEpRet |            -166 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |     AverageQ1Vals |           -37.4 |
# |         StdQ1Vals |            3.11 |
# |         MaxQ1Vals |           -28.8 |
# |         MinQ1Vals |           -51.7 |
# |     AverageQ2Vals |           -37.4 |
# |         StdQ2Vals |            3.11 |
# |         MaxQ2Vals |           -28.8 |
# |         MinQ2Vals |           -51.8 |
# |            LossPi |            36.9 |
# |             LossQ |           0.139 |
# |              Time |             385 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            19.9 |
# |          MaxEpRet |            -151 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -199 |
# |      StdTestEpRet |            11.7 |
# |      MaxTestEpRet |            -167 |
# |      MinTestEpRet |            -212 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |     AverageQ1Vals |           -38.5 |
# |         StdQ1Vals |            3.18 |
# |         MaxQ1Vals |           -29.9 |
# |         MinQ1Vals |           -52.9 |
# |     AverageQ2Vals |           -38.5 |
# |         StdQ2Vals |            3.19 |
# |         MaxQ2Vals |           -29.8 |
# |         MinQ2Vals |             -53 |
# |            LossPi |              38 |
# |             LossQ |           0.141 |
# |              Time |             400 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -201 |
# |          StdEpRet |            15.8 |
# |          MaxEpRet |            -161 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |            10.1 |
# |      MaxTestEpRet |            -187 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |     AverageQ1Vals |           -39.6 |
# |         StdQ1Vals |            3.24 |
# |         MaxQ1Vals |           -30.7 |
# |         MinQ1Vals |           -54.7 |
# |     AverageQ2Vals |           -39.6 |
# |         StdQ2Vals |            3.24 |
# |         MaxQ2Vals |           -30.6 |
# |         MinQ2Vals |           -54.2 |
# |            LossPi |            39.1 |
# |             LossQ |           0.146 |
# |              Time |             415 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            13.8 |
# |          MaxEpRet |            -161 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -199 |
# |      StdTestEpRet |            16.7 |
# |      MaxTestEpRet |            -157 |
# |      MinTestEpRet |            -212 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -40.7 |
# |         StdQ1Vals |            3.29 |
# |         MaxQ1Vals |           -31.4 |
# |         MinQ1Vals |           -55.8 |
# |     AverageQ2Vals |           -40.7 |
# |         StdQ2Vals |            3.29 |
# |         MaxQ2Vals |           -31.4 |
# |         MinQ2Vals |           -55.4 |
# |            LossPi |            40.2 |
# |             LossQ |           0.149 |
# |              Time |             429 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            11.5 |
# |          MaxEpRet |            -177 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |             6.4 |
# |      MaxTestEpRet |            -193 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |     AverageQ1Vals |           -41.8 |
# |         StdQ1Vals |            3.34 |
# |         MaxQ1Vals |           -32.4 |
# |         MinQ1Vals |           -57.7 |
# |     AverageQ2Vals |           -41.8 |
# |         StdQ2Vals |            3.34 |
# |         MaxQ2Vals |           -32.4 |
# |         MinQ2Vals |           -57.3 |
# |            LossPi |            41.3 |
# |             LossQ |           0.152 |
# |              Time |             444 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            9.56 |
# |          MaxEpRet |            -185 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -201 |
# |      StdTestEpRet |              15 |
# |      MaxTestEpRet |            -177 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |     AverageQ1Vals |           -42.9 |
# |         StdQ1Vals |            3.38 |
# |         MaxQ1Vals |           -33.3 |
# |         MinQ1Vals |           -58.5 |
# |     AverageQ2Vals |           -42.9 |
# |         StdQ2Vals |            3.38 |
# |         MaxQ2Vals |           -33.2 |
# |         MinQ2Vals |           -58.4 |
# |            LossPi |            42.4 |
# |             LossQ |           0.156 |
# |              Time |             459 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            15.7 |
# |          MaxEpRet |            -157 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            16.5 |
# |      MaxTestEpRet |            -161 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |     AverageQ1Vals |             -44 |
# |         StdQ1Vals |            3.41 |
# |         MaxQ1Vals |           -34.3 |
# |         MinQ1Vals |             -60 |
# |     AverageQ2Vals |             -44 |
# |         StdQ2Vals |            3.41 |
# |         MaxQ2Vals |           -34.1 |
# |         MinQ2Vals |           -59.6 |
# |            LossPi |            43.5 |
# |             LossQ |           0.161 |
# |              Time |             474 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            18.1 |
# |          MaxEpRet |            -162 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |            9.88 |
# |      MaxTestEpRet |            -177 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |     AverageQ1Vals |           -45.1 |
# |         StdQ1Vals |            3.47 |
# |         MaxQ1Vals |           -35.2 |
# |         MinQ1Vals |           -61.3 |
# |     AverageQ2Vals |           -45.1 |
# |         StdQ2Vals |            3.47 |
# |         MaxQ2Vals |             -35 |
# |         MinQ2Vals |           -61.1 |
# |            LossPi |            44.7 |
# |             LossQ |           0.164 |
# |              Time |             489 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            13.9 |
# |          MaxEpRet |            -169 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -197 |
# |      StdTestEpRet |            15.3 |
# |      MaxTestEpRet |            -166 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |     AverageQ1Vals |           -46.2 |
# |         StdQ1Vals |            3.53 |
# |         MaxQ1Vals |             -36 |
# |         MinQ1Vals |           -62.6 |
# |     AverageQ2Vals |           -46.2 |
# |         StdQ2Vals |            3.53 |
# |         MaxQ2Vals |           -36.1 |
# |         MinQ2Vals |           -62.5 |
# |            LossPi |            45.7 |
# |             LossQ |           0.172 |
# |              Time |             504 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -201 |
# |          StdEpRet |            14.8 |
# |          MaxEpRet |            -166 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -200 |
# |      StdTestEpRet |            10.4 |
# |      MaxTestEpRet |            -183 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |     AverageQ1Vals |           -47.2 |
# |         StdQ1Vals |            3.57 |
# |         MaxQ1Vals |           -36.9 |
# |         MinQ1Vals |           -63.9 |
# |     AverageQ2Vals |           -47.2 |
# |         StdQ2Vals |            3.57 |
# |         MaxQ2Vals |           -36.8 |
# |         MinQ2Vals |           -63.9 |
# |            LossPi |            46.8 |
# |             LossQ |           0.177 |
# |              Time |             518 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -204 |
# |          StdEpRet |            14.9 |
# |          MaxEpRet |            -172 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -182 |
# |      StdTestEpRet |            14.6 |
# |      MaxTestEpRet |            -158 |
# |      MinTestEpRet |            -204 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |     AverageQ1Vals |           -48.3 |
# |         StdQ1Vals |            3.63 |
# |         MaxQ1Vals |           -38.1 |
# |         MinQ1Vals |           -64.2 |
# |     AverageQ2Vals |           -48.3 |
# |         StdQ2Vals |            3.63 |
# |         MaxQ2Vals |             -38 |
# |         MinQ2Vals |           -64.8 |
# |            LossPi |            47.9 |
# |             LossQ |           0.181 |
# |              Time |             533 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -201 |
# |          StdEpRet |            14.2 |
# |          MaxEpRet |            -162 |
# |          MinEpRet |            -224 |
# |  AverageTestEpRet |            -181 |
# |      StdTestEpRet |            22.8 |
# |      MaxTestEpRet |            -148 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |     AverageQ1Vals |           -49.4 |
# |         StdQ1Vals |            3.68 |
# |         MaxQ1Vals |           -38.8 |
# |         MinQ1Vals |           -66.1 |
# |     AverageQ2Vals |           -49.4 |
# |         StdQ2Vals |            3.68 |
# |         MaxQ2Vals |           -38.8 |
# |         MinQ2Vals |           -66.1 |
# |            LossPi |            48.9 |
# |             LossQ |           0.184 |
# |              Time |             548 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -197 |
# |          StdEpRet |            14.2 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -197 |
# |      StdTestEpRet |            14.4 |
# |      MaxTestEpRet |            -157 |
# |      MinTestEpRet |            -211 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |     AverageQ1Vals |           -50.4 |
# |         StdQ1Vals |            3.75 |
# |         MaxQ1Vals |           -39.6 |
# |         MinQ1Vals |           -66.9 |
# |     AverageQ2Vals |           -50.4 |
# |         StdQ2Vals |            3.75 |
# |         MaxQ2Vals |           -39.8 |
# |         MinQ2Vals |           -67.2 |
# |            LossPi |              50 |
# |             LossQ |           0.189 |
# |              Time |             563 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -189 |
# |          StdEpRet |            21.4 |
# |          MaxEpRet |            -135 |
# |          MinEpRet |            -214 |
# |  AverageTestEpRet |            -197 |
# |      StdTestEpRet |            12.1 |
# |      MaxTestEpRet |            -177 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -51.4 |
# |         StdQ1Vals |            3.79 |
# |         MaxQ1Vals |           -40.6 |
# |         MinQ1Vals |             -68 |
# |     AverageQ2Vals |           -51.4 |
# |         StdQ2Vals |            3.79 |
# |         MaxQ2Vals |           -40.5 |
# |         MinQ2Vals |           -68.3 |
# |            LossPi |              51 |
# |             LossQ |           0.194 |
# |              Time |             577 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -192 |
# |          StdEpRet |            15.3 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |            -211 |
# |  AverageTestEpRet |            -195 |
# |      StdTestEpRet |            12.9 |
# |      MaxTestEpRet |            -166 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |     AverageQ1Vals |           -52.4 |
# |         StdQ1Vals |            3.86 |
# |         MaxQ1Vals |           -41.6 |
# |         MinQ1Vals |           -69.5 |
# |     AverageQ2Vals |           -52.4 |
# |         StdQ2Vals |            3.86 |
# |         MaxQ2Vals |           -41.6 |
# |         MinQ2Vals |           -69.3 |
# |            LossPi |              52 |
# |             LossQ |           0.201 |
# |              Time |             592 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -192 |
# |          StdEpRet |            16.9 |
# |          MaxEpRet |            -151 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -183 |
# |      StdTestEpRet |            15.5 |
# |      MaxTestEpRet |            -156 |
# |      MinTestEpRet |            -205 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |     AverageQ1Vals |           -53.4 |
# |         StdQ1Vals |            3.93 |
# |         MaxQ1Vals |           -42.3 |
# |         MinQ1Vals |           -70.9 |
# |     AverageQ2Vals |           -53.4 |
# |         StdQ2Vals |            3.93 |
# |         MaxQ2Vals |           -42.4 |
# |         MinQ2Vals |             -71 |
# |            LossPi |              53 |
# |             LossQ |           0.206 |
# |              Time |             607 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -200 |
# |          StdEpRet |            11.2 |
# |          MaxEpRet |            -177 |
# |          MinEpRet |            -215 |
# |  AverageTestEpRet |            -199 |
# |      StdTestEpRet |              15 |
# |      MaxTestEpRet |            -174 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |     AverageQ1Vals |           -54.4 |
# |         StdQ1Vals |            3.99 |
# |         MaxQ1Vals |           -43.2 |
# |         MinQ1Vals |           -71.7 |
# |     AverageQ2Vals |           -54.4 |
# |         StdQ2Vals |            3.99 |
# |         MaxQ2Vals |           -43.4 |
# |         MinQ2Vals |           -71.7 |
# |            LossPi |              54 |
# |             LossQ |           0.208 |
# |              Time |             621 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            17.6 |
# |          MaxEpRet |            -157 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -185 |
# |      StdTestEpRet |            28.1 |
# |      MaxTestEpRet |            -132 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |     AverageQ1Vals |           -55.4 |
# |         StdQ1Vals |            4.05 |
# |         MaxQ1Vals |             -44 |
# |         MinQ1Vals |           -73.8 |
# |     AverageQ2Vals |           -55.4 |
# |         StdQ2Vals |            4.05 |
# |         MaxQ2Vals |             -44 |
# |         MinQ2Vals |           -74.1 |
# |            LossPi |              55 |
# |             LossQ |           0.215 |
# |              Time |             636 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -194 |
# |          StdEpRet |              11 |
# |          MaxEpRet |            -170 |
# |          MinEpRet |            -209 |
# |  AverageTestEpRet |            -204 |
# |      StdTestEpRet |            13.9 |
# |      MaxTestEpRet |            -177 |
# |      MinTestEpRet |            -226 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |     AverageQ1Vals |           -56.3 |
# |         StdQ1Vals |             4.1 |
# |         MaxQ1Vals |           -44.9 |
# |         MinQ1Vals |           -74.5 |
# |     AverageQ2Vals |           -56.3 |
# |         StdQ2Vals |             4.1 |
# |         MaxQ2Vals |           -44.9 |
# |         MinQ2Vals |           -74.9 |
# |            LossPi |            55.9 |
# |             LossQ |           0.222 |
# |              Time |             651 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -188 |
# |          StdEpRet |            23.3 |
# |          MaxEpRet |            -127 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -195 |
# |      StdTestEpRet |             8.5 |
# |      MaxTestEpRet |            -183 |
# |      MinTestEpRet |            -208 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |     AverageQ1Vals |           -57.3 |
# |         StdQ1Vals |            4.17 |
# |         MaxQ1Vals |           -45.6 |
# |         MinQ1Vals |           -75.6 |
# |     AverageQ2Vals |           -57.3 |
# |         StdQ2Vals |            4.17 |
# |         MaxQ2Vals |           -45.9 |
# |         MinQ2Vals |           -75.5 |
# |            LossPi |            56.9 |
# |             LossQ |           0.225 |
# |              Time |             666 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -193 |
# |          StdEpRet |            20.3 |
# ...
# ---------------------------------------
# |             Epoch |             785 |
# |      AverageEpRet |            -106 |
# |          StdEpRet |            23.9 |
# |          MaxEpRet |           -70.7 |
# |          MinEpRet |            -169 |
# |  AverageTestEpRet |            -115 |
# |      StdTestEpRet |            44.1 |
# |      MaxTestEpRet |           -42.9 |
# |      MinTestEpRet |            -179 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -84.8 |
# |         StdQ1Vals |            15.4 |
# |         MaxQ1Vals |           -54.2 |
# |         MinQ1Vals |            -165 |
# |     AverageQ2Vals |           -84.8 |
# |         StdQ2Vals |            15.4 |
# |         MaxQ2Vals |           -54.3 |
# |         MinQ2Vals |            -167 |
# |            LossPi |            84.7 |
# |             LossQ |           0.897 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             786 |
# |      AverageEpRet |            -124 |
# |          StdEpRet |            27.7 |
# |          MaxEpRet |             -79 |
# |          MinEpRet |            -184 |
# |  AverageTestEpRet |           -84.7 |
# |      StdTestEpRet |              30 |
# |      MaxTestEpRet |           -43.7 |
# |      MinTestEpRet |            -156 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -84.8 |
# |         StdQ1Vals |            15.4 |
# |         MaxQ1Vals |           -54.4 |
# |         MinQ1Vals |            -171 |
# |     AverageQ2Vals |           -84.8 |
# |         StdQ2Vals |            15.4 |
# |         MaxQ2Vals |           -54.5 |
# |         MinQ2Vals |            -169 |
# |            LossPi |            84.6 |
# |             LossQ |            0.89 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             787 |
# |      AverageEpRet |            -107 |
# |          StdEpRet |            23.4 |
# |          MaxEpRet |           -67.2 |
# |          MinEpRet |            -162 |
# |  AverageTestEpRet |            -106 |
# |      StdTestEpRet |            29.4 |
# |      MaxTestEpRet |           -66.5 |
# |      MinTestEpRet |            -157 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -84.7 |
# |         StdQ1Vals |            15.4 |
# |         MaxQ1Vals |           -54.2 |
# |         MinQ1Vals |            -172 |
# |     AverageQ2Vals |           -84.7 |
# |         StdQ2Vals |            15.4 |
# |         MaxQ2Vals |           -54.3 |
# |         MinQ2Vals |            -171 |
# |            LossPi |            84.5 |
# |             LossQ |           0.889 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             788 |
# |      AverageEpRet |           -99.5 |
# |          StdEpRet |            16.3 |
# |          MaxEpRet |           -71.1 |
# |          MinEpRet |            -131 |
# |  AverageTestEpRet |           -78.1 |
# |      StdTestEpRet |              18 |
# |      MaxTestEpRet |           -42.7 |
# |      MinTestEpRet |            -101 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -84.7 |
# |         StdQ1Vals |            15.4 |
# |         MaxQ1Vals |           -54.2 |
# |         MinQ1Vals |            -170 |
# |     AverageQ2Vals |           -84.7 |
# |         StdQ2Vals |            15.4 |
# |         MaxQ2Vals |           -54.2 |
# |         MinQ2Vals |            -168 |
# |            LossPi |            84.6 |
# |             LossQ |            0.88 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             789 |
# |      AverageEpRet |            -105 |
# |          StdEpRet |            17.9 |
# |          MaxEpRet |           -61.9 |
# |          MinEpRet |            -139 |
# |  AverageTestEpRet |           -97.7 |
# |      StdTestEpRet |            23.7 |
# |      MaxTestEpRet |           -45.6 |
# |      MinTestEpRet |            -142 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -84.6 |
# |         StdQ1Vals |            15.3 |
# |         MaxQ1Vals |           -54.1 |
# |         MinQ1Vals |            -170 |
# |     AverageQ2Vals |           -84.6 |
# |         StdQ2Vals |            15.3 |
# |         MaxQ2Vals |           -54.2 |
# |         MinQ2Vals |            -170 |
# |            LossPi |            84.4 |
# |             LossQ |           0.874 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             790 |
# |      AverageEpRet |            -108 |
# |          StdEpRet |            23.5 |
# |          MaxEpRet |           -73.5 |
# |          MinEpRet |            -145 |
# |  AverageTestEpRet |            -110 |
# |      StdTestEpRet |            37.1 |
# |      MaxTestEpRet |             -65 |
# |      MinTestEpRet |            -209 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -84.6 |
# |         StdQ1Vals |            15.3 |
# |         MaxQ1Vals |           -54.4 |
# |         MinQ1Vals |            -167 |
# |     AverageQ2Vals |           -84.6 |
# |         StdQ2Vals |            15.3 |
# |         MaxQ2Vals |           -54.2 |
# |         MinQ2Vals |            -166 |
# |            LossPi |            84.4 |
# |             LossQ |            0.87 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             791 |
# |      AverageEpRet |            -103 |
# |          StdEpRet |            22.5 |
# |          MaxEpRet |           -64.8 |
# |          MinEpRet |            -141 |
# |  AverageTestEpRet |             -89 |
# |      StdTestEpRet |            20.6 |
# |      MaxTestEpRet |           -58.6 |
# |      MinTestEpRet |            -118 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -84.6 |
# |         StdQ1Vals |            15.3 |
# |         MaxQ1Vals |           -54.2 |
# |         MinQ1Vals |            -170 |
# |     AverageQ2Vals |           -84.6 |
# |         StdQ2Vals |            15.3 |
# |         MaxQ2Vals |           -54.4 |
# |         MinQ2Vals |            -170 |
# |            LossPi |            84.4 |
# |             LossQ |           0.883 |
# |              Time |        1.21e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             792 |
# |      AverageEpRet |            -103 |
# |          StdEpRet |            19.7 |
# |          MaxEpRet |             -78 |
# |          MinEpRet |            -144 |
# |  AverageTestEpRet |           -98.5 |
# |      StdTestEpRet |            24.2 |
# |      MaxTestEpRet |           -38.2 |
# |      MinTestEpRet |            -125 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -84.6 |
# |         StdQ1Vals |            15.4 |
# |         MaxQ1Vals |             -54 |
# |         MinQ1Vals |            -170 |
# |     AverageQ2Vals |           -84.6 |
# |         StdQ2Vals |            15.4 |
# |         MaxQ2Vals |           -54.2 |
# |         MinQ2Vals |            -171 |
# |            LossPi |            84.4 |
# |             LossQ |           0.875 |
# |              Time |        1.21e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             793 |
# |      AverageEpRet |            -118 |
# |          StdEpRet |            26.1 |
# |          MaxEpRet |           -74.8 |
# |          MinEpRet |            -181 |
# |  AverageTestEpRet |            -118 |
# |      StdTestEpRet |              32 |
# |      MaxTestEpRet |           -76.4 |
# |      MinTestEpRet |            -176 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -84.5 |
# |         StdQ1Vals |            15.3 |
# |         MaxQ1Vals |           -54.1 |
# |         MinQ1Vals |            -167 |
# |     AverageQ2Vals |           -84.5 |
# |         StdQ2Vals |            15.3 |
# |         MaxQ2Vals |           -54.2 |
# |         MinQ2Vals |            -167 |
# |            LossPi |            84.2 |
# |             LossQ |           0.893 |
# |              Time |        1.21e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             794 |
# |      AverageEpRet |            -103 |
# |          StdEpRet |            18.2 |
# |          MaxEpRet |           -76.5 |
# |          MinEpRet |            -141 |
# |  AverageTestEpRet |            -120 |
# |      StdTestEpRet |            23.5 |
# |      MaxTestEpRet |           -69.8 |
# |      MinTestEpRet |            -157 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -84.5 |
# |         StdQ1Vals |            15.3 |
# |         MaxQ1Vals |           -53.7 |
# |         MinQ1Vals |            -170 |
# |     AverageQ2Vals |           -84.5 |
# |         StdQ2Vals |            15.3 |
# |         MaxQ2Vals |           -53.9 |
# |         MinQ2Vals |            -168 |
# |            LossPi |            84.3 |
# |             LossQ |           0.879 |
# |              Time |        1.21e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             795 |
# |      AverageEpRet |            -109 |
# |          StdEpRet |            20.9 |
# |          MaxEpRet |           -62.8 |
# |          MinEpRet |            -136 |
# |  AverageTestEpRet |            -108 |
# |      StdTestEpRet |              39 |
# |      MaxTestEpRet |             -25 |
# |      MinTestEpRet |            -181 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -84.4 |
# |         StdQ1Vals |            15.3 |
# |         MaxQ1Vals |           -53.9 |
# |         MinQ1Vals |            -169 |
# |     AverageQ2Vals |           -84.4 |
# |         StdQ2Vals |            15.3 |
# |         MaxQ2Vals |             -54 |
# |         MinQ2Vals |            -171 |
# |            LossPi |            84.3 |
# |             LossQ |           0.879 |
# |              Time |        1.21e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             796 |
# |      AverageEpRet |            -105 |
# |          StdEpRet |            20.6 |
# |          MaxEpRet |           -68.2 |
# |          MinEpRet |            -137 |
# |  AverageTestEpRet |           -96.1 |
# |      StdTestEpRet |            35.6 |
# |      MaxTestEpRet |           -43.1 |
# |      MinTestEpRet |            -171 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -84.4 |
# |         StdQ1Vals |            15.3 |
# |         MaxQ1Vals |           -54.1 |
# |         MinQ1Vals |            -173 |
# |     AverageQ2Vals |           -84.4 |
# |         StdQ2Vals |            15.3 |
# |         MaxQ2Vals |           -54.1 |
# |         MinQ2Vals |            -173 |
# |            LossPi |            84.1 |
# |             LossQ |           0.874 |
# |              Time |        1.21e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             797 |
# |      AverageEpRet |            -108 |
# |          StdEpRet |            17.8 |
# |          MaxEpRet |           -69.7 |
# |          MinEpRet |            -137 |
# |  AverageTestEpRet |            -108 |
# |      StdTestEpRet |            29.2 |
# |      MaxTestEpRet |           -57.3 |
# |      MinTestEpRet |            -148 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -84.4 |
# |         StdQ1Vals |            15.3 |
# |         MaxQ1Vals |           -54.1 |
# |         MinQ1Vals |            -170 |
# |     AverageQ2Vals |           -84.4 |
# |         StdQ2Vals |            15.3 |
# |         MaxQ2Vals |           -54.1 |
# |         MinQ2Vals |            -171 |
# |            LossPi |            84.1 |
# |             LossQ |            0.86 |
# |              Time |        1.21e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             798 |
# |      AverageEpRet |            -110 |
# |          StdEpRet |            27.8 |
# |          MaxEpRet |             -73 |
# |          MinEpRet |            -199 |
# |  AverageTestEpRet |            -111 |
# |      StdTestEpRet |            20.1 |
# |      MaxTestEpRet |           -85.7 |
# |      MinTestEpRet |            -147 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -84.3 |
# |         StdQ1Vals |            15.3 |
# |         MaxQ1Vals |           -53.8 |
# |         MinQ1Vals |            -169 |
# |     AverageQ2Vals |           -84.3 |
# |         StdQ2Vals |            15.3 |
# |         MaxQ2Vals |           -53.7 |
# |         MinQ2Vals |            -168 |
# |            LossPi |            84.1 |
# |             LossQ |           0.868 |
# |              Time |        1.22e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             799 |
# |      AverageEpRet |            -112 |
# |          StdEpRet |            28.5 |
# |          MaxEpRet |           -78.5 |
# |          MinEpRet |            -179 |
# |  AverageTestEpRet |            -104 |
# |      StdTestEpRet |              20 |
# |      MaxTestEpRet |           -58.2 |
# |      MinTestEpRet |            -142 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -84.2 |
# |         StdQ1Vals |            15.3 |
# |         MaxQ1Vals |           -54.1 |
# |         MinQ1Vals |            -166 |
# |     AverageQ2Vals |           -84.2 |
# |         StdQ2Vals |            15.3 |
# |         MaxQ2Vals |           -54.1 |
# |         MinQ2Vals |            -167 |
# |            LossPi |              84 |
# |             LossQ |           0.878 |
# |              Time |        1.22e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             800 |
# |      AverageEpRet |            -111 |
# |          StdEpRet |            32.2 |
# |          MaxEpRet |           -69.2 |
# |          MinEpRet |            -181 |
# |  AverageTestEpRet |            -114 |
# |      StdTestEpRet |            30.9 |
# |      MaxTestEpRet |           -68.2 |
# |      MinTestEpRet |            -166 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -84.2 |
# |         StdQ1Vals |            15.3 |
# |         MaxQ1Vals |           -53.9 |
# |         MinQ1Vals |            -171 |
# |     AverageQ2Vals |           -84.2 |
# |         StdQ2Vals |            15.3 |
# |         MaxQ2Vals |           -54.1 |
# |         MinQ2Vals |            -166 |
# |            LossPi |              84 |
# |             LossQ |           0.874 |
# |              Time |        1.22e+04 |
# ---------------------------------------

# %% [markdown]
# #### Hidden layers

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it1_hid_var0', exp_name='td3_n_it1_hid_var0')
seed_b = 0
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.99
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[700], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.001
qlr_b = 0.001

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.05

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)
# Out:
# Logging data to td3_n_it1_hid_var0/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             700
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	150,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fc9b0b23710>, env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.05, 'qx2': 0.01, 'qx4': 0.01, 'pu1': 0.5, 'pu2': 0.5}, ep_len=110)",
#     "epochs":	800,
#     "exp_name":	"td3_n_it1_hid_var0",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fc97c338410>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_n_it1_hid_var0",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_n_it1_hid_var0",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_n_it1_hid_var0/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_n_it1_hid_var0",
#         "output_dir":	"td3_n_it1_hid_var0"
#     },
#     "max_ep_len":	110,
#     "noise_clip":	0.05,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.999,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	20000,
#     "steps_per_epoch":	1650,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 8402, 	 q1: 9101, 	 q2: 9101
# /home/lecauchoismatthieu/drlenv/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -303 |
# |          StdEpRet |            11.4 |
# |          MaxEpRet |            -289 |
# |          MinEpRet |            -325 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            12.5 |
# |      MaxTestEpRet |            -179 |
# |      MinTestEpRet |            -226 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |     AverageQ1Vals |           -3.18 |
# |         StdQ1Vals |           0.569 |
# |         MaxQ1Vals |           0.245 |
# |         MinQ1Vals |            -5.2 |
# |     AverageQ2Vals |           -3.18 |
# |         StdQ2Vals |           0.575 |
# |         MaxQ2Vals |           0.309 |
# |         MinQ2Vals |           -5.29 |
# |            LossPi |            2.85 |
# |             LossQ |           0.379 |
# |              Time |            8.31 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -323 |
# |          StdEpRet |            19.4 |
# |          MaxEpRet |            -286 |
# |          MinEpRet |            -351 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            15.7 |
# |      MaxTestEpRet |            -165 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |     AverageQ1Vals |           -4.48 |
# |         StdQ1Vals |           0.772 |
# |         MaxQ1Vals |           -2.37 |
# |         MinQ1Vals |           -8.31 |
# |     AverageQ2Vals |           -4.48 |
# |         StdQ2Vals |           0.772 |
# |         MaxQ2Vals |           -2.39 |
# |         MinQ2Vals |           -8.34 |
# |            LossPi |            4.02 |
# |             LossQ |          0.0875 |
# |              Time |            22.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -313 |
# |          StdEpRet |              23 |
# |          MaxEpRet |            -287 |
# |          MinEpRet |            -367 |
# |  AverageTestEpRet |            -212 |
# |      StdTestEpRet |             8.8 |
# |      MaxTestEpRet |            -193 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |     AverageQ1Vals |           -6.08 |
# |         StdQ1Vals |           0.916 |
# |         MaxQ1Vals |           -3.24 |
# |         MinQ1Vals |           -10.5 |
# |     AverageQ2Vals |           -6.08 |
# |         StdQ2Vals |           0.916 |
# |         MaxQ2Vals |           -3.32 |
# |         MinQ2Vals |           -10.6 |
# |            LossPi |            5.56 |
# |             LossQ |          0.0754 |
# |              Time |            36.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -317 |
# |          StdEpRet |            31.4 |
# |          MaxEpRet |            -285 |
# |          MinEpRet |            -385 |
# |  AverageTestEpRet |            -212 |
# |      StdTestEpRet |            10.5 |
# |      MaxTestEpRet |            -191 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |     AverageQ1Vals |           -7.76 |
# |         StdQ1Vals |            1.13 |
# |         MaxQ1Vals |           -4.48 |
# |         MinQ1Vals |             -13 |
# |     AverageQ2Vals |           -7.76 |
# |         StdQ2Vals |            1.13 |
# |         MaxQ2Vals |           -4.46 |
# |         MinQ2Vals |           -12.9 |
# |            LossPi |            7.18 |
# |             LossQ |          0.0785 |
# |              Time |            50.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -318 |
# |          StdEpRet |            25.8 |
# |          MaxEpRet |            -268 |
# |          MinEpRet |            -358 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            10.1 |
# |      MaxTestEpRet |            -195 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |     AverageQ1Vals |           -9.41 |
# |         StdQ1Vals |            1.32 |
# |         MaxQ1Vals |           -5.77 |
# |         MinQ1Vals |           -15.3 |
# |     AverageQ2Vals |           -9.41 |
# |         StdQ2Vals |            1.32 |
# |         MaxQ2Vals |           -5.76 |
# |         MinQ2Vals |           -15.4 |
# |            LossPi |            8.77 |
# |             LossQ |          0.0793 |
# |              Time |            64.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -329 |
# |          StdEpRet |            27.9 |
# |          MaxEpRet |            -286 |
# |          MinEpRet |            -378 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            9.42 |
# |      MaxTestEpRet |            -191 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |     AverageQ1Vals |           -11.1 |
# |         StdQ1Vals |            1.51 |
# |         MaxQ1Vals |           -6.92 |
# |         MinQ1Vals |           -17.4 |
# |     AverageQ2Vals |           -11.1 |
# |         StdQ2Vals |            1.51 |
# |         MaxQ2Vals |           -6.95 |
# |         MinQ2Vals |           -17.6 |
# |            LossPi |            10.4 |
# |             LossQ |          0.0869 |
# |              Time |            79.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -314 |
# |          StdEpRet |            24.9 |
# |          MaxEpRet |            -281 |
# |          MinEpRet |            -363 |
# |  AverageTestEpRet |            -210 |
# |      StdTestEpRet |            10.2 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |     AverageQ1Vals |           -12.8 |
# |         StdQ1Vals |            1.69 |
# |         MaxQ1Vals |            -8.2 |
# |         MinQ1Vals |           -19.3 |
# |     AverageQ2Vals |           -12.8 |
# |         StdQ2Vals |            1.69 |
# |         MaxQ2Vals |           -8.32 |
# |         MinQ2Vals |           -19.6 |
# |            LossPi |              12 |
# |             LossQ |          0.0924 |
# |              Time |            93.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -315 |
# |          StdEpRet |            27.2 |
# |          MaxEpRet |            -288 |
# |          MinEpRet |            -386 |
# |  AverageTestEpRet |            -216 |
# |      StdTestEpRet |            3.04 |
# |      MaxTestEpRet |            -211 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |     AverageQ1Vals |           -14.3 |
# |         StdQ1Vals |            1.84 |
# |         MaxQ1Vals |           -9.52 |
# |         MinQ1Vals |           -22.1 |
# |     AverageQ2Vals |           -14.3 |
# |         StdQ2Vals |            1.84 |
# |         MaxQ2Vals |           -9.59 |
# |         MinQ2Vals |           -21.8 |
# |            LossPi |            13.5 |
# |             LossQ |             0.1 |
# |              Time |             107 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -316 |
# |          StdEpRet |            19.9 |
# |          MaxEpRet |            -286 |
# |          MinEpRet |            -356 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |            12.1 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |            -224 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |     AverageQ1Vals |           -15.8 |
# |         StdQ1Vals |            1.96 |
# |         MaxQ1Vals |           -10.6 |
# |         MinQ1Vals |           -24.1 |
# |     AverageQ2Vals |           -15.8 |
# |         StdQ2Vals |            1.96 |
# |         MaxQ2Vals |           -10.7 |
# |         MinQ2Vals |           -23.9 |
# |            LossPi |            14.9 |
# |             LossQ |            0.11 |
# |              Time |             121 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -331 |
# |          StdEpRet |            29.5 |
# |          MaxEpRet |            -286 |
# |          MinEpRet |            -396 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |            11.3 |
# |      MaxTestEpRet |            -188 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -17.3 |
# |         StdQ1Vals |            2.07 |
# |         MaxQ1Vals |           -11.8 |
# |         MinQ1Vals |           -25.9 |
# |     AverageQ2Vals |           -17.3 |
# |         StdQ2Vals |            2.07 |
# |         MaxQ2Vals |           -11.8 |
# |         MinQ2Vals |             -26 |
# |            LossPi |            16.3 |
# |             LossQ |           0.121 |
# |              Time |             135 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -335 |
# |          StdEpRet |            33.4 |
# |          MaxEpRet |            -286 |
# |          MinEpRet |            -398 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |            10.8 |
# |      MaxTestEpRet |            -191 |
# |      MinTestEpRet |            -224 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |     AverageQ1Vals |           -18.8 |
# |         StdQ1Vals |            2.22 |
# |         MaxQ1Vals |           -13.1 |
# |         MinQ1Vals |           -27.8 |
# |     AverageQ2Vals |           -18.8 |
# |         StdQ2Vals |            2.22 |
# |         MaxQ2Vals |             -13 |
# |         MinQ2Vals |           -27.9 |
# |            LossPi |            17.8 |
# |             LossQ |           0.134 |
# |              Time |             148 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -313 |
# |          StdEpRet |            26.7 |
# |          MaxEpRet |            -279 |
# |          MinEpRet |            -370 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            9.83 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |     AverageQ1Vals |           -20.2 |
# |         StdQ1Vals |            2.28 |
# |         MaxQ1Vals |           -14.2 |
# |         MinQ1Vals |           -29.6 |
# |     AverageQ2Vals |           -20.2 |
# |         StdQ2Vals |            2.28 |
# |         MaxQ2Vals |           -14.1 |
# |         MinQ2Vals |           -29.6 |
# |            LossPi |            19.2 |
# |             LossQ |           0.141 |
# |              Time |             163 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -224 |
# |          StdEpRet |              37 |
# |          MaxEpRet |            -195 |
# |          MinEpRet |            -321 |
# |  AverageTestEpRet |            -199 |
# |      StdTestEpRet |            19.2 |
# |      MaxTestEpRet |            -160 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |     AverageQ1Vals |           -21.5 |
# |         StdQ1Vals |            2.37 |
# |         MaxQ1Vals |           -15.3 |
# |         MinQ1Vals |           -30.9 |
# |     AverageQ2Vals |           -21.5 |
# |         StdQ2Vals |            2.37 |
# |         MaxQ2Vals |           -15.3 |
# |         MinQ2Vals |           -31.1 |
# |            LossPi |            20.5 |
# |             LossQ |            0.14 |
# |              Time |             177 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |              16 |
# |          MaxEpRet |            -171 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            10.2 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |     AverageQ1Vals |           -22.6 |
# |         StdQ1Vals |            2.53 |
# |         MaxQ1Vals |           -16.2 |
# |         MinQ1Vals |           -32.3 |
# |     AverageQ2Vals |           -22.6 |
# |         StdQ2Vals |            2.53 |
# |         MaxQ2Vals |           -16.1 |
# |         MinQ2Vals |           -32.8 |
# |            LossPi |            21.6 |
# |             LossQ |           0.133 |
# |              Time |             192 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -206 |
# |          StdEpRet |            13.1 |
# |          MaxEpRet |            -178 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |            10.8 |
# |      MaxTestEpRet |            -187 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |     AverageQ1Vals |           -23.7 |
# |         StdQ1Vals |            2.64 |
# |         MaxQ1Vals |           -17.2 |
# |         MinQ1Vals |             -34 |
# |     AverageQ2Vals |           -23.7 |
# |         StdQ2Vals |            2.64 |
# |         MaxQ2Vals |           -17.1 |
# |         MinQ2Vals |           -34.2 |
# |            LossPi |            22.8 |
# |             LossQ |           0.129 |
# |              Time |             206 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -209 |
# |          StdEpRet |            11.9 |
# |          MaxEpRet |            -176 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            4.97 |
# |      MaxTestEpRet |            -201 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |     AverageQ1Vals |           -24.8 |
# |         StdQ1Vals |            2.71 |
# |         MaxQ1Vals |           -18.3 |
# |         MinQ1Vals |           -35.2 |
# |     AverageQ2Vals |           -24.8 |
# |         StdQ2Vals |            2.71 |
# |         MaxQ2Vals |           -18.2 |
# |         MinQ2Vals |           -35.4 |
# |            LossPi |              24 |
# |             LossQ |           0.126 |
# |              Time |             220 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |              13 |
# |          MaxEpRet |            -170 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -202 |
# |      StdTestEpRet |              11 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |             -26 |
# |         StdQ1Vals |            2.77 |
# |         MaxQ1Vals |           -19.1 |
# |         MinQ1Vals |           -36.7 |
# |     AverageQ2Vals |             -26 |
# |         StdQ2Vals |            2.77 |
# |         MaxQ2Vals |           -19.1 |
# |         MinQ2Vals |           -36.9 |
# |            LossPi |            25.2 |
# |             LossQ |           0.125 |
# |              Time |             235 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -201 |
# |          StdEpRet |            15.3 |
# |          MaxEpRet |            -169 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            9.15 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |     AverageQ1Vals |           -27.1 |
# |         StdQ1Vals |            2.83 |
# |         MaxQ1Vals |           -20.1 |
# |         MinQ1Vals |           -38.5 |
# |     AverageQ2Vals |           -27.1 |
# |         StdQ2Vals |            2.83 |
# |         MaxQ2Vals |           -20.2 |
# |         MinQ2Vals |           -38.7 |
# |            LossPi |            26.4 |
# |             LossQ |           0.123 |
# |              Time |             249 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -206 |
# |          StdEpRet |            15.7 |
# |          MaxEpRet |            -158 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |              16 |
# |      MaxTestEpRet |            -169 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |     AverageQ1Vals |           -28.3 |
# |         StdQ1Vals |            2.89 |
# |         MaxQ1Vals |           -21.2 |
# |         MinQ1Vals |           -39.5 |
# |     AverageQ2Vals |           -28.3 |
# |         StdQ2Vals |            2.89 |
# |         MaxQ2Vals |           -21.2 |
# |         MinQ2Vals |           -39.4 |
# |            LossPi |            27.6 |
# |             LossQ |           0.124 |
# |              Time |             264 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -211 |
# |          StdEpRet |            6.26 |
# |          MaxEpRet |            -198 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -202 |
# |      StdTestEpRet |            22.6 |
# |      MaxTestEpRet |            -150 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -29.4 |
# |         StdQ1Vals |            2.93 |
# |         MaxQ1Vals |           -22.2 |
# |         MinQ1Vals |           -41.1 |
# |     AverageQ2Vals |           -29.4 |
# |         StdQ2Vals |            2.93 |
# |         MaxQ2Vals |           -22.2 |
# |         MinQ2Vals |             -41 |
# |            LossPi |            28.8 |
# |             LossQ |           0.122 |
# |              Time |             278 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            10.1 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            8.45 |
# |      MaxTestEpRet |            -194 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |     AverageQ1Vals |           -30.6 |
# |         StdQ1Vals |            2.97 |
# |         MaxQ1Vals |           -23.2 |
# |         MinQ1Vals |           -42.7 |
# |     AverageQ2Vals |           -30.6 |
# |         StdQ2Vals |            2.97 |
# |         MaxQ2Vals |           -23.3 |
# |         MinQ2Vals |           -42.9 |
# |            LossPi |            29.9 |
# |             LossQ |           0.122 |
# |              Time |             292 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -209 |
# |          StdEpRet |            9.22 |
# |          MaxEpRet |            -189 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -199 |
# |      StdTestEpRet |            16.1 |
# |      MaxTestEpRet |            -171 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |     AverageQ1Vals |           -31.7 |
# |         StdQ1Vals |            3.02 |
# |         MaxQ1Vals |           -24.3 |
# |         MinQ1Vals |           -43.9 |
# |     AverageQ2Vals |           -31.7 |
# |         StdQ2Vals |            3.02 |
# |         MaxQ2Vals |           -24.2 |
# |         MinQ2Vals |           -43.9 |
# |            LossPi |            31.1 |
# |             LossQ |           0.124 |
# |              Time |             306 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -202 |
# |          StdEpRet |            15.6 |
# |          MaxEpRet |            -166 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            6.45 |
# |      MaxTestEpRet |            -197 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |     AverageQ1Vals |           -32.9 |
# |         StdQ1Vals |            3.05 |
# |         MaxQ1Vals |           -25.3 |
# |         MinQ1Vals |           -45.3 |
# |     AverageQ2Vals |           -32.9 |
# |         StdQ2Vals |            3.05 |
# |         MaxQ2Vals |           -25.4 |
# |         MinQ2Vals |           -45.7 |
# |            LossPi |            32.3 |
# |             LossQ |           0.125 |
# |              Time |             321 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            14.6 |
# |          MaxEpRet |            -178 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            5.33 |
# |      MaxTestEpRet |            -195 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |     AverageQ1Vals |           -34.1 |
# |         StdQ1Vals |            3.08 |
# |         MaxQ1Vals |           -26.3 |
# |         MinQ1Vals |           -46.1 |
# |     AverageQ2Vals |           -34.1 |
# |         StdQ2Vals |            3.08 |
# |         MaxQ2Vals |           -26.3 |
# |         MinQ2Vals |           -46.8 |
# |            LossPi |            33.5 |
# |             LossQ |           0.126 |
# |              Time |             335 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -197 |
# |          StdEpRet |            20.3 |
# |          MaxEpRet |            -157 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -204 |
# |      StdTestEpRet |            12.7 |
# |      MaxTestEpRet |            -177 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |     AverageQ1Vals |           -35.2 |
# |         StdQ1Vals |            3.13 |
# |         MaxQ1Vals |           -27.2 |
# |         MinQ1Vals |           -48.3 |
# |     AverageQ2Vals |           -35.2 |
# |         StdQ2Vals |            3.13 |
# |         MaxQ2Vals |           -27.2 |
# |         MinQ2Vals |             -48 |
# |            LossPi |            34.6 |
# |             LossQ |           0.129 |
# |              Time |             350 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -197 |
# |          StdEpRet |            13.6 |
# |          MaxEpRet |            -161 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -213 |
# |      StdTestEpRet |            6.36 |
# |      MaxTestEpRet |            -201 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |     AverageQ1Vals |           -36.4 |
# |         StdQ1Vals |            3.15 |
# |         MaxQ1Vals |           -28.2 |
# |         MinQ1Vals |           -49.4 |
# |     AverageQ2Vals |           -36.4 |
# |         StdQ2Vals |            3.15 |
# |         MaxQ2Vals |           -28.2 |
# |         MinQ2Vals |           -49.6 |
# |            LossPi |            35.8 |
# |             LossQ |           0.132 |
# |              Time |             365 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -199 |
# |          StdEpRet |            23.3 |
# |          MaxEpRet |            -135 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -200 |
# |      StdTestEpRet |            11.2 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |     AverageQ1Vals |           -37.5 |
# |         StdQ1Vals |            3.21 |
# |         MaxQ1Vals |           -29.2 |
# |         MinQ1Vals |           -50.6 |
# |     AverageQ2Vals |           -37.5 |
# |         StdQ2Vals |            3.21 |
# |         MaxQ2Vals |           -29.3 |
# |         MinQ2Vals |           -50.8 |
# |            LossPi |            36.9 |
# |             LossQ |           0.136 |
# |              Time |             379 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -208 |
# |          StdEpRet |            10.2 |
# |          MaxEpRet |            -185 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -194 |
# |      StdTestEpRet |            16.4 |
# |      MaxTestEpRet |            -175 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |     AverageQ1Vals |           -38.6 |
# |         StdQ1Vals |            3.26 |
# |         MaxQ1Vals |           -30.3 |
# |         MinQ1Vals |           -52.2 |
# |     AverageQ2Vals |           -38.6 |
# |         StdQ2Vals |            3.26 |
# |         MaxQ2Vals |           -30.2 |
# |         MinQ2Vals |           -52.3 |
# |            LossPi |            38.1 |
# |             LossQ |           0.139 |
# |              Time |             394 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            19.5 |
# |          MaxEpRet |            -154 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -201 |
# |      StdTestEpRet |            17.4 |
# |      MaxTestEpRet |            -160 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |     AverageQ1Vals |           -39.7 |
# |         StdQ1Vals |            3.32 |
# |         MaxQ1Vals |           -31.2 |
# |         MinQ1Vals |           -53.8 |
# |     AverageQ2Vals |           -39.7 |
# |         StdQ2Vals |            3.32 |
# |         MaxQ2Vals |           -31.1 |
# |         MinQ2Vals |           -53.7 |
# |            LossPi |            39.2 |
# |             LossQ |           0.144 |
# |              Time |             408 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -199 |
# |          StdEpRet |            17.5 |
# |          MaxEpRet |            -163 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |            22.7 |
# |      MaxTestEpRet |            -151 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -40.8 |
# |         StdQ1Vals |            3.37 |
# |         MaxQ1Vals |           -32.3 |
# |         MinQ1Vals |           -55.1 |
# |     AverageQ2Vals |           -40.8 |
# |         StdQ2Vals |            3.37 |
# |         MaxQ2Vals |           -32.1 |
# |         MinQ2Vals |           -55.2 |
# |            LossPi |            40.3 |
# |             LossQ |           0.148 |
# |              Time |             423 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -207 |
# |          StdEpRet |            11.5 |
# |          MaxEpRet |            -177 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -193 |
# |      StdTestEpRet |            18.2 |
# |      MaxTestEpRet |            -159 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |     AverageQ1Vals |           -41.9 |
# |         StdQ1Vals |            3.43 |
# |         MaxQ1Vals |           -33.2 |
# |         MinQ1Vals |           -56.8 |
# |     AverageQ2Vals |           -41.9 |
# |         StdQ2Vals |            3.43 |
# |         MaxQ2Vals |           -33.1 |
# |         MinQ2Vals |           -56.6 |
# |            LossPi |            41.4 |
# |             LossQ |           0.151 |
# |              Time |             437 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            14.5 |
# |          MaxEpRet |            -174 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |              22 |
# |      MaxTestEpRet |            -135 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |     AverageQ1Vals |             -43 |
# |         StdQ1Vals |            3.46 |
# |         MaxQ1Vals |           -34.3 |
# |         MinQ1Vals |           -57.9 |
# |     AverageQ2Vals |             -43 |
# |         StdQ2Vals |            3.46 |
# |         MaxQ2Vals |           -34.1 |
# |         MinQ2Vals |           -58.1 |
# |            LossPi |            42.6 |
# |             LossQ |           0.154 |
# |              Time |             452 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -200 |
# |          StdEpRet |              24 |
# |          MaxEpRet |            -124 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -192 |
# |      StdTestEpRet |            16.4 |
# |      MaxTestEpRet |            -170 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |     AverageQ1Vals |           -44.1 |
# |         StdQ1Vals |            3.52 |
# |         MaxQ1Vals |           -35.2 |
# |         MinQ1Vals |           -59.2 |
# |     AverageQ2Vals |           -44.1 |
# |         StdQ2Vals |            3.52 |
# |         MaxQ2Vals |           -35.1 |
# |         MinQ2Vals |           -59.4 |
# |            LossPi |            43.6 |
# |             LossQ |           0.156 |
# |              Time |             466 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -196 |
# |          StdEpRet |            17.9 |
# |          MaxEpRet |            -158 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -201 |
# |      StdTestEpRet |            6.99 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |     AverageQ1Vals |           -45.2 |
# |         StdQ1Vals |            3.59 |
# |         MaxQ1Vals |           -36.2 |
# |         MinQ1Vals |           -60.5 |
# |     AverageQ2Vals |           -45.2 |
# |         StdQ2Vals |            3.59 |
# |         MaxQ2Vals |             -36 |
# |         MinQ2Vals |           -60.4 |
# |            LossPi |            44.7 |
# |             LossQ |           0.161 |
# |              Time |             480 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            10.3 |
# |          MaxEpRet |            -185 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -186 |
# |      StdTestEpRet |            21.8 |
# |      MaxTestEpRet |            -150 |
# |      MinTestEpRet |            -215 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |     AverageQ1Vals |           -46.2 |
# |         StdQ1Vals |            3.66 |
# |         MaxQ1Vals |             -37 |
# |         MinQ1Vals |           -61.8 |
# |     AverageQ2Vals |           -46.2 |
# |         StdQ2Vals |            3.66 |
# |         MaxQ2Vals |             -37 |
# |         MinQ2Vals |           -62.3 |
# |            LossPi |            45.8 |
# |             LossQ |           0.164 |
# |              Time |             495 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            10.6 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |            11.5 |
# |      MaxTestEpRet |            -183 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |     AverageQ1Vals |           -47.3 |
# |         StdQ1Vals |            3.71 |
# |         MaxQ1Vals |             -38 |
# |         MinQ1Vals |           -63.3 |
# |     AverageQ2Vals |           -47.3 |
# |         StdQ2Vals |            3.71 |
# |         MaxQ2Vals |             -38 |
# |         MinQ2Vals |             -63 |
# |            LossPi |            46.9 |
# |             LossQ |           0.169 |
# |              Time |             509 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -202 |
# |          StdEpRet |            17.4 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -197 |
# |      StdTestEpRet |            15.9 |
# |      MaxTestEpRet |            -166 |
# |      MinTestEpRet |            -215 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |     AverageQ1Vals |           -48.4 |
# |         StdQ1Vals |            3.76 |
# |         MaxQ1Vals |           -38.8 |
# |         MinQ1Vals |           -64.7 |
# |     AverageQ2Vals |           -48.4 |
# |         StdQ2Vals |            3.76 |
# |         MaxQ2Vals |           -38.8 |
# |         MinQ2Vals |           -64.3 |
# |            LossPi |            47.9 |
# |             LossQ |           0.172 |
# |              Time |             524 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -206 |
# |          StdEpRet |            8.06 |
# |          MaxEpRet |            -186 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -187 |
# |      StdTestEpRet |            20.7 |
# |      MaxTestEpRet |            -157 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |     AverageQ1Vals |           -49.4 |
# |         StdQ1Vals |            3.81 |
# |         MaxQ1Vals |           -39.5 |
# |         MinQ1Vals |           -66.1 |
# |     AverageQ2Vals |           -49.4 |
# |         StdQ2Vals |            3.81 |
# |         MaxQ2Vals |           -39.4 |
# |         MinQ2Vals |           -65.6 |
# |            LossPi |              49 |
# |             LossQ |           0.174 |
# |              Time |             538 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -191 |
# |          StdEpRet |            15.5 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -194 |
# |      StdTestEpRet |            11.3 |
# |      MaxTestEpRet |            -178 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |     AverageQ1Vals |           -50.4 |
# |         StdQ1Vals |            3.87 |
# |         MaxQ1Vals |           -40.3 |
# |         MinQ1Vals |           -66.9 |
# |     AverageQ2Vals |           -50.4 |
# |         StdQ2Vals |            3.87 |
# |         MaxQ2Vals |           -40.4 |
# |         MinQ2Vals |           -66.5 |
# |            LossPi |              50 |
# |             LossQ |           0.176 |
# |              Time |             553 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -190 |
# |          StdEpRet |              20 |
# |          MaxEpRet |            -147 |
# |          MinEpRet |            -215 |
# |  AverageTestEpRet |            -200 |
# |      StdTestEpRet |            8.57 |
# |      MaxTestEpRet |            -187 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -51.5 |
# |         StdQ1Vals |            3.94 |
# |         MaxQ1Vals |           -41.1 |
# |         MinQ1Vals |           -68.2 |
# |     AverageQ2Vals |           -51.5 |
# |         StdQ2Vals |            3.94 |
# |         MaxQ2Vals |             -41 |
# |         MinQ2Vals |           -68.1 |
# |            LossPi |            51.1 |
# |             LossQ |           0.184 |
# |              Time |             567 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            17.4 |
# |          MaxEpRet |            -150 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -192 |
# |      StdTestEpRet |            26.2 |
# |      MaxTestEpRet |            -123 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |     AverageQ1Vals |           -52.5 |
# |         StdQ1Vals |               4 |
# |         MaxQ1Vals |           -41.6 |
# |         MinQ1Vals |           -69.7 |
# |     AverageQ2Vals |           -52.5 |
# |         StdQ2Vals |               4 |
# |         MaxQ2Vals |           -41.6 |
# |         MinQ2Vals |           -69.6 |
# |            LossPi |            52.1 |
# |             LossQ |           0.189 |
# |              Time |             582 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -189 |
# |          StdEpRet |            22.5 |
# |          MaxEpRet |            -139 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -190 |
# |      StdTestEpRet |            23.3 |
# |      MaxTestEpRet |            -138 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |     AverageQ1Vals |           -53.5 |
# |         StdQ1Vals |            4.05 |
# |         MaxQ1Vals |           -42.5 |
# |         MinQ1Vals |           -70.9 |
# |     AverageQ2Vals |           -53.5 |
# |         StdQ2Vals |            4.06 |
# |         MaxQ2Vals |           -42.5 |
# |         MinQ2Vals |           -70.7 |
# |            LossPi |            53.1 |
# |             LossQ |           0.194 |
# |              Time |             597 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -197 |
# |          StdEpRet |            12.2 |
# |          MaxEpRet |            -175 |
# |          MinEpRet |            -211 |
# |  AverageTestEpRet |            -194 |
# |      StdTestEpRet |            22.8 |
# |      MaxTestEpRet |            -134 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |     AverageQ1Vals |           -54.5 |
# |         StdQ1Vals |            4.11 |
# |         MaxQ1Vals |           -43.3 |
# |         MinQ1Vals |           -71.4 |
# |     AverageQ2Vals |           -54.5 |
# |         StdQ2Vals |            4.11 |
# |         MaxQ2Vals |           -43.1 |
# |         MinQ2Vals |           -71.9 |
# |            LossPi |            54.1 |
# |             LossQ |           0.199 |
# |              Time |             611 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -193 |
# |          StdEpRet |            17.2 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -188 |
# |      StdTestEpRet |            14.5 |
# |      MaxTestEpRet |            -156 |
# |      MinTestEpRet |            -211 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |     AverageQ1Vals |           -55.4 |
# |         StdQ1Vals |             4.2 |
# |         MaxQ1Vals |           -43.7 |
# |         MinQ1Vals |             -73 |
# |     AverageQ2Vals |           -55.4 |
# |         StdQ2Vals |             4.2 |
# |         MaxQ2Vals |           -43.5 |
# |         MinQ2Vals |           -73.2 |
# |            LossPi |              55 |
# |             LossQ |           0.203 |
# |              Time |             626 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -189 |
# |          StdEpRet |            16.6 |
# |          MaxEpRet |            -165 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -194 |
# |      StdTestEpRet |            17.8 |
# |      MaxTestEpRet |            -151 |
# |      MinTestEpRet |            -215 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |     AverageQ1Vals |           -56.4 |
# |         StdQ1Vals |            4.26 |
# |         MaxQ1Vals |           -44.4 |
# |         MinQ1Vals |           -74.3 |
# |     AverageQ2Vals |           -56.4 |
# |         StdQ2Vals |            4.26 |
# |         MaxQ2Vals |           -44.4 |
# |         MinQ2Vals |           -74.2 |
# |            LossPi |              56 |
# |             LossQ |           0.209 |
# |              Time |             641 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -193 |
# |          StdEpRet |              14 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -186 |
# |      StdTestEpRet |            15.4 |
# |      MaxTestEpRet |            -149 |
# |      MinTestEpRet |            -210 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |     AverageQ1Vals |           -57.3 |
# |         StdQ1Vals |            4.33 |
# |         MaxQ1Vals |           -45.1 |
# |         MinQ1Vals |           -75.2 |
# |     AverageQ2Vals |           -57.3 |
# |         StdQ2Vals |            4.33 |
# |         MaxQ2Vals |           -45.1 |
# |         MinQ2Vals |           -75.8 |
# |            LossPi |              57 |
# |             LossQ |           0.214 |
# |              Time |             656 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -190 |
# |          StdEpRet |              13 |
# ...
# ---------------------------------------
# |             Epoch |             785 |
# |      AverageEpRet |            -127 |
# |          StdEpRet |            23.2 |
# |          MaxEpRet |           -89.1 |
# |          MinEpRet |            -171 |
# |  AverageTestEpRet |           -98.4 |
# |      StdTestEpRet |            42.9 |
# |      MaxTestEpRet |           -59.5 |
# |      MinTestEpRet |            -197 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -94.6 |
# |         StdQ1Vals |              16 |
# |         MaxQ1Vals |           -65.7 |
# |         MinQ1Vals |            -180 |
# |     AverageQ2Vals |           -94.6 |
# |         StdQ2Vals |              16 |
# |         MaxQ2Vals |           -65.7 |
# |         MinQ2Vals |            -182 |
# |            LossPi |            94.4 |
# |             LossQ |           0.817 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             786 |
# |      AverageEpRet |            -105 |
# |          StdEpRet |            14.7 |
# |          MaxEpRet |           -73.9 |
# |          MinEpRet |            -134 |
# |  AverageTestEpRet |            -107 |
# |      StdTestEpRet |            22.1 |
# |      MaxTestEpRet |           -77.4 |
# |      MinTestEpRet |            -155 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -94.5 |
# |         StdQ1Vals |              16 |
# |         MaxQ1Vals |           -65.7 |
# |         MinQ1Vals |            -181 |
# |     AverageQ2Vals |           -94.5 |
# |         StdQ2Vals |              16 |
# |         MaxQ2Vals |           -65.6 |
# |         MinQ2Vals |            -184 |
# |            LossPi |            94.2 |
# |             LossQ |           0.776 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             787 |
# |      AverageEpRet |            -115 |
# |          StdEpRet |            25.7 |
# |          MaxEpRet |           -76.2 |
# |          MinEpRet |            -174 |
# |  AverageTestEpRet |           -94.1 |
# |      StdTestEpRet |            28.5 |
# |      MaxTestEpRet |           -52.2 |
# |      MinTestEpRet |            -143 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -94.4 |
# |         StdQ1Vals |              16 |
# |         MaxQ1Vals |           -65.4 |
# |         MinQ1Vals |            -184 |
# |     AverageQ2Vals |           -94.4 |
# |         StdQ2Vals |              16 |
# |         MaxQ2Vals |           -65.6 |
# |         MinQ2Vals |            -182 |
# |            LossPi |            94.1 |
# |             LossQ |            0.81 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             788 |
# |      AverageEpRet |            -110 |
# |          StdEpRet |            28.4 |
# |          MaxEpRet |           -73.4 |
# |          MinEpRet |            -185 |
# |  AverageTestEpRet |            -116 |
# |      StdTestEpRet |            41.2 |
# |      MaxTestEpRet |           -65.1 |
# |      MinTestEpRet |            -207 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -94.3 |
# |         StdQ1Vals |              16 |
# |         MaxQ1Vals |           -65.6 |
# |         MinQ1Vals |            -187 |
# |     AverageQ2Vals |           -94.3 |
# |         StdQ2Vals |              16 |
# |         MaxQ2Vals |           -65.6 |
# |         MinQ2Vals |            -187 |
# |            LossPi |            94.1 |
# |             LossQ |           0.792 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             789 |
# |      AverageEpRet |            -117 |
# |          StdEpRet |              25 |
# |          MaxEpRet |           -69.7 |
# |          MinEpRet |            -159 |
# |  AverageTestEpRet |            -110 |
# |      StdTestEpRet |            19.7 |
# |      MaxTestEpRet |           -83.3 |
# |      MinTestEpRet |            -146 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -94.3 |
# |         StdQ1Vals |              16 |
# |         MaxQ1Vals |           -65.3 |
# |         MinQ1Vals |            -183 |
# |     AverageQ2Vals |           -94.3 |
# |         StdQ2Vals |              16 |
# |         MaxQ2Vals |           -65.5 |
# |         MinQ2Vals |            -184 |
# |            LossPi |            94.1 |
# |             LossQ |           0.795 |
# |              Time |        1.18e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             790 |
# |      AverageEpRet |            -123 |
# |          StdEpRet |            25.4 |
# |          MaxEpRet |           -81.4 |
# |          MinEpRet |            -173 |
# |  AverageTestEpRet |           -96.2 |
# |      StdTestEpRet |            27.9 |
# |      MaxTestEpRet |           -47.9 |
# |      MinTestEpRet |            -152 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.3e+06 |
# |     AverageQ1Vals |           -94.2 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.7 |
# |         MinQ1Vals |            -179 |
# |     AverageQ2Vals |           -94.2 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.6 |
# |         MinQ2Vals |            -181 |
# |            LossPi |              94 |
# |             LossQ |           0.803 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             791 |
# |      AverageEpRet |            -119 |
# |          StdEpRet |            31.6 |
# |          MaxEpRet |           -77.8 |
# |          MinEpRet |            -178 |
# |  AverageTestEpRet |            -121 |
# |      StdTestEpRet |            31.4 |
# |      MaxTestEpRet |           -65.7 |
# |      MinTestEpRet |            -170 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -94.2 |
# |         StdQ1Vals |              16 |
# |         MaxQ1Vals |           -65.7 |
# |         MinQ1Vals |            -179 |
# |     AverageQ2Vals |           -94.2 |
# |         StdQ2Vals |              16 |
# |         MaxQ2Vals |           -65.5 |
# |         MinQ2Vals |            -180 |
# |            LossPi |            93.9 |
# |             LossQ |           0.809 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             792 |
# |      AverageEpRet |            -121 |
# |          StdEpRet |            29.3 |
# |          MaxEpRet |             -85 |
# |          MinEpRet |            -191 |
# |  AverageTestEpRet |            -124 |
# |      StdTestEpRet |            37.1 |
# |      MaxTestEpRet |           -64.6 |
# |      MinTestEpRet |            -181 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |           -94.1 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.4 |
# |         MinQ1Vals |            -184 |
# |     AverageQ2Vals |           -94.1 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.3 |
# |         MinQ2Vals |            -183 |
# |            LossPi |            93.9 |
# |             LossQ |           0.805 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             793 |
# |      AverageEpRet |            -117 |
# |          StdEpRet |            26.8 |
# |          MaxEpRet |           -73.2 |
# |          MinEpRet |            -160 |
# |  AverageTestEpRet |            -105 |
# |      StdTestEpRet |            27.1 |
# |      MaxTestEpRet |           -71.7 |
# |      MinTestEpRet |            -165 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |             -94 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.4 |
# |         MinQ1Vals |            -182 |
# |     AverageQ2Vals |             -94 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.5 |
# |         MinQ2Vals |            -183 |
# |            LossPi |            93.8 |
# |             LossQ |           0.805 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             794 |
# |      AverageEpRet |            -131 |
# |          StdEpRet |            33.1 |
# |          MaxEpRet |           -89.1 |
# |          MinEpRet |            -187 |
# |  AverageTestEpRet |            -111 |
# |      StdTestEpRet |            31.4 |
# |      MaxTestEpRet |           -68.4 |
# |      MinTestEpRet |            -161 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |             -94 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.2 |
# |         MinQ1Vals |            -186 |
# |     AverageQ2Vals |             -94 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.3 |
# |         MinQ2Vals |            -185 |
# |            LossPi |            93.8 |
# |             LossQ |           0.809 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             795 |
# |      AverageEpRet |            -120 |
# |          StdEpRet |            23.8 |
# |          MaxEpRet |           -79.2 |
# |          MinEpRet |            -180 |
# |  AverageTestEpRet |            -102 |
# |      StdTestEpRet |            38.2 |
# |      MaxTestEpRet |           -55.7 |
# |      MinTestEpRet |            -188 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |             -94 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.4 |
# |         MinQ1Vals |            -182 |
# |     AverageQ2Vals |             -94 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.5 |
# |         MinQ2Vals |            -182 |
# |            LossPi |            93.7 |
# |             LossQ |           0.802 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             796 |
# |      AverageEpRet |            -131 |
# |          StdEpRet |              34 |
# |          MaxEpRet |           -63.2 |
# |          MinEpRet |            -188 |
# |  AverageTestEpRet |            -110 |
# |      StdTestEpRet |            26.6 |
# |      MaxTestEpRet |           -73.1 |
# |      MinTestEpRet |            -146 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.31e+06 |
# |     AverageQ1Vals |             -94 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.3 |
# |         MinQ1Vals |            -184 |
# |     AverageQ2Vals |             -94 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.4 |
# |         MinQ2Vals |            -183 |
# |            LossPi |            93.7 |
# |             LossQ |           0.797 |
# |              Time |        1.19e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             797 |
# |      AverageEpRet |            -118 |
# |          StdEpRet |            21.3 |
# |          MaxEpRet |           -88.9 |
# |          MinEpRet |            -166 |
# |  AverageTestEpRet |            -134 |
# |      StdTestEpRet |            21.9 |
# |      MaxTestEpRet |            -101 |
# |      MinTestEpRet |            -184 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -93.9 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.3 |
# |         MinQ1Vals |            -186 |
# |     AverageQ2Vals |           -93.9 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.5 |
# |         MinQ2Vals |            -185 |
# |            LossPi |            93.7 |
# |             LossQ |           0.801 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             798 |
# |      AverageEpRet |            -122 |
# |          StdEpRet |            19.7 |
# |          MaxEpRet |           -80.7 |
# |          MinEpRet |            -146 |
# |  AverageTestEpRet |             -94 |
# |      StdTestEpRet |            18.7 |
# |      MaxTestEpRet |           -62.8 |
# |      MinTestEpRet |            -125 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -93.8 |
# |         StdQ1Vals |            15.8 |
# |         MaxQ1Vals |           -65.3 |
# |         MinQ1Vals |            -179 |
# |     AverageQ2Vals |           -93.8 |
# |         StdQ2Vals |            15.8 |
# |         MaxQ2Vals |           -65.2 |
# |         MinQ2Vals |            -182 |
# |            LossPi |            93.6 |
# |             LossQ |             0.8 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             799 |
# |      AverageEpRet |            -114 |
# |          StdEpRet |            25.6 |
# |          MaxEpRet |           -61.3 |
# |          MinEpRet |            -146 |
# |  AverageTestEpRet |            -115 |
# |      StdTestEpRet |            30.8 |
# |      MaxTestEpRet |           -64.6 |
# |      MinTestEpRet |            -190 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -93.9 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.4 |
# |         MinQ1Vals |            -185 |
# |     AverageQ2Vals |           -93.9 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.3 |
# |         MinQ2Vals |            -184 |
# |            LossPi |            93.7 |
# |             LossQ |           0.807 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             800 |
# |      AverageEpRet |            -119 |
# |          StdEpRet |            20.1 |
# |          MaxEpRet |             -73 |
# |          MinEpRet |            -148 |
# |  AverageTestEpRet |           -96.2 |
# |      StdTestEpRet |              25 |
# |      MaxTestEpRet |           -46.7 |
# |      MinTestEpRet |            -135 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+06 |
# |     AverageQ1Vals |           -93.8 |
# |         StdQ1Vals |            15.9 |
# |         MaxQ1Vals |           -65.1 |
# |         MinQ1Vals |            -180 |
# |     AverageQ2Vals |           -93.8 |
# |         StdQ2Vals |            15.9 |
# |         MaxQ2Vals |           -65.3 |
# |         MinQ2Vals |            -182 |
# |            LossPi |            93.6 |
# |             LossQ |           0.802 |
# |              Time |         1.2e+04 |
# ---------------------------------------

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it1_hid_var1', exp_name='td3_n_it1_hid_var1')
seed_b = 0
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.99
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[1000], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.001
qlr_b = 0.001

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.05

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)
# Out:
# Logging data to td3_n_it1_hid_var1/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             1000
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	150,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fc9b0b23710>, env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.05, 'qx2': 0.01, 'qx4': 0.01, 'pu1': 0.5, 'pu2': 0.5}, ep_len=110)",
#     "epochs":	800,
#     "exp_name":	"td3_n_it1_hid_var1",
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fc97e7a4550>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_n_it1_hid_var1",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_n_it1_hid_var1",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_n_it1_hid_var1/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_n_it1_hid_var1",
#         "output_dir":	"td3_n_it1_hid_var1"
#     },
#     "max_ep_len":	110,
#     "noise_clip":	0.05,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "policy_delay":	2,
#     "polyak":	0.999,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	20000,
#     "steps_per_epoch":	1650,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 12002, 	 q1: 13001, 	 q2: 13001
# /home/lecauchoismatthieu/drlenv/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -318 |
# |          StdEpRet |            20.2 |
# |          MaxEpRet |            -287 |
# |          MinEpRet |            -362 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            12.9 |
# |      MaxTestEpRet |            -177 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |     AverageQ1Vals |           -3.22 |
# |         StdQ1Vals |            0.57 |
# |         MaxQ1Vals |           0.363 |
# |         MinQ1Vals |           -5.37 |
# |     AverageQ2Vals |           -3.22 |
# |         StdQ2Vals |           0.582 |
# |         MaxQ2Vals |           0.541 |
# |         MinQ2Vals |            -5.2 |
# |            LossPi |            2.87 |
# |             LossQ |           0.354 |
# |              Time |            8.73 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -315 |
# |          StdEpRet |            25.2 |
# |          MaxEpRet |            -275 |
# |          MinEpRet |            -356 |
# |  AverageTestEpRet |            -199 |
# |      StdTestEpRet |            26.4 |
# |      MaxTestEpRet |            -134 |
# |      MinTestEpRet |            -225 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |     AverageQ1Vals |           -4.49 |
# |         StdQ1Vals |           0.795 |
# |         MaxQ1Vals |           -2.35 |
# |         MinQ1Vals |           -7.81 |
# |     AverageQ2Vals |           -4.49 |
# |         StdQ2Vals |           0.794 |
# |         MaxQ2Vals |           -2.37 |
# |         MinQ2Vals |           -7.75 |
# |            LossPi |            4.03 |
# |             LossQ |          0.0755 |
# |              Time |              24 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -334 |
# |          StdEpRet |            23.7 |
# |          MaxEpRet |            -282 |
# |          MinEpRet |            -370 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            14.1 |
# |      MaxTestEpRet |            -170 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |     AverageQ1Vals |            -6.2 |
# |         StdQ1Vals |           0.989 |
# |         MaxQ1Vals |           -3.46 |
# |         MinQ1Vals |           -10.5 |
# |     AverageQ2Vals |            -6.2 |
# |         StdQ2Vals |            0.99 |
# |         MaxQ2Vals |           -3.39 |
# |         MinQ2Vals |           -10.5 |
# |            LossPi |            5.67 |
# |             LossQ |          0.0608 |
# |              Time |            39.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -317 |
# |          StdEpRet |            22.2 |
# |          MaxEpRet |            -288 |
# |          MinEpRet |            -381 |
# |  AverageTestEpRet |            -218 |
# |      StdTestEpRet |            3.86 |
# |      MaxTestEpRet |            -211 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |     AverageQ1Vals |           -7.91 |
# |         StdQ1Vals |            1.17 |
# |         MaxQ1Vals |           -4.36 |
# |         MinQ1Vals |           -13.1 |
# |     AverageQ2Vals |           -7.91 |
# |         StdQ2Vals |            1.17 |
# |         MaxQ2Vals |           -4.36 |
# |         MinQ2Vals |             -13 |
# |            LossPi |             7.3 |
# |             LossQ |          0.0603 |
# |              Time |            54.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -304 |
# |          StdEpRet |            19.5 |
# |          MaxEpRet |            -282 |
# |          MinEpRet |            -354 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            7.65 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |     AverageQ1Vals |            -9.5 |
# |         StdQ1Vals |            1.32 |
# |         MaxQ1Vals |           -5.41 |
# |         MinQ1Vals |           -15.6 |
# |     AverageQ2Vals |            -9.5 |
# |         StdQ2Vals |            1.32 |
# |         MaxQ2Vals |           -5.42 |
# |         MinQ2Vals |           -15.5 |
# |            LossPi |            8.82 |
# |             LossQ |          0.0631 |
# |              Time |              70 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -302 |
# |          StdEpRet |            14.7 |
# |          MaxEpRet |            -279 |
# |          MinEpRet |            -333 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            10.3 |
# |      MaxTestEpRet |            -187 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |     AverageQ1Vals |             -11 |
# |         StdQ1Vals |            1.47 |
# |         MaxQ1Vals |           -6.54 |
# |         MinQ1Vals |           -17.9 |
# |     AverageQ2Vals |             -11 |
# |         StdQ2Vals |            1.47 |
# |         MaxQ2Vals |           -6.52 |
# |         MinQ2Vals |           -17.7 |
# |            LossPi |            10.3 |
# |             LossQ |          0.0666 |
# |              Time |            85.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -313 |
# |          StdEpRet |            36.9 |
# |          MaxEpRet |            -279 |
# |          MinEpRet |            -387 |
# |  AverageTestEpRet |            -213 |
# |      StdTestEpRet |            7.65 |
# |      MaxTestEpRet |            -194 |
# |      MinTestEpRet |            -225 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |     AverageQ1Vals |           -12.6 |
# |         StdQ1Vals |            1.61 |
# |         MaxQ1Vals |           -7.66 |
# |         MinQ1Vals |           -20.1 |
# |     AverageQ2Vals |           -12.6 |
# |         StdQ2Vals |            1.61 |
# |         MaxQ2Vals |           -7.73 |
# |         MinQ2Vals |             -20 |
# |            LossPi |            11.8 |
# |             LossQ |          0.0741 |
# |              Time |             100 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -316 |
# |          StdEpRet |            26.5 |
# |          MaxEpRet |            -273 |
# |          MinEpRet |            -368 |
# |  AverageTestEpRet |            -197 |
# |      StdTestEpRet |            16.9 |
# |      MaxTestEpRet |            -170 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |     AverageQ1Vals |           -14.1 |
# |         StdQ1Vals |            1.79 |
# |         MaxQ1Vals |            -8.6 |
# |         MinQ1Vals |           -22.3 |
# |     AverageQ2Vals |           -14.1 |
# |         StdQ2Vals |            1.79 |
# |         MaxQ2Vals |           -8.79 |
# |         MinQ2Vals |           -22.1 |
# |            LossPi |            13.3 |
# |             LossQ |           0.084 |
# |              Time |             116 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -328 |
# |          StdEpRet |            32.6 |
# |          MaxEpRet |            -277 |
# |          MinEpRet |            -394 |
# |  AverageTestEpRet |            -210 |
# |      StdTestEpRet |            11.2 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |     AverageQ1Vals |           -15.7 |
# |         StdQ1Vals |            1.93 |
# |         MaxQ1Vals |           -9.78 |
# |         MinQ1Vals |           -23.9 |
# |     AverageQ2Vals |           -15.7 |
# |         StdQ2Vals |            1.93 |
# |         MaxQ2Vals |           -9.81 |
# |         MinQ2Vals |             -24 |
# |            LossPi |            14.8 |
# |             LossQ |          0.0949 |
# |              Time |             131 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -312 |
# |          StdEpRet |            20.8 |
# |          MaxEpRet |            -283 |
# |          MinEpRet |            -368 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            8.58 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -17.2 |
# |         StdQ1Vals |            2.05 |
# |         MaxQ1Vals |           -11.1 |
# |         MinQ1Vals |           -26.1 |
# |     AverageQ2Vals |           -17.2 |
# |         StdQ2Vals |            2.05 |
# |         MaxQ2Vals |           -11.1 |
# |         MinQ2Vals |           -26.1 |
# |            LossPi |            16.2 |
# |             LossQ |           0.105 |
# |              Time |             146 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -310 |
# |          StdEpRet |            28.1 |
# |          MaxEpRet |            -273 |
# |          MinEpRet |            -366 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            9.32 |
# |      MaxTestEpRet |            -187 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |     AverageQ1Vals |           -18.6 |
# |         StdQ1Vals |            2.13 |
# |         MaxQ1Vals |           -12.3 |
# |         MinQ1Vals |           -27.5 |
# |     AverageQ2Vals |           -18.6 |
# |         StdQ2Vals |            2.13 |
# |         MaxQ2Vals |           -12.3 |
# |         MinQ2Vals |           -27.7 |
# |            LossPi |            17.6 |
# |             LossQ |            0.11 |
# |              Time |             161 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -329 |
# |          StdEpRet |            31.2 |
# |          MaxEpRet |            -292 |
# |          MinEpRet |            -402 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |            12.5 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |     AverageQ1Vals |             -20 |
# |         StdQ1Vals |            2.24 |
# |         MaxQ1Vals |           -13.4 |
# |         MinQ1Vals |           -29.4 |
# |     AverageQ2Vals |             -20 |
# |         StdQ2Vals |            2.24 |
# |         MaxQ2Vals |           -13.5 |
# |         MinQ2Vals |           -29.6 |
# |            LossPi |              19 |
# |             LossQ |           0.122 |
# |              Time |             176 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -219 |
# |          StdEpRet |            35.7 |
# |          MaxEpRet |            -174 |
# |          MinEpRet |            -305 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            7.38 |
# |      MaxTestEpRet |            -193 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |     AverageQ1Vals |           -21.3 |
# |         StdQ1Vals |            2.33 |
# |         MaxQ1Vals |           -14.8 |
# |         MinQ1Vals |             -31 |
# |     AverageQ2Vals |           -21.3 |
# |         StdQ2Vals |            2.33 |
# |         MaxQ2Vals |           -14.8 |
# |         MinQ2Vals |           -31.3 |
# |            LossPi |            20.3 |
# |             LossQ |           0.124 |
# |              Time |             192 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -208 |
# |          StdEpRet |            12.6 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -210 |
# |      StdTestEpRet |            11.9 |
# |      MaxTestEpRet |            -178 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |     AverageQ1Vals |           -22.4 |
# |         StdQ1Vals |            2.47 |
# |         MaxQ1Vals |           -15.8 |
# |         MinQ1Vals |           -32.7 |
# |     AverageQ2Vals |           -22.4 |
# |         StdQ2Vals |            2.47 |
# |         MaxQ2Vals |           -15.8 |
# |         MinQ2Vals |           -33.2 |
# |            LossPi |            21.5 |
# |             LossQ |           0.116 |
# |              Time |             208 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            13.3 |
# |          MaxEpRet |            -175 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            25.9 |
# |      MaxTestEpRet |            -145 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |     AverageQ1Vals |           -23.5 |
# |         StdQ1Vals |            2.58 |
# |         MaxQ1Vals |           -16.9 |
# |         MinQ1Vals |             -34 |
# |     AverageQ2Vals |           -23.5 |
# |         StdQ2Vals |            2.59 |
# |         MaxQ2Vals |           -17.1 |
# |         MinQ2Vals |           -34.6 |
# |            LossPi |            22.7 |
# |             LossQ |           0.114 |
# |              Time |             223 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -208 |
# |          StdEpRet |            11.5 |
# |          MaxEpRet |            -178 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            11.2 |
# |      MaxTestEpRet |            -175 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |     AverageQ1Vals |           -24.7 |
# |         StdQ1Vals |            2.64 |
# |         MaxQ1Vals |           -18.2 |
# |         MinQ1Vals |           -36.1 |
# |     AverageQ2Vals |           -24.7 |
# |         StdQ2Vals |            2.64 |
# |         MaxQ2Vals |           -18.2 |
# |         MinQ2Vals |           -36.7 |
# |            LossPi |            23.9 |
# |             LossQ |           0.111 |
# |              Time |             239 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -207 |
# |          StdEpRet |            14.9 |
# |          MaxEpRet |            -173 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            8.14 |
# |      MaxTestEpRet |            -187 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |           -25.9 |
# |         StdQ1Vals |            2.68 |
# |         MaxQ1Vals |           -19.3 |
# |         MinQ1Vals |           -37.5 |
# |     AverageQ2Vals |           -25.9 |
# |         StdQ2Vals |            2.68 |
# |         MaxQ2Vals |           -19.2 |
# |         MinQ2Vals |           -38.2 |
# |            LossPi |            25.1 |
# |             LossQ |           0.111 |
# |              Time |             254 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -208 |
# |          StdEpRet |            9.63 |
# |          MaxEpRet |            -183 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -210 |
# |      StdTestEpRet |            9.97 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |     AverageQ1Vals |             -27 |
# |         StdQ1Vals |            2.73 |
# |         MaxQ1Vals |           -20.5 |
# |         MinQ1Vals |           -38.7 |
# |     AverageQ2Vals |             -27 |
# |         StdQ2Vals |            2.73 |
# |         MaxQ2Vals |           -20.4 |
# |         MinQ2Vals |           -39.5 |
# |            LossPi |            26.3 |
# |             LossQ |            0.11 |
# |              Time |             270 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -208 |
# |          StdEpRet |              10 |
# |          MaxEpRet |            -185 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -199 |
# |      StdTestEpRet |            17.3 |
# |      MaxTestEpRet |            -169 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |     AverageQ1Vals |           -28.2 |
# |         StdQ1Vals |            2.76 |
# |         MaxQ1Vals |           -21.4 |
# |         MinQ1Vals |           -40.3 |
# |     AverageQ2Vals |           -28.2 |
# |         StdQ2Vals |            2.76 |
# |         MaxQ2Vals |           -21.5 |
# |         MinQ2Vals |             -41 |
# |            LossPi |            27.5 |
# |             LossQ |            0.11 |
# |              Time |             286 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            29.9 |
# |          MaxEpRet |            -123 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -203 |
# |      StdTestEpRet |            9.72 |
# |      MaxTestEpRet |            -181 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -29.3 |
# |         StdQ1Vals |            2.81 |
# |         MaxQ1Vals |           -22.4 |
# |         MinQ1Vals |           -41.4 |
# |     AverageQ2Vals |           -29.3 |
# |         StdQ2Vals |            2.81 |
# |         MaxQ2Vals |           -22.5 |
# |         MinQ2Vals |           -42.1 |
# |            LossPi |            28.6 |
# |             LossQ |           0.112 |
# |              Time |             301 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -206 |
# |          StdEpRet |            14.4 |
# |          MaxEpRet |            -177 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |            19.3 |
# |      MaxTestEpRet |            -148 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |     AverageQ1Vals |           -30.5 |
# |         StdQ1Vals |            2.85 |
# |         MaxQ1Vals |           -23.6 |
# |         MinQ1Vals |           -43.3 |
# |     AverageQ2Vals |           -30.5 |
# |         StdQ2Vals |            2.85 |
# |         MaxQ2Vals |           -23.5 |
# |         MinQ2Vals |           -43.8 |
# |            LossPi |            29.8 |
# |             LossQ |           0.114 |
# |              Time |             317 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -202 |
# |          StdEpRet |            13.5 |
# |          MaxEpRet |            -172 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            7.33 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |     AverageQ1Vals |           -31.6 |
# |         StdQ1Vals |            2.88 |
# |         MaxQ1Vals |           -24.5 |
# |         MinQ1Vals |           -44.8 |
# |     AverageQ2Vals |           -31.6 |
# |         StdQ2Vals |            2.88 |
# |         MaxQ2Vals |           -24.5 |
# |         MinQ2Vals |           -45.5 |
# |            LossPi |              31 |
# |             LossQ |           0.116 |
# |              Time |             333 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -204 |
# |          StdEpRet |            15.9 |
# |          MaxEpRet |            -165 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -200 |
# |      StdTestEpRet |            22.5 |
# |      MaxTestEpRet |            -142 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |     AverageQ1Vals |           -32.8 |
# |         StdQ1Vals |            2.91 |
# |         MaxQ1Vals |           -25.2 |
# |         MinQ1Vals |             -46 |
# |     AverageQ2Vals |           -32.8 |
# |         StdQ2Vals |            2.91 |
# |         MaxQ2Vals |           -25.2 |
# |         MinQ2Vals |           -46.4 |
# |            LossPi |            32.2 |
# |             LossQ |           0.118 |
# |              Time |             348 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -201 |
# |          StdEpRet |            13.5 |
# |          MaxEpRet |            -173 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            22.1 |
# |      MaxTestEpRet |            -162 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |     AverageQ1Vals |             -34 |
# |         StdQ1Vals |            2.95 |
# |         MaxQ1Vals |             -26 |
# |         MinQ1Vals |           -47.8 |
# |     AverageQ2Vals |             -34 |
# |         StdQ2Vals |            2.95 |
# |         MaxQ2Vals |             -26 |
# |         MinQ2Vals |           -48.6 |
# |            LossPi |            33.4 |
# |             LossQ |           0.121 |
# |              Time |             364 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -204 |
# |          StdEpRet |              12 |
# |          MaxEpRet |            -180 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -187 |
# |      StdTestEpRet |            25.5 |
# |      MaxTestEpRet |            -141 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |     AverageQ1Vals |           -35.1 |
# |         StdQ1Vals |            2.99 |
# |         MaxQ1Vals |           -26.7 |
# |         MinQ1Vals |           -49.1 |
# |     AverageQ2Vals |           -35.1 |
# |         StdQ2Vals |            2.99 |
# |         MaxQ2Vals |           -26.6 |
# |         MinQ2Vals |           -49.5 |
# |            LossPi |            34.5 |
# |             LossQ |           0.123 |
# |              Time |             380 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -202 |
# |          StdEpRet |            12.5 |
# |          MaxEpRet |            -183 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            18.9 |
# |      MaxTestEpRet |            -153 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |     AverageQ1Vals |           -36.2 |
# |         StdQ1Vals |            3.04 |
# |         MaxQ1Vals |           -27.4 |
# |         MinQ1Vals |           -50.7 |
# |     AverageQ2Vals |           -36.2 |
# |         StdQ2Vals |            3.04 |
# |         MaxQ2Vals |           -27.3 |
# |         MinQ2Vals |           -50.9 |
# |            LossPi |            35.7 |
# |             LossQ |           0.126 |
# |              Time |             395 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            16.4 |
# |          MaxEpRet |            -153 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -197 |
# |      StdTestEpRet |            8.81 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -209 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |     AverageQ1Vals |           -37.3 |
# |         StdQ1Vals |            3.08 |
# |         MaxQ1Vals |           -28.1 |
# |         MinQ1Vals |           -52.3 |
# |     AverageQ2Vals |           -37.3 |
# |         StdQ2Vals |            3.08 |
# |         MaxQ2Vals |           -28.1 |
# |         MinQ2Vals |           -52.6 |
# |            LossPi |            36.8 |
# |             LossQ |           0.127 |
# |              Time |             411 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -204 |
# |          StdEpRet |            12.2 |
# |          MaxEpRet |            -179 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            13.5 |
# |      MaxTestEpRet |            -172 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |     AverageQ1Vals |           -38.4 |
# |         StdQ1Vals |            3.15 |
# |         MaxQ1Vals |           -28.8 |
# |         MinQ1Vals |           -53.7 |
# |     AverageQ2Vals |           -38.4 |
# |         StdQ2Vals |            3.15 |
# |         MaxQ2Vals |           -28.8 |
# |         MinQ2Vals |           -54.1 |
# |            LossPi |            37.9 |
# |             LossQ |           0.131 |
# |              Time |             427 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -200 |
# |          StdEpRet |            11.6 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            10.2 |
# |      MaxTestEpRet |            -181 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |     AverageQ1Vals |           -39.6 |
# |         StdQ1Vals |            3.19 |
# |         MaxQ1Vals |           -29.6 |
# |         MinQ1Vals |           -55.1 |
# |     AverageQ2Vals |           -39.6 |
# |         StdQ2Vals |            3.19 |
# |         MaxQ2Vals |           -29.6 |
# |         MinQ2Vals |           -55.2 |
# |            LossPi |            39.1 |
# |             LossQ |           0.134 |
# |              Time |             443 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            15.7 |
# |          MaxEpRet |            -177 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |            18.8 |
# |      MaxTestEpRet |            -164 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -40.7 |
# |         StdQ1Vals |            3.23 |
# |         MaxQ1Vals |           -30.3 |
# |         MinQ1Vals |           -56.1 |
# |     AverageQ2Vals |           -40.7 |
# |         StdQ2Vals |            3.23 |
# |         MaxQ2Vals |           -30.3 |
# |         MinQ2Vals |           -56.1 |
# |            LossPi |            40.2 |
# |             LossQ |           0.138 |
# |              Time |             459 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -197 |
# |          StdEpRet |            20.7 |
# |          MaxEpRet |            -148 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |            19.8 |
# |      MaxTestEpRet |            -153 |
# |      MinTestEpRet |            -215 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |     AverageQ1Vals |           -41.8 |
# |         StdQ1Vals |             3.3 |
# |         MaxQ1Vals |             -31 |
# |         MinQ1Vals |             -56 |
# |     AverageQ2Vals |           -41.8 |
# |         StdQ2Vals |             3.3 |
# |         MaxQ2Vals |           -31.2 |
# |         MinQ2Vals |           -55.8 |
# |            LossPi |            41.3 |
# |             LossQ |           0.142 |
# |              Time |             475 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -191 |
# |          StdEpRet |            19.2 |
# |          MaxEpRet |            -158 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -203 |
# |      StdTestEpRet |              14 |
# |      MaxTestEpRet |            -182 |
# |      MinTestEpRet |            -227 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |     AverageQ1Vals |           -42.8 |
# |         StdQ1Vals |            3.39 |
# |         MaxQ1Vals |           -31.6 |
# |         MinQ1Vals |           -59.3 |
# |     AverageQ2Vals |           -42.8 |
# |         StdQ2Vals |            3.39 |
# |         MaxQ2Vals |           -31.8 |
# |         MinQ2Vals |           -59.2 |
# |            LossPi |            42.3 |
# |             LossQ |           0.145 |
# |              Time |             490 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -193 |
# |          StdEpRet |            17.3 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -200 |
# |      StdTestEpRet |            12.5 |
# |      MaxTestEpRet |            -171 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |     AverageQ1Vals |           -43.9 |
# |         StdQ1Vals |            3.46 |
# |         MaxQ1Vals |           -32.5 |
# |         MinQ1Vals |           -60.5 |
# |     AverageQ2Vals |           -43.9 |
# |         StdQ2Vals |            3.46 |
# |         MaxQ2Vals |           -32.7 |
# |         MinQ2Vals |           -60.1 |
# |            LossPi |            43.4 |
# |             LossQ |           0.148 |
# |              Time |             507 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            19.3 |
# |          MaxEpRet |            -142 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -193 |
# |      StdTestEpRet |            20.9 |
# |      MaxTestEpRet |            -143 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |     AverageQ1Vals |           -44.9 |
# |         StdQ1Vals |            3.53 |
# |         MaxQ1Vals |           -33.4 |
# |         MinQ1Vals |           -61.6 |
# |     AverageQ2Vals |           -44.9 |
# |         StdQ2Vals |            3.53 |
# |         MaxQ2Vals |           -33.3 |
# |         MinQ2Vals |           -61.8 |
# |            LossPi |            44.5 |
# |             LossQ |           0.153 |
# |              Time |             523 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -204 |
# |          StdEpRet |            10.8 |
# |          MaxEpRet |            -173 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -192 |
# |      StdTestEpRet |            19.1 |
# |      MaxTestEpRet |            -163 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |     AverageQ1Vals |             -46 |
# |         StdQ1Vals |            3.57 |
# |         MaxQ1Vals |           -34.1 |
# |         MinQ1Vals |           -62.9 |
# |     AverageQ2Vals |             -46 |
# |         StdQ2Vals |            3.57 |
# |         MaxQ2Vals |           -34.1 |
# |         MinQ2Vals |           -62.6 |
# |            LossPi |            45.5 |
# |             LossQ |           0.157 |
# |              Time |             539 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -193 |
# |          StdEpRet |            18.2 |
# |          MaxEpRet |            -145 |
# |          MinEpRet |            -214 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            18.2 |
# |      MaxTestEpRet |            -159 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |     AverageQ1Vals |           -47.1 |
# |         StdQ1Vals |            3.63 |
# |         MaxQ1Vals |           -34.8 |
# |         MinQ1Vals |           -64.4 |
# |     AverageQ2Vals |           -47.1 |
# |         StdQ2Vals |            3.63 |
# |         MaxQ2Vals |           -34.8 |
# |         MinQ2Vals |           -63.8 |
# |            LossPi |            46.6 |
# |             LossQ |           0.161 |
# |              Time |             555 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            20.3 |
# |          MaxEpRet |            -145 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -189 |
# |      StdTestEpRet |            15.3 |
# |      MaxTestEpRet |            -152 |
# |      MinTestEpRet |            -204 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |     AverageQ1Vals |           -48.1 |
# |         StdQ1Vals |             3.7 |
# |         MaxQ1Vals |           -35.6 |
# |         MinQ1Vals |           -65.6 |
# |     AverageQ2Vals |           -48.1 |
# |         StdQ2Vals |             3.7 |
# |         MaxQ2Vals |           -35.7 |
# |         MinQ2Vals |             -65 |
# |            LossPi |            47.6 |
# |             LossQ |           0.164 |
# |              Time |             571 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -196 |
# |          StdEpRet |            13.3 |
# |          MaxEpRet |            -174 |
# |          MinEpRet |            -214 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |              19 |
# |      MaxTestEpRet |            -159 |
# |      MinTestEpRet |            -215 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |     AverageQ1Vals |           -49.1 |
# |         StdQ1Vals |            3.77 |
# |         MaxQ1Vals |           -36.2 |
# |         MinQ1Vals |           -66.7 |
# |     AverageQ2Vals |           -49.1 |
# |         StdQ2Vals |            3.77 |
# |         MaxQ2Vals |           -36.4 |
# |         MinQ2Vals |           -66.1 |
# |            LossPi |            48.7 |
# |             LossQ |           0.168 |
# |              Time |             588 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            15.5 |
# |          MaxEpRet |            -167 |
# |          MinEpRet |            -213 |
# |  AverageTestEpRet |            -193 |
# |      StdTestEpRet |            21.7 |
# |      MaxTestEpRet |            -131 |
# |      MinTestEpRet |            -209 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |     AverageQ1Vals |           -50.1 |
# |         StdQ1Vals |            3.83 |
# |         MaxQ1Vals |             -37 |
# |         MinQ1Vals |             -68 |
# |     AverageQ2Vals |           -50.1 |
# |         StdQ2Vals |            3.83 |
# |         MaxQ2Vals |           -37.1 |
# |         MinQ2Vals |           -67.5 |
# |            LossPi |            49.7 |
# |             LossQ |           0.173 |
# |              Time |             604 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -189 |
# |          StdEpRet |            15.9 |
# |          MaxEpRet |            -163 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |            17.8 |
# |      MaxTestEpRet |            -149 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -51.1 |
# |         StdQ1Vals |            3.91 |
# |         MaxQ1Vals |           -37.8 |
# |         MinQ1Vals |             -68 |
# |     AverageQ2Vals |           -51.1 |
# |         StdQ2Vals |            3.91 |
# |         MaxQ2Vals |           -37.9 |
# |         MinQ2Vals |           -67.4 |
# |            LossPi |            50.7 |
# |             LossQ |           0.178 |
# |              Time |             620 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            15.8 |
# |          MaxEpRet |            -164 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -186 |
# |      StdTestEpRet |            24.7 |
# |      MaxTestEpRet |            -125 |
# |      MinTestEpRet |            -211 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |     AverageQ1Vals |           -52.1 |
# |         StdQ1Vals |            3.98 |
# |         MaxQ1Vals |           -38.6 |
# |         MinQ1Vals |           -69.3 |
# |     AverageQ2Vals |           -52.1 |
# |         StdQ2Vals |            3.99 |
# |         MaxQ2Vals |           -38.6 |
# |         MinQ2Vals |           -68.8 |
# |            LossPi |            51.7 |
# |             LossQ |           0.184 |
# |              Time |             636 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            13.4 |
# |          MaxEpRet |            -172 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -195 |
# |      StdTestEpRet |            11.3 |
# |      MaxTestEpRet |            -167 |
# |      MinTestEpRet |            -209 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |     AverageQ1Vals |           -53.1 |
# |         StdQ1Vals |            4.04 |
# |         MaxQ1Vals |           -39.4 |
# |         MinQ1Vals |           -70.7 |
# |     AverageQ2Vals |           -53.1 |
# |         StdQ2Vals |            4.04 |
# |         MaxQ2Vals |           -39.5 |
# |         MinQ2Vals |           -70.3 |
# |            LossPi |            52.7 |
# |             LossQ |           0.188 |
# |              Time |             653 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -194 |
# |          StdEpRet |              14 |
# |          MaxEpRet |            -167 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -191 |
# |      StdTestEpRet |            21.6 |
# |      MaxTestEpRet |            -150 |
# |      MinTestEpRet |            -212 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |     AverageQ1Vals |             -54 |
# |         StdQ1Vals |            4.12 |
# |         MaxQ1Vals |           -40.1 |
# |         MinQ1Vals |           -72.2 |
# |     AverageQ2Vals |             -54 |
# |         StdQ2Vals |            4.12 |
# |         MaxQ2Vals |           -40.1 |
# |         MinQ2Vals |           -71.4 |
# |            LossPi |            53.6 |
# |             LossQ |           0.193 |
# |              Time |             669 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -189 |
# |          StdEpRet |            17.5 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -186 |
# |      StdTestEpRet |            29.3 |
# |      MaxTestEpRet |            -127 |
# |      MinTestEpRet |            -215 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |     AverageQ1Vals |             -55 |
# |         StdQ1Vals |            4.18 |
# |         MaxQ1Vals |           -40.8 |
# |         MinQ1Vals |           -73.5 |
# |     AverageQ2Vals |             -55 |
# |         StdQ2Vals |            4.18 |
# |         MaxQ2Vals |           -40.8 |
# |         MinQ2Vals |           -73.2 |
# |            LossPi |            54.6 |
# |             LossQ |           0.195 |
# |              Time |             685 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -193 |
# |          StdEpRet |            20.8 |
# |          MaxEpRet |            -154 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -193 |
# |      StdTestEpRet |            15.9 |
# |      MaxTestEpRet |            -151 |
# |      MinTestEpRet |            -211 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |     AverageQ1Vals |           -55.9 |
# |         StdQ1Vals |            4.26 |
# |         MaxQ1Vals |           -41.5 |
# |         MinQ1Vals |           -73.8 |
# |     AverageQ2Vals |           -55.9 |
# |         StdQ2Vals |            4.26 |
# |         MaxQ2Vals |           -41.5 |
# |         MinQ2Vals |           -73.5 |
# |            LossPi |            55.5 |
# |             LossQ |           0.202 |
# |              Time |             702 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -191 |
# |          StdEpRet |            15.7 |
# |          MaxEpRet |            -159 |
# |          MinEpRet |            -213 |
# |  AverageTestEpRet |            -183 |
# |      StdTestEpRet |            17.9 |
# |      MaxTestEpRet |            -150 |
# |      MinTestEpRet |            -204 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |     AverageQ1Vals |           -56.8 |
# |         StdQ1Vals |            4.33 |
# |         MaxQ1Vals |           -42.1 |
# |         MinQ1Vals |           -74.7 |
# |     AverageQ2Vals |           -56.8 |
# |         StdQ2Vals |            4.33 |
# |         MaxQ2Vals |           -42.3 |
# |         MinQ2Vals |           -74.1 |
# |            LossPi |            56.5 |
# |             LossQ |           0.206 |
# |              Time |             718 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -189 |
# |          StdEpRet |            19.5 |
# ...
# ---------------------------------------
# |             Epoch |             391 |
# |      AverageEpRet |            -125 |
# |          StdEpRet |            17.5 |
# |          MaxEpRet |            -101 |
# |          MinEpRet |            -151 |
# |  AverageTestEpRet |            -122 |
# |      StdTestEpRet |            30.7 |
# |      MaxTestEpRet |           -71.4 |
# |      MinTestEpRet |            -158 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.45e+05 |
# |     AverageQ1Vals |            -112 |
# |         StdQ1Vals |            16.5 |
# |         MaxQ1Vals |           -78.7 |
# |         MinQ1Vals |            -191 |
# |     AverageQ2Vals |            -112 |
# |         StdQ2Vals |            16.5 |
# |         MaxQ2Vals |           -78.6 |
# |         MinQ2Vals |            -188 |
# |            LossPi |             112 |
# |             LossQ |            1.02 |
# |              Time |         6.7e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             392 |
# |      AverageEpRet |            -123 |
# |          StdEpRet |            22.5 |
# |          MaxEpRet |           -82.6 |
# |          MinEpRet |            -157 |
# |  AverageTestEpRet |            -136 |
# |      StdTestEpRet |            30.2 |
# |      MaxTestEpRet |           -82.2 |
# |      MinTestEpRet |            -178 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.47e+05 |
# |     AverageQ1Vals |            -112 |
# |         StdQ1Vals |            16.5 |
# |         MaxQ1Vals |           -78.7 |
# |         MinQ1Vals |            -191 |
# |     AverageQ2Vals |            -112 |
# |         StdQ2Vals |            16.5 |
# |         MaxQ2Vals |           -78.5 |
# |         MinQ2Vals |            -188 |
# |            LossPi |             112 |
# |             LossQ |            1.02 |
# |              Time |        6.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             393 |
# |      AverageEpRet |            -125 |
# |          StdEpRet |            31.7 |
# |          MaxEpRet |           -83.4 |
# |          MinEpRet |            -202 |
# |  AverageTestEpRet |            -129 |
# |      StdTestEpRet |            19.5 |
# |      MaxTestEpRet |            -107 |
# |      MinTestEpRet |            -164 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.48e+05 |
# |     AverageQ1Vals |            -112 |
# |         StdQ1Vals |            16.6 |
# |         MaxQ1Vals |           -78.5 |
# |         MinQ1Vals |            -190 |
# |     AverageQ2Vals |            -112 |
# |         StdQ2Vals |            16.6 |
# |         MaxQ2Vals |           -78.5 |
# |         MinQ2Vals |            -187 |
# |            LossPi |             111 |
# |             LossQ |            1.01 |
# |              Time |        6.73e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             394 |
# |      AverageEpRet |            -138 |
# |          StdEpRet |            23.1 |
# |          MaxEpRet |            -106 |
# |          MinEpRet |            -177 |
# |  AverageTestEpRet |            -116 |
# |      StdTestEpRet |            21.9 |
# |      MaxTestEpRet |           -77.9 |
# |      MinTestEpRet |            -152 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.5e+05 |
# |     AverageQ1Vals |            -112 |
# |         StdQ1Vals |            16.6 |
# |         MaxQ1Vals |           -78.3 |
# |         MinQ1Vals |            -188 |
# |     AverageQ2Vals |            -112 |
# |         StdQ2Vals |            16.6 |
# |         MaxQ2Vals |           -78.5 |
# |         MinQ2Vals |            -186 |
# |            LossPi |             111 |
# |             LossQ |            1.01 |
# |              Time |        6.75e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             395 |
# |      AverageEpRet |            -126 |
# |          StdEpRet |            22.4 |
# |          MaxEpRet |           -92.4 |
# |          MinEpRet |            -164 |
# |  AverageTestEpRet |            -133 |
# |      StdTestEpRet |            27.1 |
# |      MaxTestEpRet |           -96.2 |
# |      MinTestEpRet |            -166 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.52e+05 |
# |     AverageQ1Vals |            -112 |
# |         StdQ1Vals |            16.6 |
# |         MaxQ1Vals |           -78.2 |
# |         MinQ1Vals |            -188 |
# |     AverageQ2Vals |            -112 |
# |         StdQ2Vals |            16.6 |
# |         MaxQ2Vals |           -78.1 |
# |         MinQ2Vals |            -185 |
# |            LossPi |             111 |
# |             LossQ |            1.03 |
# |              Time |        6.77e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             396 |
# |      AverageEpRet |            -130 |
# |          StdEpRet |            28.1 |
# |          MaxEpRet |           -83.8 |
# |          MinEpRet |            -175 |
# |  AverageTestEpRet |            -135 |
# |      StdTestEpRet |              11 |
# |      MaxTestEpRet |            -119 |
# |      MinTestEpRet |            -151 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.53e+05 |
# |     AverageQ1Vals |            -112 |
# |         StdQ1Vals |            16.5 |
# |         MaxQ1Vals |           -78.2 |
# |         MinQ1Vals |            -191 |
# |     AverageQ2Vals |            -112 |
# |         StdQ2Vals |            16.5 |
# |         MaxQ2Vals |           -78.1 |
# |         MinQ2Vals |            -187 |
# |            LossPi |             111 |
# |             LossQ |            1.02 |
# |              Time |        6.78e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             397 |
# |      AverageEpRet |            -119 |
# |          StdEpRet |            27.2 |
# |          MaxEpRet |             -81 |
# |          MinEpRet |            -159 |
# |  AverageTestEpRet |            -133 |
# |      StdTestEpRet |            22.6 |
# |      MaxTestEpRet |             -92 |
# |      MinTestEpRet |            -170 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.55e+05 |
# |     AverageQ1Vals |            -112 |
# |         StdQ1Vals |            16.6 |
# |         MaxQ1Vals |           -78.2 |
# |         MinQ1Vals |            -191 |
# |     AverageQ2Vals |            -112 |
# |         StdQ2Vals |            16.6 |
# |         MaxQ2Vals |           -78.5 |
# |         MinQ2Vals |            -188 |
# |            LossPi |             111 |
# |             LossQ |            1.02 |
# |              Time |         6.8e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             398 |
# |      AverageEpRet |            -126 |
# |          StdEpRet |            27.7 |
# |          MaxEpRet |           -84.4 |
# |          MinEpRet |            -178 |
# |  AverageTestEpRet |            -139 |
# |      StdTestEpRet |            30.3 |
# |      MaxTestEpRet |           -68.8 |
# |      MinTestEpRet |            -186 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.57e+05 |
# |     AverageQ1Vals |            -112 |
# |         StdQ1Vals |            16.6 |
# |         MaxQ1Vals |           -77.8 |
# |         MinQ1Vals |            -186 |
# |     AverageQ2Vals |            -112 |
# |         StdQ2Vals |            16.6 |
# |         MaxQ2Vals |             -78 |
# |         MinQ2Vals |            -185 |
# |            LossPi |             111 |
# |             LossQ |            1.02 |
# |              Time |        6.82e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             399 |
# |      AverageEpRet |            -122 |
# |          StdEpRet |            27.2 |
# |          MaxEpRet |           -65.4 |
# |          MinEpRet |            -180 |
# |  AverageTestEpRet |            -137 |
# |      StdTestEpRet |            27.2 |
# |      MaxTestEpRet |           -77.4 |
# |      MinTestEpRet |            -178 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.58e+05 |
# |     AverageQ1Vals |            -111 |
# |         StdQ1Vals |            16.6 |
# |         MaxQ1Vals |           -77.9 |
# |         MinQ1Vals |            -190 |
# |     AverageQ2Vals |            -111 |
# |         StdQ2Vals |            16.6 |
# |         MaxQ2Vals |           -77.9 |
# |         MinQ2Vals |            -185 |
# |            LossPi |             111 |
# |             LossQ |            1.03 |
# |              Time |        6.84e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             400 |
# |      AverageEpRet |            -131 |
# |          StdEpRet |            25.9 |
# |          MaxEpRet |           -94.8 |
# |          MinEpRet |            -179 |
# |  AverageTestEpRet |            -129 |
# |      StdTestEpRet |            24.4 |
# |      MaxTestEpRet |           -94.3 |
# |      MinTestEpRet |            -178 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+05 |
# |     AverageQ1Vals |            -111 |
# |         StdQ1Vals |            16.5 |
# |         MaxQ1Vals |             -78 |
# |         MinQ1Vals |            -189 |
# |     AverageQ2Vals |            -111 |
# |         StdQ2Vals |            16.5 |
# |         MaxQ2Vals |           -78.1 |
# |         MinQ2Vals |            -188 |
# |            LossPi |             111 |
# |             LossQ |            1.04 |
# |              Time |        6.85e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             401 |
# |      AverageEpRet |            -128 |
# |          StdEpRet |            22.6 |
# |          MaxEpRet |           -93.5 |
# |          MinEpRet |            -166 |
# |  AverageTestEpRet |            -121 |
# |      StdTestEpRet |              27 |
# |      MaxTestEpRet |           -73.6 |
# |      MinTestEpRet |            -165 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.62e+05 |
# |     AverageQ1Vals |            -111 |
# |         StdQ1Vals |            16.5 |
# |         MaxQ1Vals |             -78 |
# |         MinQ1Vals |            -191 |
# |     AverageQ2Vals |            -111 |
# |         StdQ2Vals |            16.5 |
# |         MaxQ2Vals |           -78.2 |
# |         MinQ2Vals |            -189 |
# |            LossPi |             111 |
# |             LossQ |            1.04 |
# |              Time |        6.87e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             402 |
# |      AverageEpRet |            -124 |
# |          StdEpRet |            24.2 |
# |          MaxEpRet |           -90.1 |
# |          MinEpRet |            -177 |
# |  AverageTestEpRet |            -126 |
# |      StdTestEpRet |            16.7 |
# |      MaxTestEpRet |           -90.2 |
# |      MinTestEpRet |            -149 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.63e+05 |
# |     AverageQ1Vals |            -111 |
# |         StdQ1Vals |            16.5 |
# |         MaxQ1Vals |             -78 |
# |         MinQ1Vals |            -191 |
# |     AverageQ2Vals |            -111 |
# |         StdQ2Vals |            16.5 |
# |         MaxQ2Vals |           -77.8 |
# |         MinQ2Vals |            -189 |
# |            LossPi |             111 |
# |             LossQ |            1.01 |
# |              Time |        6.89e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             403 |
# |      AverageEpRet |            -126 |
# |          StdEpRet |            29.2 |
# |          MaxEpRet |           -86.1 |
# |          MinEpRet |            -186 |
# |  AverageTestEpRet |            -131 |
# |      StdTestEpRet |            22.1 |
# |      MaxTestEpRet |           -89.6 |
# |      MinTestEpRet |            -177 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.65e+05 |
# |     AverageQ1Vals |            -111 |
# |         StdQ1Vals |            16.6 |
# |         MaxQ1Vals |           -77.9 |
# |         MinQ1Vals |            -191 |
# |     AverageQ2Vals |            -111 |
# |         StdQ2Vals |            16.6 |
# |         MaxQ2Vals |           -77.8 |
# |         MinQ2Vals |            -189 |
# |            LossPi |             111 |
# |             LossQ |            1.04 |
# |              Time |        6.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             404 |
# |      AverageEpRet |            -134 |
# |          StdEpRet |            27.1 |
# |          MaxEpRet |           -89.1 |
# |          MinEpRet |            -197 |
# |  AverageTestEpRet |            -124 |
# |      StdTestEpRet |            24.8 |
# |      MaxTestEpRet |           -81.8 |
# |      MinTestEpRet |            -168 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.67e+05 |
# |     AverageQ1Vals |            -111 |
# |         StdQ1Vals |            16.6 |
# |         MaxQ1Vals |           -77.8 |
# |         MinQ1Vals |            -187 |
# |     AverageQ2Vals |            -111 |
# |         StdQ2Vals |            16.6 |
# |         MaxQ2Vals |           -77.9 |
# |         MinQ2Vals |            -186 |
# |            LossPi |             111 |
# |             LossQ |            1.02 |
# |              Time |        6.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             405 |
# |      AverageEpRet |            -131 |
# |          StdEpRet |            22.3 |
# |          MaxEpRet |           -95.9 |
# |          MinEpRet |            -171 |
# |  AverageTestEpRet |            -123 |
# |      StdTestEpRet |            29.2 |
# |      MaxTestEpRet |           -70.8 |
# |      MinTestEpRet |            -181 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.68e+05 |
# |     AverageQ1Vals |            -111 |
# |         StdQ1Vals |            16.5 |
# |         MaxQ1Vals |           -78.2 |
# |         MinQ1Vals |            -190 |
# |     AverageQ2Vals |            -111 |
# |         StdQ2Vals |            16.5 |
# |         MaxQ2Vals |           -78.1 |
# |         MinQ2Vals |            -188 |
# |            LossPi |             111 |
# |             LossQ |            1.03 |
# |              Time |        6.94e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             406 |
# |      AverageEpRet |            -132 |
# |          StdEpRet |              24 |
# |          MaxEpRet |           -95.5 |
# |          MinEpRet |            -173 |
# |  AverageTestEpRet |            -109 |
# |      StdTestEpRet |            31.1 |
# |      MaxTestEpRet |           -76.2 |
# |      MinTestEpRet |            -183 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.7e+05 |
# |     AverageQ1Vals |            -111 |
# |         StdQ1Vals |            16.6 |
# |         MaxQ1Vals |           -77.8 |
# |         MinQ1Vals |            -191 |
# |     AverageQ2Vals |            -111 |
# |         StdQ2Vals |            16.6 |
# |         MaxQ2Vals |           -77.7 |
# |         MinQ2Vals |            -189 |
# |            LossPi |             111 |
# |             LossQ |            1.02 |
# |              Time |        6.96e+03 |
# ---------------------------------------

# %% [markdown]
# #### Batch size

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it1_bs_var0', exp_name='td3_n_it1_bs_var0')
seed_b = 0
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.99
polyak_b = 0.999
batchsize_b = 125
startsteps_b = 20000
args_b = dict(hidden_sizes=[800], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.001
qlr_b = 0.001

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.05

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it1_bs_var1', exp_name='td3_n_it1_bs_var1')
seed_b = 0
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.99
polyak_b = 0.999
batchsize_b = 175
startsteps_b = 20000
args_b = dict(hidden_sizes=[800], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.001
qlr_b = 0.001

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.05

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %% [markdown]
# #### Discount factor

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it1_g_var0', exp_name='td3_n_it1_g_var0')
seed_b = 0
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.985
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[800], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.001
qlr_b = 0.001

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.05

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it1_g_var1', exp_name='td3_n_it1_g_var1')
seed_b = 0
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.9925
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[800], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.001
qlr_b = 0.001

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.05

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %% [markdown]
# #### Polyak

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it1_pol_var0', exp_name='td3_n_it1_pol_var0')
seed_b = 0
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.99
polyak_b = 0.9975
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[800], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.001
qlr_b = 0.001

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.05

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it1_pol_var1', exp_name='td3_n_it1_pol_var1')
seed_b = 0
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.99
polyak_b = 0.9995
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[800], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.001
qlr_b = 0.001

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.05

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %% [markdown]
# #### Noise clip

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it1_nc_var0', exp_name='td3_n_it1_nc_var0')
seed_b = 0
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.99
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[800], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.001
qlr_b = 0.001

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.04

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_it1_nc_var0', exp_name='td3_n_it1_nc_var0')
seed_b = 0
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.99
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[800], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.001
qlr_b = 0.001

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.075

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)

# %% [markdown]
# ## New baseline

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_b_it2_10', exp_name='td3_n_b_it2_10')
seed_b = 10
epochs_b = 2500
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.985
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[700], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0015
qlr_b = 0.0015

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.04

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)
# Out:
# Logging data to todelete/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             700
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	150,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fc157faa268>, env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.02, 'qx2': 0.01, 'qx4': 0.01, 'pu1': 0.5, 'pu2': 0.5}, ep_len=110)",
#     "epochs":	2500,
#     "exp_name":	"todelete",
#     "gamma":	0.985,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fc125aad438>":	{
#             "epoch_dict":	{},
#             "exp_name":	"todelete",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"todelete",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='todelete/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"todelete",
#         "output_dir":	"todelete"
#     },
#     "max_ep_len":	110,
#     "noise_clip":	0.04,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0015,
#     "policy_delay":	2,
#     "polyak":	0.999,
#     "q_lr":	0.0015,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	10,
#     "start_steps":	20000,
#     "steps_per_epoch":	1650,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 8402, 	 q1: 9101, 	 q2: 9101
#
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -332 |
# |          StdEpRet |            27.9 |
# |          MaxEpRet |            -295 |
# |          MinEpRet |            -383 |
# |  AverageTestEpRet |            -232 |
# |      StdTestEpRet |            22.8 |
# |      MaxTestEpRet |            -211 |
# |      MinTestEpRet |            -292 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |     AverageQ1Vals |           -3.37 |
# |         StdQ1Vals |           0.623 |
# |         MaxQ1Vals |           0.281 |
# |         MinQ1Vals |           -5.62 |
# |     AverageQ2Vals |           -3.37 |
# |         StdQ2Vals |           0.634 |
# |         MaxQ2Vals |           0.359 |
# |         MinQ2Vals |           -5.59 |
# |            LossPi |            3.02 |
# |             LossQ |           0.326 |
# |              Time |            6.52 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -336 |
# |          StdEpRet |            29.8 |
# |          MaxEpRet |            -298 |
# |          MinEpRet |            -405 |
# |  AverageTestEpRet |            -222 |
# |      StdTestEpRet |            12.5 |
# |      MaxTestEpRet |            -187 |
# |      MinTestEpRet |            -233 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |     AverageQ1Vals |           -4.71 |
# |         StdQ1Vals |           0.846 |
# |         MaxQ1Vals |           -2.53 |
# |         MinQ1Vals |           -8.42 |
# |     AverageQ2Vals |           -4.71 |
# |         StdQ2Vals |           0.846 |
# |         MaxQ2Vals |           -2.52 |
# |         MinQ2Vals |           -8.36 |
# |            LossPi |            4.23 |
# |             LossQ |          0.0603 |
# |              Time |              17 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -333 |
# |          StdEpRet |            22.9 |
# |          MaxEpRet |            -304 |
# |          MinEpRet |            -379 |
# |  AverageTestEpRet |            -219 |
# |      StdTestEpRet |            7.52 |
# |      MaxTestEpRet |            -201 |
# |      MinTestEpRet |            -229 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |     AverageQ1Vals |           -6.48 |
# |         StdQ1Vals |            1.04 |
# |         MaxQ1Vals |           -3.47 |
# |         MinQ1Vals |             -11 |
# |     AverageQ2Vals |           -6.48 |
# |         StdQ2Vals |            1.04 |
# |         MaxQ2Vals |           -3.54 |
# |         MinQ2Vals |             -11 |
# |            LossPi |            5.94 |
# |             LossQ |          0.0537 |
# |              Time |            27.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -330 |
# |          StdEpRet |            26.2 |
# |          MaxEpRet |            -299 |
# |          MinEpRet |            -397 |
# |  AverageTestEpRet |            -218 |
# |      StdTestEpRet |            5.18 |
# |      MaxTestEpRet |            -207 |
# |      MinTestEpRet |            -225 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |     AverageQ1Vals |           -8.19 |
# |         StdQ1Vals |            1.21 |
# |         MaxQ1Vals |           -4.51 |
# |         MinQ1Vals |           -13.2 |
# |     AverageQ2Vals |           -8.19 |
# |         StdQ2Vals |            1.22 |
# |         MaxQ2Vals |           -4.56 |
# |         MinQ2Vals |           -13.2 |
# |            LossPi |            7.57 |
# |             LossQ |          0.0563 |
# |              Time |            38.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -330 |
# |          StdEpRet |            23.1 |
# |          MaxEpRet |            -295 |
# |          MinEpRet |            -376 |
# |  AverageTestEpRet |            -218 |
# |      StdTestEpRet |            4.38 |
# |      MaxTestEpRet |            -210 |
# |      MinTestEpRet |            -225 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |     AverageQ1Vals |            -9.9 |
# |         StdQ1Vals |             1.4 |
# |         MaxQ1Vals |            -5.6 |
# |         MinQ1Vals |           -15.9 |
# |     AverageQ2Vals |            -9.9 |
# |         StdQ2Vals |            1.41 |
# |         MaxQ2Vals |           -5.68 |
# |         MinQ2Vals |           -15.8 |
# |            LossPi |            9.21 |
# |             LossQ |          0.0639 |
# |              Time |            48.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -322 |
# |          StdEpRet |            23.9 |
# |          MaxEpRet |            -283 |
# |          MinEpRet |            -373 |
# |  AverageTestEpRet |            -216 |
# |      StdTestEpRet |            5.22 |
# |      MaxTestEpRet |            -206 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |     AverageQ1Vals |           -11.5 |
# |         StdQ1Vals |            1.56 |
# |         MaxQ1Vals |           -6.84 |
# |         MinQ1Vals |           -18.1 |
# |     AverageQ2Vals |           -11.5 |
# |         StdQ2Vals |            1.56 |
# |         MaxQ2Vals |            -6.8 |
# |         MinQ2Vals |           -18.2 |
# |            LossPi |            10.8 |
# |             LossQ |          0.0703 |
# |              Time |            58.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -321 |
# |          StdEpRet |            23.1 |
# |          MaxEpRet |            -283 |
# |          MinEpRet |            -362 |
# |  AverageTestEpRet |            -216 |
# |      StdTestEpRet |            5.26 |
# |      MaxTestEpRet |            -206 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |     AverageQ1Vals |           -13.1 |
# |         StdQ1Vals |            1.71 |
# |         MaxQ1Vals |           -8.11 |
# |         MinQ1Vals |           -20.1 |
# |     AverageQ2Vals |           -13.1 |
# |         StdQ2Vals |            1.71 |
# |         MaxQ2Vals |           -8.07 |
# |         MinQ2Vals |             -20 |
# |            LossPi |            12.3 |
# |             LossQ |          0.0751 |
# |              Time |            68.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -323 |
# |          StdEpRet |            23.3 |
# |          MaxEpRet |            -287 |
# |          MinEpRet |            -371 |
# |  AverageTestEpRet |            -216 |
# |      StdTestEpRet |            4.56 |
# |      MaxTestEpRet |            -206 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |     AverageQ1Vals |           -14.6 |
# |         StdQ1Vals |            1.81 |
# |         MaxQ1Vals |           -9.37 |
# |         MinQ1Vals |           -22.3 |
# |     AverageQ2Vals |           -14.6 |
# |         StdQ2Vals |            1.81 |
# |         MaxQ2Vals |           -9.36 |
# |         MinQ2Vals |           -22.1 |
# |            LossPi |            13.7 |
# |             LossQ |          0.0804 |
# |              Time |            79.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -328 |
# |          StdEpRet |            27.7 |
# |          MaxEpRet |            -291 |
# |          MinEpRet |            -390 |
# |  AverageTestEpRet |            -219 |
# |      StdTestEpRet |            4.15 |
# |      MaxTestEpRet |            -207 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |     AverageQ1Vals |           -16.1 |
# |         StdQ1Vals |            1.92 |
# |         MaxQ1Vals |           -10.7 |
# |         MinQ1Vals |           -24.3 |
# |     AverageQ2Vals |           -16.1 |
# |         StdQ2Vals |            1.92 |
# |         MaxQ2Vals |           -10.7 |
# |         MinQ2Vals |           -24.2 |
# |            LossPi |            15.2 |
# |             LossQ |          0.0891 |
# |              Time |            91.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -321 |
# |          StdEpRet |              21 |
# |          MaxEpRet |            -291 |
# |          MinEpRet |            -373 |
# |  AverageTestEpRet |            -216 |
# |      StdTestEpRet |            6.95 |
# |      MaxTestEpRet |            -199 |
# |      MinTestEpRet |            -224 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -17.5 |
# |         StdQ1Vals |            1.99 |
# |         MaxQ1Vals |           -11.9 |
# |         MinQ1Vals |             -26 |
# |     AverageQ2Vals |           -17.5 |
# |         StdQ2Vals |            1.99 |
# |         MaxQ2Vals |           -11.7 |
# |         MinQ2Vals |           -25.8 |
# |            LossPi |            16.6 |
# |             LossQ |           0.101 |
# |              Time |             102 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -324 |
# |          StdEpRet |              32 |
# |          MaxEpRet |            -280 |
# |          MinEpRet |            -371 |
# |  AverageTestEpRet |            -218 |
# |      StdTestEpRet |            2.33 |
# |      MaxTestEpRet |            -214 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |     AverageQ1Vals |           -18.9 |
# |         StdQ1Vals |            2.07 |
# |         MaxQ1Vals |             -13 |
# |         MinQ1Vals |           -27.4 |
# |     AverageQ2Vals |           -18.9 |
# |         StdQ2Vals |            2.07 |
# |         MaxQ2Vals |           -12.8 |
# |         MinQ2Vals |           -27.3 |
# |            LossPi |            17.9 |
# |             LossQ |           0.108 |
# |              Time |             113 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -334 |
# |          StdEpRet |            28.6 |
# |          MaxEpRet |            -301 |
# |          MinEpRet |            -399 |
# |  AverageTestEpRet |            -216 |
# |      StdTestEpRet |            6.29 |
# |      MaxTestEpRet |            -200 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |     AverageQ1Vals |           -20.3 |
# |         StdQ1Vals |            2.15 |
# |         MaxQ1Vals |           -14.3 |
# |         MinQ1Vals |           -29.2 |
# |     AverageQ2Vals |           -20.3 |
# |         StdQ2Vals |            2.15 |
# |         MaxQ2Vals |           -14.2 |
# |         MinQ2Vals |           -28.9 |
# |            LossPi |            19.3 |
# |             LossQ |           0.116 |
# |              Time |             124 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -230 |
# |          StdEpRet |            33.6 |
# |          MaxEpRet |            -201 |
# |          MinEpRet |            -324 |
# |  AverageTestEpRet |            -213 |
# |      StdTestEpRet |             8.5 |
# |      MaxTestEpRet |            -196 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |     AverageQ1Vals |           -21.6 |
# |         StdQ1Vals |            2.23 |
# |         MaxQ1Vals |           -15.5 |
# |         MinQ1Vals |           -30.6 |
# |     AverageQ2Vals |           -21.6 |
# |         StdQ2Vals |            2.23 |
# |         MaxQ2Vals |           -15.4 |
# |         MinQ2Vals |           -30.4 |
# |            LossPi |            20.6 |
# |             LossQ |           0.118 |
# |              Time |             136 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -219 |
# |          StdEpRet |            5.94 |
# |          MaxEpRet |            -199 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -219 |
# |      StdTestEpRet |            4.39 |
# |      MaxTestEpRet |            -211 |
# |      MinTestEpRet |            -226 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |     AverageQ1Vals |           -22.7 |
# |         StdQ1Vals |            2.37 |
# |         MaxQ1Vals |           -16.3 |
# |         MinQ1Vals |           -32.2 |
# |     AverageQ2Vals |           -22.7 |
# |         StdQ2Vals |            2.37 |
# |         MaxQ2Vals |           -16.3 |
# |         MinQ2Vals |           -32.2 |
# |            LossPi |            21.7 |
# |             LossQ |           0.111 |
# |              Time |             146 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -219 |
# |          StdEpRet |            9.57 |
# |          MaxEpRet |            -190 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -219 |
# |      StdTestEpRet |            2.79 |
# |      MaxTestEpRet |            -215 |
# |      MinTestEpRet |            -225 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |     AverageQ1Vals |           -23.8 |
# |         StdQ1Vals |            2.45 |
# |         MaxQ1Vals |           -17.4 |
# |         MinQ1Vals |           -33.8 |
# |     AverageQ2Vals |           -23.8 |
# |         StdQ2Vals |            2.45 |
# |         MaxQ2Vals |           -17.5 |
# |         MinQ2Vals |           -33.8 |
# |            LossPi |            22.9 |
# |             LossQ |           0.106 |
# |              Time |             156 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -218 |
# |          StdEpRet |            6.96 |
# |          MaxEpRet |            -203 |
# |          MinEpRet |            -227 |
# |  AverageTestEpRet |            -218 |
# |      StdTestEpRet |            8.78 |
# |      MaxTestEpRet |            -197 |
# |      MinTestEpRet |            -229 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |     AverageQ1Vals |           -24.9 |
# |         StdQ1Vals |            2.51 |
# |         MaxQ1Vals |           -18.5 |
# |         MinQ1Vals |           -34.9 |
# |     AverageQ2Vals |           -24.9 |
# |         StdQ2Vals |            2.51 |
# |         MaxQ2Vals |           -18.5 |
# |         MinQ2Vals |           -34.9 |
# |            LossPi |              24 |
# |             LossQ |           0.103 |
# |              Time |             168 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -219 |
# |          StdEpRet |             6.2 |
# |          MaxEpRet |            -198 |
# |          MinEpRet |            -224 |
# |  AverageTestEpRet |            -216 |
# |      StdTestEpRet |            5.43 |
# |      MaxTestEpRet |            -206 |
# |      MinTestEpRet |            -224 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |             -26 |
# |         StdQ1Vals |            2.55 |
# |         MaxQ1Vals |           -19.6 |
# |         MinQ1Vals |           -36.3 |
# |     AverageQ2Vals |             -26 |
# |         StdQ2Vals |            2.55 |
# |         MaxQ2Vals |           -19.7 |
# |         MinQ2Vals |           -36.2 |
# |            LossPi |            25.2 |
# |             LossQ |           0.102 |
# |              Time |             180 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -218 |
# |          StdEpRet |            8.41 |
# |          MaxEpRet |            -196 |
# |          MinEpRet |            -229 |
# |  AverageTestEpRet |            -220 |
# |      StdTestEpRet |            4.11 |
# |      MaxTestEpRet |            -212 |
# |      MinTestEpRet |            -228 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |     AverageQ1Vals |           -27.1 |
# |         StdQ1Vals |            2.58 |
# |         MaxQ1Vals |           -20.6 |
# |         MinQ1Vals |           -37.6 |
# |     AverageQ2Vals |           -27.1 |
# |         StdQ2Vals |            2.58 |
# |         MaxQ2Vals |           -20.5 |
# |         MinQ2Vals |           -37.6 |
# |            LossPi |            26.4 |
# |             LossQ |          0.0986 |
# |              Time |             194 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -219 |
# |          StdEpRet |            8.85 |
# |          MaxEpRet |            -188 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -218 |
# |      StdTestEpRet |            5.34 |
# |      MaxTestEpRet |            -210 |
# |      MinTestEpRet |            -228 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |     AverageQ1Vals |           -28.2 |
# |         StdQ1Vals |             2.6 |
# |         MaxQ1Vals |           -21.9 |
# |         MinQ1Vals |           -39.6 |
# |     AverageQ2Vals |           -28.2 |
# |         StdQ2Vals |             2.6 |
# |         MaxQ2Vals |           -21.9 |
# |         MinQ2Vals |           -39.4 |
# |            LossPi |            27.5 |
# |             LossQ |          0.0991 |
# |              Time |             213 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -220 |
# |          StdEpRet |            5.25 |
# |          MaxEpRet |            -206 |
# |          MinEpRet |            -227 |
# |  AverageTestEpRet |            -217 |
# |      StdTestEpRet |            4.72 |
# |      MaxTestEpRet |            -208 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -29.4 |
# |         StdQ1Vals |             2.6 |
# |         MaxQ1Vals |           -22.9 |
# |         MinQ1Vals |           -40.6 |
# |     AverageQ2Vals |           -29.4 |
# |         StdQ2Vals |             2.6 |
# |         MaxQ2Vals |           -22.9 |
# |         MinQ2Vals |           -40.8 |
# |            LossPi |            28.7 |
# |             LossQ |          0.0977 |
# |              Time |             223 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -215 |
# |          StdEpRet |              10 |
# |          MaxEpRet |            -188 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -214 |
# |      StdTestEpRet |            7.43 |
# |      MaxTestEpRet |            -199 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |     AverageQ1Vals |           -30.5 |
# |         StdQ1Vals |            2.62 |
# |         MaxQ1Vals |           -23.9 |
# |         MinQ1Vals |           -42.2 |
# |     AverageQ2Vals |           -30.5 |
# |         StdQ2Vals |            2.62 |
# |         MaxQ2Vals |             -24 |
# |         MinQ2Vals |           -42.3 |
# |            LossPi |            29.9 |
# |             LossQ |          0.0951 |
# |              Time |             234 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -217 |
# |          StdEpRet |            6.96 |
# |          MaxEpRet |            -204 |
# |          MinEpRet |            -228 |
# |  AverageTestEpRet |            -215 |
# |      StdTestEpRet |            3.32 |
# |      MaxTestEpRet |            -209 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |     AverageQ1Vals |           -31.6 |
# |         StdQ1Vals |            2.63 |
# |         MaxQ1Vals |           -25.2 |
# |         MinQ1Vals |           -43.2 |
# |     AverageQ2Vals |           -31.6 |
# |         StdQ2Vals |            2.63 |
# |         MaxQ2Vals |           -25.1 |
# |         MinQ2Vals |           -43.2 |
# |            LossPi |              31 |
# |             LossQ |          0.0951 |
# |              Time |             245 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -218 |
# |          StdEpRet |            5.71 |
# |          MaxEpRet |            -206 |
# |          MinEpRet |            -227 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |            19.7 |
# |      MaxTestEpRet |            -154 |
# |      MinTestEpRet |            -225 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |     AverageQ1Vals |           -32.7 |
# |         StdQ1Vals |            2.63 |
# |         MaxQ1Vals |           -26.3 |
# |         MinQ1Vals |           -44.6 |
# |     AverageQ2Vals |           -32.7 |
# |         StdQ2Vals |            2.63 |
# |         MaxQ2Vals |           -26.2 |
# |         MinQ2Vals |           -44.9 |
# |            LossPi |            32.1 |
# |             LossQ |          0.0945 |
# |              Time |             256 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -216 |
# |          StdEpRet |            9.18 |
# |          MaxEpRet |            -187 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -219 |
# |      StdTestEpRet |            5.23 |
# |      MaxTestEpRet |            -204 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |     AverageQ1Vals |           -33.8 |
# |         StdQ1Vals |            2.64 |
# |         MaxQ1Vals |           -27.3 |
# |         MinQ1Vals |             -46 |
# |     AverageQ2Vals |           -33.8 |
# |         StdQ2Vals |            2.64 |
# |         MaxQ2Vals |           -27.3 |
# |         MinQ2Vals |           -46.1 |
# |            LossPi |            33.3 |
# |             LossQ |          0.0932 |
# |              Time |             267 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -216 |
# |          StdEpRet |               7 |
# |          MaxEpRet |            -196 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -216 |
# |      StdTestEpRet |            5.23 |
# |      MaxTestEpRet |            -205 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |     AverageQ1Vals |           -34.9 |
# |         StdQ1Vals |            2.64 |
# |         MaxQ1Vals |           -28.4 |
# |         MinQ1Vals |           -47.3 |
# |     AverageQ2Vals |           -34.9 |
# |         StdQ2Vals |            2.64 |
# |         MaxQ2Vals |           -28.4 |
# |         MinQ2Vals |           -47.4 |
# |            LossPi |            34.4 |
# |             LossQ |          0.0926 |
# |              Time |             278 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -219 |
# |          StdEpRet |               6 |
# |          MaxEpRet |            -203 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -215 |
# |      StdTestEpRet |            3.89 |
# |      MaxTestEpRet |            -208 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |     AverageQ1Vals |             -36 |
# |         StdQ1Vals |            2.64 |
# |         MaxQ1Vals |           -29.5 |
# |         MinQ1Vals |             -48 |
# |     AverageQ2Vals |             -36 |
# |         StdQ2Vals |            2.64 |
# |         MaxQ2Vals |           -29.4 |
# |         MinQ2Vals |           -48.2 |
# |            LossPi |            35.5 |
# |             LossQ |          0.0939 |
# |              Time |             290 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -218 |
# |          StdEpRet |            5.53 |
# |          MaxEpRet |            -204 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -215 |
# |      StdTestEpRet |            6.22 |
# |      MaxTestEpRet |            -201 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |     AverageQ1Vals |           -37.1 |
# |         StdQ1Vals |            2.64 |
# |         MaxQ1Vals |           -30.6 |
# |         MinQ1Vals |           -48.7 |
# |     AverageQ2Vals |           -37.1 |
# |         StdQ2Vals |            2.64 |
# |         MaxQ2Vals |           -30.5 |
# |         MinQ2Vals |           -48.7 |
# |            LossPi |            36.6 |
# |             LossQ |          0.0932 |
# |              Time |             304 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -217 |
# |          StdEpRet |            6.53 |
# |          MaxEpRet |            -206 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |            21.5 |
# |      MaxTestEpRet |            -153 |
# |      MinTestEpRet |            -226 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |     AverageQ1Vals |           -38.2 |
# |         StdQ1Vals |            2.64 |
# |         MaxQ1Vals |           -31.6 |
# |         MinQ1Vals |           -50.1 |
# |     AverageQ2Vals |           -38.2 |
# |         StdQ2Vals |            2.64 |
# |         MaxQ2Vals |           -31.5 |
# |         MinQ2Vals |           -50.2 |
# |            LossPi |            37.7 |
# |             LossQ |          0.0926 |
# |              Time |             317 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -217 |
# |          StdEpRet |            9.83 |
# |          MaxEpRet |            -190 |
# |          MinEpRet |            -227 |
# |  AverageTestEpRet |            -216 |
# |      StdTestEpRet |            9.43 |
# |      MaxTestEpRet |            -191 |
# |      MinTestEpRet |            -224 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |     AverageQ1Vals |           -39.3 |
# |         StdQ1Vals |            2.64 |
# |         MaxQ1Vals |           -32.7 |
# |         MinQ1Vals |           -51.9 |
# |     AverageQ2Vals |           -39.3 |
# |         StdQ2Vals |            2.64 |
# |         MaxQ2Vals |           -32.8 |
# |         MinQ2Vals |           -52.1 |
# |            LossPi |            38.8 |
# |             LossQ |          0.0937 |
# |              Time |             328 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -218 |
# |          StdEpRet |            6.74 |
# |          MaxEpRet |            -202 |
# |          MinEpRet |            -229 |
# |  AverageTestEpRet |            -215 |
# |      StdTestEpRet |            7.93 |
# |      MaxTestEpRet |            -192 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -40.4 |
# |         StdQ1Vals |            2.63 |
# |         MaxQ1Vals |           -33.7 |
# |         MinQ1Vals |             -53 |
# |     AverageQ2Vals |           -40.4 |
# |         StdQ2Vals |            2.63 |
# |         MaxQ2Vals |           -33.7 |
# |         MinQ2Vals |           -53.4 |
# |            LossPi |            39.9 |
# |             LossQ |           0.093 |
# |              Time |             339 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -213 |
# |          StdEpRet |            7.39 |
# |          MaxEpRet |            -203 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -214 |
# |      StdTestEpRet |            8.16 |
# |      MaxTestEpRet |            -194 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |     AverageQ1Vals |           -41.4 |
# |         StdQ1Vals |            2.63 |
# |         MaxQ1Vals |           -34.6 |
# |         MinQ1Vals |             -54 |
# |     AverageQ2Vals |           -41.4 |
# |         StdQ2Vals |            2.63 |
# |         MaxQ2Vals |           -34.7 |
# |         MinQ2Vals |           -54.2 |
# |            LossPi |              41 |
# |             LossQ |          0.0941 |
# |              Time |             352 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -217 |
# |          StdEpRet |            8.61 |
# |          MaxEpRet |            -189 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -218 |
# |      StdTestEpRet |            5.16 |
# |      MaxTestEpRet |            -205 |
# |      MinTestEpRet |            -225 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |     AverageQ1Vals |           -42.5 |
# |         StdQ1Vals |            2.63 |
# |         MaxQ1Vals |           -35.4 |
# |         MinQ1Vals |           -55.2 |
# |     AverageQ2Vals |           -42.5 |
# |         StdQ2Vals |            2.63 |
# |         MaxQ2Vals |           -35.5 |
# |         MinQ2Vals |           -55.3 |
# |            LossPi |              42 |
# |             LossQ |          0.0959 |
# |              Time |             366 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -219 |
# |          StdEpRet |            3.83 |
# |          MaxEpRet |            -212 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -215 |
# |      StdTestEpRet |            10.6 |
# |      MaxTestEpRet |            -185 |
# |      MinTestEpRet |            -225 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |     AverageQ1Vals |           -43.5 |
# |         StdQ1Vals |            2.64 |
# |         MaxQ1Vals |           -36.4 |
# |         MinQ1Vals |           -56.8 |
# |     AverageQ2Vals |           -43.5 |
# |         StdQ2Vals |            2.64 |
# |         MaxQ2Vals |           -36.4 |
# |         MinQ2Vals |             -57 |
# |            LossPi |            43.1 |
# |             LossQ |          0.0959 |
# |              Time |             377 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -220 |
# |          StdEpRet |            4.05 |
# |          MaxEpRet |            -213 |
# |          MinEpRet |            -227 |
# |  AverageTestEpRet |            -203 |
# |      StdTestEpRet |            25.5 |
# |      MaxTestEpRet |            -141 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |     AverageQ1Vals |           -44.5 |
# |         StdQ1Vals |            2.62 |
# |         MaxQ1Vals |           -37.4 |
# |         MinQ1Vals |           -57.8 |
# |     AverageQ2Vals |           -44.5 |
# |         StdQ2Vals |            2.62 |
# |         MaxQ2Vals |           -37.4 |
# |         MinQ2Vals |           -57.9 |
# |            LossPi |            44.1 |
# |             LossQ |          0.0956 |
# |              Time |             388 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -216 |
# |          StdEpRet |            8.09 |
# |          MaxEpRet |            -197 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -216 |
# |      StdTestEpRet |             4.9 |
# |      MaxTestEpRet |            -203 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |     AverageQ1Vals |           -45.6 |
# |         StdQ1Vals |            2.62 |
# |         MaxQ1Vals |           -38.2 |
# |         MinQ1Vals |           -58.3 |
# |     AverageQ2Vals |           -45.6 |
# |         StdQ2Vals |            2.62 |
# |         MaxQ2Vals |           -38.1 |
# |         MinQ2Vals |           -58.4 |
# |            LossPi |            45.2 |
# |             LossQ |          0.0973 |
# |              Time |             399 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -213 |
# |          StdEpRet |            8.12 |
# |          MaxEpRet |            -196 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -210 |
# |      StdTestEpRet |            18.1 |
# |      MaxTestEpRet |            -158 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |     AverageQ1Vals |           -46.6 |
# |         StdQ1Vals |            2.61 |
# |         MaxQ1Vals |             -39 |
# |         MinQ1Vals |           -59.9 |
# |     AverageQ2Vals |           -46.6 |
# |         StdQ2Vals |            2.61 |
# |         MaxQ2Vals |           -39.2 |
# |         MinQ2Vals |           -60.1 |
# |            LossPi |            46.2 |
# |             LossQ |          0.0987 |
# |              Time |             410 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -217 |
# |          StdEpRet |             4.1 |
# |          MaxEpRet |            -210 |
# |          MinEpRet |            -224 |
# |  AverageTestEpRet |            -217 |
# |      StdTestEpRet |            5.06 |
# |      MaxTestEpRet |            -209 |
# |      MinTestEpRet |            -225 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |     AverageQ1Vals |           -47.6 |
# |         StdQ1Vals |            2.63 |
# |         MaxQ1Vals |           -40.1 |
# |         MinQ1Vals |           -60.7 |
# |     AverageQ2Vals |           -47.6 |
# |         StdQ2Vals |            2.63 |
# |         MaxQ2Vals |             -40 |
# |         MinQ2Vals |           -60.8 |
# |            LossPi |            47.2 |
# |             LossQ |          0.0996 |
# |              Time |             421 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -207 |
# |          StdEpRet |            13.4 |
# |          MaxEpRet |            -184 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -215 |
# |      StdTestEpRet |             5.2 |
# |      MaxTestEpRet |            -207 |
# |      MinTestEpRet |            -225 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |     AverageQ1Vals |           -48.6 |
# |         StdQ1Vals |            2.63 |
# |         MaxQ1Vals |             -41 |
# |         MinQ1Vals |           -60.8 |
# |     AverageQ2Vals |           -48.6 |
# |         StdQ2Vals |            2.63 |
# |         MaxQ2Vals |             -41 |
# |         MinQ2Vals |           -60.7 |
# |            LossPi |            48.2 |
# |             LossQ |           0.101 |
# |              Time |             432 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -217 |
# |          StdEpRet |            7.53 |
# |          MaxEpRet |            -199 |
# |          MinEpRet |            -227 |
# |  AverageTestEpRet |            -213 |
# |      StdTestEpRet |            8.99 |
# |      MaxTestEpRet |            -197 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |     AverageQ1Vals |           -49.5 |
# |         StdQ1Vals |            2.64 |
# |         MaxQ1Vals |           -41.9 |
# |         MinQ1Vals |             -63 |
# |     AverageQ2Vals |           -49.5 |
# |         StdQ2Vals |            2.64 |
# |         MaxQ2Vals |           -41.9 |
# |         MinQ2Vals |           -63.1 |
# |            LossPi |            49.2 |
# |             LossQ |           0.104 |
# |              Time |             443 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -210 |
# |          StdEpRet |            10.8 |
# |          MaxEpRet |            -185 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -217 |
# |      StdTestEpRet |            7.04 |
# |      MaxTestEpRet |            -198 |
# |      MinTestEpRet |            -227 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -50.5 |
# |         StdQ1Vals |            2.65 |
# |         MaxQ1Vals |           -42.6 |
# |         MinQ1Vals |           -63.2 |
# |     AverageQ2Vals |           -50.5 |
# |         StdQ2Vals |            2.65 |
# |         MaxQ2Vals |           -42.5 |
# |         MinQ2Vals |           -63.6 |
# |            LossPi |            50.1 |
# |             LossQ |           0.102 |
# |              Time |             454 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -214 |
# |          StdEpRet |            7.75 |
# |          MaxEpRet |            -197 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -214 |
# |      StdTestEpRet |            7.53 |
# |      MaxTestEpRet |            -198 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |     AverageQ1Vals |           -51.4 |
# |         StdQ1Vals |            2.67 |
# |         MaxQ1Vals |           -43.7 |
# |         MinQ1Vals |           -65.3 |
# |     AverageQ2Vals |           -51.4 |
# |         StdQ2Vals |            2.67 |
# |         MaxQ2Vals |           -43.7 |
# |         MinQ2Vals |           -65.2 |
# |            LossPi |            51.1 |
# |             LossQ |           0.103 |
# |              Time |             465 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -213 |
# |          StdEpRet |            14.1 |
# |          MaxEpRet |            -173 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -212 |
# |      StdTestEpRet |            7.73 |
# |      MaxTestEpRet |            -193 |
# |      MinTestEpRet |            -222 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |     AverageQ1Vals |           -52.3 |
# |         StdQ1Vals |            2.68 |
# |         MaxQ1Vals |           -44.5 |
# |         MinQ1Vals |           -65.6 |
# |     AverageQ2Vals |           -52.3 |
# |         StdQ2Vals |            2.68 |
# |         MaxQ2Vals |           -44.6 |
# |         MinQ2Vals |             -66 |
# |            LossPi |              52 |
# |             LossQ |           0.104 |
# |              Time |             477 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -217 |
# |          StdEpRet |            6.14 |
# |          MaxEpRet |            -205 |
# |          MinEpRet |            -224 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |            10.5 |
# |      MaxTestEpRet |            -182 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |     AverageQ1Vals |           -53.3 |
# |         StdQ1Vals |            2.69 |
# |         MaxQ1Vals |           -45.3 |
# |         MinQ1Vals |             -67 |
# |     AverageQ2Vals |           -53.3 |
# |         StdQ2Vals |            2.69 |
# |         MaxQ2Vals |           -45.4 |
# |         MinQ2Vals |             -67 |
# |            LossPi |            52.9 |
# |             LossQ |           0.107 |
# |              Time |             492 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -212 |
# |          StdEpRet |             8.5 |
# |          MaxEpRet |            -198 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -215 |
# |      StdTestEpRet |            6.41 |
# |      MaxTestEpRet |            -201 |
# |      MinTestEpRet |            -224 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |     AverageQ1Vals |           -54.2 |
# |         StdQ1Vals |             2.7 |
# |         MaxQ1Vals |           -46.4 |
# |         MinQ1Vals |           -68.1 |
# |     AverageQ2Vals |           -54.2 |
# |         StdQ2Vals |             2.7 |
# |         MaxQ2Vals |           -46.3 |
# |         MinQ2Vals |           -68.3 |
# |            LossPi |            53.8 |
# |             LossQ |           0.108 |
# |              Time |             505 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -213 |
# |          StdEpRet |            9.87 |
# |          MaxEpRet |            -192 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -210 |
# |      StdTestEpRet |             9.3 |
# |      MaxTestEpRet |            -186 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |     AverageQ1Vals |           -55.1 |
# |         StdQ1Vals |            2.72 |
# |         MaxQ1Vals |             -47 |
# |         MinQ1Vals |             -69 |
# |     AverageQ2Vals |           -55.1 |
# |         StdQ2Vals |            2.72 |
# |         MaxQ2Vals |             -47 |
# |         MinQ2Vals |           -69.2 |
# |            LossPi |            54.7 |
# |             LossQ |           0.107 |
# |              Time |             519 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -214 |
# |          StdEpRet |            8.56 |
# |          MaxEpRet |            -189 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -217 |
# |      StdTestEpRet |            6.87 |
# |      MaxTestEpRet |            -197 |
# |      MinTestEpRet |            -224 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |     AverageQ1Vals |             -56 |
# |         StdQ1Vals |            2.74 |
# |         MaxQ1Vals |           -47.9 |
# |         MinQ1Vals |           -69.8 |
# |     AverageQ2Vals |             -56 |
# |         StdQ2Vals |            2.74 |
# |         MaxQ2Vals |           -47.9 |
# |         MinQ2Vals |           -70.1 |
# |            LossPi |            55.6 |
# |             LossQ |           0.109 |
# |              Time |             533 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            -214 |
# |          StdEpRet |            6.69 |
# |          MaxEpRet |            -197 |
# |          MinEpRet |            -226 |
# |  AverageTestEpRet |            -210 |
# |      StdTestEpRet |            7.37 |
# |      MaxTestEpRet |            -196 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# ...
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.26e+05 |
# |     AverageQ1Vals |           -99.7 |
# |         StdQ1Vals |            6.15 |
# |         MaxQ1Vals |           -84.6 |
# |         MinQ1Vals |            -123 |
# |     AverageQ2Vals |           -99.7 |
# |         StdQ2Vals |            6.15 |
# |         MaxQ2Vals |           -84.5 |
# |         MinQ2Vals |            -122 |
# |            LossPi |            99.4 |
# |             LossQ |           0.339 |
# |              Time |        1.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             138 |
# |      AverageEpRet |            -178 |
# |          StdEpRet |            26.9 |
# |          MaxEpRet |            -140 |
# |          MinEpRet |            -230 |
# |  AverageTestEpRet |            -187 |
# |      StdTestEpRet |            20.7 |
# |      MaxTestEpRet |            -145 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.28e+05 |
# |     AverageQ1Vals |           -99.9 |
# |         StdQ1Vals |             6.2 |
# |         MaxQ1Vals |           -84.6 |
# |         MinQ1Vals |            -125 |
# |     AverageQ2Vals |           -99.9 |
# |         StdQ2Vals |             6.2 |
# |         MaxQ2Vals |           -84.6 |
# |         MinQ2Vals |            -124 |
# |            LossPi |            99.6 |
# |             LossQ |           0.345 |
# |              Time |        1.53e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             139 |
# |      AverageEpRet |            -176 |
# |          StdEpRet |            19.7 |
# |          MaxEpRet |            -140 |
# |          MinEpRet |            -215 |
# |  AverageTestEpRet |            -191 |
# |      StdTestEpRet |            23.4 |
# |      MaxTestEpRet |            -126 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.29e+05 |
# |     AverageQ1Vals |            -100 |
# |         StdQ1Vals |            6.25 |
# |         MaxQ1Vals |           -84.8 |
# |         MinQ1Vals |            -124 |
# |     AverageQ2Vals |            -100 |
# |         StdQ2Vals |            6.25 |
# |         MaxQ2Vals |           -84.7 |
# |         MinQ2Vals |            -123 |
# |            LossPi |            99.7 |
# |             LossQ |            0.34 |
# |              Time |        1.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             140 |
# |      AverageEpRet |            -179 |
# |          StdEpRet |            19.8 |
# |          MaxEpRet |            -138 |
# |          MinEpRet |            -204 |
# |  AverageTestEpRet |            -181 |
# |      StdTestEpRet |            25.7 |
# |      MaxTestEpRet |            -125 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+05 |
# |     AverageQ1Vals |            -100 |
# |         StdQ1Vals |             6.3 |
# |         MaxQ1Vals |           -84.9 |
# |         MinQ1Vals |            -124 |
# |     AverageQ2Vals |            -100 |
# |         StdQ2Vals |            6.31 |
# |         MaxQ2Vals |           -84.8 |
# |         MinQ2Vals |            -124 |
# |            LossPi |             100 |
# |             LossQ |           0.352 |
# |              Time |        1.55e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             141 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            22.3 |
# |          MaxEpRet |            -155 |
# |          MinEpRet |            -232 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            17.4 |
# |      MaxTestEpRet |            -162 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.33e+05 |
# |     AverageQ1Vals |            -100 |
# |         StdQ1Vals |            6.36 |
# |         MaxQ1Vals |           -84.8 |
# |         MinQ1Vals |            -124 |
# |     AverageQ2Vals |            -100 |
# |         StdQ2Vals |            6.36 |
# |         MaxQ2Vals |           -84.8 |
# |         MinQ2Vals |            -123 |
# |            LossPi |             100 |
# |             LossQ |           0.355 |
# |              Time |        1.57e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             142 |
# |      AverageEpRet |            -187 |
# |          StdEpRet |            23.7 |
# |          MaxEpRet |            -144 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -188 |
# |      StdTestEpRet |            32.5 |
# |      MaxTestEpRet |            -135 |
# |      MinTestEpRet |            -240 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.34e+05 |
# |     AverageQ1Vals |            -101 |
# |         StdQ1Vals |            6.39 |
# |         MaxQ1Vals |           -84.9 |
# |         MinQ1Vals |            -125 |
# |     AverageQ2Vals |            -101 |
# |         StdQ2Vals |            6.39 |
# |         MaxQ2Vals |           -84.9 |
# |         MinQ2Vals |            -125 |
# |            LossPi |             100 |
# |             LossQ |           0.357 |
# |              Time |        1.58e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             143 |
# |      AverageEpRet |            -184 |
# |          StdEpRet |              23 |
# |          MaxEpRet |            -130 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -174 |
# |      StdTestEpRet |            25.9 |
# |      MaxTestEpRet |            -128 |
# |      MinTestEpRet |            -209 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.36e+05 |
# |     AverageQ1Vals |            -101 |
# |         StdQ1Vals |            6.45 |
# |         MaxQ1Vals |           -84.7 |
# |         MinQ1Vals |            -125 |
# |     AverageQ2Vals |            -101 |
# |         StdQ2Vals |            6.45 |
# |         MaxQ2Vals |           -84.9 |
# |         MinQ2Vals |            -125 |
# |            LossPi |             100 |
# |             LossQ |           0.359 |
# |              Time |        1.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             144 |
# |      AverageEpRet |            -187 |
# |          StdEpRet |            24.8 |
# |          MaxEpRet |            -130 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -186 |
# |      StdTestEpRet |            21.1 |
# |      MaxTestEpRet |            -149 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.38e+05 |
# |     AverageQ1Vals |            -101 |
# |         StdQ1Vals |            6.51 |
# |         MaxQ1Vals |           -84.9 |
# |         MinQ1Vals |            -124 |
# |     AverageQ2Vals |            -101 |
# |         StdQ2Vals |            6.51 |
# |         MaxQ2Vals |             -85 |
# |         MinQ2Vals |            -124 |
# |            LossPi |             101 |
# |             LossQ |           0.369 |
# |              Time |         1.6e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             145 |
# |      AverageEpRet |            -195 |
# |          StdEpRet |            18.2 |
# |          MaxEpRet |            -150 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -170 |
# |      StdTestEpRet |            34.6 |
# |      MaxTestEpRet |            -100 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.39e+05 |
# |     AverageQ1Vals |            -101 |
# |         StdQ1Vals |            6.54 |
# |         MaxQ1Vals |           -84.9 |
# |         MinQ1Vals |            -126 |
# |     AverageQ2Vals |            -101 |
# |         StdQ2Vals |            6.54 |
# |         MaxQ2Vals |             -85 |
# |         MinQ2Vals |            -126 |
# |            LossPi |             101 |
# |             LossQ |           0.366 |
# |              Time |        1.62e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             146 |
# |      AverageEpRet |            -188 |
# |          StdEpRet |              20 |
# |          MaxEpRet |            -153 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -183 |
# |      StdTestEpRet |            21.6 |
# |      MaxTestEpRet |            -144 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.41e+05 |
# |     AverageQ1Vals |            -101 |
# |         StdQ1Vals |            6.59 |
# |         MaxQ1Vals |           -85.1 |
# |         MinQ1Vals |            -127 |
# |     AverageQ2Vals |            -101 |
# |         StdQ2Vals |            6.59 |
# |         MaxQ2Vals |             -85 |
# |         MinQ2Vals |            -127 |
# |            LossPi |             101 |
# |             LossQ |           0.367 |
# |              Time |        1.63e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             147 |
# |      AverageEpRet |            -183 |
# |          StdEpRet |            21.5 |
# |          MaxEpRet |            -150 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -193 |
# |      StdTestEpRet |            23.8 |
# |      MaxTestEpRet |            -156 |
# |      MinTestEpRet |            -227 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.43e+05 |
# |     AverageQ1Vals |            -101 |
# |         StdQ1Vals |            6.65 |
# |         MaxQ1Vals |           -84.9 |
# |         MinQ1Vals |            -127 |
# |     AverageQ2Vals |            -101 |
# |         StdQ2Vals |            6.65 |
# |         MaxQ2Vals |           -84.9 |
# |         MinQ2Vals |            -127 |
# |            LossPi |             101 |
# |             LossQ |           0.375 |
# |              Time |        1.64e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             148 |
# |      AverageEpRet |            -185 |
# |          StdEpRet |            20.5 |
# |          MaxEpRet |            -134 |
# |          MinEpRet |            -207 |
# |  AverageTestEpRet |            -186 |
# |      StdTestEpRet |            19.4 |
# |      MaxTestEpRet |            -159 |
# |      MinTestEpRet |            -221 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.44e+05 |
# |     AverageQ1Vals |            -101 |
# |         StdQ1Vals |            6.69 |
# |         MaxQ1Vals |             -85 |
# |         MinQ1Vals |            -128 |
# |     AverageQ2Vals |            -101 |
# |         StdQ2Vals |            6.69 |
# |         MaxQ2Vals |             -85 |
# |         MinQ2Vals |            -128 |
# |            LossPi |             101 |
# |             LossQ |           0.373 |
# |              Time |        1.65e+03 |
# ---------------------------------------
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-20-62fcb2109706>", line 29, in <module>
#     polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)
#   File "/home/matthieulc/Documents/MA2/DRLGyro/resources/spinningup/spinup/algos/pytorch/td3/td3.py", line 323, in td3
#     update(data=batch, timer=j)
#   File "/home/matthieulc/Documents/MA2/DRLGyro/resources/spinningup/spinup/algos/pytorch/td3/td3.py", line 249, in update
#     pi_optimizer.step()
#   File "/home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/optim/adam.py", line 96, in step
#     exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/tensorflow_core/python/keras/api/_v1/keras/__init__.py", line 16, in <module>
#     from . import backend
#   File "/home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/tensorflow_core/python/keras/api/_v1/keras/backend/__init__.py", line 11, in <module>
#     from tensorflow.python.framework.ops import name_scope_v1 as name_scope
# ImportError: cannot import name 'name_scope_v1'
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Adding extra layer

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='td3_n_b_it2_extralay', exp_name='td3_n_b_it2_extralay')
seed_b = 10
epochs_b = 800
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.985
polyak_b = 0.999
batchsize_b = 150
startsteps_b = 20000
args_b = dict(hidden_sizes=[700,50], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0015
qlr_b = 0.0015

# TD3 specific params
pd_b = 2
targnoise_b = 0.2
noiseclip_b = 0.04

# Env function
reward_args = {'k': 0.05, 'qx2' : 0.01, 'qx4' : 0.01, 'pu1':0.5,'pu2':0.5}
env = partial(env_fn,env_name = 'gyroscopeenv-v0',reward_type = 'Normalized', reward_args = reward_args,ep_len=110)

# Baseline 0 training
spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)
# Out:
# Warning: Log dir td3_n_b_it2_extralay already exists! Storing info there anyway.
# Logging data to td3_n_b_it2_extralay/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             700,
#             50
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	150,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fd7c46d1268>, env_name='gyroscopeenv-v0', reward_type='Normalized', reward_args={'k': 0.05, 'qx2': 0.01, 'qx4': 0.01, 'pu1': 0.5, 'pu2': 0.5}, ep_len=110)",
#     "epochs":	800,
#     "exp_name":	"td3_n_b_it2_extralay",
#     "gamma":	0.985,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fd792c77fd0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"td3_n_b_it2_extralay",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"td3_n_b_it2_extralay",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='td3_n_b_it2_extralay/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"td3_n_b_it2_extralay",
#         "output_dir":	"td3_n_b_it2_extralay"
#     },
#     "max_ep_len":	110,
#     "noise_clip":	0.04,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0015,
#     "policy_delay":	2,
#     "polyak":	0.999,
#     "q_lr":	0.0015,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	10,
#     "start_steps":	20000,
#     "steps_per_epoch":	1650,
#     "target_noise":	0.2,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 42152, 	 q1: 43501, 	 q2: 43501
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -317 |
# |          StdEpRet |              28 |
# |          MaxEpRet |            -282 |
# |          MinEpRet |            -375 |
# |  AverageTestEpRet |            -213 |
# |      StdTestEpRet |             7.5 |
# |      MaxTestEpRet |            -198 |
# |      MinTestEpRet |            -223 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |     AverageQ1Vals |           -3.42 |
# |         StdQ1Vals |           0.616 |
# |         MaxQ1Vals |           0.105 |
# |         MinQ1Vals |           -5.89 |
# |     AverageQ2Vals |           -3.42 |
# |         StdQ2Vals |           0.608 |
# |         MaxQ2Vals |         -0.0341 |
# |         MinQ2Vals |           -5.78 |
# |            LossPi |            3.04 |
# |             LossQ |           0.279 |
# |              Time |              10 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -311 |
# |          StdEpRet |            21.8 |
# |          MaxEpRet |            -283 |
# |          MinEpRet |            -377 |
# |  AverageTestEpRet |            -216 |
# |      StdTestEpRet |            7.15 |
# |      MaxTestEpRet |            -206 |
# |      MinTestEpRet |            -229 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |     AverageQ1Vals |           -4.55 |
# |         StdQ1Vals |             0.8 |
# |         MaxQ1Vals |            -2.5 |
# |         MinQ1Vals |           -8.07 |
# |     AverageQ2Vals |           -4.55 |
# |         StdQ2Vals |           0.802 |
# |         MaxQ2Vals |           -2.46 |
# |         MinQ2Vals |            -8.1 |
# |            LossPi |            4.08 |
# |             LossQ |          0.0554 |
# |              Time |            27.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -320 |
# |          StdEpRet |            25.1 |
# |          MaxEpRet |            -277 |
# |          MinEpRet |            -378 |
# |  AverageTestEpRet |            -204 |
# |      StdTestEpRet |            12.1 |
# |      MaxTestEpRet |            -177 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |     AverageQ1Vals |           -6.02 |
# |         StdQ1Vals |           0.985 |
# |         MaxQ1Vals |           -3.26 |
# |         MinQ1Vals |           -10.5 |
# |     AverageQ2Vals |           -6.02 |
# |         StdQ2Vals |           0.987 |
# |         MaxQ2Vals |           -3.34 |
# |         MinQ2Vals |           -10.6 |
# |            LossPi |            5.49 |
# |             LossQ |          0.0548 |
# |              Time |            45.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -319 |
# |          StdEpRet |            23.7 |
# |          MaxEpRet |            -291 |
# |          MinEpRet |            -369 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            9.18 |
# |      MaxTestEpRet |            -194 |
# |      MinTestEpRet |            -224 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |     AverageQ1Vals |           -7.58 |
# |         StdQ1Vals |             1.2 |
# |         MaxQ1Vals |           -4.19 |
# |         MinQ1Vals |           -12.7 |
# |     AverageQ2Vals |           -7.58 |
# |         StdQ2Vals |             1.2 |
# |         MaxQ2Vals |           -4.23 |
# |         MinQ2Vals |           -12.8 |
# |            LossPi |            6.98 |
# |             LossQ |          0.0634 |
# |              Time |              64 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            -315 |
# |          StdEpRet |            26.5 |
# |          MaxEpRet |            -272 |
# |          MinEpRet |            -363 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |            13.1 |
# |      MaxTestEpRet |            -174 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |     AverageQ1Vals |            -9.2 |
# |         StdQ1Vals |            1.36 |
# |         MaxQ1Vals |           -5.43 |
# |         MinQ1Vals |           -14.8 |
# |     AverageQ2Vals |            -9.2 |
# |         StdQ2Vals |            1.37 |
# |         MaxQ2Vals |           -5.46 |
# |         MinQ2Vals |             -15 |
# |            LossPi |            8.53 |
# |             LossQ |          0.0756 |
# |              Time |            82.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            -317 |
# |          StdEpRet |              21 |
# |          MaxEpRet |            -289 |
# |          MinEpRet |            -372 |
# |  AverageTestEpRet |            -209 |
# |      StdTestEpRet |            7.78 |
# |      MaxTestEpRet |            -187 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |     AverageQ1Vals |           -10.8 |
# |         StdQ1Vals |            1.53 |
# |         MaxQ1Vals |           -6.52 |
# |         MinQ1Vals |           -17.3 |
# |     AverageQ2Vals |           -10.8 |
# |         StdQ2Vals |            1.53 |
# |         MaxQ2Vals |           -6.54 |
# |         MinQ2Vals |           -17.4 |
# |            LossPi |              10 |
# |             LossQ |          0.0897 |
# |              Time |             101 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |            -313 |
# |          StdEpRet |            24.2 |
# |          MaxEpRet |            -280 |
# |          MinEpRet |            -371 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            8.86 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |     AverageQ1Vals |           -12.3 |
# |         StdQ1Vals |            1.67 |
# |         MaxQ1Vals |           -7.61 |
# |         MinQ1Vals |           -19.3 |
# |     AverageQ2Vals |           -12.3 |
# |         StdQ2Vals |            1.68 |
# |         MaxQ2Vals |           -7.63 |
# |         MinQ2Vals |           -19.4 |
# |            LossPi |            11.5 |
# |             LossQ |           0.102 |
# |              Time |             120 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |            -323 |
# |          StdEpRet |            25.8 |
# |          MaxEpRet |            -290 |
# |          MinEpRet |            -382 |
# |  AverageTestEpRet |            -210 |
# |      StdTestEpRet |            6.49 |
# |      MaxTestEpRet |            -198 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |     AverageQ1Vals |           -13.8 |
# |         StdQ1Vals |            1.82 |
# |         MaxQ1Vals |           -8.64 |
# |         MinQ1Vals |           -21.4 |
# |     AverageQ2Vals |           -13.8 |
# |         StdQ2Vals |            1.82 |
# |         MaxQ2Vals |           -8.61 |
# |         MinQ2Vals |           -21.3 |
# |            LossPi |            12.9 |
# |             LossQ |           0.113 |
# |              Time |             137 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |            -321 |
# |          StdEpRet |            33.8 |
# |          MaxEpRet |            -265 |
# |          MinEpRet |            -397 |
# |  AverageTestEpRet |            -210 |
# |      StdTestEpRet |            6.35 |
# |      MaxTestEpRet |            -197 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |     AverageQ1Vals |           -15.2 |
# |         StdQ1Vals |            1.93 |
# |         MaxQ1Vals |           -9.71 |
# |         MinQ1Vals |           -23.8 |
# |     AverageQ2Vals |           -15.2 |
# |         StdQ2Vals |            1.93 |
# |         MaxQ2Vals |           -9.54 |
# |         MinQ2Vals |           -23.7 |
# |            LossPi |            14.3 |
# |             LossQ |           0.127 |
# |              Time |             154 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |            -312 |
# |          StdEpRet |            24.8 |
# |          MaxEpRet |            -286 |
# |          MinEpRet |            -375 |
# |  AverageTestEpRet |            -204 |
# |      StdTestEpRet |            9.91 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |     AverageQ1Vals |           -16.7 |
# |         StdQ1Vals |            2.05 |
# |         MaxQ1Vals |           -10.7 |
# |         MinQ1Vals |           -25.5 |
# |     AverageQ2Vals |           -16.7 |
# |         StdQ2Vals |            2.05 |
# |         MaxQ2Vals |           -10.4 |
# |         MinQ2Vals |           -25.4 |
# |            LossPi |            15.7 |
# |             LossQ |           0.142 |
# |              Time |             171 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |            -322 |
# |          StdEpRet |            30.2 |
# |          MaxEpRet |            -282 |
# |          MinEpRet |            -370 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |             8.4 |
# |      MaxTestEpRet |            -190 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |     AverageQ1Vals |             -18 |
# |         StdQ1Vals |            2.14 |
# |         MaxQ1Vals |           -11.4 |
# |         MinQ1Vals |           -27.2 |
# |     AverageQ2Vals |             -18 |
# |         StdQ2Vals |            2.14 |
# |         MaxQ2Vals |           -11.2 |
# |         MinQ2Vals |           -27.2 |
# |            LossPi |            17.1 |
# |             LossQ |           0.152 |
# |              Time |             188 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |            -317 |
# |          StdEpRet |            27.1 |
# |          MaxEpRet |            -282 |
# |          MinEpRet |            -398 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |            11.2 |
# |      MaxTestEpRet |            -182 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |     AverageQ1Vals |           -19.4 |
# |         StdQ1Vals |            2.21 |
# |         MaxQ1Vals |             -13 |
# |         MinQ1Vals |             -29 |
# |     AverageQ2Vals |           -19.4 |
# |         StdQ2Vals |            2.21 |
# |         MaxQ2Vals |           -12.8 |
# |         MinQ2Vals |           -28.8 |
# |            LossPi |            18.4 |
# |             LossQ |           0.165 |
# |              Time |             204 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |            -222 |
# |          StdEpRet |            38.5 |
# |          MaxEpRet |            -170 |
# |          MinEpRet |            -332 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |            11.7 |
# |      MaxTestEpRet |            -182 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |     AverageQ1Vals |           -20.6 |
# |         StdQ1Vals |            2.31 |
# |         MaxQ1Vals |           -13.5 |
# |         MinQ1Vals |           -30.6 |
# |     AverageQ2Vals |           -20.6 |
# |         StdQ2Vals |            2.31 |
# |         MaxQ2Vals |           -13.5 |
# |         MinQ2Vals |           -30.8 |
# |            LossPi |            19.6 |
# |             LossQ |           0.165 |
# |              Time |             219 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            16.6 |
# |          MaxEpRet |            -165 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |            12.5 |
# |      MaxTestEpRet |            -183 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |     AverageQ1Vals |           -21.6 |
# |         StdQ1Vals |            2.48 |
# |         MaxQ1Vals |           -14.4 |
# |         MinQ1Vals |           -31.7 |
# |     AverageQ2Vals |           -21.6 |
# |         StdQ2Vals |            2.48 |
# |         MaxQ2Vals |           -14.4 |
# |         MinQ2Vals |           -31.9 |
# |            LossPi |            20.6 |
# |             LossQ |            0.16 |
# |              Time |             234 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            14.2 |
# |          MaxEpRet |            -167 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |            11.3 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |     AverageQ1Vals |           -22.6 |
# |         StdQ1Vals |            2.61 |
# |         MaxQ1Vals |           -15.6 |
# |         MinQ1Vals |           -33.9 |
# |     AverageQ2Vals |           -22.6 |
# |         StdQ2Vals |            2.61 |
# |         MaxQ2Vals |           -15.2 |
# |         MinQ2Vals |           -33.8 |
# |            LossPi |            21.7 |
# |             LossQ |           0.156 |
# |              Time |             251 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            -209 |
# |          StdEpRet |            11.9 |
# |          MaxEpRet |            -177 |
# |          MinEpRet |            -224 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            10.8 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |     AverageQ1Vals |           -23.6 |
# |         StdQ1Vals |            2.71 |
# |         MaxQ1Vals |           -16.5 |
# |         MinQ1Vals |           -34.8 |
# |     AverageQ2Vals |           -23.6 |
# |         StdQ2Vals |            2.71 |
# |         MaxQ2Vals |           -16.4 |
# |         MinQ2Vals |           -35.1 |
# |            LossPi |            22.8 |
# |             LossQ |           0.157 |
# |              Time |             270 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -209 |
# |          StdEpRet |            12.9 |
# |          MaxEpRet |            -172 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -195 |
# |      StdTestEpRet |            21.6 |
# |      MaxTestEpRet |            -143 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |     AverageQ1Vals |           -24.7 |
# |         StdQ1Vals |            2.76 |
# |         MaxQ1Vals |           -17.6 |
# |         MinQ1Vals |           -36.4 |
# |     AverageQ2Vals |           -24.7 |
# |         StdQ2Vals |            2.76 |
# |         MaxQ2Vals |           -17.3 |
# |         MinQ2Vals |           -36.7 |
# |            LossPi |            23.9 |
# |             LossQ |           0.156 |
# |              Time |             289 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            -207 |
# |          StdEpRet |            12.9 |
# |          MaxEpRet |            -176 |
# |          MinEpRet |            -220 |
# |  AverageTestEpRet |            -208 |
# |      StdTestEpRet |            8.33 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |     AverageQ1Vals |           -25.8 |
# |         StdQ1Vals |            2.79 |
# |         MaxQ1Vals |           -18.4 |
# |         MinQ1Vals |           -38.4 |
# |     AverageQ2Vals |           -25.8 |
# |         StdQ2Vals |            2.79 |
# |         MaxQ2Vals |           -18.2 |
# |         MinQ2Vals |           -38.4 |
# |            LossPi |              25 |
# |             LossQ |           0.156 |
# |              Time |             307 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -208 |
# |          StdEpRet |            11.6 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -206 |
# |      StdTestEpRet |            7.99 |
# |      MaxTestEpRet |            -192 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |     AverageQ1Vals |           -26.8 |
# |         StdQ1Vals |            2.82 |
# |         MaxQ1Vals |           -19.1 |
# |         MinQ1Vals |             -39 |
# |     AverageQ2Vals |           -26.8 |
# |         StdQ2Vals |            2.82 |
# |         MaxQ2Vals |           -19.2 |
# |         MinQ2Vals |           -39.3 |
# |            LossPi |            26.1 |
# |             LossQ |           0.158 |
# |              Time |             325 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            -202 |
# |          StdEpRet |            18.6 |
# |          MaxEpRet |            -161 |
# |          MinEpRet |            -223 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |            11.1 |
# |      MaxTestEpRet |            -178 |
# |      MinTestEpRet |            -216 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |     AverageQ1Vals |           -27.9 |
# |         StdQ1Vals |            2.86 |
# |         MaxQ1Vals |           -20.1 |
# |         MinQ1Vals |           -40.3 |
# |     AverageQ2Vals |           -27.9 |
# |         StdQ2Vals |            2.86 |
# |         MaxQ2Vals |           -20.1 |
# |         MinQ2Vals |           -40.7 |
# |            LossPi |            27.2 |
# |             LossQ |           0.159 |
# |              Time |             341 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -208 |
# |          StdEpRet |            8.61 |
# |          MaxEpRet |            -189 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -203 |
# |      StdTestEpRet |            15.7 |
# |      MaxTestEpRet |            -168 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |     AverageQ1Vals |           -28.9 |
# |         StdQ1Vals |            2.89 |
# |         MaxQ1Vals |           -20.9 |
# |         MinQ1Vals |           -42.1 |
# |     AverageQ2Vals |           -28.9 |
# |         StdQ2Vals |            2.89 |
# |         MaxQ2Vals |           -20.9 |
# |         MinQ2Vals |           -42.3 |
# |            LossPi |            28.3 |
# |             LossQ |           0.157 |
# |              Time |             359 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -205 |
# |          StdEpRet |            12.5 |
# |          MaxEpRet |            -175 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |            16.9 |
# |      MaxTestEpRet |            -160 |
# |      MinTestEpRet |            -210 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |     AverageQ1Vals |             -30 |
# |         StdQ1Vals |            2.92 |
# |         MaxQ1Vals |           -21.6 |
# |         MinQ1Vals |           -43.4 |
# |     AverageQ2Vals |             -30 |
# |         StdQ2Vals |            2.92 |
# |         MaxQ2Vals |           -21.7 |
# |         MinQ2Vals |           -43.6 |
# |            LossPi |            29.3 |
# |             LossQ |           0.162 |
# |              Time |             374 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -207 |
# |          StdEpRet |            13.1 |
# |          MaxEpRet |            -168 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -200 |
# |      StdTestEpRet |              21 |
# |      MaxTestEpRet |            -144 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |     AverageQ1Vals |             -31 |
# |         StdQ1Vals |            2.96 |
# |         MaxQ1Vals |           -22.4 |
# |         MinQ1Vals |           -44.6 |
# |     AverageQ2Vals |             -31 |
# |         StdQ2Vals |            2.96 |
# |         MaxQ2Vals |           -22.7 |
# |         MinQ2Vals |           -44.8 |
# |            LossPi |            30.4 |
# |             LossQ |           0.164 |
# |              Time |             391 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -212 |
# |          StdEpRet |            9.48 |
# |          MaxEpRet |            -191 |
# |          MinEpRet |            -225 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            18.3 |
# |      MaxTestEpRet |            -165 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |     AverageQ1Vals |           -32.1 |
# |         StdQ1Vals |            2.99 |
# |         MaxQ1Vals |           -23.5 |
# |         MinQ1Vals |           -46.2 |
# |     AverageQ2Vals |           -32.1 |
# |         StdQ2Vals |            2.99 |
# |         MaxQ2Vals |           -23.5 |
# |         MinQ2Vals |           -46.4 |
# |            LossPi |            31.5 |
# |             LossQ |           0.168 |
# |              Time |             409 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            8.64 |
# |          MaxEpRet |            -187 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -194 |
# |      StdTestEpRet |            13.8 |
# |      MaxTestEpRet |            -170 |
# |      MinTestEpRet |            -210 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |     AverageQ1Vals |           -33.1 |
# |         StdQ1Vals |            3.01 |
# |         MaxQ1Vals |           -24.3 |
# |         MinQ1Vals |           -47.3 |
# |     AverageQ2Vals |           -33.1 |
# |         StdQ2Vals |            3.01 |
# |         MaxQ2Vals |           -24.2 |
# |         MinQ2Vals |           -47.1 |
# |            LossPi |            32.5 |
# |             LossQ |            0.17 |
# |              Time |             426 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -200 |
# |          StdEpRet |            12.4 |
# |          MaxEpRet |            -172 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -207 |
# |      StdTestEpRet |            18.6 |
# |      MaxTestEpRet |            -153 |
# |      MinTestEpRet |            -218 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |     AverageQ1Vals |           -34.1 |
# |         StdQ1Vals |            3.04 |
# |         MaxQ1Vals |           -25.1 |
# |         MinQ1Vals |           -48.3 |
# |     AverageQ2Vals |           -34.1 |
# |         StdQ2Vals |            3.04 |
# |         MaxQ2Vals |           -25.1 |
# |         MinQ2Vals |           -48.7 |
# |            LossPi |            33.6 |
# |             LossQ |           0.174 |
# |              Time |             445 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -200 |
# |          StdEpRet |            13.6 |
# |          MaxEpRet |            -180 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -198 |
# |      StdTestEpRet |            18.6 |
# |      MaxTestEpRet |            -155 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |     AverageQ1Vals |           -35.1 |
# |         StdQ1Vals |            3.07 |
# |         MaxQ1Vals |           -25.8 |
# |         MinQ1Vals |           -49.5 |
# |     AverageQ2Vals |           -35.1 |
# |         StdQ2Vals |            3.07 |
# |         MaxQ2Vals |             -26 |
# |         MinQ2Vals |           -49.1 |
# |            LossPi |            34.6 |
# |             LossQ |            0.18 |
# |              Time |             461 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -200 |
# |          StdEpRet |            15.2 |
# |          MaxEpRet |            -167 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -202 |
# |      StdTestEpRet |            15.1 |
# |      MaxTestEpRet |            -167 |
# |      MinTestEpRet |            -226 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |     AverageQ1Vals |           -36.1 |
# |         StdQ1Vals |            3.12 |
# |         MaxQ1Vals |           -26.6 |
# |         MinQ1Vals |             -51 |
# |     AverageQ2Vals |           -36.1 |
# |         StdQ2Vals |            3.12 |
# |         MaxQ2Vals |           -26.7 |
# |         MinQ2Vals |           -50.7 |
# |            LossPi |            35.6 |
# |             LossQ |           0.188 |
# |              Time |             480 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -201 |
# |          StdEpRet |            12.7 |
# |          MaxEpRet |            -172 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -211 |
# |      StdTestEpRet |            4.58 |
# |      MaxTestEpRet |            -204 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |     AverageQ1Vals |           -37.1 |
# |         StdQ1Vals |            3.16 |
# |         MaxQ1Vals |           -27.5 |
# |         MinQ1Vals |           -51.7 |
# |     AverageQ2Vals |           -37.1 |
# |         StdQ2Vals |            3.16 |
# |         MaxQ2Vals |           -27.7 |
# |         MinQ2Vals |           -51.7 |
# |            LossPi |            36.6 |
# |             LossQ |            0.19 |
# |              Time |             501 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            18.7 |
# |          MaxEpRet |            -157 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |              12 |
# |      MaxTestEpRet |            -180 |
# |      MinTestEpRet |            -220 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |     AverageQ1Vals |           -38.1 |
# |         StdQ1Vals |            3.21 |
# |         MaxQ1Vals |           -28.5 |
# |         MinQ1Vals |           -53.1 |
# |     AverageQ2Vals |           -38.1 |
# |         StdQ2Vals |            3.21 |
# |         MaxQ2Vals |           -28.5 |
# |         MinQ2Vals |           -53.5 |
# |            LossPi |            37.6 |
# |             LossQ |           0.194 |
# |              Time |             523 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -201 |
# |          StdEpRet |            12.2 |
# |          MaxEpRet |            -183 |
# |          MinEpRet |            -222 |
# |  AverageTestEpRet |            -195 |
# |      StdTestEpRet |            16.1 |
# |      MaxTestEpRet |            -160 |
# |      MinTestEpRet |            -212 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |     AverageQ1Vals |             -39 |
# |         StdQ1Vals |            3.27 |
# |         MaxQ1Vals |           -29.4 |
# |         MinQ1Vals |           -54.1 |
# |     AverageQ2Vals |             -39 |
# |         StdQ2Vals |            3.27 |
# |         MaxQ2Vals |           -29.4 |
# |         MinQ2Vals |           -54.3 |
# |            LossPi |            38.5 |
# |             LossQ |           0.205 |
# |              Time |             541 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -203 |
# |          StdEpRet |            13.5 |
# |          MaxEpRet |            -171 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -192 |
# |      StdTestEpRet |            20.4 |
# |      MaxTestEpRet |            -147 |
# |      MinTestEpRet |            -215 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |     AverageQ1Vals |             -40 |
# |         StdQ1Vals |             3.3 |
# |         MaxQ1Vals |           -30.2 |
# |         MinQ1Vals |           -55.3 |
# |     AverageQ2Vals |             -40 |
# |         StdQ2Vals |             3.3 |
# |         MaxQ2Vals |           -30.2 |
# |         MinQ2Vals |           -55.5 |
# |            LossPi |            39.5 |
# |             LossQ |           0.209 |
# |              Time |             559 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -197 |
# |          StdEpRet |            13.4 |
# |          MaxEpRet |            -165 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -205 |
# |      StdTestEpRet |            11.8 |
# |      MaxTestEpRet |            -187 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |     AverageQ1Vals |           -40.9 |
# |         StdQ1Vals |            3.34 |
# |         MaxQ1Vals |           -30.9 |
# |         MinQ1Vals |           -56.9 |
# |     AverageQ2Vals |           -40.9 |
# |         StdQ2Vals |            3.34 |
# |         MaxQ2Vals |           -30.8 |
# |         MinQ2Vals |           -57.3 |
# |            LossPi |            40.5 |
# |             LossQ |           0.211 |
# |              Time |             577 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            -200 |
# |          StdEpRet |            11.4 |
# |          MaxEpRet |            -177 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -194 |
# |      StdTestEpRet |            14.4 |
# |      MaxTestEpRet |            -160 |
# |      MinTestEpRet |            -215 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |     AverageQ1Vals |           -41.9 |
# |         StdQ1Vals |            3.42 |
# |         MaxQ1Vals |           -31.8 |
# |         MinQ1Vals |           -56.8 |
# |     AverageQ2Vals |           -41.9 |
# |         StdQ2Vals |            3.42 |
# |         MaxQ2Vals |           -31.8 |
# |         MinQ2Vals |           -57.3 |
# |            LossPi |            41.4 |
# |             LossQ |           0.215 |
# |              Time |             596 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            11.7 |
# |          MaxEpRet |            -169 |
# |          MinEpRet |            -214 |
# |  AverageTestEpRet |            -195 |
# |      StdTestEpRet |            11.7 |
# |      MaxTestEpRet |            -173 |
# |      MinTestEpRet |            -210 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |     AverageQ1Vals |           -42.8 |
# |         StdQ1Vals |            3.49 |
# |         MaxQ1Vals |           -32.7 |
# |         MinQ1Vals |           -58.4 |
# |     AverageQ2Vals |           -42.8 |
# |         StdQ2Vals |            3.49 |
# |         MaxQ2Vals |           -32.5 |
# |         MinQ2Vals |           -58.7 |
# |            LossPi |            42.3 |
# |             LossQ |           0.226 |
# |              Time |             613 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -197 |
# |          StdEpRet |            11.9 |
# |          MaxEpRet |            -164 |
# |          MinEpRet |            -215 |
# |  AverageTestEpRet |            -202 |
# |      StdTestEpRet |            12.3 |
# |      MaxTestEpRet |            -178 |
# |      MinTestEpRet |            -219 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |     AverageQ1Vals |           -43.7 |
# |         StdQ1Vals |            3.53 |
# |         MaxQ1Vals |           -33.1 |
# |         MinQ1Vals |           -59.3 |
# |     AverageQ2Vals |           -43.7 |
# |         StdQ2Vals |            3.53 |
# |         MaxQ2Vals |           -33.4 |
# |         MinQ2Vals |           -59.6 |
# |            LossPi |            43.2 |
# |             LossQ |           0.233 |
# |              Time |             630 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -193 |
# |          StdEpRet |            22.7 |
# |          MaxEpRet |            -145 |
# |          MinEpRet |            -214 |
# |  AverageTestEpRet |            -193 |
# |      StdTestEpRet |            15.6 |
# |      MaxTestEpRet |            -159 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |     AverageQ1Vals |           -44.6 |
# |         StdQ1Vals |            3.58 |
# |         MaxQ1Vals |             -34 |
# |         MinQ1Vals |           -60.6 |
# |     AverageQ2Vals |           -44.6 |
# |         StdQ2Vals |            3.59 |
# |         MaxQ2Vals |             -34 |
# |         MinQ2Vals |           -60.6 |
# |            LossPi |            44.1 |
# |             LossQ |           0.242 |
# |              Time |             649 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |              13 |
# |          MaxEpRet |            -168 |
# |          MinEpRet |            -214 |
# |  AverageTestEpRet |            -190 |
# |      StdTestEpRet |              16 |
# |      MaxTestEpRet |            -156 |
# |      MinTestEpRet |            -211 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |     AverageQ1Vals |           -45.5 |
# |         StdQ1Vals |            3.65 |
# |         MaxQ1Vals |           -34.7 |
# |         MinQ1Vals |           -62.1 |
# |     AverageQ2Vals |           -45.5 |
# |         StdQ2Vals |            3.65 |
# |         MaxQ2Vals |           -34.8 |
# |         MinQ2Vals |           -61.7 |
# |            LossPi |              45 |
# |             LossQ |           0.247 |
# |              Time |             666 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -188 |
# |          StdEpRet |            20.9 |
# |          MaxEpRet |            -149 |
# |          MinEpRet |            -217 |
# |  AverageTestEpRet |            -194 |
# |      StdTestEpRet |              20 |
# |      MaxTestEpRet |            -138 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |     AverageQ1Vals |           -46.3 |
# |         StdQ1Vals |            3.73 |
# |         MaxQ1Vals |           -35.4 |
# |         MinQ1Vals |           -62.6 |
# |     AverageQ2Vals |           -46.3 |
# |         StdQ2Vals |            3.73 |
# |         MaxQ2Vals |           -35.5 |
# |         MinQ2Vals |           -62.7 |
# |            LossPi |            45.9 |
# |             LossQ |           0.257 |
# |              Time |             684 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -202 |
# |          StdEpRet |            13.7 |
# |          MaxEpRet |            -176 |
# |          MinEpRet |            -221 |
# |  AverageTestEpRet |            -196 |
# |      StdTestEpRet |            17.2 |
# |      MaxTestEpRet |            -148 |
# |      MinTestEpRet |            -209 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |     AverageQ1Vals |           -47.2 |
# |         StdQ1Vals |            3.79 |
# |         MaxQ1Vals |           -36.3 |
# |         MinQ1Vals |           -63.4 |
# |     AverageQ2Vals |           -47.2 |
# |         StdQ2Vals |            3.79 |
# |         MaxQ2Vals |           -36.1 |
# |         MinQ2Vals |           -63.8 |
# |            LossPi |            46.8 |
# |             LossQ |           0.261 |
# |              Time |             704 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -200 |
# |          StdEpRet |            16.8 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |            -229 |
# |  AverageTestEpRet |            -186 |
# |      StdTestEpRet |            20.5 |
# |      MaxTestEpRet |            -155 |
# |      MinTestEpRet |            -209 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |     AverageQ1Vals |             -48 |
# |         StdQ1Vals |            3.84 |
# |         MaxQ1Vals |           -36.8 |
# |         MinQ1Vals |           -65.1 |
# |     AverageQ2Vals |             -48 |
# |         StdQ2Vals |            3.84 |
# |         MaxQ2Vals |           -36.8 |
# |         MinQ2Vals |           -65.3 |
# |            LossPi |            47.6 |
# |             LossQ |           0.266 |
# |              Time |             721 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -198 |
# |          StdEpRet |            17.8 |
# |          MaxEpRet |            -158 |
# |          MinEpRet |            -219 |
# |  AverageTestEpRet |            -191 |
# |      StdTestEpRet |              19 |
# |      MaxTestEpRet |            -155 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |     AverageQ1Vals |           -48.9 |
# |         StdQ1Vals |            3.89 |
# |         MaxQ1Vals |           -37.6 |
# |         MinQ1Vals |           -65.8 |
# |     AverageQ2Vals |           -48.9 |
# |         StdQ2Vals |            3.89 |
# |         MaxQ2Vals |           -37.5 |
# |         MinQ2Vals |           -65.8 |
# |            LossPi |            48.5 |
# |             LossQ |           0.278 |
# |              Time |             738 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -193 |
# |          StdEpRet |            13.5 |
# |          MaxEpRet |            -169 |
# |          MinEpRet |            -218 |
# |  AverageTestEpRet |            -192 |
# |      StdTestEpRet |            18.5 |
# |      MaxTestEpRet |            -147 |
# |      MinTestEpRet |            -213 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |     AverageQ1Vals |           -49.7 |
# |         StdQ1Vals |            3.95 |
# |         MaxQ1Vals |           -38.5 |
# |         MinQ1Vals |           -66.6 |
# |     AverageQ2Vals |           -49.7 |
# |         StdQ2Vals |            3.96 |
# |         MaxQ2Vals |           -38.4 |
# |         MinQ2Vals |             -67 |
# |            LossPi |            49.3 |
# |             LossQ |           0.279 |
# |              Time |             755 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -190 |
# |          StdEpRet |            11.8 |
# |          MaxEpRet |            -174 |
# |          MinEpRet |            -210 |
# |  AverageTestEpRet |            -199 |
# |      StdTestEpRet |            14.6 |
# |      MaxTestEpRet |            -166 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |     AverageQ1Vals |           -50.5 |
# |         StdQ1Vals |            4.03 |
# |         MaxQ1Vals |             -39 |
# |         MinQ1Vals |           -68.4 |
# |     AverageQ2Vals |           -50.5 |
# |         StdQ2Vals |            4.03 |
# |         MaxQ2Vals |           -38.9 |
# |         MinQ2Vals |           -67.9 |
# |            LossPi |            50.1 |
# |             LossQ |           0.289 |
# |              Time |             775 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -190 |
# |          StdEpRet |            14.5 |
# |          MaxEpRet |            -174 |
# |          MinEpRet |            -216 |
# |  AverageTestEpRet |            -182 |
# |      StdTestEpRet |            36.4 |
# |      MaxTestEpRet |           -92.9 |
# |      MinTestEpRet |            -211 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |     AverageQ1Vals |           -51.3 |
# |         StdQ1Vals |            4.09 |
# |         MaxQ1Vals |           -39.6 |
# |         MinQ1Vals |           -68.9 |
# |     AverageQ2Vals |           -51.3 |
# |         StdQ2Vals |             4.1 |
# |         MaxQ2Vals |           -39.5 |
# |         MinQ2Vals |           -68.3 |
# |            LossPi |            50.9 |
# |             LossQ |           0.291 |
# |              Time |             795 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -188 |
# |          StdEpRet |            17.7 |
# |          MaxEpRet |            -154 |
# |          MinEpRet |            -227 |
# |  AverageTestEpRet |            -185 |
# |      StdTestEpRet |              19 |
# |      MaxTestEpRet |            -154 |
# |      MinTestEpRet |            -209 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |     AverageQ1Vals |           -52.1 |
# |         StdQ1Vals |            4.16 |
# |         MaxQ1Vals |           -40.4 |
# |         MinQ1Vals |           -69.7 |
# |     AverageQ2Vals |           -52.1 |
# |         StdQ2Vals |            4.16 |
# |         MaxQ2Vals |             -40 |
# |         MinQ2Vals |           -69.6 |
# |            LossPi |            51.7 |
# |             LossQ |           0.306 |
# |              Time |             813 |
# ---------------------------------------
# ---------------------------------------
# ...
# |         MinQ1Vals |            -118 |
# |     AverageQ2Vals |           -80.6 |
# |         StdQ2Vals |            10.4 |
# |         MaxQ2Vals |           -55.6 |
# |         MinQ2Vals |            -117 |
# |            LossPi |            80.1 |
# |             LossQ |           0.963 |
# |              Time |        2.52e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             124 |
# |      AverageEpRet |            -158 |
# |          StdEpRet |            29.8 |
# |          MaxEpRet |           -98.2 |
# |          MinEpRet |            -195 |
# |  AverageTestEpRet |            -132 |
# |      StdTestEpRet |            26.8 |
# |      MaxTestEpRet |           -92.1 |
# |      MinTestEpRet |            -176 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.05e+05 |
# |     AverageQ1Vals |           -80.7 |
# |         StdQ1Vals |            10.4 |
# |         MaxQ1Vals |           -55.8 |
# |         MinQ1Vals |            -116 |
# |     AverageQ2Vals |           -80.7 |
# |         StdQ2Vals |            10.5 |
# |         MaxQ2Vals |           -55.6 |
# |         MinQ2Vals |            -117 |
# |            LossPi |            80.3 |
# |             LossQ |           0.958 |
# |              Time |        2.54e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             125 |
# |      AverageEpRet |            -150 |
# |          StdEpRet |            26.3 |
# |          MaxEpRet |            -107 |
# |          MinEpRet |            -197 |
# |  AverageTestEpRet |            -133 |
# |      StdTestEpRet |            42.1 |
# |      MaxTestEpRet |           -63.6 |
# |      MinTestEpRet |            -196 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.06e+05 |
# |     AverageQ1Vals |           -80.8 |
# |         StdQ1Vals |            10.5 |
# |         MaxQ1Vals |           -55.8 |
# |         MinQ1Vals |            -117 |
# |     AverageQ2Vals |           -80.8 |
# |         StdQ2Vals |            10.5 |
# |         MaxQ2Vals |           -55.7 |
# |         MinQ2Vals |            -117 |
# |            LossPi |            80.3 |
# |             LossQ |           0.966 |
# |              Time |        2.56e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             126 |
# |      AverageEpRet |            -145 |
# |          StdEpRet |            29.7 |
# |          MaxEpRet |            -101 |
# |          MinEpRet |            -206 |
# |  AverageTestEpRet |            -146 |
# |      StdTestEpRet |            29.5 |
# |      MaxTestEpRet |           -97.5 |
# |      MinTestEpRet |            -190 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.08e+05 |
# |     AverageQ1Vals |           -80.9 |
# |         StdQ1Vals |            10.6 |
# |         MaxQ1Vals |           -55.2 |
# |         MinQ1Vals |            -117 |
# |     AverageQ2Vals |           -80.9 |
# |         StdQ2Vals |            10.6 |
# |         MaxQ2Vals |           -55.5 |
# |         MinQ2Vals |            -118 |
# |            LossPi |            80.4 |
# |             LossQ |           0.969 |
# |              Time |        2.59e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             127 |
# |      AverageEpRet |            -161 |
# |          StdEpRet |            22.6 |
# |          MaxEpRet |            -117 |
# |          MinEpRet |            -195 |
# |  AverageTestEpRet |            -157 |
# |      StdTestEpRet |            37.6 |
# |      MaxTestEpRet |            -117 |
# |      MinTestEpRet |            -217 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.1e+05 |
# |     AverageQ1Vals |             -81 |
# |         StdQ1Vals |            10.6 |
# |         MaxQ1Vals |           -55.6 |
# |         MinQ1Vals |            -118 |
# |     AverageQ2Vals |             -81 |
# |         StdQ2Vals |            10.6 |
# |         MaxQ2Vals |           -55.5 |
# |         MinQ2Vals |            -119 |
# |            LossPi |            80.5 |
# |             LossQ |           0.978 |
# |              Time |        2.61e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             128 |
# |      AverageEpRet |            -146 |
# |          StdEpRet |            30.4 |
# |          MaxEpRet |           -95.3 |
# |          MinEpRet |            -204 |
# |  AverageTestEpRet |            -139 |
# |      StdTestEpRet |            24.2 |
# |      MaxTestEpRet |             -99 |
# |      MinTestEpRet |            -177 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.11e+05 |
# |     AverageQ1Vals |             -81 |
# |         StdQ1Vals |            10.7 |
# |         MaxQ1Vals |           -55.5 |
# |         MinQ1Vals |            -116 |
# |     AverageQ2Vals |             -81 |
# |         StdQ2Vals |            10.7 |
# |         MaxQ2Vals |           -55.6 |
# |         MinQ2Vals |            -118 |
# |            LossPi |            80.5 |
# |             LossQ |           0.984 |
# |              Time |        2.64e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             129 |
# |      AverageEpRet |            -164 |
# |          StdEpRet |            26.6 |
# |          MaxEpRet |            -111 |
# |          MinEpRet |            -206 |
# |  AverageTestEpRet |            -150 |
# |      StdTestEpRet |            41.2 |
# |      MaxTestEpRet |           -60.6 |
# |      MinTestEpRet |            -203 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.13e+05 |
# |     AverageQ1Vals |           -81.1 |
# |         StdQ1Vals |            10.8 |
# |         MaxQ1Vals |           -55.2 |
# |         MinQ1Vals |            -119 |
# |     AverageQ2Vals |           -81.1 |
# |         StdQ2Vals |            10.8 |
# |         MaxQ2Vals |           -55.2 |
# |         MinQ2Vals |            -118 |
# |            LossPi |            80.6 |
# |             LossQ |           0.987 |
# |              Time |        2.66e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             130 |
# |      AverageEpRet |            -157 |
# |          StdEpRet |            28.8 |
# |          MaxEpRet |           -98.1 |
# |          MinEpRet |            -195 |
# |  AverageTestEpRet |            -156 |
# |      StdTestEpRet |            29.3 |
# |      MaxTestEpRet |             -99 |
# |      MinTestEpRet |            -194 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+05 |
# |     AverageQ1Vals |           -81.2 |
# |         StdQ1Vals |            10.8 |
# |         MaxQ1Vals |           -55.1 |
# |         MinQ1Vals |            -118 |
# |     AverageQ2Vals |           -81.2 |
# |         StdQ2Vals |            10.8 |
# |         MaxQ2Vals |           -55.4 |
# |         MinQ2Vals |            -119 |
# |            LossPi |            80.7 |
# |             LossQ |           0.979 |
# |              Time |        2.68e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             131 |
# |      AverageEpRet |            -145 |
# |          StdEpRet |              25 |
# |          MaxEpRet |            -107 |
# |          MinEpRet |            -198 |
# |  AverageTestEpRet |            -145 |
# |      StdTestEpRet |              26 |
# |      MaxTestEpRet |            -104 |
# |      MinTestEpRet |            -183 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.16e+05 |
# |     AverageQ1Vals |           -81.2 |
# |         StdQ1Vals |            10.8 |
# |         MaxQ1Vals |           -55.2 |
# |         MinQ1Vals |            -119 |
# |     AverageQ2Vals |           -81.2 |
# |         StdQ2Vals |            10.8 |
# |         MaxQ2Vals |           -55.3 |
# |         MinQ2Vals |            -120 |
# |            LossPi |            80.7 |
# |             LossQ |           0.981 |
# |              Time |        2.71e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             132 |
# |      AverageEpRet |            -157 |
# |          StdEpRet |            21.9 |
# |          MaxEpRet |            -125 |
# |          MinEpRet |            -206 |
# |  AverageTestEpRet |            -162 |
# |      StdTestEpRet |            38.6 |
# |      MaxTestEpRet |           -82.6 |
# |      MinTestEpRet |            -214 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.18e+05 |
# |     AverageQ1Vals |           -81.3 |
# |         StdQ1Vals |            10.9 |
# |         MaxQ1Vals |           -55.1 |
# |         MinQ1Vals |            -119 |
# |     AverageQ2Vals |           -81.3 |
# |         StdQ2Vals |            10.9 |
# |         MaxQ2Vals |           -55.5 |
# |         MinQ2Vals |            -120 |
# |            LossPi |            80.9 |
# |             LossQ |            1.01 |
# |              Time |        2.73e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             133 |
# |      AverageEpRet |            -148 |
# |          StdEpRet |            27.8 |
# |          MaxEpRet |            -104 |
# |          MinEpRet |            -202 |
# |  AverageTestEpRet |            -133 |
# |      StdTestEpRet |            30.6 |
# |      MaxTestEpRet |           -78.1 |
# |      MinTestEpRet |            -187 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.19e+05 |
# |     AverageQ1Vals |           -81.4 |
# |         StdQ1Vals |            10.9 |
# |         MaxQ1Vals |           -55.2 |
# |         MinQ1Vals |            -119 |
# |     AverageQ2Vals |           -81.4 |
# |         StdQ2Vals |            10.9 |
# |         MaxQ2Vals |           -55.4 |
# |         MinQ2Vals |            -119 |
# |            LossPi |            80.9 |
# |             LossQ |           0.994 |
# |              Time |        2.76e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             134 |
# |      AverageEpRet |            -158 |
# |          StdEpRet |            22.3 |
# |          MaxEpRet |            -122 |
# |          MinEpRet |            -204 |
# |  AverageTestEpRet |            -155 |
# |      StdTestEpRet |            31.8 |
# |      MaxTestEpRet |            -104 |
# |      MinTestEpRet |            -208 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.21e+05 |
# |     AverageQ1Vals |           -81.5 |
# |         StdQ1Vals |              11 |
# |         MaxQ1Vals |           -54.9 |
# |         MinQ1Vals |            -120 |
# |     AverageQ2Vals |           -81.5 |
# |         StdQ2Vals |              11 |
# |         MaxQ2Vals |           -55.6 |
# |         MinQ2Vals |            -120 |
# |            LossPi |              81 |
# |             LossQ |               1 |
# |              Time |        2.79e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             135 |
# |      AverageEpRet |            -154 |
# |          StdEpRet |            21.9 |
# |          MaxEpRet |            -111 |
# |          MinEpRet |            -193 |
# |  AverageTestEpRet |            -159 |
# |      StdTestEpRet |            22.3 |
# |      MaxTestEpRet |            -120 |
# |      MinTestEpRet |            -181 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.23e+05 |
# |     AverageQ1Vals |           -81.5 |
# |         StdQ1Vals |              11 |
# |         MaxQ1Vals |           -55.1 |
# |         MinQ1Vals |            -120 |
# |     AverageQ2Vals |           -81.5 |
# |         StdQ2Vals |              11 |
# |         MaxQ2Vals |           -55.4 |
# |         MinQ2Vals |            -120 |
# |            LossPi |            81.1 |
# |             LossQ |           0.999 |
# |              Time |        2.81e+03 |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-d2aa5bccbad1> in <module>
#      27 # Baseline 0 training
#      28 spinup.td3_pytorch(env, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
# ---> 29 polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b, policy_delay = pd_b, target_noise = targnoise_b, noise_clip = noiseclip_b)
#
# ~/Documents/MA2/DRLGyro/resources/spinningup/spinup/algos/pytorch/td3/td3.py in td3(env_fn, actor_critic, ac_kwargs, seed, steps_per_epoch, epochs, replay_size, gamma, polyak, pi_lr, q_lr, batch_size, start_steps, update_after, update_every, act_noise, target_noise, noise_clip, policy_delay, num_test_episodes, max_ep_len, logger_kwargs, save_freq)
#     321             for j in range(update_every):
#     322                 batch = replay_buffer.sample_batch(batch_size)
# --> 323                 update(data=batch, timer=j)
#     324
#     325         # End of epoch handling
#
# ~/Documents/MA2/DRLGyro/resources/spinningup/spinup/algos/pytorch/td3/td3.py in update(data, timer)
#     228         # First run one gradient descent step for Q1 and Q2
#     229         q_optimizer.zero_grad()
# --> 230         loss_q, loss_info = compute_loss_q(data)
#     231         loss_q.backward()
#     232         q_optimizer.step()
#
# ~/Documents/MA2/DRLGyro/resources/spinningup/spinup/algos/pytorch/td3/td3.py in compute_loss_q(data)
#     187         # Bellman backup for Q functions
#     188         with torch.no_grad():
# --> 189             pi_targ = ac_targ.pi(o2)
#     190
#     191             # Target policy smoothing
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/Documents/MA2/DRLGyro/resources/spinningup/spinup/algos/pytorch/td3/core.py in forward(self, obs)
#      31     def forward(self, obs):
#      32         # Return output from network scaled to action space limits.
# ---> 33         return self.act_limit * self.pi(obs)
#      34
#      35 class MLPQFunction(nn.Module):
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530
#     531     def __call__(self, *input, **kwargs):
# --> 532         for hook in self._forward_pre_hooks.values():
#     533             result = hook(self, input)
#     534             if result is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test

# %%
# Test paramaters
env_name = 'gyroscopeenv-v0'
reward_type = 'Quadratic'
reward_args = {'qx1':1,'qx2':0,'qx3':1,'qx4':0,'pu1':0,'pu2':0}
seed = 2
agent_path = 'td3_n_b_it2/'
init_state = [70*np.pi/180,0,0,0,20*np.pi/180,0,10]
ep_len = 110
t_end = ep_len*0.05

# Perform testing
r,score,x1_eval,x2_eval,x3_eval,x4_eval,x1_ref_eval,x3_ref_eval,act = test_agent(env_name,reward_type,reward_args,seed,agent_path,init_state,t_end,ep_len)
# Out:
# Total cumulative reward: -3.386328942232901

# %% [markdown]
# ## Plot

# %%
plot_test(x1_eval,x2_eval,x3_eval,x4_eval,x1_ref_eval,x3_ref_eval,act,t_end)

# %% [markdown]
# ## Evaluate control performance

# %%
# Single evaluation
env_name = 'gyroscopeenv-v0'
agent_path = 'td3_n_b_var1/'
ss_bound = 0.05
metrics = evaluate_control(env_name,agent_path,ss_bound)
metrics

# %%
# Init dataframe
env_name = 'gyroscopeenv-v0'
agent_paths = ['td3_n_b_it1/','td3_n_it1_lr_var0/','td3_n_it1_lr_var1/','td3_n_it1_hid_var0/','td3_n_it1_hid_var1/','td3_n_it1_bs_var0/','td3_n_it1_bs_var1/','td3_n_it1_g_var0/','td3_n_it1_g_var1/','td3_n_it1_pol_var0/','td3_n_it1_pol_var1/','td3_n_it1_nc_var0/','td3_n_it1_nc_var1/','td3_n_b_it2/']
ss_bound = 0.05

# Loop dataframe
for idx, agent_path in zip(range(len(agent_paths)),agent_paths):
    if idx == 0:
        metrics = evaluate_control(env_name,agent_path,ss_bound)
    else:
        new_metrics = evaluate_control(env_name,agent_path,ss_bound)
        metrics = metrics.append(new_metrics)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-61af205bd18c> in <module>
#       9         metrics = evaluate_control(env_name,agent_path,ss_bound)
#      10     else:
# ---> 11         new_metrics = evaluate_control(env_name,agent_path,ss_bound)
#      12         metrics = metrics.append(new_metrics)
#
# ~/Documents/MA2/DRLGyro/code/custom_functions/custom_functions/custom_functions.py in evaluate_control(env_name, agent_path, ss_bound)
#     255
#     256         # Run trial
# --> 257         r,score,x1_eval,x2_eval,x3_eval,x4_eval,x1_ref_eval,x3_ref_eval,act = run_trial(env,dt,eval_per_dt,agent,state,t_end,ep_len)
#     258
#     259         # Evaluate control metrics for that run
#
# ~/Documents/MA2/DRLGyro/code/custom_functions/custom_functions/custom_functions.py in run_trial(env, dt, eval_per_dt, agent, state, t_end, ep_len, x1_ref_seq, x3_ref_seq, w_seq)
#     114
#     115         # Get action from agent
# --> 116         action = agent.act(torch.as_tensor(obs, dtype=torch.float32))
#     117
#     118         # Perform step in environment
#
# ~/Documents/MA2/DRLGyro/resources/spinningup/spinup/algos/pytorch/td3/core.py in act(self, obs)
#      60     def act(self, obs):
#      61         with torch.no_grad():
# ---> 62             return self.pi(obs).numpy()
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/Documents/MA2/DRLGyro/resources/spinningup/spinup/algos/pytorch/td3/core.py in forward(self, obs)
#      31     def forward(self, obs):
#      32         # Return output from network scaled to action space limits.
# ---> 33         return self.act_limit * self.pi(obs)
#      34
#      35 class MLPQFunction(nn.Module):
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
# -> 1374             output += bias
#    1375         ret = output
#    1376     return ret
#
# KeyboardInterrupt:

# %%
# Manipulate
metrics_man = metrics[['$\theta$ MAE (rad)','$\phi$ MAE (rad)','$\theta$ MSSE (rad)','$\phi$ MSSE (rad)','$\theta$ in bounds (%)','$\phi$ in bounds (%)','$\theta$ unsteady (%)','$\phi$ unsteady (%)','u1 (V)','u2 (V)','u1 variation (V)','u2 variation (V)']]
metrics_man = metrics_man.transpose()
metrics_man = metrics_man.round(2)
metrics_man
# Out:
# Config.                 td3_n_b_it1/  td3_n_it1_lr_var0/  td3_n_it1_lr_var1/  \
# $\theta$ MAE (rad)              0.21                0.21                0.18
# $\phi$ MAE (rad)                0.13                0.13                0.12
# $\theta$ MSSE (rad)             0.04                0.04                0.04
# $\phi$ MSSE (rad)               0.02                0.02                0.02
# $\theta$ in bounds (%)         77.50               69.50               64.00
# $\phi$ in bounds (%)           89.50               89.00               90.00
# $\theta$ unsteady (%)           0.00                0.00                0.00
# $\phi$ unsteady (%)             0.00                0.00                0.00
# u1 (V)                          0.73                0.79                0.80
# u2 (V)                          0.59                0.64                0.55
# u1 variation (V)                0.06                0.07                0.07
# u2 variation (V)                0.07                0.07                0.07
#
# Config.                 td3_n_it1_hid_var0/  td3_n_it1_hid_var1/  \
# $\theta$ MAE (rad)                     0.23                 0.23
# $\phi$ MAE (rad)                       0.11                 0.14
# $\theta$ MSSE (rad)                    0.03                 0.03
# $\phi$ MSSE (rad)                      0.02                 0.03
# $\theta$ in bounds (%)                74.00                69.50
# $\phi$ in bounds (%)                  97.00                82.00
# $\theta$ unsteady (%)                  0.00                 0.00
# $\phi$ unsteady (%)                    0.00                 0.00
# u1 (V)                                 0.89                 0.87
# u2 (V)                                 0.65                 0.61
# u1 variation (V)                       0.07                 0.07
# u2 variation (V)                       0.07                 0.08
#
# Config.                 td3_n_it1_bs_var0/  td3_n_it1_bs_var1/  \
# $\theta$ MAE (rad)                    0.20                0.21
# $\phi$ MAE (rad)                      0.13                0.13
# $\theta$ MSSE (rad)                   0.04                0.05
# $\phi$ MSSE (rad)                     0.04                0.04
# $\theta$ in bounds (%)               54.00               66.00
# $\phi$ in bounds (%)                 80.00               79.00
# $\theta$ unsteady (%)                 0.00                0.00
# $\phi$ unsteady (%)                   0.00                0.00
# u1 (V)                                0.83                0.84
# u2 (V)                                0.53                0.64
# u1 variation (V)                      0.07                0.07
# u2 variation (V)                      0.07                0.07
#
# Config.                 td3_n_it1_g_var0/  td3_n_it1_g_var1/  \
# $\theta$ MAE (rad)                   0.23               0.20
# $\phi$ MAE (rad)                     0.16               0.13
# $\theta$ MSSE (rad)                  0.02               0.04
# $\phi$ MSSE (rad)                    0.02               0.03
# $\theta$ in bounds (%)              95.00              85.00
# $\phi$ in bounds (%)                89.50              84.50
# $\theta$ unsteady (%)                0.00               0.00
# $\phi$ unsteady (%)                  0.00               0.00
# u1 (V)                               0.82               0.81
# u2 (V)                               0.60               0.68
# u1 variation (V)                     0.07               0.06
# u2 variation (V)                     0.07               0.07
#
# Config.                 td3_n_it1_pol_var0/  td3_n_it1_pol_var1/  \
# $\theta$ MAE (rad)                     0.19                 0.19
# $\phi$ MAE (rad)                       0.15                 0.14
# $\theta$ MSSE (rad)                    0.03                 0.03
# $\phi$ MSSE (rad)                      0.03                 0.05
# $\theta$ in bounds (%)                77.50                80.00
# $\phi$ in bounds (%)                  78.00                79.50
# $\theta$ unsteady (%)                  0.00                 0.00
# $\phi$ unsteady (%)                    0.00                 0.00
# u1 (V)                                 0.84                 0.79
# u2 (V)                                 0.63                 0.55
# u1 variation (V)                       0.07                 0.07
# u2 variation (V)                       0.07                 0.07
#
# Config.                 td3_n_it1_nc_var0/  td3_n_it1_nc_var1/
# $\theta$ MAE (rad)                    0.32                0.21
# $\phi$ MAE (rad)                      0.14                0.11
# $\theta$ MSSE (rad)                   0.15                0.03
# $\phi$ MSSE (rad)                     0.05                0.02
# $\theta$ in bounds (%)               74.00               86.00
# $\phi$ in bounds (%)                 78.50               97.00
# $\theta$ unsteady (%)                 0.00                0.00
# $\phi$ unsteady (%)                   0.00                0.00
# u1 (V)                                0.79                0.79
# u2 (V)                                0.60                0.59
# u1 variation (V)                      0.07                0.07
# u2 variation (V)                      0.08                0.06

# %%
# Init dataframe
env_name = 'gyroscopeenv-v0'
agent_paths = ['td3_n_b_var1/','td3_n_b_it1/','td3_n_b_it2/']
ss_bound = 0.05

# Loop dataframe
for idx, agent_path in zip(range(len(agent_paths)),agent_paths):
    if idx == 0:
        metrics = evaluate_control(env_name,agent_path,ss_bound)
    else:
        new_metrics = evaluate_control(env_name,agent_path,ss_bound)
        metrics = metrics.append(new_metrics)
# Out:
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/serialization.py:493: SourceChangeWarning: source code of class 'torch.nn.modules.container.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
# Manipulate
metrics_man = metrics[['$\theta$ MAE (rad)','$\phi$ MAE (rad)','$\theta$ MSSE (rad)','$\phi$ MSSE (rad)','$\theta$ in bounds (%)','$\phi$ in bounds (%)','$\theta$ unsteady (%)','$\phi$ unsteady (%)','u1 (V)','u2 (V)','u1 variation (V)','u2 variation (V)']]
metrics_man = metrics_man.transpose()
metrics_man = metrics_man.round(2)
metrics_man
