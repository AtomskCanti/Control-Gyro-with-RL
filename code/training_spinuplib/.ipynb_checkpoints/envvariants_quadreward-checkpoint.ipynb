# %% [markdown]
# # DDPG/TD3/SAC training of baseline with quadratic reward (spinup library)

# %%
import gym
from gym import spaces
from gym.utils import seeding
from gym.envs.registration import register

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test
from custom_functions.custom_functions import evaluate_control

import spinup

from os import path
from scipy.integrate import solve_ivp
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline
#from vpython import *
from functools import partial

register(id='gyroscopeenv-v0',entry_point='gym_GyroscopeEnv.envs:GyroscopeEnv')
register(id='gyroscopeintegralenv-v0',entry_point='gym_GyroscopeEnv.envs:GyroscopeIntegralEnv')

# %% [markdown]
# ## Environment Class and Modules

# %%
reward_args = {'qx1':9,'qx2':0.05,'qx3':9,'qx4':0.05,'pu1':0.1,'pu2':0.1}
env_int = partial(env_fn,env_name = 'gyroscopeintegralenv-v0',reward_type = 'Quadratic', reward_args = reward_args,ep_len=110)

# %%
env = env_int()
obs = env.reset()
obs[0:-2]=[1,0,0,1,0,0,5/180,0,0.9]
obs[-2:]=[1,0]
print('obs:' ,obs,'\n\n')
agent_fullpath = 'integral_norm/' + '/pyt_save/model.pt'
agent = torch.load(agent_fullpath)
action = agent.act(torch.as_tensor(obs, dtype=torch.float32))
print('action:',action)
# Out:
# obs: [1.         0.         0.         1.         0.         0.
#  0.02777778 0.         0.9        1.         0.        ]
#
#
# action: [-0.7102828  -0.04946333]

# %%
obs[-2:]
# Out:
# array([0., 0.])

# %% [markdown]
# ## Training

# %% [markdown]
# #### Integral

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='integral_500epochs', exp_name='integral_500epochs')
seed_b = 0
epochs_b = 500
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0025
qlr_b = 0.0025

# Baseline 0 training
spinup.ddpg_pytorch(env_int, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Logging data to integral_500epochs/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7efdbf0da2f0>, env_name='gyroscopeintegralenv-v0', reward_type='Quadratic', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1}, ep_len=110)",
#     "epochs":	500,
#     "exp_name":	"integral_500epochs",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7efd8d655cc0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"integral_500epochs",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"integral_500epochs",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='integral_500epochs/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"integral_500epochs",
#         "output_dir":	"integral_500epochs"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0025,
#     "polyak":	0.995,
#     "q_lr":	0.0025,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5602, 	 q: 6001
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |       -6.25e+03 |
# |          StdEpRet |        1.82e+03 |
# |          MaxEpRet |       -3.95e+03 |
# |          MinEpRet |       -1.03e+04 |
# |  AverageTestEpRet |       -8.25e+03 |
# |      StdTestEpRet |        2.21e+03 |
# |      MaxTestEpRet |       -5.28e+03 |
# |      MinTestEpRet |       -1.24e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |      AverageQVals |            -104 |
# |          StdQVals |            61.2 |
# |          MaxQVals |            1.23 |
# |          MinQVals |            -392 |
# |            LossPi |            99.1 |
# |             LossQ |        1.17e+03 |
# |              Time |            4.89 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |       -6.81e+03 |
# |          StdEpRet |        2.31e+03 |
# |          MaxEpRet |       -4.57e+03 |
# |          MinEpRet |       -1.23e+04 |
# |  AverageTestEpRet |       -5.24e+03 |
# |      StdTestEpRet |        2.28e+03 |
# |      MaxTestEpRet |            -500 |
# |      MinTestEpRet |       -8.85e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |      AverageQVals |            -353 |
# |          StdQVals |             166 |
# |          MaxQVals |           -46.9 |
# |          MinQVals |       -1.09e+03 |
# |            LossPi |             339 |
# |             LossQ |        1.08e+03 |
# |              Time |            12.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |       -7.59e+03 |
# |          StdEpRet |        1.78e+03 |
# |          MaxEpRet |       -4.45e+03 |
# |          MinEpRet |       -1.04e+04 |
# |  AverageTestEpRet |       -3.97e+03 |
# |      StdTestEpRet |        3.27e+03 |
# |      MaxTestEpRet |            -844 |
# |      MinTestEpRet |       -1.12e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |      AverageQVals |            -694 |
# |          StdQVals |             269 |
# |          MaxQVals |            -114 |
# |          MinQVals |       -1.89e+03 |
# |            LossPi |             671 |
# |             LossQ |         2.3e+03 |
# |              Time |            20.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |       -6.99e+03 |
# |          StdEpRet |        1.89e+03 |
# |          MaxEpRet |       -4.27e+03 |
# |          MinEpRet |       -9.88e+03 |
# |  AverageTestEpRet |       -4.51e+03 |
# |      StdTestEpRet |        1.83e+03 |
# |      MaxTestEpRet |            -946 |
# |      MinTestEpRet |       -8.34e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |      AverageQVals |            -984 |
# |          StdQVals |             366 |
# |          MaxQVals |            -251 |
# |          MinQVals |       -2.61e+03 |
# |            LossPi |             956 |
# |             LossQ |        3.48e+03 |
# |              Time |            27.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |       -7.55e+03 |
# |          StdEpRet |        2.27e+03 |
# |          MaxEpRet |       -4.15e+03 |
# |          MinEpRet |       -1.16e+04 |
# |  AverageTestEpRet |       -1.42e+03 |
# |      StdTestEpRet |             632 |
# |      MaxTestEpRet |            -514 |
# |      MinTestEpRet |       -2.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |      AverageQVals |       -1.23e+03 |
# |          StdQVals |             468 |
# |          MaxQVals |            -212 |
# |          MinQVals |       -3.35e+03 |
# |            LossPi |         1.2e+03 |
# |             LossQ |        4.37e+03 |
# |              Time |            35.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |        -7.9e+03 |
# |          StdEpRet |        2.46e+03 |
# |          MaxEpRet |       -3.72e+03 |
# |          MinEpRet |       -1.21e+04 |
# |  AverageTestEpRet |       -2.12e+03 |
# |      StdTestEpRet |        1.24e+03 |
# |      MaxTestEpRet |            -680 |
# |      MinTestEpRet |       -4.36e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |      AverageQVals |       -1.39e+03 |
# |          StdQVals |             543 |
# |          MaxQVals |            -246 |
# |          MinQVals |       -3.92e+03 |
# |            LossPi |        1.35e+03 |
# |             LossQ |        4.75e+03 |
# |              Time |            42.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |       -2.33e+03 |
# |          StdEpRet |        1.66e+03 |
# |          MaxEpRet |            -243 |
# |          MinEpRet |       -5.92e+03 |
# |  AverageTestEpRet |       -1.73e+03 |
# |      StdTestEpRet |             715 |
# |      MaxTestEpRet |            -650 |
# |      MinTestEpRet |       -3.27e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |      AverageQVals |       -1.46e+03 |
# |          StdQVals |             617 |
# |          MaxQVals |            -276 |
# |          MinQVals |       -4.43e+03 |
# |            LossPi |        1.42e+03 |
# |             LossQ |        4.41e+03 |
# |              Time |            50.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |       -1.98e+03 |
# |          StdEpRet |        1.63e+03 |
# |          MaxEpRet |            -367 |
# |          MinEpRet |       -6.16e+03 |
# |  AverageTestEpRet |       -2.07e+03 |
# |      StdTestEpRet |        1.74e+03 |
# |      MaxTestEpRet |            -159 |
# |      MinTestEpRet |       -6.42e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |      AverageQVals |       -1.47e+03 |
# |          StdQVals |             708 |
# |          MaxQVals |            -249 |
# |          MinQVals |       -4.92e+03 |
# |            LossPi |        1.42e+03 |
# |             LossQ |        3.71e+03 |
# |              Time |            58.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |       -2.55e+03 |
# |          StdEpRet |         2.4e+03 |
# |          MaxEpRet |            -213 |
# |          MinEpRet |        -9.5e+03 |
# |  AverageTestEpRet |       -2.49e+03 |
# |      StdTestEpRet |         1.3e+03 |
# |      MaxTestEpRet |            -269 |
# |      MinTestEpRet |       -4.86e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |      AverageQVals |       -1.49e+03 |
# |          StdQVals |             776 |
# |          MaxQVals |            -190 |
# |          MinQVals |       -5.33e+03 |
# |            LossPi |        1.45e+03 |
# |             LossQ |        3.26e+03 |
# |              Time |            66.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |       -1.76e+03 |
# |          StdEpRet |           1e+03 |
# |          MaxEpRet |            -291 |
# |          MinEpRet |       -4.18e+03 |
# |  AverageTestEpRet |       -2.25e+03 |
# |      StdTestEpRet |        1.32e+03 |
# |      MaxTestEpRet |            -615 |
# |      MinTestEpRet |       -4.38e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |       -1.53e+03 |
# |          StdQVals |             850 |
# |          MaxQVals |            -163 |
# |          MinQVals |       -5.77e+03 |
# |            LossPi |         1.5e+03 |
# |             LossQ |        2.97e+03 |
# |              Time |            74.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |       -2.65e+03 |
# |          StdEpRet |        1.72e+03 |
# |          MaxEpRet |            -460 |
# |          MinEpRet |       -6.03e+03 |
# |  AverageTestEpRet |       -1.67e+03 |
# |      StdTestEpRet |             806 |
# |      MaxTestEpRet |            -650 |
# |      MinTestEpRet |       -3.58e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |      AverageQVals |        -1.6e+03 |
# |          StdQVals |             921 |
# |          MaxQVals |            -145 |
# |          MinQVals |       -6.26e+03 |
# |            LossPi |        1.57e+03 |
# |             LossQ |        2.82e+03 |
# |              Time |            82.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |       -2.34e+03 |
# |          StdEpRet |        1.37e+03 |
# |          MaxEpRet |            -869 |
# |          MinEpRet |       -5.52e+03 |
# |  AverageTestEpRet |       -1.56e+03 |
# |      StdTestEpRet |             991 |
# |      MaxTestEpRet |            -389 |
# |      MinTestEpRet |       -3.58e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |      AverageQVals |       -1.68e+03 |
# |          StdQVals |             988 |
# |          MaxQVals |            -130 |
# |          MinQVals |        -6.5e+03 |
# |            LossPi |        1.65e+03 |
# |             LossQ |        2.79e+03 |
# |              Time |            89.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |       -1.43e+03 |
# |          StdEpRet |             882 |
# |          MaxEpRet |             -86 |
# |          MinEpRet |       -3.96e+03 |
# |  AverageTestEpRet |       -2.82e+03 |
# |      StdTestEpRet |        1.93e+03 |
# |      MaxTestEpRet |       -1.22e+03 |
# |      MinTestEpRet |       -7.64e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |      AverageQVals |       -1.73e+03 |
# |          StdQVals |        1.06e+03 |
# |          MaxQVals |            -112 |
# |          MinQVals |       -7.08e+03 |
# |            LossPi |         1.7e+03 |
# |             LossQ |        2.82e+03 |
# |              Time |            97.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |       -1.61e+03 |
# |          StdEpRet |             829 |
# |          MaxEpRet |            -353 |
# |          MinEpRet |       -3.14e+03 |
# |  AverageTestEpRet |       -1.29e+03 |
# |      StdTestEpRet |             891 |
# |      MaxTestEpRet |            -236 |
# |      MinTestEpRet |        -3.3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |      AverageQVals |       -1.77e+03 |
# |          StdQVals |        1.12e+03 |
# |          MaxQVals |           -91.5 |
# |          MinQVals |       -7.73e+03 |
# |            LossPi |        1.74e+03 |
# |             LossQ |        2.88e+03 |
# |              Time |             106 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |       -1.98e+03 |
# |          StdEpRet |        1.12e+03 |
# |          MaxEpRet |            -392 |
# |          MinEpRet |       -4.61e+03 |
# |  AverageTestEpRet |       -1.34e+03 |
# |      StdTestEpRet |             924 |
# |      MaxTestEpRet |            -290 |
# |      MinTestEpRet |       -2.93e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |      AverageQVals |        -1.8e+03 |
# |          StdQVals |        1.17e+03 |
# |          MaxQVals |           -83.9 |
# |          MinQVals |       -8.28e+03 |
# |            LossPi |        1.78e+03 |
# |             LossQ |        2.87e+03 |
# |              Time |             113 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |       -1.64e+03 |
# |          StdEpRet |        1.08e+03 |
# |          MaxEpRet |            -217 |
# |          MinEpRet |       -4.05e+03 |
# |  AverageTestEpRet |       -2.52e+03 |
# |      StdTestEpRet |        1.43e+03 |
# |      MaxTestEpRet |            -704 |
# |      MinTestEpRet |       -4.89e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |      AverageQVals |       -1.84e+03 |
# |          StdQVals |        1.22e+03 |
# |          MaxQVals |           -62.7 |
# |          MinQVals |       -8.75e+03 |
# |            LossPi |        1.81e+03 |
# |             LossQ |        2.94e+03 |
# |              Time |             121 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |       -1.66e+03 |
# |          StdEpRet |             715 |
# |          MaxEpRet |            -163 |
# |          MinEpRet |       -3.24e+03 |
# |  AverageTestEpRet |       -1.13e+03 |
# |      StdTestEpRet |             648 |
# |      MaxTestEpRet |           -66.5 |
# |      MinTestEpRet |       -2.24e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |      AverageQVals |       -1.88e+03 |
# |          StdQVals |        1.26e+03 |
# |          MaxQVals |           -55.2 |
# |          MinQVals |       -9.21e+03 |
# |            LossPi |        1.85e+03 |
# |             LossQ |        2.98e+03 |
# |              Time |             129 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |       -1.77e+03 |
# |          StdEpRet |             853 |
# |          MaxEpRet |            -524 |
# |          MinEpRet |       -3.52e+03 |
# |  AverageTestEpRet |            -871 |
# |      StdTestEpRet |             697 |
# |      MaxTestEpRet |            -345 |
# |      MinTestEpRet |       -2.64e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |      AverageQVals |        -1.9e+03 |
# |          StdQVals |         1.3e+03 |
# |          MaxQVals |             -41 |
# |          MinQVals |       -9.81e+03 |
# |            LossPi |        1.87e+03 |
# |             LossQ |        3.04e+03 |
# |              Time |             137 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |       -1.43e+03 |
# |          StdEpRet |             870 |
# |          MaxEpRet |            -300 |
# |          MinEpRet |       -4.07e+03 |
# |  AverageTestEpRet |       -1.34e+03 |
# |      StdTestEpRet |             905 |
# |      MaxTestEpRet |            -330 |
# |      MinTestEpRet |       -3.67e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |      AverageQVals |        -1.9e+03 |
# |          StdQVals |        1.36e+03 |
# |          MaxQVals |           -26.1 |
# |          MinQVals |       -1.03e+04 |
# |            LossPi |        1.87e+03 |
# |             LossQ |        3.02e+03 |
# |              Time |             145 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |       -1.91e+03 |
# |          StdEpRet |        1.22e+03 |
# |          MaxEpRet |            -211 |
# |          MinEpRet |       -4.67e+03 |
# |  AverageTestEpRet |       -1.83e+03 |
# |      StdTestEpRet |        1.46e+03 |
# |      MaxTestEpRet |            -411 |
# |      MinTestEpRet |        -4.2e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |       -1.91e+03 |
# |          StdQVals |        1.39e+03 |
# |          MaxQVals |           -3.44 |
# |          MinQVals |       -1.06e+04 |
# |            LossPi |        1.88e+03 |
# |             LossQ |        3.05e+03 |
# |              Time |             153 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |       -1.24e+03 |
# |          StdEpRet |             610 |
# |          MaxEpRet |            -349 |
# |          MinEpRet |       -2.72e+03 |
# |  AverageTestEpRet |       -2.04e+03 |
# |      StdTestEpRet |        1.23e+03 |
# |      MaxTestEpRet |            -815 |
# |      MinTestEpRet |       -5.17e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |      AverageQVals |       -1.93e+03 |
# |          StdQVals |        1.45e+03 |
# |          MaxQVals |             4.4 |
# |          MinQVals |       -1.09e+04 |
# |            LossPi |        1.91e+03 |
# |             LossQ |        3.11e+03 |
# |              Time |             161 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |        -1.4e+03 |
# |          StdEpRet |             930 |
# |          MaxEpRet |            -286 |
# |          MinEpRet |       -3.96e+03 |
# |  AverageTestEpRet |        -2.1e+03 |
# |      StdTestEpRet |        1.49e+03 |
# |      MaxTestEpRet |            -375 |
# |      MinTestEpRet |       -5.12e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |      AverageQVals |       -1.95e+03 |
# |          StdQVals |         1.5e+03 |
# |          MaxQVals |            63.1 |
# |          MinQVals |        -1.2e+04 |
# |            LossPi |        1.92e+03 |
# |             LossQ |        3.13e+03 |
# |              Time |             169 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |       -1.57e+03 |
# |          StdEpRet |             928 |
# |          MaxEpRet |            -242 |
# |          MinEpRet |       -3.87e+03 |
# |  AverageTestEpRet |       -1.69e+03 |
# |      StdTestEpRet |         1.4e+03 |
# |      MaxTestEpRet |            -822 |
# |      MinTestEpRet |       -5.83e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |      AverageQVals |       -1.96e+03 |
# |          StdQVals |        1.56e+03 |
# |          MaxQVals |              99 |
# |          MinQVals |       -1.25e+04 |
# |            LossPi |        1.93e+03 |
# |             LossQ |        3.18e+03 |
# |              Time |             177 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |       -1.33e+03 |
# |          StdEpRet |             613 |
# |          MaxEpRet |            -146 |
# |          MinEpRet |       -2.53e+03 |
# |  AverageTestEpRet |       -1.03e+03 |
# |      StdTestEpRet |           1e+03 |
# |      MaxTestEpRet |            -206 |
# |      MinTestEpRet |       -3.84e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |      AverageQVals |       -1.97e+03 |
# |          StdQVals |        1.61e+03 |
# |          MaxQVals |             134 |
# |          MinQVals |        -1.3e+04 |
# |            LossPi |        1.94e+03 |
# |             LossQ |        3.24e+03 |
# |              Time |             185 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |       -1.25e+03 |
# |          StdEpRet |             686 |
# |          MaxEpRet |            -476 |
# |          MinEpRet |       -2.45e+03 |
# |  AverageTestEpRet |       -1.09e+03 |
# |      StdTestEpRet |             819 |
# |      MaxTestEpRet |            -252 |
# |      MinTestEpRet |       -2.83e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |      AverageQVals |       -1.97e+03 |
# |          StdQVals |        1.66e+03 |
# |          MaxQVals |             168 |
# |          MinQVals |       -1.32e+04 |
# |            LossPi |        1.94e+03 |
# |             LossQ |        3.38e+03 |
# |              Time |             193 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |       -1.13e+03 |
# |          StdEpRet |             761 |
# |          MaxEpRet |            -195 |
# |          MinEpRet |       -2.91e+03 |
# |  AverageTestEpRet |       -2.24e+03 |
# |      StdTestEpRet |        1.74e+03 |
# |      MaxTestEpRet |            -675 |
# |      MinTestEpRet |       -6.84e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |      AverageQVals |       -1.96e+03 |
# |          StdQVals |        1.71e+03 |
# |          MaxQVals |             212 |
# |          MinQVals |       -1.34e+04 |
# |            LossPi |        1.93e+03 |
# |             LossQ |        3.38e+03 |
# |              Time |             201 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |       -1.26e+03 |
# |          StdEpRet |        1.07e+03 |
# |          MaxEpRet |            -209 |
# |          MinEpRet |       -3.65e+03 |
# |  AverageTestEpRet |        -1.6e+03 |
# |      StdTestEpRet |        1.15e+03 |
# |      MaxTestEpRet |            -463 |
# |      MinTestEpRet |       -3.98e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |      AverageQVals |       -1.95e+03 |
# |          StdQVals |        1.76e+03 |
# |          MaxQVals |             269 |
# |          MinQVals |       -1.44e+04 |
# |            LossPi |        1.93e+03 |
# |             LossQ |        3.49e+03 |
# |              Time |             209 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |       -1.16e+03 |
# |          StdEpRet |             595 |
# |          MaxEpRet |            -216 |
# |          MinEpRet |       -2.18e+03 |
# |  AverageTestEpRet |       -1.12e+03 |
# |      StdTestEpRet |             618 |
# |      MaxTestEpRet |            -296 |
# |      MinTestEpRet |       -2.21e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |      AverageQVals |       -1.96e+03 |
# |          StdQVals |        1.83e+03 |
# |          MaxQVals |             319 |
# |          MinQVals |        -1.5e+04 |
# |            LossPi |        1.92e+03 |
# |             LossQ |        3.47e+03 |
# |              Time |             217 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |        -1.5e+03 |
# |          StdEpRet |             900 |
# |          MaxEpRet |            -206 |
# |          MinEpRet |       -3.74e+03 |
# |  AverageTestEpRet |       -1.62e+03 |
# |      StdTestEpRet |             737 |
# |      MaxTestEpRet |            -332 |
# |      MinTestEpRet |        -2.7e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |      AverageQVals |       -1.96e+03 |
# |          StdQVals |        1.89e+03 |
# |          MaxQVals |             383 |
# |          MinQVals |       -1.59e+04 |
# |            LossPi |        1.93e+03 |
# |             LossQ |        3.62e+03 |
# |              Time |             225 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |       -1.24e+03 |
# |          StdEpRet |             752 |
# |          MaxEpRet |            -319 |
# |          MinEpRet |       -3.13e+03 |
# |  AverageTestEpRet |       -1.62e+03 |
# |      StdTestEpRet |             961 |
# |      MaxTestEpRet |            -235 |
# |      MinTestEpRet |       -3.25e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |       -1.95e+03 |
# |          StdQVals |        1.95e+03 |
# |          MaxQVals |             444 |
# |          MinQVals |       -1.66e+04 |
# |            LossPi |        1.91e+03 |
# |             LossQ |        3.81e+03 |
# |              Time |             233 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |       -1.17e+03 |
# |          StdEpRet |             585 |
# |          MaxEpRet |           -46.1 |
# |          MinEpRet |       -2.41e+03 |
# |  AverageTestEpRet |       -1.07e+03 |
# |      StdTestEpRet |             701 |
# |      MaxTestEpRet |            -166 |
# |      MinTestEpRet |       -2.17e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |      AverageQVals |       -1.93e+03 |
# |          StdQVals |        2.01e+03 |
# |          MaxQVals |             484 |
# |          MinQVals |       -1.75e+04 |
# |            LossPi |         1.9e+03 |
# |             LossQ |        3.88e+03 |
# |              Time |             240 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |       -1.18e+03 |
# |          StdEpRet |             791 |
# |          MaxEpRet |           -54.5 |
# |          MinEpRet |       -2.64e+03 |
# |  AverageTestEpRet |       -1.33e+03 |
# |      StdTestEpRet |             853 |
# |      MaxTestEpRet |            -391 |
# |      MinTestEpRet |       -3.44e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |      AverageQVals |       -1.94e+03 |
# |          StdQVals |        2.09e+03 |
# |          MaxQVals |             591 |
# |          MinQVals |       -1.81e+04 |
# |            LossPi |        1.91e+03 |
# |             LossQ |        4.06e+03 |
# |              Time |             248 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -795 |
# |          StdEpRet |             458 |
# |          MaxEpRet |            -273 |
# |          MinEpRet |        -1.9e+03 |
# |  AverageTestEpRet |            -768 |
# |      StdTestEpRet |             341 |
# |      MaxTestEpRet |            -454 |
# |      MinTestEpRet |        -1.5e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |      AverageQVals |       -1.92e+03 |
# |          StdQVals |        2.14e+03 |
# |          MaxQVals |             609 |
# |          MinQVals |       -1.93e+04 |
# |            LossPi |        1.89e+03 |
# |             LossQ |         4.1e+03 |
# |              Time |             257 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |       -1.37e+03 |
# |          StdEpRet |             553 |
# |          MaxEpRet |            -606 |
# |          MinEpRet |       -2.75e+03 |
# |  AverageTestEpRet |       -1.43e+03 |
# |      StdTestEpRet |             480 |
# |      MaxTestEpRet |            -683 |
# |      MinTestEpRet |        -2.1e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |      AverageQVals |       -1.93e+03 |
# |          StdQVals |        2.21e+03 |
# |          MaxQVals |             645 |
# |          MinQVals |       -2.01e+04 |
# |            LossPi |         1.9e+03 |
# |             LossQ |         4.3e+03 |
# |              Time |             265 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |       -1.49e+03 |
# |          StdEpRet |        1.25e+03 |
# |          MaxEpRet |            -137 |
# |          MinEpRet |       -3.87e+03 |
# |  AverageTestEpRet |       -1.33e+03 |
# |      StdTestEpRet |             712 |
# |      MaxTestEpRet |            -250 |
# |      MinTestEpRet |       -2.71e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |      AverageQVals |       -1.93e+03 |
# |          StdQVals |        2.27e+03 |
# |          MaxQVals |             672 |
# |          MinQVals |       -2.09e+04 |
# |            LossPi |         1.9e+03 |
# |             LossQ |         4.5e+03 |
# |              Time |             272 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |       -1.38e+03 |
# |          StdEpRet |             703 |
# |          MaxEpRet |            -325 |
# |          MinEpRet |       -2.78e+03 |
# |  AverageTestEpRet |       -1.85e+03 |
# |      StdTestEpRet |        1.23e+03 |
# |      MaxTestEpRet |            -707 |
# |      MinTestEpRet |       -4.86e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |      AverageQVals |       -1.93e+03 |
# |          StdQVals |        2.32e+03 |
# |          MaxQVals |             710 |
# |          MinQVals |       -2.18e+04 |
# |            LossPi |         1.9e+03 |
# |             LossQ |        4.64e+03 |
# |              Time |             280 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |       -1.18e+03 |
# |          StdEpRet |             982 |
# |          MaxEpRet |           -85.8 |
# |          MinEpRet |       -3.21e+03 |
# |  AverageTestEpRet |       -1.79e+03 |
# |      StdTestEpRet |        1.42e+03 |
# |      MaxTestEpRet |            -516 |
# |      MinTestEpRet |       -5.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |      AverageQVals |       -1.95e+03 |
# |          StdQVals |        2.39e+03 |
# |          MaxQVals |             739 |
# |          MinQVals |       -2.26e+04 |
# |            LossPi |        1.92e+03 |
# |             LossQ |        4.81e+03 |
# |              Time |             288 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |       -1.61e+03 |
# |          StdEpRet |             783 |
# |          MaxEpRet |            -437 |
# |          MinEpRet |       -3.42e+03 |
# |  AverageTestEpRet |       -1.87e+03 |
# |      StdTestEpRet |             782 |
# |      MaxTestEpRet |            -551 |
# |      MinTestEpRet |        -2.9e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |      AverageQVals |       -1.96e+03 |
# |          StdQVals |        2.44e+03 |
# |          MaxQVals |             778 |
# |          MinQVals |       -2.32e+04 |
# |            LossPi |        1.93e+03 |
# |             LossQ |        4.99e+03 |
# |              Time |             296 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |       -1.54e+03 |
# |          StdEpRet |             897 |
# |          MaxEpRet |            -413 |
# |          MinEpRet |       -3.32e+03 |
# |  AverageTestEpRet |        -1.4e+03 |
# |      StdTestEpRet |             810 |
# |      MaxTestEpRet |            -148 |
# |      MinTestEpRet |       -2.69e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |      AverageQVals |       -1.99e+03 |
# |          StdQVals |        2.52e+03 |
# |          MaxQVals |             846 |
# |          MinQVals |       -2.48e+04 |
# |            LossPi |        1.96e+03 |
# |             LossQ |        5.18e+03 |
# |              Time |             303 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |       -1.84e+03 |
# |          StdEpRet |             927 |
# |          MaxEpRet |            -581 |
# |          MinEpRet |       -3.39e+03 |
# |  AverageTestEpRet |       -1.48e+03 |
# |      StdTestEpRet |             569 |
# |      MaxTestEpRet |            -264 |
# |      MinTestEpRet |        -2.4e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |       -2.02e+03 |
# |          StdQVals |        2.62e+03 |
# |          MaxQVals |             925 |
# |          MinQVals |       -2.61e+04 |
# |            LossPi |        1.99e+03 |
# |             LossQ |        5.34e+03 |
# |              Time |             312 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |        -1.5e+03 |
# |          StdEpRet |        1.21e+03 |
# |          MaxEpRet |            -114 |
# |          MinEpRet |       -4.31e+03 |
# |  AverageTestEpRet |       -2.15e+03 |
# |      StdTestEpRet |        1.58e+03 |
# |      MaxTestEpRet |            -262 |
# |      MinTestEpRet |       -5.67e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |      AverageQVals |       -2.06e+03 |
# |          StdQVals |        2.67e+03 |
# |          MaxQVals |             978 |
# |          MinQVals |       -2.73e+04 |
# |            LossPi |        2.02e+03 |
# |             LossQ |        5.68e+03 |
# |              Time |             320 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |       -1.93e+03 |
# |          StdEpRet |        1.26e+03 |
# |          MaxEpRet |            -506 |
# |          MinEpRet |       -4.47e+03 |
# |  AverageTestEpRet |       -1.93e+03 |
# |      StdTestEpRet |        1.36e+03 |
# |      MaxTestEpRet |            -368 |
# |      MinTestEpRet |       -4.99e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |      AverageQVals |       -2.09e+03 |
# |          StdQVals |        2.76e+03 |
# |          MaxQVals |        1.04e+03 |
# |          MinQVals |       -2.79e+04 |
# |            LossPi |        2.06e+03 |
# |             LossQ |        6.08e+03 |
# |              Time |             328 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |       -1.39e+03 |
# |          StdEpRet |             917 |
# |          MaxEpRet |            -198 |
# |          MinEpRet |       -3.67e+03 |
# |  AverageTestEpRet |            -850 |
# |      StdTestEpRet |             428 |
# |      MaxTestEpRet |            -265 |
# |      MinTestEpRet |       -1.56e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |      AverageQVals |       -2.12e+03 |
# |          StdQVals |        2.84e+03 |
# |          MaxQVals |        1.09e+03 |
# |          MinQVals |       -2.95e+04 |
# |            LossPi |        2.08e+03 |
# |             LossQ |        6.42e+03 |
# |              Time |             335 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |       -2.01e+03 |
# |          StdEpRet |        1.14e+03 |
# |          MaxEpRet |            -786 |
# |          MinEpRet |       -4.85e+03 |
# |  AverageTestEpRet |       -1.49e+03 |
# |      StdTestEpRet |             893 |
# |      MaxTestEpRet |            -248 |
# |      MinTestEpRet |       -2.67e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |      AverageQVals |       -2.15e+03 |
# |          StdQVals |        2.92e+03 |
# |          MaxQVals |        1.14e+03 |
# |          MinQVals |       -3.14e+04 |
# |            LossPi |        2.12e+03 |
# |             LossQ |         6.6e+03 |
# |              Time |             343 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |       -1.82e+03 |
# |          StdEpRet |         1.1e+03 |
# |          MaxEpRet |            -301 |
# |          MinEpRet |       -3.86e+03 |
# |  AverageTestEpRet |       -1.52e+03 |
# |      StdTestEpRet |        1.34e+03 |
# |      MaxTestEpRet |            -391 |
# |      MinTestEpRet |       -4.73e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |      AverageQVals |       -2.21e+03 |
# |          StdQVals |        3.04e+03 |
# |          MaxQVals |        1.18e+03 |
# |          MinQVals |       -3.25e+04 |
# |            LossPi |        2.18e+03 |
# |             LossQ |        7.14e+03 |
# |              Time |             351 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |       -1.21e+03 |
# |          StdEpRet |             882 |
# |          MaxEpRet |            -260 |
# |          MinEpRet |       -3.32e+03 |
# |  AverageTestEpRet |       -1.52e+03 |
# |      StdTestEpRet |        1.06e+03 |
# |      MaxTestEpRet |            -771 |
# |      MinTestEpRet |       -4.16e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |      AverageQVals |       -2.24e+03 |
# |          StdQVals |        3.12e+03 |
# |          MaxQVals |        1.22e+03 |
# |          MinQVals |        -3.4e+04 |
# |            LossPi |        2.21e+03 |
# |             LossQ |        7.52e+03 |
# |              Time |             359 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |       -1.81e+03 |
# |          StdEpRet |             903 |
# |          MaxEpRet |            -201 |
# |          MinEpRet |       -3.19e+03 |
# |  AverageTestEpRet |       -1.74e+03 |
# |      StdTestEpRet |             608 |
# |      MaxTestEpRet |            -957 |
# |      MinTestEpRet |       -2.76e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.75e+04 |
# |      AverageQVals |       -2.27e+03 |
# |          StdQVals |        3.19e+03 |
# |          MaxQVals |        1.27e+03 |
# |          MinQVals |       -3.52e+04 |
# |            LossPi |        2.23e+03 |
# |             LossQ |        7.84e+03 |
# |              Time |             367 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |       -1.19e+03 |
# |          StdEpRet |             745 |
# |          MaxEpRet |            -297 |
# |          MinEpRet |        -3.5e+03 |
# |  AverageTestEpRet |       -1.47e+03 |
# |      StdTestEpRet |             826 |
# |      MaxTestEpRet |            -300 |
# |      MinTestEpRet |       -2.84e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.92e+04 |
# |      AverageQVals |       -2.32e+03 |
# |          StdQVals |        3.29e+03 |
# |          MaxQVals |        1.31e+03 |
# |          MinQVals |       -3.64e+04 |
# |            LossPi |        2.28e+03 |
# |             LossQ |        8.17e+03 |
# |              Time |             375 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |       -1.62e+03 |
# |          StdEpRet |        1.06e+03 |
# |          MaxEpRet |            -429 |
# |          MinEpRet |       -4.92e+03 |
# |  AverageTestEpRet |            -929 |
# |      StdTestEpRet |             874 |
# |      MaxTestEpRet |            -108 |
# |      MinTestEpRet |       -3.28e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+04 |
# |      AverageQVals |       -2.35e+03 |
# |          StdQVals |        3.39e+03 |
# |          MaxQVals |        1.36e+03 |
# |          MinQVals |       -3.71e+04 |
# |            LossPi |        2.31e+03 |
# |             LossQ |        8.51e+03 |
# |              Time |             383 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |       -1.53e+03 |
# |          StdEpRet |        1.39e+03 |
# |          MaxEpRet |            -180 |
# |          MinEpRet |       -5.68e+03 |
# |  AverageTestEpRet |       -1.41e+03 |
# |      StdTestEpRet |        1.34e+03 |
# |      MaxTestEpRet |            -306 |
# |      MinTestEpRet |       -3.79e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |       -2.39e+03 |
# |          StdQVals |        3.52e+03 |
# |          MaxQVals |        1.43e+03 |
# |          MinQVals |       -3.77e+04 |
# |            LossPi |        2.35e+03 |
# |             LossQ |        9.05e+03 |
# |              Time |             391 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |       -1.34e+03 |
# |          StdEpRet |        1.32e+03 |
# |          MaxEpRet |            -307 |
# |          MinEpRet |       -5.85e+03 |
# |  AverageTestEpRet |       -1.85e+03 |
# |      StdTestEpRet |        1.22e+03 |
# |      MaxTestEpRet |            -279 |
# |      MinTestEpRet |       -3.89e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.41e+04 |
# |      AverageQVals |       -2.42e+03 |
# |          StdQVals |        3.63e+03 |
# |          MaxQVals |        1.51e+03 |
# |          MinQVals |          -4e+04 |
# |            LossPi |        2.38e+03 |
# |             LossQ |        9.26e+03 |
# |              Time |             399 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |       -1.65e+03 |
# |          StdEpRet |        1.02e+03 |
# |          MaxEpRet |            -327 |
# |          MinEpRet |       -4.28e+03 |
# |  AverageTestEpRet |       -1.59e+03 |
# |      StdTestEpRet |        1.02e+03 |
# |      MaxTestEpRet |            -234 |
# |      MinTestEpRet |       -3.55e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.58e+04 |
# |      AverageQVals |       -2.43e+03 |
# |          StdQVals |        3.73e+03 |
# |          MaxQVals |        1.57e+03 |
# |          MinQVals |       -4.16e+04 |
# |            LossPi |        2.39e+03 |
# |             LossQ |        9.67e+03 |
# |              Time |             406 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |       -1.15e+03 |
# |          StdEpRet |             889 |
# |          MaxEpRet |            -220 |
# |          MinEpRet |       -3.07e+03 |
# |  AverageTestEpRet |       -1.68e+03 |
# |      StdTestEpRet |        1.16e+03 |
# |      MaxTestEpRet |            -265 |
# |      MinTestEpRet |       -4.08e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.74e+04 |
# |      AverageQVals |       -2.46e+03 |
# |          StdQVals |        3.85e+03 |
# |          MaxQVals |        1.64e+03 |
# |          MinQVals |       -4.28e+04 |
# |            LossPi |        2.42e+03 |
# |             LossQ |        1.04e+04 |
# |              Time |             414 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |       -1.54e+03 |
# |          StdEpRet |        2.35e+03 |
# |          MaxEpRet |            -103 |
# |          MinEpRet |       -8.97e+03 |
# |  AverageTestEpRet |        -1.9e+03 |
# |      StdTestEpRet |        1.27e+03 |
# |      MaxTestEpRet |            -357 |
# |      MinTestEpRet |        -4.1e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.91e+04 |
# |      AverageQVals |       -2.49e+03 |
# |          StdQVals |           4e+03 |
# |          MaxQVals |        1.71e+03 |
# |          MinQVals |        -4.5e+04 |
# |            LossPi |        2.45e+03 |
# |             LossQ |        1.07e+04 |
# |              Time |             422 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |          -2e+03 |
# |          StdEpRet |        1.64e+03 |
# |          MaxEpRet |             -51 |
# |          MinEpRet |       -6.23e+03 |
# |  AverageTestEpRet |       -1.58e+03 |
# |      StdTestEpRet |         1.4e+03 |
# |      MaxTestEpRet |            -268 |
# |      MinTestEpRet |       -4.53e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        9.07e+04 |
# |      AverageQVals |       -2.51e+03 |
# |          StdQVals |        4.08e+03 |
# |          MaxQVals |        1.82e+03 |
# |          MinQVals |       -4.66e+04 |
# |            LossPi |        2.47e+03 |
# |             LossQ |        1.11e+04 |
# |              Time |             429 |
# ---------------------------------------
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             482 |
# |      AverageEpRet |          -7e+03 |
# |          StdEpRet |        1.76e+03 |
# |          MaxEpRet |       -4.72e+03 |
# |          MinEpRet |        -1.1e+04 |
# |  AverageTestEpRet |        -6.9e+03 |
# |      StdTestEpRet |        2.18e+03 |
# |      MaxTestEpRet |       -3.69e+03 |
# |      MinTestEpRet |       -1.15e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.95e+05 |
# |      AverageQVals |       -9.15e+07 |
# |          StdQVals |        1.28e+08 |
# |          MaxQVals |       -6.36e+06 |
# |          MinQVals |        -1.5e+09 |
# |            LossPi |        9.14e+07 |
# |             LossQ |        2.59e+13 |
# |              Time |        3.87e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             483 |
# |      AverageEpRet |       -7.42e+03 |
# |          StdEpRet |        1.22e+03 |
# |          MaxEpRet |       -5.74e+03 |
# |          MinEpRet |       -1.02e+04 |
# |  AverageTestEpRet |        -6.6e+03 |
# |      StdTestEpRet |        1.75e+03 |
# |      MaxTestEpRet |        -3.9e+03 |
# |      MinTestEpRet |       -9.98e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.97e+05 |
# |      AverageQVals |       -9.29e+07 |
# |          StdQVals |         1.3e+08 |
# |          MaxQVals |       -7.56e+06 |
# |          MinQVals |       -1.54e+09 |
# |            LossPi |        9.28e+07 |
# |             LossQ |        2.64e+13 |
# |              Time |        3.88e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             484 |
# |      AverageEpRet |       -7.22e+03 |
# |          StdEpRet |        1.97e+03 |
# |          MaxEpRet |       -3.98e+03 |
# |          MinEpRet |       -1.13e+04 |
# |  AverageTestEpRet |       -7.64e+03 |
# |      StdTestEpRet |        1.69e+03 |
# |      MaxTestEpRet |       -4.13e+03 |
# |      MinTestEpRet |       -1.14e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.99e+05 |
# |      AverageQVals |       -9.37e+07 |
# |          StdQVals |        1.31e+08 |
# |          MaxQVals |       -6.54e+06 |
# |          MinQVals |       -1.49e+09 |
# |            LossPi |        9.36e+07 |
# |             LossQ |        2.69e+13 |
# |              Time |        3.88e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             485 |
# |      AverageEpRet |       -7.12e+03 |
# |          StdEpRet |        1.65e+03 |
# |          MaxEpRet |       -4.45e+03 |
# |          MinEpRet |       -9.54e+03 |
# |  AverageTestEpRet |       -7.36e+03 |
# |      StdTestEpRet |        2.82e+03 |
# |      MaxTestEpRet |       -4.27e+03 |
# |      MinTestEpRet |       -1.19e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |           8e+05 |
# |      AverageQVals |       -9.53e+07 |
# |          StdQVals |        1.32e+08 |
# |          MaxQVals |       -7.99e+06 |
# |          MinQVals |       -1.51e+09 |
# |            LossPi |        9.52e+07 |
# |             LossQ |        2.77e+13 |
# |              Time |        3.89e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             486 |
# |      AverageEpRet |       -7.63e+03 |
# |          StdEpRet |        2.29e+03 |
# |          MaxEpRet |       -3.71e+03 |
# |          MinEpRet |        -1.1e+04 |
# |  AverageTestEpRet |       -6.23e+03 |
# |      StdTestEpRet |        1.11e+03 |
# |      MaxTestEpRet |       -4.51e+03 |
# |      MinTestEpRet |       -8.75e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.02e+05 |
# |      AverageQVals |       -9.64e+07 |
# |          StdQVals |        1.34e+08 |
# |          MaxQVals |       -7.95e+06 |
# |          MinQVals |       -1.54e+09 |
# |            LossPi |        9.63e+07 |
# |             LossQ |        2.81e+13 |
# |              Time |         3.9e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             487 |
# |      AverageEpRet |       -6.78e+03 |
# |          StdEpRet |           2e+03 |
# |          MaxEpRet |       -3.75e+03 |
# |          MinEpRet |       -1.04e+04 |
# |  AverageTestEpRet |       -6.77e+03 |
# |      StdTestEpRet |        1.95e+03 |
# |      MaxTestEpRet |       -4.27e+03 |
# |      MinTestEpRet |       -1.14e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.04e+05 |
# |      AverageQVals |       -9.75e+07 |
# |          StdQVals |        1.36e+08 |
# |          MaxQVals |       -8.21e+06 |
# |          MinQVals |       -1.56e+09 |
# |            LossPi |        9.74e+07 |
# |             LossQ |        2.85e+13 |
# |              Time |        3.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             488 |
# |      AverageEpRet |          -7e+03 |
# |          StdEpRet |        2.11e+03 |
# |          MaxEpRet |       -4.02e+03 |
# |          MinEpRet |       -1.16e+04 |
# |  AverageTestEpRet |       -7.43e+03 |
# |      StdTestEpRet |        2.13e+03 |
# |      MaxTestEpRet |       -3.89e+03 |
# |      MinTestEpRet |       -1.11e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.05e+05 |
# |      AverageQVals |       -9.92e+07 |
# |          StdQVals |        1.38e+08 |
# |          MaxQVals |       -7.14e+06 |
# |          MinQVals |       -1.59e+09 |
# |            LossPi |        9.91e+07 |
# |             LossQ |        2.91e+13 |
# |              Time |        3.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             489 |
# |      AverageEpRet |       -6.69e+03 |
# |          StdEpRet |        1.31e+03 |
# |          MaxEpRet |       -4.29e+03 |
# |          MinEpRet |       -8.95e+03 |
# |  AverageTestEpRet |       -8.49e+03 |
# |      StdTestEpRet |        1.59e+03 |
# |      MaxTestEpRet |       -5.18e+03 |
# |      MinTestEpRet |       -1.08e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.07e+05 |
# |      AverageQVals |          -1e+08 |
# |          StdQVals |        1.39e+08 |
# |          MaxQVals |       -7.27e+06 |
# |          MinQVals |       -1.59e+09 |
# |            LossPi |           1e+08 |
# |             LossQ |        2.95e+13 |
# |              Time |        3.92e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             490 |
# |      AverageEpRet |       -7.96e+03 |
# |          StdEpRet |        3.11e+03 |
# |          MaxEpRet |       -3.15e+03 |
# |          MinEpRet |       -1.26e+04 |
# |  AverageTestEpRet |       -7.96e+03 |
# |      StdTestEpRet |           2e+03 |
# |      MaxTestEpRet |       -4.83e+03 |
# |      MinTestEpRet |       -1.18e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+05 |
# |      AverageQVals |       -1.01e+08 |
# |          StdQVals |        1.39e+08 |
# |          MaxQVals |       -8.45e+06 |
# |          MinQVals |       -1.62e+09 |
# |            LossPi |        1.01e+08 |
# |             LossQ |        3.04e+13 |
# |              Time |        3.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             491 |
# |      AverageEpRet |       -7.46e+03 |
# |          StdEpRet |        2.14e+03 |
# |          MaxEpRet |       -4.92e+03 |
# |          MinEpRet |        -1.2e+04 |
# |  AverageTestEpRet |       -7.94e+03 |
# |      StdTestEpRet |         1.5e+03 |
# |      MaxTestEpRet |       -6.29e+03 |
# |      MinTestEpRet |       -1.08e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         8.1e+05 |
# |      AverageQVals |       -1.02e+08 |
# |          StdQVals |        1.41e+08 |
# |          MaxQVals |       -7.55e+06 |
# |          MinQVals |       -1.59e+09 |
# |            LossPi |        1.02e+08 |
# |             LossQ |         3.1e+13 |
# |              Time |        3.94e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             492 |
# |      AverageEpRet |       -7.06e+03 |
# |          StdEpRet |        1.93e+03 |
# |          MaxEpRet |       -3.94e+03 |
# |          MinEpRet |       -1.18e+04 |
# |  AverageTestEpRet |       -6.47e+03 |
# |      StdTestEpRet |        2.36e+03 |
# |      MaxTestEpRet |       -3.91e+03 |
# |      MinTestEpRet |        -1.1e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.12e+05 |
# |      AverageQVals |       -1.04e+08 |
# |          StdQVals |        1.44e+08 |
# |          MaxQVals |        -7.7e+06 |
# |          MinQVals |       -1.64e+09 |
# |            LossPi |        1.03e+08 |
# |             LossQ |        3.15e+13 |
# |              Time |        3.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             493 |
# |      AverageEpRet |       -6.53e+03 |
# |          StdEpRet |        1.72e+03 |
# |          MaxEpRet |       -4.02e+03 |
# |          MinEpRet |       -1.08e+04 |
# |  AverageTestEpRet |       -6.73e+03 |
# |      StdTestEpRet |             840 |
# |      MaxTestEpRet |       -4.66e+03 |
# |      MinTestEpRet |       -7.83e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.13e+05 |
# |      AverageQVals |       -1.05e+08 |
# |          StdQVals |        1.44e+08 |
# |          MaxQVals |       -7.93e+06 |
# |          MinQVals |       -1.67e+09 |
# |            LossPi |        1.05e+08 |
# |             LossQ |         3.2e+13 |
# |              Time |        3.96e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             494 |
# |      AverageEpRet |       -7.41e+03 |
# |          StdEpRet |        1.83e+03 |
# |          MaxEpRet |       -4.46e+03 |
# |          MinEpRet |       -1.19e+04 |
# |  AverageTestEpRet |       -7.14e+03 |
# |      StdTestEpRet |        2.52e+03 |
# |      MaxTestEpRet |        -3.1e+03 |
# |      MinTestEpRet |       -1.23e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.15e+05 |
# |      AverageQVals |       -1.06e+08 |
# |          StdQVals |        1.46e+08 |
# |          MaxQVals |       -8.24e+06 |
# |          MinQVals |       -1.66e+09 |
# |            LossPi |        1.06e+08 |
# |             LossQ |        3.28e+13 |
# |              Time |        3.96e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             495 |
# |      AverageEpRet |       -7.49e+03 |
# |          StdEpRet |        1.61e+03 |
# |          MaxEpRet |       -4.98e+03 |
# |          MinEpRet |       -1.08e+04 |
# |  AverageTestEpRet |       -8.07e+03 |
# |      StdTestEpRet |        1.72e+03 |
# |      MaxTestEpRet |       -5.99e+03 |
# |      MinTestEpRet |       -1.14e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.17e+05 |
# |      AverageQVals |       -1.07e+08 |
# |          StdQVals |        1.47e+08 |
# |          MaxQVals |       -1.06e+07 |
# |          MinQVals |       -1.68e+09 |
# |            LossPi |        1.07e+08 |
# |             LossQ |        3.34e+13 |
# |              Time |        3.97e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             496 |
# |      AverageEpRet |       -7.69e+03 |
# |          StdEpRet |        2.01e+03 |
# |          MaxEpRet |       -4.73e+03 |
# |          MinEpRet |       -1.11e+04 |
# |  AverageTestEpRet |       -7.33e+03 |
# |      StdTestEpRet |        1.89e+03 |
# |      MaxTestEpRet |        -4.8e+03 |
# |      MinTestEpRet |       -1.18e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.18e+05 |
# |      AverageQVals |       -1.08e+08 |
# |          StdQVals |        1.48e+08 |
# |          MaxQVals |       -8.38e+06 |
# |          MinQVals |       -1.68e+09 |
# |            LossPi |        1.08e+08 |
# |             LossQ |         3.4e+13 |
# |              Time |        3.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             497 |
# |      AverageEpRet |       -7.23e+03 |
# |          StdEpRet |        2.12e+03 |
# |          MaxEpRet |       -4.24e+03 |
# |          MinEpRet |       -1.17e+04 |
# |  AverageTestEpRet |        -6.4e+03 |
# |      StdTestEpRet |        1.54e+03 |
# |      MaxTestEpRet |       -4.14e+03 |
# |      MinTestEpRet |       -8.45e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         8.2e+05 |
# |      AverageQVals |       -1.09e+08 |
# |          StdQVals |        1.49e+08 |
# |          MaxQVals |       -8.52e+06 |
# |          MinQVals |        -1.7e+09 |
# |            LossPi |        1.09e+08 |
# |             LossQ |        3.42e+13 |
# |              Time |        3.99e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             498 |
# |      AverageEpRet |       -6.77e+03 |
# |          StdEpRet |        1.91e+03 |
# |          MaxEpRet |       -4.43e+03 |
# |          MinEpRet |       -1.17e+04 |
# |  AverageTestEpRet |       -6.59e+03 |
# |      StdTestEpRet |        2.52e+03 |
# |      MaxTestEpRet |       -3.51e+03 |
# |      MinTestEpRet |        -1.2e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.22e+05 |
# |      AverageQVals |       -1.11e+08 |
# |          StdQVals |        1.51e+08 |
# |          MaxQVals |       -1.02e+07 |
# |          MinQVals |        -1.7e+09 |
# |            LossPi |        1.11e+08 |
# |             LossQ |        3.49e+13 |
# |              Time |           4e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             499 |
# |      AverageEpRet |       -7.46e+03 |
# |          StdEpRet |        1.72e+03 |
# |          MaxEpRet |       -4.27e+03 |
# |          MinEpRet |       -1.09e+04 |
# |  AverageTestEpRet |        -7.1e+03 |
# |      StdTestEpRet |        1.53e+03 |
# |      MaxTestEpRet |       -4.65e+03 |
# |      MinTestEpRet |       -9.86e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.23e+05 |
# |      AverageQVals |       -1.11e+08 |
# |          StdQVals |        1.52e+08 |
# |          MaxQVals |       -1.02e+07 |
# |          MinQVals |       -1.71e+09 |
# |            LossPi |        1.11e+08 |
# |             LossQ |        3.57e+13 |
# |              Time |        4.01e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             500 |
# |      AverageEpRet |       -8.58e+03 |
# |          StdEpRet |        2.11e+03 |
# |          MaxEpRet |       -4.22e+03 |
# |          MinEpRet |       -1.13e+04 |
# |  AverageTestEpRet |       -7.69e+03 |
# |      StdTestEpRet |        1.85e+03 |
# |      MaxTestEpRet |       -5.21e+03 |
# |      MinTestEpRet |       -1.08e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+05 |
# |      AverageQVals |       -1.13e+08 |
# |          StdQVals |        1.53e+08 |
# |          MaxQVals |       -9.44e+06 |
# |          MinQVals |       -1.77e+09 |
# |            LossPi |        1.13e+08 |
# |             LossQ |        3.66e+13 |
# |              Time |        4.01e+03 |
# ---------------------------------------

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='integral_scaled', exp_name='integral_scaled')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0025
qlr_b = 0.0025

# Baseline 0 training
spinup.ddpg_pytorch(env_int, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Warning: Log dir integral_scaled already exists! Storing info there anyway.
# Logging data to integral_scaled/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fb0ae275268>, env_name='gyroscopeintegralenv-v0', reward_type='Quadratic', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1}, ep_len=110)",
#     "epochs":	100,
#     "exp_name":	"integral_scaled",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fb07c8ef4e0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"integral_scaled",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"integral_scaled",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='integral_scaled/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"integral_scaled",
#         "output_dir":	"integral_scaled"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.0025,
#     "polyak":	0.995,
#     "q_lr":	0.0025,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 5602, 	 q: 6001
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |        -6.7e+03 |
# |          StdEpRet |             956 |
# |          MaxEpRet |       -5.39e+03 |
# |          MinEpRet |       -9.31e+03 |
# |  AverageTestEpRet |       -4.74e+03 |
# |      StdTestEpRet |        1.08e+03 |
# |      MaxTestEpRet |       -3.53e+03 |
# |      MinTestEpRet |       -7.59e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |      AverageQVals |            -106 |
# |          StdQVals |            70.6 |
# |          MaxQVals |           0.318 |
# |          MinQVals |            -373 |
# |            LossPi |             103 |
# |             LossQ |        1.08e+03 |
# |              Time |            4.54 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |       -6.94e+03 |
# |          StdEpRet |             669 |
# |          MaxEpRet |       -5.66e+03 |
# |          MinEpRet |        -8.3e+03 |
# |  AverageTestEpRet |       -1.81e+03 |
# |      StdTestEpRet |        1.24e+03 |
# |      MaxTestEpRet |            -433 |
# |      MinTestEpRet |       -4.69e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |      AverageQVals |            -339 |
# |          StdQVals |             156 |
# |          MaxQVals |           -34.2 |
# |          MinQVals |            -922 |
# |            LossPi |             312 |
# |             LossQ |        1.34e+03 |
# |              Time |            12.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |       -6.85e+03 |
# |          StdEpRet |             855 |
# |          MaxEpRet |       -4.72e+03 |
# |          MinEpRet |       -8.56e+03 |
# |  AverageTestEpRet |       -2.88e+03 |
# |      StdTestEpRet |         1.2e+03 |
# |      MaxTestEpRet |            -667 |
# |      MinTestEpRet |       -4.46e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |      AverageQVals |            -541 |
# |          StdQVals |             163 |
# |          MaxQVals |            -133 |
# |          MinQVals |       -1.17e+03 |
# |            LossPi |             503 |
# |             LossQ |        1.99e+03 |
# |              Time |            20.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |          -7e+03 |
# |          StdEpRet |        1.06e+03 |
# |          MaxEpRet |        -5.2e+03 |
# |          MinEpRet |       -9.51e+03 |
# |  AverageTestEpRet |        -3.9e+03 |
# |      StdTestEpRet |        3.25e+03 |
# |      MaxTestEpRet |           -44.7 |
# |      MinTestEpRet |       -8.85e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |      AverageQVals |            -718 |
# |          StdQVals |             175 |
# |          MaxQVals |            -267 |
# |          MinQVals |       -1.56e+03 |
# |            LossPi |             679 |
# |             LossQ |        1.77e+03 |
# |              Time |              29 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |       -7.08e+03 |
# |          StdEpRet |             351 |
# |          MaxEpRet |       -6.43e+03 |
# |          MinEpRet |       -7.62e+03 |
# |  AverageTestEpRet |       -2.53e+03 |
# |      StdTestEpRet |        1.75e+03 |
# |      MaxTestEpRet |            -149 |
# |      MinTestEpRet |       -4.97e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |      AverageQVals |            -864 |
# |          StdQVals |             196 |
# |          MaxQVals |            -337 |
# |          MinQVals |       -1.67e+03 |
# |            LossPi |             818 |
# |             LossQ |        1.71e+03 |
# |              Time |            39.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |        -6.8e+03 |
# |          StdEpRet |             560 |
# |          MaxEpRet |       -5.47e+03 |
# |          MinEpRet |       -7.67e+03 |
# |  AverageTestEpRet |       -2.05e+03 |
# |      StdTestEpRet |        1.26e+03 |
# |      MaxTestEpRet |            -906 |
# |      MinTestEpRet |       -4.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |      AverageQVals |            -950 |
# |          StdQVals |             207 |
# |          MaxQVals |            -317 |
# |          MinQVals |       -1.79e+03 |
# |            LossPi |             900 |
# |             LossQ |        1.65e+03 |
# |              Time |            50.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |       -1.98e+03 |
# |          StdEpRet |        1.67e+03 |
# |          MaxEpRet |            -251 |
# |          MinEpRet |       -7.28e+03 |
# |  AverageTestEpRet |        -2.5e+03 |
# |      StdTestEpRet |        1.39e+03 |
# |      MaxTestEpRet |            -204 |
# |      MinTestEpRet |       -4.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |      AverageQVals |       -1.01e+03 |
# |          StdQVals |             213 |
# |          MaxQVals |            -348 |
# |          MinQVals |       -1.95e+03 |
# |            LossPi |             964 |
# |             LossQ |        1.36e+03 |
# |              Time |            61.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |       -2.48e+03 |
# |          StdEpRet |        2.13e+03 |
# |          MaxEpRet |            -485 |
# |          MinEpRet |       -8.48e+03 |
# |  AverageTestEpRet |       -2.72e+03 |
# |      StdTestEpRet |         1.3e+03 |
# |      MaxTestEpRet |            -569 |
# |      MinTestEpRet |       -4.24e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |      AverageQVals |       -1.06e+03 |
# |          StdQVals |             231 |
# |          MaxQVals |            -366 |
# |          MinQVals |       -2.09e+03 |
# |            LossPi |        1.02e+03 |
# |             LossQ |         1.1e+03 |
# |              Time |            72.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |       -3.06e+03 |
# |          StdEpRet |        1.58e+03 |
# |          MaxEpRet |            -329 |
# |          MinEpRet |       -5.37e+03 |
# |  AverageTestEpRet |       -3.54e+03 |
# |      StdTestEpRet |        1.49e+03 |
# |      MaxTestEpRet |       -1.04e+03 |
# |      MinTestEpRet |       -5.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |      AverageQVals |       -1.14e+03 |
# |          StdQVals |             297 |
# |          MaxQVals |            -357 |
# |          MinQVals |       -2.46e+03 |
# |            LossPi |         1.1e+03 |
# |             LossQ |        1.13e+03 |
# |              Time |            84.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |       -2.77e+03 |
# |          StdEpRet |        1.02e+03 |
# |          MaxEpRet |       -1.06e+03 |
# |          MinEpRet |       -4.24e+03 |
# |  AverageTestEpRet |       -2.94e+03 |
# |      StdTestEpRet |             963 |
# |      MaxTestEpRet |       -1.09e+03 |
# |      MinTestEpRet |       -3.91e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |       -1.21e+03 |
# |          StdQVals |             362 |
# |          MaxQVals |            -371 |
# |          MinQVals |       -2.52e+03 |
# |            LossPi |        1.17e+03 |
# |             LossQ |        1.02e+03 |
# |              Time |            96.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |       -3.41e+03 |
# |          StdEpRet |        1.36e+03 |
# |          MaxEpRet |       -1.04e+03 |
# |          MinEpRet |          -6e+03 |
# |  AverageTestEpRet |       -3.14e+03 |
# |      StdTestEpRet |        1.11e+03 |
# |      MaxTestEpRet |            -556 |
# |      MinTestEpRet |        -4.4e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |      AverageQVals |       -1.32e+03 |
# |          StdQVals |             541 |
# |          MaxQVals |            -312 |
# |          MinQVals |       -3.72e+03 |
# |            LossPi |        1.28e+03 |
# |             LossQ |             921 |
# |              Time |             109 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |       -2.92e+03 |
# |          StdEpRet |        1.65e+03 |
# |          MaxEpRet |            -973 |
# |          MinEpRet |        -5.8e+03 |
# |  AverageTestEpRet |       -3.74e+03 |
# |      StdTestEpRet |        2.11e+03 |
# |      MaxTestEpRet |            -691 |
# |      MinTestEpRet |       -6.78e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |      AverageQVals |        -1.5e+03 |
# |          StdQVals |             860 |
# |          MaxQVals |            -265 |
# |          MinQVals |       -6.08e+03 |
# |            LossPi |        1.47e+03 |
# |             LossQ |             918 |
# |              Time |             121 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |       -4.17e+03 |
# |          StdEpRet |             852 |
# |          MaxEpRet |       -2.67e+03 |
# |          MinEpRet |       -6.43e+03 |
# |  AverageTestEpRet |       -1.12e+03 |
# |      StdTestEpRet |             394 |
# |      MaxTestEpRet |            -427 |
# |      MinTestEpRet |        -1.8e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |      AverageQVals |       -1.82e+03 |
# |          StdQVals |        1.45e+03 |
# |          MaxQVals |            -225 |
# |          MinQVals |       -7.42e+03 |
# |            LossPi |        1.79e+03 |
# |             LossQ |             966 |
# |              Time |             132 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |       -3.12e+03 |
# |          StdEpRet |             907 |
# |          MaxEpRet |       -1.05e+03 |
# |          MinEpRet |       -4.25e+03 |
# |  AverageTestEpRet |            -803 |
# |      StdTestEpRet |             358 |
# |      MaxTestEpRet |            -219 |
# |      MinTestEpRet |       -1.45e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |      AverageQVals |       -2.19e+03 |
# |          StdQVals |        1.96e+03 |
# |          MaxQVals |            -175 |
# |          MinQVals |       -8.16e+03 |
# |            LossPi |        2.15e+03 |
# |             LossQ |             947 |
# |              Time |             143 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |       -4.29e+03 |
# |          StdEpRet |             734 |
# |          MaxEpRet |       -3.09e+03 |
# |          MinEpRet |       -6.26e+03 |
# |  AverageTestEpRet |            -959 |
# |      StdTestEpRet |             904 |
# |      MaxTestEpRet |            -199 |
# |      MinTestEpRet |       -3.45e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |      AverageQVals |       -2.55e+03 |
# |          StdQVals |        2.42e+03 |
# |          MaxQVals |            -115 |
# |          MinQVals |       -9.77e+03 |
# |            LossPi |        2.51e+03 |
# |             LossQ |             929 |
# |              Time |             154 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |       -3.49e+03 |
# |          StdEpRet |         1.2e+03 |
# |          MaxEpRet |            -737 |
# |          MinEpRet |       -4.75e+03 |
# |  AverageTestEpRet |            -844 |
# |      StdTestEpRet |             591 |
# |      MaxTestEpRet |            -325 |
# |      MinTestEpRet |       -2.01e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |      AverageQVals |       -2.93e+03 |
# |          StdQVals |        2.86e+03 |
# |          MaxQVals |           -48.9 |
# |          MinQVals |       -9.97e+03 |
# |            LossPi |        2.89e+03 |
# |             LossQ |             949 |
# |              Time |             166 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |       -3.93e+03 |
# |          StdEpRet |        1.48e+03 |
# |          MaxEpRet |       -1.17e+03 |
# |          MinEpRet |       -6.15e+03 |
# |  AverageTestEpRet |            -716 |
# |      StdTestEpRet |             316 |
# |      MaxTestEpRet |            -373 |
# |      MinTestEpRet |       -1.43e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |      AverageQVals |       -3.29e+03 |
# |          StdQVals |        3.19e+03 |
# |          MaxQVals |            16.1 |
# |          MinQVals |       -1.07e+04 |
# |            LossPi |        3.25e+03 |
# |             LossQ |             948 |
# |              Time |             178 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |       -2.73e+03 |
# |          StdEpRet |        1.46e+03 |
# |          MaxEpRet |            -429 |
# |          MinEpRet |        -4.9e+03 |
# |  AverageTestEpRet |            -473 |
# |      StdTestEpRet |             288 |
# |      MaxTestEpRet |           -82.5 |
# |      MinTestEpRet |       -1.07e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |      AverageQVals |       -3.56e+03 |
# |          StdQVals |         3.4e+03 |
# |          MaxQVals |              65 |
# |          MinQVals |       -1.07e+04 |
# |            LossPi |        3.53e+03 |
# |             LossQ |             932 |
# |              Time |             189 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |       -1.45e+03 |
# |          StdEpRet |        1.27e+03 |
# |          MaxEpRet |            -121 |
# |          MinEpRet |       -4.47e+03 |
# |  AverageTestEpRet |            -516 |
# |      StdTestEpRet |             199 |
# |      MaxTestEpRet |           -66.8 |
# |      MinTestEpRet |            -741 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |      AverageQVals |       -3.75e+03 |
# |          StdQVals |        3.47e+03 |
# |          MaxQVals |             109 |
# |          MinQVals |       -1.06e+04 |
# |            LossPi |        3.72e+03 |
# |             LossQ |             913 |
# |              Time |             200 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |       -1.11e+03 |
# |          StdEpRet |             607 |
# |          MaxEpRet |            -163 |
# |          MinEpRet |       -2.23e+03 |
# |  AverageTestEpRet |       -1.06e+03 |
# |      StdTestEpRet |             739 |
# |      MaxTestEpRet |            -311 |
# |      MinTestEpRet |       -2.96e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |       -3.91e+03 |
# |          StdQVals |        3.51e+03 |
# |          MaxQVals |             153 |
# |          MinQVals |       -1.05e+04 |
# |            LossPi |        3.88e+03 |
# |             LossQ |             901 |
# |              Time |             209 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            -782 |
# |          StdEpRet |             488 |
# |          MaxEpRet |            -137 |
# |          MinEpRet |       -2.12e+03 |
# |  AverageTestEpRet |            -635 |
# |      StdTestEpRet |             281 |
# |      MaxTestEpRet |            -271 |
# |      MinTestEpRet |       -1.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |      AverageQVals |       -4.04e+03 |
# |          StdQVals |         3.5e+03 |
# |          MaxQVals |             189 |
# |          MinQVals |       -1.03e+04 |
# |            LossPi |        4.01e+03 |
# |             LossQ |             880 |
# |              Time |             219 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            -888 |
# |          StdEpRet |             502 |
# |          MaxEpRet |            -134 |
# |          MinEpRet |       -1.86e+03 |
# |  AverageTestEpRet |            -660 |
# |      StdTestEpRet |             511 |
# |      MaxTestEpRet |            -149 |
# |      MinTestEpRet |       -1.94e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |      AverageQVals |       -4.13e+03 |
# |          StdQVals |        3.48e+03 |
# |          MaxQVals |             240 |
# |          MinQVals |       -1.02e+04 |
# |            LossPi |         4.1e+03 |
# |             LossQ |             864 |
# |              Time |             229 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -738 |
# |          StdEpRet |             557 |
# |          MaxEpRet |            -169 |
# |          MinEpRet |       -2.19e+03 |
# |  AverageTestEpRet |          -2e+03 |
# |      StdTestEpRet |        2.19e+03 |
# |      MaxTestEpRet |            -322 |
# |      MinTestEpRet |       -7.21e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |      AverageQVals |        -4.2e+03 |
# |          StdQVals |        3.46e+03 |
# |          MaxQVals |             268 |
# |          MinQVals |       -1.01e+04 |
# |            LossPi |        4.17e+03 |
# |             LossQ |             843 |
# |              Time |             239 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |            -658 |
# |          StdEpRet |             309 |
# |          MaxEpRet |            -147 |
# |          MinEpRet |       -1.26e+03 |
# |  AverageTestEpRet |       -6.36e+03 |
# |      StdTestEpRet |         1.3e+03 |
# |      MaxTestEpRet |       -3.18e+03 |
# |      MinTestEpRet |       -7.98e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |      AverageQVals |       -4.25e+03 |
# |          StdQVals |        3.43e+03 |
# |          MaxQVals |             284 |
# |          MinQVals |       -1.03e+04 |
# |            LossPi |        4.21e+03 |
# |             LossQ |             859 |
# |              Time |             251 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            -586 |
# |          StdEpRet |             245 |
# |          MaxEpRet |            -183 |
# |          MinEpRet |        -1.1e+03 |
# |  AverageTestEpRet |       -7.11e+03 |
# |      StdTestEpRet |             208 |
# |      MaxTestEpRet |       -6.88e+03 |
# |      MinTestEpRet |       -7.56e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |      AverageQVals |       -4.23e+03 |
# |          StdQVals |        3.35e+03 |
# |          MaxQVals |             298 |
# |          MinQVals |       -1.03e+04 |
# |            LossPi |         4.2e+03 |
# |             LossQ |             833 |
# |              Time |             262 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |            -543 |
# |          StdEpRet |             269 |
# |          MaxEpRet |           -75.7 |
# |          MinEpRet |            -944 |
# |  AverageTestEpRet |       -7.49e+03 |
# |      StdTestEpRet |             166 |
# |      MaxTestEpRet |       -7.22e+03 |
# |      MinTestEpRet |       -7.77e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |      AverageQVals |        -4.2e+03 |
# |          StdQVals |        3.21e+03 |
# |          MaxQVals |             329 |
# |          MinQVals |       -9.93e+03 |
# |            LossPi |        4.17e+03 |
# |             LossQ |             826 |
# |              Time |             273 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |       -1.08e+03 |
# |          StdEpRet |             545 |
# |          MaxEpRet |            -368 |
# |          MinEpRet |        -2.1e+03 |
# |  AverageTestEpRet |       -7.66e+03 |
# |      StdTestEpRet |             236 |
# |      MaxTestEpRet |       -7.33e+03 |
# |      MinTestEpRet |       -8.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |      AverageQVals |       -4.09e+03 |
# |          StdQVals |        3.06e+03 |
# |          MaxQVals |             340 |
# |          MinQVals |       -9.58e+03 |
# |            LossPi |        4.06e+03 |
# |             LossQ |             816 |
# |              Time |             283 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |       -1.94e+03 |
# |          StdEpRet |             863 |
# |          MaxEpRet |            -599 |
# |          MinEpRet |       -3.46e+03 |
# |  AverageTestEpRet |       -7.75e+03 |
# |      StdTestEpRet |             216 |
# |      MaxTestEpRet |       -7.46e+03 |
# |      MinTestEpRet |       -8.22e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |      AverageQVals |       -3.92e+03 |
# |          StdQVals |        2.89e+03 |
# |          MaxQVals |             359 |
# |          MinQVals |       -9.16e+03 |
# |            LossPi |        3.89e+03 |
# |             LossQ |             841 |
# |              Time |             292 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |       -1.19e+03 |
# |          StdEpRet |             793 |
# |          MaxEpRet |            -162 |
# |          MinEpRet |       -2.59e+03 |
# |  AverageTestEpRet |       -7.78e+03 |
# |      StdTestEpRet |             214 |
# |      MaxTestEpRet |       -7.45e+03 |
# |      MinTestEpRet |        -8.1e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |      AverageQVals |       -3.72e+03 |
# |          StdQVals |        2.72e+03 |
# |          MaxQVals |             362 |
# |          MinQVals |       -8.81e+03 |
# |            LossPi |        3.69e+03 |
# |             LossQ |             853 |
# |              Time |             302 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -803 |
# |          StdEpRet |             530 |
# |          MaxEpRet |            -107 |
# |          MinEpRet |       -2.43e+03 |
# |  AverageTestEpRet |       -7.68e+03 |
# |      StdTestEpRet |             297 |
# |      MaxTestEpRet |       -7.17e+03 |
# |      MinTestEpRet |       -8.28e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |       -3.53e+03 |
# |          StdQVals |        2.57e+03 |
# |          MaxQVals |             374 |
# |          MinQVals |       -8.34e+03 |
# |            LossPi |         3.5e+03 |
# |             LossQ |             874 |
# |              Time |             312 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            -678 |
# |          StdEpRet |             475 |
# |          MaxEpRet |            -179 |
# |          MinEpRet |          -2e+03 |
# |  AverageTestEpRet |       -7.77e+03 |
# |      StdTestEpRet |             154 |
# |      MaxTestEpRet |       -7.57e+03 |
# |      MinTestEpRet |       -8.09e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |      AverageQVals |       -3.34e+03 |
# |          StdQVals |        2.43e+03 |
# |          MaxQVals |             395 |
# |          MinQVals |       -8.13e+03 |
# |            LossPi |        3.32e+03 |
# |             LossQ |             860 |
# |              Time |             322 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -885 |
# |          StdEpRet |             560 |
# |          MaxEpRet |            -135 |
# |          MinEpRet |          -2e+03 |
# |  AverageTestEpRet |       -7.69e+03 |
# |      StdTestEpRet |             144 |
# |      MaxTestEpRet |       -7.47e+03 |
# |      MinTestEpRet |       -7.89e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |      AverageQVals |       -3.16e+03 |
# |          StdQVals |        2.31e+03 |
# |          MaxQVals |             424 |
# |          MinQVals |       -7.83e+03 |
# |            LossPi |        3.13e+03 |
# |             LossQ |             860 |
# |              Time |             332 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -923 |
# |          StdEpRet |             465 |
# |          MaxEpRet |            -225 |
# |          MinEpRet |       -2.06e+03 |
# |  AverageTestEpRet |       -7.76e+03 |
# |      StdTestEpRet |             191 |
# |      MaxTestEpRet |       -7.52e+03 |
# |      MinTestEpRet |        -8.1e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |      AverageQVals |       -2.97e+03 |
# |          StdQVals |        2.19e+03 |
# |          MaxQVals |             435 |
# |          MinQVals |       -7.61e+03 |
# |            LossPi |        2.95e+03 |
# |             LossQ |             836 |
# |              Time |             342 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |       -1.37e+03 |
# |          StdEpRet |        1.01e+03 |
# |          MaxEpRet |            -230 |
# |          MinEpRet |        -3.1e+03 |
# |  AverageTestEpRet |       -7.71e+03 |
# |      StdTestEpRet |             250 |
# |      MaxTestEpRet |       -7.17e+03 |
# |      MinTestEpRet |       -8.03e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |      AverageQVals |       -2.78e+03 |
# |          StdQVals |        2.09e+03 |
# |          MaxQVals |             433 |
# |          MinQVals |       -7.33e+03 |
# |            LossPi |        2.76e+03 |
# |             LossQ |             844 |
# |              Time |             351 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |       -2.09e+03 |
# |          StdEpRet |        1.93e+03 |
# |          MaxEpRet |            -119 |
# |          MinEpRet |       -6.03e+03 |
# |  AverageTestEpRet |        -7.7e+03 |
# |      StdTestEpRet |             188 |
# |      MaxTestEpRet |       -7.48e+03 |
# |      MinTestEpRet |       -8.06e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |      AverageQVals |       -2.63e+03 |
# |          StdQVals |        1.98e+03 |
# |          MaxQVals |             463 |
# |          MinQVals |       -7.08e+03 |
# |            LossPi |         2.6e+03 |
# |             LossQ |             859 |
# |              Time |             362 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |       -6.97e+03 |
# |          StdEpRet |             964 |
# |          MaxEpRet |       -4.69e+03 |
# |          MinEpRet |       -7.84e+03 |
# |  AverageTestEpRet |       -7.71e+03 |
# |      StdTestEpRet |             203 |
# |      MaxTestEpRet |       -7.41e+03 |
# |      MinTestEpRet |       -8.03e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |      AverageQVals |       -2.55e+03 |
# |          StdQVals |        1.95e+03 |
# |          MaxQVals |             483 |
# |          MinQVals |       -9.31e+03 |
# |            LossPi |        2.52e+03 |
# |             LossQ |        1.01e+03 |
# |              Time |             371 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |       -6.97e+03 |
# |          StdEpRet |             866 |
# |          MaxEpRet |       -4.82e+03 |
# |          MinEpRet |          -8e+03 |
# |  AverageTestEpRet |       -7.62e+03 |
# |      StdTestEpRet |             185 |
# |      MaxTestEpRet |       -7.25e+03 |
# |      MinTestEpRet |       -7.84e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |      AverageQVals |       -2.58e+03 |
# |          StdQVals |         2.1e+03 |
# |          MaxQVals |             532 |
# |          MinQVals |       -1.14e+04 |
# |            LossPi |        2.55e+03 |
# |             LossQ |        1.02e+03 |
# |              Time |             381 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |        -7.3e+03 |
# |          StdEpRet |             634 |
# |          MaxEpRet |       -6.05e+03 |
# |          MinEpRet |       -8.21e+03 |
# |  AverageTestEpRet |       -7.57e+03 |
# |      StdTestEpRet |             318 |
# |      MaxTestEpRet |       -6.92e+03 |
# |      MinTestEpRet |       -7.84e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |      AverageQVals |       -2.67e+03 |
# |          StdQVals |        2.46e+03 |
# |          MaxQVals |             562 |
# |          MinQVals |       -1.43e+04 |
# |            LossPi |        2.64e+03 |
# |             LossQ |        1.11e+03 |
# |              Time |             391 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |       -8.52e+03 |
# |          StdEpRet |        2.63e+03 |
# |          MaxEpRet |       -4.79e+03 |
# |          MinEpRet |       -1.28e+04 |
# |  AverageTestEpRet |       -8.42e+03 |
# |      StdTestEpRet |        1.38e+03 |
# |      MaxTestEpRet |       -7.26e+03 |
# |      MinTestEpRet |       -1.14e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |      AverageQVals |       -2.84e+03 |
# |          StdQVals |        3.04e+03 |
# |          MaxQVals |             605 |
# |          MinQVals |       -1.78e+04 |
# |            LossPi |        2.81e+03 |
# |             LossQ |        1.11e+03 |
# |              Time |             402 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |       -6.09e+03 |
# |          StdEpRet |        2.05e+03 |
# |          MaxEpRet |       -3.87e+03 |
# |          MinEpRet |       -1.04e+04 |
# |  AverageTestEpRet |       -7.78e+03 |
# |      StdTestEpRet |             737 |
# |      MaxTestEpRet |       -6.76e+03 |
# |      MinTestEpRet |        -9.4e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |          -3e+03 |
# |          StdQVals |        3.47e+03 |
# |          MaxQVals |             654 |
# |          MinQVals |       -1.76e+04 |
# |            LossPi |        2.97e+03 |
# |             LossQ |        1.14e+03 |
# |              Time |             415 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |       -3.14e+03 |
# |          StdEpRet |        1.79e+03 |
# |          MaxEpRet |            -703 |
# |          MinEpRet |       -6.38e+03 |
# |  AverageTestEpRet |       -3.32e+03 |
# |      StdTestEpRet |        1.81e+03 |
# |      MaxTestEpRet |            -312 |
# |      MinTestEpRet |       -7.42e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |      AverageQVals |       -3.18e+03 |
# |          StdQVals |        3.88e+03 |
# |          MaxQVals |             704 |
# |          MinQVals |       -1.95e+04 |
# |            LossPi |        3.15e+03 |
# |             LossQ |        1.17e+03 |
# |              Time |             429 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |       -1.33e+03 |
# |          StdEpRet |             920 |
# |          MaxEpRet |            -310 |
# |          MinEpRet |       -3.74e+03 |
# |  AverageTestEpRet |       -2.99e+03 |
# |      StdTestEpRet |        1.54e+03 |
# |      MaxTestEpRet |            -152 |
# |      MinTestEpRet |       -5.54e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |      AverageQVals |        -3.2e+03 |
# |          StdQVals |        3.92e+03 |
# |          MaxQVals |             776 |
# |          MinQVals |       -1.93e+04 |
# |            LossPi |        3.17e+03 |
# |             LossQ |        1.16e+03 |
# |              Time |             441 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |       -1.72e+03 |
# |          StdEpRet |             993 |
# |          MaxEpRet |            -218 |
# |          MinEpRet |       -3.91e+03 |
# |  AverageTestEpRet |       -1.92e+03 |
# |      StdTestEpRet |        1.16e+03 |
# |      MaxTestEpRet |            -169 |
# |      MinTestEpRet |       -3.43e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |      AverageQVals |       -3.18e+03 |
# |          StdQVals |         3.9e+03 |
# |          MaxQVals |             828 |
# |          MinQVals |       -1.89e+04 |
# |            LossPi |        3.15e+03 |
# |             LossQ |        1.16e+03 |
# |              Time |             452 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |       -2.07e+03 |
# |          StdEpRet |             930 |
# |          MaxEpRet |            -150 |
# |          MinEpRet |       -3.56e+03 |
# |  AverageTestEpRet |       -1.47e+03 |
# |      StdTestEpRet |        1.01e+03 |
# |      MaxTestEpRet |            -361 |
# |      MinTestEpRet |       -3.15e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |      AverageQVals |       -3.16e+03 |
# |          StdQVals |        3.85e+03 |
# |          MaxQVals |             928 |
# |          MinQVals |       -1.87e+04 |
# |            LossPi |        3.13e+03 |
# |             LossQ |        1.16e+03 |
# |              Time |             463 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |        -1.8e+03 |
# |          StdEpRet |        1.21e+03 |
# |          MaxEpRet |            -201 |
# |          MinEpRet |        -4.1e+03 |
# |  AverageTestEpRet |       -1.27e+03 |
# |      StdTestEpRet |        1.04e+03 |
# |      MaxTestEpRet |            -138 |
# |      MinTestEpRet |       -3.54e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |      AverageQVals |       -3.08e+03 |
# |          StdQVals |        3.76e+03 |
# |          MaxQVals |             991 |
# |          MinQVals |       -1.84e+04 |
# |            LossPi |        3.05e+03 |
# |             LossQ |        1.16e+03 |
# |              Time |             475 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |       -1.61e+03 |
# |          StdEpRet |        1.38e+03 |
# |          MaxEpRet |            -245 |
# |          MinEpRet |       -5.54e+03 |
# |  AverageTestEpRet |       -1.64e+03 |
# |      StdTestEpRet |        1.13e+03 |
# |      MaxTestEpRet |            -326 |
# |      MinTestEpRet |       -3.84e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |      AverageQVals |       -3.02e+03 |
# |          StdQVals |        3.69e+03 |
# |          MaxQVals |        1.06e+03 |
# |          MinQVals |       -1.81e+04 |
# |            LossPi |        2.99e+03 |
# |             LossQ |        1.15e+03 |
# |              Time |             488 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |       -1.53e+03 |
# |          StdEpRet |        1.29e+03 |
# |          MaxEpRet |           -69.2 |
# |          MinEpRet |       -4.47e+03 |
# |  AverageTestEpRet |       -2.12e+03 |
# |      StdTestEpRet |        1.15e+03 |
# |      MaxTestEpRet |            -695 |
# |      MinTestEpRet |       -4.75e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.75e+04 |
# |      AverageQVals |       -2.94e+03 |
# |          StdQVals |        3.62e+03 |
# |          MaxQVals |        1.14e+03 |
# |          MinQVals |       -1.79e+04 |
# |            LossPi |        2.91e+03 |
# |             LossQ |        1.14e+03 |
# |              Time |             499 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |       -1.41e+03 |
# |          StdEpRet |        1.22e+03 |
# |          MaxEpRet |           -38.4 |
# |          MinEpRet |       -4.05e+03 |
# |  AverageTestEpRet |       -1.14e+03 |
# |      StdTestEpRet |        1.08e+03 |
# |      MaxTestEpRet |           -78.9 |
# |      MinTestEpRet |       -3.28e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.92e+04 |
# |      AverageQVals |       -2.85e+03 |
# |          StdQVals |        3.52e+03 |
# |          MaxQVals |        1.22e+03 |
# |          MinQVals |       -1.76e+04 |
# |            LossPi |        2.81e+03 |
# |             LossQ |        1.14e+03 |
# |              Time |             509 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |       -1.14e+03 |
# |          StdEpRet |             758 |
# |          MaxEpRet |            -297 |
# |          MinEpRet |       -2.68e+03 |
# |  AverageTestEpRet |       -1.04e+03 |
# |      StdTestEpRet |             761 |
# |      MaxTestEpRet |            -382 |
# |      MinTestEpRet |       -3.16e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+04 |
# |      AverageQVals |        -2.7e+03 |
# |          StdQVals |         3.4e+03 |
# |          MaxQVals |        1.29e+03 |
# |          MinQVals |       -1.73e+04 |
# |            LossPi |        2.67e+03 |
# |             LossQ |        1.14e+03 |
# |              Time |             523 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            -753 |
# |          StdEpRet |             451 |
# |          MaxEpRet |           -83.8 |
# |          MinEpRet |        -1.5e+03 |
# |  AverageTestEpRet |            -504 |
# |      StdTestEpRet |             417 |
# |      MaxTestEpRet |           -88.1 |
# |      MinTestEpRet |       -1.27e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |       -2.57e+03 |
# |          StdQVals |         3.3e+03 |
# |          MaxQVals |        1.36e+03 |
# |          MinQVals |       -1.71e+04 |
# |            LossPi |        2.54e+03 |
# |             LossQ |        1.11e+03 |
# |              Time |             533 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |            -478 |
# |          StdEpRet |             254 |
# |          MaxEpRet |            -106 |
# |          MinEpRet |            -860 |
# |  AverageTestEpRet |            -614 |
# |      StdTestEpRet |             477 |
# |      MaxTestEpRet |           -89.3 |
# |      MinTestEpRet |       -1.49e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.41e+04 |
# |      AverageQVals |        -2.4e+03 |
# |          StdQVals |        3.18e+03 |
# |          MaxQVals |        1.41e+03 |
# |          MinQVals |       -1.68e+04 |
# |            LossPi |        2.37e+03 |
# |             LossQ |        1.08e+03 |
# |              Time |             544 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |            -454 |
# |          StdEpRet |             276 |
# |          MaxEpRet |           -84.5 |
# |          MinEpRet |       -1.01e+03 |
# |  AverageTestEpRet |            -439 |
# |      StdTestEpRet |             263 |
# |      MaxTestEpRet |           -87.3 |
# |      MinTestEpRet |            -813 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.58e+04 |
# |      AverageQVals |       -2.21e+03 |
# |          StdQVals |        3.07e+03 |
# |          MaxQVals |        1.45e+03 |
# |          MinQVals |       -1.65e+04 |
# |            LossPi |        2.18e+03 |
# |             LossQ |        1.09e+03 |
# |              Time |             554 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |            -439 |
# |          StdEpRet |             277 |
# |          MaxEpRet |           -52.8 |
# |          MinEpRet |       -1.04e+03 |
# |  AverageTestEpRet |            -482 |
# |      StdTestEpRet |             232 |
# |      MaxTestEpRet |           -81.2 |
# |      MinTestEpRet |            -835 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.74e+04 |
# |      AverageQVals |       -2.04e+03 |
# |          StdQVals |        2.97e+03 |
# |          MaxQVals |        1.51e+03 |
# |          MinQVals |       -1.62e+04 |
# |            LossPi |        2.02e+03 |
# |             LossQ |        1.07e+03 |
# |              Time |             565 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |            -399 |
# |          StdEpRet |             165 |
# |          MaxEpRet |            -154 |
# |          MinEpRet |            -766 |
# |  AverageTestEpRet |            -333 |
# |      StdTestEpRet |             199 |
# |      MaxTestEpRet |            -125 |
# |      MinTestEpRet |            -709 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.91e+04 |
# |      AverageQVals |       -1.86e+03 |
# |          StdQVals |        2.86e+03 |
# |          MaxQVals |        1.57e+03 |
# |          MinQVals |       -1.59e+04 |
# |            LossPi |        1.83e+03 |
# |             LossQ |        1.02e+03 |
# |              Time |             576 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |            -622 |
# |          StdEpRet |             305 |
# |          MaxEpRet |            -129 |
# |          MinEpRet |        -1.3e+03 |
# |  AverageTestEpRet |            -604 |
# |      StdTestEpRet |             344 |
# |      MaxTestEpRet |            -143 |
# |      MinTestEpRet |       -1.29e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        9.07e+04 |
# |      AverageQVals |       -1.71e+03 |
# |          StdQVals |        2.77e+03 |
# |          MaxQVals |         1.6e+03 |
# |          MinQVals |       -1.55e+04 |
# |            LossPi |        1.68e+03 |
# |             LossQ |             989 |
# |              Time |             589 |
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              82 |
# |      AverageEpRet |            -915 |
# |          StdEpRet |             576 |
# |          MaxEpRet |            -126 |
# |          MinEpRet |       -2.08e+03 |
# |  AverageTestEpRet |            -816 |
# |      StdTestEpRet |             552 |
# |      MaxTestEpRet |            -216 |
# |      MinTestEpRet |        -2.2e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.35e+05 |
# |      AverageQVals |       -1.07e+03 |
# |          StdQVals |        4.63e+03 |
# |          MaxQVals |        2.86e+03 |
# |          MinQVals |       -2.09e+04 |
# |            LossPi |        1.05e+03 |
# |             LossQ |             847 |
# |              Time |             911 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              83 |
# |      AverageEpRet |       -1.08e+03 |
# |          StdEpRet |             435 |
# |          MaxEpRet |            -252 |
# |          MinEpRet |       -1.86e+03 |
# |  AverageTestEpRet |            -628 |
# |      StdTestEpRet |             259 |
# |      MaxTestEpRet |            -305 |
# |      MinTestEpRet |       -1.04e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.37e+05 |
# |      AverageQVals |        -1.2e+03 |
# |          StdQVals |        4.89e+03 |
# |          MaxQVals |        2.94e+03 |
# |          MinQVals |       -2.05e+04 |
# |            LossPi |        1.18e+03 |
# |             LossQ |             804 |
# |              Time |             921 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |       -1.11e+03 |
# |          StdEpRet |             673 |
# |          MaxEpRet |            -256 |
# |          MinEpRet |       -2.33e+03 |
# |  AverageTestEpRet |            -736 |
# |      StdTestEpRet |             376 |
# |      MaxTestEpRet |            -432 |
# |      MinTestEpRet |        -1.7e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.39e+05 |
# |      AverageQVals |       -1.34e+03 |
# |          StdQVals |        5.11e+03 |
# |          MaxQVals |        2.96e+03 |
# |          MinQVals |       -2.01e+04 |
# |            LossPi |        1.31e+03 |
# |             LossQ |             794 |
# |              Time |             933 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |       -1.21e+03 |
# |          StdEpRet |             710 |
# |          MaxEpRet |            -278 |
# |          MinEpRet |       -2.87e+03 |
# |  AverageTestEpRet |            -562 |
# |      StdTestEpRet |             429 |
# |      MaxTestEpRet |            -134 |
# |      MinTestEpRet |       -1.56e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.4e+05 |
# |      AverageQVals |       -1.41e+03 |
# |          StdQVals |         5.2e+03 |
# |          MaxQVals |           3e+03 |
# |          MinQVals |       -1.94e+04 |
# |            LossPi |        1.39e+03 |
# |             LossQ |             784 |
# |              Time |             946 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |        -1.1e+03 |
# |          StdEpRet |             798 |
# |          MaxEpRet |            -217 |
# |          MinEpRet |       -2.74e+03 |
# |  AverageTestEpRet |            -841 |
# |      StdTestEpRet |             305 |
# |      MaxTestEpRet |            -430 |
# |      MinTestEpRet |       -1.56e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.42e+05 |
# |      AverageQVals |       -1.51e+03 |
# |          StdQVals |        5.28e+03 |
# |          MaxQVals |        3.04e+03 |
# |          MinQVals |       -1.87e+04 |
# |            LossPi |        1.49e+03 |
# |             LossQ |             772 |
# |              Time |             957 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |            -781 |
# |          StdEpRet |             249 |
# |          MaxEpRet |            -236 |
# |          MinEpRet |       -1.42e+03 |
# |  AverageTestEpRet |            -657 |
# |      StdTestEpRet |             375 |
# |      MaxTestEpRet |            -300 |
# |      MinTestEpRet |       -1.52e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.44e+05 |
# |      AverageQVals |       -1.54e+03 |
# |          StdQVals |        5.26e+03 |
# |          MaxQVals |        3.06e+03 |
# |          MinQVals |        -1.8e+04 |
# |            LossPi |        1.52e+03 |
# |             LossQ |             746 |
# |              Time |             968 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |       -1.08e+03 |
# |          StdEpRet |             554 |
# |          MaxEpRet |            -361 |
# |          MinEpRet |       -2.28e+03 |
# |  AverageTestEpRet |            -603 |
# |      StdTestEpRet |             343 |
# |      MaxTestEpRet |           -81.5 |
# |      MinTestEpRet |        -1.1e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.45e+05 |
# |      AverageQVals |       -1.63e+03 |
# |          StdQVals |        5.28e+03 |
# |          MaxQVals |        3.07e+03 |
# |          MinQVals |       -1.73e+04 |
# |            LossPi |         1.6e+03 |
# |             LossQ |             734 |
# |              Time |             980 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |            -519 |
# |          StdEpRet |             224 |
# |          MaxEpRet |            -174 |
# |          MinEpRet |       -1.04e+03 |
# |  AverageTestEpRet |            -511 |
# |      StdTestEpRet |             190 |
# |      MaxTestEpRet |            -237 |
# |      MinTestEpRet |            -794 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.47e+05 |
# |      AverageQVals |       -1.63e+03 |
# |          StdQVals |         5.2e+03 |
# |          MaxQVals |        3.11e+03 |
# |          MinQVals |       -1.67e+04 |
# |            LossPi |        1.61e+03 |
# |             LossQ |             695 |
# |              Time |             991 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |            -717 |
# |          StdEpRet |             234 |
# |          MaxEpRet |            -321 |
# |          MinEpRet |       -1.17e+03 |
# |  AverageTestEpRet |            -774 |
# |      StdTestEpRet |             407 |
# |      MaxTestEpRet |            -152 |
# |      MinTestEpRet |       -1.53e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+05 |
# |      AverageQVals |       -1.64e+03 |
# |          StdQVals |         5.1e+03 |
# |          MaxQVals |        3.19e+03 |
# |          MinQVals |       -1.59e+04 |
# |            LossPi |        1.61e+03 |
# |             LossQ |             679 |
# |              Time |           1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |            -898 |
# |          StdEpRet |             308 |
# |          MaxEpRet |            -429 |
# |          MinEpRet |       -1.43e+03 |
# |  AverageTestEpRet |       -1.07e+03 |
# |      StdTestEpRet |             603 |
# |      MaxTestEpRet |            -352 |
# |      MinTestEpRet |       -2.09e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.5e+05 |
# |      AverageQVals |       -1.65e+03 |
# |          StdQVals |        5.03e+03 |
# |          MaxQVals |        3.22e+03 |
# |          MinQVals |       -1.53e+04 |
# |            LossPi |        1.63e+03 |
# |             LossQ |             662 |
# |              Time |        1.01e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |            -857 |
# |          StdEpRet |             430 |
# |          MaxEpRet |            -381 |
# |          MinEpRet |       -1.81e+03 |
# |  AverageTestEpRet |            -782 |
# |      StdTestEpRet |             196 |
# |      MaxTestEpRet |            -444 |
# |      MinTestEpRet |        -1.1e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.52e+05 |
# |      AverageQVals |       -1.65e+03 |
# |          StdQVals |        4.93e+03 |
# |          MaxQVals |        3.27e+03 |
# |          MinQVals |       -1.49e+04 |
# |            LossPi |        1.62e+03 |
# |             LossQ |             651 |
# |              Time |        1.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |            -770 |
# |          StdEpRet |             428 |
# |          MaxEpRet |            -177 |
# |          MinEpRet |        -1.7e+03 |
# |  AverageTestEpRet |            -499 |
# |      StdTestEpRet |             310 |
# |      MaxTestEpRet |            -198 |
# |      MinTestEpRet |       -1.12e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.53e+05 |
# |      AverageQVals |       -1.66e+03 |
# |          StdQVals |        4.85e+03 |
# |          MaxQVals |        3.23e+03 |
# |          MinQVals |       -1.43e+04 |
# |            LossPi |        1.64e+03 |
# |             LossQ |             632 |
# |              Time |        1.04e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |            -874 |
# |          StdEpRet |             507 |
# |          MaxEpRet |            -266 |
# |          MinEpRet |       -2.19e+03 |
# |  AverageTestEpRet |            -621 |
# |      StdTestEpRet |             355 |
# |      MaxTestEpRet |            -181 |
# |      MinTestEpRet |       -1.25e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.55e+05 |
# |      AverageQVals |       -1.67e+03 |
# |          StdQVals |        4.77e+03 |
# |          MaxQVals |        3.23e+03 |
# |          MinQVals |       -1.35e+04 |
# |            LossPi |        1.65e+03 |
# |             LossQ |             624 |
# |              Time |        1.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |            -727 |
# |          StdEpRet |             283 |
# |          MaxEpRet |            -280 |
# |          MinEpRet |       -1.24e+03 |
# |  AverageTestEpRet |            -457 |
# |      StdTestEpRet |             207 |
# |      MaxTestEpRet |            -163 |
# |      MinTestEpRet |            -814 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.57e+05 |
# |      AverageQVals |       -1.67e+03 |
# |          StdQVals |         4.7e+03 |
# |          MaxQVals |        3.23e+03 |
# |          MinQVals |       -1.32e+04 |
# |            LossPi |        1.65e+03 |
# |             LossQ |             629 |
# |              Time |        1.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |            -809 |
# |          StdEpRet |             427 |
# |          MaxEpRet |            -145 |
# |          MinEpRet |       -1.54e+03 |
# |  AverageTestEpRet |            -970 |
# |      StdTestEpRet |             488 |
# |      MaxTestEpRet |            -224 |
# |      MinTestEpRet |       -1.58e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.58e+05 |
# |      AverageQVals |       -1.68e+03 |
# |          StdQVals |        4.63e+03 |
# |          MaxQVals |        3.23e+03 |
# |          MinQVals |       -1.28e+04 |
# |            LossPi |        1.66e+03 |
# |             LossQ |             614 |
# |              Time |        1.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |            -760 |
# |          StdEpRet |             348 |
# |          MaxEpRet |            -199 |
# |          MinEpRet |       -1.35e+03 |
# |  AverageTestEpRet |            -643 |
# |      StdTestEpRet |             431 |
# |      MaxTestEpRet |            -271 |
# |      MinTestEpRet |       -1.77e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.6e+05 |
# |      AverageQVals |       -1.68e+03 |
# |          StdQVals |        4.55e+03 |
# |          MaxQVals |        3.22e+03 |
# |          MinQVals |       -1.24e+04 |
# |            LossPi |        1.66e+03 |
# |             LossQ |             615 |
# |              Time |        1.08e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |            -906 |
# |          StdEpRet |             585 |
# |          MaxEpRet |            -131 |
# |          MinEpRet |       -2.06e+03 |
# |  AverageTestEpRet |            -802 |
# |      StdTestEpRet |             342 |
# |      MaxTestEpRet |            -312 |
# |      MinTestEpRet |       -1.37e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.62e+05 |
# |      AverageQVals |       -1.67e+03 |
# |          StdQVals |        4.47e+03 |
# |          MaxQVals |        3.16e+03 |
# |          MinQVals |       -1.28e+04 |
# |            LossPi |        1.65e+03 |
# |             LossQ |             612 |
# |              Time |        1.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |            -740 |
# |          StdEpRet |             404 |
# |          MaxEpRet |            -111 |
# |          MinEpRet |       -1.57e+03 |
# |  AverageTestEpRet |            -912 |
# |      StdTestEpRet |             399 |
# |      MaxTestEpRet |            -343 |
# |      MinTestEpRet |       -1.54e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.63e+05 |
# |      AverageQVals |       -1.67e+03 |
# |          StdQVals |         4.4e+03 |
# |          MaxQVals |        3.17e+03 |
# |          MinQVals |       -1.27e+04 |
# |            LossPi |        1.65e+03 |
# |             LossQ |             610 |
# |              Time |         1.1e+03 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             100 |
# |      AverageEpRet |            -962 |
# |          StdEpRet |             518 |
# |          MaxEpRet |            -217 |
# |          MinEpRet |       -1.73e+03 |
# |  AverageTestEpRet |            -722 |
# |      StdTestEpRet |             371 |
# |      MaxTestEpRet |            -223 |
# |      MinTestEpRet |       -1.25e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+05 |
# |      AverageQVals |       -1.64e+03 |
# |          StdQVals |        4.33e+03 |
# |          MaxQVals |        3.17e+03 |
# |          MinQVals |       -1.25e+04 |
# |            LossPi |        1.62e+03 |
# |             LossQ |             619 |
# |              Time |        1.11e+03 |
# ---------------------------------------

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='integral_norm', exp_name='integral_norm')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.0025
qlr_b = 0.0025

# Baseline 0 training
spinup.ddpg_pytorch(env_int, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)

# %% [markdown]
# ## Test

# %%
# Test paramaters
env_name = 'gyroscopeintegralenv-v0'
reward_type = 'Quadratic'
reward_args = {'qx1':9,'qx2':0.05,'qx3':9,'qx4':0.05,'pu1':0.1,'pu2':0.1}
seed = 0
agent_path = 'integral_scaled/'
init_state = None#[0,0,0,0,0.5,0,20]
ep_len = 220
t_end = ep_len*0.05

# Perform testing
r,score,x1_eval,x2_eval,x3_eval,x4_eval,x1_ref_eval,x3_ref_eval,act = test_agent(env_name,reward_type,reward_args,seed,agent_path,init_state,t_end,ep_len)
# Out:
# Total cumulative reward: -5086.193058256482

# %% [markdown]
# ## Plot

# %%
plot_test(x1_eval,x2_eval,x3_eval,x4_eval,x1_ref_eval,x3_ref_eval,act,t_end)

# %% [markdown]
# ## Evaluate control performance

# %%
# Single evaluation
env_name = 'gyroscopeenv-v0'
agent_path = 'ddpg_b0'
ss_bound = 0.3
metrics = evaluate_control(env_name,agent_path,ss_bound)
metrics
# Out:
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
#          $\theta$ MAE (rad)  $\phi$ MAE (rad)  $\theta$ MSSE (rad)  \
# Config.
# ddpg_b0            0.586866           0.44291              0.54001
#
#          $\phi$ MSSE (rad)  $\theta$ in bounds (%)  $\phi$ in bounds (%)  \
# Config.
# ddpg_b0           0.367145                    30.5                  51.5
#
#          $\theta$ unsteady (%)  $\phi$ unsteady (%)  $\theta$ rise time (s)  \
# Config.
# ddpg_b0                    0.0                  7.0                0.186066
#
#          $\phi$ rise time (s)  $\theta$ settling time (s)  \
# Config.
# ddpg_b0              0.766869                    1.210041
#
#          $\phi$ settling time (s)    u1 (V)    u2 (V)  u1 variation (V)  \
# Config.
# ddpg_b0                  1.044782  1.718111  1.446938          0.268772
#
#          u2 variation (V)  Convergence time (min)
# Config.
# ddpg_b0          0.324769               14.706724

# %%
# Init dataframe
env_name = 'gyroscopeintegralenv-v0'
agent_paths = ['integral_norm_s10/']
ss_bound = 0.3

# Loop dataframe
for idx, agent_path in zip(range(len(agent_paths)),agent_paths):
    if idx == 0:
        metrics = evaluate_control(env_name,agent_path,ss_bound)
    else:
        new_metrics = evaluate_control(env_name,agent_path,ss_bound)
        metrics = metrics.append(new_metrics)

# Show
metrics
# Out:
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
#                     $\theta$ MAE (rad)  $\phi$ MAE (rad)  $\theta$ MSSE (rad)  \
# Config.
# integral_norm_s10/            0.661056          0.559971             0.488759
#
#                     $\phi$ MSSE (rad)  $\theta$ in bounds (%)  \
# Config.
# integral_norm_s10/           0.568524                    42.5
#
#                     $\phi$ in bounds (%)  $\theta$ unsteady (%)  \
# Config.
# integral_norm_s10/                   5.0                   12.0
#
#                     $\phi$ unsteady (%)  $\theta$ rise time (s)  \
# Config.
# integral_norm_s10/                 32.0                0.498088
#
#                     $\phi$ rise time (s)  $\theta$ settling time (s)  \
# Config.
# integral_norm_s10/                  0.35                    1.030735
#
#                     $\phi$ settling time (s)    u1 (V)    u2 (V)  \
# Config.
# integral_norm_s10/                    1.9375  2.887029  4.023105
#
#                     u1 variation (V)  u2 variation (V)  Convergence time (min)
# Config.
# integral_norm_s10/          0.650895          1.066619                15.70701
