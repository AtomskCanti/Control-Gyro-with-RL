# %% [markdown]
# # DDPG with discontinuous state space to showcase discontinuity (spinup library)

# %%
import gym
from gym import spaces
from gym.utils import seeding
from gym.envs.registration import register

from custom_functions.custom_functions import env_fn 
from custom_functions.custom_functions import test_agent
from custom_functions.custom_functions import plot_test

import spinup

from os import path
from scipy.integrate import solve_ivp
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline
#from vpython import *
from functools import partial
import matplotlib as matplt
matplt.use("pgf")
matplt.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})


register(id='gyroscopediscontinuousenv-v0',entry_point='gym_GyroscopeEnv.envs:GyroscopeDiscontinuousEnv')

# %% [markdown]
# ## Training

# %% [markdown]
# #### Quadratic reward

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='ddpg_discontinuous_quadratic', exp_name='Discontinuity and quadratic reward function')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.001
qlr_b = 0.001

# Env function
reward_args = {'qx1':9,'qx2':0.05,'qx3':9,'qx4':0.05,'pu1':0.1,'pu2':0.1}
env_fn = partial(env_fn,env_name = 'gyroscopediscontinuousenv-v0',reward_type = 'Quadratic', reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Logging data to ddpg_discontinuous/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(<function env_fn at 0x7fda02cd5ea0>, env_name='gyroscopediscontinuousenv-v0', reward_type='Quadratic', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1})",
#     "epochs":	100,
#     "exp_name":	"Quadratic reward function",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fd9cbe53518>":	{
#             "epoch_dict":	{},
#             "exp_name":	"Quadratic reward function",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_discontinuous",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_discontinuous/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"Quadratic reward function",
#         "output_dir":	"ddpg_discontinuous"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 4002, 	 q: 4401
# /home/matthieulc/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |       -7.55e+03 |
# |          StdEpRet |        1.33e+03 |
# |          MaxEpRet |       -5.38e+03 |
# |          MinEpRet |       -1.03e+04 |
# |  AverageTestEpRet |        -7.6e+03 |
# |      StdTestEpRet |        1.61e+03 |
# |      MaxTestEpRet |       -4.45e+03 |
# |      MinTestEpRet |        -9.3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+03 |
# |      AverageQVals |            -129 |
# |          StdQVals |            67.5 |
# |          MaxQVals |            2.15 |
# |          MinQVals |            -356 |
# |            LossPi |             119 |
# |             LossQ |        1.64e+03 |
# |              Time |            5.41 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |       -7.51e+03 |
# |          StdEpRet |        1.02e+03 |
# |          MaxEpRet |        -5.7e+03 |
# |          MinEpRet |       -9.01e+03 |
# |  AverageTestEpRet |       -4.68e+03 |
# |      StdTestEpRet |        1.75e+03 |
# |      MaxTestEpRet |       -2.35e+03 |
# |      MinTestEpRet |       -8.25e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+03 |
# |      AverageQVals |            -390 |
# |          StdQVals |             155 |
# |          MaxQVals |           -63.7 |
# |          MinQVals |            -975 |
# |            LossPi |             371 |
# |             LossQ |        1.91e+03 |
# |              Time |            13.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |       -7.56e+03 |
# |          StdEpRet |             847 |
# |          MaxEpRet |       -6.39e+03 |
# |          MinEpRet |       -9.64e+03 |
# |  AverageTestEpRet |       -6.08e+03 |
# |      StdTestEpRet |        2.65e+03 |
# |      MaxTestEpRet |       -2.86e+03 |
# |      MinTestEpRet |       -1.23e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+03 |
# |      AverageQVals |            -706 |
# |          StdQVals |             233 |
# |          MaxQVals |            -200 |
# |          MinQVals |       -1.58e+03 |
# |            LossPi |             683 |
# |             LossQ |        2.48e+03 |
# |              Time |            21.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |       -7.67e+03 |
# |          StdEpRet |        1.34e+03 |
# |          MaxEpRet |       -5.96e+03 |
# |          MinEpRet |       -1.04e+04 |
# |  AverageTestEpRet |       -4.64e+03 |
# |      StdTestEpRet |        2.98e+03 |
# |      MaxTestEpRet |        -1.1e+03 |
# |      MinTestEpRet |        -1.1e+04 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+03 |
# |      AverageQVals |       -1.03e+03 |
# |          StdQVals |             308 |
# |          MaxQVals |            -313 |
# |          MinQVals |       -2.12e+03 |
# |            LossPi |        1.01e+03 |
# |             LossQ |        3.16e+03 |
# |              Time |            30.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |       -7.66e+03 |
# |          StdEpRet |        1.66e+03 |
# |          MaxEpRet |       -5.18e+03 |
# |          MinEpRet |       -1.03e+04 |
# |  AverageTestEpRet |       -4.08e+03 |
# |      StdTestEpRet |         1.4e+03 |
# |      MaxTestEpRet |       -1.25e+03 |
# |      MinTestEpRet |       -6.91e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+03 |
# |      AverageQVals |       -1.33e+03 |
# |          StdQVals |             385 |
# |          MaxQVals |            -360 |
# |          MinQVals |       -2.62e+03 |
# |            LossPi |        1.31e+03 |
# |             LossQ |        4.58e+03 |
# |              Time |            39.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |       -7.35e+03 |
# |          StdEpRet |         1.3e+03 |
# |          MaxEpRet |       -4.71e+03 |
# |          MinEpRet |       -9.29e+03 |
# |  AverageTestEpRet |        -3.5e+03 |
# |      StdTestEpRet |        1.17e+03 |
# |      MaxTestEpRet |       -1.08e+03 |
# |      MinTestEpRet |       -6.13e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         9.9e+03 |
# |      AverageQVals |       -1.58e+03 |
# |          StdQVals |             457 |
# |          MaxQVals |            -437 |
# |          MinQVals |       -3.12e+03 |
# |            LossPi |        1.55e+03 |
# |             LossQ |         5.5e+03 |
# |              Time |            49.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |       -3.69e+03 |
# |          StdEpRet |        2.12e+03 |
# |          MaxEpRet |       -1.08e+03 |
# |          MinEpRet |       -8.45e+03 |
# |  AverageTestEpRet |       -2.22e+03 |
# |      StdTestEpRet |         1.1e+03 |
# |      MaxTestEpRet |            -674 |
# |      MinTestEpRet |       -3.47e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.15e+04 |
# |      AverageQVals |       -1.79e+03 |
# |          StdQVals |             521 |
# |          MaxQVals |            -487 |
# |          MinQVals |       -3.54e+03 |
# |            LossPi |        1.76e+03 |
# |             LossQ |        6.04e+03 |
# |              Time |            58.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |       -3.02e+03 |
# |          StdEpRet |        1.62e+03 |
# |          MaxEpRet |           -58.3 |
# |          MinEpRet |       -6.37e+03 |
# |  AverageTestEpRet |       -2.01e+03 |
# |      StdTestEpRet |             906 |
# |      MaxTestEpRet |            -540 |
# |      MinTestEpRet |        -3.5e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.32e+04 |
# |      AverageQVals |       -1.95e+03 |
# |          StdQVals |             589 |
# |          MaxQVals |            -557 |
# |          MinQVals |       -3.92e+03 |
# |            LossPi |        1.92e+03 |
# |             LossQ |        6.12e+03 |
# |              Time |            68.2 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |       -1.66e+03 |
# |          StdEpRet |        1.32e+03 |
# |          MaxEpRet |            -339 |
# |          MinEpRet |       -5.52e+03 |
# |  AverageTestEpRet |       -1.28e+03 |
# |      StdTestEpRet |        1.04e+03 |
# |      MaxTestEpRet |            -208 |
# |      MinTestEpRet |       -3.28e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+04 |
# |      AverageQVals |       -2.08e+03 |
# |          StdQVals |             646 |
# |          MaxQVals |            -658 |
# |          MinQVals |       -4.26e+03 |
# |            LossPi |        2.05e+03 |
# |             LossQ |        6.26e+03 |
# |              Time |            77.8 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |       -1.92e+03 |
# |          StdEpRet |        1.44e+03 |
# |          MaxEpRet |            -370 |
# |          MinEpRet |       -5.07e+03 |
# |  AverageTestEpRet |       -1.37e+03 |
# |      StdTestEpRet |        1.31e+03 |
# |      MaxTestEpRet |           -78.7 |
# |      MinTestEpRet |       -3.98e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+04 |
# |      AverageQVals |       -2.18e+03 |
# |          StdQVals |             703 |
# |          MaxQVals |            -666 |
# |          MinQVals |       -4.52e+03 |
# |            LossPi |        2.15e+03 |
# |             LossQ |        6.47e+03 |
# |              Time |            87.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |       -1.37e+03 |
# |          StdEpRet |             832 |
# |          MaxEpRet |            -180 |
# |          MinEpRet |       -3.06e+03 |
# |  AverageTestEpRet |       -1.44e+03 |
# |      StdTestEpRet |        1.17e+03 |
# |      MaxTestEpRet |            -150 |
# |      MinTestEpRet |       -3.95e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.81e+04 |
# |      AverageQVals |       -2.26e+03 |
# |          StdQVals |             734 |
# |          MaxQVals |            -699 |
# |          MinQVals |       -4.75e+03 |
# |            LossPi |        2.24e+03 |
# |             LossQ |         6.4e+03 |
# |              Time |            95.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |       -1.43e+03 |
# |          StdEpRet |        1.12e+03 |
# |          MaxEpRet |            -203 |
# |          MinEpRet |       -4.17e+03 |
# |  AverageTestEpRet |       -1.12e+03 |
# |      StdTestEpRet |             974 |
# |      MaxTestEpRet |            -120 |
# |      MinTestEpRet |       -3.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.98e+04 |
# |      AverageQVals |       -2.31e+03 |
# |          StdQVals |             753 |
# |          MaxQVals |            -735 |
# |          MinQVals |       -4.94e+03 |
# |            LossPi |        2.28e+03 |
# |             LossQ |         6.5e+03 |
# |              Time |             103 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |       -1.36e+03 |
# |          StdEpRet |        1.42e+03 |
# |          MaxEpRet |             -99 |
# |          MinEpRet |       -5.63e+03 |
# |  AverageTestEpRet |        -1.3e+03 |
# |      StdTestEpRet |             892 |
# |      MaxTestEpRet |            -197 |
# |      MinTestEpRet |       -2.72e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.14e+04 |
# |      AverageQVals |       -2.34e+03 |
# |          StdQVals |             765 |
# |          MaxQVals |            -768 |
# |          MinQVals |       -5.11e+03 |
# |            LossPi |        2.31e+03 |
# |             LossQ |        6.48e+03 |
# |              Time |             111 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |       -1.26e+03 |
# |          StdEpRet |        1.06e+03 |
# |          MaxEpRet |            -185 |
# |          MinEpRet |       -3.81e+03 |
# |  AverageTestEpRet |            -791 |
# |      StdTestEpRet |             484 |
# |      MaxTestEpRet |            -266 |
# |      MinTestEpRet |       -1.93e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.31e+04 |
# |      AverageQVals |       -2.36e+03 |
# |          StdQVals |             767 |
# |          MaxQVals |            -796 |
# |          MinQVals |       -5.22e+03 |
# |            LossPi |        2.33e+03 |
# |             LossQ |        6.73e+03 |
# |              Time |             119 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |       -1.23e+03 |
# |          StdEpRet |        1.38e+03 |
# |          MaxEpRet |           -35.8 |
# |          MinEpRet |        -4.5e+03 |
# |  AverageTestEpRet |       -1.26e+03 |
# |      StdTestEpRet |        1.02e+03 |
# |      MaxTestEpRet |           -55.3 |
# |      MinTestEpRet |       -4.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.47e+04 |
# |      AverageQVals |       -2.38e+03 |
# |          StdQVals |             765 |
# |          MaxQVals |            -813 |
# |          MinQVals |       -5.29e+03 |
# |            LossPi |        2.36e+03 |
# |             LossQ |        6.71e+03 |
# |              Time |             127 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |       -1.01e+03 |
# |          StdEpRet |             924 |
# |          MaxEpRet |           -88.9 |
# |          MinEpRet |        -3.5e+03 |
# |  AverageTestEpRet |            -648 |
# |      StdTestEpRet |             532 |
# |      MaxTestEpRet |            -116 |
# |      MinTestEpRet |       -2.01e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.64e+04 |
# |      AverageQVals |       -2.37e+03 |
# |          StdQVals |             755 |
# |          MaxQVals |            -830 |
# |          MinQVals |       -5.32e+03 |
# |            LossPi |        2.35e+03 |
# |             LossQ |        6.75e+03 |
# |              Time |             135 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            -979 |
# |          StdEpRet |             754 |
# |          MaxEpRet |           -41.2 |
# |          MinEpRet |       -2.47e+03 |
# |  AverageTestEpRet |       -1.23e+03 |
# |      StdTestEpRet |        1.07e+03 |
# |      MaxTestEpRet |            -117 |
# |      MinTestEpRet |       -3.91e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         2.8e+04 |
# |      AverageQVals |       -2.36e+03 |
# |          StdQVals |             745 |
# |          MaxQVals |            -846 |
# |          MinQVals |        -5.4e+03 |
# |            LossPi |        2.34e+03 |
# |             LossQ |        6.99e+03 |
# |              Time |             143 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |        -1.2e+03 |
# |          StdEpRet |        1.06e+03 |
# |          MaxEpRet |            -105 |
# |          MinEpRet |       -3.61e+03 |
# |  AverageTestEpRet |       -1.49e+03 |
# |      StdTestEpRet |             943 |
# |      MaxTestEpRet |            -419 |
# |      MinTestEpRet |       -3.63e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        2.97e+04 |
# |      AverageQVals |       -2.33e+03 |
# |          StdQVals |             747 |
# |          MaxQVals |            -854 |
# |          MinQVals |       -5.36e+03 |
# |            LossPi |        2.31e+03 |
# |             LossQ |        7.01e+03 |
# |              Time |             151 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -984 |
# |          StdEpRet |             546 |
# |          MaxEpRet |            -104 |
# |          MinEpRet |       -2.13e+03 |
# |  AverageTestEpRet |       -1.35e+03 |
# |      StdTestEpRet |        1.18e+03 |
# |      MaxTestEpRet |            -194 |
# |      MinTestEpRet |       -3.47e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.13e+04 |
# |      AverageQVals |       -2.29e+03 |
# |          StdQVals |             749 |
# |          MaxQVals |            -855 |
# |          MinQVals |       -5.37e+03 |
# |            LossPi |        2.27e+03 |
# |             LossQ |        6.71e+03 |
# |              Time |             159 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |       -1.25e+03 |
# |          StdEpRet |        1.21e+03 |
# |          MaxEpRet |           -87.1 |
# |          MinEpRet |       -4.37e+03 |
# |  AverageTestEpRet |       -1.17e+03 |
# |      StdTestEpRet |        1.06e+03 |
# |      MaxTestEpRet |            -171 |
# |      MinTestEpRet |       -4.08e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         3.3e+04 |
# |      AverageQVals |       -2.26e+03 |
# |          StdQVals |             740 |
# |          MaxQVals |            -837 |
# |          MinQVals |       -5.36e+03 |
# |            LossPi |        2.24e+03 |
# |             LossQ |        6.63e+03 |
# |              Time |             167 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |       -1.36e+03 |
# |          StdEpRet |             963 |
# |          MaxEpRet |           -42.6 |
# |          MinEpRet |       -4.25e+03 |
# |  AverageTestEpRet |            -851 |
# |      StdTestEpRet |             832 |
# |      MaxTestEpRet |            -104 |
# |      MinTestEpRet |       -3.07e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.46e+04 |
# |      AverageQVals |       -2.22e+03 |
# |          StdQVals |             740 |
# |          MaxQVals |            -814 |
# |          MinQVals |       -5.35e+03 |
# |            LossPi |         2.2e+03 |
# |             LossQ |        6.53e+03 |
# |              Time |             174 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |       -1.12e+03 |
# |          StdEpRet |        1.29e+03 |
# |          MaxEpRet |           -98.7 |
# |          MinEpRet |       -5.52e+03 |
# |  AverageTestEpRet |       -1.68e+03 |
# |      StdTestEpRet |        1.31e+03 |
# |      MaxTestEpRet |            -359 |
# |      MinTestEpRet |       -3.65e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.63e+04 |
# |      AverageQVals |       -2.18e+03 |
# |          StdQVals |             733 |
# |          MaxQVals |            -786 |
# |          MinQVals |       -5.35e+03 |
# |            LossPi |        2.16e+03 |
# |             LossQ |        6.42e+03 |
# |              Time |             182 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            -669 |
# |          StdEpRet |             443 |
# |          MaxEpRet |           -57.6 |
# |          MinEpRet |       -1.25e+03 |
# |  AverageTestEpRet |       -1.45e+03 |
# |      StdTestEpRet |        1.98e+03 |
# |      MaxTestEpRet |            -199 |
# |      MinTestEpRet |       -6.61e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.79e+04 |
# |      AverageQVals |       -2.14e+03 |
# |          StdQVals |             731 |
# |          MaxQVals |            -764 |
# |          MinQVals |       -5.42e+03 |
# |            LossPi |        2.12e+03 |
# |             LossQ |        6.49e+03 |
# |              Time |             190 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |        -1.2e+03 |
# |          StdEpRet |             748 |
# |          MaxEpRet |            -119 |
# |          MinEpRet |       -3.18e+03 |
# |  AverageTestEpRet |            -671 |
# |      StdTestEpRet |             317 |
# |      MaxTestEpRet |           -74.5 |
# |      MinTestEpRet |       -1.02e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        3.96e+04 |
# |      AverageQVals |        -2.1e+03 |
# |          StdQVals |             723 |
# |          MaxQVals |            -733 |
# |          MinQVals |       -5.39e+03 |
# |            LossPi |        2.08e+03 |
# |             LossQ |        6.37e+03 |
# |              Time |             198 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |        -1.6e+03 |
# |          StdEpRet |        1.33e+03 |
# |          MaxEpRet |            -293 |
# |          MinEpRet |        -5.6e+03 |
# |  AverageTestEpRet |       -1.65e+03 |
# |      StdTestEpRet |        1.79e+03 |
# |      MaxTestEpRet |            -195 |
# |      MinTestEpRet |       -6.57e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.12e+04 |
# |      AverageQVals |       -2.06e+03 |
# |          StdQVals |             718 |
# |          MaxQVals |            -706 |
# |          MinQVals |       -5.34e+03 |
# |            LossPi |        2.05e+03 |
# |             LossQ |        6.45e+03 |
# |              Time |             206 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |       -1.09e+03 |
# |          StdEpRet |             750 |
# |          MaxEpRet |            -192 |
# |          MinEpRet |       -2.85e+03 |
# |  AverageTestEpRet |       -1.08e+03 |
# |      StdTestEpRet |        1.02e+03 |
# |      MaxTestEpRet |           -73.8 |
# |      MinTestEpRet |       -3.24e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.29e+04 |
# |      AverageQVals |       -2.02e+03 |
# |          StdQVals |             712 |
# |          MaxQVals |            -678 |
# |          MinQVals |       -5.28e+03 |
# |            LossPi |           2e+03 |
# |             LossQ |        6.46e+03 |
# |              Time |             214 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            -670 |
# |          StdEpRet |             368 |
# |          MaxEpRet |            -154 |
# |          MinEpRet |       -1.56e+03 |
# |  AverageTestEpRet |            -928 |
# |      StdTestEpRet |             583 |
# |      MaxTestEpRet |           -41.7 |
# |      MinTestEpRet |       -1.72e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.45e+04 |
# |      AverageQVals |       -1.97e+03 |
# |          StdQVals |             702 |
# |          MaxQVals |            -646 |
# |          MinQVals |       -5.26e+03 |
# |            LossPi |        1.95e+03 |
# |             LossQ |        6.25e+03 |
# |              Time |             221 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            -870 |
# |          StdEpRet |             978 |
# |          MaxEpRet |            -153 |
# |          MinEpRet |       -3.88e+03 |
# |  AverageTestEpRet |       -1.09e+03 |
# |      StdTestEpRet |             940 |
# |      MaxTestEpRet |            -189 |
# |      MinTestEpRet |       -3.58e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.62e+04 |
# |      AverageQVals |       -1.92e+03 |
# |          StdQVals |             695 |
# |          MaxQVals |            -615 |
# |          MinQVals |        -5.2e+03 |
# |            LossPi |        1.91e+03 |
# |             LossQ |        6.12e+03 |
# |              Time |             229 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |            -900 |
# |          StdEpRet |             703 |
# |          MaxEpRet |            -156 |
# |          MinEpRet |       -3.09e+03 |
# |  AverageTestEpRet |       -1.01e+03 |
# |      StdTestEpRet |             427 |
# |      MaxTestEpRet |            -335 |
# |      MinTestEpRet |       -1.67e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.78e+04 |
# |      AverageQVals |       -1.87e+03 |
# |          StdQVals |             684 |
# |          MaxQVals |            -583 |
# |          MinQVals |       -5.19e+03 |
# |            LossPi |        1.85e+03 |
# |             LossQ |        6.08e+03 |
# |              Time |             237 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            -895 |
# |          StdEpRet |             654 |
# |          MaxEpRet |            -173 |
# |          MinEpRet |       -2.66e+03 |
# |  AverageTestEpRet |            -594 |
# |      StdTestEpRet |             477 |
# |      MaxTestEpRet |           -48.5 |
# |      MinTestEpRet |       -1.35e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        4.95e+04 |
# |      AverageQVals |       -1.82e+03 |
# |          StdQVals |             677 |
# |          MaxQVals |            -558 |
# |          MinQVals |       -5.07e+03 |
# |            LossPi |        1.81e+03 |
# |             LossQ |        5.91e+03 |
# |              Time |             245 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |       -1.34e+03 |
# |          StdEpRet |        1.15e+03 |
# |          MaxEpRet |            -232 |
# |          MinEpRet |       -3.91e+03 |
# |  AverageTestEpRet |       -1.01e+03 |
# |      StdTestEpRet |             641 |
# |      MaxTestEpRet |            -102 |
# |      MinTestEpRet |       -2.25e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.11e+04 |
# |      AverageQVals |       -1.77e+03 |
# |          StdQVals |             660 |
# |          MaxQVals |            -538 |
# |          MinQVals |          -5e+03 |
# |            LossPi |        1.76e+03 |
# |             LossQ |        5.68e+03 |
# |              Time |             253 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |            -748 |
# |          StdEpRet |             365 |
# |          MaxEpRet |            -174 |
# |          MinEpRet |       -1.48e+03 |
# |  AverageTestEpRet |            -821 |
# |      StdTestEpRet |             481 |
# |      MaxTestEpRet |            -290 |
# |      MinTestEpRet |       -1.73e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.28e+04 |
# |      AverageQVals |       -1.73e+03 |
# |          StdQVals |             644 |
# |          MaxQVals |            -513 |
# |          MinQVals |       -4.89e+03 |
# |            LossPi |        1.71e+03 |
# |             LossQ |         5.6e+03 |
# |              Time |             261 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            -633 |
# |          StdEpRet |             398 |
# |          MaxEpRet |           -98.7 |
# |          MinEpRet |       -1.49e+03 |
# |  AverageTestEpRet |       -1.05e+03 |
# |      StdTestEpRet |        1.23e+03 |
# |      MaxTestEpRet |            -133 |
# |      MinTestEpRet |       -4.59e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.44e+04 |
# |      AverageQVals |       -1.68e+03 |
# |          StdQVals |             632 |
# |          MaxQVals |            -491 |
# |          MinQVals |       -4.87e+03 |
# |            LossPi |        1.67e+03 |
# |             LossQ |        5.51e+03 |
# |              Time |             269 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |       -1.12e+03 |
# |          StdEpRet |             694 |
# |          MaxEpRet |            -330 |
# |          MinEpRet |       -2.97e+03 |
# |  AverageTestEpRet |            -806 |
# |      StdTestEpRet |             519 |
# |      MaxTestEpRet |            -200 |
# |      MinTestEpRet |       -1.98e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.61e+04 |
# |      AverageQVals |       -1.64e+03 |
# |          StdQVals |             621 |
# |          MaxQVals |            -468 |
# |          MinQVals |       -4.78e+03 |
# |            LossPi |        1.63e+03 |
# |             LossQ |        5.37e+03 |
# |              Time |             277 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |            -502 |
# |          StdEpRet |             456 |
# |          MaxEpRet |           -68.6 |
# |          MinEpRet |       -1.73e+03 |
# |  AverageTestEpRet |            -744 |
# |      StdTestEpRet |             196 |
# |      MaxTestEpRet |            -344 |
# |      MinTestEpRet |            -925 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.77e+04 |
# |      AverageQVals |       -1.59e+03 |
# |          StdQVals |             607 |
# |          MaxQVals |            -447 |
# |          MinQVals |       -4.64e+03 |
# |            LossPi |        1.58e+03 |
# |             LossQ |        5.56e+03 |
# |              Time |             285 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            -679 |
# |          StdEpRet |             344 |
# |          MaxEpRet |            -101 |
# |          MinEpRet |       -1.31e+03 |
# |  AverageTestEpRet |            -928 |
# |      StdTestEpRet |             791 |
# |      MaxTestEpRet |            -156 |
# |      MinTestEpRet |       -2.28e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        5.94e+04 |
# |      AverageQVals |       -1.54e+03 |
# |          StdQVals |             587 |
# |          MaxQVals |            -420 |
# |          MinQVals |       -4.54e+03 |
# |            LossPi |        1.53e+03 |
# |             LossQ |        5.12e+03 |
# |              Time |             293 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            -920 |
# |          StdEpRet |             612 |
# |          MaxEpRet |            -138 |
# |          MinEpRet |       -2.19e+03 |
# |  AverageTestEpRet |            -698 |
# |      StdTestEpRet |             257 |
# |      MaxTestEpRet |            -283 |
# |      MinTestEpRet |       -1.26e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.1e+04 |
# |      AverageQVals |       -1.49e+03 |
# |          StdQVals |             572 |
# |          MaxQVals |            -395 |
# |          MinQVals |       -4.39e+03 |
# |            LossPi |        1.47e+03 |
# |             LossQ |        4.64e+03 |
# |              Time |             301 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            -633 |
# |          StdEpRet |             570 |
# |          MaxEpRet |             -86 |
# |          MinEpRet |       -2.55e+03 |
# |  AverageTestEpRet |            -808 |
# |      StdTestEpRet |             691 |
# |      MaxTestEpRet |            -131 |
# |      MinTestEpRet |       -2.64e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.27e+04 |
# |      AverageQVals |       -1.44e+03 |
# |          StdQVals |             561 |
# |          MaxQVals |            -367 |
# |          MinQVals |       -4.33e+03 |
# |            LossPi |        1.42e+03 |
# |             LossQ |        4.65e+03 |
# |              Time |             309 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            -790 |
# |          StdEpRet |             781 |
# |          MaxEpRet |            -147 |
# |          MinEpRet |       -3.48e+03 |
# |  AverageTestEpRet |            -775 |
# |      StdTestEpRet |             406 |
# |      MaxTestEpRet |           -93.4 |
# |      MinTestEpRet |       -1.36e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.43e+04 |
# |      AverageQVals |       -1.38e+03 |
# |          StdQVals |             543 |
# |          MaxQVals |            -341 |
# |          MinQVals |       -4.22e+03 |
# |            LossPi |        1.36e+03 |
# |             LossQ |        4.42e+03 |
# |              Time |             317 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            -913 |
# |          StdEpRet |             888 |
# |          MaxEpRet |            -184 |
# |          MinEpRet |       -3.94e+03 |
# |  AverageTestEpRet |            -693 |
# |      StdTestEpRet |             830 |
# |      MaxTestEpRet |            -105 |
# |      MinTestEpRet |       -2.48e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         6.6e+04 |
# |      AverageQVals |       -1.33e+03 |
# |          StdQVals |             528 |
# |          MaxQVals |            -318 |
# |          MinQVals |       -4.07e+03 |
# |            LossPi |        1.31e+03 |
# |             LossQ |        4.21e+03 |
# |              Time |             325 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |            -655 |
# |          StdEpRet |             392 |
# |          MaxEpRet |            -103 |
# |          MinEpRet |       -1.69e+03 |
# |  AverageTestEpRet |            -557 |
# |      StdTestEpRet |             256 |
# |      MaxTestEpRet |           -62.3 |
# |      MinTestEpRet |            -872 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.76e+04 |
# |      AverageQVals |       -1.29e+03 |
# |          StdQVals |             517 |
# |          MaxQVals |            -300 |
# |          MinQVals |       -3.95e+03 |
# |            LossPi |        1.28e+03 |
# |             LossQ |        4.06e+03 |
# |              Time |             333 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            -407 |
# |          StdEpRet |             297 |
# |          MaxEpRet |           -26.8 |
# |          MinEpRet |            -997 |
# |  AverageTestEpRet |            -914 |
# |      StdTestEpRet |             760 |
# |      MaxTestEpRet |             -76 |
# |      MinTestEpRet |       -2.97e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        6.93e+04 |
# |      AverageQVals |       -1.25e+03 |
# |          StdQVals |             505 |
# |          MaxQVals |            -287 |
# |          MinQVals |        -3.9e+03 |
# |            LossPi |        1.24e+03 |
# |             LossQ |        3.98e+03 |
# |              Time |             341 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            -693 |
# |          StdEpRet |             590 |
# |          MaxEpRet |            -118 |
# |          MinEpRet |       -2.57e+03 |
# |  AverageTestEpRet |            -907 |
# |      StdTestEpRet |             669 |
# |      MaxTestEpRet |            -126 |
# |      MinTestEpRet |       -2.08e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.09e+04 |
# |      AverageQVals |       -1.22e+03 |
# |          StdQVals |             505 |
# |          MaxQVals |            -271 |
# |          MinQVals |       -3.87e+03 |
# |            LossPi |        1.21e+03 |
# |             LossQ |        3.88e+03 |
# |              Time |             349 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |            -692 |
# |          StdEpRet |             470 |
# |          MaxEpRet |           -94.4 |
# |          MinEpRet |       -1.61e+03 |
# |  AverageTestEpRet |            -528 |
# |      StdTestEpRet |             171 |
# |      MaxTestEpRet |            -297 |
# |      MinTestEpRet |            -857 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.26e+04 |
# |      AverageQVals |       -1.19e+03 |
# |          StdQVals |             498 |
# |          MaxQVals |            -252 |
# |          MinQVals |       -3.82e+03 |
# |            LossPi |        1.18e+03 |
# |             LossQ |        3.79e+03 |
# |              Time |             356 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            -946 |
# |          StdEpRet |             734 |
# |          MaxEpRet |           -99.4 |
# |          MinEpRet |       -2.75e+03 |
# |  AverageTestEpRet |       -1.12e+03 |
# |      StdTestEpRet |             818 |
# |      MaxTestEpRet |            -125 |
# |      MinTestEpRet |       -2.98e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.42e+04 |
# |      AverageQVals |       -1.15e+03 |
# |          StdQVals |             490 |
# |          MaxQVals |            -236 |
# |          MinQVals |        -3.7e+03 |
# |            LossPi |        1.14e+03 |
# |             LossQ |        3.85e+03 |
# |              Time |             364 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            -586 |
# |          StdEpRet |             443 |
# |          MaxEpRet |           -66.4 |
# |          MinEpRet |        -1.4e+03 |
# |  AverageTestEpRet |       -1.24e+03 |
# |      StdTestEpRet |             898 |
# |      MaxTestEpRet |           -71.4 |
# |      MinTestEpRet |       -2.87e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.59e+04 |
# |      AverageQVals |       -1.12e+03 |
# |          StdQVals |             480 |
# |          MaxQVals |            -224 |
# |          MinQVals |       -3.68e+03 |
# |            LossPi |        1.11e+03 |
# |             LossQ |        3.62e+03 |
# |              Time |             372 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |          -1e+03 |
# |          StdEpRet |             719 |
# |          MaxEpRet |            -136 |
# |          MinEpRet |       -2.61e+03 |
# |  AverageTestEpRet |            -898 |
# |      StdTestEpRet |             586 |
# |      MaxTestEpRet |            -214 |
# |      MinTestEpRet |       -2.16e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.75e+04 |
# |      AverageQVals |       -1.09e+03 |
# |          StdQVals |             476 |
# |          MaxQVals |            -213 |
# |          MinQVals |       -3.57e+03 |
# |            LossPi |        1.08e+03 |
# |             LossQ |        3.58e+03 |
# |              Time |             380 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |            -649 |
# |          StdEpRet |             358 |
# |          MaxEpRet |           -91.1 |
# |          MinEpRet |       -1.38e+03 |
# |  AverageTestEpRet |            -736 |
# |      StdTestEpRet |             335 |
# |      MaxTestEpRet |            -351 |
# |      MinTestEpRet |       -1.32e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        7.92e+04 |
# |      AverageQVals |       -1.06e+03 |
# |          StdQVals |             466 |
# |          MaxQVals |            -197 |
# |          MinQVals |       -3.54e+03 |
# |            LossPi |        1.05e+03 |
# |             LossQ |        3.66e+03 |
# |              Time |             387 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |       -1.16e+03 |
# |          StdEpRet |        1.03e+03 |
# |          MaxEpRet |            -118 |
# |          MinEpRet |       -3.55e+03 |
# |  AverageTestEpRet |       -1.17e+03 |
# |      StdTestEpRet |        1.56e+03 |
# |      MaxTestEpRet |            -169 |
# |      MinTestEpRet |       -5.74e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.08e+04 |
# |      AverageQVals |       -1.03e+03 |
# |          StdQVals |             455 |
# |          MaxQVals |            -182 |
# |          MinQVals |       -3.42e+03 |
# |            LossPi |        1.02e+03 |
# |             LossQ |        3.54e+03 |
# |              Time |             395 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            -550 |
# |          StdEpRet |             357 |
# |          MaxEpRet |            -128 |
# |          MinEpRet |       -1.48e+03 |
# |  AverageTestEpRet |            -654 |
# |      StdTestEpRet |             461 |
# |      MaxTestEpRet |           -78.3 |
# |      MinTestEpRet |       -1.46e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.25e+04 |
# |      AverageQVals |            -994 |
# |          StdQVals |             452 |
# |          MaxQVals |            -171 |
# |          MinQVals |       -3.44e+03 |
# |            LossPi |             984 |
# |             LossQ |        3.19e+03 |
# |              Time |             403 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |            -848 |
# |          StdEpRet |             676 |
# |          MaxEpRet |           -44.6 |
# |          MinEpRet |       -2.53e+03 |
# |  AverageTestEpRet |       -1.01e+03 |
# |      StdTestEpRet |             668 |
# |      MaxTestEpRet |            -299 |
# |      MinTestEpRet |       -2.59e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.41e+04 |
# |      AverageQVals |            -964 |
# |          StdQVals |             446 |
# |          MaxQVals |            -156 |
# |          MinQVals |       -3.37e+03 |
# |            LossPi |             954 |
# |             LossQ |        3.34e+03 |
# |              Time |             411 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |            -531 |
# |          StdEpRet |             589 |
# |          MaxEpRet |           -82.2 |
# |          MinEpRet |       -2.56e+03 |
# |  AverageTestEpRet |            -790 |
# |      StdTestEpRet |             390 |
# |      MaxTestEpRet |            -295 |
# |      MinTestEpRet |       -1.59e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.58e+04 |
# |      AverageQVals |            -933 |
# |          StdQVals |             441 |
# |          MaxQVals |            -144 |
# |          MinQVals |       -3.34e+03 |
# |            LossPi |             922 |
# |             LossQ |        3.17e+03 |
# |              Time |             419 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |            -904 |
# |          StdEpRet |             514 |
# |          MaxEpRet |            -252 |
# |          MinEpRet |       -2.38e+03 |
# |  AverageTestEpRet |            -717 |
# |      StdTestEpRet |             470 |
# |      MaxTestEpRet |           -96.2 |
# |      MinTestEpRet |       -1.42e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.74e+04 |
# |      AverageQVals |            -899 |
# |          StdQVals |             432 |
# |          MaxQVals |            -127 |
# |          MinQVals |       -3.29e+03 |
# |            LossPi |             888 |
# |             LossQ |        3.25e+03 |
# |              Time |             427 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |            -766 |
# |          StdEpRet |             575 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |       -2.07e+03 |
# |  AverageTestEpRet |            -614 |
# |      StdTestEpRet |             322 |
# |      MaxTestEpRet |            -255 |
# |      MinTestEpRet |       -1.23e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        8.91e+04 |
# |      AverageQVals |            -865 |
# |          StdQVals |             424 |
# |          MaxQVals |            -114 |
# |          MinQVals |       -3.15e+03 |
# |            LossPi |             855 |
# |             LossQ |        2.97e+03 |
# |              Time |             434 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |            -504 |
# |          StdEpRet |             339 |
# |          MaxEpRet |             -59 |
# |          MinEpRet |       -1.02e+03 |
# |  AverageTestEpRet |            -853 |
# |      StdTestEpRet |             407 |
# |      MaxTestEpRet |            -248 |
# |      MinTestEpRet |       -1.63e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        9.07e+04 |
# |      AverageQVals |            -837 |
# |          StdQVals |             419 |
# |          MaxQVals |            -103 |
# |          MinQVals |       -3.16e+03 |
# |            LossPi |             826 |
# |             LossQ |        2.98e+03 |
# |              Time |             443 |
# ---------------------------------------
# ---------------------------------------
# ...
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              82 |
# |      AverageEpRet |            -634 |
# |          StdEpRet |             424 |
# |          MaxEpRet |            -113 |
# |          MinEpRet |       -1.65e+03 |
# |  AverageTestEpRet |            -580 |
# |      StdTestEpRet |             281 |
# |      MaxTestEpRet |            -301 |
# |      MinTestEpRet |       -1.04e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.35e+05 |
# |      AverageQVals |            -168 |
# |          StdQVals |             284 |
# |          MaxQVals |             314 |
# |          MinQVals |       -1.94e+03 |
# |            LossPi |             158 |
# |             LossQ |         1.5e+03 |
# |              Time |             656 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              83 |
# |      AverageEpRet |            -602 |
# |          StdEpRet |             401 |
# |          MaxEpRet |           -57.2 |
# |          MinEpRet |       -1.53e+03 |
# |  AverageTestEpRet |            -887 |
# |      StdTestEpRet |             469 |
# |      MaxTestEpRet |           -97.8 |
# |      MinTestEpRet |       -1.51e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.37e+05 |
# |      AverageQVals |            -144 |
# |          StdQVals |             281 |
# |          MaxQVals |             342 |
# |          MinQVals |        -1.9e+03 |
# |            LossPi |             134 |
# |             LossQ |        1.42e+03 |
# |              Time |             664 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              84 |
# |      AverageEpRet |            -770 |
# |          StdEpRet |             518 |
# |          MaxEpRet |           -59.6 |
# |          MinEpRet |       -1.83e+03 |
# |  AverageTestEpRet |            -945 |
# |      StdTestEpRet |        1.44e+03 |
# |      MaxTestEpRet |            -135 |
# |      MinTestEpRet |       -5.15e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.39e+05 |
# |      AverageQVals |            -123 |
# |          StdQVals |             280 |
# |          MaxQVals |             360 |
# |          MinQVals |       -1.81e+03 |
# |            LossPi |             113 |
# |             LossQ |        1.45e+03 |
# |              Time |             672 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              85 |
# |      AverageEpRet |            -862 |
# |          StdEpRet |             586 |
# |          MaxEpRet |            -264 |
# |          MinEpRet |       -2.82e+03 |
# |  AverageTestEpRet |            -680 |
# |      StdTestEpRet |             334 |
# |      MaxTestEpRet |            -175 |
# |      MinTestEpRet |       -1.15e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.4e+05 |
# |      AverageQVals |           -98.8 |
# |          StdQVals |             275 |
# |          MaxQVals |             376 |
# |          MinQVals |       -1.78e+03 |
# |            LossPi |            88.4 |
# |             LossQ |        1.36e+03 |
# |              Time |             679 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              86 |
# |      AverageEpRet |            -665 |
# |          StdEpRet |             745 |
# |          MaxEpRet |           -80.4 |
# |          MinEpRet |       -3.16e+03 |
# |  AverageTestEpRet |            -765 |
# |      StdTestEpRet |             428 |
# |      MaxTestEpRet |            -297 |
# |      MinTestEpRet |       -1.82e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.42e+05 |
# |      AverageQVals |             -74 |
# |          StdQVals |             269 |
# |          MaxQVals |             394 |
# |          MinQVals |       -1.77e+03 |
# |            LossPi |            63.9 |
# |             LossQ |        1.38e+03 |
# |              Time |             687 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              87 |
# |      AverageEpRet |            -861 |
# |          StdEpRet |             483 |
# |          MaxEpRet |            -205 |
# |          MinEpRet |          -2e+03 |
# |  AverageTestEpRet |            -591 |
# |      StdTestEpRet |             226 |
# |      MaxTestEpRet |            -258 |
# |      MinTestEpRet |            -897 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.44e+05 |
# |      AverageQVals |           -51.8 |
# |          StdQVals |             265 |
# |          MaxQVals |             413 |
# |          MinQVals |       -1.65e+03 |
# |            LossPi |            41.4 |
# |             LossQ |        1.29e+03 |
# |              Time |             695 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              88 |
# |      AverageEpRet |            -778 |
# |          StdEpRet |             447 |
# |          MaxEpRet |           -59.1 |
# |          MinEpRet |       -1.64e+03 |
# |  AverageTestEpRet |            -521 |
# |      StdTestEpRet |             259 |
# |      MaxTestEpRet |            -201 |
# |      MinTestEpRet |       -1.04e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.45e+05 |
# |      AverageQVals |           -30.3 |
# |          StdQVals |             264 |
# |          MaxQVals |             438 |
# |          MinQVals |       -1.64e+03 |
# |            LossPi |              20 |
# |             LossQ |        1.23e+03 |
# |              Time |             703 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              89 |
# |      AverageEpRet |            -587 |
# |          StdEpRet |             369 |
# |          MaxEpRet |           -20.9 |
# |          MinEpRet |       -1.36e+03 |
# |  AverageTestEpRet |            -776 |
# |      StdTestEpRet |             569 |
# |      MaxTestEpRet |            -145 |
# |      MinTestEpRet |       -2.06e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.47e+05 |
# |      AverageQVals |           -8.82 |
# |          StdQVals |             258 |
# |          MaxQVals |             445 |
# |          MinQVals |       -1.57e+03 |
# |            LossPi |           -1.48 |
# |             LossQ |        1.27e+03 |
# |              Time |             711 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              90 |
# |      AverageEpRet |            -792 |
# |          StdEpRet |             300 |
# |          MaxEpRet |            -241 |
# |          MinEpRet |       -1.26e+03 |
# |  AverageTestEpRet |            -549 |
# |      StdTestEpRet |             340 |
# |      MaxTestEpRet |            -166 |
# |      MinTestEpRet |       -1.18e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.48e+05 |
# |      AverageQVals |            13.8 |
# |          StdQVals |             255 |
# |          MaxQVals |             479 |
# |          MinQVals |       -1.56e+03 |
# |            LossPi |           -24.3 |
# |             LossQ |        1.21e+03 |
# |              Time |             719 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              91 |
# |      AverageEpRet |            -823 |
# |          StdEpRet |             335 |
# |          MaxEpRet |            -296 |
# |          MinEpRet |        -1.4e+03 |
# |  AverageTestEpRet |            -740 |
# |      StdTestEpRet |             330 |
# |      MaxTestEpRet |            -236 |
# |      MinTestEpRet |       -1.24e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.5e+05 |
# |      AverageQVals |            37.3 |
# |          StdQVals |             253 |
# |          MaxQVals |             474 |
# |          MinQVals |       -1.49e+03 |
# |            LossPi |           -47.9 |
# |             LossQ |        1.12e+03 |
# |              Time |             727 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              92 |
# |      AverageEpRet |            -723 |
# |          StdEpRet |             352 |
# |          MaxEpRet |            -289 |
# |          MinEpRet |       -1.56e+03 |
# |  AverageTestEpRet |            -505 |
# |      StdTestEpRet |             181 |
# |      MaxTestEpRet |            -338 |
# |      MinTestEpRet |            -987 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.52e+05 |
# |      AverageQVals |            57.8 |
# |          StdQVals |             249 |
# |          MaxQVals |             492 |
# |          MinQVals |       -1.55e+03 |
# |            LossPi |           -67.8 |
# |             LossQ |        1.09e+03 |
# |              Time |             735 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              93 |
# |      AverageEpRet |            -913 |
# |          StdEpRet |             789 |
# |          MaxEpRet |           -99.3 |
# |          MinEpRet |       -3.29e+03 |
# |  AverageTestEpRet |       -1.04e+03 |
# |      StdTestEpRet |         1.2e+03 |
# |      MaxTestEpRet |            -254 |
# |      MinTestEpRet |        -4.6e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.53e+05 |
# |      AverageQVals |              75 |
# |          StdQVals |             250 |
# |          MaxQVals |             513 |
# |          MinQVals |       -1.45e+03 |
# |            LossPi |           -85.2 |
# |             LossQ |             974 |
# |              Time |             743 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              94 |
# |      AverageEpRet |            -584 |
# |          StdEpRet |             371 |
# |          MaxEpRet |            -160 |
# |          MinEpRet |       -1.45e+03 |
# |  AverageTestEpRet |       -1.14e+03 |
# |      StdTestEpRet |        1.37e+03 |
# |      MaxTestEpRet |            -133 |
# |      MinTestEpRet |       -5.06e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.55e+05 |
# |      AverageQVals |              96 |
# |          StdQVals |             247 |
# |          MaxQVals |             532 |
# |          MinQVals |        -1.4e+03 |
# |            LossPi |            -107 |
# |             LossQ |           1e+03 |
# |              Time |             750 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              95 |
# |      AverageEpRet |            -744 |
# |          StdEpRet |             398 |
# |          MaxEpRet |            -204 |
# |          MinEpRet |       -1.89e+03 |
# |  AverageTestEpRet |            -539 |
# |      StdTestEpRet |             343 |
# |      MaxTestEpRet |            -122 |
# |      MinTestEpRet |       -1.08e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.57e+05 |
# |      AverageQVals |             117 |
# |          StdQVals |             246 |
# |          MaxQVals |             550 |
# |          MinQVals |       -1.37e+03 |
# |            LossPi |            -128 |
# |             LossQ |             959 |
# |              Time |             758 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              96 |
# |      AverageEpRet |            -581 |
# |          StdEpRet |             370 |
# |          MaxEpRet |            -152 |
# |          MinEpRet |       -1.33e+03 |
# |  AverageTestEpRet |       -1.02e+03 |
# |      StdTestEpRet |             686 |
# |      MaxTestEpRet |            -464 |
# |      MinTestEpRet |       -2.92e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.58e+05 |
# |      AverageQVals |             139 |
# |          StdQVals |             241 |
# |          MaxQVals |             572 |
# |          MinQVals |       -1.37e+03 |
# |            LossPi |            -149 |
# |             LossQ |             933 |
# |              Time |             767 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              97 |
# |      AverageEpRet |            -621 |
# |          StdEpRet |             303 |
# |          MaxEpRet |            -169 |
# |          MinEpRet |       -1.32e+03 |
# |  AverageTestEpRet |            -808 |
# |      StdTestEpRet |             507 |
# |      MaxTestEpRet |            -103 |
# |      MinTestEpRet |       -1.79e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |         1.6e+05 |
# |      AverageQVals |             156 |
# |          StdQVals |             240 |
# |          MaxQVals |             575 |
# |          MinQVals |       -1.43e+03 |
# |            LossPi |            -166 |
# |             LossQ |             882 |
# |              Time |             775 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              98 |
# |      AverageEpRet |            -703 |
# |          StdEpRet |             340 |
# |          MaxEpRet |            -182 |
# |          MinEpRet |       -1.29e+03 |
# |  AverageTestEpRet |            -491 |
# |      StdTestEpRet |             279 |
# |      MaxTestEpRet |            -200 |
# |      MinTestEpRet |       -1.11e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.62e+05 |
# |      AverageQVals |             174 |
# |          StdQVals |             240 |
# |          MaxQVals |             590 |
# |          MinQVals |       -1.34e+03 |
# |            LossPi |            -185 |
# |             LossQ |             907 |
# |              Time |             782 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              99 |
# |      AverageEpRet |            -588 |
# |          StdEpRet |             244 |
# |          MaxEpRet |            -153 |
# |          MinEpRet |       -1.02e+03 |
# |  AverageTestEpRet |            -737 |
# |      StdTestEpRet |             319 |
# |      MaxTestEpRet |            -364 |
# |      MinTestEpRet |        -1.3e+03 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.63e+05 |
# |      AverageQVals |             192 |
# |          StdQVals |             238 |
# |          MaxQVals |             608 |
# |          MinQVals |       -1.42e+03 |
# |            LossPi |            -202 |
# |             LossQ |             840 |
# |              Time |             790 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |             100 |
# |      AverageEpRet |            -614 |
# |          StdEpRet |             313 |
# |          MaxEpRet |            -178 |
# |          MinEpRet |       -1.31e+03 |
# |  AverageTestEpRet |            -584 |
# |      StdTestEpRet |             254 |
# |      MaxTestEpRet |            -127 |
# |      MinTestEpRet |            -950 |
# |             EpLen |             110 |
# |         TestEpLen |             110 |
# | TotalEnvInteracts |        1.65e+05 |
# |      AverageQVals |             207 |
# |          StdQVals |             238 |
# |          MaxQVals |             638 |
# |          MinQVals |        -1.4e+03 |
# |            LossPi |            -217 |
# |             LossQ |             860 |
# |              Time |             798 |
# ---------------------------------------

# %% [markdown]
# #### Normalized reward

# %%
# Setup baseline 0
logger_kwargs = dict(output_dir='ddpg_discontinuous_normalized', exp_name='Discontinuity and normalized reward function')
seed_b = 0
epochs_b = 100
maxeplen_b = 110

spe_b = maxeplen_b * 15
repsize_b = 1000000
gamma_b = 0.995
polyak_b = 0.995
batchsize_b = 100
startsteps_b = 10000
args_b = dict(hidden_sizes=[400,], activation=torch.nn.ReLU)
actnoise_b = 0.1
pilr_b = 0.001
qlr_b = 0.001

# Env function
reward_args = {'k': 0.2}
env_fn = partial(env_fn,env_name = 'gyroscopediscontinuousenv-v0',reward_type = 'Normalized', reward_args = reward_args)

# Baseline 0 training
spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
# Out:
# Logging data to ddpg_discontinuous_normalized/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             400
#         ]
#     },
#     "act_noise":	0.1,
#     "actor_critic":	"MLPActorCritic",
#     "batch_size":	100,
#     "env_fn":	"functools.partial(functools.partial(functools.partial(<function env_fn at 0x7fda02cd5ea0>, env_name='gyroscopediscontinuousenv-v0', reward_type='Quadratic', reward_args={'qx1': 9, 'qx2': 0.05, 'qx3': 9, 'qx4': 0.05, 'pu1': 0.1, 'pu2': 0.1}), env_name='gyroscopediscontinuousenv-v0', reward_type='Normalized', reward_args={'k': 0.2}), env_name='gyroscopediscontinuousenv-v0', reward_type='Normalized', reward_args={'k': 0.2})",
#     "epochs":	100,
#     "exp_name":	"Discontinuity and normalized reward function",
#     "gamma":	0.995,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fd9cbc705c0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"Discontinuity and normalized reward function",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"ddpg_discontinuous_normalized",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='ddpg_discontinuous_normalized/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"Discontinuity and normalized reward function",
#         "output_dir":	"ddpg_discontinuous_normalized"
#     },
#     "max_ep_len":	110,
#     "num_test_episodes":	10,
#     "pi_lr":	0.001,
#     "polyak":	0.995,
#     "q_lr":	0.001,
#     "replay_size":	1000000,
#     "save_freq":	1,
#     "seed":	0,
#     "start_steps":	10000,
#     "steps_per_epoch":	1650,
#     "update_after":	1000,
#     "update_every":	50
# }
#
# Number of parameters: 	 pi: 4002, 	 q: 4401
# /home/matthieulc/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-13bd13ad1359> in <module>
#      22 # Baseline 0 training
#      23 spinup.ddpg_pytorch(env_fn, ac_kwargs = args_b, seed = seed_b, steps_per_epoch = spe_b, epochs = epochs_b, replay_size = repsize_b, gamma = gamma_b,
# ---> 24 polyak = polyak_b, batch_size = batchsize_b, start_steps = startsteps_b, max_ep_len = maxeplen_b,logger_kwargs = logger_kwargs, act_noise = actnoise_b, pi_lr = pilr_b, q_lr = qlr_b)
#
# ~/Documents/MA2/ps-drl-for-gyroscope-control/resources/spinningup/spinup/algos/pytorch/ddpg/ddpg.py in ddpg(env_fn, actor_critic, ac_kwargs, seed, steps_per_epoch, epochs, replay_size, gamma, polyak, pi_lr, q_lr, batch_size, start_steps, update_after, update_every, act_noise, num_test_episodes, max_ep_len, logger_kwargs, save_freq)
#     281             for _ in range(update_every):
#     282                 batch = replay_buffer.sample_batch(batch_size)
# --> 283                 update(data=batch)
#     284
#     285         # End of epoch handling
#
# ~/Documents/MA2/ps-drl-for-gyroscope-control/resources/spinningup/spinup/algos/pytorch/ddpg/ddpg.py in update(data)
#     222                 # params, as opposed to "mul" and "add", which would make new tensors.
#     223                 p_targ.data.mul_(polyak)
# --> 224                 p_targ.data.add_((1 - polyak) * p.data)
#     225
#     226     def get_action(o, noise_scale):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test

# %%
# Test paramaters
env_name = 'gyroscopediscontinuousenv-v0'
reward_type = 'Quadratic'
reward_args = {'qx1':1,'qx2':0,'qx3':1,'qx4':0,'pu1':0,'pu2':0} # reward for mean squared error
seed = 2
agent_path = 'ddpg_discontinuous_normalized/pyt_save/model.pt'
init_state = [0,0,0,0,-np.pi,0,200*2*np.pi/60] 
t_end = 100*0.05

# Get Q-values (spinup implementation of ddpg core has been changed for that purpose by adding a method "crit"!)
obs_pi = [np.pi*0.95,-0.000005,0,0,-np.pi,0,20]
obs_minuspi = [-np.pi*0.95,-0.000005,0,0,-np.pi,0,20]
act_plus = [10,0] # positive voltage on u1 (for theta) to make it turn towards pi
act_minus = [0,0] # negative voltage on u1 (for theta) to make it turn towards -pi
agent = torch.load(agent_path)

Q_pi_plus = agent.crit(torch.as_tensor(obs_pi, dtype=torch.float32),torch.as_tensor(act_plus, dtype=torch.float32))
Q_pi_minus = agent.crit(torch.as_tensor(obs_pi, dtype=torch.float32),torch.as_tensor(act_minus, dtype=torch.float32))
print("Q-value for [u1,u2] = {} at state s = {}: {}".format(act_plus,obs_pi,Q_pi_plus))
print("Q-value for [u1,u2] = {} at state s = {}: {}".format(act_minus,obs_pi,Q_pi_minus))

Q_minuspi_plus = agent.crit(torch.as_tensor(obs_minuspi, dtype=torch.float32),torch.as_tensor(act_plus, dtype=torch.float32))
Q_minuspi_minus = agent.crit(torch.as_tensor(obs_minuspi, dtype=torch.float32),torch.as_tensor(act_minus, dtype=torch.float32))
print("Q-value for [u1,u2] = {} at state s = {}: {}".format(act_plus,obs_minuspi,Q_minuspi_plus))
print("Q-value for [u1,u2] = {} at state s = {}: {}".format(act_minus,obs_minuspi,Q_minuspi_minus))


# Perform testing
agent_path = 'ddpg_discontinuous_normalized'
r,score,x1_eval,x2_eval,x3_eval,x4_eval,x1_ref_eval,x3_ref_eval,act = test_agent(env_name,reward_type,reward_args,seed,agent_path,init_state,t_end,ep_len=110)
# Out:
# Q-value for [u1,u2] = [10, 0] at state s = [2.9845130209103035, -5e-06, 0, 0, -3.141592653589793, 0, 20]: -56.37056350708008
# Q-value for [u1,u2] = [0, 0] at state s = [2.9845130209103035, -5e-06, 0, 0, -3.141592653589793, 0, 20]: -56.78080368041992
# Q-value for [u1,u2] = [10, 0] at state s = [-2.9845130209103035, -5e-06, 0, 0, -3.141592653589793, 0, 20]: -54.60612869262695
# Q-value for [u1,u2] = [0, 0] at state s = [-2.9845130209103035, -5e-06, 0, 0, -3.141592653589793, 0, 20]: -53.63178634643555
# Total cumulative reward: -58.04309932253662
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/torch/serialization.py:493: SourceChangeWarning: source code of class 'torch.nn.modules.container.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /home/matthieulc/Documents/MA2/DRLGyro/resources/drlgyroenv/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ## Plot

# %%
time = np.linspace(0, t_end, len(x1_eval))

plt.figure(figsize=(10,7))
plt.title(r'',fontsize=20, y=1.05)
plt.xlabel('Time [s]',fontsize=16)
plt.ylabel('Angular position [°]',fontsize=16)
plt.ylim([-200,200])
plt.xlim([0,5])
plt.grid()


# RL Agent
plt.plot(time,180*(x1_eval)/np.pi,'r',label=r'$\theta$')

# Reference
plt.plot(time, 180*x1_ref_eval/np.pi, color='black',label=r'Reference on $\theta$ at $\pm 180$°')
plt.plot(time, -180*x1_ref_eval/np.pi, color='black')

plt.legend()
plt.savefig('discont.pgf')
